# %% [markdown]
# ## Importing important libraries

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import nibabel as nib #for loading nii files
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf #for deep learning

# %% [markdown]
# ## Reading the metadata

# %%
data = pd.read_csv('../input/covid19-ct-scans/metadata.csv')
data.head()
# Out:
#                                              ct_scan  \
# 0  ../input/covid19-ct-scans/ct_scans/coronacases...
# 1  ../input/covid19-ct-scans/ct_scans/coronacases...
# 2  ../input/covid19-ct-scans/ct_scans/coronacases...
# 3  ../input/covid19-ct-scans/ct_scans/coronacases...
# 4  ../input/covid19-ct-scans/ct_scans/coronacases...
#
#                                            lung_mask  \
# 0  ../input/covid19-ct-scans/lung_mask/coronacase...
# 1  ../input/covid19-ct-scans/lung_mask/coronacase...
# 2  ../input/covid19-ct-scans/lung_mask/coronacase...
# 3  ../input/covid19-ct-scans/lung_mask/coronacase...
# 4  ../input/covid19-ct-scans/lung_mask/coronacase...
#
#                                       infection_mask  \
# 0  ../input/covid19-ct-scans/infection_mask/coron...
# 1  ../input/covid19-ct-scans/infection_mask/coron...
# 2  ../input/covid19-ct-scans/infection_mask/coron...
# 3  ../input/covid19-ct-scans/infection_mask/coron...
# 4  ../input/covid19-ct-scans/infection_mask/coron...
#
#                              lung_and_infection_mask
# 0  ../input/covid19-ct-scans/lung_and_infection_m...
# 1  ../input/covid19-ct-scans/lung_and_infection_m...
# 2  ../input/covid19-ct-scans/lung_and_infection_m...
# 3  ../input/covid19-ct-scans/lung_and_infection_m...
# 4  ../input/covid19-ct-scans/lung_and_infection_m...

# %% [markdown]
# ## Defining function for readiing .nii files

# %%
def read_nii(filepath):
    '''
    Reads .nii file and returns pixel array
    '''
    ct_scan = nib.load(filepath)
    array   = ct_scan.get_fdata()
    array   = np.rot90(np.array(array))
    return(array)

# %% [markdown]
# ## Reading the chest ct scan data

# %%
# Read sample
sample_ct   = read_nii(data.loc[2,'ct_scan'])
sample_lung = read_nii(data.loc[2,'lung_mask'])
sample_infe = read_nii(data.loc[2,'infection_mask'])
sample_all  = read_nii(data.loc[2,'lung_and_infection_mask'])

# %% [markdown]
# ## Plotting the sample images

# %%
fig = plt.figure(figsize = (18,15))
plt.subplot(1,4,1)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.title('Original Image')

plt.subplot(1,4,2)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_lung[..., 150],alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung Mask')

plt.subplot(1,4,3)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_infe[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Infection Mask')

plt.subplot(1,4,4)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_all[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung and Infection Mask')
# Out:
# Text(0.5, 1.0, 'Lung and Infection Mask')

# %% [markdown]
# ## Converting the data into array for training model

# %%
import numpy as np
import cv2
import random
from scipy.ndimage import rotate, shift, zoom

lungs = []
infections = []
case_ids = []
img_size = 320

# ----------- Load and Resize Data -----------
for case_index in range(len(data)):
    ct = read_nii(data['ct_scan'][case_index])
    infect = read_nii(data['infection_mask'][case_index])

    for slice_index in range(ct.shape[0]):
        lung_img = cv2.resize(ct[slice_index], dsize=(img_size, img_size)).astype('float32')
        infec_img = cv2.resize(infect[slice_index], dsize=(img_size, img_size)).astype('float32')

        lungs.append(lung_img[..., np.newaxis])
        infections.append(infec_img[..., np.newaxis])
        case_ids.append(case_index)

# %%
import numpy as np

# case_ids should be a NumPy array telling which case each slice belongs to
# Convert and binarize
lungs = np.array(lungs, dtype=np.float32)
infections = (np.array(infections, dtype=np.uint8) > 0.5).astype(np.uint8)
case_ids = np.array(case_ids)

# %% [markdown]
# ## Performing test and train split

# %%
# ----------- Case-wise Split -----------
unique_cases = np.unique(case_ids)
train_cases = np.append(unique_cases[2:4], unique_cases[6:20])
temp_cases = unique_cases[4:6]
val_cases = unique_cases[:2]

train_mask = np.isin(case_ids, train_cases)
temp_mask = np.isin(case_ids, temp_cases)
val_mask = np.isin(case_ids, val_cases)

lung_train = lungs[train_mask]
infect_train = infections[train_mask]
lung_temp = lungs[temp_mask]
infect_temp = infections[temp_mask]
lung_test = lungs[val_mask]
infect_test = infections[val_mask]

print(f"✅ Train: {lung_train.shape[0]} slices from {len(train_cases)} cases")
print(f"✅ Validation: {lung_temp.shape[0]} slices from {len(temp_cases)} cases")
print(f"✅ Test: {lung_test.shape[0]} slices from {len(val_cases)} cases")

# ----------- Augmentation -----------
def augment_image(img, mask):
    if random.random() < 0.5:
        img = np.fliplr(img)
        mask = np.fliplr(mask)
    if random.random() < 0.5:
        img = np.flipud(img)
        mask = np.flipud(mask)

    angle = random.uniform(-15, 15)
    img = rotate(img, angle, reshape=False, order=1, mode='nearest')
    mask = rotate(mask, angle, reshape=False, order=0, mode='nearest')

    shift_val = np.random.uniform(-0.1, 0.1, size=2) * img.shape[:2]
    img = shift(img, shift=(*shift_val, 0), order=1, mode='nearest')
    mask = shift(mask, shift=(*shift_val, 0), order=0, mode='nearest')

    zoom_factor = random.uniform(0.9, 1.1)
    img = zoom(img, (zoom_factor, zoom_factor, 1), order=1)
    mask = zoom(mask, (zoom_factor, zoom_factor, 1), order=0)

    return fix_shape(img), fix_shape(mask)

def fix_shape(arr, target_size=(320, 320)):
    h, w, c = arr.shape
    th, tw = target_size
    dh = th - h
    dw = tw - w
    if dh > 0 or dw > 0:
        pad_h = (max(dh // 2, 0), max(dh - dh // 2, 0))
        pad_w = (max(dw // 2, 0), max(dw - dw // 2, 0))
        arr = np.pad(arr, (pad_h, pad_w, (0, 0)), mode='constant')
    arr = arr[:th, :tw, :]
    return arr.astype('float32')

# ----------- Apply Augmentation -----------
aug_lung_train = []
aug_infect_train = []

for i in range(len(lung_train)):
    img, mask = augment_image(lung_train[i], infect_train[i])
    aug_lung_train.append(img)
    aug_infect_train.append(mask)

lung_train = np.stack(aug_lung_train)
infect_train = np.stack(aug_infect_train)

# Final Binarization
infect_train = (infect_train > 0.5).astype(np.uint8)
infect_test = (infect_test > 0.5).astype(np.uint8)

print(f"✅ Augmented training shape: {lung_train.shape}")
print("✅ All preprocessing complete.")
# Out:
# ✅ Train: 9143 slices from 16 cases
# ✅ Validation: 1024 slices from 2 cases
# ✅ Test: 1024 slices from 2 cases
# ✅ Augmented training shape: (9143, 320, 320, 1)
# ✅ All preprocessing complete.

# %%
import tensorflow as tf
from tensorflow.keras import backend as K
import numpy as np
from scipy.spatial import cKDTree

smooth = 1.0

# Binary Dice coefficient (soft - commonly used during training)
def dice_coef_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# Binary IoU coefficient (soft)
def iou_coef_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# Soft Precision
def precision_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + smooth) / (K.sum(y_pred_f) + smooth)

# Soft Recall (Sensitivity)
def recall_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + smooth) / (K.sum(y_true_f) + smooth)

# Soft Specificity
def specificity_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    tn = K.sum((1 - y_true_f) * (1 - y_pred_f))
    fp = K.sum((1 - y_true_f) * y_pred_f)
    return (tn + smooth) / (tn + fp + smooth)

# Soft Accuracy
def accuracy_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    tp = K.sum(y_true_f * y_pred_f)
    tn = K.sum((1 - y_true_f) * (1 - y_pred_f))
    total = K.cast(K.shape(y_true_f)[0], 'float32')
    return (tp + tn + smooth) / (total + smooth)

# Soft F1-score (harmonic mean of precision & recall - very close to Dice, standard in many repos)
def f1_infection(y_true, y_pred):
    precision = precision_infection(y_true, y_pred)
    recall    = recall_infection(y_true, y_pred)
    return (2. * precision * recall + smooth) / (precision + recall + smooth)

# Hausdorff Distance 95 % (robust & most commonly used in medical imaging challenges)
# Lower = better. Returns the mean HD95 over the batch.
def _calculate_hd95(y_true, y_pred):
    hd_list = []
    for i in range(y_true.shape[0]):
        # Hard threshold at 0.5 (standard for evaluation metrics)
        gt = np.squeeze(y_true[i]) > 0.5
        pred = np.squeeze(y_pred[i]) > 0.5

        gt_pts = np.argwhere(gt)
        pred_pts = np.argwhere(pred)

        # Cases with empty masks
        if gt_pts.shape[0] == 0 and pred_pts.shape[0] == 0:
            hd_list.append(0.0)
            continue
        if gt_pts.shape[0] == 0 or pred_pts.shape[0] == 0:
            hd_list.append(400.0)  # large penalty - adjust to your image diagonal if needed (e.g. ~362 for 256×256, ~724 for 512×512)
            continue

        # Directed distances
        dist_gt_to_pred = cKDTree(pred_pts).query(gt_pts)[0]
        dist_pred_to_gt = cKDTree(gt_pts).query(pred_pts)[0]

        hd95 = max(
            np.percentile(dist_gt_to_pred, 95),
            np.percentile(dist_pred_to_gt, 95)
        )
        hd_list.append(hd95)

    return np.mean(hd_list, dtype=np.float32)

def hausdorff95_infection(y_true, y_pred):
    hd = tf.numpy_function(_calculate_hd95, [y_true, y_pred], tf.float32)
    hd.set_shape(())
    return hd

# Optional: KL Divergence (you already had this)
kld = tf.keras.losses.KLDivergence()

# %%
from tensorflow.keras.losses import BinaryCrossentropy

def loss_f(y_true, y_pred):
    bce = BinaryCrossentropy()
    return dice_loss(y_true, y_pred) + bce(y_true, y_pred) 

def loss_e(y_true, y_pred):
    bce = BinaryCrossentropy()
    return dice_loss(y_true, y_pred)  + kld(y_true, y_pred)
    
def dice_loss(y_true, y_pred):
    return 1. - dice_coef_infection(y_true, y_pred)

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Multiply, Conv2D, DepthwiseConv2D, Dense, Flatten, MaxPooling2D, UpSampling2D, concatenate, Activation, LayerNormalization, Add, Dropout, Conv2DTranspose, multiply, Reshape, GlobalAveragePooling2D, Permute, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Concatenate

def activation_block(x):
    x = Activation("gelu")(x)
    return LayerNormalization()(x)

def conv_stem(x, filters: int, patch_size: int):
    x = Conv2D(filters, kernel_size=patch_size,padding='same', strides=patch_size)(x)
    return activation_block(x)

def vector_block(xyz, cmf, red):
    # red means reduction
    # cmf means filters, denotes vector size
    opt1 = conv_stem(xyz, cmf, red)
    opt2 = conv_stem(xyz, cmf, red)
    
    o1 = GlobalAveragePooling2D()(opt1)
    o2 = GlobalAveragePooling2D()(opt2)

    o5 = concatenate([o1, o2], -1)
    return o5

def mlp_feature(vect, cmf):
    oo = Flatten()(vect)
    o6 = Dense(cmf, activation='gelu')(oo)
    o6 = Dropout(0.2)(o6)
    o6 = Dense(cmf * 2, activation='gelu')(o6)

    o6 = Reshape((1, cmf * 2))(o6)
    o7 = Permute((2, 1))(o6)

    o8 = multiply([o6, o7])
    
    o8 = Lambda(lambda x: tf.expand_dims(x, -1))(o8)
    
    o8 = Reshape((cmf, cmf, 4))(o8)

    return o8

def frz_block(xyz):
    shape = xyz.shape
    a1, a2, a3, a4 = shape[0], shape[1], shape[2], shape[3]
    cmf = a2
    o5 = vector_block(xyz, cmf, 5)
    o7 = mlp_feature(o5, cmf)

    o7 = concatenate([o7, xyz, o7], -1)
    return o7

def up_frz(x1, x2, n_filters):
    # Upsample x1 using Conv2DTranspose
    x1 = Conv2DTranspose(n_filters * 4, 3, strides=2, activation='gelu', padding="same")(x1)
    
    # Apply Conv2D to x2
    x2 = Conv2D(n_filters * 2, 3, activation='gelu', padding="same")(x2)
    
    # Apply attention mechanism
    x = concatenate([x1, x2])
    
    # Apply Dropout for regularization
    x = Dropout(0.3)(x)
    
    return x

# %%
# !pip install keras-unet-collection

# !pip show keras-unet-collection
# !ls /opt/conda/lib/python3.7/site-packages/keras_unet_collection/
# !cp -r /opt/conda/lib/python3.7/site-packages/keras_unet_collection ./custom_keras_unet_collection
import re

# Define the ViT_block function
transunet_2d_base_code = """
def transunet_2d_base(input_tensor, filter_num, stack_num_down=2, stack_num_up=2, 
                      embed_dim=768, num_mlp=3072, num_heads=12, num_transformer=12,
                      activation='ReLU', mlp_activation='GELU', batch_norm=False, pool=True, unpool=True, 
                      backbone=None, weights='imagenet', freeze_backbone=True, freeze_batch_norm=True, name='transunet'):
    '''
    The base of transUNET with an optional ImageNet-trained backbone.
    '''
    activation_func = eval(activation)
    
    X_skip = []
    depth_ = len(filter_num)
    
    # ----- internal parameters ----- #
    
    patch_size = 1
    input_size = input_tensor.shape[1]
    encode_size = input_size // 2**(depth_-1)
    num_patches = encode_size ** 2 
    key_dim = embed_dim // num_heads
    filter_num_MLP = [num_mlp, embed_dim]
    
    # ----- UNet-like downsampling ----- #
    
    if backbone is None:
        X = input_tensor
        X = CONV_stack(X, filter_num[0], stack_num=stack_num_down, activation=activation, 
                       batch_norm=batch_norm, name='{}_down0'.format(name))
        X_skip.append(X)
        
        for i, f in enumerate(filter_num[1:]):
            X = UNET_left(X, f, stack_num=stack_num_down, activation=activation, pool=pool, 
                          batch_norm=batch_norm, name='{}_down{}'.format(name, i+1))        
            X_skip.append(X)
    else:
        if 'VGG' in backbone:
            backbone_ = backbone_zoo(backbone, weights, input_tensor, depth_, freeze_backbone, freeze_batch_norm)
            X_skip = backbone_([input_tensor,])
            depth_encode = len(X_skip)
        else:
            backbone_ = backbone_zoo(backbone, weights, input_tensor, depth_-1, freeze_backbone, freeze_batch_norm)
            X_skip = backbone_([input_tensor,])
            depth_encode = len(X_skip) + 1
        
        if depth_encode < depth_:
            X = X_skip[-1]
            for i in range(depth_-depth_encode):
                i_real = i + depth_encode
                X = UNET_left(X, filter_num[i_real], stack_num=stack_num_down, activation=activation, pool=pool, 
                              batch_norm=batch_norm, name='{}_down{}'.format(name, i_real+1))
                X_skip.append(X)
        
    X = X_skip[-1]
    X_skip = X_skip[:-1]

    X = Conv2D(filter_num[-1], 1, padding='valid', use_bias=False, name='{}_conv_trans_before'.format(name))(X)

    X = patch_extract((patch_size, patch_size))(X)
    X = patch_embedding(num_patches, embed_dim)(X)

    # stacked ViTs with block_index for each ViT block
    for i in range(num_transformer):
        X = ViT_block(X, num_heads, key_dim, filter_num_MLP, activation=mlp_activation, 
                      name='{}_ViT_{}'.format(name, i))  # Passing block_index as i

    X = tf.reshape(X, (-1, encode_size, encode_size, embed_dim))

    X = Conv2D(filter_num[-1], 3, padding='same', activation='relu', use_bias=False, name='{}_conv_trans_after'.format(name))(X)

    X_skip.append(X)
    
    # ----- UNet-like upsampling ----- #
    
    X_skip = X_skip[::-1]
    X = X_skip[0]
    X_decode = X_skip[1:]
    depth_decode = len(X_decode)
    filter_num_decode = filter_num[:-1][::-1]

    for i in range(depth_decode):
        X = UNET_right(X, [X_decode[i],], filter_num_decode[i], stack_num=stack_num_up, activation=activation, 
                       unpool=unpool, batch_norm=batch_norm, name='{}_up{}'.format(name, i))

    if depth_decode < depth_-1:
        for i in range(depth_-depth_decode-1):
            i_real = i + depth_decode
            X = UNET_right(X, None, filter_num_decode[i_real], stack_num=stack_num_up, activation=activation, 
                       unpool=unpool, batch_norm=batch_norm, concat=False, name='{}_up{}'.format(name, i_real))
            
    return X
"""

# Define the new code for the UNET_right function
unet_right_code = """
def UNET_right(X, X_list, channel, kernel_size=3, 
               stack_num=2, activation='ReLU',
               unpool=True, batch_norm=False, concat=True, name='right0'):
    '''
    The decoder block of U-net.
    
    Input
    ----------
        X: input tensor.
        X_list: a list of other tensors that connected to the input tensor.
        channel: number of convolution filters.
        kernel_size: size of 2-d convolution kernels.
        stack_num: number of convolutional layers.
        activation: one of the `tensorflow.keras.layers` interface, e.g., 'ReLU'.
        unpool: True or 'bilinear' for Upsampling2D with bilinear interpolation.
                'nearest' for Upsampling2D with nearest interpolation.
                False for Conv2DTranspose + batch norm + activation.
        batch_norm: True for batch normalization, False otherwise.
        concat: True for concatenating the corresponded X_list elements.
        name: prefix of the created keras layers.
        
    Output
    ----------
        X: output tensor.
    
    '''
    
    pool_size = 2
    
    X = decode_layer(X, channel, pool_size, unpool, 
                     activation=activation, batch_norm=batch_norm, name='{}_decode'.format(name))
    
    if concat:
        # <--- *stacked convolutional can be applied here
        X = concatenate([X,]+X_list, axis=3, name=name+'_concat')
    
    # Stacked convolutions after concatenation 
    X = CONV_stack(X, channel, kernel_size, stack_num=stack_num, activation=activation, 
                   batch_norm=batch_norm, name=name+'_conv_after_concat')
    
    return X
"""

# File path for _model_transunet_2d.py
file_path = "./custom_keras_unet_collection/_model_transunet_2d.py"

# Read the original file content
with open(file_path, "r") as f:
    original_content = f.read()

# Replace or append the new functions into the original content
updated_content = original_content + transunet_2d_base_code + unet_right_code

# Write the updated content back to the file
with open(file_path, "w") as f:
    f.write(updated_content)

print("Successfully updated _model_transunet_2d.py with the new functions.")

# Correct path to models.py
models_file_path = "./custom_keras_unet_collection/models.py"

# Define updated content
updated_models_content = """
from __future__ import absolute_import

from custom_keras_unet_collection._model_unet_2d import unet_2d
from custom_keras_unet_collection._model_vnet_2d import vnet_2d
from custom_keras_unet_collection._model_unet_plus_2d import unet_plus_2d
from custom_keras_unet_collection._model_r2_unet_2d import r2_unet_2d
from custom_keras_unet_collection._model_att_unet_2d import att_unet_2d
from custom_keras_unet_collection._model_resunet_a_2d import resunet_a_2d
from custom_keras_unet_collection._model_u2net_2d import u2net_2d
from custom_keras_unet_collection._model_unet_3plus_2d import unet_3plus_2d
from custom_keras_unet_collection._model_transunet_2d import transunet_2d
from custom_keras_unet_collection._model_swin_unet_2d import swin_unet_2d
"""

# Write the updated content
try:
    with open(models_file_path, "w") as f:
        f.write(updated_models_content)
    print("models.py updated successfully.")
except FileNotFoundError:
    print("models.py not found. Verify the path.")

from custom_keras_unet_collection.models import transunet_2d

# Define the input size
inputs = (img_size, img_size, 1)

model = transunet_2d(
    input_size=inputs,      # Input size for 256x256 RGB images
    filter_num=[16, 64, 128, 256, 512],  # Filters for encoder blocks
    n_labels=1,                    # Number of output classes
    stack_num_down=2,              # Convolution layers per encoder level
    stack_num_up=1,                # Convolution layers per decoder level
    embed_dim=768,                 # Transformer embedding dimension
    num_mlp=3072,                  # Feed-forward network dimension
    num_heads=12,                   # Multi-head attention heads
    num_transformer=12,             # Number of Transformer blocks
    activation='ReLU',             # Activation function
    mlp_activation='GELU',         # Activation for MLP layers
    output_activation='Sigmoid',   # Output activation
    batch_norm=True,               # Use batch normalization
    pool=True,                     # Use max pooling
    unpool=True, 
    backbone='ResNet50',
    freeze_backbone=False,
    weights=None,
    name='transunet'              # Model name
)
# Out:
# Collecting keras-unet-collection
#   Downloading keras_unet_collection-0.1.13-py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 4.2 MB/s  eta 0:00:01
# Installing collected packages: keras-unet-collection
# Successfully installed keras-unet-collection-0.1.13
# Name: keras-unet-collection
# Version: 0.1.13
# Summary: The Tensorflow, Keras implementation of U-net, V-net, U-net++, UNET 3+, Attention U-net, R2U-net, ResUnet-a, U^2-Net, TransUNET, and Swin-UNET with optional ImageNet-trained backbones.
# Home-page: https://github.com/yingkaisha/keras-unet-collection
# Author: Yingkai (Kyle) Sha
# Author-email: yingkaisha@gmail.com
# License: UNKNOWN
# Location: /opt/conda/lib/python3.7/site-packages
# Requires:
# Required-by:
# __init__.py		_model_unet_3plus_2d.py  model_r2_unet_2d.py
# __pycache__		_model_unet_plus_2d.py	 model_resunet_a_2d.py
# _backbone_zoo.py	_model_vnet_2d.py	 model_u2net_2d.py
# _model_att_unet_2d.py	activations.py		 model_unet_2d.py
# _model_r2_unet_2d.py	backbones.py		 model_unet_3plus_2d.py
# _model_resunet_a_2d.py	base.py			 model_unet_plus_2d.py
# _model_swin_unet_2d.py	layer_utils.py		 models.py
# _model_transunet_2d.py	loss.py			 transformer_layers.py
# _model_u2net_2d.py	losses.py		 utils.py
# _model_unet_2d.py	model_att_unet_2d.py
# Successfully updated _model_transunet_2d.py with the new functions.
# models.py updated successfully.

# %%
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2_as_graph

def get_flops(model):
    """Calculate Floating Point Operations (FLOPs) of a Keras model in TensorFlow 2.x."""
    # Convert Keras model to a TensorFlow function
    concrete_func = tf.function(lambda inputs: model(inputs))
    concrete_func = concrete_func.get_concrete_function(
        tf.TensorSpec([1] + list(model.input_shape[1:]), model.input.dtype)
    )

    # Convert to frozen graph
    frozen_func, _ = convert_variables_to_constants_v2_as_graph(concrete_func)

    # Compute FLOPs
    flops = tf.compat.v1.profiler.profile(
        frozen_func.graph,
        options=tf.compat.v1.profiler.ProfileOptionBuilder.float_operation(),
    )

    return flops.total_float_ops

# Compute FLOPs
flops = get_flops(model)
print(f"Total FLOPs: {flops / 1e9:.2f} GFLOPs")  # Convert to GFLOPs

from tensorflow.keras.optimizers import Adam

optimizer = Adam(learning_rate=1e-3)
model.compile(optimizer=optimizer, loss=loss_f, metrics=[dice_coef_infection, iou_coef_infection, precision_infection, recall_infection, hausdorff95_infection, specificity_infection, accuracy_infection, f1_infection])

# Model summary
model.summary()
# Out:
# Total FLOPs: 84.21 GFLOPs
# Model: "transunet_model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 320, 320, 1) 0
# __________________________________________________________________________________________________
# ResNet50_backbone (Functional)  [(None, 160, 160, 64 8582912     input_1[0][0]
# __________________________________________________________________________________________________
# transunet_conv_trans_before (Co (None, 20, 20, 512)  524288      ResNet50_backbone[0][3]
# __________________________________________________________________________________________________
# patch_extract (patch_extract)   (None, 400, 512)     0           transunet_conv_trans_before[0][0]
# __________________________________________________________________________________________________
# patch_embedding (patch_embeddin (None, 400, 768)     701184      patch_extract[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_0_layer_norm_1 (L (None, 400, 768)     1536        patch_embedding[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_0_atten (MultiHea (None, 400, 768)     2362368     transunet_ViT_0_layer_norm_1[0][0
#                                                                  transunet_ViT_0_layer_norm_1[0][0
# __________________________________________________________________________________________________
# transunet_ViT_0_skip_1 (Add)    (None, 400, 768)     0           transunet_ViT_0_atten[0][0]
#                                                                  patch_embedding[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_0_layer_norm_2 (L (None, 400, 768)     1536        transunet_ViT_0_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_0_mlp_dense_0 (De (None, 400, 3072)    2362368     transunet_ViT_0_layer_norm_2[0][0
# __________________________________________________________________________________________________
# transunet_ViT_0_mlp_activation_ (None, 400, 3072)    0           transunet_ViT_0_mlp_dense_0[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_0_mlp_dense_1 (De (None, 400, 768)     2360064     transunet_ViT_0_mlp_activation_0[
# __________________________________________________________________________________________________
# transunet_ViT_0_mlp_activation_ (None, 400, 768)     0           transunet_ViT_0_mlp_dense_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_0_skip_2 (Add)    (None, 400, 768)     0           transunet_ViT_0_mlp_activation_1[
#                                                                  transunet_ViT_0_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_1_layer_norm_1 (L (None, 400, 768)     1536        transunet_ViT_0_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_1_atten (MultiHea (None, 400, 768)     2362368     transunet_ViT_1_layer_norm_1[0][0
#                                                                  transunet_ViT_1_layer_norm_1[0][0
# __________________________________________________________________________________________________
# transunet_ViT_1_skip_1 (Add)    (None, 400, 768)     0           transunet_ViT_1_atten[0][0]
#                                                                  transunet_ViT_0_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_1_layer_norm_2 (L (None, 400, 768)     1536        transunet_ViT_1_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_1_mlp_dense_0 (De (None, 400, 3072)    2362368     transunet_ViT_1_layer_norm_2[0][0
# __________________________________________________________________________________________________
# transunet_ViT_1_mlp_activation_ (None, 400, 3072)    0           transunet_ViT_1_mlp_dense_0[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_1_mlp_dense_1 (De (None, 400, 768)     2360064     transunet_ViT_1_mlp_activation_0[
# __________________________________________________________________________________________________
# transunet_ViT_1_mlp_activation_ (None, 400, 768)     0           transunet_ViT_1_mlp_dense_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_1_skip_2 (Add)    (None, 400, 768)     0           transunet_ViT_1_mlp_activation_1[
#                                                                  transunet_ViT_1_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_2_layer_norm_1 (L (None, 400, 768)     1536        transunet_ViT_1_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_2_atten (MultiHea (None, 400, 768)     2362368     transunet_ViT_2_layer_norm_1[0][0
#                                                                  transunet_ViT_2_layer_norm_1[0][0
# __________________________________________________________________________________________________
# transunet_ViT_2_skip_1 (Add)    (None, 400, 768)     0           transunet_ViT_2_atten[0][0]
#                                                                  transunet_ViT_1_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_2_layer_norm_2 (L (None, 400, 768)     1536        transunet_ViT_2_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_2_mlp_dense_0 (De (None, 400, 3072)    2362368     transunet_ViT_2_layer_norm_2[0][0
# __________________________________________________________________________________________________
# transunet_ViT_2_mlp_activation_ (None, 400, 3072)    0           transunet_ViT_2_mlp_dense_0[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_2_mlp_dense_1 (De (None, 400, 768)     2360064     transunet_ViT_2_mlp_activation_0[
# __________________________________________________________________________________________________
# transunet_ViT_2_mlp_activation_ (None, 400, 768)     0           transunet_ViT_2_mlp_dense_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_2_skip_2 (Add)    (None, 400, 768)     0           transunet_ViT_2_mlp_activation_1[
#                                                                  transunet_ViT_2_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_3_layer_norm_1 (L (None, 400, 768)     1536        transunet_ViT_2_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_3_atten (MultiHea (None, 400, 768)     2362368     transunet_ViT_3_layer_norm_1[0][0
#                                                                  transunet_ViT_3_layer_norm_1[0][0
# __________________________________________________________________________________________________
# transunet_ViT_3_skip_1 (Add)    (None, 400, 768)     0           transunet_ViT_3_atten[0][0]
#                                                                  transunet_ViT_2_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_3_layer_norm_2 (L (None, 400, 768)     1536        transunet_ViT_3_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_3_mlp_dense_0 (De (None, 400, 3072)    2362368     transunet_ViT_3_layer_norm_2[0][0
# __________________________________________________________________________________________________
# transunet_ViT_3_mlp_activation_ (None, 400, 3072)    0           transunet_ViT_3_mlp_dense_0[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_3_mlp_dense_1 (De (None, 400, 768)     2360064     transunet_ViT_3_mlp_activation_0[
# __________________________________________________________________________________________________
# transunet_ViT_3_mlp_activation_ (None, 400, 768)     0           transunet_ViT_3_mlp_dense_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_3_skip_2 (Add)    (None, 400, 768)     0           transunet_ViT_3_mlp_activation_1[
#                                                                  transunet_ViT_3_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_4_layer_norm_1 (L (None, 400, 768)     1536        transunet_ViT_3_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_4_atten (MultiHea (None, 400, 768)     2362368     transunet_ViT_4_layer_norm_1[0][0
#                                                                  transunet_ViT_4_layer_norm_1[0][0
# __________________________________________________________________________________________________
# transunet_ViT_4_skip_1 (Add)    (None, 400, 768)     0           transunet_ViT_4_atten[0][0]
#                                                                  transunet_ViT_3_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_4_layer_norm_2 (L (None, 400, 768)     1536        transunet_ViT_4_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_4_mlp_dense_0 (De (None, 400, 3072)    2362368     transunet_ViT_4_layer_norm_2[0][0
# __________________________________________________________________________________________________
# transunet_ViT_4_mlp_activation_ (None, 400, 3072)    0           transunet_ViT_4_mlp_dense_0[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_4_mlp_dense_1 (De (None, 400, 768)     2360064     transunet_ViT_4_mlp_activation_0[
# __________________________________________________________________________________________________
# transunet_ViT_4_mlp_activation_ (None, 400, 768)     0           transunet_ViT_4_mlp_dense_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_4_skip_2 (Add)    (None, 400, 768)     0           transunet_ViT_4_mlp_activation_1[
#                                                                  transunet_ViT_4_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_5_layer_norm_1 (L (None, 400, 768)     1536        transunet_ViT_4_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_5_atten (MultiHea (None, 400, 768)     2362368     transunet_ViT_5_layer_norm_1[0][0
#                                                                  transunet_ViT_5_layer_norm_1[0][0
# __________________________________________________________________________________________________
# transunet_ViT_5_skip_1 (Add)    (None, 400, 768)     0           transunet_ViT_5_atten[0][0]
#                                                                  transunet_ViT_4_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_5_layer_norm_2 (L (None, 400, 768)     1536        transunet_ViT_5_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_5_mlp_dense_0 (De (None, 400, 3072)    2362368     transunet_ViT_5_layer_norm_2[0][0
# __________________________________________________________________________________________________
# transunet_ViT_5_mlp_activation_ (None, 400, 3072)    0           transunet_ViT_5_mlp_dense_0[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_5_mlp_dense_1 (De (None, 400, 768)     2360064     transunet_ViT_5_mlp_activation_0[
# __________________________________________________________________________________________________
# transunet_ViT_5_mlp_activation_ (None, 400, 768)     0           transunet_ViT_5_mlp_dense_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_5_skip_2 (Add)    (None, 400, 768)     0           transunet_ViT_5_mlp_activation_1[
#                                                                  transunet_ViT_5_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_6_layer_norm_1 (L (None, 400, 768)     1536        transunet_ViT_5_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_6_atten (MultiHea (None, 400, 768)     2362368     transunet_ViT_6_layer_norm_1[0][0
#                                                                  transunet_ViT_6_layer_norm_1[0][0
# __________________________________________________________________________________________________
# transunet_ViT_6_skip_1 (Add)    (None, 400, 768)     0           transunet_ViT_6_atten[0][0]
#                                                                  transunet_ViT_5_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_6_layer_norm_2 (L (None, 400, 768)     1536        transunet_ViT_6_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_6_mlp_dense_0 (De (None, 400, 3072)    2362368     transunet_ViT_6_layer_norm_2[0][0
# __________________________________________________________________________________________________
# transunet_ViT_6_mlp_activation_ (None, 400, 3072)    0           transunet_ViT_6_mlp_dense_0[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_6_mlp_dense_1 (De (None, 400, 768)     2360064     transunet_ViT_6_mlp_activation_0[
# __________________________________________________________________________________________________
# transunet_ViT_6_mlp_activation_ (None, 400, 768)     0           transunet_ViT_6_mlp_dense_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_6_skip_2 (Add)    (None, 400, 768)     0           transunet_ViT_6_mlp_activation_1[
#                                                                  transunet_ViT_6_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_7_layer_norm_1 (L (None, 400, 768)     1536        transunet_ViT_6_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_7_atten (MultiHea (None, 400, 768)     2362368     transunet_ViT_7_layer_norm_1[0][0
#                                                                  transunet_ViT_7_layer_norm_1[0][0
# __________________________________________________________________________________________________
# transunet_ViT_7_skip_1 (Add)    (None, 400, 768)     0           transunet_ViT_7_atten[0][0]
#                                                                  transunet_ViT_6_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_7_layer_norm_2 (L (None, 400, 768)     1536        transunet_ViT_7_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_7_mlp_dense_0 (De (None, 400, 3072)    2362368     transunet_ViT_7_layer_norm_2[0][0
# __________________________________________________________________________________________________
# transunet_ViT_7_mlp_activation_ (None, 400, 3072)    0           transunet_ViT_7_mlp_dense_0[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_7_mlp_dense_1 (De (None, 400, 768)     2360064     transunet_ViT_7_mlp_activation_0[
# __________________________________________________________________________________________________
# transunet_ViT_7_mlp_activation_ (None, 400, 768)     0           transunet_ViT_7_mlp_dense_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_7_skip_2 (Add)    (None, 400, 768)     0           transunet_ViT_7_mlp_activation_1[
#                                                                  transunet_ViT_7_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_8_layer_norm_1 (L (None, 400, 768)     1536        transunet_ViT_7_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_8_atten (MultiHea (None, 400, 768)     2362368     transunet_ViT_8_layer_norm_1[0][0
#                                                                  transunet_ViT_8_layer_norm_1[0][0
# __________________________________________________________________________________________________
# transunet_ViT_8_skip_1 (Add)    (None, 400, 768)     0           transunet_ViT_8_atten[0][0]
#                                                                  transunet_ViT_7_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_8_layer_norm_2 (L (None, 400, 768)     1536        transunet_ViT_8_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_8_mlp_dense_0 (De (None, 400, 3072)    2362368     transunet_ViT_8_layer_norm_2[0][0
# __________________________________________________________________________________________________
# transunet_ViT_8_mlp_activation_ (None, 400, 3072)    0           transunet_ViT_8_mlp_dense_0[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_8_mlp_dense_1 (De (None, 400, 768)     2360064     transunet_ViT_8_mlp_activation_0[
# __________________________________________________________________________________________________
# transunet_ViT_8_mlp_activation_ (None, 400, 768)     0           transunet_ViT_8_mlp_dense_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_8_skip_2 (Add)    (None, 400, 768)     0           transunet_ViT_8_mlp_activation_1[
#                                                                  transunet_ViT_8_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_9_layer_norm_1 (L (None, 400, 768)     1536        transunet_ViT_8_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_9_atten (MultiHea (None, 400, 768)     2362368     transunet_ViT_9_layer_norm_1[0][0
#                                                                  transunet_ViT_9_layer_norm_1[0][0
# __________________________________________________________________________________________________
# transunet_ViT_9_skip_1 (Add)    (None, 400, 768)     0           transunet_ViT_9_atten[0][0]
#                                                                  transunet_ViT_8_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_9_layer_norm_2 (L (None, 400, 768)     1536        transunet_ViT_9_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_9_mlp_dense_0 (De (None, 400, 3072)    2362368     transunet_ViT_9_layer_norm_2[0][0
# __________________________________________________________________________________________________
# transunet_ViT_9_mlp_activation_ (None, 400, 3072)    0           transunet_ViT_9_mlp_dense_0[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_9_mlp_dense_1 (De (None, 400, 768)     2360064     transunet_ViT_9_mlp_activation_0[
# __________________________________________________________________________________________________
# transunet_ViT_9_mlp_activation_ (None, 400, 768)     0           transunet_ViT_9_mlp_dense_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_9_skip_2 (Add)    (None, 400, 768)     0           transunet_ViT_9_mlp_activation_1[
#                                                                  transunet_ViT_9_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_10_layer_norm_1 ( (None, 400, 768)     1536        transunet_ViT_9_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_10_atten (MultiHe (None, 400, 768)     2362368     transunet_ViT_10_layer_norm_1[0][
#                                                                  transunet_ViT_10_layer_norm_1[0][
# __________________________________________________________________________________________________
# transunet_ViT_10_skip_1 (Add)   (None, 400, 768)     0           transunet_ViT_10_atten[0][0]
#                                                                  transunet_ViT_9_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_10_layer_norm_2 ( (None, 400, 768)     1536        transunet_ViT_10_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_10_mlp_dense_0 (D (None, 400, 3072)    2362368     transunet_ViT_10_layer_norm_2[0][
# __________________________________________________________________________________________________
# transunet_ViT_10_mlp_activation (None, 400, 3072)    0           transunet_ViT_10_mlp_dense_0[0][0
# __________________________________________________________________________________________________
# transunet_ViT_10_mlp_dense_1 (D (None, 400, 768)     2360064     transunet_ViT_10_mlp_activation_0
# __________________________________________________________________________________________________
# transunet_ViT_10_mlp_activation (None, 400, 768)     0           transunet_ViT_10_mlp_dense_1[0][0
# __________________________________________________________________________________________________
# transunet_ViT_10_skip_2 (Add)   (None, 400, 768)     0           transunet_ViT_10_mlp_activation_1
#                                                                  transunet_ViT_10_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_11_layer_norm_1 ( (None, 400, 768)     1536        transunet_ViT_10_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_11_atten (MultiHe (None, 400, 768)     2362368     transunet_ViT_11_layer_norm_1[0][
#                                                                  transunet_ViT_11_layer_norm_1[0][
# __________________________________________________________________________________________________
# transunet_ViT_11_skip_1 (Add)   (None, 400, 768)     0           transunet_ViT_11_atten[0][0]
#                                                                  transunet_ViT_10_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_11_layer_norm_2 ( (None, 400, 768)     1536        transunet_ViT_11_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_11_mlp_dense_0 (D (None, 400, 3072)    2362368     transunet_ViT_11_layer_norm_2[0][
# __________________________________________________________________________________________________
# transunet_ViT_11_mlp_activation (None, 400, 3072)    0           transunet_ViT_11_mlp_dense_0[0][0
# __________________________________________________________________________________________________
# transunet_ViT_11_mlp_dense_1 (D (None, 400, 768)     2360064     transunet_ViT_11_mlp_activation_0
# __________________________________________________________________________________________________
# transunet_ViT_11_mlp_activation (None, 400, 768)     0           transunet_ViT_11_mlp_dense_1[0][0
# __________________________________________________________________________________________________
# transunet_ViT_11_skip_2 (Add)   (None, 400, 768)     0           transunet_ViT_11_mlp_activation_1
#                                                                  transunet_ViT_11_skip_1[0][0]
# __________________________________________________________________________________________________
# tf.reshape (TFOpLambda)         (None, 20, 20, 768)  0           transunet_ViT_11_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_conv_trans_after (Con (None, 20, 20, 512)  3538944     tf.reshape[0][0]
# __________________________________________________________________________________________________
# transunet_up0_decode_unpool (Up (None, 40, 40, 512)  0           transunet_conv_trans_after[0][0]
# __________________________________________________________________________________________________
# transunet_up0_concat (Concatena (None, 40, 40, 1024) 0           transunet_up0_decode_unpool[0][0]
#                                                                  ResNet50_backbone[0][2]
# __________________________________________________________________________________________________
# transunet_up0_conv_after_concat (None, 40, 40, 256)  2359296     transunet_up0_concat[0][0]
# __________________________________________________________________________________________________
# transunet_up0_conv_after_concat (None, 40, 40, 256)  1024        transunet_up0_conv_after_concat_0
# __________________________________________________________________________________________________
# transunet_up0_conv_after_concat (None, 40, 40, 256)  0           transunet_up0_conv_after_concat_0
# __________________________________________________________________________________________________
# transunet_up1_decode_unpool (Up (None, 80, 80, 256)  0           transunet_up0_conv_after_concat_0
# __________________________________________________________________________________________________
# transunet_up1_concat (Concatena (None, 80, 80, 512)  0           transunet_up1_decode_unpool[0][0]
#                                                                  ResNet50_backbone[0][1]
# __________________________________________________________________________________________________
# transunet_up1_conv_after_concat (None, 80, 80, 128)  589824      transunet_up1_concat[0][0]
# __________________________________________________________________________________________________
# transunet_up1_conv_after_concat (None, 80, 80, 128)  512         transunet_up1_conv_after_concat_0
# __________________________________________________________________________________________________
# transunet_up1_conv_after_concat (None, 80, 80, 128)  0           transunet_up1_conv_after_concat_0
# __________________________________________________________________________________________________
# transunet_up2_decode_unpool (Up (None, 160, 160, 128 0           transunet_up1_conv_after_concat_0
# __________________________________________________________________________________________________
# transunet_up2_concat (Concatena (None, 160, 160, 192 0           transunet_up2_decode_unpool[0][0]
#                                                                  ResNet50_backbone[0][0]
# __________________________________________________________________________________________________
# transunet_up2_conv_after_concat (None, 160, 160, 64) 110592      transunet_up2_concat[0][0]
# __________________________________________________________________________________________________
# transunet_up2_conv_after_concat (None, 160, 160, 64) 256         transunet_up2_conv_after_concat_0
# __________________________________________________________________________________________________
# transunet_up2_conv_after_concat (None, 160, 160, 64) 0           transunet_up2_conv_after_concat_0
# __________________________________________________________________________________________________
# transunet_up3_decode_unpool (Up (None, 320, 320, 64) 0           transunet_up2_conv_after_concat_0
# __________________________________________________________________________________________________
# transunet_up3_conv_after_concat (None, 320, 320, 16) 9216        transunet_up3_decode_unpool[0][0]
# __________________________________________________________________________________________________
# transunet_up3_conv_after_concat (None, 320, 320, 16) 64          transunet_up3_conv_after_concat_0
# __________________________________________________________________________________________________
# transunet_up3_conv_after_concat (None, 320, 320, 16) 0           transunet_up3_conv_after_concat_0
# __________________________________________________________________________________________________
# transunet_output (Conv2D)       (None, 320, 320, 1)  17          transunet_up3_conv_after_concat_0
# __________________________________________________________________________________________________
# transunet_output_activation (Ac (None, 320, 320, 1)  0           transunet_output[0][0]
# ==================================================================================================
# Total params: 101,472,593
# Trainable params: 101,441,073
# Non-trainable params: 31,520
# __________________________________________________________________________________________________

# %%
# Install required packages
# !pip install openpyxl

# Imports
import openpyxl  # required for reading .xlsx files
import pandas as pd
import tensorflow as tf
import os
import shutil
from tensorflow.keras.callbacks import LearningRateScheduler, ReduceLROnPlateau

# File paths
checkpoint_filepath = '/kaggle/working/checkpoint.h5.keras'
metrics_file = '/kaggle/working/training_metrics.xlsx'
pre_checkpoint_filepath = '/kaggle/input/transunet-covid19-finalrun-2/checkpoint.h5.keras'
pre_metrics_file = '/kaggle/input/transunet-covid19-finalrun-2/training_metrics.xlsx'

# Restore checkpoint and metrics if available
if os.path.exists(pre_checkpoint_filepath):
    shutil.copy(pre_checkpoint_filepath, checkpoint_filepath)
    print(f"Restored checkpoint from: {pre_checkpoint_filepath}")

if os.path.exists(pre_metrics_file):
    shutil.copy(pre_metrics_file, metrics_file)
    print(f"Restored metrics file from: {pre_metrics_file}")

# Load last epoch
def load_last_epoch():
    if os.path.exists(metrics_file):
        try:
            df = pd.read_excel(metrics_file, engine='openpyxl')
            if not df.empty and 'epoch' in df.columns:
                return df['epoch'].iloc[-1] + 1
        except Exception as e:
            print(f"⚠️ Could not read metrics file: {e}")
    return 0

last_epoch = load_last_epoch()

# Get best validation loss from previous runs
def get_best_val_loss():
    if os.path.exists(metrics_file):
        try:
            df = pd.read_excel(metrics_file, engine='openpyxl')
            if 'val_loss' in df.columns and not df['val_loss'].isnull().all():
                return df['val_loss'].min()
        except Exception as e:
            print(f"⚠️ Could not read val_loss from metrics file: {e}")
    return float('inf')

best_val_loss = get_best_val_loss()

# Custom model checkpoint
class CustomModelCheckpoint(tf.keras.callbacks.Callback):
    def __init__(self, filepath):
        super().__init__()
        self.filepath = filepath
        self.best_loss = best_val_loss

    def on_epoch_end(self, epoch, logs=None):
        current_loss = logs.get('val_loss')
        if current_loss is not None and current_loss < self.best_loss:
            self.best_loss = current_loss
            self.model.save(self.filepath)
            print(f"✅ Model saved at epoch {epoch + 1} with val_loss: {current_loss:.4f}")

# === Learning Rate Schedule ===
def lr_schedule(epoch, lr):
    return 1e-4 if epoch >= 1 else lr

lr_scheduler = LearningRateScheduler(lr_schedule, verbose=1)

# Logger for Excel
class MetricsLogger(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        df_new = pd.DataFrame([{**logs, 'epoch': epoch}])
        try:
            if os.path.exists(metrics_file):
                df = pd.read_excel(metrics_file, engine='openpyxl')
                df = pd.concat([df, df_new], ignore_index=True)
            else:
                df = df_new
            df.to_excel(metrics_file, index=False, engine='openpyxl')
        except Exception as e:
            print(f"⚠️ Failed to log metrics: {e}")

# Early stopping with patience and saving best weights
class CustomEarlyStopping(tf.keras.callbacks.Callback):
    def __init__(self, patience=20):
        super().__init__()
        self.patience = patience
        self.wait = 0
        self.best_loss = best_val_loss

    def on_epoch_end(self, epoch, logs=None):
        current_loss = logs.get('val_loss')
        if current_loss is None:
            return
        if current_loss < self.best_loss:
            self.best_loss = current_loss
            self.wait = 0
            self.model.save_weights(checkpoint_filepath)
        else:
            self.wait += 1
            if self.wait >= self.patience:
                print(f"🛑 Early stopping at epoch {epoch + 1}")
                self.model.stop_training = True


# Final callbacks list
callbacks = [
    CustomModelCheckpoint(filepath=checkpoint_filepath),
    MetricsLogger(),
    lr_scheduler,
    CustomEarlyStopping(patience=20)
]
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.3-py2.py3-none-any.whl (251 kB)
#      |████████████████████████████████| 251 kB 10.8 MB/s eta 0:00:01
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.3
# Restored checkpoint from: /kaggle/input/transunet-covid19-finalrun-2/checkpoint.h5.keras
# Restored metrics file from: /kaggle/input/transunet-covid19-finalrun-2/training_metrics.xlsx

# %% [markdown]
# ## Training the model

# %%
import time
import os
import pandas as pd
import numpy as np
from tensorflow.keras.utils import Sequence
from tensorflow.keras.models import load_model

EPOCHS = 100

# Record the start time
start_time = time.time()

# === Load last completed epoch from metrics file ===
def load_last_epoch():
    if os.path.exists(pre_metrics_file):
        try:
            df = pd.read_excel(pre_metrics_file, engine='openpyxl')
            if not df.empty and 'epoch' in df.columns:
                return int(df['epoch'].iloc[-1]) + 1
        except Exception as e:
            print(f"⚠️ Failed to read metrics file: {e}")
    return 0

last_epoch = load_last_epoch()

# === Load pretrained weights if available ===
if os.path.exists(pre_checkpoint_filepath):
    print("✅ Checkpoint found. Loading pretrained weights...")
    model.load_weights(pre_checkpoint_filepath)
    print(f"🔁 Resuming training from epoch {last_epoch}")
else:
    print("🆕 No checkpoint found. Starting training from scratch.")
    last_epoch = 0

# === Prepare input and label tensors ===
lung_train = np.asarray(lung_train, dtype=np.float16)
infect_train = np.asarray(infect_train, dtype=np.uint8)

lung_temp = np.asarray(lung_temp, dtype=np.float16)
infect_temp = np.asarray(infect_temp, dtype=np.uint8)

lung_test = np.asarray(lung_test, dtype=np.float16)
infect_test = np.asarray(infect_test, dtype=np.uint8)

# === Data Generator ===
class LungDataGenerator(Sequence):
    def __init__(self, X, Y, batch_size=8, shuffle=True):
        self.X = X
        self.Y = Y
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indices = np.arange(len(X))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.X) / self.batch_size))

    def __getitem__(self, index):
        batch_ids = self.indices[index * self.batch_size:(index + 1) * self.batch_size]
        X_batch = self.X[batch_ids]
        Y_batch = self.Y[batch_ids]
        return np.asarray(X_batch, dtype=np.float16), np.asarray(Y_batch, dtype=np.uint8)

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indices)

# === Create generators ===
train_gen = LungDataGenerator(lung_train, infect_train, batch_size=8)
temp_gen = LungDataGenerator(lung_temp, infect_temp, batch_size=8, shuffle=False)
val_gen = LungDataGenerator(lung_test, infect_test, batch_size=8, shuffle=False)

# === Train the model ===
history = model.fit(
    train_gen,
    validation_data=temp_gen,
    epochs=EPOCHS,
    initial_epoch=last_epoch,
    callbacks=callbacks
)

# === Timing info ===
end_time = time.time()
total_time = end_time - start_time
print(f"✅ Total training time: {total_time:.2f} seconds ({total_time / 60:.2f} minutes)")
# Out:
# ✅ Checkpoint found. Loading pretrained weights...
# 🔁 Resuming training from epoch 42
# Epoch 43/100
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 718s 609ms/step - loss: 0.3974 - dice_coef_infection: 0.6281 - iou_coef_infection: 0.4926 - precision_infection: 0.6504 - recall_infection: 0.6883 - hausdorff95_infection: 49.0736 - specificity_infection: 0.9974 - accuracy_infection: 0.9947 - f1_infection: 0.8136 - val_loss: 0.2098 - val_dice_coef_infection: 0.7960 - val_iou_coef_infection: 0.7734 - val_precision_infection: 0.8543 - val_recall_infection: 0.8735 - val_hausdorff95_infection: 19.0453 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.9178
# Epoch 44/100
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 692s 605ms/step - loss: 0.3800 - dice_coef_infection: 0.6446 - iou_coef_infection: 0.5063 - precision_infection: 0.6621 - recall_infection: 0.7025 - hausdorff95_infection: 48.5157 - specificity_infection: 0.9975 - accuracy_infection: 0.9949 - f1_infection: 0.8152 - val_loss: 0.2422 - val_dice_coef_infection: 0.7641 - val_iou_coef_infection: 0.7469 - val_precision_infection: 0.8385 - val_recall_infection: 0.8636 - val_hausdorff95_infection: 30.0769 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.9060
# Epoch 45/100
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 692s 605ms/step - loss: 0.3825 - dice_coef_infection: 0.6425 - iou_coef_infection: 0.5058 - precision_infection: 0.6493 - recall_infection: 0.7092 - hausdorff95_infection: 48.8539 - specificity_infection: 0.9972 - accuracy_infection: 0.9947 - f1_infection: 0.8166 - val_loss: 0.1902 - val_dice_coef_infection: 0.8210 - val_iou_coef_infection: 0.8020 - val_precision_infection: 0.9273 - val_recall_infection: 0.8416 - val_hausdorff95_infection: 32.9709 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9987 - val_f1_infection: 0.9214
# Epoch 46/100
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 691s 605ms/step - loss: 0.3862 - dice_coef_infection: 0.6380 - iou_coef_infection: 0.5051 - precision_infection: 0.6579 - recall_infection: 0.7028 - hausdorff95_infection: 46.6762 - specificity_infection: 0.9974 - accuracy_infection: 0.9950 - f1_infection: 0.8161 - val_loss: 0.1955 - val_dice_coef_infection: 0.8134 - val_iou_coef_infection: 0.7962 - val_precision_infection: 0.9255 - val_recall_infection: 0.8504 - val_hausdorff95_infection: 35.2000 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9989 - val_f1_infection: 0
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 691s 605ms/step - loss: 0.3950 - dice_coef_infection: 0.6303 - iou_coef_infection: 0.4958 - precision_infection: 0.6500 - recall_infection: 0.6823 - hausdorff95_infection: 57.1180 - specificity_infection: 0.9975 - accuracy_infection: 0.9948 - f1_infection: 0.8181 - val_loss: 0.2024 - val_dice_coef_infection: 0.8040 - val_iou_coef_infection: 0.7818 - val_precision_infection: 0.8554 - val_recall_infection: 0.8740 - val_hausdorff95_infection: 17.0682 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.9231
# 🛑 Early stopping at epoch 71
# ✅ Total training time: 20093.62 seconds (334.89 minutes)

# %% [markdown]
# ## Plotting the performance metrics

# %%
plt.plot(history.history['dice_coef_infection'])
plt.plot(history.history['val_dice_coef_infection'])
plt.title('dice_coef_infection vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Dice_coef')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# %%
plt.plot(history.history['iou_coef_infection'])
plt.plot(history.history['val_iou_coef_infection'])
plt.title('iou_coef_infection vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Iou_coef')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Val'], loc = 'upper right')
plt.show()

# %% [markdown]
# ## Using our trained model for prediction

# %%
import numpy as np
import time

# Start timer (high precision)
start_time = time.perf_counter()

# Evaluate the model on the validation generator
results = model.evaluate(val_gen, verbose=1)

# End timer
end_time = time.perf_counter()

# Calculate evaluation time
eval_time = end_time - start_time

# Print metric names with results
print("\n===== Validation Metrics =====")
for name, value in zip(model.metrics_names, results):
    print(f"{name}: {value:.6f}")

print(f"\nEvaluation Time: {eval_time:.8f} seconds\n")
# Out:
# 128/128 [==============================] - 27s 211ms/step - loss: 0.3680 - dice_coef_infection: 0.6722 - iou_coef_infection: 0.6295 - precision_infection: 0.9189 - recall_infection: 0.6746 - hausdorff95_infection: 77.4042 - specificity_infection: 0.9998 - accuracy_infection: 0.9960 - f1_infection: 0.8357
#
# ===== Validation Metrics =====
# loss: 0.368035
# dice_coef_infection: 0.672213
# iou_coef_infection: 0.629494
# precision_infection: 0.918886
# recall_infection: 0.674591
# hausdorff95_infection: 77.404190
# specificity_infection: 0.999795
# accuracy_infection: 0.995987
# f1_infection: 0.835717
#
# Evaluation Time: 27.03438501 seconds

# %%
import matplotlib.pyplot as plt
import numpy as np

# Run inference if not already done
predicted = model.predict(lung_test)

# Selected indices to visualize (744 as 1st, 280 as 2nd, 230 as 3rd)
selected_indices = [744, 280, 230]
n_samples = len(selected_indices)

# Mapping indices to custom names
name_mapping = {
    0: ("Image1_Covid", "GT1_Covid", "Predict1_Covid_DSEG_Unet"),  # Index 744
    1: ("Image2_Covid", "GT2_Covid", "Predict2_Covid_DSEG_Unet"),  # Index 280
    2: ("Image3_Covid", "GT3_Covid", "Predict3_Covid_DSEG_Unet")   # Index 230
}

# Plot
for j, i in enumerate(selected_indices):
    lung_img = lung_test[i][..., 0].astype(np.float32)
    gt_infect = (infect_test[i][..., 0] > 0.5).astype(np.float32)
    pred_infect = predicted[i][..., 0].astype(np.float32)

    # Normalize lung image
    if lung_img.max() > lung_img.min():
        lung_img = (lung_img - lung_img.min()) / (lung_img.max() - lung_img.min())
    lung_img = np.clip(lung_img, 0, 1)
    pred_infect = np.clip(pred_infect, 0, 1)

    # Get custom names for this index
    input_name, gt_name, pred_name = name_mapping[j]

    # Save Original Lung
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{input_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

    # Save Ground Truth Infection
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.imshow(gt_infect, cmap='Reds', alpha=0.6)
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{gt_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

    # Save Predicted Infection
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.imshow(pred_infect, cmap='Reds', alpha=0.6)
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{pred_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

print("Separate JPEG files saved for input images (Image1_Covid, Image2_Covid, Image3_Covid), "
      "ground truths (GT1_Covid, GT2_Covid, GT3_Covid), and predictions "
      "(Predict1_Covid_DSEG_Unet, Predict2_Covid_DSEG_Unet, Predict3_Covid_DSEG_Unet).")
# Out:
# Separate JPEG files saved for input images (Image1_Covid, Image2_Covid, Image3_Covid), ground truths (GT1_Covid, GT2_Covid, GT3_Covid), and predictions (Predict1_Covid_DSEG_Unet, Predict2_Covid_DSEG_Unet, Predict3_Covid_DSEG_Unet).
