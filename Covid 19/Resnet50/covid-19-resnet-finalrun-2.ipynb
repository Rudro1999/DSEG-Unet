# %% [markdown]
# ## Importing important libraries

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import nibabel as nib #for loading nii files
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf #for deep learning

# %% [markdown]
# ## Reading the metadata

# %%
data = pd.read_csv('../input/covid19-ct-scans/metadata.csv')
data.head()
# Out:
#                                              ct_scan  \
# 0  ../input/covid19-ct-scans/ct_scans/coronacases...
# 1  ../input/covid19-ct-scans/ct_scans/coronacases...
# 2  ../input/covid19-ct-scans/ct_scans/coronacases...
# 3  ../input/covid19-ct-scans/ct_scans/coronacases...
# 4  ../input/covid19-ct-scans/ct_scans/coronacases...
#
#                                            lung_mask  \
# 0  ../input/covid19-ct-scans/lung_mask/coronacase...
# 1  ../input/covid19-ct-scans/lung_mask/coronacase...
# 2  ../input/covid19-ct-scans/lung_mask/coronacase...
# 3  ../input/covid19-ct-scans/lung_mask/coronacase...
# 4  ../input/covid19-ct-scans/lung_mask/coronacase...
#
#                                       infection_mask  \
# 0  ../input/covid19-ct-scans/infection_mask/coron...
# 1  ../input/covid19-ct-scans/infection_mask/coron...
# 2  ../input/covid19-ct-scans/infection_mask/coron...
# 3  ../input/covid19-ct-scans/infection_mask/coron...
# 4  ../input/covid19-ct-scans/infection_mask/coron...
#
#                              lung_and_infection_mask
# 0  ../input/covid19-ct-scans/lung_and_infection_m...
# 1  ../input/covid19-ct-scans/lung_and_infection_m...
# 2  ../input/covid19-ct-scans/lung_and_infection_m...
# 3  ../input/covid19-ct-scans/lung_and_infection_m...
# 4  ../input/covid19-ct-scans/lung_and_infection_m...

# %% [markdown]
# ## Defining function for readiing .nii files

# %%
def read_nii(filepath):
    '''
    Reads .nii file and returns pixel array
    '''
    ct_scan = nib.load(filepath)
    array   = ct_scan.get_fdata()
    array   = np.rot90(np.array(array))
    return(array)

# %% [markdown]
# ## Reading the chest ct scan data

# %%
# Read sample
sample_ct   = read_nii(data.loc[2,'ct_scan'])
sample_lung = read_nii(data.loc[2,'lung_mask'])
sample_infe = read_nii(data.loc[2,'infection_mask'])
sample_all  = read_nii(data.loc[2,'lung_and_infection_mask'])

# %% [markdown]
# ## Plotting the sample images

# %%
fig = plt.figure(figsize = (18,15))
plt.subplot(1,4,1)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.title('Original Image')

plt.subplot(1,4,2)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_lung[..., 150],alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung Mask')

plt.subplot(1,4,3)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_infe[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Infection Mask')

plt.subplot(1,4,4)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_all[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung and Infection Mask')
# Out:
# Text(0.5, 1.0, 'Lung and Infection Mask')

# %% [markdown]
# ## Converting the data into array for training model

# %%
import numpy as np
import cv2
import random
from scipy.ndimage import rotate, shift, zoom

lungs = []
infections = []
case_ids = []
img_size = 320

# ----------- Load and Resize Data -----------
for case_index in range(len(data)):
    ct = read_nii(data['ct_scan'][case_index])
    infect = read_nii(data['infection_mask'][case_index])

    for slice_index in range(ct.shape[0]):
        lung_img = cv2.resize(ct[slice_index], dsize=(img_size, img_size)).astype('float32')
        infec_img = cv2.resize(infect[slice_index], dsize=(img_size, img_size)).astype('float32')

        lungs.append(lung_img[..., np.newaxis])
        infections.append(infec_img[..., np.newaxis])
        case_ids.append(case_index)

# %%
import numpy as np

# case_ids should be a NumPy array telling which case each slice belongs to
# Convert and binarize
lungs = np.array(lungs, dtype=np.float32)
infections = (np.array(infections, dtype=np.uint8) > 0.5).astype(np.uint8)
case_ids = np.array(case_ids)

# %% [markdown]
# ## Performing test and train split

# %%
# ----------- Case-wise Split -----------
unique_cases = np.unique(case_ids)
train_cases = np.append(unique_cases[2:4], unique_cases[6:20])
temp_cases = unique_cases[4:6]
val_cases = unique_cases[:2]

train_mask = np.isin(case_ids, train_cases)
temp_mask = np.isin(case_ids, temp_cases)
val_mask = np.isin(case_ids, val_cases)

lung_train = lungs[train_mask]
infect_train = infections[train_mask]
lung_temp = lungs[temp_mask]
infect_temp = infections[temp_mask]
lung_test = lungs[val_mask]
infect_test = infections[val_mask]

print(f"✅ Train: {lung_train.shape[0]} slices from {len(train_cases)} cases")
print(f"✅ Validation: {lung_temp.shape[0]} slices from {len(temp_cases)} cases")
print(f"✅ Test: {lung_test.shape[0]} slices from {len(val_cases)} cases")

# ----------- Augmentation -----------
def augment_image(img, mask):
    if random.random() < 0.5:
        img = np.fliplr(img)
        mask = np.fliplr(mask)
    if random.random() < 0.5:
        img = np.flipud(img)
        mask = np.flipud(mask)

    angle = random.uniform(-15, 15)
    img = rotate(img, angle, reshape=False, order=1, mode='nearest')
    mask = rotate(mask, angle, reshape=False, order=0, mode='nearest')

    shift_val = np.random.uniform(-0.1, 0.1, size=2) * img.shape[:2]
    img = shift(img, shift=(*shift_val, 0), order=1, mode='nearest')
    mask = shift(mask, shift=(*shift_val, 0), order=0, mode='nearest')

    zoom_factor = random.uniform(0.9, 1.1)
    img = zoom(img, (zoom_factor, zoom_factor, 1), order=1)
    mask = zoom(mask, (zoom_factor, zoom_factor, 1), order=0)

    return fix_shape(img), fix_shape(mask)

def fix_shape(arr, target_size=(320, 320)):
    h, w, c = arr.shape
    th, tw = target_size
    dh = th - h
    dw = tw - w
    if dh > 0 or dw > 0:
        pad_h = (max(dh // 2, 0), max(dh - dh // 2, 0))
        pad_w = (max(dw // 2, 0), max(dw - dw // 2, 0))
        arr = np.pad(arr, (pad_h, pad_w, (0, 0)), mode='constant')
    arr = arr[:th, :tw, :]
    return arr.astype('float32')

# ----------- Apply Augmentation -----------
aug_lung_train = []
aug_infect_train = []

for i in range(len(lung_train)):
    img, mask = augment_image(lung_train[i], infect_train[i])
    aug_lung_train.append(img)
    aug_infect_train.append(mask)

lung_train = np.stack(aug_lung_train)
infect_train = np.stack(aug_infect_train)

# Final Binarization
infect_train = (infect_train > 0.5).astype(np.uint8)
infect_test = (infect_test > 0.5).astype(np.uint8)

print(f"✅ Augmented training shape: {lung_train.shape}")
print("✅ All preprocessing complete.")
# Out:
# ✅ Train: 9143 slices from 16 cases
# ✅ Validation: 1024 slices from 2 cases
# ✅ Test: 1024 slices from 2 cases
# ✅ Augmented training shape: (9143, 320, 320, 1)
# ✅ All preprocessing complete.

# %%
import tensorflow as tf
from tensorflow.keras import backend as K
import numpy as np
from scipy.spatial import cKDTree

smooth = 1.0

# Binary Dice coefficient (soft - commonly used during training)
def dice_coef_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# Binary IoU coefficient (soft)
def iou_coef_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# Soft Precision
def precision_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + smooth) / (K.sum(y_pred_f) + smooth)

# Soft Recall (Sensitivity)
def recall_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + smooth) / (K.sum(y_true_f) + smooth)

# Soft Specificity
def specificity_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    tn = K.sum((1 - y_true_f) * (1 - y_pred_f))
    fp = K.sum((1 - y_true_f) * y_pred_f)
    return (tn + smooth) / (tn + fp + smooth)

# Soft Accuracy
def accuracy_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    tp = K.sum(y_true_f * y_pred_f)
    tn = K.sum((1 - y_true_f) * (1 - y_pred_f))
    total = K.cast(K.shape(y_true_f)[0], 'float32')
    return (tp + tn + smooth) / (total + smooth)

# Soft F1-score (harmonic mean of precision & recall - very close to Dice, standard in many repos)
def f1_infection(y_true, y_pred):
    precision = precision_infection(y_true, y_pred)
    recall    = recall_infection(y_true, y_pred)
    return (2. * precision * recall + smooth) / (precision + recall + smooth)

# Hausdorff Distance 95 % (robust & most commonly used in medical imaging challenges)
# Lower = better. Returns the mean HD95 over the batch.
def _calculate_hd95(y_true, y_pred):
    hd_list = []
    for i in range(y_true.shape[0]):
        # Hard threshold at 0.5 (standard for evaluation metrics)
        gt = np.squeeze(y_true[i]) > 0.5
        pred = np.squeeze(y_pred[i]) > 0.5

        gt_pts = np.argwhere(gt)
        pred_pts = np.argwhere(pred)

        # Cases with empty masks
        if gt_pts.shape[0] == 0 and pred_pts.shape[0] == 0:
            hd_list.append(0.0)
            continue
        if gt_pts.shape[0] == 0 or pred_pts.shape[0] == 0:
            hd_list.append(400.0)  # large penalty - adjust to your image diagonal if needed (e.g. ~362 for 256×256, ~724 for 512×512)
            continue

        # Directed distances
        dist_gt_to_pred = cKDTree(pred_pts).query(gt_pts)[0]
        dist_pred_to_gt = cKDTree(gt_pts).query(pred_pts)[0]

        hd95 = max(
            np.percentile(dist_gt_to_pred, 95),
            np.percentile(dist_pred_to_gt, 95)
        )
        hd_list.append(hd95)

    return np.mean(hd_list, dtype=np.float32)

def hausdorff95_infection(y_true, y_pred):
    hd = tf.numpy_function(_calculate_hd95, [y_true, y_pred], tf.float32)
    hd.set_shape(())
    return hd

# Optional: KL Divergence (you already had this)
kld = tf.keras.losses.KLDivergence()

# %%
from tensorflow.keras.losses import BinaryCrossentropy

def loss_f(y_true, y_pred):
    bce = BinaryCrossentropy()
    return dice_loss(y_true, y_pred) + bce(y_true, y_pred) 

def loss_e(y_true, y_pred):
    bce = BinaryCrossentropy()
    return dice_loss(y_true, y_pred)  + kld(y_true, y_pred)
    
def dice_loss(y_true, y_pred):
    return 1. - dice_coef_infection(y_true, y_pred)

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Multiply, Conv2D, DepthwiseConv2D, Dense, Flatten, MaxPooling2D, UpSampling2D, concatenate, Activation, LayerNormalization, Add, Dropout, Conv2DTranspose, multiply, Reshape, GlobalAveragePooling2D, Permute, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Concatenate

def activation_block(x):
    x = Activation("gelu")(x)
    return LayerNormalization()(x)

def conv_stem(x, filters: int, patch_size: int):
    x = Conv2D(filters, kernel_size=patch_size,padding='same', strides=patch_size)(x)
    return activation_block(x)

def vector_block(xyz, cmf, red):
    # red means reduction
    # cmf means filters, denotes vector size
    opt1 = conv_stem(xyz, cmf, red)
    opt2 = conv_stem(xyz, cmf, red)
    
    o1 = GlobalAveragePooling2D()(opt1)
    o2 = GlobalAveragePooling2D()(opt2)

    o5 = concatenate([o1, o2], -1)
    return o5

def mlp_feature(vect, cmf):
    oo = Flatten()(vect)
    o6 = Dense(cmf, activation='gelu')(oo)
    o6 = Dropout(0.2)(o6)
    o6 = Dense(cmf * 2, activation='gelu')(o6)

    o6 = Reshape((1, cmf * 2))(o6)
    o7 = Permute((2, 1))(o6)

    o8 = multiply([o6, o7])
    
    o8 = Lambda(lambda x: tf.expand_dims(x, -1))(o8)
    
    o8 = Reshape((cmf, cmf, 4))(o8)

    return o8

def frz_block(xyz):
    shape = xyz.shape
    a1, a2, a3, a4 = shape[0], shape[1], shape[2], shape[3]
    cmf = a2
    o5 = vector_block(xyz, cmf, 5)
    o7 = mlp_feature(o5, cmf)

    o7 = concatenate([o7, xyz, o7], -1)
    return o7

def up_frz(x1, x2, n_filters):
    # Upsample x1 using Conv2DTranspose
    x1 = Conv2DTranspose(n_filters * 4, 3, strides=2, activation='gelu', padding="same")(x1)
    
    # Apply Conv2D to x2
    x2 = Conv2D(n_filters * 2, 3, activation='gelu', padding="same")(x2)
    
    # Apply attention mechanism
    x = concatenate([x1, x2])
    
    # Apply Dropout for regularization
    x = Dropout(0.3)(x)
    
    return x

# %%
inputs = (img_size, img_size, 1)

! pip install segmentation-models
# !pip install -U keras
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, UpSampling2D, concatenate, BatchNormalization, Activation

def model_build_func(input_shape, n_labels):
    inputs = Input(shape=input_shape, name='input_image')
    # Load ResNet50 without top layers
    base_model = ResNet50(include_top=False, weights=None, input_shape=input_shape, input_tensor=inputs)
    # Define skip connections
    o1 = base_model.get_layer('conv1_relu').output  # e.g., 112x112x64 for 224x224 input
    o2 = base_model.get_layer('conv2_block3_out').output  # 56x56x256
    o3 = base_model.get_layer('conv3_block4_out').output  # 28x28x512
    o4 = base_model.get_layer('conv4_block6_out').output  # 14x14x1024
    o5 = base_model.get_layer('conv5_block3_out').output  # 7x7x2048
   
    # Decoder Stage 1
    d1_up = UpSampling2D()(o5)
    d1_concat = concatenate([d1_up, o4])
    d1_conv1 = Conv2D(256, 3, padding='same', use_bias=False)(d1_concat)
    d1_bn1 = BatchNormalization()(d1_conv1)
    d1_relu1 = Activation('relu')(d1_bn1)
    d1_conv2 = Conv2D(256, 3, padding='same', use_bias=False)(d1_relu1)
    d1_bn2 = BatchNormalization()(d1_conv2)
    d1_relu2 = Activation('relu')(d1_bn2)
    # Decoder Stage 2
    d2_up = UpSampling2D()(d1_relu2)
    d2_concat = concatenate([d2_up, o3])
    d2_conv1 = Conv2D(128, 3, padding='same', use_bias=False)(d2_concat)
    d2_bn1 = BatchNormalization()(d2_conv1)
    d2_relu1 = Activation('relu')(d2_bn1)
    d2_conv2 = Conv2D(128, 3, padding='same', use_bias=False)(d2_relu1)
    d2_bn2 = BatchNormalization()(d2_conv2)
    d2_relu2 = Activation('relu')(d2_bn2)
    # Decoder Stage 3
    d3_up = UpSampling2D()(d2_relu2)
    d3_concat = concatenate([d3_up, o2])
    d3_conv1 = Conv2D(64, 3, padding='same', use_bias=False)(d3_concat)
    d3_bn1 = BatchNormalization()(d3_conv1)
    d3_relu1 = Activation('relu')(d3_bn1)
    d3_conv2 = Conv2D(64, 3, padding='same', use_bias=False)(d3_relu1)
    d3_bn2 = BatchNormalization()(d3_conv2)
    d3_relu2 = Activation('relu')(d3_bn2)
    # Decoder Stage 4
    d4_up = UpSampling2D()(d3_relu2)
    d4_concat = concatenate([d4_up, o1])
    d4_conv1 = Conv2D(32, 3, padding='same', use_bias=False)(d4_concat)
    d4_bn1 = BatchNormalization()(d4_conv1)
    d4_relu1 = Activation('relu')(d4_bn1)
    d4_conv2 = Conv2D(32, 3, padding='same', use_bias=False)(d4_relu1)
    d4_bn2 = BatchNormalization()(d4_conv2)
    d4_relu2 = Activation('relu')(d4_bn2)
    # Final Stage
    d5_up = UpSampling2D()(d4_relu2)
    d5_conv1 = Conv2D(16, 3, padding='same', use_bias=False)(d5_up)
    d5_bn1 = BatchNormalization()(d5_conv1)
    d5_relu1 = Activation('relu')(d5_bn1)
    d5_conv2 = Conv2D(16, 3, padding='same', use_bias=False)(d5_relu1)
    d5_bn2 = BatchNormalization()(d5_conv2)
    d5_relu2 = Activation('relu')(d5_bn2)
    final_conv = Conv2D(n_labels, 3, padding='same')(d5_relu2)
    output = Activation('sigmoid')(final_conv)
    model = Model(inputs=inputs, outputs=output)
    return model

model = model_build_func(inputs, 1)
# Out:
# Collecting segmentation-models
#   Downloading segmentation_models-1.0.1-py3-none-any.whl (33 kB)
# Collecting image-classifiers==1.0.0
#   Downloading image_classifiers-1.0.0-py3-none-any.whl (19 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 2.5 MB/s  eta 0:00:01
# Collecting efficientnet==1.0.0
#   Downloading efficientnet-1.0.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: scikit-image in /opt/conda/lib/python3.7/site-packages (from efficientnet==1.0.0->segmentation-models) (0.18.1)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.7/site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (2.10.0)
# Requirement already satisfied: numpy>=1.9.1 in /opt/conda/lib/python3.7/site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.19.5)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from h5py->keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.15.0)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (7.2.0)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (3.4.1)
# Requirement already satisfied: imageio>=2.3.0 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.9.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.1.1)
# Requirement already satisfied: networkx>=2.0 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.5)
# Requirement already satisfied: scipy>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.5.4)
# Requirement already satisfied: tifffile>=2019.7.26 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2021.4.8)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.7/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.7/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (2.8.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (1.3.1)
# Requirement already satisfied: decorator>=4.3.0 in /opt/conda/lib/python3.7/site-packages (from networkx>=2.0->scikit-image->efficientnet==1.0.0->segmentation-models) (4.4.2)
# Installing collected packages: keras-applications, image-classifiers, efficientnet, segmentation-models
# Successfully installed efficientnet-1.0.0 image-classifiers-1.0.0 keras-applications-1.0.8 segmentation-models-1.0.1
# Requirement already satisfied: keras in /opt/conda/lib/python3.7/site-packages (2.4.3)
# Collecting keras
#   Downloading keras-2.11.0-py2.py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 5.3 MB/s eta 0:00:01
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: Keras 2.4.3
#     Uninstalling Keras-2.4.3:
#       Successfully uninstalled Keras-2.4.3
# Successfully installed keras-2.11.0

# %%
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2_as_graph

def get_flops(model):
    """Calculate Floating Point Operations (FLOPs) of a Keras model in TensorFlow 2.x."""
    # Convert Keras model to a TensorFlow function
    concrete_func = tf.function(lambda inputs: model(inputs))
    concrete_func = concrete_func.get_concrete_function(
        tf.TensorSpec([1] + list(model.input_shape[1:]), model.input.dtype)
    )

    # Convert to frozen graph
    frozen_func, _ = convert_variables_to_constants_v2_as_graph(concrete_func)

    # Compute FLOPs
    flops = tf.compat.v1.profiler.profile(
        frozen_func.graph,
        options=tf.compat.v1.profiler.ProfileOptionBuilder.float_operation(),
    )

    return flops.total_float_ops

# Compute FLOPs
flops = get_flops(model)
print(f"Total FLOPs: {flops / 1e9:.2f} GFLOPs")  # Convert to GFLOPs

from tensorflow.keras.optimizers import Adam

optimizer = Adam(learning_rate=1e-3)
model.compile(optimizer=optimizer, loss=loss_f, metrics=[dice_coef_infection, iou_coef_infection, precision_infection, recall_infection, hausdorff95_infection, specificity_infection, accuracy_infection, f1_infection])

# Model summary
model.summary()
# Out:
# Total FLOPs: 31.99 GFLOPs
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_image (InputLayer)        [(None, 320, 320, 1) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 326, 326, 1)  0           input_image[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 160, 160, 64) 3200        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 160, 160, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 160, 160, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 162, 162, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 80, 80, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 80, 80, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 80, 80, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 80, 80, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 80, 80, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 80, 80, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 80, 80, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 80, 80, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 80, 80, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 80, 80, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 80, 80, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 80, 80, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 80, 80, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 80, 80, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 80, 80, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 80, 80, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 80, 80, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 80, 80, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 80, 80, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 80, 80, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 80, 80, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 80, 80, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 80, 80, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 80, 80, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 80, 80, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 80, 80, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 80, 80, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 80, 80, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 80, 80, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 80, 80, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 80, 80, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 80, 80, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 80, 80, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 40, 40, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 40, 40, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 40, 40, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 40, 40, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 40, 40, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 40, 40, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 40, 40, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 40, 40, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 40, 40, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 40, 40, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 40, 40, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 40, 40, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 40, 40, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 40, 40, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 40, 40, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 40, 40, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 40, 40, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 40, 40, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 40, 40, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 40, 40, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 40, 40, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 40, 40, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 40, 40, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 40, 40, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 40, 40, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 40, 40, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 40, 40, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 40, 40, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 40, 40, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 40, 40, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 40, 40, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 40, 40, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 40, 40, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 40, 40, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 40, 40, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 40, 40, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 40, 40, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 40, 40, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 40, 40, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 40, 40, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 40, 40, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 40, 40, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 20, 20, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 20, 20, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 20, 20, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 20, 20, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 20, 20, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 20, 20, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 20, 20, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 20, 20, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 20, 20, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 20, 20, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 20, 20, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 20, 20, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 20, 20, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 20, 20, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 20, 20, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 20, 20, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 20, 20, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 20, 20, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 20, 20, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 20, 20, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 20, 20, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 20, 20, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 20, 20, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 20, 20, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 20, 20, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 20, 20, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 20, 20, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 20, 20, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 20, 20, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 20, 20, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 20, 20, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 20, 20, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 20, 20, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 20, 20, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 20, 20, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 20, 20, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 20, 20, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 20, 20, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 20, 20, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 20, 20, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 20, 20, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 20, 20, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 20, 20, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 20, 20, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 20, 20, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 20, 20, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 20, 20, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 20, 20, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 20, 20, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 20, 20, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 20, 20, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 20, 20, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 20, 20, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 20, 20, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 20, 20, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 20, 20, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 20, 20, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 20, 20, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 20, 20, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 20, 20, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 20, 20, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 20, 20, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 10, 10, 512)  524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 10, 10, 512)  2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 10, 10, 512)  0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 10, 10, 512)  2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 10, 10, 512)  2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 10, 10, 512)  0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 10, 10, 2048) 2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 10, 10, 2048) 1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 10, 10, 2048) 8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 10, 10, 2048) 8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 10, 10, 2048) 0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 10, 10, 2048) 0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 10, 10, 512)  1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 10, 10, 512)  2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 10, 10, 512)  0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 10, 10, 512)  2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 10, 10, 512)  2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 10, 10, 512)  0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 10, 10, 2048) 1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 10, 10, 2048) 8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 10, 10, 2048) 0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 10, 10, 2048) 0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 10, 10, 512)  1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 10, 10, 512)  2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 10, 10, 512)  0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 10, 10, 512)  2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 10, 10, 512)  2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 10, 10, 512)  0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 10, 10, 2048) 1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 10, 10, 2048) 8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 10, 10, 2048) 0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 10, 10, 2048) 0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 20, 20, 2048) 0           conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 20, 20, 3072) 0           up_sampling2d[0][0]
#                                                                  conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 20, 20, 256)  7077888     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 20, 20, 256)  1024        conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 20, 20, 256)  0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 20, 20, 256)  589824      activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 20, 20, 256)  1024        conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 20, 20, 256)  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 40, 40, 256)  0           activation_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 40, 40, 768)  0           up_sampling2d_1[0][0]
#                                                                  conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 40, 40, 128)  884736      concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 40, 40, 128)  512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 40, 40, 128)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 40, 40, 128)  147456      activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 40, 40, 128)  512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 40, 40, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 80, 80, 128)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 80, 80, 384)  0           up_sampling2d_2[0][0]
#                                                                  conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 80, 80, 64)   221184      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 80, 80, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 80, 80, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 80, 80, 64)   36864       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 80, 80, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 80, 80, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 160, 160, 64) 0           activation_5[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 160, 160, 128 0           up_sampling2d_3[0][0]
#                                                                  conv1_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 160, 160, 32) 36864       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 160, 160, 32) 128         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 160, 160, 32) 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 160, 160, 32) 9216        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 160, 160, 32) 128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 160, 160, 32) 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 320, 320, 32) 0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 320, 320, 16) 4608        up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 320, 320, 16) 64          conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 320, 320, 16) 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 320, 320, 16) 2304        activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 320, 320, 16) 64          conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 320, 320, 16) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 320, 320, 1)  145         activation_9[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 320, 320, 1)  0           conv2d_10[0][0]
# ==================================================================================================
# Total params: 32,596,497
# Trainable params: 32,541,393
# Non-trainable params: 55,104
# __________________________________________________________________________________________________

# %%
# Install required packages
# !pip install openpyxl

# Imports
import openpyxl  # required for reading .xlsx files
import pandas as pd
import tensorflow as tf
import os
import shutil
from tensorflow.keras.callbacks import LearningRateScheduler, ReduceLROnPlateau

# File paths
checkpoint_filepath = '/kaggle/working/checkpoint.h5.keras'
metrics_file = '/kaggle/working/training_metrics.xlsx'
pre_checkpoint_filepath = '/kaggle/input/transunet-covid19-finalrun/checkpoint.h5.keras'
pre_metrics_file = '/kaggle/input/transunet-covid19-finalrun/training_metrics.xlsx'

# Restore checkpoint and metrics if available
if os.path.exists(pre_checkpoint_filepath):
    shutil.copy(pre_checkpoint_filepath, checkpoint_filepath)
    print(f"Restored checkpoint from: {pre_checkpoint_filepath}")

if os.path.exists(pre_metrics_file):
    shutil.copy(pre_metrics_file, metrics_file)
    print(f"Restored metrics file from: {pre_metrics_file}")

# Load last epoch
def load_last_epoch():
    if os.path.exists(metrics_file):
        try:
            df = pd.read_excel(metrics_file, engine='openpyxl')
            if not df.empty and 'epoch' in df.columns:
                return df['epoch'].iloc[-1] + 1
        except Exception as e:
            print(f"⚠️ Could not read metrics file: {e}")
    return 0

last_epoch = load_last_epoch()

# Get best validation loss from previous runs
def get_best_val_loss():
    if os.path.exists(metrics_file):
        try:
            df = pd.read_excel(metrics_file, engine='openpyxl')
            if 'val_loss' in df.columns and not df['val_loss'].isnull().all():
                return df['val_loss'].min()
        except Exception as e:
            print(f"⚠️ Could not read val_loss from metrics file: {e}")
    return float('inf')

best_val_loss = get_best_val_loss()

# Custom model checkpoint
class CustomModelCheckpoint(tf.keras.callbacks.Callback):
    def __init__(self, filepath):
        super().__init__()
        self.filepath = filepath
        self.best_loss = best_val_loss

    def on_epoch_end(self, epoch, logs=None):
        current_loss = logs.get('val_loss')
        if current_loss is not None and current_loss < self.best_loss:
            self.best_loss = current_loss
            self.model.save(self.filepath)
            print(f"✅ Model saved at epoch {epoch + 1} with val_loss: {current_loss:.4f}")

# === Learning Rate Schedule ===
def lr_schedule(epoch, lr):
    return 1e-4 if epoch >= 5 else lr

lr_scheduler = LearningRateScheduler(lr_schedule, verbose=1)

# Logger for Excel
class MetricsLogger(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        df_new = pd.DataFrame([{**logs, 'epoch': epoch}])
        try:
            if os.path.exists(metrics_file):
                df = pd.read_excel(metrics_file, engine='openpyxl')
                df = pd.concat([df, df_new], ignore_index=True)
            else:
                df = df_new
            df.to_excel(metrics_file, index=False, engine='openpyxl')
        except Exception as e:
            print(f"⚠️ Failed to log metrics: {e}")

# Early stopping with patience and saving best weights
class CustomEarlyStopping(tf.keras.callbacks.Callback):
    def __init__(self, patience=20):
        super().__init__()
        self.patience = patience
        self.wait = 0
        self.best_loss = best_val_loss

    def on_epoch_end(self, epoch, logs=None):
        current_loss = logs.get('val_loss')
        if current_loss is None:
            return
        if current_loss < self.best_loss:
            self.best_loss = current_loss
            self.wait = 0
            self.model.save_weights(checkpoint_filepath)
        else:
            self.wait += 1
            if self.wait >= self.patience:
                print(f"🛑 Early stopping at epoch {epoch + 1}")
                self.model.stop_training = True


# Final callbacks list
callbacks = [
    CustomModelCheckpoint(filepath=checkpoint_filepath),
    MetricsLogger(),
    lr_scheduler,
    CustomEarlyStopping(patience=20)
]
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.3-py2.py3-none-any.whl (251 kB)
#      |████████████████████████████████| 251 kB 5.3 MB/s eta 0:00:01
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.3

# %% [markdown]
# ## Training the model

# %%
import time
import os
import pandas as pd
import numpy as np
from tensorflow.keras.utils import Sequence
from tensorflow.keras.models import load_model

EPOCHS = 100

# Record the start time
start_time = time.time()

# === Load last completed epoch from metrics file ===
def load_last_epoch():
    if os.path.exists(pre_metrics_file):
        try:
            df = pd.read_excel(pre_metrics_file, engine='openpyxl')
            if not df.empty and 'epoch' in df.columns:
                return int(df['epoch'].iloc[-1]) + 1
        except Exception as e:
            print(f"⚠️ Failed to read metrics file: {e}")
    return 0

last_epoch = load_last_epoch()

# === Load pretrained weights if available ===
if os.path.exists(pre_checkpoint_filepath):
    print("✅ Checkpoint found. Loading pretrained weights...")
    model.load_weights(pre_checkpoint_filepath)
    print(f"🔁 Resuming training from epoch {last_epoch}")
else:
    print("🆕 No checkpoint found. Starting training from scratch.")
    last_epoch = 0

# === Prepare input and label tensors ===
lung_train = np.asarray(lung_train, dtype=np.float16)
infect_train = np.asarray(infect_train, dtype=np.uint8)

lung_temp = np.asarray(lung_temp, dtype=np.float16)
infect_temp = np.asarray(infect_temp, dtype=np.uint8)

lung_test = np.asarray(lung_test, dtype=np.float16)
infect_test = np.asarray(infect_test, dtype=np.uint8)

# === Data Generator ===
class LungDataGenerator(Sequence):
    def __init__(self, X, Y, batch_size=8, shuffle=True):
        self.X = X
        self.Y = Y
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indices = np.arange(len(X))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.X) / self.batch_size))

    def __getitem__(self, index):
        batch_ids = self.indices[index * self.batch_size:(index + 1) * self.batch_size]
        X_batch = self.X[batch_ids]
        Y_batch = self.Y[batch_ids]
        return np.asarray(X_batch, dtype=np.float16), np.asarray(Y_batch, dtype=np.uint8)

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indices)

# === Create generators ===
train_gen = LungDataGenerator(lung_train, infect_train, batch_size=8)
temp_gen = LungDataGenerator(lung_temp, infect_temp, batch_size=8, shuffle=False)
val_gen = LungDataGenerator(lung_test, infect_test, batch_size=8, shuffle=False)

# === Train the model ===
history = model.fit(
    train_gen,
    validation_data=temp_gen,
    epochs=EPOCHS,
    initial_epoch=last_epoch,
    callbacks=callbacks
)

# === Timing info ===
end_time = time.time()
total_time = end_time - start_time
print(f"✅ Total training time: {total_time:.2f} seconds ({total_time / 60:.2f} minutes)")
# Out:
# 🆕 No checkpoint found. Starting training from scratch.
# Epoch 1/100
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 223s 185ms/step - loss: 1.0816 - dice_coef_infection: 0.0420 - iou_coef_infection: 0.0228 - precision_infection: 0.0350 - recall_infection: 0.1649 - hausdorff95_infection: 160.3929 - specificity_infection: 0.9232 - accuracy_infection: 0.9159 - f1_infection: 0.8664 - val_loss: 1.2129 - val_dice_coef_infection: 0.0032 - val_iou_coef_infection: 0.0017 - val_precision_infection: 0.0024 - val_recall_infection: 0.7878 - val_hausdorff95_infection: 292.9039 - val_specificity_infection: 0.8708 - val_accuracy_infection: 0.8688 - val_f1_infection: 0.6020
# ✅ Model saved at epoch 1 with val_loss: 1.2129
# Epoch 2/100
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.8854 - dice_coef_infection: 0.1776 - iou_coef_infection: 0.1116 - precision_infection: 0.1765 - recall_infection: 0.2966 - hausdorff95_infection: 145.6907 - specificity_infection: 0.9876 - accuracy_infection: 0.9806 - f1_infection: 0.8090 - val_loss: 1.0097 - val_dice_coef_infection: 0.0044 - val_iou_coef_infection: 0.0040 - val_precision_infection: 0.0151 - val_recall_infection: 0.7822 - val_hausdorff95_infection: 82.0312 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9975 - val_f1_infection: 0.6007
# ✅ Model saved at epoch 2 with val_loss: 1.0097
# Epoch 3/100
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 208s 182ms/step - loss: 0.7082 - dice_coef_infection: 0.3443 - iou_coef_infection: 0.2323 - precision_infection: 0.3575 - recall_infection: 0.4743 - hausdorff95_infection: 130.1569 - specificity_infection: 0.9926 - accuracy_infection: 0.9870 - f1_infection: 0.7602 - val_loss: 0.8661 - val_dice_coef_infection: 0.1431 - val_iou_coef_infection: 0.1255 - val_precision_infection: 0.2034 - val_recall_infection: 0.8283 - val_hausdorff95_infection: 38.6108 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9985 - val_f1_infection: 0.6243
# ✅ Model saved at epoch 3 with val_loss: 0.8661
# Epoch 4/100
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.6048 - dice_coef_infection: 0.4384 - iou_coef_infection: 0.3099 - precision_infection: 0.4527 - recall_infection: 0.5507 - hausdorff95_infection: 99.1802 - specificity_infection: 0.9945 - accuracy_infection: 0.9901 - f1_infection: 0.7661 - val_loss: 0.8306 - val_dice_coef_infection: 0.1804 - val_iou_coef_infection: 0.1665 - val_precision_infection: 0.2264 - val_recall_infection: 0.8211 - val_hausdorff95_infection: 49.6341 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9984 - val_f1_infection: 0.6582
# ✅ Model saved at epoch 4 with val_loss: 0.8306
# Epoch 5/100
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 208s 182ms/step - loss: 0.5849 - dice_coef_infection: 0.4565 - iou_coef_infection: 0.3282 - precision_infection: 0.4711 - recall_infection: 0.5801 - hausdorff95_infection: 97.2127 - specificity_infection: 0.9949 - accuracy_infection: 0.9906 - f1_infection: 0.7689 - val_loss: 0.8005 - val_dice_coef_infection: 0.2057 - val_iou_coef_infection: 0.1864 - val_precision_infection: 0.2661 - val_recall_infection: 0.8533 - val_hausdorff95_infection: 31.5141 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9988 - val_f1_infection: 0.6393
# ✅ Model saved at epoch 5 with val_loss: 0.8005
# Epoch 6/100
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 208s 182ms/step - loss: 0.5197 - dice_coef_infection: 0.5136 - iou_coef_infection: 0.3792 - precision_infection: 0.5251 - recall_infection: 0.6303 - hausdorff95_infection: 81.6880 - specificity_infection: 0.9961 - accuracy_infection: 0.9922 - f1_infection: 0.7751 - val_loss: 0.7549 - val_dice_coef_infection: 0.2492 - val_iou_coef_infection: 0.2261 - val_precision_infection: 0.2852 - val_recall_infection: 0.8902 - val_hausdorff95_infection: 20.5607 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9991 - val_f1_infection: 0.6545
# ✅ Model saved at epoch 6 with val_loss: 0.7549
# Epoch 7/100
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 182ms/step - loss: 0.4775 - dice_coef_infection: 0.5546 - iou_coef_infection: 0.4143 - precision_infection: 0.5709 - recall_infection: 0.6331 - hausdorff95_infection: 79.3743 - specificity_infection: 0.9967 - accuracy_infection: 0.9930 - f1_infection: 0.7892 - val_loss: 0.7272 - val_dice_coef_infection: 0.2765 - val_iou_coef_infection: 0.2524 - val_precision_infection: 0.3020 - val_recall_infection: 0.9006 - val_hausdorff95_infection: 19.2075 - val_specificity_infection: 0.9996 - val_accuracy_infection: 0.9991 - val_f1_infection: 0.6670
# ✅ Model saved at epoch 7 with val_loss: 0.7272
# Epoch 8/100
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 208s 182ms/step - loss: 0.5005 - dice_coef_infection: 0.5325 - iou_coef_infection: 0.3966 - precision_infection: 0.5482 - recall_infection: 0.6333 - hausdorff95_infection: 79.7906 - specificity_infection: 0.9966 - accuracy_infection: 0.9929 - f1_infection: 0.7815 - val_loss: 0.6850 - val_dice_coef_infection: 0.3198 - val_iou_coef_infection: 0.2980 - val_precision_infection: 0.3708 - val_recall_infection: 0.8776 - val_hausdorff95_infection: 22.2400 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.6952
# ✅ Model saved at epoch 8 with val_loss: 0.6850
# Epoch 9/100
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 208s 182ms/step - loss: 0.4851 - dice_coef_infection: 0.5441 - iou_coef_infection: 0.4100 - precision_infection: 0.5582 - recall_infection: 0.6383 - hausdorff95_infection: 74.6790 - specificity_infection: 0.9971 - accuracy_infection: 0.9937 - f1_infection: 0.7913 - val_loss: 0.6809 - val_dice_coef_infection: 0.3236 - val_iou_coef_infection: 0.2996 - val_precision_infection: 0.3647 - val_recall_infection: 0.8868 - val_hausdorff95_infection: 18.9016 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9991 - val_f1_infection: 0.6968
# ✅ Model saved at epoch 9 with val_loss: 0.6809
# Epoch 10/100
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 208s 182ms/step - loss: 0.4597 - dice_coef_infection: 0.5692 - iou_coef_infection: 0.4312 - precision_infection: 0.5829 - recall_infection: 0.6464 - hausdorff95_infection: 71.5608 - specificity_infection: 0.9971 - accuracy_infection: 0.9937 - f1_infection: 0.7962 - val_loss: 0.7259 - val_dice_coef_infection: 0.2779 - val_iou_coef_infection: 0.2522 - val_precision_infection: 0.3051 - val_recall_infection: 0.8940 - val_hausdorff95_infection: 15.3132 - val_specificity_infection: 0.9996 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.6717
# Epoch 11/100
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 208s 182ms/step - loss: 0.4471 - dice_coef_infection: 0.5810 - iou_coef_infection: 0.4402 - precision_infection: 0.5975 - recall_infection: 0.6512 - hausdorff95_infection: 68.5219 - specificity_infection: 0.9972 - accuracy_infection: 0.9939 - f1_infection: 0.7958 - val_loss: 0.6415 - val_dice_coef_infection: 0.3650 - val_iou_coef_infection: 0.3464 - val_precision_infection: 0.4418 - val_recall_infection: 0.8571 - val_hausdorff95_infection: 30.1979 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9989 - val_f1_infection: 0.7251
# ✅ Model saved at epoch 11 with val_loss: 0.6415
# Epoch 12/100
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 208s 182ms/step - loss: 0.4400 - dice_coef_infection: 0.5882 - iou_coef_infection: 0.4501 - precision_infection: 0.6001 - recall_infection: 0.6684 - hausdorff95_infection: 65.8938 - specificity_infection: 0.9972 - accuracy_infection: 0.9940 - f1_infection: 0.7994 - val_loss: 0.5628 - val_dice_coef_infection: 0.4420 - val_iou_coef_infection: 0.4206 - val_precision_infection: 0.4977 - val_recall_infection: 0.8792 - val_hausdorff95_infection: 23.9917 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9991 - val_f1_infection: 0.7624
# ✅ Model saved at epoch 12 with val_loss: 0.5628
# Epoch 13/100
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.4266 - dice_coef_infection: 0.6013 - iou_coef_infection: 0.4588 - precision_infection: 0.6176 - recall_infection: 0.6656 - hausdorff95_infection: 67.3081 - specificity_infection: 0.9974 - accuracy_infection: 0.9942 - f1_infection: 0.7991 - val_loss: 0.5000 - val_dice_coef_infection: 0.5047 - val_iou_coef_infection: 0.4796 - val_precision_infection: 0.5358 - val_recall_infection: 0.8946 - val_hausdorff95_infection: 17.7458 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9991 - val_f1_infection: 0.7926
# ✅ Model saved at epoch 13 with val_loss: 0.5000
# Epoch 14/100
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.4380 - dice_coef_infection: 0.5901 - iou_coef_infection: 0.4502 - precision_infection: 0.6039 - recall_infection: 0.6526 - hausdorff95_infection: 65.3303 - specificity_infection: 0.9973 - accuracy_infection: 0.9942 - f1_infection: 0.8034 - val_loss: 0.4833 - val_dice_coef_infection: 0.5214 - val_iou_coef_infection: 0.4980 - val_precision_infection: 0.5697 - val_recall_infection: 0.8823 - val_hausdorff95_infection: 18.1357 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9991 - val_f1_infection: 0.8017
# ✅ Model saved at epoch 14 with val_loss: 0.4833
# Epoch 15/100
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.4343 - dice_coef_infection: 0.5929 - iou_coef_infection: 0.4527 - precision_infection: 0.6068 - recall_infection: 0.6567 - hausdorff95_infection: 68.0160 - specificity_infection: 0.9973 - accuracy_infection: 0.9943 - f1_infection: 0.8007 - val_loss: 0.5194 - val_dice_coef_infection: 0.4855 - val_iou_coef_infection: 0.4615 - val_precision_infection: 0.5300 - val_recall_infection: 0.8849 - val_hausdorff95_infection: 18.8195 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9991 - val_f1_infection: 0.7837
# Epoch 16/100
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 208s 182ms/step - loss: 0.4285 - dice_coef_infection: 0.5983 - iou_coef_infection: 0.4587 - precision_infection: 0.6092 - recall_infection: 0.6644 - hausdorff95_infection: 63.6397 - specificity_infection: 0.9974 - accuracy_infection: 0.9945 - f1_infection: 0.8031 - val_loss: 0.4564 - val_dice_coef_infection: 0.5485 - val_iou_coef_infection: 0.5276 - val_precision_infection: 0.6065 - val_recall_infection: 0.8805 - val_hausdorff95_infection: 21.2708 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9991 - val_f1_infection: 0.8138
# ✅ Model saved at epoch 16 with val_loss: 0.4564
# Epoch 17/100
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.4413 - dice_coef_infection: 0.5882 - iou_coef_infection: 0.4505 - precision_infection: 0.6088 - recall_infection: 0.6560 - hausdorff95_infection: 62.4366 - specificity_infection: 0.9973 - accuracy_infection: 0.9941 - f1_infection: 0.8017 - val_loss: 0.3410 - val_dice_coef_infection: 0.6649 - val_iou_coef_infection: 0.6458 - val_precision_infection: 0.7388 - val_recall_infection: 0.8727 - val_hausdorff95_infection: 25.7508 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9991 - val_f1_infection: 0.8627
# ✅ Model saved at epoch 17 with val_loss: 0.3410
# Epoch 18/100
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.4126 - dice_coef_infection: 0.6155 - iou_coef_infection: 0.4748 - precision_infection: 0.6285 - recall_infection: 0.6721 - hausdorff95_infection: 62.4148 - specificity_infection: 0.9973 - accuracy_infection: 0.9944 - f1_infection: 0.8092 - val_loss: 0.2550 - val_dice_coef_infection: 0.7496 - val_iou_coef_infection: 0.7276 - val_precision_infection: 0.8064 - val_recall_infection: 0.8902 - val_hausdorff95_infection: 18.3950 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9992 - val_f1_infection: 0.8966
# ✅ Model saved at epoch 18 with val_loss: 0.2550
# Epoch 19/100
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.4318 - dice_coef_infection: 0.5970 - iou_coef_infection: 0.4579 - precision_infection: 0.6175 - recall_infection: 0.6616 - hausdorff95_infection: 62.9244 - specificity_infection: 0.9973 - accuracy_infection: 0.9943 - f1_infection: 0.8016 - val_loss: 0.2383 - val_dice_coef_infection: 0.7686 - val_iou_coef_infection: 0.7510 - val_precision_infection: 0.8576 - val_recall_infection: 0.8669 - val_hausdorff95_infection: 29.9503 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.9027
# ✅ Model saved at epoch 19 with val_loss: 0.2383
# Epoch 20/100
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.4229 - dice_coef_infection: 0.6062 - iou_coef_infection: 0.4698 - precision_infection: 0.6298 - recall_infection: 0.6590 - hausdorff95_infection: 62.3450 - specificity_infection: 0.9974 - accuracy_infection: 0.9944 - f1_infection: 0.8118 - val_loss: 0.2486 - val_dice_coef_infection: 0.7569 - val_iou_coef_infection: 0.7340 - val_precision_infection: 0.8123 - val_recall_infection: 0.8796 - val_hausdorff95_infection: 18.9650 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9991 - val_f1_infection: 0.8988
# Epoch 21/100
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.4141 - dice_coef_infection: 0.6160 - iou_coef_infection: 0.4773 - precision_infection: 0.6379 - recall_infection: 0.6717 - hausdorff95_infection: 60.6239 - specificity_infection: 0.9973 - accuracy_infection: 0.9943 - f1_infection: 0.8087 - val_loss: 0.2002 - val_dice_coef_infection: 0.8051 - val_iou_coef_infection: 0.7832 - val_precision_infection: 0.8609 - val_recall_infection: 0.8858 - val_hausdorff95_infection: 18.1492 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9991 - val_f1_infection: 0.9192
# ✅ Model saved at epoch 21 with val_loss: 0.2002
# Epoch 22/100
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.4152 - dice_coef_infection: 0.6144 - iou_coef_infection: 0.4772 - precision_infection: 0.6441 - recall_infection: 0.6659 - hausdorff95_infection: 56.9511 - specificity_infection: 0.9974 - accuracy_infection: 0.9945 - f1_infection: 0.8088 - val_loss: 0.1950 - val_dice_coef_infection: 0.8119 - val_iou_coef_infection: 0.7932 - val_precision_infection: 0.8941 - val_recall_infection: 0.8672 - val_hausdorff95_infection: 27.2559 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.9194
# ✅ Model saved at epoch 22 with val_loss: 0.1950
# Epoch 23/100
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.4186 - dice_coef_infection: 0.6113 - iou_coef_infection: 0.4764 - precision_infection: 0.6448 - recall_infection: 0.6646 - hausdorff95_infection: 55.5153 - specificity_infection: 0.9975 - accuracy_infection: 0.9946 - f1_infection: 0.8087 - val_loss: 0.1760 - val_dice_coef_infection: 0.8283 - val_iou_coef_infection: 0.8011 - val_precision_infection: 0.8437 - val_recall_infection: 0.9103 - val_hausdorff95_infection: 12.2757 - val_specificity_infection: 0.9995 - val_accuracy_infection: 0.9991 - val_f1_infection: 0.9293
# ✅ Model saved at epoch 23 with val_loss: 0.1760
# Epoch 24/100
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.4090 - dice_coef_infection: 0.6185 - iou_coef_infection: 0.4830 - precision_infection: 0.6381 - recall_infection: 0.6766 - hausdorff95_infection: 54.5831 - specificity_infection: 0.9974 - accuracy_infection: 0.9947 - f1_infection: 0.8114 - val_loss: 0.1767 - val_dice_coef_infection: 0.8303 - val_iou_coef_infection: 0.8083 - val_precision_infection: 0.9002 - val_recall_infection: 0.8712 - val_hausdorff95_infection: 18.3520 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.9280
# Epoch 25/100
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.4038 - dice_coef_infection: 0.6253 - iou_coef_infection: 0.4880 - precision_infection: 0.6510 - recall_infection: 0.6733 - hausdorff95_infection: 57.8822 - specificity_infection: 0.9974 - accuracy_infection: 0.9945 - f1_infection: 0.8133 - val_loss: 0.1668 - val_dice_coef_infection: 0.8379 - val_iou_coef_infection: 0.8133 - val_precision_infection: 0.8714 - val_recall_infection: 0.9004 - val_hausdorff95_infection: 15.4711 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9992 - val_f1_infection: 0.9315
# ✅ Model saved at epoch 25 with val_loss: 0.1668
# Epoch 26/100
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.4352 - dice_coef_infection: 0.5955 - iou_coef_infection: 0.4590 - precision_infection: 0.6298 - recall_infection: 0.6501 - hausdorff95_infection: 54.7558 - specificity_infection: 0.9974 - accuracy_infection: 0.9944 - f1_infection: 0.8029 - val_loss: 0.1775 - val_dice_coef_infection: 0.8281 - val_iou_coef_infection: 0.8058 - val_precision_infection: 0.8816 - val_recall_infection: 0.8859 - val_hausdorff95_infection: 19.8121 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9991 - val_f1_infection: 0.9265
# Epoch 27/100
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 182ms/step - loss: 0.4018 - dice_coef_infection: 0.6267 - iou_coef_infection: 0.4889 - precision_infection: 0.6441 - recall_infection: 0.6823 - hausdorff95_infection: 56.0643 - specificity_infection: 0.9974 - accuracy_infection: 0.9946 - f1_infection: 0.8124 - val_loss: 0.1586 - val_dice_coef_infection: 0.8460 - val_iou_coef_infection: 0.8206 - val_precision_infection: 0.8746 - val_recall_infection: 0.9054 - val_hausdorff95_infection: 13.9775 - val_specificity_infection: 0.9996 - val_accuracy_infection: 0.9992 - val_f1_infection: 0.9340
# ✅ Model saved at epoch 27 with val_loss: 0.1586
# Epoch 28/100
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 208s 182ms/step - loss: 0.4077 - dice_coef_infection: 0.6208 - iou_coef_infection: 0.4837 - precision_infection: 0.6353 - recall_infection: 0.6801 - hausdorff95_infection: 55.2998 - specificity_infection: 0.9974 - accuracy_infection: 0.9947 - f1_infection: 0.8131 - val_loss: 0.1787 - val_dice_coef_infection: 0.8300 - val_iou_coef_infection: 0.8117 - val_precision_infection: 0.9247 - val_recall_infection: 0.8620 - val_hausdorff95_infection: 29.5675 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.9229
# Epoch 29/100
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.3935 - dice_coef_infection: 0.6345 - iou_coef_infection: 0.4981 - precision_infection: 0.6565 - recall_infection: 0.6850 - hausdorff95_infection: 56.1571 - specificity_infection: 0.9976 - accuracy_infection: 0.9949 - f1_infection: 0.8162 - val_loss: 0.1639 - val_dice_coef_infection: 0.8430 - val_iou_coef_infection: 0.8235 - val_precision_infection: 0.9205 - val_recall_infection: 0.8747 - val_hausdorff95_infection: 23.3896 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9991 - val_f1_infection: 0.9299
# Epoch 30/100
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.4048 - dice_coef_infection: 0.6237 - iou_coef_infection: 0.4864 - precision_infection: 0.6456 - recall_infection: 0.6755 - hausdorff95_infection: 54.9157 - specificity_infection: 0.9975 - accuracy_infection: 0.9948 - f1_infection: 0.8131 - val_loss: 0.1580 - val_dice_coef_infection: 0.8481 - val_iou_coef_infection: 0.8291 - val_precision_infection: 0.9217 - val_recall_infection: 0.8719 - val_hausdorff95_infection: 25.3814 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9991 - val_f1_infection: 0.9342
# ✅ Model saved at epoch 30 with val_loss: 0.1580
# Epoch 31/100
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.4184 - dice_coef_infection: 0.6113 - iou_coef_infection: 0.4791 - precision_infection: 0.6560 - recall_infection: 0.6572 - hausdorff95_infection: 52.2226 - specificity_infection: 0.9975 - accuracy_infection: 0.9948 - f1_infection: 0.8111 - val_loss: 0.1454 - val_dice_coef_infection: 0.8618 - val_iou_coef_infection: 0.8421 - val_precision_infection: 0.9420 - val_recall_infection: 0.8754 - val_hausdorff95_infection: 23.8376 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9991 - val_f1_infection: 0.9346
# ✅ Model saved at epoch 31 with val_loss: 0.1454
# Epoch 32/100
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.4048 - dice_coef_infection: 0.6258 - iou_coef_infection: 0.4874 - precision_infection: 0.6666 - recall_infection: 0.6571 - hausdorff95_infection: 52.6015 - specificity_infection: 0.9975 - accuracy_infection: 0.9946 - f1_infection: 0.8120 - val_loss: 0.1417 - val_dice_coef_infection: 0.8642 - val_iou_coef_infection: 0.8397 - val_precision_infection: 0.9055 - val_recall_infection: 0.8903 - val_hausdorff95_infection: 15.8056 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9991 - val_f1_infection: 0.9410
# ✅ Model saved at epoch 32 with val_loss: 0.1417
# Epoch 33/100
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.4072 - dice_coef_infection: 0.6225 - iou_coef_infection: 0.4849 - precision_infection: 0.6546 - recall_infection: 0.6763 - hausdorff95_infection: 50.6109 - specificity_infection: 0.9974 - accuracy_infection: 0.9946 - f1_infection: 0.8072 - val_loss: 0.1719 - val_dice_coef_infection: 0.8338 - val_iou_coef_infection: 0.8131 - val_precision_infection: 0.8940 - val_recall_infection: 0.8815 - val_hausdorff95_infection: 22.2631 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9992 - val_f1_infection: 0.9296
# Epoch 34/100
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.3935 - dice_coef_infection: 0.6350 - iou_coef_infection: 0.4989 - precision_infection: 0.6700 - recall_infection: 0.6857 - hausdorff95_infection: 51.0585 - specificity_infection: 0.9976 - accuracy_infection: 0.9948 - f1_infection: 0.8108 - val_loss: 0.1441 - val_dice_coef_infection: 0.8614 - val_iou_coef_infection: 0.8380 - val_precision_infection: 0.9001 - val_recall_infection: 0.8927 - val_hausdorff95_infection: 18.0170 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9991 - val_f1_infection: 0.9424
# Epoch 35/100
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.3820 - dice_coef_infection: 0.6465 - iou_coef_infection: 0.5097 - precision_infection: 0.6749 - recall_infection: 0.6794 - hausdorff95_infection: 51.4556 - specificity_infection: 0.9975 - accuracy_infection: 0.9948 - f1_infection: 0.8225 - val_loss: 0.1511 - val_dice_coef_infection: 0.8563 - val_iou_coef_infection: 0.8365 - val_precision_infection: 0.9296 - val_recall_infection: 0.8718 - val_hausdorff95_infection: 25.6361 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9991 - val_f1_infection: 0.9372
# Epoch 36/100
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.3890 - dice_coef_infection: 0.6418 - iou_coef_infection: 0.5044 - precision_infection: 0.6800 - recall_infection: 0.6711 - hausdorff95_infection: 51.6325 - specificity_infection: 0.9976 - accuracy_infection: 0.9947 - f1_infection: 0.8176 - val_loss: 0.1561 - val_dice_coef_infection: 0.8508 - val_iou_coef_infection: 0.8306 - val_precision_infection: 0.9189 - val_recall_infection: 0.8787 - val_hausdorff95_infection: 24.7890 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9991 - val_f1_infection: 0.9336
# Epoch 37/100
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 208s 182ms/step - loss: 0.4082 - dice_coef_infection: 0.6209 - iou_coef_infection: 0.4866 - precision_infection: 0.6621 - recall_infection: 0.6633 - hausdorff95_infection: 52.9529 - specificity_infection: 0.9975 - accuracy_infection: 0.9948 - f1_infection: 0.8114 - val_loss: 0.1446 - val_dice_coef_infection: 0.8614 - val_iou_coef_infection: 0.8391 - val_precision_infection: 0.9198 - val_recall_infection: 0.8799 - val_hausdorff95_infection: 20.3008 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9991 - val_f1_infection: 0.9401
# Epoch 38/100
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 208s 182ms/step - loss: 0.4006 - dice_coef_infection: 0.6278 - iou_coef_infection: 0.4913 - precision_infection: 0.6520 - recall_infection: 0.6720 - hausdorff95_infection: 50.9630 - specificity_infection: 0.9975 - accuracy_infection: 0.9949 - f1_infection: 0.8160 - val_loss: 0.1522 - val_dice_coef_infection: 0.8553 - val_iou_coef_infection: 0.8362 - val_precision_infection: 0.9424 - val_recall_infection: 0.8709 - val_hausdorff95_infection: 27.7781 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9991 - val_f1_infection: 0.9322
# Epoch 39/100
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.4043 - dice_coef_infection: 0.6231 - iou_coef_infection: 0.4864 - precision_infection: 0.6676 - recall_infection: 0.6630 - hausdorff95_infection: 49.8208 - specificity_infection: 0.9977 - accuracy_infection: 0.9950 - f1_infection: 0.8077 - val_loss: 0.1508 - val_dice_coef_infection: 0.8547 - val_iou_coef_infection: 0.8314 - val_precision_infection: 0.9000 - val_recall_infection: 0.8856 - val_hausdorff95_infection: 16.0442 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9991 - val_f1_infection: 0.9408
# Epoch 40/100
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.3711 - dice_coef_infection: 0.6573 - iou_coef_infection: 0.5205 - precision_infection: 0.6765 - recall_infection: 0.6980 - hausdorff95_infection: 51.0307 - specificity_infection: 0.9975 - accuracy_infection: 0.9947 - f1_infection: 0.8245 - val_loss: 0.1535 - val_dice_coef_infection: 0.8516 - val_iou_coef_infection: 0.8264 - val_precision_infection: 0.8812 - val_recall_infection: 0.8962 - val_hausdorff95_infection: 13.1949 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9992 - val_f1_infection: 0.9388
# Epoch 41/100
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.3812 - dice_coef_infection: 0.6473 - iou_coef_infection: 0.5115 - precision_infection: 0.6824 - recall_infection: 0.6818 - hausdorff95_infection: 53.2577 - specificity_infection: 0.9975 - accuracy_infection: 0.9948 - f1_infection: 0.8203 - val_loss: 0.1493 - val_dice_coef_infection: 0.8558 - val_iou_coef_infection: 0.8343 - val_precision_infection: 0.9059 - val_recall_infection: 0.8903 - val_hausdorff95_infection: 18.5693 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9992 - val_f1_infection: 0.9378
# Epoch 42/100
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.3705 - dice_coef_infection: 0.6585 - iou_coef_infection: 0.5176 - precision_infection: 0.6820 - recall_infection: 0.6945 - hausdorff95_infection: 48.2501 - specificity_infection: 0.9976 - accuracy_infection: 0.9949 - f1_infection: 0.8192 - val_loss: 0.1547 - val_dice_coef_infection: 0.8505 - val_iou_coef_infection: 0.8276 - val_precision_infection: 0.8899 - val_recall_infection: 0.8928 - val_hausdorff95_infection: 16.4222 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9992 - val_f1_infection: 0.9378
# Epoch 43/100
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.3698 - dice_coef_infection: 0.6573 - iou_coef_infection: 0.5215 - precision_infection: 0.6839 - recall_infection: 0.6963 - hausdorff95_infection: 48.5176 - specificity_infection: 0.9976 - accuracy_infection: 0.9951 - f1_infection: 0.8234 - val_loss: 0.1691 - val_dice_coef_infection: 0.8385 - val_iou_coef_infection: 0.8181 - val_precision_infection: 0.9093 - val_recall_infection: 0.8746 - val_hausdorff95_infection: 24.3925 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9991 - val_f1_infection: 0.9290
# Epoch 44/100
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.3769 - dice_coef_infection: 0.6499 - iou_coef_infection: 0.5146 - precision_infection: 0.6732 - recall_infection: 0.6922 - hausdorff95_infection: 49.5594 - specificity_infection: 0.9976 - accuracy_infection: 0.9951 - f1_infection: 0.8206 - val_loss: 0.1395 - val_dice_coef_infection: 0.8665 - val_iou_coef_infection: 0.8439 - val_precision_infection: 0.9145 - val_recall_infection: 0.8889 - val_hausdorff95_infection: 17.5952 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9992 - val_f1_infection: 0.9429
# ✅ Model saved at epoch 44 with val_loss: 0.1395
# Epoch 45/100
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.4125 - dice_coef_infection: 0.6202 - iou_coef_infection: 0.4872 - precision_infection: 0.6695 - recall_infection: 0.6588 - hausdorff95_infection: 50.2696 - specificity_infection: 0.9976 - accuracy_infection: 0.9946 - f1_infection: 0.8100 - val_loss: 0.1416 - val_dice_coef_infection: 0.8636 - val_iou_coef_infection: 0.8405 - val_precision_infection: 0.9051 - val_recall_infection: 0.8976 - val_hausdorff95_infection: 17.1247 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9992 - val_f1_infection: 0.9394
# Epoch 46/100
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.3945 - dice_coef_infection: 0.6329 - iou_coef_infection: 0.4994 - precision_infection: 0.6738 - recall_infection: 0.6707 - hausdorff95_infection: 49.2094 - specificity_infection: 0.9978 - accuracy_infection: 0.9953 - f1_infection: 0.8187 - val_loss: 0.1500 - val_dice_coef_infection: 0.8553 - val_iou_coef_infection: 0.8323 - val_precision_infection: 0.8970 - val_recall_infection: 0.8930 - val_hausdorff95_infection: 16.3066 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9992 - val_f1_infection: 0.9387
# Epoch 47/100
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.3758 - dice_coef_infection: 0.6505 - iou_coef_infection: 0.5145 - precision_infection: 0.6857 - recall_infection: 0.6857 - hausdorff95_infection: 50.9317 - specificity_infection: 0.9976 - accuracy_infection: 0.9951 - f1_infection: 0.8178 - val_loss: 0.1614 - val_dice_coef_infection: 0.8451 - val_iou_coef_infection: 0.8247 - val_precision_infection: 0.9139 - val_recall_infection: 0.8769 - val_hausdorff95_infection: 17.7911 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9991 - val_f1_infection: 0.9327
# Epoch 48/100
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.3506 - dice_coef_infection: 0.6763 - iou_coef_infection: 0.5385 - precision_infection: 0.6936 - recall_infection: 0.7053 - hausdorff95_infection: 44.1714 - specificity_infection: 0.9976 - accuracy_infection: 0.9951 - f1_infection: 0.8311 - val_loss: 0.1723 - val_dice_coef_infection: 0.8353 - val_iou_coef_infection: 0.8158 - val_precision_infection: 0.9223 - val_recall_infection: 0.8622 - val_hausdorff95_infection: 22.3196 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.9268
# Epoch 49/100
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.3720 - dice_coef_infection: 0.6557 - iou_coef_infection: 0.5205 - precision_infection: 0.7016 - recall_infection: 0.6849 - hausdorff95_infection: 48.8899 - specificity_infection: 0.9976 - accuracy_infection: 0.9949 - f1_infection: 0.8200 - val_loss: 0.1441 - val_dice_coef_infection: 0.8610 - val_iou_coef_infection: 0.8372 - val_precision_infection: 0.8986 - val_recall_infection: 0.8974 - val_hausdorff95_infection: 16.0834 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9992 - val_f1_infection: 0.9398
# Epoch 50/100
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 208s 182ms/step - loss: 0.3587 - dice_coef_infection: 0.6678 - iou_coef_infection: 0.5324 - precision_infection: 0.6836 - recall_infection: 0.7049 - hausdorff95_infection: 45.2779 - specificity_infection: 0.9975 - accuracy_infection: 0.9949 - f1_infection: 0.8295 - val_loss: 0.1322 - val_dice_coef_infection: 0.8730 - val_iou_coef_infection: 0.8497 - val_precision_infection: 0.9093 - val_recall_infection: 0.8958 - val_hausdorff95_infection: 15.9549 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9992 - val_f1_infection: 0.9469
# ✅ Model saved at epoch 50 with val_loss: 0.1322
# Epoch 51/100
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 208s 182ms/step - loss: 0.3690 - dice_coef_infection: 0.6584 - iou_coef_infection: 0.5230 - precision_infection: 0.6952 - recall_infection: 0.6881 - hausdorff95_infection: 47.5104 - specificity_infection: 0.9976 - accuracy_infection: 0.9951 - f1_infection: 0.8225 - val_loss: 0.1507 - val_dice_coef_infection: 0.8546 - val_iou_coef_infection: 0.8310 - val_precision_infection: 0.8950 - val_recall_infection: 0.8929 - val_hausdorff95_infection: 16.8256 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9992 - val_f1_infection: 0.9376
# Epoch 52/100
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 208s 182ms/step - loss: 0.3632 - dice_coef_infection: 0.6647 - iou_coef_infection: 0.5309 - precision_infection: 0.7073 - recall_infection: 0.6978 - hausdorff95_infection: 47.8127 - specificity_infection: 0.9976 - accuracy_infection: 0.9951 - f1_infection: 0.8216 - val_loss: 0.1506 - val_dice_coef_infection: 0.8585 - val_iou_coef_infection: 0.8392 - val_precision_infection: 0.9516 - val_recall_infection: 0.8614 - val_hausdorff95_infection: 26.5886 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.9355
# Epoch 53/100
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 208s 182ms/step - loss: 0.3736 - dice_coef_infection: 0.6526 - iou_coef_infection: 0.5193 - precision_infection: 0.6764 - recall_infection: 0.6944 - hausdorff95_infection: 48.0161 - specificity_infection: 0.9976 - accuracy_infection: 0.9952 - f1_infection: 0.8242 - val_loss: 0.1665 - val_dice_coef_infection: 0.8393 - val_iou_coef_infection: 0.8158 - val_precision_infection: 0.8874 - val_recall_infection: 0.8865 - val_hausdorff95_infection: 15.1601 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9991 - val_f1_infection: 0.9328
# Epoch 54/100
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 208s 182ms/step - loss: 0.3743 - dice_coef_infection: 0.6535 - iou_coef_infection: 0.5148 - precision_infection: 0.6810 - recall_infection: 0.6893 - hausdorff95_infection: 46.4377 - specificity_infection: 0.9976 - accuracy_infection: 0.9949 - f1_infection: 0.8202 - val_loss: 0.1362 - val_dice_coef_infection: 0.8687 - val_iou_coef_infection: 0.8438 - val_precision_infection: 0.8920 - val_recall_infection: 0.9039 - val_hausdorff95_infection: 13.9129 - val_specificity_infection: 0.9996 - val_accuracy_infection: 0.9991 - val_f1_infection: 0.9462
# Epoch 55/100
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 208s 182ms/step - loss: 0.3771 - dice_coef_infection: 0.6512 - iou_coef_infection: 0.5131 - precision_infection: 0.6878 - recall_infection: 0.6818 - hausdorff95_infection: 49.6040 - specificity_infection: 0.9976 - accuracy_infection: 0.9950 - f1_infection: 0.8186 - val_loss: 0.1495 - val_dice_coef_infection: 0.8570 - val_iou_coef_infection: 0.8375 - val_precision_infection: 0.9250 - val_recall_infection: 0.8773 - val_hausdorff95_infection: 21.5390 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9991 - val_f1_infection: 0.9376
# Epoch 56/100
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 208s 182ms/step - loss: 0.3871 - dice_coef_infection: 0.6407 - iou_coef_infection: 0.5045 - precision_infection: 0.6830 - recall_infection: 0.6703 - hausdorff95_infection: 44.9658 - specificity_infection: 0.9976 - accuracy_infection: 0.9951 - f1_infection: 0.8160 - val_loss: 0.1593 - val_dice_coef_infection: 0.8465 - val_iou_coef_infection: 0.8233 - val_precision_infection: 0.8894 - val_recall_infection: 0.8868 - val_hausdorff95_infection: 16.0266 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9992 - val_f1_infection: 0.9379
# Epoch 57/100
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 208s 182ms/step - loss: 0.3723 - dice_coef_infection: 0.6522 - iou_coef_infection: 0.5219 - precision_infection: 0.6957 - recall_infection: 0.6775 - hausdorff95_infection: 45.2056 - specificity_infection: 0.9978 - accuracy_infection: 0.9954 - f1_infection: 0.8276 - val_loss: 0.1607 - val_dice_coef_infection: 0.8456 - val_iou_coef_infection: 0.8219 - val_precision_infection: 0.8832 - val_recall_infection: 0.8916 - val_hausdorff95_infection: 16.9440 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9991 - val_f1_infection: 0.9357
# Epoch 58/100
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 208s 182ms/step - loss: 0.3621 - dice_coef_infection: 0.6653 - iou_coef_infection: 0.5279 - precision_infection: 0.6856 - recall_infection: 0.7065 - hausdorff95_infection: 46.9933 - specificity_infection: 0.9974 - accuracy_infection: 0.9949 - f1_infection: 0.8241 - val_loss: 0.1470 - val_dice_coef_infection: 0.8586 - val_iou_coef_infection: 0.8350 - val_precision_infection: 0.8933 - val_recall_infection: 0.8890 - val_hausdorff95_infection: 15.2390 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9991 - val_f1_infection: 0.9436
# Epoch 59/100
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 208s 182ms/step - loss: 0.3486 - dice_coef_infection: 0.6769 - iou_coef_infection: 0.5393 - precision_infection: 0.6968 - recall_infection: 0.7079 - hausdorff95_infection: 44.9894 - specificity_infection: 0.9978 - accuracy_infection: 0.9954 - f1_infection: 0.8294 - val_loss: 0.1501 - val_dice_coef_infection: 0.8552 - val_iou_coef_infection: 0.8323 - val_precision_infection: 0.9017 - val_recall_infection: 0.8905 - val_hausdorff95_infection: 17.5673 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9992 - val_f1_infection: 0.9373
# Epoch 60/100
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 208s 182ms/step - loss: 0.3469 - dice_coef_infection: 0.6776 - iou_coef_infection: 0.5416 - precision_infection: 0.6934 - recall_infection: 0.7134 - hausdorff95_infection: 43.5980 - specificity_infection: 0.9976 - accuracy_infection: 0.9953 - f1_infection: 0.8316 - val_loss: 0.1495 - val_dice_coef_infection: 0.8564 - val_iou_coef_infection: 0.8333 - val_precision_infection: 0.9044 - val_recall_infection: 0.8906 - val_hausdorff95_infection: 16.1208 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9992 - val_f1_infection: 0.9371
# Epoch 61/100
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.3485 - dice_coef_infection: 0.6763 - iou_coef_infection: 0.5410 - precision_infection: 0.6893 - recall_infection: 0.7152 - hausdorff95_infection: 43.3716 - specificity_infection: 0.9976 - accuracy_infection: 0.9953 - f1_infection: 0.8316 - val_loss: 0.1794 - val_dice_coef_infection: 0.8256 - val_iou_coef_infection: 0.8013 - val_precision_infection: 0.8573 - val_recall_infection: 0.8956 - val_hausdorff95_infection: 16.2045 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9992 - val_f1_infection: 0.9275
# Epoch 62/100
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 207s 181ms/step - loss: 0.3584 - dice_coef_infection: 0.6668 - iou_coef_infection: 0.5341 - precision_infection: 0.6984 - recall_infection: 0.7000 - hausdorff95_infection: 45.9533 - specificity_infection: 0.9976 - accuracy_infection: 0.9952 - f1_infection: 0.8287 - val_loss: 0.1580 - val_dice_coef_infection: 0.8475 - val_iou_coef_infection: 0.8262 - val_precision_infection: 0.8976 - val_recall_infection: 0.8846 - val_hausdorff95_infection: 17.1894 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9992 - val_f1_infection: 0.9369
# Epoch 63/100
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 208s 182ms/step - loss: 0.3525 - dice_coef_infection: 0.6723 - iou_coef_infection: 0.5396 - precision_infection: 0.6934 - recall_infection: 0.7181 - hausdorff95_infection: 44.1377 - specificity_infection: 0.9977 - accuracy_infection: 0.9952 - f1_infection: 0.8279 - val_loss: 0.1884 - val_dice_coef_infection: 0.8214 - val_iou_coef_infection: 0.8036 - val_precision_infection: 0.9266 - val_recall_infection: 0.8535 - val_hausdorff95_infection: 30.0042 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.9201
# Epoch 64/100
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 208s 182ms/step - loss: 0.3636 - dice_coef_infection: 0.6620 - iou_coef_infection: 0.5265 - precision_infection: 0.6866 - recall_infection: 0.7016 - hausdorff95_infection: 46.2043 - specificity_infection: 0.9976 - accuracy_infection: 0.9952 - f1_infection: 0.8231 - val_loss: 0.1637 - val_dice_coef_infection: 0.8434 - val_iou_coef_infection: 0.8235 - val_precision_infection: 0.9267 - val_recall_infection: 0.8670 - val_hausdorff95_infection: 22.3508 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9991 - val_f1_infection: 0.9309
# Epoch 65/100
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 208s 182ms/step - loss: 0.3577 - dice_coef_infection: 0.6682 - iou_coef_infection: 0.5305 - precision_infection: 0.6952 - recall_infection: 0.7032 - hausdorff95_infection: 46.6206 - specificity_infection: 0.9977 - accuracy_infection: 0.9952 - f1_infection: 0.8246 - val_loss: 0.1475 - val_dice_coef_infection: 0.8574 - val_iou_coef_infection: 0.8346 - val_precision_infection: 0.8940 - val_recall_infection: 0.8986 - val_hausdorff95_infection: 17.0394 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9992 - val_f1_infection: 0.9384
# Epoch 66/100
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 208s 182ms/step - loss: 0.3508 - dice_coef_infection: 0.6750 - iou_coef_infection: 0.5397 - precision_infection: 0.6904 - recall_infection: 0.7198 - hausdorff95_infection: 43.5995 - specificity_infection: 0.9976 - accuracy_infection: 0.9952 - f1_infection: 0.8284 - val_loss: 0.1662 - val_dice_coef_infection: 0.8381 - val_iou_coef_infection: 0.8148 - val_precision_infection: 0.8638 - val_recall_infection: 0.9055 - val_hausdorff95_infection: 16.7208 - val_specificity_infection: 0.9996 - val_accuracy_infection: 0.9992 - val_f1_infection: 0.9322
# Epoch 67/100
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 208s 182ms/step - loss: 0.3457 - dice_coef_infection: 0.6799 - iou_coef_infection: 0.5443 - precision_infection: 0.6951 - recall_infection: 0.7218 - hausdorff95_infection: 44.9601 - specificity_infection: 0.9977 - accuracy_infection: 0.9952 - f1_infection: 0.8315 - val_loss: 0.1502 - val_dice_coef_infection: 0.8542 - val_iou_coef_infection: 0.8292 - val_precision_infection: 0.8786 - val_recall_infection: 0.9073 - val_hausdorff95_infection: 15.2329 - val_specificity_infection: 0.9996 - val_accuracy_infection: 0.9992 - val_f1_infection: 0.9371
# Epoch 68/100
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 208s 182ms/step - loss: 0.3574 - dice_coef_infection: 0.6681 - iou_coef_infection: 0.5334 - precision_infection: 0.6960 - recall_infection: 0.6918 - hausdorff95_infection: 44.4168 - specificity_infection: 0.9978 - accuracy_infection: 0.9954 - f1_infection: 0.8300 - val_loss: 0.1492 - val_dice_coef_infection: 0.8558 - val_iou_coef_infection: 0.8355 - val_precision_infection: 0.9105 - val_recall_infection: 0.8904 - val_hausdorff95_infection: 18.9174 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9992 - val_f1_infection: 0.9372
# Epoch 69/100
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 208s 182ms/step - loss: 0.3210 - dice_coef_infection: 0.7039 - iou_coef_infection: 0.5652 - precision_infection: 0.7165 - recall_infection: 0.7277 - hausdorff95_infection: 42.8235 - specificity_infection: 0.9976 - accuracy_infection: 0.9952 - f1_infection: 0.8388 - val_loss: 0.1685 - val_dice_coef_infection: 0.8370 - val_iou_coef_infection: 0.8166 - val_precision_infection: 0.8893 - val_recall_infection: 0.8855 - val_hausdorff95_infection: 19.6036 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9992 - val_f1_infection: 0.9318
# Epoch 70/100
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 208s 182ms/step - loss: 0.3331 - dice_coef_infection: 0.6916 - iou_coef_infection: 0.5553 - precision_infection: 0.7132 - recall_infection: 0.7129 - hausdorff95_infection: 39.7260 - specificity_infection: 0.9978 - accuracy_infection: 0.9954 - f1_infection: 0.8365 - val_loss: 0.1736 - val_dice_coef_infection: 0.8342 - val_iou_coef_infection: 0.8148 - val_precision_infection: 0.9078 - val_recall_infection: 0.8637 - val_hausdorff95_infection: 25.9570 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.9310
# 🛑 Early stopping at epoch 70
# ✅ Total training time: 14600.18 seconds (243.34 minutes)

# %% [markdown]
# ## Plotting the performance metrics

# %%
plt.plot(history.history['dice_coef_infection'])
plt.plot(history.history['val_dice_coef_infection'])
plt.title('dice_coef_infection vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Dice_coef')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# %%
plt.plot(history.history['iou_coef_infection'])
plt.plot(history.history['val_iou_coef_infection'])
plt.title('iou_coef_infection vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Iou_coef')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Val'], loc = 'upper right')
plt.show()

# %% [markdown]
# ## Using our trained model for prediction

# %%
import numpy as np
import time

# Start timer (high precision)
start_time = time.perf_counter()

# Evaluate the model on the validation generator
results = model.evaluate(val_gen, verbose=1)

# End timer
end_time = time.perf_counter()

# Calculate evaluation time
eval_time = end_time - start_time

# Print metric names with results
print("\n===== Validation Metrics =====")
for name, value in zip(model.metrics_names, results):
    print(f"{name}: {value:.6f}")

print(f"\nEvaluation Time: {eval_time:.8f} seconds\n")
# Out:
# 128/128 [==============================] - 8s 66ms/step - loss: 0.3305 - dice_coef_infection: 0.7184 - iou_coef_infection: 0.6808 - precision_infection: 0.9582 - recall_infection: 0.7055 - hausdorff95_infection: 66.1634 - specificity_infection: 0.9998 - accuracy_infection: 0.9964 - f1_infection: 0.8558
#
# ===== Validation Metrics =====
# loss: 0.330546
# dice_coef_infection: 0.718362
# iou_coef_infection: 0.680849
# precision_infection: 0.958240
# recall_infection: 0.705525
# hausdorff95_infection: 66.163414
# specificity_infection: 0.999841
# accuracy_infection: 0.996388
# f1_infection: 0.855781
#
# Evaluation Time: 8.48085731 seconds

# %%
import matplotlib.pyplot as plt
import numpy as np

# Run inference if not already done
predicted = model.predict(lung_test)

# Selected indices to visualize (744 as 1st, 280 as 2nd, 230 as 3rd)
selected_indices = [744, 280, 230]
n_samples = len(selected_indices)

# Mapping indices to custom names
name_mapping = {
    0: ("Image1_Covid", "GT1_Covid", "Predict1_Covid_DSEG_Unet"),  # Index 744
    1: ("Image2_Covid", "GT2_Covid", "Predict2_Covid_DSEG_Unet"),  # Index 280
    2: ("Image3_Covid", "GT3_Covid", "Predict3_Covid_DSEG_Unet")   # Index 230
}

# Plot
for j, i in enumerate(selected_indices):
    lung_img = lung_test[i][..., 0].astype(np.float32)
    gt_infect = (infect_test[i][..., 0] > 0.5).astype(np.float32)
    pred_infect = predicted[i][..., 0].astype(np.float32)

    # Normalize lung image
    if lung_img.max() > lung_img.min():
        lung_img = (lung_img - lung_img.min()) / (lung_img.max() - lung_img.min())
    lung_img = np.clip(lung_img, 0, 1)
    pred_infect = np.clip(pred_infect, 0, 1)

    # Get custom names for this index
    input_name, gt_name, pred_name = name_mapping[j]

    # Save Original Lung
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{input_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

    # Save Ground Truth Infection
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.imshow(gt_infect, cmap='Reds', alpha=0.6)
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{gt_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

    # Save Predicted Infection
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.imshow(pred_infect, cmap='Reds', alpha=0.6)
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{pred_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

print("Separate JPEG files saved for input images (Image1_Covid, Image2_Covid, Image3_Covid), "
      "ground truths (GT1_Covid, GT2_Covid, GT3_Covid), and predictions "
      "(Predict1_Covid_DSEG_Unet, Predict2_Covid_DSEG_Unet, Predict3_Covid_DSEG_Unet).")
# Out:
# Separate JPEG files saved for input images (Image1_Covid, Image2_Covid, Image3_Covid), ground truths (GT1_Covid, GT2_Covid, GT3_Covid), and predictions (Predict1_Covid_DSEG_Unet, Predict2_Covid_DSEG_Unet, Predict3_Covid_DSEG_Unet).
