# %% [markdown]
# ## Importing important libraries

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import nibabel as nib #for loading nii files
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf #for deep learning

# %% [markdown]
# ## Reading the metadata

# %%
data = pd.read_csv('../input/covid19-ct-scans/metadata.csv')
data.head()
# Out:
#                                              ct_scan  \
# 0  ../input/covid19-ct-scans/ct_scans/coronacases...
# 1  ../input/covid19-ct-scans/ct_scans/coronacases...
# 2  ../input/covid19-ct-scans/ct_scans/coronacases...
# 3  ../input/covid19-ct-scans/ct_scans/coronacases...
# 4  ../input/covid19-ct-scans/ct_scans/coronacases...
#
#                                            lung_mask  \
# 0  ../input/covid19-ct-scans/lung_mask/coronacase...
# 1  ../input/covid19-ct-scans/lung_mask/coronacase...
# 2  ../input/covid19-ct-scans/lung_mask/coronacase...
# 3  ../input/covid19-ct-scans/lung_mask/coronacase...
# 4  ../input/covid19-ct-scans/lung_mask/coronacase...
#
#                                       infection_mask  \
# 0  ../input/covid19-ct-scans/infection_mask/coron...
# 1  ../input/covid19-ct-scans/infection_mask/coron...
# 2  ../input/covid19-ct-scans/infection_mask/coron...
# 3  ../input/covid19-ct-scans/infection_mask/coron...
# 4  ../input/covid19-ct-scans/infection_mask/coron...
#
#                              lung_and_infection_mask
# 0  ../input/covid19-ct-scans/lung_and_infection_m...
# 1  ../input/covid19-ct-scans/lung_and_infection_m...
# 2  ../input/covid19-ct-scans/lung_and_infection_m...
# 3  ../input/covid19-ct-scans/lung_and_infection_m...
# 4  ../input/covid19-ct-scans/lung_and_infection_m...

# %% [markdown]
# ## Defining function for readiing .nii files

# %%
def read_nii(filepath):
    '''
    Reads .nii file and returns pixel array
    '''
    ct_scan = nib.load(filepath)
    array   = ct_scan.get_fdata()
    array   = np.rot90(np.array(array))
    return(array)

# %% [markdown]
# ## Reading the chest ct scan data

# %%
# Read sample
sample_ct   = read_nii(data.loc[2,'ct_scan'])
sample_lung = read_nii(data.loc[2,'lung_mask'])
sample_infe = read_nii(data.loc[2,'infection_mask'])
sample_all  = read_nii(data.loc[2,'lung_and_infection_mask'])

# %% [markdown]
# ## Plotting the sample images

# %%
fig = plt.figure(figsize = (18,15))
plt.subplot(1,4,1)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.title('Original Image')

plt.subplot(1,4,2)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_lung[..., 150],alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung Mask')

plt.subplot(1,4,3)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_infe[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Infection Mask')

plt.subplot(1,4,4)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_all[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung and Infection Mask')
# Out:
# Text(0.5, 1.0, 'Lung and Infection Mask')

# %% [markdown]
# ## Converting the data into array for training model

# %%
import numpy as np
import cv2
import random
from scipy.ndimage import rotate, shift, zoom

lungs = []
infections = []
case_ids = []
img_size = 320

# ----------- Load and Resize Data -----------
for case_index in range(len(data)):
    ct = read_nii(data['ct_scan'][case_index])
    infect = read_nii(data['infection_mask'][case_index])

    for slice_index in range(ct.shape[0]):
        lung_img = cv2.resize(ct[slice_index], dsize=(img_size, img_size)).astype('float32')
        infec_img = cv2.resize(infect[slice_index], dsize=(img_size, img_size)).astype('float32')

        lungs.append(lung_img[..., np.newaxis])
        infections.append(infec_img[..., np.newaxis])
        case_ids.append(case_index)

# %%
import numpy as np

# case_ids should be a NumPy array telling which case each slice belongs to
# Convert and binarize
lungs = np.array(lungs, dtype=np.float32)
infections = (np.array(infections, dtype=np.uint8) > 0.5).astype(np.uint8)
case_ids = np.array(case_ids)

# %% [markdown]
# ## Performing test and train split

# %%
# ----------- Case-wise Split -----------
unique_cases = np.unique(case_ids)
train_cases = np.append(unique_cases[4:12], unique_cases[12:20])
temp_cases = unique_cases[2:4]
val_cases = unique_cases[:2]

train_mask = np.isin(case_ids, train_cases)
temp_mask = np.isin(case_ids, temp_cases)
val_mask = np.isin(case_ids, val_cases)

lung_train = lungs[train_mask]
infect_train = infections[train_mask]
lung_temp = lungs[temp_mask]
infect_temp = infections[temp_mask]
lung_test = lungs[val_mask]
infect_test = infections[val_mask]

print(f"✅ Train: {lung_train.shape[0]} slices from {len(train_cases)} cases")
print(f"✅ Validation: {lung_temp.shape[0]} slices from {len(temp_cases)} cases")
print(f"✅ Test: {lung_test.shape[0]} slices from {len(val_cases)} cases")

# ----------- Augmentation -----------
def augment_image(img, mask):
    if random.random() < 0.5:
        img = np.fliplr(img)
        mask = np.fliplr(mask)
    if random.random() < 0.5:
        img = np.flipud(img)
        mask = np.flipud(mask)

    angle = random.uniform(-15, 15)
    img = rotate(img, angle, reshape=False, order=1, mode='nearest')
    mask = rotate(mask, angle, reshape=False, order=0, mode='nearest')

    shift_val = np.random.uniform(-0.1, 0.1, size=2) * img.shape[:2]
    img = shift(img, shift=(*shift_val, 0), order=1, mode='nearest')
    mask = shift(mask, shift=(*shift_val, 0), order=0, mode='nearest')

    zoom_factor = random.uniform(0.9, 1.1)
    img = zoom(img, (zoom_factor, zoom_factor, 1), order=1)
    mask = zoom(mask, (zoom_factor, zoom_factor, 1), order=0)

    return fix_shape(img), fix_shape(mask)

def fix_shape(arr, target_size=(320, 320)):
    h, w, c = arr.shape
    th, tw = target_size
    dh = th - h
    dw = tw - w
    if dh > 0 or dw > 0:
        pad_h = (max(dh // 2, 0), max(dh - dh // 2, 0))
        pad_w = (max(dw // 2, 0), max(dw - dw // 2, 0))
        arr = np.pad(arr, (pad_h, pad_w, (0, 0)), mode='constant')
    arr = arr[:th, :tw, :]
    return arr.astype('float32')

# ----------- Apply Augmentation -----------
aug_lung_train = []
aug_infect_train = []

for i in range(len(lung_train)):
    img, mask = augment_image(lung_train[i], infect_train[i])
    aug_lung_train.append(img)
    aug_infect_train.append(mask)

lung_train = np.stack(aug_lung_train)
infect_train = np.stack(aug_infect_train)

# Final Binarization
infect_train = (infect_train > 0.5).astype(np.uint8)
infect_test = (infect_test > 0.5).astype(np.uint8)

print(f"✅ Augmented training shape: {lung_train.shape}")
print("✅ All preprocessing complete.")
# Out:
# ✅ Train: 9143 slices from 16 cases
# ✅ Validation: 1024 slices from 2 cases
# ✅ Test: 1024 slices from 2 cases
# ✅ Augmented training shape: (9143, 320, 320, 1)
# ✅ All preprocessing complete.

# %%
import tensorflow as tf
from tensorflow.keras import backend as K
import numpy as np
from scipy.spatial import cKDTree

smooth = 1.0

# Binary Dice coefficient (soft - commonly used during training)
def dice_coef_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# Binary IoU coefficient (soft)
def iou_coef_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# Soft Precision
def precision_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + smooth) / (K.sum(y_pred_f) + smooth)

# Soft Recall (Sensitivity)
def recall_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + smooth) / (K.sum(y_true_f) + smooth)

# Soft Specificity
def specificity_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    tn = K.sum((1 - y_true_f) * (1 - y_pred_f))
    fp = K.sum((1 - y_true_f) * y_pred_f)
    return (tn + smooth) / (tn + fp + smooth)

# Soft Accuracy
def accuracy_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    tp = K.sum(y_true_f * y_pred_f)
    tn = K.sum((1 - y_true_f) * (1 - y_pred_f))
    total = K.cast(K.shape(y_true_f)[0], 'float32')
    return (tp + tn + smooth) / (total + smooth)

# Soft F1-score (harmonic mean of precision & recall - very close to Dice, standard in many repos)
def f1_infection(y_true, y_pred):
    precision = precision_infection(y_true, y_pred)
    recall    = recall_infection(y_true, y_pred)
    return (2. * precision * recall + smooth) / (precision + recall + smooth)

# Hausdorff Distance 95 % (robust & most commonly used in medical imaging challenges)
# Lower = better. Returns the mean HD95 over the batch.
def _calculate_hd95(y_true, y_pred):
    hd_list = []
    for i in range(y_true.shape[0]):
        # Hard threshold at 0.5 (standard for evaluation metrics)
        gt = np.squeeze(y_true[i]) > 0.5
        pred = np.squeeze(y_pred[i]) > 0.5

        gt_pts = np.argwhere(gt)
        pred_pts = np.argwhere(pred)

        # Cases with empty masks
        if gt_pts.shape[0] == 0 and pred_pts.shape[0] == 0:
            hd_list.append(0.0)
            continue
        if gt_pts.shape[0] == 0 or pred_pts.shape[0] == 0:
            hd_list.append(400.0)  # large penalty - adjust to your image diagonal if needed (e.g. ~362 for 256×256, ~724 for 512×512)
            continue

        # Directed distances
        dist_gt_to_pred = cKDTree(pred_pts).query(gt_pts)[0]
        dist_pred_to_gt = cKDTree(gt_pts).query(pred_pts)[0]

        hd95 = max(
            np.percentile(dist_gt_to_pred, 95),
            np.percentile(dist_pred_to_gt, 95)
        )
        hd_list.append(hd95)

    return np.mean(hd_list, dtype=np.float32)

def hausdorff95_infection(y_true, y_pred):
    hd = tf.numpy_function(_calculate_hd95, [y_true, y_pred], tf.float32)
    hd.set_shape(())
    return hd

# Optional: KL Divergence (you already had this)
kld = tf.keras.losses.KLDivergence()

# %%
from tensorflow.keras.losses import BinaryCrossentropy

def loss_f(y_true, y_pred):
    bce = BinaryCrossentropy()
    return dice_loss(y_true, y_pred) + bce(y_true, y_pred) 

def loss_e(y_true, y_pred):
    bce = BinaryCrossentropy()
    return dice_loss(y_true, y_pred)  + kld(y_true, y_pred)
    
def dice_loss(y_true, y_pred):
    return 1. - dice_coef_infection(y_true, y_pred)

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Multiply, Conv2D, DepthwiseConv2D, Dense, Flatten, MaxPooling2D, UpSampling2D, concatenate, Activation, LayerNormalization, Add, Dropout, Conv2DTranspose, multiply, Reshape, GlobalAveragePooling2D, Permute, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Concatenate

def activation_block(x):
    x = Activation("gelu")(x)
    return LayerNormalization()(x)

def conv_stem(x, filters: int, patch_size: int):
    x = Conv2D(filters, kernel_size=patch_size,padding='same', strides=patch_size)(x)
    return activation_block(x)

def vector_block(xyz, cmf, red):
    # red means reduction
    # cmf means filters, denotes vector size
    opt1 = conv_stem(xyz, cmf, red)
    opt2 = conv_stem(xyz, cmf, red)
    
    o1 = GlobalAveragePooling2D()(opt1)
    o2 = GlobalAveragePooling2D()(opt2)

    o5 = concatenate([o1, o2], -1)
    return o5

def mlp_feature(vect, cmf):
    oo = Flatten()(vect)
    o6 = Dense(cmf, activation='gelu')(oo)
    o6 = Dropout(0.2)(o6)
    o6 = Dense(cmf * 2, activation='gelu')(o6)

    o6 = Reshape((1, cmf * 2))(o6)
    o7 = Permute((2, 1))(o6)

    o8 = multiply([o6, o7])
    
    o8 = Lambda(lambda x: tf.expand_dims(x, -1))(o8)
    
    o8 = Reshape((cmf, cmf, 4))(o8)

    return o8

def frz_block(xyz):
    shape = xyz.shape
    a1, a2, a3, a4 = shape[0], shape[1], shape[2], shape[3]
    cmf = a2
    o5 = vector_block(xyz, cmf, 5)
    o7 = mlp_feature(o5, cmf)

    o7 = concatenate([o7, xyz, o7], -1)
    return o7

def up_frz(x1, x2, n_filters):
    # Upsample x1 using Conv2DTranspose
    x1 = Conv2DTranspose(n_filters * 4, 3, strides=2, activation='gelu', padding="same")(x1)
    
    # Apply Conv2D to x2
    x2 = Conv2D(n_filters * 2, 3, activation='gelu', padding="same")(x2)
    
    # Apply attention mechanism
    x = concatenate([x1, x2])
    
    # Apply Dropout for regularization
    x = Dropout(0.3)(x)
    
    return x

# %%
# !pip install keras-unet-collection

# !pip show keras-unet-collection
# !ls /opt/conda/lib/python3.7/site-packages/keras_unet_collection/
# !cp -r /opt/conda/lib/python3.7/site-packages/keras_unet_collection ./custom_keras_unet_collection
import re

# Define the updated swin_unet_2d_base function
updated_swin_unet_2d_base = """
def swin_unet_2d_base(input_tensor, filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, shift_window=True, name='swin_unet'):
    '''
    The base of SwinUNET with num_mlp set dynamically to equal embed_dim.
    
    ----------
    Cao, H., Wang, Y., Chen, J., Jiang, D., Zhang, X., Tian, Q. and Wang, M., 2021. 
    Swin-Unet: Unet-like Pure Transformer for Medical Image Segmentation. arXiv preprint arXiv:2105.05537.

    Input
    ----------
        input_tensor: the input tensor of the base, e.g., keras.layers.Input((None, None, 3)).
        filter_num_begin: number of channels in the first downsampling block; 
                          it is also the number of embedded dimensions.
        depth: the depth of Swin-UNET, e.g., depth=4 means three down/upsampling levels and a bottom level.
        stack_num_down: number of convolutional layers per downsampling level/block. 
        stack_num_up: number of convolutional layers (after concatenation) per upsampling level/block.
        name: prefix of the created keras model and its layers.

        ---------- (keywords of Swin-Transformers) ----------

        patch_size: The size of extracted patches, 
                    e.g., patch_size=(2, 2) means 2-by-2 patches
                    *Height and width of the patch must be equal.

        num_heads: number of attention heads per down/upsampling level,
                     e.g., num_heads=[4, 8, 16, 16] means increased attention heads with increasing depth.
                     *The length of num_heads must equal to depth.

        window_size: the size of attention window per down/upsampling level,
                     e.g., window_size=[4, 2, 2, 2] means decreased window size with increasing depth.

        shift_window: The indicator of window shifting;
                      shift_window=True means applying Swin-MSA for every two Swin-Transformer blocks.
                      shift_window=False means MSA with fixed window locations for all blocks.

    Output
    ----------
        output tensor.
    
    Note: This function is experimental.
          The activation functions of all Swin-Transformers are fixed to GELU.
    '''
    # Compute number of patches to be embedded
    input_size = input_tensor.shape.as_list()[1:]
    num_patch_x = input_size[0] // patch_size[0]
    num_patch_y = input_size[1] // patch_size[1]

    # Number of Embedded dimensions
    embed_dim = filter_num_begin

    depth_ = depth

    X_skip = []

    X = input_tensor

    # Patch extraction
    X = patch_extract(patch_size)(X)

    # Embed patches to tokens
    X = patch_embedding(num_patch_x * num_patch_y, embed_dim)(X)

    # The first Swin Transformer stack
    X = swin_transformer_stack(X, stack_num=stack_num_down, 
                               embed_dim=embed_dim, num_patch=(num_patch_x, num_patch_y), 
                               num_heads=num_heads[0], window_size=window_size[0], num_mlp=embed_dim*4, 
                               shift_window=shift_window, name='{}_swin_down0'.format(name))
    X_skip.append(X)

    # Downsampling blocks
    for i in range(depth_ - 1):

        # Patch merging
        X = patch_merging((num_patch_x, num_patch_y), embed_dim=embed_dim, name='down{}'.format(i))(X)

        # Update token shape info
        embed_dim = embed_dim * 2
        num_patch_x = num_patch_x // 2
        num_patch_y = num_patch_y // 2

        # Swin Transformer stacks
        X = swin_transformer_stack(X, stack_num=stack_num_down, 
                                   embed_dim=embed_dim, num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i + 1], window_size=window_size[i + 1], num_mlp=embed_dim*4, 
                                   shift_window=shift_window, name='{}_swin_down{}'.format(name, i + 1))

        # Store tensors for concat
        X_skip.append(X)

    # Reverse indexing encoded tensors and hyperparameters
    X_skip = X_skip[::-1]
    num_heads = num_heads[::-1]
    window_size = window_size[::-1]

    # Upsampling begins at the deepest available tensor
    X = X_skip[0]

    # Other tensors are preserved for concatenation
    X_decode = X_skip[1:]

    depth_decode = len(X_decode)

    for i in range(depth_decode):

        # Patch expanding
        X = patch_expanding(num_patch=(num_patch_x, num_patch_y),
                            embed_dim=embed_dim, upsample_rate=2, return_vector=True, name='{}_swin_up{}'.format(name, i))(X)

        # Update token shape info
        embed_dim = embed_dim // 2
        num_patch_x = num_patch_x * 2
        num_patch_y = num_patch_y * 2

        # Concatenation and linear projection
        X = concatenate([X, X_decode[i]], axis=-1, name='{}_concat_{}'.format(name, i))
        X = Dense(embed_dim, use_bias=False, name='{}_concat_linear_proj_{}'.format(name, i))(X)

        # Swin Transformer stacks
        X = swin_transformer_stack(X, stack_num=stack_num_up, 
                                   embed_dim=embed_dim, num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i], window_size=window_size[i], num_mlp=embed_dim*4, 
                                   shift_window=shift_window, name='{}_swin_up{}'.format(name, i))

    # The last expanding layer; it produces full-size feature maps based on the patch size
    # !!! <--- \"patch_size[0]\" is used; it assumes patch_size = (size, size)
    X = patch_expanding(num_patch=(num_patch_x, num_patch_y),
                        embed_dim=embed_dim, upsample_rate=patch_size[0], return_vector=False)(X)

    return X
"""

# File path for _model_swin_unet_2d.py
file_path = "./custom_keras_unet_collection/_model_swin_unet_2d.py"

# Read the original file content
with open(file_path, "r") as f:
    original_content = f.read()

# Replace the swin_unet_2d_base function in the content
updated_content = re.sub(
    r"def swin_unet_2d_base\(.*?def",  # Match the function definition up to the next def
    updated_swin_unet_2d_base + "\ndef",  # Replace with the updated function
    original_content,
    flags=re.DOTALL  # Ensure it matches across multiple lines
)

# Write the updated content back to the file
with open(file_path, "w") as f:
    f.write(updated_content)

print("Updated swin_unet_2d_base function successfully.")

# Correct path to models.py
models_file_path = "./custom_keras_unet_collection/models.py"

# Define updated content
updated_models_content = """
from __future__ import absolute_import

from custom_keras_unet_collection._model_unet_2d import unet_2d
from custom_keras_unet_collection._model_vnet_2d import vnet_2d
from custom_keras_unet_collection._model_unet_plus_2d import unet_plus_2d
from custom_keras_unet_collection._model_r2_unet_2d import r2_unet_2d
from custom_keras_unet_collection._model_att_unet_2d import att_unet_2d
from custom_keras_unet_collection._model_resunet_a_2d import resunet_a_2d
from custom_keras_unet_collection._model_u2net_2d import u2net_2d
from custom_keras_unet_collection._model_unet_3plus_2d import unet_3plus_2d
from custom_keras_unet_collection._model_transunet_2d import transunet_2d
from custom_keras_unet_collection._model_swin_unet_2d import swin_unet_2d
"""

# Write the updated content
try:
    with open(models_file_path, "w") as f:
        f.write(updated_models_content)
    print("models.py updated successfully.")
except FileNotFoundError:
    print("models.py not found. Verify the path.")

from custom_keras_unet_collection.models import swin_unet_2d
from tensorflow.keras.layers import Activation

# Define the input size
inputs = (img_size, img_size, 1)

model = swin_unet_2d(
    input_size=inputs,  # Input size for 256x256 RGB images
    filter_num_begin=96,       # Starting embedding dimension
    n_labels=1,                # Number of output channels
    depth=4,                    # Number of encoder-decoder levels
    stack_num_down=2,           # Transformer blocks per down-sampling level
    stack_num_up=2,             # Transformer blocks per up-sampling level
    patch_size=(4, 4),          # Patch size for image tokenization
    num_heads=[3, 6, 12, 24],   # Attention heads at each level
    window_size=[10, 10, 10, 10],   # Window size for shifted window attention
    num_mlp=1536,               # Feed-forward network dimension
    output_activation='Sigmoid',  # Output activation for segmentation tasks
    shift_window=True          # Use shifted window attention
)
# Out:
# Collecting keras-unet-collection
#   Downloading keras_unet_collection-0.1.13-py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 3.7 MB/s  eta 0:00:01
# Installing collected packages: keras-unet-collection
# Successfully installed keras-unet-collection-0.1.13
# Name: keras-unet-collection
# Version: 0.1.13
# Summary: The Tensorflow, Keras implementation of U-net, V-net, U-net++, UNET 3+, Attention U-net, R2U-net, ResUnet-a, U^2-Net, TransUNET, and Swin-UNET with optional ImageNet-trained backbones.
# Home-page: https://github.com/yingkaisha/keras-unet-collection
# Author: Yingkai (Kyle) Sha
# Author-email: yingkaisha@gmail.com
# License: UNKNOWN
# Location: /opt/conda/lib/python3.7/site-packages
# Requires:
# Required-by:
# __init__.py		_model_unet_3plus_2d.py  model_r2_unet_2d.py
# __pycache__		_model_unet_plus_2d.py	 model_resunet_a_2d.py
# _backbone_zoo.py	_model_vnet_2d.py	 model_u2net_2d.py
# _model_att_unet_2d.py	activations.py		 model_unet_2d.py
# _model_r2_unet_2d.py	backbones.py		 model_unet_3plus_2d.py
# _model_resunet_a_2d.py	base.py			 model_unet_plus_2d.py
# _model_swin_unet_2d.py	layer_utils.py		 models.py
# _model_transunet_2d.py	loss.py			 transformer_layers.py
# _model_u2net_2d.py	losses.py		 utils.py
# _model_unet_2d.py	model_att_unet_2d.py
# Updated swin_unet_2d_base function successfully.
# models.py updated successfully.

# %%
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2_as_graph

def get_flops(model):
    """Calculate Floating Point Operations (FLOPs) of a Keras model in TensorFlow 2.x."""
    # Convert Keras model to a TensorFlow function
    concrete_func = tf.function(lambda inputs: model(inputs))
    concrete_func = concrete_func.get_concrete_function(
        tf.TensorSpec([1] + list(model.input_shape[1:]), model.input.dtype)
    )

    # Convert to frozen graph
    frozen_func, _ = convert_variables_to_constants_v2_as_graph(concrete_func)

    # Compute FLOPs
    flops = tf.compat.v1.profiler.profile(
        frozen_func.graph,
        options=tf.compat.v1.profiler.ProfileOptionBuilder.float_operation(),
    )

    return flops.total_float_ops

# Compute FLOPs
flops = get_flops(model)
print(f"Total FLOPs: {flops / 1e9:.2f} GFLOPs")  # Convert to GFLOPs

from tensorflow.keras.optimizers import Adam

optimizer = Adam(learning_rate=1e-3)
model.compile(optimizer=optimizer, loss=loss_f, metrics=[dice_coef_infection, iou_coef_infection, precision_infection, recall_infection, hausdorff95_infection, specificity_infection, accuracy_infection, f1_infection])

# Model summary
model.summary()
# Out:
# Total FLOPs: 24.45 GFLOPs
# Model: "swin_unet_model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 320, 320, 1) 0
# __________________________________________________________________________________________________
# patch_extract (patch_extract)   (None, 6400, 16)     0           input_1[0][0]
# __________________________________________________________________________________________________
# patch_embedding (patch_embeddin (None, 6400, 96)     616032      patch_extract[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block (SwinTra (None, 6400, 96)     122923      patch_embedding[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_1 (SwinT (None, 6400, 96)     762923      swin_transformer_block[0][0]
# __________________________________________________________________________________________________
# patch_merging (patch_merging)   (None, 1600, 192)    73728       swin_transformer_block_1[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_2 (SwinT (None, 1600, 192)    457030      patch_merging[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_3 (SwinT (None, 1600, 192)    617030      swin_transformer_block_2[0][0]
# __________________________________________________________________________________________________
# patch_merging_1 (patch_merging) (None, 400, 384)     294912      swin_transformer_block_3[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_4 (SwinT (None, 400, 384)     1788796     patch_merging_1[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_5 (SwinT (None, 400, 384)     1828796     swin_transformer_block_4[0][0]
# __________________________________________________________________________________________________
# patch_merging_2 (patch_merging) (None, 100, 768)     1179648     swin_transformer_block_5[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_6 (SwinT (None, 100, 768)     7106536     patch_merging_2[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_7 (SwinT (None, 100, 768)     7116536     swin_transformer_block_6[0][0]
# __________________________________________________________________________________________________
# patch_expanding (patch_expandin (None, 400, 384)     1179648     swin_transformer_block_7[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_0 (Concatenate (None, 400, 768)     0           patch_expanding[0][0]
#                                                                  swin_transformer_block_5[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_linear_proj_0  (None, 400, 384)     294912      swin_unet_concat_0[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_8 (SwinT (None, 400, 384)     1793128     swin_unet_concat_linear_proj_0[0]
# __________________________________________________________________________________________________
# swin_transformer_block_9 (SwinT (None, 400, 384)     1833128     swin_transformer_block_8[0][0]
# __________________________________________________________________________________________________
# patch_expanding_1 (patch_expand (None, 1600, 192)    294912      swin_transformer_block_9[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_1 (Concatenate (None, 1600, 384)    0           patch_expanding_1[0][0]
#                                                                  swin_transformer_block_3[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_linear_proj_1  (None, 1600, 192)    73728       swin_unet_concat_1[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_10 (Swin (None, 1600, 192)    459196      swin_unet_concat_linear_proj_1[0]
# __________________________________________________________________________________________________
# swin_transformer_block_11 (Swin (None, 1600, 192)    619196      swin_transformer_block_10[0][0]
# __________________________________________________________________________________________________
# patch_expanding_2 (patch_expand (None, 6400, 96)     73728       swin_transformer_block_11[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_2 (Concatenate (None, 6400, 192)    0           patch_expanding_2[0][0]
#                                                                  swin_transformer_block_1[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_linear_proj_2  (None, 6400, 96)     18432       swin_unet_concat_2[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_12 (Swin (None, 6400, 96)     124006      swin_unet_concat_linear_proj_2[0]
# __________________________________________________________________________________________________
# swin_transformer_block_13 (Swin (None, 6400, 96)     764006      swin_transformer_block_12[0][0]
# __________________________________________________________________________________________________
# patch_expanding_3 (patch_expand (None, 320, 320, 24) 36864       swin_transformer_block_13[0][0]
# __________________________________________________________________________________________________
# swin_unet_output (Conv2D)       (None, 320, 320, 1)  25          patch_expanding_3[0][0]
# __________________________________________________________________________________________________
# swin_unet_output_activation (Ac (None, 320, 320, 1)  0           swin_unet_output[0][0]
# ==================================================================================================
# Total params: 29,529,799
# Trainable params: 27,699,799
# Non-trainable params: 1,830,000
# __________________________________________________________________________________________________

# %%
# Install required packages
# !pip install openpyxl

# Imports
import openpyxl  # required for reading .xlsx files
import pandas as pd
import tensorflow as tf
import os
import shutil
from tensorflow.keras.callbacks import LearningRateScheduler, ReduceLROnPlateau

# File paths
checkpoint_filepath = '/kaggle/working/checkpoint.h5.keras'
metrics_file = '/kaggle/working/training_metrics.xlsx'
pre_checkpoint_filepath = '/kaggle/input/swinunet-covid19-finalrun-1/checkpoint.h5.keras'
pre_metrics_file = '/kaggle/input/swinunet-covid19-finalrun-1/training_metrics.xlsx'

# Restore checkpoint and metrics if available
if os.path.exists(pre_checkpoint_filepath):
    shutil.copy(pre_checkpoint_filepath, checkpoint_filepath)
    print(f"Restored checkpoint from: {pre_checkpoint_filepath}")

if os.path.exists(pre_metrics_file):
    shutil.copy(pre_metrics_file, metrics_file)
    print(f"Restored metrics file from: {pre_metrics_file}")

# Load last epoch
def load_last_epoch():
    if os.path.exists(metrics_file):
        try:
            df = pd.read_excel(metrics_file, engine='openpyxl')
            if not df.empty and 'epoch' in df.columns:
                return df['epoch'].iloc[-1] + 1
        except Exception as e:
            print(f"⚠️ Could not read metrics file: {e}")
    return 0

last_epoch = load_last_epoch()

# Get best validation loss from previous runs
def get_best_val_loss():
    if os.path.exists(metrics_file):
        try:
            df = pd.read_excel(metrics_file, engine='openpyxl')
            if 'val_loss' in df.columns and not df['val_loss'].isnull().all():
                return df['val_loss'].min()
        except Exception as e:
            print(f"⚠️ Could not read val_loss from metrics file: {e}")
    return float('inf')

best_val_loss = get_best_val_loss()

# Custom model checkpoint
class CustomModelCheckpoint(tf.keras.callbacks.Callback):
    def __init__(self, filepath):
        super().__init__()
        self.filepath = filepath
        self.best_loss = best_val_loss

    def on_epoch_end(self, epoch, logs=None):
        current_loss = logs.get('val_loss')
        if current_loss is not None and current_loss < self.best_loss:
            self.best_loss = current_loss
            self.model.save(self.filepath)
            print(f"✅ Model saved at epoch {epoch + 1} with val_loss: {current_loss:.4f}")

# === Learning Rate Schedule ===
def lr_schedule(epoch, lr):
    return 1e-4 if epoch >= 1 else lr

lr_scheduler = LearningRateScheduler(lr_schedule, verbose=1)

# Logger for Excel
class MetricsLogger(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        df_new = pd.DataFrame([{**logs, 'epoch': epoch}])
        try:
            if os.path.exists(metrics_file):
                df = pd.read_excel(metrics_file, engine='openpyxl')
                df = pd.concat([df, df_new], ignore_index=True)
            else:
                df = df_new
            df.to_excel(metrics_file, index=False, engine='openpyxl')
        except Exception as e:
            print(f"⚠️ Failed to log metrics: {e}")

# Early stopping with patience and saving best weights
class CustomEarlyStopping(tf.keras.callbacks.Callback):
    def __init__(self, patience=20):
        super().__init__()
        self.patience = patience
        self.wait = 0
        self.best_loss = best_val_loss

    def on_epoch_end(self, epoch, logs=None):
        current_loss = logs.get('val_loss')
        if current_loss is None:
            return
        if current_loss < self.best_loss:
            self.best_loss = current_loss
            self.wait = 0
            self.model.save_weights(checkpoint_filepath)
        else:
            self.wait += 1
            if self.wait >= self.patience:
                print(f"🛑 Early stopping at epoch {epoch + 1}")
                self.model.stop_training = True


# Final callbacks list
callbacks = [
    CustomModelCheckpoint(filepath=checkpoint_filepath),
    MetricsLogger(),
    lr_scheduler,
    CustomEarlyStopping(patience=20)
]
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.3-py2.py3-none-any.whl (251 kB)
#      |████████████████████████████████| 251 kB 13.5 MB/s eta 0:00:01
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.3
# Restored checkpoint from: /kaggle/input/swinunet-covid19-finalrun-1/checkpoint.h5.keras
# Restored metrics file from: /kaggle/input/swinunet-covid19-finalrun-1/training_metrics.xlsx

# %% [markdown]
# ## Training the model

# %%
import time
import os
import pandas as pd
import numpy as np
from tensorflow.keras.utils import Sequence
from tensorflow.keras.models import load_model

EPOCHS = 100

# Record the start time
start_time = time.time()

# === Load last completed epoch from metrics file ===
def load_last_epoch():
    if os.path.exists(pre_metrics_file):
        try:
            df = pd.read_excel(pre_metrics_file, engine='openpyxl')
            if not df.empty and 'epoch' in df.columns:
                return int(df['epoch'].iloc[-1]) + 1
        except Exception as e:
            print(f"⚠️ Failed to read metrics file: {e}")
    return 0

last_epoch = load_last_epoch()

# === Load pretrained weights if available ===
if os.path.exists(pre_checkpoint_filepath):
    print("✅ Checkpoint found. Loading pretrained weights...")
    model.load_weights(pre_checkpoint_filepath)
    print(f"🔁 Resuming training from epoch {last_epoch}")
else:
    print("🆕 No checkpoint found. Starting training from scratch.")
    last_epoch = 0

# === Prepare input and label tensors ===
lung_train = np.asarray(lung_train, dtype=np.float16)
infect_train = np.asarray(infect_train, dtype=np.uint8)

lung_temp = np.asarray(lung_temp, dtype=np.float16)
infect_temp = np.asarray(infect_temp, dtype=np.uint8)

lung_test = np.asarray(lung_test, dtype=np.float16)
infect_test = np.asarray(infect_test, dtype=np.uint8)

# === Data Generator ===
class LungDataGenerator(Sequence):
    def __init__(self, X, Y, batch_size=8, shuffle=True):
        self.X = X
        self.Y = Y
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indices = np.arange(len(X))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.X) / self.batch_size))

    def __getitem__(self, index):
        batch_ids = self.indices[index * self.batch_size:(index + 1) * self.batch_size]
        X_batch = self.X[batch_ids]
        Y_batch = self.Y[batch_ids]
        return np.asarray(X_batch, dtype=np.float16), np.asarray(Y_batch, dtype=np.uint8)

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indices)

# === Create generators ===
train_gen = LungDataGenerator(lung_train, infect_train, batch_size=8)
temp_gen = LungDataGenerator(lung_temp, infect_temp, batch_size=8, shuffle=False)
val_gen = LungDataGenerator(lung_test, infect_test, batch_size=8, shuffle=False)

# === Train the model ===
history = model.fit(
    train_gen,
    validation_data=temp_gen,
    epochs=EPOCHS,
    initial_epoch=last_epoch,
    callbacks=callbacks
)

# === Timing info ===
end_time = time.time()
total_time = end_time - start_time
print(f"✅ Total training time: {total_time:.2f} seconds ({total_time / 60:.2f} minutes)")
# Out:
# ✅ Checkpoint found. Loading pretrained weights...
# 🔁 Resuming training from epoch 70
# Epoch 71/100
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 523s 435ms/step - loss: 0.3926 - dice_coef_infection: 0.6353 - iou_coef_infection: 0.5080 - precision_infection: 0.6703 - recall_infection: 0.6903 - hausdorff95_infection: 46.3435 - specificity_infection: 0.9974 - accuracy_infection: 0.9954 - f1_infection: 0.8200 - val_loss: 0.4563 - val_dice_coef_infection: 0.6137 - val_iou_coef_infection: 0.5862 - val_precision_infection: 0.8638 - val_recall_infection: 0.6380 - val_hausdorff95_infection: 104.5869 - val_specificity_infection: 0.9994 - val_accuracy_infection: 0.9942 - val_f1_infection: 0.8293
# ✅ Model saved at epoch 71 with val_loss: 0.4563
# Epoch 72/100
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 494s 432ms/step - loss: 0.3807 - dice_coef_infection: 0.6494 - iou_coef_infection: 0.5177 - precision_infection: 0.6905 - recall_infection: 0.6818 - hausdorff95_infection: 47.5063 - specificity_infection: 0.9976 - accuracy_infection: 0.9955 - f1_infection: 0.8223 - val_loss: 0.5664 - val_dice_coef_infection: 0.5502 - val_iou_coef_infection: 0.5270 - val_precision_infection: 0.6994 - val_recall_infection: 0.6201 - val_hausdorff95_infection: 86.7966 - val_specificity_infection: 0.9996 - val_accuracy_infection: 0.9933 - val_f1_infection: 0.8616
# Epoch 73/100
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 494s 432ms/step - loss: 0.3694 - dice_coef_infection: 0.6627 - iou_coef_infection: 0.5307 - precision_infection: 0.6969 - recall_infection: 0.7017 - hausdorff95_infection: 51.6471 - specificity_infection: 0.9976 - accuracy_infection: 0.9956 - f1_infection: 0.8242 - val_loss: 0.4820 - val_dice_coef_infection: 0.6047 - val_iou_coef_infection: 0.5743 - val_precision_infection: 0.8059 - val_recall_infection: 0.6418 - val_hausdorff95_infection: 88.1457 - val_specificity_infection: 0.9993 - val_accuracy_infection: 0.9939 - val_f1_infection: 0.8411
# Epoch 74/100
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 493s 432ms/step - loss: 0.3541 - dice_coef_infection: 0.6733 - iou_coef_infection: 0.5422 - precision_infection: 0.6925 - recall_infection: 0.7123 - hausdorff95_infection: 43.8865 - specificity_infection: 0.9975 - accuracy_infection: 0.9955 - f1_infection: 0.8330 - val_loss: 0.4630 - val_dice_coef_infection: 0.6309 - val_iou_coef_infection: 0.6050 - val_precision_infection: 0.8821 - val_recall_infection: 0.6318 - val_hausdorff95_infection: 101.2055 - val_specificity_infection: 0.9994 - val_accuracy_infection: 0.9941 - val_f1_infection: 0.8408
# Epoch 75/100
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 493s 431ms/step - loss: 0.3456 - dice_coef_infection: 0.6808 - iou_coef_infection: 0.5501 - precision_infection: 0.6958 - recall_infection: 0.7189 - hausdorff95_infection: 43.8133 - specificity_infection: 0.9977 - accuracy_infection: 0.9958 - f1_infection: 0.8377 - val_loss: 0.5479 - val_dice_coef_infection: 0.5353 - val_iou_coef_infection: 0.5087 - val_precision_infection: 0.6547 - val_recall_infection: 0.6345 - val_hausdorff95_infection: 86.0686 - val_specificity_infection: 0.9992 - val_accuracy_infection: 0.9938 - val_f1_infection: 0.8569
# Epoch 76/100
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 495s 433ms/step - loss: 0.3655 - dice_coef_infection: 0.6621 - iou_coef_infection: 0.5325 - precision_infection: 0.6950 - recall_infection: 0.7020 - hausdorff95_infection: 46.7106 - specificity_infection: 0.9978 - accuracy_infection: 0.9960 - f1_infection: 0.8274 - val_loss: 0.4830 - val_dice_coef_infection: 0.6104 - val_iou_coef_infection: 0.5839 - val_precision_infection: 0.7478 - val_recall_infection: 0.6344 - val_hausdorff95_infection: 79.3280 - val_specificity_infection: 0.9993 - val_accuracy_infection: 0.9939 - val_f1_infection: 0.8805
# Epoch 77/100
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 495s 433ms/step - loss: 0.3763 - dice_coef_infection: 0.6547 - iou_coef_infection: 0.5255 - precision_infection: 0.6807 - recall_infection: 0.6877 - hausdorff95_infection: 49.6833 - specificity_infection: 0.9977 - accuracy_infection: 0.9957 - f1_infection: 0.8324 - val_loss: 0.5509 - val_dice_coef_infection: 0.5322 - val_iou_coef_infection: 0.5012 - val_precision_infection: 0.6802 - val_recall_infection: 0.6411 - val_hausdorff95_infection: 80.4962 - val_specificity_infection: 0.9991 - val_accuracy_infection: 0.9934 - val_f1_infection: 0.8250
# Epoch 78/100
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 494s 432ms/step - loss: 0.3913 - dice_coef_infection: 0.6401 - iou_coef_infection: 0.5069 - precision_infection: 0.6740 - recall_infection: 0.6794 - hausdorff95_infection: 53.3474 - specificity_infection: 0.9976 - accuracy_infection: 0.9954 - f1_infection: 0.8192 - val_loss: 0.4531 - val_dice_coef_infection: 0.6084 - val_iou_coef_infection: 0.5800 - val_precision_infection: 0.8080 - val_recall_infection: 0.6466 - val_hausdorff95_infection: 102.4663 - val_specificity_infection: 0.9992 - val_accuracy_infection: 0.9944 - val_f1_infection: 0.8434
# ✅ Model saved at epoch 78 with val_loss: 0.4531
# Epoch 79/100
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 493s 432ms/step - loss: 0.3961 - dice_coef_infection: 0.6411 - iou_coef_infection: 0.5150 - precision_infection: 0.6732 - recall_infection: 0.6757 - hausdorff95_infection: 54.5268 - specificity_infection: 0.9976 - accuracy_infection: 0.9955 - f1_infection: 0.8307 - val_loss: 0.5493 - val_dice_coef_infection: 0.5561 - val_iou_coef_infection: 0.5300 - val_precision_infection: 0.7345 - val_recall_infection: 0.6286 - val_hausdorff95_infection: 98.8612 - val_specificity_infection: 0.9993 - val_accuracy_infection: 0.9936 - val_f1_infection: 0.8384
# Epoch 80/100
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 493s 432ms/step - loss: 0.4135 - dice_coef_infection: 0.6185 - iou_coef_infection: 0.4901 - precision_infection: 0.6491 - recall_infection: 0.6702 - hausdorff95_infection: 54.9381 - specificity_infection: 0.9975 - accuracy_infection: 0.9953 - f1_infection: 0.8166 - val_loss: 0.5098 - val_dice_coef_infection: 0.6153 - val_iou_coef_infection: 0.5905 - val_precision_infection: 0.8925 - val_recall_infection: 0.6262 - val_hausdorff95_infection: 107.5723 - val_specificity_infection: 0.9995 - val_accuracy_infection: 0.9935 - val_f1_infection: 0.8286
# Epoch 81/100
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 493s 432ms/step - loss: 0.3864 - dice_coef_infection: 0.6454 - iou_coef_infection: 0.5150 - precision_infection: 0.6783 - recall_infection: 0.6768 - hausdorff95_infection: 47.4209 - specificity_infection: 0.9976 - accuracy_infection: 0.9955 - f1_infection: 0.8276 - val_loss: 0.6075 - val_dice_coef_infection: 0.4914 - val_iou_coef_infection: 0.4636 - val_precision_infection: 0.6105 - val_recall_infection: 0.6417 - val_hausdorff95_infection: 106.8087 - val_specificity_infection: 0.9989 - val_accuracy_infection: 0.9941 - val_f1_infection: 0.8284
# Epoch 82/100
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 493s 432ms/step - loss: 0.3928 - dice_coef_infection: 0.6372 - iou_coef_infection: 0.5051 - precision_infection: 0.6689 - recall_infection: 0.6786 - hausdorff95_infection: 56.6560 - specificity_infection: 0.9975 - accuracy_infection: 0.9955 - f1_infection: 0.8215 - val_loss: 0.4501 - val_dice_coef_infection: 0.6200 - val_iou_coef_infection: 0.5919 - val_precision_infection: 0.8875 - val_recall_infection: 0.6400 - val_hausdorff95_infection: 105.9002 - val_specificity_infection: 0.9993 - val_accuracy_infection: 0.9941 - val_f1_infection: 0.8236
# ✅ Model saved at epoch 82 with val_loss: 0.4501
# Epoch 83/100
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 493s 432ms/step - loss: 0.4499 - dice_coef_infection: 0.5918 - iou_coef_infection: 0.4642 - precision_infection: 0.6674 - recall_infection: 0.6280 - hausdorff95_infection: 55.3967 - specificity_infection: 0.9976 - accuracy_infection: 0.9949 - f1_infection: 0.8029 - val_loss: 0.4769 - val_dice_coef_infection: 0.6005 - val_iou_coef_infection: 0.5716 - val_precision_infection: 0.8098 - val_recall_infection: 0.6477 - val_hausdorff95_infection: 99.1106 - val_specificity_infection: 0.9991 - val_accuracy_infection: 0.9944 - val_f1_infection: 0.8356
# Epoch 84/100
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 494s 432ms/step - loss: 0.3706 - dice_coef_infection: 0.6578 - iou_coef_infection: 0.5226 - precision_infection: 0.6800 - recall_infection: 0.6921 - hausdorff95_infection: 44.4450 - specificity_infection: 0.9977 - accuracy_infection: 0.9957 - f1_infection: 0.8278 - val_loss: 0.4373 - val_dice_coef_infection: 0.6240 - val_iou_coef_infection: 0.5945 - val_precision_infection: 0.8305 - val_recall_infection: 0.6463 - val_hausdorff95_infection: 93.7459 - val_specificity_infection: 0.9993 - val_accuracy_infection: 0.9942 - val_f1_infection: 0.8474
# ✅ Model saved at epoch 84 with val_loss: 0.4373
# Epoch 85/100
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 494s 432ms/step - loss: 0.4106 - dice_coef_infection: 0.6213 - iou_coef_infection: 0.4940 - precision_infection: 0.6693 - recall_infection: 0.6630 - hausdorff95_infection: 55.8267 - specificity_infection: 0.9973 - accuracy_infection: 0.9951 - f1_infection: 0.8191 - val_loss: 0.4523 - val_dice_coef_infection: 0.6240 - val_iou_coef_infection: 0.5931 - val_precision_infection: 0.8088 - val_recall_infection: 0.6468 - val_hausdorff95_infection: 94.1675 - val_specificity_infection: 0.9993 - val_accuracy_infection: 0.9943 - val_f1_infection: 0.8550
# Epoch 86/100
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 493s 432ms/step - loss: 0.3507 - dice_coef_infection: 0.6748 - iou_coef_infection: 0.5410 - precision_infection: 0.7047 - recall_infection: 0.7112 - hausdorff95_infection: 42.7232 - specificity_infection: 0.9977 - accuracy_infection: 0.9959 - f1_infection: 0.8269 - val_loss: 0.4830 - val_dice_coef_infection: 0.5892 - val_iou_coef_infection: 0.5624 - val_precision_infection: 0.8278 - val_recall_infection: 0.6343 - val_hausdorff95_infection: 105.8237 - val_specificity_infection: 0.9995 - val_accuracy_infection: 0.9940 - val_f1_infection: 0.8278
# Epoch 87/100
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 493s 432ms/step - loss: 0.3546 - dice_coef_infection: 0.6725 - iou_coef_infection: 0.5394 - precision_infection: 0.7068 - recall_infection: 0.7025 - hausdorff95_infection: 41.2453 - specificity_infection: 0.9976 - accuracy_infection: 0.9956 - f1_infection: 0.8282 - val_loss: 0.5659 - val_dice_coef_infection: 0.5058 - val_iou_coef_infection: 0.4796 - val_precision_infection: 0.6033 - val_recall_infection: 0.6452 - val_hausdorff95_infection: 94.3868 - val_specificity_infection: 0.9987 - val_accuracy_infection: 0.9943 - val_f1_infection: 0.8472
# Epoch 88/100
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 493s 432ms/step - loss: 0.4118 - dice_coef_infection: 0.6295 - iou_coef_infection: 0.5047 - precision_infection: 0.6672 - recall_infection: 0.6773 - hausdorff95_infection: 56.9153 - specificity_infection: 0.9976 - accuracy_infection: 0.9954 - f1_infection: 0.8230 - val_loss: 0.5468 - val_dice_coef_infection: 0.5647 - val_iou_coef_infection: 0.5399 - val_precision_infection: 0.7782 - val_recall_infection: 0.6226 - val_hausdorff95_infection: 108.7913 - val_specificity_infection: 0.9995 - val_accuracy_infection: 0.9932 - val_f1_infection: 0.8334
# Epoch 89/100
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 493s 432ms/step - loss: 0.3669 - dice_coef_infection: 0.6604 - iou_coef_infection: 0.5279 - precision_infection: 0.6870 - recall_infection: 0.6968 - hausdorff95_infection: 44.9901 - specificity_infection: 0.9976 - accuracy_infection: 0.9956 - f1_infection: 0.8276 - val_loss: 0.4909 - val_dice_coef_infection: 0.5798 - val_iou_coef_infection: 0.5517 - val_precision_infection: 0.8025 - val_recall_infection: 0.6348 - val_hausdorff95_infection: 102.0254 - val_specificity_infection: 0.9995 - val_accuracy_infection: 0.9938 - val_f1_infection: 0.8263
# Epoch 90/100
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 494s 432ms/step - loss: 0.4184 - dice_coef_infection: 0.6204 - iou_coef_infection: 0.4939 - precision_infection: 0.6415 - recall_infection: 0.6663 - hausdorff95_infection: 68.2113 - specificity_infection: 0.9973 - accuracy_infection: 0.9949 - f1_infection: 0.8282 - val_loss: 0.4998 - val_dice_coef_infection: 0.5874 - val_iou_coef_infection: 0.5625 - val_precision_infection: 0.8294 - val_recall_infection: 0.6256 - val_hausdorff95_infection: 108.7527 - val_specificity_infection: 0.9995 - val_accuracy_infection: 0.9937 - val_f1_infection: 0.8305
# Epoch 91/100
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 493s 431ms/step - loss: 0.4126 - dice_coef_infection: 0.6222 - iou_coef_infection: 0.4974 - precision_infection: 0.6744 - recall_infection: 0.6661 - hausdorff95_infection: 53.1328 - specificity_infection: 0.9977 - accuracy_infection: 0.9955 - f1_infection: 0.8166 - val_loss: 0.4996 - val_dice_coef_infection: 0.5762 - val_iou_coef_infection: 0.5479 - val_precision_infection: 0.7857 - val_recall_infection: 0.6464 - val_hausdorff95_infection: 104.5590 - val_specificity_infection: 0.9992 - val_accuracy_infection: 0.9944 - val_f1_infection: 0.8251
# Epoch 92/100
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 493s 431ms/step - loss: 0.3812 - dice_coef_infection: 0.6489 - iou_coef_infection: 0.5203 - precision_infection: 0.6800 - recall_infection: 0.6838 - hausdorff95_infection: 51.0381 - specificity_infection: 0.9974 - accuracy_infection: 0.9954 - f1_infection: 0.8305 - val_loss: 0.5668 - val_dice_coef_infection: 0.5426 - val_iou_coef_infection: 0.5199 - val_precision_infection: 0.7763 - val_recall_infection: 0.6185 - val_hausdorff95_infection: 112.9199 - val_specificity_infection: 0.9995 - val_accuracy_infection: 0.9935 - val_f1_infection: 0.8170
# Epoch 93/100
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 493s 432ms/step - loss: 0.3676 - dice_coef_infection: 0.6601 - iou_coef_infection: 0.5318 - precision_infection: 0.6942 - recall_infection: 0.7008 - hausdorff95_infection: 46.4665 - specificity_infection: 0.9976 - accuracy_infection: 0.9958 - f1_infection: 0.8279 - val_loss: 0.5721 - val_dice_coef_infection: 0.4968 - val_iou_coef_infection: 0.4657 - val_precision_infection: 0.6456 - val_recall_infection: 0.6427 - val_hausdorff95_infection: 91.2274 - val_specificity_infection: 0.9992 - val_accuracy_infection: 0.9942 - val_f1_infection: 0.8103
# Epoch 94/100
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 493s 431ms/step - loss: 0.3513 - dice_coef_infection: 0.6780 - iou_coef_infection: 0.5482 - precision_infection: 0.7213 - recall_infection: 0.7083 - hausdorff95_infection: 46.2980 - specificity_infection: 0.9977 - accuracy_infection: 0.9958 - f1_infection: 0.8305 - val_loss: 0.5548 - val_dice_coef_infection: 0.5491 - val_iou_coef_infection: 0.5214 - val_precision_infection: 0.7462 - val_recall_infection: 0.6300 - val_hausdorff95_infection: 92.7866 - val_specificity_infection: 0.9994 - val_accuracy_infection: 0.9935 - val_f1_infection: 0.8252
# Epoch 95/100
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 493s 431ms/step - loss: 0.3629 - dice_coef_infection: 0.6668 - iou_coef_infection: 0.5361 - precision_infection: 0.6939 - recall_infection: 0.7015 - hausdorff95_infection: 45.6752 - specificity_infection: 0.9976 - accuracy_infection: 0.9958 - f1_infection: 0.8306 - val_loss: 0.5157 - val_dice_coef_infection: 0.5804 - val_iou_coef_infection: 0.5580 - val_precision_infection: 0.8454 - val_recall_infection: 0.6171 - val_hausdorff95_infection: 112.3583 - val_specificity_infection: 0.9996 - val_accuracy_infection: 0.9935 - val_f1_infection: 0.8210
# Epoch 96/100
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 493s 431ms/step - loss: 0.3681 - dice_coef_infection: 0.6603 - iou_coef_infection: 0.5297 - precision_infection: 0.7063 - recall_infection: 0.6916 - hausdorff95_infection: 44.2425 - specificity_infection: 0.9977 - accuracy_infection: 0.9957 - f1_infection: 0.8251 - val_loss: 0.6019 - val_dice_coef_infection: 0.4637 - val_iou_coef_infection: 0.4329 - val_precision_infection: 0.6038 - val_recall_infection: 0.6424 - val_hausdorff95_infection: 94.7830 - val_specificity_infection: 0.9993 - val_accuracy_infection: 0.9939 - val_f1_infection: 0.8028
# Epoch 97/100
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 494s 432ms/step - loss: 0.4034 - dice_coef_infection: 0.6291 - iou_coef_infection: 0.4988 - precision_infection: 0.6846 - recall_infection: 0.6633 - hausdorff95_infection: 48.3691 - specificity_infection: 0.9977 - accuracy_infection: 0.9955 - f1_infection: 0.8149 - val_loss: 0.7124 - val_dice_coef_infection: 0.3449 - val_iou_coef_infection: 0.3120 - val_precision_infection: 0.4072 - val_recall_infection: 0.6601 - val_hausdorff95_infection: 141.1495 - val_specificity_infection: 0.9987 - val_accuracy_infection: 0.9942 - val_f1_infection: 0.7663
# Epoch 98/100
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 493s 432ms/step - loss: 0.3526 - dice_coef_infection: 0.6722 - iou_coef_infection: 0.5394 - precision_infection: 0.7056 - recall_infection: 0.7073 - hausdorff95_infection: 47.8490 - specificity_infection: 0.9977 - accuracy_infection: 0.9958 - f1_infection: 0.8272 - val_loss: 0.5909 - val_dice_coef_infection: 0.5280 - val_iou_coef_infection: 0.5095 - val_precision_infection: 0.6834 - val_recall_infection: 0.6039 - val_hausdorff95_infection: 99.5508 - val_specificity_infection: 0.9995 - val_accuracy_infection: 0.9923 - val_f1_infection: 0.8578
# Epoch 99/100
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 493s 431ms/step - loss: 0.3299 - dice_coef_infection: 0.6957 - iou_coef_infection: 0.5663 - precision_infection: 0.7355 - recall_infection: 0.7145 - hausdorff95_infection: 45.6162 - specificity_infection: 0.9978 - accuracy_infection: 0.9960 - f1_infection: 0.8365 - val_loss: 0.4704 - val_dice_coef_infection: 0.5868 - val_iou_coef_infection: 0.5626 - val_precision_infection: 0.7981 - val_recall_infection: 0.6360 - val_hausdorff95_infection: 102.9573 - val_specificity_infection: 0.9992 - val_accuracy_infection: 0.9944 - val_f1_infection: 0.8380
# Epoch 100/100
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 493s 432ms/step - loss: 0.3961 - dice_coef_infection: 0.6372 - iou_coef_infection: 0.5064 - precision_infection: 0.6707 - recall_infection: 0.6935 - hausdorff95_infection: 51.6842 - specificity_infection: 0.9971 - accuracy_infection: 0.9950 - f1_infection: 0.8154 - val_loss: 0.5234 - val_dice_coef_infection: 0.5592 - val_iou_coef_infection: 0.5312 - val_precision_infection: 0.7670 - val_recall_infection: 0.6308 - val_hausdorff95_infection: 88.7509 - val_specificity_infection: 0.9995 - val_accuracy_infection: 0.9937 - val_f1_infection: 0.8261
# ✅ Total training time: 14847.00 seconds (247.45 minutes)

# %% [markdown]
# ## Plotting the performance metrics

# %%
plt.plot(history.history['dice_coef_infection'])
plt.plot(history.history['val_dice_coef_infection'])
plt.title('dice_coef_infection vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Dice_coef')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# %%
plt.plot(history.history['iou_coef_infection'])
plt.plot(history.history['val_iou_coef_infection'])
plt.title('iou_coef_infection vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Iou_coef')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Val'], loc = 'upper right')
plt.show()

# %% [markdown]
# ## Using our trained model for prediction

# %%
import numpy as np
import time

# Start timer (high precision)
start_time = time.perf_counter()

# Evaluate the model on the validation generator
results = model.evaluate(val_gen, verbose=1)

# End timer
end_time = time.perf_counter()

# Calculate evaluation time
eval_time = end_time - start_time

# Print metric names with results
print("\n===== Validation Metrics =====")
for name, value in zip(model.metrics_names, results):
    print(f"{name}: {value:.6f}")

print(f"\nEvaluation Time: {eval_time:.8f} seconds\n")
# Out:
# 128/128 [==============================] - 19s 148ms/step - loss: 0.5070 - dice_coef_infection: 0.5849 - iou_coef_infection: 0.5496 - precision_infection: 0.7736 - recall_infection: 0.7102 - hausdorff95_infection: 81.4562 - specificity_infection: 0.9993 - accuracy_infection: 0.9958 - f1_infection: 0.8038
#
# ===== Validation Metrics =====
# loss: 0.506998
# dice_coef_infection: 0.584894
# iou_coef_infection: 0.549630
# precision_infection: 0.773557
# recall_infection: 0.710244
# hausdorff95_infection: 81.456192
# specificity_infection: 0.999346
# accuracy_infection: 0.995809
# f1_infection: 0.803752
#
# Evaluation Time: 19.04148751 seconds

# %%
import matplotlib.pyplot as plt
import numpy as np

# Run inference if not already done
predicted = model.predict(lung_test)

# Selected indices to visualize (744 as 1st, 280 as 2nd, 230 as 3rd)
selected_indices = [744, 280, 230]
n_samples = len(selected_indices)

# Mapping indices to custom names
name_mapping = {
    0: ("Image1_Covid", "GT1_Covid", "Predict1_Covid_DSEG_Unet"),  # Index 744
    1: ("Image2_Covid", "GT2_Covid", "Predict2_Covid_DSEG_Unet"),  # Index 280
    2: ("Image3_Covid", "GT3_Covid", "Predict3_Covid_DSEG_Unet")   # Index 230
}

# Plot
for j, i in enumerate(selected_indices):
    lung_img = lung_test[i][..., 0].astype(np.float32)
    gt_infect = (infect_test[i][..., 0] > 0.5).astype(np.float32)
    pred_infect = predicted[i][..., 0].astype(np.float32)

    # Normalize lung image
    if lung_img.max() > lung_img.min():
        lung_img = (lung_img - lung_img.min()) / (lung_img.max() - lung_img.min())
    lung_img = np.clip(lung_img, 0, 1)
    pred_infect = np.clip(pred_infect, 0, 1)

    # Get custom names for this index
    input_name, gt_name, pred_name = name_mapping[j]

    # Save Original Lung
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{input_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

    # Save Ground Truth Infection
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.imshow(gt_infect, cmap='Reds', alpha=0.6)
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{gt_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

    # Save Predicted Infection
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.imshow(pred_infect, cmap='Reds', alpha=0.6)
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{pred_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

print("Separate JPEG files saved for input images (Image1_Covid, Image2_Covid, Image3_Covid), "
      "ground truths (GT1_Covid, GT2_Covid, GT3_Covid), and predictions "
      "(Predict1_Covid_DSEG_Unet, Predict2_Covid_DSEG_Unet, Predict3_Covid_DSEG_Unet).")
# Out:
# Separate JPEG files saved for input images (Image1_Covid, Image2_Covid, Image3_Covid), ground truths (GT1_Covid, GT2_Covid, GT3_Covid), and predictions (Predict1_Covid_DSEG_Unet, Predict2_Covid_DSEG_Unet, Predict3_Covid_DSEG_Unet).
