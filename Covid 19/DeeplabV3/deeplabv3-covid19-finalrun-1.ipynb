# %% [markdown]
# ## Importing important libraries

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import nibabel as nib #for loading nii files
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf #for deep learning

# %% [markdown]
# ## Reading the metadata

# %%
data = pd.read_csv('../input/covid19-ct-scans/metadata.csv')
data.head()
# Out:
#                                              ct_scan  \
# 0  ../input/covid19-ct-scans/ct_scans/coronacases...
# 1  ../input/covid19-ct-scans/ct_scans/coronacases...
# 2  ../input/covid19-ct-scans/ct_scans/coronacases...
# 3  ../input/covid19-ct-scans/ct_scans/coronacases...
# 4  ../input/covid19-ct-scans/ct_scans/coronacases...
#
#                                            lung_mask  \
# 0  ../input/covid19-ct-scans/lung_mask/coronacase...
# 1  ../input/covid19-ct-scans/lung_mask/coronacase...
# 2  ../input/covid19-ct-scans/lung_mask/coronacase...
# 3  ../input/covid19-ct-scans/lung_mask/coronacase...
# 4  ../input/covid19-ct-scans/lung_mask/coronacase...
#
#                                       infection_mask  \
# 0  ../input/covid19-ct-scans/infection_mask/coron...
# 1  ../input/covid19-ct-scans/infection_mask/coron...
# 2  ../input/covid19-ct-scans/infection_mask/coron...
# 3  ../input/covid19-ct-scans/infection_mask/coron...
# 4  ../input/covid19-ct-scans/infection_mask/coron...
#
#                              lung_and_infection_mask
# 0  ../input/covid19-ct-scans/lung_and_infection_m...
# 1  ../input/covid19-ct-scans/lung_and_infection_m...
# 2  ../input/covid19-ct-scans/lung_and_infection_m...
# 3  ../input/covid19-ct-scans/lung_and_infection_m...
# 4  ../input/covid19-ct-scans/lung_and_infection_m...

# %% [markdown]
# ## Defining function for readiing .nii files

# %%
def read_nii(filepath):
    '''
    Reads .nii file and returns pixel array
    '''
    ct_scan = nib.load(filepath)
    array   = ct_scan.get_fdata()
    array   = np.rot90(np.array(array))
    return(array)

# %% [markdown]
# ## Reading the chest ct scan data

# %%
# Read sample
sample_ct   = read_nii(data.loc[2,'ct_scan'])
sample_lung = read_nii(data.loc[2,'lung_mask'])
sample_infe = read_nii(data.loc[2,'infection_mask'])
sample_all  = read_nii(data.loc[2,'lung_and_infection_mask'])

# %% [markdown]
# ## Plotting the sample images

# %%
fig = plt.figure(figsize = (18,15))
plt.subplot(1,4,1)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.title('Original Image')

plt.subplot(1,4,2)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_lung[..., 150],alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung Mask')

plt.subplot(1,4,3)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_infe[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Infection Mask')

plt.subplot(1,4,4)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_all[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung and Infection Mask')
# Out:
# Text(0.5, 1.0, 'Lung and Infection Mask')

# %% [markdown]
# ## Converting the data into array for training model

# %%
import numpy as np
import cv2
import random
from scipy.ndimage import rotate, shift, zoom

lungs = []
infections = []
case_ids = []
img_size = 320

# ----------- Load and Resize Data -----------
for case_index in range(len(data)):
    ct = read_nii(data['ct_scan'][case_index])
    infect = read_nii(data['infection_mask'][case_index])

    for slice_index in range(ct.shape[0]):
        lung_img = cv2.resize(ct[slice_index], dsize=(img_size, img_size)).astype('float32')
        infec_img = cv2.resize(infect[slice_index], dsize=(img_size, img_size)).astype('float32')

        lungs.append(lung_img[..., np.newaxis])
        infections.append(infec_img[..., np.newaxis])
        case_ids.append(case_index)

# %%
import numpy as np

# case_ids should be a NumPy array telling which case each slice belongs to
# Convert and binarize
lungs = np.array(lungs, dtype=np.float32)
infections = (np.array(infections, dtype=np.uint8) > 0.5).astype(np.uint8)
case_ids = np.array(case_ids)

# %% [markdown]
# ## Performing test and train split

# %%
# ----------- Case-wise Split -----------
unique_cases = np.unique(case_ids)
train_cases = np.append(unique_cases[4:6], unique_cases[6:20])
temp_cases = unique_cases[2:4]
val_cases = unique_cases[:2]

train_mask = np.isin(case_ids, train_cases)
temp_mask = np.isin(case_ids, temp_cases)
val_mask = np.isin(case_ids, val_cases)

lung_train = lungs[train_mask]
infect_train = infections[train_mask]
lung_temp = lungs[temp_mask]
infect_temp = infections[temp_mask]
lung_test = lungs[val_mask]
infect_test = infections[val_mask]

print(f"✅ Train: {lung_train.shape[0]} slices from {len(train_cases)} cases")
print(f"✅ Validation: {lung_temp.shape[0]} slices from {len(temp_cases)} cases")
print(f"✅ Test: {lung_test.shape[0]} slices from {len(val_cases)} cases")

# ----------- Augmentation -----------
def augment_image(img, mask):
    if random.random() < 0.5:
        img = np.fliplr(img)
        mask = np.fliplr(mask)
    if random.random() < 0.5:
        img = np.flipud(img)
        mask = np.flipud(mask)

    angle = random.uniform(-15, 15)
    img = rotate(img, angle, reshape=False, order=1, mode='nearest')
    mask = rotate(mask, angle, reshape=False, order=0, mode='nearest')

    shift_val = np.random.uniform(-0.1, 0.1, size=2) * img.shape[:2]
    img = shift(img, shift=(*shift_val, 0), order=1, mode='nearest')
    mask = shift(mask, shift=(*shift_val, 0), order=0, mode='nearest')

    zoom_factor = random.uniform(0.9, 1.1)
    img = zoom(img, (zoom_factor, zoom_factor, 1), order=1)
    mask = zoom(mask, (zoom_factor, zoom_factor, 1), order=0)

    return fix_shape(img), fix_shape(mask)

def fix_shape(arr, target_size=(320, 320)):
    h, w, c = arr.shape
    th, tw = target_size
    dh = th - h
    dw = tw - w
    if dh > 0 or dw > 0:
        pad_h = (max(dh // 2, 0), max(dh - dh // 2, 0))
        pad_w = (max(dw // 2, 0), max(dw - dw // 2, 0))
        arr = np.pad(arr, (pad_h, pad_w, (0, 0)), mode='constant')
    arr = arr[:th, :tw, :]
    return arr.astype('float32')

# ----------- Apply Augmentation -----------
aug_lung_train = []
aug_infect_train = []

for i in range(len(lung_train)):
    img, mask = augment_image(lung_train[i], infect_train[i])
    aug_lung_train.append(img)
    aug_infect_train.append(mask)

lung_train = np.stack(aug_lung_train)
infect_train = np.stack(aug_infect_train)

# Final Binarization
infect_train = (infect_train > 0.5).astype(np.uint8)
infect_test = (infect_test > 0.5).astype(np.uint8)

print(f"✅ Augmented training shape: {lung_train.shape}")
print("✅ All preprocessing complete.")
# Out:
# ✅ Train: 9143 slices from 16 cases
# ✅ Validation: 1024 slices from 2 cases
# ✅ Test: 1024 slices from 2 cases
# ✅ Augmented training shape: (9143, 320, 320, 1)
# ✅ All preprocessing complete.

# %%
import tensorflow as tf
from tensorflow.keras import backend as K
import numpy as np
from scipy.spatial import cKDTree

smooth = 1.0

# Binary Dice coefficient (soft - commonly used during training)
def dice_coef_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# Binary IoU coefficient (soft)
def iou_coef_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# Soft Precision
def precision_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + smooth) / (K.sum(y_pred_f) + smooth)

# Soft Recall (Sensitivity)
def recall_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + smooth) / (K.sum(y_true_f) + smooth)

# Soft Specificity
def specificity_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    tn = K.sum((1 - y_true_f) * (1 - y_pred_f))
    fp = K.sum((1 - y_true_f) * y_pred_f)
    return (tn + smooth) / (tn + fp + smooth)

# Soft Accuracy
def accuracy_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    tp = K.sum(y_true_f * y_pred_f)
    tn = K.sum((1 - y_true_f) * (1 - y_pred_f))
    total = K.cast(K.shape(y_true_f)[0], 'float32')
    return (tp + tn + smooth) / (total + smooth)

# Soft F1-score (harmonic mean of precision & recall - very close to Dice, standard in many repos)
def f1_infection(y_true, y_pred):
    precision = precision_infection(y_true, y_pred)
    recall    = recall_infection(y_true, y_pred)
    return (2. * precision * recall + smooth) / (precision + recall + smooth)

# Hausdorff Distance 95 % (robust & most commonly used in medical imaging challenges)
# Lower = better. Returns the mean HD95 over the batch.
def _calculate_hd95(y_true, y_pred):
    hd_list = []
    for i in range(y_true.shape[0]):
        # Hard threshold at 0.5 (standard for evaluation metrics)
        gt = np.squeeze(y_true[i]) > 0.5
        pred = np.squeeze(y_pred[i]) > 0.5

        gt_pts = np.argwhere(gt)
        pred_pts = np.argwhere(pred)

        # Cases with empty masks
        if gt_pts.shape[0] == 0 and pred_pts.shape[0] == 0:
            hd_list.append(0.0)
            continue
        if gt_pts.shape[0] == 0 or pred_pts.shape[0] == 0:
            hd_list.append(400.0)  # large penalty - adjust to your image diagonal if needed (e.g. ~362 for 256×256, ~724 for 512×512)
            continue

        # Directed distances
        dist_gt_to_pred = cKDTree(pred_pts).query(gt_pts)[0]
        dist_pred_to_gt = cKDTree(gt_pts).query(pred_pts)[0]

        hd95 = max(
            np.percentile(dist_gt_to_pred, 95),
            np.percentile(dist_pred_to_gt, 95)
        )
        hd_list.append(hd95)

    return np.mean(hd_list, dtype=np.float32)

def hausdorff95_infection(y_true, y_pred):
    hd = tf.numpy_function(_calculate_hd95, [y_true, y_pred], tf.float32)
    hd.set_shape(())
    return hd

# Optional: KL Divergence (you already had this)
kld = tf.keras.losses.KLDivergence()

# %%
from tensorflow.keras.losses import BinaryCrossentropy

def loss_f(y_true, y_pred):
    bce = BinaryCrossentropy()
    return dice_loss(y_true, y_pred) + bce(y_true, y_pred) 

def loss_e(y_true, y_pred):
    bce = BinaryCrossentropy()
    return dice_loss(y_true, y_pred)  + kld(y_true, y_pred)
    
def dice_loss(y_true, y_pred):
    return 1. - dice_coef_infection(y_true, y_pred)

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Multiply, Conv2D, DepthwiseConv2D, Dense, Flatten, MaxPooling2D, UpSampling2D, concatenate, Activation, LayerNormalization, Add, Dropout, Conv2DTranspose, multiply, Reshape, GlobalAveragePooling2D, Permute, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Concatenate

def activation_block(x):
    x = Activation("gelu")(x)
    return LayerNormalization()(x)

def conv_stem(x, filters: int, patch_size: int):
    x = Conv2D(filters, kernel_size=patch_size,padding='same', strides=patch_size)(x)
    return activation_block(x)

def vector_block(xyz, cmf, red):
    # red means reduction
    # cmf means filters, denotes vector size
    opt1 = conv_stem(xyz, cmf, red)
    opt2 = conv_stem(xyz, cmf, red)
    
    o1 = GlobalAveragePooling2D()(opt1)
    o2 = GlobalAveragePooling2D()(opt2)

    o5 = concatenate([o1, o2], -1)
    return o5

def mlp_feature(vect, cmf):
    oo = Flatten()(vect)
    o6 = Dense(cmf, activation='gelu')(oo)
    o6 = Dropout(0.2)(o6)
    o6 = Dense(cmf * 2, activation='gelu')(o6)

    o6 = Reshape((1, cmf * 2))(o6)
    o7 = Permute((2, 1))(o6)

    o8 = multiply([o6, o7])
    
    o8 = Lambda(lambda x: tf.expand_dims(x, -1))(o8)
    
    o8 = Reshape((cmf, cmf, 4))(o8)

    return o8

def frz_block(xyz):
    shape = xyz.shape
    a1, a2, a3, a4 = shape[0], shape[1], shape[2], shape[3]
    cmf = a2
    o5 = vector_block(xyz, cmf, 5)
    o7 = mlp_feature(o5, cmf)

    o7 = concatenate([o7, xyz, o7], -1)
    return o7

def up_frz(x1, x2, n_filters):
    # Upsample x1 using Conv2DTranspose
    x1 = Conv2DTranspose(n_filters * 4, 3, strides=2, activation='gelu', padding="same")(x1)
    
    # Apply Conv2D to x2
    x2 = Conv2D(n_filters * 2, 3, activation='gelu', padding="same")(x2)
    
    # Apply attention mechanism
    x = concatenate([x1, x2])
    
    # Apply Dropout for regularization
    x = Dropout(0.3)(x)
    
    return x

# %%
# Install necessary dependencies
# !pip install -U segmentation-models
# !pip install segmentation-models --extra-index-url https://test.pypi.org/simple
# !pip install efficientnet

# Import libraries
from tensorflow.keras.applications import ResNet50
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model

# Define a convolution block function
def convolution_block(block_input, num_filters=256, kernel_size=3, dilation_rate=1, use_bias=False):
    x = layers.Conv2D(
        num_filters,
        kernel_size=kernel_size,
        dilation_rate=dilation_rate,
        padding="same",
        use_bias=use_bias,
        kernel_initializer=keras.initializers.HeNormal(),
    )(block_input)
    x = layers.BatchNormalization()(x)
    return keras.activations.relu(x)  # Fixed activation

# Define the Dilated Spatial Pyramid Pooling (DSPP) module
def DilatedSpatialPyramidPooling(dspp_input):
    dims = dspp_input.shape
    x = layers.AveragePooling2D(pool_size=(dims[1], dims[2]))(dspp_input)
    x = convolution_block(x, kernel_size=1, use_bias=True)
    out_pool = layers.UpSampling2D(
        size=(dims[1] // x.shape[1], dims[2] // x.shape[2]),
        interpolation="bilinear",
    )(x)

    out_1 = convolution_block(dspp_input, kernel_size=1, dilation_rate=1)
    out_6 = convolution_block(dspp_input, kernel_size=3, dilation_rate=2)
    out_12 = convolution_block(dspp_input, kernel_size=3, dilation_rate=4)
    out_18 = convolution_block(dspp_input, kernel_size=3, dilation_rate=6)

    x = layers.Concatenate(axis=-1)([out_pool, out_1, out_6, out_12, out_18])
    output = convolution_block(x, kernel_size=1)
    return output

# Define the DeepLabV3+ model
def DeeplabV3Plus(image_size=256, num_classes=1):
    inputs = Input(shape=(image_size, image_size, 1), name='input_image')

    # Load ResNet50 without top layers
    base_model = ResNet50(include_top=False, weights=None, input_tensor=inputs)

    # ResNet50 skip connections (common choices)
    x2 = base_model.get_layer('conv1_relu').output           # 112x112
    x3 = base_model.get_layer('conv2_block3_out').output     # 56x56
    x4 = base_model.get_layer('conv3_block4_out').output     # 28x28
    x5 = base_model.get_layer('conv4_block6_out').output     # 14x14

    # Apply DSPP module to x5 (bottleneck features)
    x = DilatedSpatialPyramidPooling(x5)

    # Upsampling and concatenation
    input_a = layers.UpSampling2D(
        size=(image_size // 4 // x.shape[1], image_size // 4 // x.shape[2]),
        interpolation="bilinear",
    )(x)
    input_b = convolution_block(x3, num_filters=48, kernel_size=1)

    x = layers.Concatenate(axis=-1)([input_a, input_b])
    x = convolution_block(x)
    x = convolution_block(x)

    x = layers.UpSampling2D(
        size=(image_size // x.shape[1], image_size // x.shape[2]),
        interpolation="bilinear",
    )(x)

    # Final output layer
    model_output = layers.Conv2D(num_classes, kernel_size=(1, 1), padding="same")(x)
    model_output = layers.Activation("sigmoid")(model_output)

    return Model(inputs=base_model.input, outputs=model_output)

# Instantiate model
image_size = 320  # Define image size
num_classes = 1   # Define number of classes

model = DeeplabV3Plus(image_size, num_classes)
# Out:
# Collecting segmentation-models
#   Downloading segmentation_models-1.0.1-py3-none-any.whl (33 kB)
# Collecting image-classifiers==1.0.0
#   Downloading image_classifiers-1.0.0-py3-none-any.whl (19 kB)
# Collecting efficientnet==1.0.0
#   Downloading efficientnet-1.0.0-py3-none-any.whl (17 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 6.0 MB/s  eta 0:00:01
# Requirement already satisfied: scikit-image in /opt/conda/lib/python3.7/site-packages (from efficientnet==1.0.0->segmentation-models) (0.18.1)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.7/site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (2.10.0)
# Requirement already satisfied: numpy>=1.9.1 in /opt/conda/lib/python3.7/site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.19.5)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from h5py->keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.15.0)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (3.4.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2021.4.8)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (7.2.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.1.1)
# Requirement already satisfied: scipy>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.5.4)
# Requirement already satisfied: imageio>=2.3.0 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.9.0)
# Requirement already satisfied: networkx>=2.0 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.7/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (2.8.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.7/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (0.10.0)
# Requirement already satisfied: decorator>=4.3.0 in /opt/conda/lib/python3.7/site-packages (from networkx>=2.0->scikit-image->efficientnet==1.0.0->segmentation-models) (4.4.2)
# Installing collected packages: keras-applications, image-classifiers, efficientnet, segmentation-models
# Successfully installed efficientnet-1.0.0 image-classifiers-1.0.0 keras-applications-1.0.8 segmentation-models-1.0.1
# Looking in indexes: https://pypi.org/simple, https://test.pypi.org/simple
# Requirement already satisfied: segmentation-models in /opt/conda/lib/python3.7/site-packages (1.0.1)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /opt/conda/lib/python3.7/site-packages (from segmentation-models) (1.0.8)
# Requirement already satisfied: efficientnet==1.0.0 in /opt/conda/lib/python3.7/site-packages (from segmentation-models) (1.0.0)
# Requirement already satisfied: image-classifiers==1.0.0 in /opt/conda/lib/python3.7/site-packages (from segmentation-models) (1.0.0)
# Requirement already satisfied: scikit-image in /opt/conda/lib/python3.7/site-packages (from efficientnet==1.0.0->segmentation-models) (0.18.1)
# Requirement already satisfied: numpy>=1.9.1 in /opt/conda/lib/python3.7/site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.19.5)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.7/site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (2.10.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from h5py->keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.15.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2021.4.8)
# Requirement already satisfied: imageio>=2.3.0 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.9.0)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (3.4.1)
# Requirement already satisfied: scipy>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.5.4)
# Requirement already satisfied: PyWavelets>=1.1.1 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.1.1)
# Requirement already satisfied: networkx>=2.0 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.5)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (7.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.7/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.7/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (2.8.1)
# Requirement already satisfied: decorator>=4.3.0 in /opt/conda/lib/python3.7/site-packages (from networkx>=2.0->scikit-image->efficientnet==1.0.0->segmentation-models) (4.4.2)
# Requirement already satisfied: efficientnet in /opt/conda/lib/python3.7/site-packages (1.0.0)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /opt/conda/lib/python3.7/site-packages (from efficientnet) (1.0.8)
# Requirement already satisfied: scikit-image in /opt/conda/lib/python3.7/site-packages (from efficientnet) (0.18.1)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.7/site-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (2.10.0)
# Requirement already satisfied: numpy>=1.9.1 in /opt/conda/lib/python3.7/site-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.19.5)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from h5py->keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.15.0)
# Requirement already satisfied: networkx>=2.0 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet) (2.5)
# Requirement already satisfied: tifffile>=2019.7.26 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet) (2021.4.8)
# Requirement already satisfied: scipy>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet) (1.5.4)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet) (7.2.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet) (1.1.1)
# Requirement already satisfied: imageio>=2.3.0 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet) (2.9.0)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet) (3.4.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.7/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.7/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet) (0.10.0)
# Requirement already satisfied: decorator>=4.3.0 in /opt/conda/lib/python3.7/site-packages (from networkx>=2.0->scikit-image->efficientnet) (4.4.2)

# %%
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2_as_graph

def get_flops(model):
    """Calculate Floating Point Operations (FLOPs) of a Keras model in TensorFlow 2.x."""
    # Convert Keras model to a TensorFlow function
    concrete_func = tf.function(lambda inputs: model(inputs))
    concrete_func = concrete_func.get_concrete_function(
        tf.TensorSpec([1] + list(model.input_shape[1:]), model.input.dtype)
    )

    # Convert to frozen graph
    frozen_func, _ = convert_variables_to_constants_v2_as_graph(concrete_func)

    # Compute FLOPs
    flops = tf.compat.v1.profiler.profile(
        frozen_func.graph,
        options=tf.compat.v1.profiler.ProfileOptionBuilder.float_operation(),
    )

    return flops.total_float_ops

# Compute FLOPs
flops = get_flops(model)
print(f"Total FLOPs: {flops / 1e9:.2f} GFLOPs")  # Convert to GFLOPs

from tensorflow.keras.optimizers import Adam

optimizer = Adam(learning_rate=1e-3)
model.compile(optimizer=optimizer, loss=loss_f, metrics=[dice_coef_infection, iou_coef_infection, precision_infection, recall_infection, hausdorff95_infection, specificity_infection, accuracy_infection, f1_infection])

# Model summary
model.summary()
# Out:
# Total FLOPs: 36.14 GFLOPs
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_image (InputLayer)        [(None, 320, 320, 1) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 326, 326, 1)  0           input_image[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 160, 160, 64) 3200        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 160, 160, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 160, 160, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 162, 162, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 80, 80, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 80, 80, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 80, 80, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 80, 80, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 80, 80, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 80, 80, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 80, 80, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 80, 80, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 80, 80, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 80, 80, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 80, 80, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 80, 80, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 80, 80, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 80, 80, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 80, 80, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 80, 80, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 80, 80, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 80, 80, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 80, 80, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 80, 80, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 80, 80, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 80, 80, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 80, 80, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 80, 80, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 80, 80, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 80, 80, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 80, 80, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 80, 80, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 80, 80, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 80, 80, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 80, 80, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 80, 80, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 80, 80, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 40, 40, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 40, 40, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 40, 40, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 40, 40, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 40, 40, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 40, 40, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 40, 40, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 40, 40, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 40, 40, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 40, 40, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 40, 40, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 40, 40, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 40, 40, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 40, 40, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 40, 40, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 40, 40, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 40, 40, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 40, 40, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 40, 40, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 40, 40, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 40, 40, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 40, 40, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 40, 40, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 40, 40, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 40, 40, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 40, 40, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 40, 40, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 40, 40, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 40, 40, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 40, 40, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 40, 40, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 40, 40, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 40, 40, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 40, 40, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 40, 40, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 40, 40, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 40, 40, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 40, 40, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 40, 40, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 40, 40, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 40, 40, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 40, 40, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 20, 20, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 20, 20, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 20, 20, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 20, 20, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 20, 20, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 20, 20, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 20, 20, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 20, 20, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 20, 20, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 20, 20, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 20, 20, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 20, 20, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 20, 20, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 20, 20, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 20, 20, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 20, 20, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 20, 20, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 20, 20, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 20, 20, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 20, 20, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 20, 20, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 20, 20, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 20, 20, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 20, 20, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 20, 20, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 20, 20, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 20, 20, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 20, 20, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 20, 20, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 20, 20, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 20, 20, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 20, 20, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 20, 20, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 20, 20, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 20, 20, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 20, 20, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 20, 20, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 20, 20, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 20, 20, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 20, 20, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 20, 20, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 20, 20, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 20, 20, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 20, 20, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 20, 20, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 20, 20, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 20, 20, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 20, 20, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 20, 20, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 20, 20, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 20, 20, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 20, 20, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 20, 20, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 20, 20, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 20, 20, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 20, 20, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 20, 20, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 20, 20, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 20, 20, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 20, 20, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 20, 20, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 20, 20, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 1, 1, 1024)   0           conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 1, 1, 256)    262400      average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 1, 1, 256)    1024        conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 20, 20, 256)  262144      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 20, 20, 256)  2359296     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 20, 20, 256)  2359296     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 20, 20, 256)  2359296     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu (TFOpLambda)         (None, 1, 1, 256)    0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 20, 20, 256)  1024        conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 20, 20, 256)  1024        conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 20, 20, 256)  1024        conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 20, 20, 256)  1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 20, 20, 256)  0           tf.nn.relu[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_1 (TFOpLambda)       (None, 20, 20, 256)  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_2 (TFOpLambda)       (None, 20, 20, 256)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_3 (TFOpLambda)       (None, 20, 20, 256)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_4 (TFOpLambda)       (None, 20, 20, 256)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 20, 20, 1280) 0           up_sampling2d[0][0]
#                                                                  tf.nn.relu_1[0][0]
#                                                                  tf.nn.relu_2[0][0]
#                                                                  tf.nn.relu_3[0][0]
#                                                                  tf.nn.relu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 20, 20, 256)  327680      concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 20, 20, 256)  1024        conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 80, 80, 48)   12288       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_5 (TFOpLambda)       (None, 20, 20, 256)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 80, 80, 48)   192         conv2d_6[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 80, 80, 256)  0           tf.nn.relu_5[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_6 (TFOpLambda)       (None, 80, 80, 48)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 80, 80, 304)  0           up_sampling2d_1[0][0]
#                                                                  tf.nn.relu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 80, 80, 256)  700416      concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 80, 80, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_7 (TFOpLambda)       (None, 80, 80, 256)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 80, 80, 256)  589824      tf.nn.relu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 80, 80, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_8 (TFOpLambda)       (None, 80, 80, 256)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 320, 320, 256 0           tf.nn.relu_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 320, 320, 1)  257         up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 320, 320, 1)  0           conv2d_9[0][0]
# ==================================================================================================
# Total params: 17,824,193
# Trainable params: 17,789,409
# Non-trainable params: 34,784
# __________________________________________________________________________________________________

# %%
# Install required packages
# !pip install openpyxl

# Imports
import openpyxl  # required for reading .xlsx files
import pandas as pd
import tensorflow as tf
import os
import shutil
from tensorflow.keras.callbacks import LearningRateScheduler, ReduceLROnPlateau

# File paths
checkpoint_filepath = '/kaggle/working/checkpoint.h5.keras'
metrics_file = '/kaggle/working/training_metrics.xlsx'
pre_checkpoint_filepath = '/kaggle/input/swinunet-covid19-finalrun2/checkpoint.h5.keras'
pre_metrics_file = '/kaggle/input/swinunet-covid19-finalrun2/training_metrics.xlsx'

# Restore checkpoint and metrics if available
if os.path.exists(pre_checkpoint_filepath):
    shutil.copy(pre_checkpoint_filepath, checkpoint_filepath)
    print(f"Restored checkpoint from: {pre_checkpoint_filepath}")

if os.path.exists(pre_metrics_file):
    shutil.copy(pre_metrics_file, metrics_file)
    print(f"Restored metrics file from: {pre_metrics_file}")

# Load last epoch
def load_last_epoch():
    if os.path.exists(metrics_file):
        try:
            df = pd.read_excel(metrics_file, engine='openpyxl')
            if not df.empty and 'epoch' in df.columns:
                return df['epoch'].iloc[-1] + 1
        except Exception as e:
            print(f"⚠️ Could not read metrics file: {e}")
    return 0

last_epoch = load_last_epoch()

# Get best validation loss from previous runs
def get_best_val_loss():
    if os.path.exists(metrics_file):
        try:
            df = pd.read_excel(metrics_file, engine='openpyxl')
            if 'val_loss' in df.columns and not df['val_loss'].isnull().all():
                return df['val_loss'].min()
        except Exception as e:
            print(f"⚠️ Could not read val_loss from metrics file: {e}")
    return float('inf')

best_val_loss = get_best_val_loss()

# Custom model checkpoint
class CustomModelCheckpoint(tf.keras.callbacks.Callback):
    def __init__(self, filepath):
        super().__init__()
        self.filepath = filepath
        self.best_loss = best_val_loss

    def on_epoch_end(self, epoch, logs=None):
        current_loss = logs.get('val_loss')
        if current_loss is not None and current_loss < self.best_loss:
            self.best_loss = current_loss
            self.model.save(self.filepath)
            print(f"✅ Model saved at epoch {epoch + 1} with val_loss: {current_loss:.4f}")

# === Learning Rate Schedule ===
def lr_schedule(epoch, lr):
    return 1e-4 if epoch >= 1 else lr

lr_scheduler = LearningRateScheduler(lr_schedule, verbose=1)

# Logger for Excel
class MetricsLogger(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        df_new = pd.DataFrame([{**logs, 'epoch': epoch}])
        try:
            if os.path.exists(metrics_file):
                df = pd.read_excel(metrics_file, engine='openpyxl')
                df = pd.concat([df, df_new], ignore_index=True)
            else:
                df = df_new
            df.to_excel(metrics_file, index=False, engine='openpyxl')
        except Exception as e:
            print(f"⚠️ Failed to log metrics: {e}")

# Early stopping with patience and saving best weights
class CustomEarlyStopping(tf.keras.callbacks.Callback):
    def __init__(self, patience=20):
        super().__init__()
        self.patience = patience
        self.wait = 0
        self.best_loss = best_val_loss

    def on_epoch_end(self, epoch, logs=None):
        current_loss = logs.get('val_loss')
        if current_loss is None:
            return
        if current_loss < self.best_loss:
            self.best_loss = current_loss
            self.wait = 0
            self.model.save_weights(checkpoint_filepath)
        else:
            self.wait += 1
            if self.wait >= self.patience:
                print(f"🛑 Early stopping at epoch {epoch + 1}")
                self.model.stop_training = True


# Final callbacks list
callbacks = [
    CustomModelCheckpoint(filepath=checkpoint_filepath),
    MetricsLogger(),
    lr_scheduler,
    CustomEarlyStopping(patience=20)
]
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.3-py2.py3-none-any.whl (251 kB)
#      |████████████████████████████████| 251 kB 8.5 MB/s eta 0:00:01
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.3

# %% [markdown]
# ## Training the model

# %%
import time
import os
import pandas as pd
import numpy as np
from tensorflow.keras.utils import Sequence
from tensorflow.keras.models import load_model

EPOCHS = 100

# Record the start time
start_time = time.time()

# === Load last completed epoch from metrics file ===
def load_last_epoch():
    if os.path.exists(pre_metrics_file):
        try:
            df = pd.read_excel(pre_metrics_file, engine='openpyxl')
            if not df.empty and 'epoch' in df.columns:
                return int(df['epoch'].iloc[-1]) + 1
        except Exception as e:
            print(f"⚠️ Failed to read metrics file: {e}")
    return 0

last_epoch = load_last_epoch()

# === Load pretrained weights if available ===
if os.path.exists(pre_checkpoint_filepath):
    print("✅ Checkpoint found. Loading pretrained weights...")
    model.load_weights(pre_checkpoint_filepath)
    print(f"🔁 Resuming training from epoch {last_epoch}")
else:
    print("🆕 No checkpoint found. Starting training from scratch.")
    last_epoch = 0

# === Prepare input and label tensors ===
lung_train = np.asarray(lung_train, dtype=np.float16)
infect_train = np.asarray(infect_train, dtype=np.uint8)

lung_temp = np.asarray(lung_temp, dtype=np.float16)
infect_temp = np.asarray(infect_temp, dtype=np.uint8)

lung_test = np.asarray(lung_test, dtype=np.float16)
infect_test = np.asarray(infect_test, dtype=np.uint8)

# === Data Generator ===
class LungDataGenerator(Sequence):
    def __init__(self, X, Y, batch_size=8, shuffle=True):
        self.X = X
        self.Y = Y
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indices = np.arange(len(X))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.X) / self.batch_size))

    def __getitem__(self, index):
        batch_ids = self.indices[index * self.batch_size:(index + 1) * self.batch_size]
        X_batch = self.X[batch_ids]
        Y_batch = self.Y[batch_ids]
        return np.asarray(X_batch, dtype=np.float16), np.asarray(Y_batch, dtype=np.uint8)

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indices)

# === Create generators ===
train_gen = LungDataGenerator(lung_train, infect_train, batch_size=8)
temp_gen = LungDataGenerator(lung_temp, infect_temp, batch_size=8, shuffle=False)
val_gen = LungDataGenerator(lung_test, infect_test, batch_size=8, shuffle=False)

# === Train the model ===
history = model.fit(
    train_gen,
    validation_data=temp_gen,
    epochs=EPOCHS,
    initial_epoch=last_epoch,
    callbacks=callbacks
)

# === Timing info ===
end_time = time.time()
total_time = end_time - start_time
print(f"✅ Total training time: {total_time:.2f} seconds ({total_time / 60:.2f} minutes)")
# Out:
# 🆕 No checkpoint found. Starting training from scratch.
# Epoch 1/100
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 241s 201ms/step - loss: 0.9611 - dice_coef_infection: 0.1253 - iou_coef_infection: 0.0764 - precision_infection: 0.1224 - recall_infection: 0.2872 - hausdorff95_infection: 140.5170 - specificity_infection: 0.9654 - accuracy_infection: 0.9589 - f1_infection: 0.8112 - val_loss: 1.1065 - val_dice_coef_infection: 0.0141 - val_iou_coef_infection: 0.0140 - val_precision_infection: 0.0183 - val_recall_infection: 0.5637 - val_hausdorff95_infection: 168.7500 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9883 - val_f1_infection: 0.7232
# ✅ Model saved at epoch 1 with val_loss: 1.1065
# Epoch 2/100
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 227s 199ms/step - loss: 0.7927 - dice_coef_infection: 0.2598 - iou_coef_infection: 0.1697 - precision_infection: 0.2767 - recall_infection: 0.3840 - hausdorff95_infection: 117.9390 - specificity_infection: 0.9924 - accuracy_infection: 0.9869 - f1_infection: 0.7757 - val_loss: 1.0634 - val_dice_coef_infection: 0.0142 - val_iou_coef_infection: 0.0104 - val_precision_infection: 0.0834 - val_recall_infection: 0.5682 - val_hausdorff95_infection: 148.9734 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9891 - val_f1_infection: 0.6821
# ✅ Model saved at epoch 2 with val_loss: 1.0634
# Epoch 3/100
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.6282 - dice_coef_infection: 0.4090 - iou_coef_infection: 0.2855 - precision_infection: 0.4256 - recall_infection: 0.5389 - hausdorff95_infection: 91.8782 - specificity_infection: 0.9949 - accuracy_infection: 0.9908 - f1_infection: 0.7592 - val_loss: 1.0475 - val_dice_coef_infection: 0.0258 - val_iou_coef_infection: 0.0219 - val_precision_infection: 0.1097 - val_recall_infection: 0.5683 - val_hausdorff95_infection: 147.7200 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9892 - val_f1_infection: 0.6794
# ✅ Model saved at epoch 3 with val_loss: 1.0475
# Epoch 4/100
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.5755 - dice_coef_infection: 0.4594 - iou_coef_infection: 0.3285 - precision_infection: 0.4748 - recall_infection: 0.5747 - hausdorff95_infection: 84.2993 - specificity_infection: 0.9957 - accuracy_infection: 0.9919 - f1_infection: 0.7696 - val_loss: 0.9665 - val_dice_coef_infection: 0.1144 - val_iou_coef_infection: 0.1096 - val_precision_infection: 0.2359 - val_recall_infection: 0.5695 - val_hausdorff95_infection: 144.1781 - val_specificity_infection: 1.0000 - val_accuracy_infection: 0.9894 - val_f1_infection: 0.7116
# ✅ Model saved at epoch 4 with val_loss: 0.9665
# Epoch 5/100
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.5301 - dice_coef_infection: 0.5021 - iou_coef_infection: 0.3677 - precision_infection: 0.5223 - recall_infection: 0.6148 - hausdorff95_infection: 76.3616 - specificity_infection: 0.9965 - accuracy_infection: 0.9928 - f1_infection: 0.7742 - val_loss: 0.6557 - val_dice_coef_infection: 0.3826 - val_iou_coef_infection: 0.3615 - val_precision_infection: 0.4872 - val_recall_infection: 0.6167 - val_hausdorff95_infection: 116.8311 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9940 - val_f1_infection: 0.8141
# ✅ Model saved at epoch 5 with val_loss: 0.6557
# Epoch 6/100
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.4803 - dice_coef_infection: 0.5484 - iou_coef_infection: 0.4082 - precision_infection: 0.5632 - recall_infection: 0.6311 - hausdorff95_infection: 67.9248 - specificity_infection: 0.9969 - accuracy_infection: 0.9937 - f1_infection: 0.7892 - val_loss: 0.6369 - val_dice_coef_infection: 0.4052 - val_iou_coef_infection: 0.3891 - val_precision_infection: 0.5673 - val_recall_infection: 0.6132 - val_hausdorff95_infection: 121.5648 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9944 - val_f1_infection: 0.7989
# ✅ Model saved at epoch 6 with val_loss: 0.6369
# Epoch 7/100
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 200ms/step - loss: 0.4504 - dice_coef_infection: 0.5761 - iou_coef_infection: 0.4348 - precision_infection: 0.5913 - recall_infection: 0.6542 - hausdorff95_infection: 64.2598 - specificity_infection: 0.9972 - accuracy_infection: 0.9941 - f1_infection: 0.7951 - val_loss: 0.8607 - val_dice_coef_infection: 0.1883 - val_iou_coef_infection: 0.1710 - val_precision_infection: 0.3274 - val_recall_infection: 0.6106 - val_hausdorff95_infection: 120.9306 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9940 - val_f1_infection: 0.7075
# Epoch 8/100
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.4555 - dice_coef_infection: 0.5717 - iou_coef_infection: 0.4332 - precision_infection: 0.5889 - recall_infection: 0.6632 - hausdorff95_infection: 59.2368 - specificity_infection: 0.9973 - accuracy_infection: 0.9943 - f1_infection: 0.7931 - val_loss: 0.7290 - val_dice_coef_infection: 0.3339 - val_iou_coef_infection: 0.3182 - val_precision_infection: 0.5227 - val_recall_infection: 0.6041 - val_hausdorff95_infection: 124.6966 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9934 - val_f1_infection: 0.7547
# Epoch 9/100
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.4426 - dice_coef_infection: 0.5823 - iou_coef_infection: 0.4457 - precision_infection: 0.5942 - recall_infection: 0.6714 - hausdorff95_infection: 58.2385 - specificity_infection: 0.9973 - accuracy_infection: 0.9946 - f1_infection: 0.7993 - val_loss: 0.7046 - val_dice_coef_infection: 0.3564 - val_iou_coef_infection: 0.3398 - val_precision_infection: 0.6202 - val_recall_infection: 0.6082 - val_hausdorff95_infection: 122.1615 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9938 - val_f1_infection: 0.7351
# Epoch 10/100
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.4344 - dice_coef_infection: 0.5905 - iou_coef_infection: 0.4564 - precision_infection: 0.6166 - recall_infection: 0.6775 - hausdorff95_infection: 56.6866 - specificity_infection: 0.9976 - accuracy_infection: 0.9950 - f1_infection: 0.7995 - val_loss: 0.4557 - val_dice_coef_infection: 0.5982 - val_iou_coef_infection: 0.5797 - val_precision_infection: 0.8966 - val_recall_infection: 0.6166 - val_hausdorff95_infection: 119.9588 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9943 - val_f1_infection: 0.8179
# ✅ Model saved at epoch 10 with val_loss: 0.4557
# Epoch 11/100
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.4176 - dice_coef_infection: 0.6077 - iou_coef_infection: 0.4718 - precision_infection: 0.6257 - recall_infection: 0.6873 - hausdorff95_infection: 50.9817 - specificity_infection: 0.9976 - accuracy_infection: 0.9949 - f1_infection: 0.8049 - val_loss: 0.4784 - val_dice_coef_infection: 0.5822 - val_iou_coef_infection: 0.5604 - val_precision_infection: 0.8987 - val_recall_infection: 0.6176 - val_hausdorff95_infection: 114.6945 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9939 - val_f1_infection: 0.8044
# Epoch 12/100
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.3962 - dice_coef_infection: 0.6288 - iou_coef_infection: 0.4934 - precision_infection: 0.6618 - recall_infection: 0.6923 - hausdorff95_infection: 52.3857 - specificity_infection: 0.9978 - accuracy_infection: 0.9952 - f1_infection: 0.8096 - val_loss: 0.4500 - val_dice_coef_infection: 0.6120 - val_iou_coef_infection: 0.5904 - val_precision_infection: 0.9236 - val_recall_infection: 0.6160 - val_hausdorff95_infection: 117.5022 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9937 - val_f1_infection: 0.8205
# ✅ Model saved at epoch 12 with val_loss: 0.4500
# Epoch 13/100
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 200ms/step - loss: 0.4157 - dice_coef_infection: 0.6098 - iou_coef_infection: 0.4739 - precision_infection: 0.6296 - recall_infection: 0.6861 - hausdorff95_infection: 49.2897 - specificity_infection: 0.9975 - accuracy_infection: 0.9950 - f1_infection: 0.8054 - val_loss: 0.4266 - val_dice_coef_infection: 0.6297 - val_iou_coef_infection: 0.6087 - val_precision_infection: 0.9656 - val_recall_infection: 0.6165 - val_hausdorff95_infection: 117.3438 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9940 - val_f1_infection: 0.8185
# ✅ Model saved at epoch 13 with val_loss: 0.4266
# Epoch 14/100
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 200ms/step - loss: 0.3943 - dice_coef_infection: 0.6307 - iou_coef_infection: 0.4982 - precision_infection: 0.6614 - recall_infection: 0.6828 - hausdorff95_infection: 50.5668 - specificity_infection: 0.9977 - accuracy_infection: 0.9952 - f1_infection: 0.8191 - val_loss: 0.4085 - val_dice_coef_infection: 0.6426 - val_iou_coef_infection: 0.6202 - val_precision_infection: 0.9541 - val_recall_infection: 0.6292 - val_hausdorff95_infection: 112.4282 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9949 - val_f1_infection: 0.8301
# ✅ Model saved at epoch 14 with val_loss: 0.4085
# Epoch 15/100
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 200ms/step - loss: 0.3885 - dice_coef_infection: 0.6380 - iou_coef_infection: 0.5016 - precision_infection: 0.6721 - recall_infection: 0.6883 - hausdorff95_infection: 47.3577 - specificity_infection: 0.9978 - accuracy_infection: 0.9951 - f1_infection: 0.8146 - val_loss: 0.4112 - val_dice_coef_infection: 0.6402 - val_iou_coef_infection: 0.6178 - val_precision_infection: 0.9487 - val_recall_infection: 0.6284 - val_hausdorff95_infection: 112.3793 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9948 - val_f1_infection: 0.8289
# Epoch 16/100
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 200ms/step - loss: 0.4004 - dice_coef_infection: 0.6280 - iou_coef_infection: 0.4939 - precision_infection: 0.6658 - recall_infection: 0.6787 - hausdorff95_infection: 45.6810 - specificity_infection: 0.9976 - accuracy_infection: 0.9950 - f1_infection: 0.8148 - val_loss: 0.4307 - val_dice_coef_infection: 0.6258 - val_iou_coef_infection: 0.6085 - val_precision_infection: 0.9746 - val_recall_infection: 0.6155 - val_hausdorff95_infection: 119.8934 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9944 - val_f1_infection: 0.8151
# Epoch 17/100
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 200ms/step - loss: 0.3647 - dice_coef_infection: 0.6592 - iou_coef_infection: 0.5251 - precision_infection: 0.6848 - recall_infection: 0.7035 - hausdorff95_infection: 46.9729 - specificity_infection: 0.9978 - accuracy_infection: 0.9953 - f1_infection: 0.8276 - val_loss: 0.4300 - val_dice_coef_infection: 0.6309 - val_iou_coef_infection: 0.6116 - val_precision_infection: 0.9575 - val_recall_infection: 0.6176 - val_hausdorff95_infection: 119.4126 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9943 - val_f1_infection: 0.8229
# Epoch 18/100
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.3852 - dice_coef_infection: 0.6411 - iou_coef_infection: 0.5074 - precision_infection: 0.6912 - recall_infection: 0.6825 - hausdorff95_infection: 45.5999 - specificity_infection: 0.9979 - accuracy_infection: 0.9955 - f1_infection: 0.8150 - val_loss: 0.4376 - val_dice_coef_infection: 0.6294 - val_iou_coef_infection: 0.6127 - val_precision_infection: 0.9703 - val_recall_infection: 0.6147 - val_hausdorff95_infection: 121.0632 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9944 - val_f1_infection: 0.8208
# Epoch 19/100
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.3595 - dice_coef_infection: 0.6656 - iou_coef_infection: 0.5324 - precision_infection: 0.6893 - recall_infection: 0.7069 - hausdorff95_infection: 45.6206 - specificity_infection: 0.9979 - accuracy_infection: 0.9955 - f1_infection: 0.8303 - val_loss: 0.4530 - val_dice_coef_infection: 0.6190 - val_iou_coef_infection: 0.6044 - val_precision_infection: 0.9816 - val_recall_infection: 0.6055 - val_hausdorff95_infection: 126.0194 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9938 - val_f1_infection: 0.8116
# Epoch 20/100
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.3814 - dice_coef_infection: 0.6422 - iou_coef_infection: 0.5111 - precision_infection: 0.6784 - recall_infection: 0.6957 - hausdorff95_infection: 43.6529 - specificity_infection: 0.9979 - accuracy_infection: 0.9956 - f1_infection: 0.8192 - val_loss: 0.4478 - val_dice_coef_infection: 0.6159 - val_iou_coef_infection: 0.5951 - val_precision_infection: 0.9675 - val_recall_infection: 0.6121 - val_hausdorff95_infection: 115.5767 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9936 - val_f1_infection: 0.8087
# Epoch 21/100
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.3688 - dice_coef_infection: 0.6570 - iou_coef_infection: 0.5229 - precision_infection: 0.6848 - recall_infection: 0.7038 - hausdorff95_infection: 45.2547 - specificity_infection: 0.9977 - accuracy_infection: 0.9953 - f1_infection: 0.8235 - val_loss: 0.4201 - val_dice_coef_infection: 0.6379 - val_iou_coef_infection: 0.6162 - val_precision_infection: 0.9783 - val_recall_infection: 0.6227 - val_hausdorff95_infection: 115.7479 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9944 - val_f1_infection: 0.8185
# Epoch 22/100
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.3765 - dice_coef_infection: 0.6511 - iou_coef_infection: 0.5177 - precision_infection: 0.6951 - recall_infection: 0.6819 - hausdorff95_infection: 44.7415 - specificity_infection: 0.9980 - accuracy_infection: 0.9955 - f1_infection: 0.8242 - val_loss: 0.4200 - val_dice_coef_infection: 0.6395 - val_iou_coef_infection: 0.6206 - val_precision_infection: 0.9870 - val_recall_infection: 0.6219 - val_hausdorff95_infection: 116.4298 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9948 - val_f1_infection: 0.8183
# Epoch 23/100
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.3680 - dice_coef_infection: 0.6546 - iou_coef_infection: 0.5227 - precision_infection: 0.6785 - recall_infection: 0.7062 - hausdorff95_infection: 43.7361 - specificity_infection: 0.9979 - accuracy_infection: 0.9958 - f1_infection: 0.8261 - val_loss: 0.4611 - val_dice_coef_infection: 0.5815 - val_iou_coef_infection: 0.5571 - val_precision_infection: 0.8510 - val_recall_infection: 0.6440 - val_hausdorff95_infection: 108.9107 - val_specificity_infection: 0.9996 - val_accuracy_infection: 0.9955 - val_f1_infection: 0.8098
# Epoch 24/100
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.3375 - dice_coef_infection: 0.6844 - iou_coef_infection: 0.5500 - precision_infection: 0.7046 - recall_infection: 0.7248 - hausdorff95_infection: 43.0069 - specificity_infection: 0.9980 - accuracy_infection: 0.9958 - f1_infection: 0.8332 - val_loss: 0.4415 - val_dice_coef_infection: 0.6215 - val_iou_coef_infection: 0.5997 - val_precision_infection: 0.9765 - val_recall_infection: 0.6162 - val_hausdorff95_infection: 117.3071 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9937 - val_f1_infection: 0.8094
# Epoch 25/100
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.3493 - dice_coef_infection: 0.6726 - iou_coef_infection: 0.5379 - precision_infection: 0.6948 - recall_infection: 0.7170 - hausdorff95_infection: 42.8299 - specificity_infection: 0.9980 - accuracy_infection: 0.9959 - f1_infection: 0.8283 - val_loss: 0.4451 - val_dice_coef_infection: 0.6236 - val_iou_coef_infection: 0.6092 - val_precision_infection: 0.9748 - val_recall_infection: 0.6111 - val_hausdorff95_infection: 124.2413 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9942 - val_f1_infection: 0.8162
# Epoch 26/100
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.3581 - dice_coef_infection: 0.6675 - iou_coef_infection: 0.5376 - precision_infection: 0.7156 - recall_infection: 0.6960 - hausdorff95_infection: 43.8581 - specificity_infection: 0.9980 - accuracy_infection: 0.9955 - f1_infection: 0.8297 - val_loss: 0.4074 - val_dice_coef_infection: 0.6417 - val_iou_coef_infection: 0.6217 - val_precision_infection: 0.9875 - val_recall_infection: 0.6236 - val_hausdorff95_infection: 114.6307 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9948 - val_f1_infection: 0.8189
# ✅ Model saved at epoch 26 with val_loss: 0.4074
# Epoch 27/100
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 200ms/step - loss: 0.3628 - dice_coef_infection: 0.6628 - iou_coef_infection: 0.5287 - precision_infection: 0.7053 - recall_infection: 0.6974 - hausdorff95_infection: 41.3600 - specificity_infection: 0.9981 - accuracy_infection: 0.9956 - f1_infection: 0.8240 - val_loss: 0.4348 - val_dice_coef_infection: 0.6237 - val_iou_coef_infection: 0.6076 - val_precision_infection: 0.9838 - val_recall_infection: 0.6130 - val_hausdorff95_infection: 120.5475 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9943 - val_f1_infection: 0.8120
# Epoch 28/100
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 200ms/step - loss: 0.3385 - dice_coef_infection: 0.6848 - iou_coef_infection: 0.5533 - precision_infection: 0.7277 - recall_infection: 0.7010 - hausdorff95_infection: 40.0845 - specificity_infection: 0.9982 - accuracy_infection: 0.9960 - f1_infection: 0.8359 - val_loss: 0.4237 - val_dice_coef_infection: 0.6379 - val_iou_coef_infection: 0.6184 - val_precision_infection: 0.9852 - val_recall_infection: 0.6203 - val_hausdorff95_infection: 116.5647 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9945 - val_f1_infection: 0.8180
# Epoch 29/100
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 200ms/step - loss: 0.3625 - dice_coef_infection: 0.6611 - iou_coef_infection: 0.5297 - precision_infection: 0.7147 - recall_infection: 0.6960 - hausdorff95_infection: 39.0689 - specificity_infection: 0.9981 - accuracy_infection: 0.9958 - f1_infection: 0.8209 - val_loss: 0.4187 - val_dice_coef_infection: 0.6425 - val_iou_coef_infection: 0.6191 - val_precision_infection: 0.9807 - val_recall_infection: 0.6220 - val_hausdorff95_infection: 114.4873 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9939 - val_f1_infection: 0.8205
# Epoch 30/100
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.3108 - dice_coef_infection: 0.7118 - iou_coef_infection: 0.5790 - precision_infection: 0.7412 - recall_infection: 0.7298 - hausdorff95_infection: 37.4889 - specificity_infection: 0.9980 - accuracy_infection: 0.9958 - f1_infection: 0.8438 - val_loss: 0.4257 - val_dice_coef_infection: 0.6415 - val_iou_coef_infection: 0.6196 - val_precision_infection: 0.9879 - val_recall_infection: 0.6207 - val_hausdorff95_infection: 116.5719 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9942 - val_f1_infection: 0.8183
# Epoch 31/100
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 200ms/step - loss: 0.3316 - dice_coef_infection: 0.6904 - iou_coef_infection: 0.5579 - precision_infection: 0.7104 - recall_infection: 0.7294 - hausdorff95_infection: 35.8507 - specificity_infection: 0.9980 - accuracy_infection: 0.9959 - f1_infection: 0.8371 - val_loss: 0.4321 - val_dice_coef_infection: 0.6307 - val_iou_coef_infection: 0.6101 - val_precision_infection: 0.9779 - val_recall_infection: 0.6134 - val_hausdorff95_infection: 115.4003 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9937 - val_f1_infection: 0.8160
# Epoch 32/100
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.3477 - dice_coef_infection: 0.6769 - iou_coef_infection: 0.5438 - precision_infection: 0.7060 - recall_infection: 0.7184 - hausdorff95_infection: 37.4919 - specificity_infection: 0.9980 - accuracy_infection: 0.9957 - f1_infection: 0.8288 - val_loss: 0.4700 - val_dice_coef_infection: 0.6158 - val_iou_coef_infection: 0.5988 - val_precision_infection: 0.9890 - val_recall_infection: 0.6010 - val_hausdorff95_infection: 121.9599 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9929 - val_f1_infection: 0.8068
# Epoch 33/100
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 200ms/step - loss: 0.3450 - dice_coef_infection: 0.6787 - iou_coef_infection: 0.5489 - precision_infection: 0.7157 - recall_infection: 0.7167 - hausdorff95_infection: 40.0514 - specificity_infection: 0.9980 - accuracy_infection: 0.9958 - f1_infection: 0.8307 - val_loss: 0.4646 - val_dice_coef_infection: 0.6199 - val_iou_coef_infection: 0.6031 - val_precision_infection: 0.9927 - val_recall_infection: 0.6061 - val_hausdorff95_infection: 122.1415 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9936 - val_f1_infection: 0.8079
# Epoch 34/100
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 200ms/step - loss: 0.3156 - dice_coef_infection: 0.7057 - iou_coef_infection: 0.5732 - precision_infection: 0.7273 - recall_infection: 0.7340 - hausdorff95_infection: 36.8594 - specificity_infection: 0.9981 - accuracy_infection: 0.9961 - f1_infection: 0.8412 - val_loss: 0.4047 - val_dice_coef_infection: 0.6500 - val_iou_coef_infection: 0.6272 - val_precision_infection: 0.9814 - val_recall_infection: 0.6284 - val_hausdorff95_infection: 114.2995 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9947 - val_f1_infection: 0.8241
# ✅ Model saved at epoch 34 with val_loss: 0.4047
# Epoch 35/100
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 200ms/step - loss: 0.3207 - dice_coef_infection: 0.7009 - iou_coef_infection: 0.5712 - precision_infection: 0.7301 - recall_infection: 0.7243 - hausdorff95_infection: 36.7322 - specificity_infection: 0.9982 - accuracy_infection: 0.9961 - f1_infection: 0.8420 - val_loss: 0.4093 - val_dice_coef_infection: 0.6497 - val_iou_coef_infection: 0.6262 - val_precision_infection: 0.9882 - val_recall_infection: 0.6277 - val_hausdorff95_infection: 114.1940 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9942 - val_f1_infection: 0.8220
# Epoch 36/100
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 200ms/step - loss: 0.3281 - dice_coef_infection: 0.6939 - iou_coef_infection: 0.5645 - precision_infection: 0.7319 - recall_infection: 0.7229 - hausdorff95_infection: 33.4395 - specificity_infection: 0.9981 - accuracy_infection: 0.9959 - f1_infection: 0.8368 - val_loss: 0.4196 - val_dice_coef_infection: 0.6400 - val_iou_coef_infection: 0.6194 - val_precision_infection: 0.9919 - val_recall_infection: 0.6202 - val_hausdorff95_infection: 116.1111 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9943 - val_f1_infection: 0.8171
# Epoch 37/100
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 200ms/step - loss: 0.3221 - dice_coef_infection: 0.6998 - iou_coef_infection: 0.5695 - precision_infection: 0.7251 - recall_infection: 0.7365 - hausdorff95_infection: 35.4417 - specificity_infection: 0.9980 - accuracy_infection: 0.9959 - f1_infection: 0.8391 - val_loss: 0.4627 - val_dice_coef_infection: 0.6234 - val_iou_coef_infection: 0.6070 - val_precision_infection: 0.9926 - val_recall_infection: 0.6074 - val_hausdorff95_infection: 121.9459 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9938 - val_f1_infection: 0.8100
# Epoch 38/100
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 200ms/step - loss: 0.3273 - dice_coef_infection: 0.6939 - iou_coef_infection: 0.5638 - precision_infection: 0.7257 - recall_infection: 0.7320 - hausdorff95_infection: 36.2049 - specificity_infection: 0.9981 - accuracy_infection: 0.9961 - f1_infection: 0.8349 - val_loss: 0.4244 - val_dice_coef_infection: 0.6346 - val_iou_coef_infection: 0.6119 - val_precision_infection: 0.9710 - val_recall_infection: 0.6207 - val_hausdorff95_infection: 114.5718 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9940 - val_f1_infection: 0.8179
# Epoch 39/100
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 200ms/step - loss: 0.3395 - dice_coef_infection: 0.6816 - iou_coef_infection: 0.5577 - precision_infection: 0.7313 - recall_infection: 0.7176 - hausdorff95_infection: 33.8485 - specificity_infection: 0.9982 - accuracy_infection: 0.9962 - f1_infection: 0.8324 - val_loss: 0.3918 - val_dice_coef_infection: 0.6570 - val_iou_coef_infection: 0.6336 - val_precision_infection: 0.9869 - val_recall_infection: 0.6356 - val_hausdorff95_infection: 113.2741 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9950 - val_f1_infection: 0.8254
# ✅ Model saved at epoch 39 with val_loss: 0.3918
# Epoch 40/100
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 200ms/step - loss: 0.3160 - dice_coef_infection: 0.7042 - iou_coef_infection: 0.5740 - precision_infection: 0.7260 - recall_infection: 0.7357 - hausdorff95_infection: 34.2710 - specificity_infection: 0.9981 - accuracy_infection: 0.9961 - f1_infection: 0.8416 - val_loss: 0.4512 - val_dice_coef_infection: 0.6175 - val_iou_coef_infection: 0.5962 - val_precision_infection: 0.9674 - val_recall_infection: 0.6157 - val_hausdorff95_infection: 116.2534 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9937 - val_f1_infection: 0.8093
# Epoch 41/100
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 200ms/step - loss: 0.3235 - dice_coef_infection: 0.7013 - iou_coef_infection: 0.5720 - precision_infection: 0.7383 - recall_infection: 0.7253 - hausdorff95_infection: 35.2857 - specificity_infection: 0.9981 - accuracy_infection: 0.9959 - f1_infection: 0.8402 - val_loss: 0.4321 - val_dice_coef_infection: 0.6362 - val_iou_coef_infection: 0.6162 - val_precision_infection: 0.9867 - val_recall_infection: 0.6168 - val_hausdorff95_infection: 116.4653 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9941 - val_f1_infection: 0.8170
# Epoch 42/100
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.3156 - dice_coef_infection: 0.7050 - iou_coef_infection: 0.5756 - precision_infection: 0.7385 - recall_infection: 0.7310 - hausdorff95_infection: 32.2329 - specificity_infection: 0.9982 - accuracy_infection: 0.9962 - f1_infection: 0.8408 - val_loss: 0.3942 - val_dice_coef_infection: 0.6517 - val_iou_coef_infection: 0.6283 - val_precision_infection: 0.9746 - val_recall_infection: 0.6297 - val_hausdorff95_infection: 110.8736 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9948 - val_f1_infection: 0.8268
# Epoch 43/100
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.3154 - dice_coef_infection: 0.7068 - iou_coef_infection: 0.5770 - precision_infection: 0.7406 - recall_infection: 0.7325 - hausdorff95_infection: 32.3071 - specificity_infection: 0.9980 - accuracy_infection: 0.9959 - f1_infection: 0.8416 - val_loss: 0.4003 - val_dice_coef_infection: 0.6540 - val_iou_coef_infection: 0.6280 - val_precision_infection: 0.9699 - val_recall_infection: 0.6302 - val_hausdorff95_infection: 108.3270 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9943 - val_f1_infection: 0.8280
# Epoch 44/100
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.3167 - dice_coef_infection: 0.7054 - iou_coef_infection: 0.5791 - precision_infection: 0.7476 - recall_infection: 0.7289 - hausdorff95_infection: 36.2726 - specificity_infection: 0.9982 - accuracy_infection: 0.9962 - f1_infection: 0.8434 - val_loss: 0.3921 - val_dice_coef_infection: 0.6571 - val_iou_coef_infection: 0.6341 - val_precision_infection: 0.9876 - val_recall_infection: 0.6360 - val_hausdorff95_infection: 114.1456 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9951 - val_f1_infection: 0.8254
# Epoch 45/100
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.3185 - dice_coef_infection: 0.7035 - iou_coef_infection: 0.5732 - precision_infection: 0.7349 - recall_infection: 0.7330 - hausdorff95_infection: 36.1534 - specificity_infection: 0.9981 - accuracy_infection: 0.9961 - f1_infection: 0.8393 - val_loss: 0.4086 - val_dice_coef_infection: 0.6474 - val_iou_coef_infection: 0.6251 - val_precision_infection: 0.9674 - val_recall_infection: 0.6264 - val_hausdorff95_infection: 111.4553 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9946 - val_f1_infection: 0.8291
# Epoch 46/100
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.3041 - dice_coef_infection: 0.7159 - iou_coef_infection: 0.5866 - precision_infection: 0.7538 - recall_infection: 0.7285 - hausdorff95_infection: 31.4272 - specificity_infection: 0.9982 - accuracy_infection: 0.9963 - f1_infection: 0.8459 - val_loss: 0.4181 - val_dice_coef_infection: 0.6438 - val_iou_coef_infection: 0.6208 - val_precision_infection: 0.9666 - val_recall_infection: 0.6222 - val_hausdorff95_infection: 114.2651 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9941 - val_f1_infection: 0.8274
# Epoch 47/100
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.3014 - dice_coef_infection: 0.7192 - iou_coef_infection: 0.5914 - precision_infection: 0.7458 - recall_infection: 0.7408 - hausdorff95_infection: 31.8725 - specificity_infection: 0.9981 - accuracy_infection: 0.9961 - f1_infection: 0.8486 - val_loss: 0.4144 - val_dice_coef_infection: 0.6383 - val_iou_coef_infection: 0.6170 - val_precision_infection: 0.9517 - val_recall_infection: 0.6190 - val_hausdorff95_infection: 112.8124 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9942 - val_f1_infection: 0.8300
# Epoch 48/100
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.3009 - dice_coef_infection: 0.7189 - iou_coef_infection: 0.5923 - precision_infection: 0.7542 - recall_infection: 0.7442 - hausdorff95_infection: 31.6287 - specificity_infection: 0.9983 - accuracy_infection: 0.9964 - f1_infection: 0.8451 - val_loss: 0.4096 - val_dice_coef_infection: 0.6455 - val_iou_coef_infection: 0.6235 - val_precision_infection: 0.9867 - val_recall_infection: 0.6246 - val_hausdorff95_infection: 114.1823 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9946 - val_f1_infection: 0.8206
# Epoch 49/100
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.2894 - dice_coef_infection: 0.7296 - iou_coef_infection: 0.6004 - precision_infection: 0.7535 - recall_infection: 0.7527 - hausdorff95_infection: 28.8434 - specificity_infection: 0.9981 - accuracy_infection: 0.9963 - f1_infection: 0.8500 - val_loss: 0.4332 - val_dice_coef_infection: 0.6342 - val_iou_coef_infection: 0.6149 - val_precision_infection: 0.9507 - val_recall_infection: 0.6156 - val_hausdorff95_infection: 116.7743 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9941 - val_f1_infection: 0.8322
# Epoch 50/100
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 200ms/step - loss: 0.3024 - dice_coef_infection: 0.7159 - iou_coef_infection: 0.5891 - precision_infection: 0.7430 - recall_infection: 0.7510 - hausdorff95_infection: 29.6094 - specificity_infection: 0.9982 - accuracy_infection: 0.9965 - f1_infection: 0.8443 - val_loss: 0.3978 - val_dice_coef_infection: 0.6542 - val_iou_coef_infection: 0.6306 - val_precision_infection: 0.9470 - val_recall_infection: 0.6323 - val_hausdorff95_infection: 107.0987 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9947 - val_f1_infection: 0.8409
# Epoch 51/100
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 200ms/step - loss: 0.2861 - dice_coef_infection: 0.7336 - iou_coef_infection: 0.6048 - precision_infection: 0.7566 - recall_infection: 0.7568 - hausdorff95_infection: 30.5878 - specificity_infection: 0.9981 - accuracy_infection: 0.9963 - f1_infection: 0.8513 - val_loss: 0.4257 - val_dice_coef_infection: 0.6412 - val_iou_coef_infection: 0.6182 - val_precision_infection: 0.9656 - val_recall_infection: 0.6191 - val_hausdorff95_infection: 110.1128 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9939 - val_f1_infection: 0.8277
# Epoch 52/100
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 200ms/step - loss: 0.2974 - dice_coef_infection: 0.7219 - iou_coef_infection: 0.5937 - precision_infection: 0.7505 - recall_infection: 0.7555 - hausdorff95_infection: 32.0569 - specificity_infection: 0.9981 - accuracy_infection: 0.9963 - f1_infection: 0.8434 - val_loss: 0.3868 - val_dice_coef_infection: 0.6609 - val_iou_coef_infection: 0.6359 - val_precision_infection: 0.9788 - val_recall_infection: 0.6378 - val_hausdorff95_infection: 112.2557 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9948 - val_f1_infection: 0.8298
# ✅ Model saved at epoch 52 with val_loss: 0.3868
# Epoch 53/100
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.3037 - dice_coef_infection: 0.7176 - iou_coef_infection: 0.5882 - precision_infection: 0.7519 - recall_infection: 0.7327 - hausdorff95_infection: 33.8980 - specificity_infection: 0.9981 - accuracy_infection: 0.9962 - f1_infection: 0.8463 - val_loss: 0.4227 - val_dice_coef_infection: 0.6374 - val_iou_coef_infection: 0.6174 - val_precision_infection: 0.9846 - val_recall_infection: 0.6180 - val_hausdorff95_infection: 116.6108 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9942 - val_f1_infection: 0.8183
# Epoch 54/100
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.2948 - dice_coef_infection: 0.7239 - iou_coef_infection: 0.5971 - precision_infection: 0.7602 - recall_infection: 0.7385 - hausdorff95_infection: 32.1032 - specificity_infection: 0.9982 - accuracy_infection: 0.9964 - f1_infection: 0.8496 - val_loss: 0.4176 - val_dice_coef_infection: 0.6414 - val_iou_coef_infection: 0.6193 - val_precision_infection: 0.9865 - val_recall_infection: 0.6199 - val_hausdorff95_infection: 114.4708 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9940 - val_f1_infection: 0.8190
# Epoch 55/100
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.2801 - dice_coef_infection: 0.7400 - iou_coef_infection: 0.6143 - precision_infection: 0.7684 - recall_infection: 0.7539 - hausdorff95_infection: 30.8071 - specificity_infection: 0.9983 - accuracy_infection: 0.9963 - f1_infection: 0.8556 - val_loss: 0.4169 - val_dice_coef_infection: 0.6414 - val_iou_coef_infection: 0.6185 - val_precision_infection: 0.9917 - val_recall_infection: 0.6190 - val_hausdorff95_infection: 112.2201 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9938 - val_f1_infection: 0.8174
# Epoch 56/100
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.3154 - dice_coef_infection: 0.7073 - iou_coef_infection: 0.5752 - precision_infection: 0.7458 - recall_infection: 0.7265 - hausdorff95_infection: 31.4472 - specificity_infection: 0.9981 - accuracy_infection: 0.9960 - f1_infection: 0.8405 - val_loss: 0.4134 - val_dice_coef_infection: 0.6459 - val_iou_coef_infection: 0.6224 - val_precision_infection: 0.9872 - val_recall_infection: 0.6243 - val_hausdorff95_infection: 112.5393 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9942 - val_f1_infection: 0.8202
# Epoch 57/100
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.2892 - dice_coef_infection: 0.7300 - iou_coef_infection: 0.5987 - precision_infection: 0.7552 - recall_infection: 0.7487 - hausdorff95_infection: 30.9404 - specificity_infection: 0.9982 - accuracy_infection: 0.9963 - f1_infection: 0.8493 - val_loss: 0.4029 - val_dice_coef_infection: 0.6578 - val_iou_coef_infection: 0.6303 - val_precision_infection: 0.9760 - val_recall_infection: 0.6323 - val_hausdorff95_infection: 106.2743 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9940 - val_f1_infection: 0.8280
# Epoch 58/100
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.2882 - dice_coef_infection: 0.7311 - iou_coef_infection: 0.6058 - precision_infection: 0.7672 - recall_infection: 0.7434 - hausdorff95_infection: 30.3996 - specificity_infection: 0.9983 - accuracy_infection: 0.9964 - f1_infection: 0.8532 - val_loss: 0.4186 - val_dice_coef_infection: 0.6460 - val_iou_coef_infection: 0.6242 - val_precision_infection: 0.9732 - val_recall_infection: 0.6255 - val_hausdorff95_infection: 113.0735 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9946 - val_f1_infection: 0.8259
# Epoch 59/100
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.2936 - dice_coef_infection: 0.7250 - iou_coef_infection: 0.6000 - precision_infection: 0.7549 - recall_infection: 0.7465 - hausdorff95_infection: 29.0045 - specificity_infection: 0.9984 - accuracy_infection: 0.9966 - f1_infection: 0.8511 - val_loss: 0.4293 - val_dice_coef_infection: 0.6398 - val_iou_coef_infection: 0.6183 - val_precision_infection: 0.9905 - val_recall_infection: 0.6188 - val_hausdorff95_infection: 113.9243 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9940 - val_f1_infection: 0.8174
# Epoch 60/100
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.2834 - dice_coef_infection: 0.7352 - iou_coef_infection: 0.6090 - precision_infection: 0.7666 - recall_infection: 0.7511 - hausdorff95_infection: 28.3703 - specificity_infection: 0.9982 - accuracy_infection: 0.9963 - f1_infection: 0.8529 - val_loss: 0.4207 - val_dice_coef_infection: 0.6492 - val_iou_coef_infection: 0.6253 - val_precision_infection: 0.9865 - val_recall_infection: 0.6263 - val_hausdorff95_infection: 112.1284 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9943 - val_f1_infection: 0.8222
# Epoch 61/100
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.3045 - dice_coef_infection: 0.7178 - iou_coef_infection: 0.5919 - precision_infection: 0.7666 - recall_infection: 0.7299 - hausdorff95_infection: 31.7697 - specificity_infection: 0.9982 - accuracy_infection: 0.9962 - f1_infection: 0.8457 - val_loss: 0.4435 - val_dice_coef_infection: 0.6350 - val_iou_coef_infection: 0.6140 - val_precision_infection: 0.9788 - val_recall_infection: 0.6143 - val_hausdorff95_infection: 115.3181 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9937 - val_f1_infection: 0.8203
# Epoch 62/100
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 228s 199ms/step - loss: 0.3239 - dice_coef_infection: 0.6980 - iou_coef_infection: 0.5718 - precision_infection: 0.7438 - recall_infection: 0.7201 - hausdorff95_infection: 30.6884 - specificity_infection: 0.9982 - accuracy_infection: 0.9962 - f1_infection: 0.8390 - val_loss: 0.4268 - val_dice_coef_infection: 0.6430 - val_iou_coef_infection: 0.6188 - val_precision_infection: 0.9887 - val_recall_infection: 0.6194 - val_hausdorff95_infection: 109.5603 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9937 - val_f1_infection: 0.8185
# Epoch 63/100
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 229s 200ms/step - loss: 0.2875 - dice_coef_infection: 0.7330 - iou_coef_infection: 0.6046 - precision_infection: 0.7687 - recall_infection: 0.7413 - hausdorff95_infection: 29.0967 - specificity_infection: 0.9984 - accuracy_infection: 0.9964 - f1_infection: 0.8517 - val_loss: 0.4371 - val_dice_coef_infection: 0.6404 - val_iou_coef_infection: 0.6156 - val_precision_infection: 0.9691 - val_recall_infection: 0.6180 - val_hausdorff95_infection: 110.0370 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9933 - val_f1_infection: 0.8239
# Epoch 64/100
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 229s 201ms/step - loss: 0.2799 - dice_coef_infection: 0.7396 - iou_coef_infection: 0.6112 - precision_infection: 0.7605 - recall_infection: 0.7612 - hausdorff95_infection: 27.1156 - specificity_infection: 0.9982 - accuracy_infection: 0.9964 - f1_infection: 0.8538 - val_loss: 0.4346 - val_dice_coef_infection: 0.6298 - val_iou_coef_infection: 0.6115 - val_precision_infection: 0.9926 - val_recall_infection: 0.6119 - val_hausdorff95_infection: 118.8496 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9939 - val_f1_infection: 0.8127
# Epoch 65/100
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 229s 201ms/step - loss: 0.2791 - dice_coef_infection: 0.7393 - iou_coef_infection: 0.6135 - precision_infection: 0.7664 - recall_infection: 0.7568 - hausdorff95_infection: 26.1274 - specificity_infection: 0.9982 - accuracy_infection: 0.9964 - f1_infection: 0.8553 - val_loss: 0.4347 - val_dice_coef_infection: 0.6399 - val_iou_coef_infection: 0.6171 - val_precision_infection: 0.9818 - val_recall_infection: 0.6186 - val_hausdorff95_infection: 115.4966 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9938 - val_f1_infection: 0.8197
# Epoch 66/100
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 229s 201ms/step - loss: 0.3112 - dice_coef_infection: 0.7153 - iou_coef_infection: 0.5880 - precision_infection: 0.7751 - recall_infection: 0.7204 - hausdorff95_infection: 30.5140 - specificity_infection: 0.9983 - accuracy_infection: 0.9962 - f1_infection: 0.8425 - val_loss: 0.4250 - val_dice_coef_infection: 0.6460 - val_iou_coef_infection: 0.6225 - val_precision_infection: 0.9661 - val_recall_infection: 0.6233 - val_hausdorff95_infection: 112.5242 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9941 - val_f1_infection: 0.8300
# Epoch 67/100
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 229s 201ms/step - loss: 0.2781 - dice_coef_infection: 0.7389 - iou_coef_infection: 0.6157 - precision_infection: 0.7705 - recall_infection: 0.7553 - hausdorff95_infection: 26.0693 - specificity_infection: 0.9983 - accuracy_infection: 0.9967 - f1_infection: 0.8566 - val_loss: 0.3888 - val_dice_coef_infection: 0.6606 - val_iou_coef_infection: 0.6347 - val_precision_infection: 0.9749 - val_recall_infection: 0.6363 - val_hausdorff95_infection: 106.9481 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9948 - val_f1_infection: 0.8300
# Epoch 68/100
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 229s 201ms/step - loss: 0.2665 - dice_coef_infection: 0.7512 - iou_coef_infection: 0.6298 - precision_infection: 0.7664 - recall_infection: 0.7692 - hausdorff95_infection: 26.8938 - specificity_infection: 0.9983 - accuracy_infection: 0.9966 - f1_infection: 0.8656 - val_loss: 0.3911 - val_dice_coef_infection: 0.6628 - val_iou_coef_infection: 0.6343 - val_precision_infection: 0.9651 - val_recall_infection: 0.6368 - val_hausdorff95_infection: 97.7836 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9947 - val_f1_infection: 0.8329
# Epoch 69/100
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 229s 201ms/step - loss: 0.2830 - dice_coef_infection: 0.7354 - iou_coef_infection: 0.6122 - precision_infection: 0.7616 - recall_infection: 0.7544 - hausdorff95_infection: 24.4748 - specificity_infection: 0.9982 - accuracy_infection: 0.9966 - f1_infection: 0.8572 - val_loss: 0.4273 - val_dice_coef_infection: 0.6412 - val_iou_coef_infection: 0.6192 - val_precision_infection: 0.9906 - val_recall_infection: 0.6200 - val_hausdorff95_infection: 113.6531 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9942 - val_f1_infection: 0.8177
# Epoch 70/100
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 229s 201ms/step - loss: 0.2998 - dice_coef_infection: 0.7191 - iou_coef_infection: 0.5949 - precision_infection: 0.7604 - recall_infection: 0.7368 - hausdorff95_infection: 27.4219 - specificity_infection: 0.9983 - accuracy_infection: 0.9965 - f1_infection: 0.8481 - val_loss: 0.4137 - val_dice_coef_infection: 0.6410 - val_iou_coef_infection: 0.6200 - val_precision_infection: 0.9884 - val_recall_infection: 0.6210 - val_hausdorff95_infection: 110.0223 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9944 - val_f1_infection: 0.8181
# Epoch 71/100
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 229s 200ms/step - loss: 0.2598 - dice_coef_infection: 0.7565 - iou_coef_infection: 0.6316 - precision_infection: 0.7810 - recall_infection: 0.7713 - hausdorff95_infection: 24.4556 - specificity_infection: 0.9984 - accuracy_infection: 0.9967 - f1_infection: 0.8606 - val_loss: 0.4316 - val_dice_coef_infection: 0.6387 - val_iou_coef_infection: 0.6150 - val_precision_infection: 0.9891 - val_recall_infection: 0.6157 - val_hausdorff95_infection: 109.9162 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9934 - val_f1_infection: 0.8164
# Epoch 72/100
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 229s 200ms/step - loss: 0.2677 - dice_coef_infection: 0.7486 - iou_coef_infection: 0.6241 - precision_infection: 0.7735 - recall_infection: 0.7694 - hausdorff95_infection: 25.3413 - specificity_infection: 0.9983 - accuracy_infection: 0.9967 - f1_infection: 0.8571 - val_loss: 0.4239 - val_dice_coef_infection: 0.6349 - val_iou_coef_infection: 0.6129 - val_precision_infection: 0.9833 - val_recall_infection: 0.6150 - val_hausdorff95_infection: 110.7834 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9937 - val_f1_infection: 0.8162
# 🛑 Early stopping at epoch 72
# ✅ Total training time: 16464.56 seconds (274.41 minutes)

# %% [markdown]
# ## Plotting the performance metrics

# %%
plt.plot(history.history['dice_coef_infection'])
plt.plot(history.history['val_dice_coef_infection'])
plt.title('dice_coef_infection vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Dice_coef')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# %%
plt.plot(history.history['iou_coef_infection'])
plt.plot(history.history['val_iou_coef_infection'])
plt.title('iou_coef_infection vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Iou_coef')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Val'], loc = 'upper right')
plt.show()

# %% [markdown]
# ## Using our trained model for prediction

# %%
import numpy as np
import time

# Start timer (high precision)
start_time = time.perf_counter()

# Evaluate the model on the validation generator
results = model.evaluate(val_gen, verbose=1)

# End timer
end_time = time.perf_counter()

# Calculate evaluation time
eval_time = end_time - start_time

# Print metric names with results
print("\n===== Validation Metrics =====")
for name, value in zip(model.metrics_names, results):
    print(f"{name}: {value:.6f}")

print(f"\nEvaluation Time: {eval_time:.8f} seconds\n")
# Out:
# 128/128 [==============================] - 9s 68ms/step - loss: 0.3269 - dice_coef_infection: 0.7269 - iou_coef_infection: 0.6919 - precision_infection: 0.9719 - recall_infection: 0.7049 - hausdorff95_infection: 67.9757 - specificity_infection: 0.9998 - accuracy_infection: 0.9962 - f1_infection: 0.8580
#
# ===== Validation Metrics =====
# loss: 0.326938
# dice_coef_infection: 0.726930
# iou_coef_infection: 0.691858
# precision_infection: 0.971875
# recall_infection: 0.704930
# hausdorff95_infection: 67.975670
# specificity_infection: 0.999801
# accuracy_infection: 0.996192
# f1_infection: 0.858014
#
# Evaluation Time: 8.76438363 seconds

# %%
import matplotlib.pyplot as plt
import numpy as np

# Run inference if not already done
predicted = model.predict(lung_test)

# Selected indices to visualize (744 as 1st, 280 as 2nd, 230 as 3rd)
selected_indices = [744, 280, 230]
n_samples = len(selected_indices)

# Mapping indices to custom names
name_mapping = {
    0: ("Image1_Covid", "GT1_Covid", "Predict1_Covid_DSEG_Unet"),  # Index 744
    1: ("Image2_Covid", "GT2_Covid", "Predict2_Covid_DSEG_Unet"),  # Index 280
    2: ("Image3_Covid", "GT3_Covid", "Predict3_Covid_DSEG_Unet")   # Index 230
}

# Plot
for j, i in enumerate(selected_indices):
    lung_img = lung_test[i][..., 0].astype(np.float32)
    gt_infect = (infect_test[i][..., 0] > 0.5).astype(np.float32)
    pred_infect = predicted[i][..., 0].astype(np.float32)

    # Normalize lung image
    if lung_img.max() > lung_img.min():
        lung_img = (lung_img - lung_img.min()) / (lung_img.max() - lung_img.min())
    lung_img = np.clip(lung_img, 0, 1)
    pred_infect = np.clip(pred_infect, 0, 1)

    # Get custom names for this index
    input_name, gt_name, pred_name = name_mapping[j]

    # Save Original Lung
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{input_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

    # Save Ground Truth Infection
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.imshow(gt_infect, cmap='Reds', alpha=0.6)
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{gt_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

    # Save Predicted Infection
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.imshow(pred_infect, cmap='Reds', alpha=0.6)
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{pred_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

print("Separate JPEG files saved for input images (Image1_Covid, Image2_Covid, Image3_Covid), "
      "ground truths (GT1_Covid, GT2_Covid, GT3_Covid), and predictions "
      "(Predict1_Covid_DSEG_Unet, Predict2_Covid_DSEG_Unet, Predict3_Covid_DSEG_Unet).")
# Out:
# Separate JPEG files saved for input images (Image1_Covid, Image2_Covid, Image3_Covid), ground truths (GT1_Covid, GT2_Covid, GT3_Covid), and predictions (Predict1_Covid_DSEG_Unet, Predict2_Covid_DSEG_Unet, Predict3_Covid_DSEG_Unet).
