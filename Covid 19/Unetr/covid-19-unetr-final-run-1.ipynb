# %% [markdown]
# ## Importing important libraries

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import nibabel as nib #for loading nii files
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf #for deep learning

# %% [markdown]
# ## Reading the metadata

# %%
data = pd.read_csv('../input/covid19-ct-scans/metadata.csv')
data.head()
# Out:
#                                              ct_scan  \
# 0  ../input/covid19-ct-scans/ct_scans/coronacases...
# 1  ../input/covid19-ct-scans/ct_scans/coronacases...
# 2  ../input/covid19-ct-scans/ct_scans/coronacases...
# 3  ../input/covid19-ct-scans/ct_scans/coronacases...
# 4  ../input/covid19-ct-scans/ct_scans/coronacases...
#
#                                            lung_mask  \
# 0  ../input/covid19-ct-scans/lung_mask/coronacase...
# 1  ../input/covid19-ct-scans/lung_mask/coronacase...
# 2  ../input/covid19-ct-scans/lung_mask/coronacase...
# 3  ../input/covid19-ct-scans/lung_mask/coronacase...
# 4  ../input/covid19-ct-scans/lung_mask/coronacase...
#
#                                       infection_mask  \
# 0  ../input/covid19-ct-scans/infection_mask/coron...
# 1  ../input/covid19-ct-scans/infection_mask/coron...
# 2  ../input/covid19-ct-scans/infection_mask/coron...
# 3  ../input/covid19-ct-scans/infection_mask/coron...
# 4  ../input/covid19-ct-scans/infection_mask/coron...
#
#                              lung_and_infection_mask
# 0  ../input/covid19-ct-scans/lung_and_infection_m...
# 1  ../input/covid19-ct-scans/lung_and_infection_m...
# 2  ../input/covid19-ct-scans/lung_and_infection_m...
# 3  ../input/covid19-ct-scans/lung_and_infection_m...
# 4  ../input/covid19-ct-scans/lung_and_infection_m...

# %% [markdown]
# ## Defining function for readiing .nii files

# %%
def read_nii(filepath):
    '''
    Reads .nii file and returns pixel array
    '''
    ct_scan = nib.load(filepath)
    array   = ct_scan.get_fdata()
    array   = np.rot90(np.array(array))
    return(array)

# %% [markdown]
# ## Reading the chest ct scan data

# %%
# Read sample
sample_ct   = read_nii(data.loc[2,'ct_scan'])
sample_lung = read_nii(data.loc[2,'lung_mask'])
sample_infe = read_nii(data.loc[2,'infection_mask'])
sample_all  = read_nii(data.loc[2,'lung_and_infection_mask'])

# %% [markdown]
# ## Plotting the sample images

# %%
fig = plt.figure(figsize = (18,15))
plt.subplot(1,4,1)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.title('Original Image')

plt.subplot(1,4,2)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_lung[..., 150],alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung Mask')

plt.subplot(1,4,3)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_infe[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Infection Mask')

plt.subplot(1,4,4)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_all[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung and Infection Mask')
# Out:
# Text(0.5, 1.0, 'Lung and Infection Mask')

# %% [markdown]
# ## Converting the data into array for training model

# %%
import numpy as np
import cv2
import random
from scipy.ndimage import rotate, shift, zoom

lungs = []
infections = []
case_ids = []
img_size = 320

# ----------- Load and Resize Data -----------
for case_index in range(len(data)):
    ct = read_nii(data['ct_scan'][case_index])
    infect = read_nii(data['infection_mask'][case_index])

    for slice_index in range(ct.shape[0]):
        lung_img = cv2.resize(ct[slice_index], dsize=(img_size, img_size)).astype('float32')
        infec_img = cv2.resize(infect[slice_index], dsize=(img_size, img_size)).astype('float32')

        lungs.append(lung_img[..., np.newaxis])
        infections.append(infec_img[..., np.newaxis])
        case_ids.append(case_index)

# %%
import numpy as np

# case_ids should be a NumPy array telling which case each slice belongs to
# Convert and binarize
lungs = np.array(lungs, dtype=np.float32)
infections = (np.array(infections, dtype=np.uint8) > 0.5).astype(np.uint8)
case_ids = np.array(case_ids)

# %% [markdown]
# ## Performing test and train split

# %%
# ----------- Case-wise Split -----------
unique_cases = np.unique(case_ids)
train_cases = np.append(unique_cases[4:12], unique_cases[12:20])
temp_cases = unique_cases[2:4]
val_cases = unique_cases[:2]

train_mask = np.isin(case_ids, train_cases)
temp_mask = np.isin(case_ids, temp_cases)
val_mask = np.isin(case_ids, val_cases)

lung_train = lungs[train_mask]
infect_train = infections[train_mask]
lung_temp = lungs[temp_mask]
infect_temp = infections[temp_mask]
lung_test = lungs[val_mask]
infect_test = infections[val_mask]

print(f"✅ Train: {lung_train.shape[0]} slices from {len(train_cases)} cases")
print(f"✅ Validation: {lung_temp.shape[0]} slices from {len(temp_cases)} cases")
print(f"✅ Test: {lung_test.shape[0]} slices from {len(val_cases)} cases")

# ----------- Augmentation -----------
def augment_image(img, mask):
    if random.random() < 0.5:
        img = np.fliplr(img)
        mask = np.fliplr(mask)
    if random.random() < 0.5:
        img = np.flipud(img)
        mask = np.flipud(mask)

    angle = random.uniform(-15, 15)
    img = rotate(img, angle, reshape=False, order=1, mode='nearest')
    mask = rotate(mask, angle, reshape=False, order=0, mode='nearest')

    shift_val = np.random.uniform(-0.1, 0.1, size=2) * img.shape[:2]
    img = shift(img, shift=(*shift_val, 0), order=1, mode='nearest')
    mask = shift(mask, shift=(*shift_val, 0), order=0, mode='nearest')

    zoom_factor = random.uniform(0.9, 1.1)
    img = zoom(img, (zoom_factor, zoom_factor, 1), order=1)
    mask = zoom(mask, (zoom_factor, zoom_factor, 1), order=0)

    return fix_shape(img), fix_shape(mask)

def fix_shape(arr, target_size=(320, 320)):
    h, w, c = arr.shape
    th, tw = target_size
    dh = th - h
    dw = tw - w
    if dh > 0 or dw > 0:
        pad_h = (max(dh // 2, 0), max(dh - dh // 2, 0))
        pad_w = (max(dw // 2, 0), max(dw - dw // 2, 0))
        arr = np.pad(arr, (pad_h, pad_w, (0, 0)), mode='constant')
    arr = arr[:th, :tw, :]
    return arr.astype('float32')

# ----------- Apply Augmentation -----------
aug_lung_train = []
aug_infect_train = []

for i in range(len(lung_train)):
    img, mask = augment_image(lung_train[i], infect_train[i])
    aug_lung_train.append(img)
    aug_infect_train.append(mask)

lung_train = np.stack(aug_lung_train)
infect_train = np.stack(aug_infect_train)

# Final Binarization
infect_train = (infect_train > 0.5).astype(np.uint8)
infect_test = (infect_test > 0.5).astype(np.uint8)

print(f"✅ Augmented training shape: {lung_train.shape}")
print("✅ All preprocessing complete.")
# Out:
# ✅ Train: 9143 slices from 16 cases
# ✅ Validation: 1024 slices from 2 cases
# ✅ Test: 1024 slices from 2 cases
# ✅ Augmented training shape: (9143, 320, 320, 1)
# ✅ All preprocessing complete.

# %%
import tensorflow as tf
from tensorflow.keras import backend as K
import numpy as np
from scipy.spatial import cKDTree

smooth = 1.0

# Binary Dice coefficient (soft - commonly used during training)
def dice_coef_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# Binary IoU coefficient (soft)
def iou_coef_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# Soft Precision
def precision_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + smooth) / (K.sum(y_pred_f) + smooth)

# Soft Recall (Sensitivity)
def recall_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + smooth) / (K.sum(y_true_f) + smooth)

# Soft Specificity
def specificity_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    tn = K.sum((1 - y_true_f) * (1 - y_pred_f))
    fp = K.sum((1 - y_true_f) * y_pred_f)
    return (tn + smooth) / (tn + fp + smooth)

# Soft Accuracy
def accuracy_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    tp = K.sum(y_true_f * y_pred_f)
    tn = K.sum((1 - y_true_f) * (1 - y_pred_f))
    total = K.cast(K.shape(y_true_f)[0], 'float32')
    return (tp + tn + smooth) / (total + smooth)

# Soft F1-score (harmonic mean of precision & recall - very close to Dice, standard in many repos)
def f1_infection(y_true, y_pred):
    precision = precision_infection(y_true, y_pred)
    recall    = recall_infection(y_true, y_pred)
    return (2. * precision * recall + smooth) / (precision + recall + smooth)

# Hausdorff Distance 95 % (robust & most commonly used in medical imaging challenges)
# Lower = better. Returns the mean HD95 over the batch.
def _calculate_hd95(y_true, y_pred):
    hd_list = []
    for i in range(y_true.shape[0]):
        # Hard threshold at 0.5 (standard for evaluation metrics)
        gt = np.squeeze(y_true[i]) > 0.5
        pred = np.squeeze(y_pred[i]) > 0.5

        gt_pts = np.argwhere(gt)
        pred_pts = np.argwhere(pred)

        # Cases with empty masks
        if gt_pts.shape[0] == 0 and pred_pts.shape[0] == 0:
            hd_list.append(0.0)
            continue
        if gt_pts.shape[0] == 0 or pred_pts.shape[0] == 0:
            hd_list.append(400.0)  # large penalty - adjust to your image diagonal if needed (e.g. ~362 for 256×256, ~724 for 512×512)
            continue

        # Directed distances
        dist_gt_to_pred = cKDTree(pred_pts).query(gt_pts)[0]
        dist_pred_to_gt = cKDTree(gt_pts).query(pred_pts)[0]

        hd95 = max(
            np.percentile(dist_gt_to_pred, 95),
            np.percentile(dist_pred_to_gt, 95)
        )
        hd_list.append(hd95)

    return np.mean(hd_list, dtype=np.float32)

def hausdorff95_infection(y_true, y_pred):
    hd = tf.numpy_function(_calculate_hd95, [y_true, y_pred], tf.float32)
    hd.set_shape(())
    return hd

# Optional: KL Divergence (you already had this)
kld = tf.keras.losses.KLDivergence()

# %%
from tensorflow.keras.losses import BinaryCrossentropy

def loss_f(y_true, y_pred):
    bce = BinaryCrossentropy()
    return dice_loss(y_true, y_pred) + bce(y_true, y_pred) 

def loss_e(y_true, y_pred):
    bce = BinaryCrossentropy()
    return dice_loss(y_true, y_pred)  + kld(y_true, y_pred)
    
def dice_loss(y_true, y_pred):
    return 1. - dice_coef_infection(y_true, y_pred)

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Multiply, Conv2D, DepthwiseConv2D, Dense, Flatten, MaxPooling2D, UpSampling2D, concatenate, Activation, LayerNormalization, Add, Dropout, Conv2DTranspose, multiply, Reshape, GlobalAveragePooling2D, Permute, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Concatenate

def activation_block(x):
    x = Activation("gelu")(x)
    return LayerNormalization()(x)

def conv_stem(x, filters: int, patch_size: int):
    x = Conv2D(filters, kernel_size=patch_size,padding='same', strides=patch_size)(x)
    return activation_block(x)

def vector_block(xyz, cmf, red):
    # red means reduction
    # cmf means filters, denotes vector size
    opt1 = conv_stem(xyz, cmf, red)
    opt2 = conv_stem(xyz, cmf, red)
    
    o1 = GlobalAveragePooling2D()(opt1)
    o2 = GlobalAveragePooling2D()(opt2)

    o5 = concatenate([o1, o2], -1)
    return o5

def mlp_feature(vect, cmf):
    oo = Flatten()(vect)
    o6 = Dense(cmf, activation='gelu')(oo)
    o6 = Dropout(0.2)(o6)
    o6 = Dense(cmf * 2, activation='gelu')(o6)

    o6 = Reshape((1, cmf * 2))(o6)
    o7 = Permute((2, 1))(o6)

    o8 = multiply([o6, o7])
    
    o8 = Lambda(lambda x: tf.expand_dims(x, -1))(o8)
    
    o8 = Reshape((cmf, cmf, 4))(o8)

    return o8

def frz_block(xyz):
    shape = xyz.shape
    a1, a2, a3, a4 = shape[0], shape[1], shape[2], shape[3]
    cmf = a2
    o5 = vector_block(xyz, cmf, 5)
    o7 = mlp_feature(o5, cmf)

    o7 = concatenate([o7, xyz, o7], -1)
    return o7

def up_frz(x1, x2, n_filters):
    # Upsample x1 using Conv2DTranspose
    x1 = Conv2DTranspose(n_filters * 4, 3, strides=2, activation='gelu', padding="same")(x1)
    
    # Apply Conv2D to x2
    x2 = Conv2D(n_filters * 2, 3, activation='gelu', padding="same")(x2)
    
    # Apply attention mechanism
    x = concatenate([x1, x2])
    
    # Apply Dropout for regularization
    x = Dropout(0.3)(x)
    
    return x

# %%
import numpy as np
import tensorflow as tf
import tensorflow_addons as tfa
import keras
import keras.backend as K
from keras.layers import (Layer, BatchNormalization, LayerNormalization, Conv2D, Conv2DTranspose, Embedding, 
    Activation, Dense, Dropout, MultiHeadAttention, add, Input, concatenate, GlobalAveragePooling1D)
from keras.models import Model

def mlp(x, hidden_units, dropout_rate):
    if not isinstance(hidden_units, list): hidden_units = [hidden_units]
    for units in hidden_units:
        x = Dense(units, activation=tf.nn.gelu)(x)
        x = Dropout(dropout_rate)(x)
    return x

class Patches(Layer):
    def __init__(self, patch_size, **kwargs):
        super(Patches, self).__init__(**kwargs)
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding='VALID',
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

    def compute_output_shape(self, input_shape):
        batch_size, height, width, channels = input_shape
        patch_height = height // self.patch_size
        patch_width = width // self.patch_size
        patch_dim = channels * (self.patch_size ** 2)
        return (batch_size, patch_height * patch_width, patch_dim)

    def get_config(self):  # Add configuration for saving
        config = super(Patches, self).get_config()
        config.update({
            'patch_size': self.patch_size
        })
        return config



class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim, **kwargs):
        super().__init__(**kwargs)
        self.num_patches = num_patches
        self.projection_dim = projection_dim
        self.projection = layers.Dense(projection_dim)
        self.position_embedding = layers.Embedding(input_dim=num_patches, output_dim=projection_dim)

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

    # Add this method
    def get_config(self):
        config = super().get_config()
        config.update({
            'num_patches': self.num_patches,
            'projection_dim': self.projection_dim,
        })
        return config



def normalization(input_tensor, normalization, name=None):

    if normalization=='batch':
        return(BatchNormalization(name=None if name is None else name + '_batchnorm')(input_tensor))
    elif normalization=='layer':
        return(LayerNormalization(epsilon=1e-6, name=None if name is None else name + '_layernorm')(input_tensor))
    elif normalization=='group':
        return(tfa.layers.GroupNormalization(groups=8, name=None if name is None else name + '_groupnorm')(input_tensor))
    elif normalization == None:
        return input_tensor
    else:
        raise ValueError('Invalid normalization')

def conv_norm_act(input_tensor, filters, kernel_size , norm_type='batch', act_type='relu', dilation=1):
    '''
    Conv2d + Normalization(norm_type:str) + Activation(act_type:str)
    '''
    output_tensor = Conv2D(filters, kernel_size, padding='same', dilation_rate=(dilation, dilation), use_bias=False if norm_type is not None else True, kernel_initializer='he_normal')(input_tensor)
    output_tensor = normalization(output_tensor, normalization=norm_type)
    if act_type is not None: output_tensor = Activation(act_type)(output_tensor)

    return output_tensor

def conv2d_block(input_tensor, filters, kernel_size, 
                norm_type, use_residual, act_type='relu',
                double_features = False, dilation=[1, 1], name=None):

    x = Conv2D(filters, kernel_size, padding='same', dilation_rate=dilation[0], use_bias=False, kernel_initializer='he_normal', name=None if name is None else name + '_conv2d_0')(input_tensor)
    x = normalization(x, norm_type, name=None if name is None else name + '_0')
    x = Activation(act_type, name=None if name is None else name + act_type + '_0')(x)

    if double_features:
        filters *= 2

    x = Conv2D(filters, kernel_size, padding='same', dilation_rate=dilation[1], use_bias=False, kernel_initializer='he_normal', name=None if name is None else name + '_conv2d_1')(x)
    x = normalization(x, norm_type, name=None if name is None else name + '_1')

    if use_residual:
        if K.int_shape(input_tensor)[-1] != K.int_shape(x)[-1]:
            shortcut = Conv2D(filters, kernel_size=1, padding='same', use_bias=False, kernel_initializer='he_normal', name=None if name is None else name + '_shortcut_conv2d')(input_tensor)
            shortcut = normalization(shortcut, norm_type, name=None if name is None else name + '_shortcut')
            x = add([x, shortcut])
        else:
            x = add([x, input_tensor])

    x = Activation(act_type, name=None if name is None else name + act_type + '_0')(x)

    return x

def deconv_conv_block(x,
                      filters_list: list,
                      kernel_size,
                      norm_type,
                      act_type,
                      ):
    '''
    Corresponding to the blue block in the UNETR architecture diagram
    '''
    for filts in filters_list:
        x = Conv2DTranspose(filts, 2, (2, 2), kernel_initializer='he_normal')(x)
        x = conv_norm_act(x, filts, kernel_size, norm_type, act_type)
    return x

def conv_deconv_block(x,
                      filters,
                      kernel_size,
                      norm_type,
                      use_residual,
                      act_type,
                      ):
    '''
    Corresponding to the yellow + green block in the UNETR architecture diagram
    '''
    x = conv2d_block(x, filters, kernel_size, norm_type, use_residual, act_type)
    x = Conv2DTranspose(filters // 2, 2, (2, 2), kernel_initializer='he_normal')(x)
    return x


def create_vit(x,
               patch_size,
               num_patches,
               projection_dim,
               num_heads,
               transformer_units,
               transformer_layers,
               dropout_rate,
               extract_layers,
               ):
    skip_connections = []

    # Create patches.
    patches = Patches(patch_size)(x)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for layer in range(transformer_layers):
        # Layer normalization 1.
        x1 = LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim//num_heads, dropout=dropout_rate
        )(x1, x1)
        # Skip connection 1.
        x2 = add([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=dropout_rate)
        # Skip connection 2.
        encoded_patches = add([x3, x2])
        if layer + 1 in extract_layers:
            skip_connections.append(encoded_patches)

    return skip_connections


def build_model(
    # ↓ Base arguments
    input_shape,
    class_nums,
    # ↓ ViT arguments
    patch_size,
    projection_dim,
    num_heads,
    transformer_units,
    transformer_layers,
    extract_layers,
    dropout_rate=0.1,
    # ↓ Conv arguments
    kernel_size=3,
    conv_norm='batch',
    conv_act='relu',
    use_residual=False,
    # ↓ Other arguments
    show_summary=False,
    output_act='sigmoid',
):
    '''
    input_shape: tuple, (height, width, channel) note that this network is used for 2D image segmentation tasks
    class_nums: int, output channels
    patch_size: int, image partition size
    projection_dim: int, projection dimensions in ViT
    num_heads: int, nums of heads for MultiHeadAttention
    transformer_units: list, the number of hidden units of the MLP module in ViT, note that it is in the form of a list, should be [hidden units, projection_dims]
    transformer_layers: int, transformer stacking nums
    extract_layers: list, Determine which layers in ViT should be added to the "skip connection", the default is [3, 6, 9, 12]
    dropout_rate: float, dropout ratio for the ViT part
    kernel_size: int, kernel size for convolution block
    conv_norm: str, The normalization method of the convolutional layer, 'batch' or 'layer' or 'group'
    conv_act: str, activation function for convolution layer
    use_residual: bool, whether the convolution module uses residual connections
    show_summary: bool, whether to show the model overview
    output_act: str, The activation function of the output layer will be determined according to class_nums when 'auto'
      (i.e. 'sigmoid' for binary segmentation task, 'softmax' for multi-class segmentation task)
    '''

    z5_de_filts = 512
    z4_de_filts_list = [512]
    z3_de_filts_list = [512, 256]
    z2_de_filts_list = [512, 256, 128]
    z1_de_filts_list = [512, 256, 128, 64]
    z45_conv_filts = 512
    z34_conv_filts = 256
    z23_conv_filts = 128
    z12_conv_filts = 64
    z01_conv_filts = 32

    if output_act == 'auto':
        output_act = 'sigmoid' if class_nums == 1 else 'softmax'

    assert input_shape[0] == input_shape[1] and input_shape[0] % patch_size == 0
    num_patches = (input_shape[0] * input_shape[1]) // (patch_size ** 2)

    inputs = Input(input_shape)
    z0 = inputs

    z1, z2, z3, z4, z5 = create_vit(
        z0,
        patch_size,
        num_patches,
        projection_dim,
        num_heads,
        transformer_units,
        transformer_layers,
        dropout_rate,
        extract_layers
    )

    z1 = tf.reshape(z1, (-1, input_shape[0] // patch_size, input_shape[1] // patch_size, projection_dim))
    z2 = tf.reshape(z2, (-1, input_shape[0] // patch_size, input_shape[1] // patch_size, projection_dim))
    z3 = tf.reshape(z3, (-1, input_shape[0] // patch_size, input_shape[1] // patch_size, projection_dim))
    z4 = tf.reshape(z4, (-1, input_shape[0] // patch_size, input_shape[1] // patch_size, projection_dim))
    z5 = tf.reshape(z5, (-1, input_shape[0] // patch_size, input_shape[1] // patch_size, projection_dim))

    z5 = Conv2DTranspose(z5_de_filts, 2, (2, 2), kernel_initializer='he_normal')(z5)
    z4 = deconv_conv_block(z4, z4_de_filts_list, kernel_size, conv_norm, conv_act)
    z4 = concatenate([z4, z5])
    z4 = conv_deconv_block(z4, z45_conv_filts, kernel_size, conv_norm, use_residual, conv_act)
    z3 = deconv_conv_block(z3, z3_de_filts_list, kernel_size, conv_norm, conv_act)
    z3 = concatenate([z3, z4])
    z3 = conv_deconv_block(z3, z34_conv_filts, kernel_size, conv_norm, use_residual, conv_act)
    z2 = deconv_conv_block(z2, z2_de_filts_list, kernel_size, conv_norm, conv_act)
    z2 = concatenate([z2, z3])
    z2 = conv_deconv_block(z2, z23_conv_filts, kernel_size, conv_norm, use_residual, conv_act)
    z1 = deconv_conv_block(z1, z1_de_filts_list, kernel_size, conv_norm, conv_act)
    z1 = concatenate([z1, z2])
    z1 = conv_deconv_block(z1, z12_conv_filts, kernel_size, conv_norm, use_residual, conv_act)
    z0 = conv2d_block(z0, z01_conv_filts, kernel_size, conv_norm, use_residual, conv_act)
    z0 = concatenate([z0, z1])
    z0 = conv2d_block(z0, z01_conv_filts, kernel_size, conv_norm, use_residual, conv_act)

    outputs = Conv2D(class_nums, 1, activation=output_act)(z0)

    model = Model(inputs=inputs, outputs=outputs)

    if show_summary:
        model.summary()

    return model
    
model = build_model(
    input_shape=(320, 320, 1), 
    class_nums=1,
    patch_size=32,
    projection_dim=768,
    num_heads=1,
    transformer_units=[3072, 768],
    transformer_layers=10,
    extract_layers=[2, 4, 6, 8, 10],
    dropout_rate=0.0,
    kernel_size=3,
    conv_norm='batch',
    conv_act='relu',
    use_residual=False,
    show_summary=False,  # Turn on for debugging
    output_act='sigmoid'
)

# %%
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2_as_graph

def get_flops(model):
    """Calculate Floating Point Operations (FLOPs) of a Keras model in TensorFlow 2.x."""
    # Convert Keras model to a TensorFlow function
    concrete_func = tf.function(lambda inputs: model(inputs))
    concrete_func = concrete_func.get_concrete_function(
        tf.TensorSpec([1] + list(model.input_shape[1:]), model.input.dtype)
    )

    # Convert to frozen graph
    frozen_func, _ = convert_variables_to_constants_v2_as_graph(concrete_func)

    # Compute FLOPs
    flops = tf.compat.v1.profiler.profile(
        frozen_func.graph,
        options=tf.compat.v1.profiler.ProfileOptionBuilder.float_operation(),
    )

    return flops.total_float_ops

# Compute FLOPs
flops = get_flops(model)
print(f"Total FLOPs: {flops / 1e9:.2f} GFLOPs")  # Convert to GFLOPs

from tensorflow.keras.optimizers import Adam

optimizer = Adam(learning_rate=1e-3)
model.compile(optimizer=optimizer, loss=loss_f, metrics=[dice_coef_infection, iou_coef_infection, precision_infection, recall_infection, hausdorff95_infection, specificity_infection, accuracy_infection, f1_infection])

# Model summary
model.summary()
# Out:
# Total FLOPs: 64.54 GFLOPs
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 320, 320, 1) 0
# __________________________________________________________________________________________________
# patches (Patches)               (None, None, 1024)   0           input_1[0][0]
# __________________________________________________________________________________________________
# patch_encoder (PatchEncoder)    (None, 100, 768)     864000      patches[0][0]
# __________________________________________________________________________________________________
# layer_normalization (LayerNorma (None, 100, 768)     1536        patch_encoder[0][0]
# __________________________________________________________________________________________________
# multi_head_attention (MultiHead (None, 100, 768)     2362368     layer_normalization[0][0]
#                                                                  layer_normalization[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 100, 768)     0           multi_head_attention[0][0]
#                                                                  patch_encoder[0][0]
# __________________________________________________________________________________________________
# layer_normalization_1 (LayerNor (None, 100, 768)     1536        add[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100, 3072)    2362368     layer_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 100, 3072)    0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 100, 768)     2360064     dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 100, 768)     0           dense_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 100, 768)     0           dropout_1[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# layer_normalization_2 (LayerNor (None, 100, 768)     1536        add_1[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_1 (MultiHe (None, 100, 768)     2362368     layer_normalization_2[0][0]
#                                                                  layer_normalization_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 100, 768)     0           multi_head_attention_1[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# layer_normalization_3 (LayerNor (None, 100, 768)     1536        add_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 100, 3072)    2362368     layer_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 100, 3072)    0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 100, 768)     2360064     dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 100, 768)     0           dense_4[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 100, 768)     0           dropout_3[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# layer_normalization_4 (LayerNor (None, 100, 768)     1536        add_3[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_2 (MultiHe (None, 100, 768)     2362368     layer_normalization_4[0][0]
#                                                                  layer_normalization_4[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 100, 768)     0           multi_head_attention_2[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# layer_normalization_5 (LayerNor (None, 100, 768)     1536        add_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 100, 3072)    2362368     layer_normalization_5[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 100, 3072)    0           dense_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 100, 768)     2360064     dropout_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 100, 768)     0           dense_6[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 100, 768)     0           dropout_5[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# layer_normalization_6 (LayerNor (None, 100, 768)     1536        add_5[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_3 (MultiHe (None, 100, 768)     2362368     layer_normalization_6[0][0]
#                                                                  layer_normalization_6[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 100, 768)     0           multi_head_attention_3[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# layer_normalization_7 (LayerNor (None, 100, 768)     1536        add_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 100, 3072)    2362368     layer_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 100, 3072)    0           dense_7[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 100, 768)     2360064     dropout_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 100, 768)     0           dense_8[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 100, 768)     0           dropout_7[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# layer_normalization_8 (LayerNor (None, 100, 768)     1536        add_7[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_4 (MultiHe (None, 100, 768)     2362368     layer_normalization_8[0][0]
#                                                                  layer_normalization_8[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 100, 768)     0           multi_head_attention_4[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# layer_normalization_9 (LayerNor (None, 100, 768)     1536        add_8[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 100, 3072)    2362368     layer_normalization_9[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 100, 3072)    0           dense_9[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 100, 768)     2360064     dropout_8[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 100, 768)     0           dense_10[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 100, 768)     0           dropout_9[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# layer_normalization_10 (LayerNo (None, 100, 768)     1536        add_9[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_5 (MultiHe (None, 100, 768)     2362368     layer_normalization_10[0][0]
#                                                                  layer_normalization_10[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 100, 768)     0           multi_head_attention_5[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# layer_normalization_11 (LayerNo (None, 100, 768)     1536        add_10[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 100, 3072)    2362368     layer_normalization_11[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 100, 3072)    0           dense_11[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 100, 768)     2360064     dropout_10[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 100, 768)     0           dense_12[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 100, 768)     0           dropout_11[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# layer_normalization_12 (LayerNo (None, 100, 768)     1536        add_11[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_6 (MultiHe (None, 100, 768)     2362368     layer_normalization_12[0][0]
#                                                                  layer_normalization_12[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 100, 768)     0           multi_head_attention_6[0][0]
#                                                                  add_11[0][0]
# __________________________________________________________________________________________________
# layer_normalization_13 (LayerNo (None, 100, 768)     1536        add_12[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 100, 3072)    2362368     layer_normalization_13[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 100, 3072)    0           dense_13[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 100, 768)     2360064     dropout_12[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 100, 768)     0           dense_14[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 100, 768)     0           dropout_13[0][0]
#                                                                  add_12[0][0]
# __________________________________________________________________________________________________
# layer_normalization_14 (LayerNo (None, 100, 768)     1536        add_13[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_7 (MultiHe (None, 100, 768)     2362368     layer_normalization_14[0][0]
#                                                                  layer_normalization_14[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 100, 768)     0           multi_head_attention_7[0][0]
#                                                                  add_13[0][0]
# __________________________________________________________________________________________________
# layer_normalization_15 (LayerNo (None, 100, 768)     1536        add_14[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 100, 3072)    2362368     layer_normalization_15[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 100, 3072)    0           dense_15[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 100, 768)     2360064     dropout_14[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 100, 768)     0           dense_16[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 100, 768)     0           dropout_15[0][0]
#                                                                  add_14[0][0]
# __________________________________________________________________________________________________
# layer_normalization_16 (LayerNo (None, 100, 768)     1536        add_15[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_8 (MultiHe (None, 100, 768)     2362368     layer_normalization_16[0][0]
#                                                                  layer_normalization_16[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 100, 768)     0           multi_head_attention_8[0][0]
#                                                                  add_15[0][0]
# __________________________________________________________________________________________________
# layer_normalization_17 (LayerNo (None, 100, 768)     1536        add_16[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 100, 3072)    2362368     layer_normalization_17[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 100, 3072)    0           dense_17[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 100, 768)     2360064     dropout_16[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 100, 768)     0           dense_18[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 100, 768)     0           dropout_17[0][0]
#                                                                  add_16[0][0]
# __________________________________________________________________________________________________
# layer_normalization_18 (LayerNo (None, 100, 768)     1536        add_17[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_9 (MultiHe (None, 100, 768)     2362368     layer_normalization_18[0][0]
#                                                                  layer_normalization_18[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 100, 768)     0           multi_head_attention_9[0][0]
#                                                                  add_17[0][0]
# __________________________________________________________________________________________________
# layer_normalization_19 (LayerNo (None, 100, 768)     1536        add_18[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 100, 3072)    2362368     layer_normalization_19[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 100, 3072)    0           dense_19[0][0]
# __________________________________________________________________________________________________
# tf.reshape_3 (TFOpLambda)       (None, 10, 10, 768)  0           add_15[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 100, 768)     2360064     dropout_18[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 20, 20, 512)  1573376     tf.reshape_3[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 100, 768)     0           dense_20[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 20, 20, 512)  2359296     conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 100, 768)     0           dropout_19[0][0]
#                                                                  add_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 20, 20, 512)  2048        conv2d[0][0]
# __________________________________________________________________________________________________
# tf.reshape_4 (TFOpLambda)       (None, 10, 10, 768)  0           add_19[0][0]
# __________________________________________________________________________________________________
# tf.reshape_2 (TFOpLambda)       (None, 10, 10, 768)  0           add_11[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 20, 20, 512)  0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 20, 20, 512)  1573376     tf.reshape_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 20, 20, 512)  1573376     tf.reshape_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 20, 20, 1024) 0           activation[0][0]
#                                                                  conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 20, 20, 512)  2359296     conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 20, 20, 512)  4718592     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 20, 20, 512)  2048        conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 20, 20, 512)  2048        conv2d_1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_1 (TFOpLambda)       (None, 10, 10, 768)  0           add_7[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 20, 20, 512)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 20, 20, 512)  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 20, 20, 512)  1573376     tf.reshape_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 40, 40, 256)  524544      activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 20, 20, 512)  2359296     activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 20, 20, 512)  2359296     conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 40, 40, 256)  589824      conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 20, 20, 512)  2048        conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 20, 20, 512)  2048        conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 40, 40, 256)  1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 20, 20, 512)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# tf.reshape (TFOpLambda)         (None, 10, 10, 768)  0           add_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 20, 20, 512)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 40, 40, 256)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 40, 40, 256)  524544      activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTran (None, 20, 20, 512)  1573376     tf.reshape[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 40, 40, 256)  524544      activation_7[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 40, 40, 512)  0           activation_4[0][0]
#                                                                  conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 20, 20, 512)  2359296     conv2d_transpose_10[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 40, 40, 256)  589824      conv2d_transpose_7[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 40, 40, 256)  1179648     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 20, 20, 512)  2048        conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 40, 40, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 40, 40, 256)  1024        conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 20, 20, 512)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 40, 40, 256)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 40, 40, 256)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 40, 40, 256)  524544      activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 80, 80, 128)  131200      activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 40, 40, 256)  589824      activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 40, 40, 256)  589824      conv2d_transpose_11[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 80, 80, 128)  147456      conv2d_transpose_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 40, 40, 256)  1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 40, 40, 256)  1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 80, 80, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 40, 40, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 40, 40, 256)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 80, 80, 128)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 80, 80, 128)  131200      activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_12 (Conv2DTran (None, 80, 80, 128)  131200      activation_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 80, 80, 256)  0           activation_9[0][0]
#                                                                  conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 80, 80, 128)  147456      conv2d_transpose_12[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 80, 80, 128)  294912      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 80, 80, 128)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 80, 80, 128)  512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 80, 80, 128)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 80, 80, 128)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_13 (Conv2DTran (None, 160, 160, 64) 32832       activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 80, 80, 128)  147456      activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 160, 160, 64) 36864       conv2d_transpose_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 80, 80, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 160, 160, 64) 256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 80, 80, 128)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 160, 160, 64) 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 160, 160, 64) 32832       activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 160, 160, 128 0           activation_15[0][0]
#                                                                  conv2d_transpose_9[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 160, 160, 64) 73728       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 320, 320, 32) 288         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 160, 160, 64) 256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 320, 320, 32) 128         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 160, 160, 64) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 320, 320, 32) 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 160, 160, 64) 36864       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 320, 320, 32) 9216        activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 160, 160, 64) 256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 320, 320, 32) 128         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 160, 160, 64) 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 320, 320, 32) 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_14 (Conv2DTran (None, 320, 320, 32) 8224        activation_17[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 320, 320, 64) 0           activation_19[0][0]
#                                                                  conv2d_transpose_14[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 320, 320, 32) 18432       concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 320, 320, 32) 128         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 320, 320, 32) 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 320, 320, 32) 9216        activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 320, 320, 32) 128         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 320, 320, 32) 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 320, 320, 1)  33          activation_21[0][0]
# ==================================================================================================
# Total params: 103,171,937
# Trainable params: 103,161,569
# Non-trainable params: 10,368
# __________________________________________________________________________________________________

# %%
# Install required packages
# !pip install openpyxl

# Imports
import openpyxl  # required for reading .xlsx files
import pandas as pd
import tensorflow as tf
import os
import shutil
from tensorflow.keras.callbacks import LearningRateScheduler, ReduceLROnPlateau

# File paths
checkpoint_filepath = '/kaggle/working/checkpoint.h5.keras'
metrics_file = '/kaggle/working/training_metrics.xlsx'
pre_checkpoint_filepath = '/kaggle/input/swinunet-covid19-finalrun-1/checkpoint.h5.keras'
pre_metrics_file = '/kaggle/input/swinunet-covid19-finalrun-1/training_metrics.xlsx'

# Restore checkpoint and metrics if available
if os.path.exists(pre_checkpoint_filepath):
    shutil.copy(pre_checkpoint_filepath, checkpoint_filepath)
    print(f"Restored checkpoint from: {pre_checkpoint_filepath}")

if os.path.exists(pre_metrics_file):
    shutil.copy(pre_metrics_file, metrics_file)
    print(f"Restored metrics file from: {pre_metrics_file}")

# Load last epoch
def load_last_epoch():
    if os.path.exists(metrics_file):
        try:
            df = pd.read_excel(metrics_file, engine='openpyxl')
            if not df.empty and 'epoch' in df.columns:
                return df['epoch'].iloc[-1] + 1
        except Exception as e:
            print(f"⚠️ Could not read metrics file: {e}")
    return 0

last_epoch = load_last_epoch()

# Get best validation loss from previous runs
def get_best_val_loss():
    if os.path.exists(metrics_file):
        try:
            df = pd.read_excel(metrics_file, engine='openpyxl')
            if 'val_loss' in df.columns and not df['val_loss'].isnull().all():
                return df['val_loss'].min()
        except Exception as e:
            print(f"⚠️ Could not read val_loss from metrics file: {e}")
    return float('inf')

best_val_loss = get_best_val_loss()

# Custom model checkpoint
class CustomModelCheckpoint(tf.keras.callbacks.Callback):
    def __init__(self, filepath):
        super().__init__()
        self.filepath = filepath
        self.best_loss = best_val_loss

    def on_epoch_end(self, epoch, logs=None):
        current_loss = logs.get('val_loss')
        if current_loss is not None and current_loss < self.best_loss:
            self.best_loss = current_loss
            self.model.save(self.filepath)
            print(f"✅ Model saved at epoch {epoch + 1} with val_loss: {current_loss:.4f}")

# === Learning Rate Schedule ===
def lr_schedule(epoch, lr):
    return 1e-4 if epoch >= 1 else lr

lr_scheduler = LearningRateScheduler(lr_schedule, verbose=1)

# Logger for Excel
class MetricsLogger(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        df_new = pd.DataFrame([{**logs, 'epoch': epoch}])
        try:
            if os.path.exists(metrics_file):
                df = pd.read_excel(metrics_file, engine='openpyxl')
                df = pd.concat([df, df_new], ignore_index=True)
            else:
                df = df_new
            df.to_excel(metrics_file, index=False, engine='openpyxl')
        except Exception as e:
            print(f"⚠️ Failed to log metrics: {e}")

# Early stopping with patience and saving best weights
class CustomEarlyStopping(tf.keras.callbacks.Callback):
    def __init__(self, patience=20):
        super().__init__()
        self.patience = patience
        self.wait = 0
        self.best_loss = best_val_loss

    def on_epoch_end(self, epoch, logs=None):
        current_loss = logs.get('val_loss')
        if current_loss is None:
            return
        if current_loss < self.best_loss:
            self.best_loss = current_loss
            self.wait = 0
            self.model.save_weights(checkpoint_filepath)
        else:
            self.wait += 1
            if self.wait >= self.patience:
                print(f"🛑 Early stopping at epoch {epoch + 1}")
                self.model.stop_training = True


# Final callbacks list
callbacks = [
    CustomModelCheckpoint(filepath=checkpoint_filepath),
    MetricsLogger(),
    lr_scheduler,
    CustomEarlyStopping(patience=20)
]
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.3-py2.py3-none-any.whl (251 kB)
#      |████████████████████████████████| 251 kB 9.3 MB/s eta 0:00:01
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.3

# %% [markdown]
# ## Training the model

# %%
import time
import os
import pandas as pd
import numpy as np
from tensorflow.keras.utils import Sequence
from tensorflow.keras.models import load_model

EPOCHS = 100

# Record the start time
start_time = time.time()

# === Load last completed epoch from metrics file ===
def load_last_epoch():
    if os.path.exists(pre_metrics_file):
        try:
            df = pd.read_excel(pre_metrics_file, engine='openpyxl')
            if not df.empty and 'epoch' in df.columns:
                return int(df['epoch'].iloc[-1]) + 1
        except Exception as e:
            print(f"⚠️ Failed to read metrics file: {e}")
    return 0

last_epoch = load_last_epoch()

# === Load pretrained weights if available ===
if os.path.exists(pre_checkpoint_filepath):
    print("✅ Checkpoint found. Loading pretrained weights...")
    model.load_weights(pre_checkpoint_filepath)
    print(f"🔁 Resuming training from epoch {last_epoch}")
else:
    print("🆕 No checkpoint found. Starting training from scratch.")
    last_epoch = 0

# === Prepare input and label tensors ===
lung_train = np.asarray(lung_train, dtype=np.float16)
infect_train = np.asarray(infect_train, dtype=np.uint8)

lung_temp = np.asarray(lung_temp, dtype=np.float16)
infect_temp = np.asarray(infect_temp, dtype=np.uint8)

lung_test = np.asarray(lung_test, dtype=np.float16)
infect_test = np.asarray(infect_test, dtype=np.uint8)

# === Data Generator ===
class LungDataGenerator(Sequence):
    def __init__(self, X, Y, batch_size=8, shuffle=True):
        self.X = X
        self.Y = Y
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indices = np.arange(len(X))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.X) / self.batch_size))

    def __getitem__(self, index):
        batch_ids = self.indices[index * self.batch_size:(index + 1) * self.batch_size]
        X_batch = self.X[batch_ids]
        Y_batch = self.Y[batch_ids]
        return np.asarray(X_batch, dtype=np.float16), np.asarray(Y_batch, dtype=np.uint8)

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indices)

# === Create generators ===
train_gen = LungDataGenerator(lung_train, infect_train, batch_size=8)
temp_gen = LungDataGenerator(lung_temp, infect_temp, batch_size=8, shuffle=False)
val_gen = LungDataGenerator(lung_test, infect_test, batch_size=8, shuffle=False)

# === Train the model ===
history = model.fit(
    train_gen,
    validation_data=temp_gen,
    epochs=EPOCHS,
    initial_epoch=last_epoch,
    callbacks=callbacks
)

# === Timing info ===
end_time = time.time()
total_time = end_time - start_time
print(f"✅ Total training time: {total_time:.2f} seconds ({total_time / 60:.2f} minutes)")
# Out:
# 🆕 No checkpoint found. Starting training from scratch.
# Epoch 1/100
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 355s 294ms/step - loss: 1.0396 - dice_coef_infection: 0.0615 - iou_coef_infection: 0.0347 - precision_infection: 0.0482 - recall_infection: 0.2160 - hausdorff95_infection: 156.7782 - specificity_infection: 0.9306 - accuracy_infection: 0.9241 - f1_infection: 0.8389 - val_loss: 1.0566 - val_dice_coef_infection: 0.0205 - val_iou_coef_infection: 0.0194 - val_precision_infection: 0.1164 - val_recall_infection: 0.5648 - val_hausdorff95_infection: 169.7680 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9887 - val_f1_infection: 0.6706
# ✅ Model saved at epoch 1 with val_loss: 1.0566
# Epoch 2/100
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 334s 292ms/step - loss: 0.7993 - dice_coef_infection: 0.2437 - iou_coef_infection: 0.1530 - precision_infection: 0.2310 - recall_infection: 0.3955 - hausdorff95_infection: 170.6083 - specificity_infection: 0.9905 - accuracy_infection: 0.9849 - f1_infection: 0.7597 - val_loss: 1.0529 - val_dice_coef_infection: 0.0137 - val_iou_coef_infection: 0.0115 - val_precision_infection: 0.1230 - val_recall_infection: 0.5660 - val_hausdorff95_infection: 166.5542 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9887 - val_f1_infection: 0.6532
# ✅ Model saved at epoch 2 with val_loss: 1.0529
# Epoch 3/100
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 334s 292ms/step - loss: 0.7609 - dice_coef_infection: 0.2773 - iou_coef_infection: 0.1778 - precision_infection: 0.2679 - recall_infection: 0.4270 - hausdorff95_infection: 158.1110 - specificity_infection: 0.9914 - accuracy_infection: 0.9864 - f1_infection: 0.7518 - val_loss: 1.0505 - val_dice_coef_infection: 0.0165 - val_iou_coef_infection: 0.0142 - val_precision_infection: 0.1401 - val_recall_infection: 0.5662 - val_hausdorff95_infection: 160.9395 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9887 - val_f1_infection: 0.6475
# ✅ Model saved at epoch 3 with val_loss: 1.0505
# Epoch 4/100
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 334s 292ms/step - loss: 0.7318 - dice_coef_infection: 0.3038 - iou_coef_infection: 0.1964 - precision_infection: 0.2965 - recall_infection: 0.4351 - hausdorff95_infection: 152.2343 - specificity_infection: 0.9924 - accuracy_infection: 0.9874 - f1_infection: 0.7529 - val_loss: 1.0248 - val_dice_coef_infection: 0.0534 - val_iou_coef_infection: 0.0521 - val_precision_infection: 0.1833 - val_recall_infection: 0.5650 - val_hausdorff95_infection: 158.9591 - val_specificity_infection: 1.0000 - val_accuracy_infection: 0.9887 - val_f1_infection: 0.6715
# ✅ Model saved at epoch 4 with val_loss: 1.0248
# Epoch 5/100
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 334s 293ms/step - loss: 0.6900 - dice_coef_infection: 0.3441 - iou_coef_infection: 0.2276 - precision_infection: 0.3454 - recall_infection: 0.4726 - hausdorff95_infection: 146.2511 - specificity_infection: 0.9930 - accuracy_infection: 0.9882 - f1_infection: 0.7479 - val_loss: 1.0413 - val_dice_coef_infection: 0.0278 - val_iou_coef_infection: 0.0242 - val_precision_infection: 0.1560 - val_recall_infection: 0.5675 - val_hausdorff95_infection: 144.1372 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9889 - val_f1_infection: 0.6501
# Epoch 6/100
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 334s 292ms/step - loss: 0.6461 - dice_coef_infection: 0.3876 - iou_coef_infection: 0.2629 - precision_infection: 0.3944 - recall_infection: 0.5178 - hausdorff95_infection: 133.6923 - specificity_infection: 0.9935 - accuracy_infection: 0.9888 - f1_infection: 0.7442 - val_loss: 1.0291 - val_dice_coef_infection: 0.0425 - val_iou_coef_infection: 0.0387 - val_precision_infection: 0.1869 - val_recall_infection: 0.5678 - val_hausdorff95_infection: 138.8350 - val_specificity_infection: 1.0000 - val_accuracy_infection: 0.9890 - val_f1_infection: 0.6512
# Epoch 7/100
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.6440 - dice_coef_infection: 0.3881 - iou_coef_infection: 0.2643 - precision_infection: 0.3954 - recall_infection: 0.5085 - hausdorff95_infection: 130.2388 - specificity_infection: 0.9940 - accuracy_infection: 0.9898 - f1_infection: 0.7503 - val_loss: 1.0269 - val_dice_coef_infection: 0.0505 - val_iou_coef_infection: 0.0469 - val_precision_infection: 0.2029 - val_recall_infection: 0.5678 - val_hausdorff95_infection: 140.9119 - val_specificity_infection: 1.0000 - val_accuracy_infection: 0.9891 - val_f1_infection: 0.6535
# Epoch 8/100
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 334s 293ms/step - loss: 0.6277 - dice_coef_infection: 0.4027 - iou_coef_infection: 0.2767 - precision_infection: 0.4091 - recall_infection: 0.4986 - hausdorff95_infection: 124.3941 - specificity_infection: 0.9947 - accuracy_infection: 0.9907 - f1_infection: 0.7607 - val_loss: 1.0209 - val_dice_coef_infection: 0.0513 - val_iou_coef_infection: 0.0440 - val_precision_infection: 0.1936 - val_recall_infection: 0.5725 - val_hausdorff95_infection: 129.1043 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9895 - val_f1_infection: 0.6525
# ✅ Model saved at epoch 8 with val_loss: 1.0209
# Epoch 9/100
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 334s 293ms/step - loss: 0.6159 - dice_coef_infection: 0.4146 - iou_coef_infection: 0.2892 - precision_infection: 0.4257 - recall_infection: 0.5291 - hausdorff95_infection: 126.3665 - specificity_infection: 0.9947 - accuracy_infection: 0.9909 - f1_infection: 0.7584 - val_loss: 0.9512 - val_dice_coef_infection: 0.1315 - val_iou_coef_infection: 0.1270 - val_precision_infection: 0.3223 - val_recall_infection: 0.5687 - val_hausdorff95_infection: 131.2604 - val_specificity_infection: 1.0000 - val_accuracy_infection: 0.9891 - val_f1_infection: 0.6822
# ✅ Model saved at epoch 9 with val_loss: 0.9512
# Epoch 10/100
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.6061 - dice_coef_infection: 0.4246 - iou_coef_infection: 0.2983 - precision_infection: 0.4330 - recall_infection: 0.5406 - hausdorff95_infection: 119.6927 - specificity_infection: 0.9951 - accuracy_infection: 0.9914 - f1_infection: 0.7622 - val_loss: 0.9985 - val_dice_coef_infection: 0.0835 - val_iou_coef_infection: 0.0773 - val_precision_infection: 0.2504 - val_recall_infection: 0.5711 - val_hausdorff95_infection: 133.1938 - val_specificity_infection: 1.0000 - val_accuracy_infection: 0.9895 - val_f1_infection: 0.6647
# Epoch 11/100
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.5822 - dice_coef_infection: 0.4508 - iou_coef_infection: 0.3184 - precision_infection: 0.4695 - recall_infection: 0.5441 - hausdorff95_infection: 117.8626 - specificity_infection: 0.9953 - accuracy_infection: 0.9913 - f1_infection: 0.7632 - val_loss: 0.9684 - val_dice_coef_infection: 0.1044 - val_iou_coef_infection: 0.0928 - val_precision_infection: 0.2694 - val_recall_infection: 0.5795 - val_hausdorff95_infection: 113.2538 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9902 - val_f1_infection: 0.6683
# Epoch 12/100
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.5795 - dice_coef_infection: 0.4501 - iou_coef_infection: 0.3211 - precision_infection: 0.4655 - recall_infection: 0.5629 - hausdorff95_infection: 115.8680 - specificity_infection: 0.9959 - accuracy_infection: 0.9924 - f1_infection: 0.7628 - val_loss: 0.9935 - val_dice_coef_infection: 0.0821 - val_iou_coef_infection: 0.0699 - val_precision_infection: 0.2440 - val_recall_infection: 0.5797 - val_hausdorff95_infection: 115.3148 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9900 - val_f1_infection: 0.6562
# Epoch 13/100
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.5778 - dice_coef_infection: 0.4532 - iou_coef_infection: 0.3225 - precision_infection: 0.4693 - recall_infection: 0.5527 - hausdorff95_infection: 115.0857 - specificity_infection: 0.9957 - accuracy_infection: 0.9920 - f1_infection: 0.7658 - val_loss: 0.9499 - val_dice_coef_infection: 0.1370 - val_iou_coef_infection: 0.1292 - val_precision_infection: 0.3360 - val_recall_infection: 0.5730 - val_hausdorff95_infection: 118.8312 - val_specificity_infection: 1.0000 - val_accuracy_infection: 0.9895 - val_f1_infection: 0.6757
# ✅ Model saved at epoch 13 with val_loss: 0.9499
# Epoch 14/100
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.5792 - dice_coef_infection: 0.4526 - iou_coef_infection: 0.3219 - precision_infection: 0.4720 - recall_infection: 0.5542 - hausdorff95_infection: 115.6312 - specificity_infection: 0.9962 - accuracy_infection: 0.9923 - f1_infection: 0.7625 - val_loss: 0.8498 - val_dice_coef_infection: 0.2317 - val_iou_coef_infection: 0.2197 - val_precision_infection: 0.4066 - val_recall_infection: 0.5794 - val_hausdorff95_infection: 110.2429 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9899 - val_f1_infection: 0.7335
# ✅ Model saved at epoch 14 with val_loss: 0.8498
# Epoch 15/100
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.5445 - dice_coef_infection: 0.4853 - iou_coef_infection: 0.3520 - precision_infection: 0.5024 - recall_infection: 0.5714 - hausdorff95_infection: 108.6879 - specificity_infection: 0.9964 - accuracy_infection: 0.9929 - f1_infection: 0.7764 - val_loss: 0.9463 - val_dice_coef_infection: 0.1348 - val_iou_coef_infection: 0.1261 - val_precision_infection: 0.3401 - val_recall_infection: 0.5752 - val_hausdorff95_infection: 129.0189 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9899 - val_f1_infection: 0.6669
# Epoch 16/100
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.5332 - dice_coef_infection: 0.4975 - iou_coef_infection: 0.3616 - precision_infection: 0.5128 - recall_infection: 0.5793 - hausdorff95_infection: 105.9125 - specificity_infection: 0.9964 - accuracy_infection: 0.9928 - f1_infection: 0.7780 - val_loss: 0.8880 - val_dice_coef_infection: 0.1950 - val_iou_coef_infection: 0.1833 - val_precision_infection: 0.3748 - val_recall_infection: 0.5793 - val_hausdorff95_infection: 113.5021 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9900 - val_f1_infection: 0.7131
# Epoch 17/100
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.5459 - dice_coef_infection: 0.4851 - iou_coef_infection: 0.3518 - precision_infection: 0.5012 - recall_infection: 0.5745 - hausdorff95_infection: 106.4833 - specificity_infection: 0.9962 - accuracy_infection: 0.9927 - f1_infection: 0.7741 - val_loss: 0.8321 - val_dice_coef_infection: 0.2459 - val_iou_coef_infection: 0.2343 - val_precision_infection: 0.4449 - val_recall_infection: 0.5803 - val_hausdorff95_infection: 113.2699 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9904 - val_f1_infection: 0.7280
# ✅ Model saved at epoch 17 with val_loss: 0.8321
# Epoch 18/100
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.5335 - dice_coef_infection: 0.4971 - iou_coef_infection: 0.3623 - precision_infection: 0.5155 - recall_infection: 0.5715 - hausdorff95_infection: 103.1513 - specificity_infection: 0.9963 - accuracy_infection: 0.9928 - f1_infection: 0.7813 - val_loss: 0.8367 - val_dice_coef_infection: 0.2615 - val_iou_coef_infection: 0.2551 - val_precision_infection: 0.4764 - val_recall_infection: 0.5712 - val_hausdorff95_infection: 123.9474 - val_specificity_infection: 1.0000 - val_accuracy_infection: 0.9893 - val_f1_infection: 0.7355
# Epoch 19/100
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.5346 - dice_coef_infection: 0.4960 - iou_coef_infection: 0.3625 - precision_infection: 0.5118 - recall_infection: 0.5743 - hausdorff95_infection: 105.4506 - specificity_infection: 0.9963 - accuracy_infection: 0.9928 - f1_infection: 0.7814 - val_loss: 0.8555 - val_dice_coef_infection: 0.2181 - val_iou_coef_infection: 0.1999 - val_precision_infection: 0.3807 - val_recall_infection: 0.5910 - val_hausdorff95_infection: 108.1104 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9906 - val_f1_infection: 0.7205
# Epoch 20/100
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.5388 - dice_coef_infection: 0.4923 - iou_coef_infection: 0.3581 - precision_infection: 0.5083 - recall_infection: 0.5762 - hausdorff95_infection: 102.4168 - specificity_infection: 0.9962 - accuracy_infection: 0.9928 - f1_infection: 0.7783 - val_loss: 0.7796 - val_dice_coef_infection: 0.3062 - val_iou_coef_infection: 0.2949 - val_precision_infection: 0.5197 - val_recall_infection: 0.5786 - val_hausdorff95_infection: 116.4588 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9901 - val_f1_infection: 0.7483
# ✅ Model saved at epoch 20 with val_loss: 0.7796
# Epoch 21/100
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.5219 - dice_coef_infection: 0.5071 - iou_coef_infection: 0.3691 - precision_infection: 0.5288 - recall_infection: 0.5819 - hausdorff95_infection: 102.6693 - specificity_infection: 0.9968 - accuracy_infection: 0.9935 - f1_infection: 0.7771 - val_loss: 0.8461 - val_dice_coef_infection: 0.2369 - val_iou_coef_infection: 0.2256 - val_precision_infection: 0.4265 - val_recall_infection: 0.5792 - val_hausdorff95_infection: 116.1232 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9902 - val_f1_infection: 0.7304
# Epoch 22/100
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.5397 - dice_coef_infection: 0.4895 - iou_coef_infection: 0.3561 - precision_infection: 0.5081 - recall_infection: 0.5825 - hausdorff95_infection: 99.0260 - specificity_infection: 0.9968 - accuracy_infection: 0.9935 - f1_infection: 0.7751 - val_loss: 0.8274 - val_dice_coef_infection: 0.2521 - val_iou_coef_infection: 0.2393 - val_precision_infection: 0.4219 - val_recall_infection: 0.5814 - val_hausdorff95_infection: 115.0114 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9903 - val_f1_infection: 0.7442
# Epoch 23/100
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.5160 - dice_coef_infection: 0.5141 - iou_coef_infection: 0.3776 - precision_infection: 0.5303 - recall_infection: 0.6050 - hausdorff95_infection: 98.5987 - specificity_infection: 0.9967 - accuracy_infection: 0.9934 - f1_infection: 0.7760 - val_loss: 0.7324 - val_dice_coef_infection: 0.3488 - val_iou_coef_infection: 0.3367 - val_precision_infection: 0.5617 - val_recall_infection: 0.5804 - val_hausdorff95_infection: 116.6569 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9903 - val_f1_infection: 0.7670
# ✅ Model saved at epoch 23 with val_loss: 0.7324
# Epoch 24/100
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.5190 - dice_coef_infection: 0.5086 - iou_coef_infection: 0.3738 - precision_infection: 0.5288 - recall_infection: 0.5808 - hausdorff95_infection: 99.5956 - specificity_infection: 0.9970 - accuracy_infection: 0.9939 - f1_infection: 0.7840 - val_loss: 0.7523 - val_dice_coef_infection: 0.3121 - val_iou_coef_infection: 0.2937 - val_precision_infection: 0.4750 - val_recall_infection: 0.5936 - val_hausdorff95_infection: 106.8151 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9915 - val_f1_infection: 0.7652
# Epoch 25/100
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.5090 - dice_coef_infection: 0.5192 - iou_coef_infection: 0.3846 - precision_infection: 0.5348 - recall_infection: 0.5985 - hausdorff95_infection: 97.0097 - specificity_infection: 0.9968 - accuracy_infection: 0.9937 - f1_infection: 0.7860 - val_loss: 0.7713 - val_dice_coef_infection: 0.3005 - val_iou_coef_infection: 0.2861 - val_precision_infection: 0.4426 - val_recall_infection: 0.5849 - val_hausdorff95_infection: 104.2142 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9908 - val_f1_infection: 0.7789
# Epoch 26/100
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4906 - dice_coef_infection: 0.5365 - iou_coef_infection: 0.4010 - precision_infection: 0.5521 - recall_infection: 0.6162 - hausdorff95_infection: 98.1463 - specificity_infection: 0.9970 - accuracy_infection: 0.9940 - f1_infection: 0.7870 - val_loss: 0.7645 - val_dice_coef_infection: 0.3162 - val_iou_coef_infection: 0.3053 - val_precision_infection: 0.5064 - val_recall_infection: 0.5790 - val_hausdorff95_infection: 116.6768 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9904 - val_f1_infection: 0.7665
# Epoch 27/100
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.5091 - dice_coef_infection: 0.5192 - iou_coef_infection: 0.3854 - precision_infection: 0.5373 - recall_infection: 0.5947 - hausdorff95_infection: 98.5526 - specificity_infection: 0.9969 - accuracy_infection: 0.9937 - f1_infection: 0.7869 - val_loss: 0.7545 - val_dice_coef_infection: 0.3169 - val_iou_coef_infection: 0.2993 - val_precision_infection: 0.4511 - val_recall_infection: 0.5903 - val_hausdorff95_infection: 110.0989 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9908 - val_f1_infection: 0.7788
# Epoch 28/100
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.5035 - dice_coef_infection: 0.5246 - iou_coef_infection: 0.3870 - precision_infection: 0.5391 - recall_infection: 0.6090 - hausdorff95_infection: 97.9255 - specificity_infection: 0.9969 - accuracy_infection: 0.9939 - f1_infection: 0.7817 - val_loss: 0.6372 - val_dice_coef_infection: 0.4549 - val_iou_coef_infection: 0.4462 - val_precision_infection: 0.7004 - val_recall_infection: 0.5762 - val_hausdorff95_infection: 126.1295 - val_specificity_infection: 1.0000 - val_accuracy_infection: 0.9903 - val_f1_infection: 0.8038
# ✅ Model saved at epoch 28 with val_loss: 0.6372
# Epoch 29/100
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.5097 - dice_coef_infection: 0.5185 - iou_coef_infection: 0.3823 - precision_infection: 0.5407 - recall_infection: 0.5945 - hausdorff95_infection: 97.5498 - specificity_infection: 0.9969 - accuracy_infection: 0.9938 - f1_infection: 0.7828 - val_loss: 0.6670 - val_dice_coef_infection: 0.4064 - val_iou_coef_infection: 0.3909 - val_precision_infection: 0.6339 - val_recall_infection: 0.5859 - val_hausdorff95_infection: 110.4151 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9908 - val_f1_infection: 0.7790
# Epoch 30/100
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 337s 295ms/step - loss: 0.4900 - dice_coef_infection: 0.5389 - iou_coef_infection: 0.4005 - precision_infection: 0.5568 - recall_infection: 0.6086 - hausdorff95_infection: 90.7897 - specificity_infection: 0.9969 - accuracy_infection: 0.9937 - f1_infection: 0.7870 - val_loss: 0.6941 - val_dice_coef_infection: 0.3801 - val_iou_coef_infection: 0.3648 - val_precision_infection: 0.5516 - val_recall_infection: 0.5870 - val_hausdorff95_infection: 111.2567 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9910 - val_f1_infection: 0.7928
# Epoch 31/100
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 337s 295ms/step - loss: 0.4773 - dice_coef_infection: 0.5495 - iou_coef_infection: 0.4145 - precision_infection: 0.5665 - recall_infection: 0.6241 - hausdorff95_infection: 89.3884 - specificity_infection: 0.9971 - accuracy_infection: 0.9943 - f1_infection: 0.7933 - val_loss: 0.6821 - val_dice_coef_infection: 0.3950 - val_iou_coef_infection: 0.3789 - val_precision_infection: 0.5773 - val_recall_infection: 0.5867 - val_hausdorff95_infection: 104.7786 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9907 - val_f1_infection: 0.7963
# Epoch 32/100
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4858 - dice_coef_infection: 0.5410 - iou_coef_infection: 0.4040 - precision_infection: 0.5579 - recall_infection: 0.6154 - hausdorff95_infection: 93.7966 - specificity_infection: 0.9971 - accuracy_infection: 0.9942 - f1_infection: 0.7892 - val_loss: 0.6517 - val_dice_coef_infection: 0.4291 - val_iou_coef_infection: 0.4178 - val_precision_infection: 0.6378 - val_recall_infection: 0.5810 - val_hausdorff95_infection: 115.7531 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9908 - val_f1_infection: 0.8050
# Epoch 33/100
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 337s 294ms/step - loss: 0.4674 - dice_coef_infection: 0.5588 - iou_coef_infection: 0.4223 - precision_infection: 0.5752 - recall_infection: 0.6309 - hausdorff95_infection: 85.2255 - specificity_infection: 0.9971 - accuracy_infection: 0.9943 - f1_infection: 0.7944 - val_loss: 0.6535 - val_dice_coef_infection: 0.4312 - val_iou_coef_infection: 0.4202 - val_precision_infection: 0.6475 - val_recall_infection: 0.5792 - val_hausdorff95_infection: 119.0120 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9904 - val_f1_infection: 0.8007
# Epoch 34/100
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 337s 295ms/step - loss: 0.4781 - dice_coef_infection: 0.5478 - iou_coef_infection: 0.4131 - precision_infection: 0.5655 - recall_infection: 0.6186 - hausdorff95_infection: 87.1111 - specificity_infection: 0.9972 - accuracy_infection: 0.9943 - f1_infection: 0.7930 - val_loss: 0.6130 - val_dice_coef_infection: 0.4573 - val_iou_coef_infection: 0.4406 - val_precision_infection: 0.6705 - val_recall_infection: 0.5904 - val_hausdorff95_infection: 111.0228 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9914 - val_f1_infection: 0.8059
# ✅ Model saved at epoch 34 with val_loss: 0.6130
# Epoch 35/100
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4608 - dice_coef_infection: 0.5648 - iou_coef_infection: 0.4276 - precision_infection: 0.5815 - recall_infection: 0.6340 - hausdorff95_infection: 85.6905 - specificity_infection: 0.9973 - accuracy_infection: 0.9945 - f1_infection: 0.7946 - val_loss: 0.6123 - val_dice_coef_infection: 0.4716 - val_iou_coef_infection: 0.4592 - val_precision_infection: 0.7356 - val_recall_infection: 0.5813 - val_hausdorff95_infection: 121.6737 - val_specificity_infection: 1.0000 - val_accuracy_infection: 0.9905 - val_f1_infection: 0.7924
# ✅ Model saved at epoch 35 with val_loss: 0.6123
# Epoch 36/100
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 337s 294ms/step - loss: 0.4680 - dice_coef_infection: 0.5575 - iou_coef_infection: 0.4200 - precision_infection: 0.5712 - recall_infection: 0.6260 - hausdorff95_infection: 87.7259 - specificity_infection: 0.9972 - accuracy_infection: 0.9944 - f1_infection: 0.7940 - val_loss: 0.6640 - val_dice_coef_infection: 0.4111 - val_iou_coef_infection: 0.3965 - val_precision_infection: 0.5849 - val_recall_infection: 0.5861 - val_hausdorff95_infection: 111.9492 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9910 - val_f1_infection: 0.8078
# Epoch 37/100
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 337s 294ms/step - loss: 0.4588 - dice_coef_infection: 0.5669 - iou_coef_infection: 0.4304 - precision_infection: 0.5779 - recall_infection: 0.6270 - hausdorff95_infection: 84.3853 - specificity_infection: 0.9971 - accuracy_infection: 0.9943 - f1_infection: 0.8022 - val_loss: 0.6452 - val_dice_coef_infection: 0.4208 - val_iou_coef_infection: 0.4010 - val_precision_infection: 0.6017 - val_recall_infection: 0.5955 - val_hausdorff95_infection: 104.6406 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9915 - val_f1_infection: 0.7982
# Epoch 38/100
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 337s 294ms/step - loss: 0.4578 - dice_coef_infection: 0.5669 - iou_coef_infection: 0.4312 - precision_infection: 0.5809 - recall_infection: 0.6444 - hausdorff95_infection: 83.7315 - specificity_infection: 0.9973 - accuracy_infection: 0.9947 - f1_infection: 0.7956 - val_loss: 0.5496 - val_dice_coef_infection: 0.5272 - val_iou_coef_infection: 0.5112 - val_precision_infection: 0.7881 - val_recall_infection: 0.5890 - val_hausdorff95_infection: 111.7670 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9913 - val_f1_infection: 0.8141
# ✅ Model saved at epoch 38 with val_loss: 0.5496
# Epoch 39/100
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4617 - dice_coef_infection: 0.5638 - iou_coef_infection: 0.4264 - precision_infection: 0.5857 - recall_infection: 0.6304 - hausdorff95_infection: 82.8422 - specificity_infection: 0.9973 - accuracy_infection: 0.9944 - f1_infection: 0.7940 - val_loss: 0.6116 - val_dice_coef_infection: 0.4765 - val_iou_coef_infection: 0.4644 - val_precision_infection: 0.7478 - val_recall_infection: 0.5802 - val_hausdorff95_infection: 115.4583 - val_specificity_infection: 1.0000 - val_accuracy_infection: 0.9904 - val_f1_infection: 0.7940
# Epoch 40/100
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4449 - dice_coef_infection: 0.5801 - iou_coef_infection: 0.4415 - precision_infection: 0.5943 - recall_infection: 0.6449 - hausdorff95_infection: 84.1598 - specificity_infection: 0.9973 - accuracy_infection: 0.9946 - f1_infection: 0.7994 - val_loss: 0.6024 - val_dice_coef_infection: 0.4801 - val_iou_coef_infection: 0.4618 - val_precision_infection: 0.7533 - val_recall_infection: 0.5904 - val_hausdorff95_infection: 110.3076 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9909 - val_f1_infection: 0.7852
# Epoch 41/100
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4439 - dice_coef_infection: 0.5816 - iou_coef_infection: 0.4431 - precision_infection: 0.6014 - recall_infection: 0.6388 - hausdorff95_infection: 83.3154 - specificity_infection: 0.9974 - accuracy_infection: 0.9946 - f1_infection: 0.8007 - val_loss: 0.6020 - val_dice_coef_infection: 0.4897 - val_iou_coef_infection: 0.4747 - val_precision_infection: 0.7798 - val_recall_infection: 0.5844 - val_hausdorff95_infection: 112.6954 - val_specificity_infection: 1.0000 - val_accuracy_infection: 0.9903 - val_f1_infection: 0.7863
# Epoch 42/100
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4614 - dice_coef_infection: 0.5642 - iou_coef_infection: 0.4278 - precision_infection: 0.5818 - recall_infection: 0.6416 - hausdorff95_infection: 83.5053 - specificity_infection: 0.9973 - accuracy_infection: 0.9946 - f1_infection: 0.7919 - val_loss: 0.5790 - val_dice_coef_infection: 0.4972 - val_iou_coef_infection: 0.4779 - val_precision_infection: 0.7537 - val_recall_infection: 0.5939 - val_hausdorff95_infection: 109.2953 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9913 - val_f1_infection: 0.7987
# Epoch 43/100
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4491 - dice_coef_infection: 0.5777 - iou_coef_infection: 0.4399 - precision_infection: 0.6005 - recall_infection: 0.6327 - hausdorff95_infection: 83.6111 - specificity_infection: 0.9973 - accuracy_infection: 0.9944 - f1_infection: 0.7991 - val_loss: 0.5791 - val_dice_coef_infection: 0.5160 - val_iou_coef_infection: 0.5051 - val_precision_infection: 0.8278 - val_recall_infection: 0.5785 - val_hausdorff95_infection: 119.3884 - val_specificity_infection: 1.0000 - val_accuracy_infection: 0.9903 - val_f1_infection: 0.7939
# Epoch 44/100
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4335 - dice_coef_infection: 0.5933 - iou_coef_infection: 0.4523 - precision_infection: 0.6096 - recall_infection: 0.6495 - hausdorff95_infection: 81.4160 - specificity_infection: 0.9972 - accuracy_infection: 0.9944 - f1_infection: 0.8019 - val_loss: 0.5750 - val_dice_coef_infection: 0.4943 - val_iou_coef_infection: 0.4747 - val_precision_infection: 0.6996 - val_recall_infection: 0.5964 - val_hausdorff95_infection: 102.9281 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9917 - val_f1_infection: 0.8219
# Epoch 45/100
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4586 - dice_coef_infection: 0.5677 - iou_coef_infection: 0.4327 - precision_infection: 0.5864 - recall_infection: 0.6328 - hausdorff95_infection: 81.8880 - specificity_infection: 0.9971 - accuracy_infection: 0.9944 - f1_infection: 0.7992 - val_loss: 0.5744 - val_dice_coef_infection: 0.5069 - val_iou_coef_infection: 0.4892 - val_precision_infection: 0.7956 - val_recall_infection: 0.5897 - val_hausdorff95_infection: 111.4684 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9908 - val_f1_infection: 0.7922
# Epoch 46/100
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4387 - dice_coef_infection: 0.5880 - iou_coef_infection: 0.4482 - precision_infection: 0.6081 - recall_infection: 0.6424 - hausdorff95_infection: 79.5895 - specificity_infection: 0.9973 - accuracy_infection: 0.9945 - f1_infection: 0.8018 - val_loss: 0.5868 - val_dice_coef_infection: 0.5020 - val_iou_coef_infection: 0.4881 - val_precision_infection: 0.7930 - val_recall_infection: 0.5829 - val_hausdorff95_infection: 113.8461 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9903 - val_f1_infection: 0.7922
# Epoch 47/100
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4452 - dice_coef_infection: 0.5796 - iou_coef_infection: 0.4440 - precision_infection: 0.5996 - recall_infection: 0.6441 - hausdorff95_infection: 78.8795 - specificity_infection: 0.9976 - accuracy_infection: 0.9950 - f1_infection: 0.8019 - val_loss: 0.6460 - val_dice_coef_infection: 0.4371 - val_iou_coef_infection: 0.4226 - val_precision_infection: 0.5770 - val_recall_infection: 0.5855 - val_hausdorff95_infection: 105.9774 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9909 - val_f1_infection: 0.8386
# Epoch 48/100
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4509 - dice_coef_infection: 0.5755 - iou_coef_infection: 0.4367 - precision_infection: 0.5958 - recall_infection: 0.6382 - hausdorff95_infection: 81.3070 - specificity_infection: 0.9973 - accuracy_infection: 0.9945 - f1_infection: 0.7955 - val_loss: 0.5479 - val_dice_coef_infection: 0.5313 - val_iou_coef_infection: 0.5154 - val_precision_infection: 0.8424 - val_recall_infection: 0.5880 - val_hausdorff95_infection: 110.5245 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9910 - val_f1_infection: 0.7965
# ✅ Model saved at epoch 48 with val_loss: 0.5479
# Epoch 49/100
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4570 - dice_coef_infection: 0.5690 - iou_coef_infection: 0.4349 - precision_infection: 0.5973 - recall_infection: 0.6473 - hausdorff95_infection: 79.4675 - specificity_infection: 0.9974 - accuracy_infection: 0.9946 - f1_infection: 0.7939 - val_loss: 0.5829 - val_dice_coef_infection: 0.5057 - val_iou_coef_infection: 0.4886 - val_precision_infection: 0.7829 - val_recall_infection: 0.5887 - val_hausdorff95_infection: 109.6299 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9908 - val_f1_infection: 0.7964
# Epoch 50/100
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4426 - dice_coef_infection: 0.5827 - iou_coef_infection: 0.4475 - precision_infection: 0.6061 - recall_infection: 0.6392 - hausdorff95_infection: 80.3859 - specificity_infection: 0.9973 - accuracy_infection: 0.9947 - f1_infection: 0.8042 - val_loss: 0.6195 - val_dice_coef_infection: 0.4619 - val_iou_coef_infection: 0.4441 - val_precision_infection: 0.6772 - val_recall_infection: 0.5909 - val_hausdorff95_infection: 105.8781 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9911 - val_f1_infection: 0.8044
# Epoch 51/100
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4462 - dice_coef_infection: 0.5797 - iou_coef_infection: 0.4445 - precision_infection: 0.5975 - recall_infection: 0.6462 - hausdorff95_infection: 77.7802 - specificity_infection: 0.9973 - accuracy_infection: 0.9946 - f1_infection: 0.8007 - val_loss: 0.5992 - val_dice_coef_infection: 0.4757 - val_iou_coef_infection: 0.4565 - val_precision_infection: 0.6408 - val_recall_infection: 0.5953 - val_hausdorff95_infection: 107.7877 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9914 - val_f1_infection: 0.8330
# Epoch 52/100
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 334s 293ms/step - loss: 0.4449 - dice_coef_infection: 0.5793 - iou_coef_infection: 0.4445 - precision_infection: 0.5941 - recall_infection: 0.6544 - hausdorff95_infection: 79.8941 - specificity_infection: 0.9974 - accuracy_infection: 0.9949 - f1_infection: 0.8014 - val_loss: 0.6318 - val_dice_coef_infection: 0.4748 - val_iou_coef_infection: 0.4662 - val_precision_infection: 0.7007 - val_recall_infection: 0.5752 - val_hausdorff95_infection: 118.7306 - val_specificity_infection: 1.0000 - val_accuracy_infection: 0.9900 - val_f1_infection: 0.8213
# Epoch 53/100
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4681 - dice_coef_infection: 0.5601 - iou_coef_infection: 0.4228 - precision_infection: 0.5916 - recall_infection: 0.6135 - hausdorff95_infection: 85.8523 - specificity_infection: 0.9973 - accuracy_infection: 0.9944 - f1_infection: 0.7927 - val_loss: 0.6403 - val_dice_coef_infection: 0.4560 - val_iou_coef_infection: 0.4419 - val_precision_infection: 0.6951 - val_recall_infection: 0.5830 - val_hausdorff95_infection: 112.4026 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9905 - val_f1_infection: 0.7957
# Epoch 54/100
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4311 - dice_coef_infection: 0.5931 - iou_coef_infection: 0.4542 - precision_infection: 0.6122 - recall_infection: 0.6469 - hausdorff95_infection: 74.1092 - specificity_infection: 0.9976 - accuracy_infection: 0.9949 - f1_infection: 0.8043 - val_loss: 0.6525 - val_dice_coef_infection: 0.4372 - val_iou_coef_infection: 0.4208 - val_precision_infection: 0.6299 - val_recall_infection: 0.5882 - val_hausdorff95_infection: 102.7972 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9909 - val_f1_infection: 0.8060
# Epoch 55/100
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4290 - dice_coef_infection: 0.5961 - iou_coef_infection: 0.4583 - precision_infection: 0.6223 - recall_infection: 0.6515 - hausdorff95_infection: 78.9223 - specificity_infection: 0.9975 - accuracy_infection: 0.9948 - f1_infection: 0.8023 - val_loss: 0.5648 - val_dice_coef_infection: 0.5287 - val_iou_coef_infection: 0.5125 - val_precision_infection: 0.8131 - val_recall_infection: 0.5868 - val_hausdorff95_infection: 109.8802 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9906 - val_f1_infection: 0.8079
# Epoch 56/100
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4210 - dice_coef_infection: 0.6062 - iou_coef_infection: 0.4670 - precision_infection: 0.6263 - recall_infection: 0.6633 - hausdorff95_infection: 74.7606 - specificity_infection: 0.9974 - accuracy_infection: 0.9945 - f1_infection: 0.8044 - val_loss: 0.6657 - val_dice_coef_infection: 0.4057 - val_iou_coef_infection: 0.3853 - val_precision_infection: 0.5300 - val_recall_infection: 0.5990 - val_hausdorff95_infection: 105.8361 - val_specificity_infection: 0.9994 - val_accuracy_infection: 0.9915 - val_f1_infection: 0.8153
# Epoch 57/100
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4280 - dice_coef_infection: 0.5982 - iou_coef_infection: 0.4602 - precision_infection: 0.6202 - recall_infection: 0.6442 - hausdorff95_infection: 78.1803 - specificity_infection: 0.9974 - accuracy_infection: 0.9947 - f1_infection: 0.8074 - val_loss: 0.5816 - val_dice_coef_infection: 0.4889 - val_iou_coef_infection: 0.4658 - val_precision_infection: 0.7377 - val_recall_infection: 0.6024 - val_hausdorff95_infection: 105.2931 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9917 - val_f1_infection: 0.7913
# Epoch 58/100
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4180 - dice_coef_infection: 0.6077 - iou_coef_infection: 0.4673 - precision_infection: 0.6260 - recall_infection: 0.6458 - hausdorff95_infection: 78.0709 - specificity_infection: 0.9974 - accuracy_infection: 0.9947 - f1_infection: 0.8133 - val_loss: 0.5414 - val_dice_coef_infection: 0.5526 - val_iou_coef_infection: 0.5382 - val_precision_infection: 0.8397 - val_recall_infection: 0.5835 - val_hausdorff95_infection: 110.7432 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9904 - val_f1_infection: 0.8168
# ✅ Model saved at epoch 58 with val_loss: 0.5414
# Epoch 59/100
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4188 - dice_coef_infection: 0.6052 - iou_coef_infection: 0.4670 - precision_infection: 0.6257 - recall_infection: 0.6625 - hausdorff95_infection: 73.4991 - specificity_infection: 0.9976 - accuracy_infection: 0.9951 - f1_infection: 0.8060 - val_loss: 0.5308 - val_dice_coef_infection: 0.5505 - val_iou_coef_infection: 0.5317 - val_precision_infection: 0.8514 - val_recall_infection: 0.5933 - val_hausdorff95_infection: 110.3214 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9912 - val_f1_infection: 0.8046
# ✅ Model saved at epoch 59 with val_loss: 0.5308
# Epoch 60/100
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4454 - dice_coef_infection: 0.5808 - iou_coef_infection: 0.4471 - precision_infection: 0.6046 - recall_infection: 0.6541 - hausdorff95_infection: 76.4707 - specificity_infection: 0.9975 - accuracy_infection: 0.9948 - f1_infection: 0.7989 - val_loss: 0.6499 - val_dice_coef_infection: 0.4532 - val_iou_coef_infection: 0.4401 - val_precision_infection: 0.7076 - val_recall_infection: 0.5810 - val_hausdorff95_infection: 113.9105 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9900 - val_f1_infection: 0.7883
# Epoch 61/100
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4263 - dice_coef_infection: 0.5990 - iou_coef_infection: 0.4620 - precision_infection: 0.6163 - recall_infection: 0.6604 - hausdorff95_infection: 75.4337 - specificity_infection: 0.9974 - accuracy_infection: 0.9947 - f1_infection: 0.8063 - val_loss: 0.6099 - val_dice_coef_infection: 0.4857 - val_iou_coef_infection: 0.4688 - val_precision_infection: 0.7394 - val_recall_infection: 0.5883 - val_hausdorff95_infection: 110.7681 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9909 - val_f1_infection: 0.7978
# Epoch 62/100
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4213 - dice_coef_infection: 0.6029 - iou_coef_infection: 0.4650 - precision_infection: 0.6210 - recall_infection: 0.6620 - hausdorff95_infection: 73.4047 - specificity_infection: 0.9975 - accuracy_infection: 0.9949 - f1_infection: 0.8056 - val_loss: 0.5843 - val_dice_coef_infection: 0.4995 - val_iou_coef_infection: 0.4794 - val_precision_infection: 0.7731 - val_recall_infection: 0.5960 - val_hausdorff95_infection: 110.0657 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9914 - val_f1_infection: 0.7892
# Epoch 63/100
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4160 - dice_coef_infection: 0.6082 - iou_coef_infection: 0.4715 - precision_infection: 0.6246 - recall_infection: 0.6650 - hausdorff95_infection: 71.3344 - specificity_infection: 0.9976 - accuracy_infection: 0.9951 - f1_infection: 0.8098 - val_loss: 0.5918 - val_dice_coef_infection: 0.5015 - val_iou_coef_infection: 0.4836 - val_precision_infection: 0.7513 - val_recall_infection: 0.5896 - val_hausdorff95_infection: 111.2564 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9907 - val_f1_infection: 0.8075
# Epoch 64/100
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4327 - dice_coef_infection: 0.5934 - iou_coef_infection: 0.4542 - precision_infection: 0.6227 - recall_infection: 0.6454 - hausdorff95_infection: 77.2576 - specificity_infection: 0.9976 - accuracy_infection: 0.9949 - f1_infection: 0.8014 - val_loss: 0.5321 - val_dice_coef_infection: 0.5512 - val_iou_coef_infection: 0.5320 - val_precision_infection: 0.8254 - val_recall_infection: 0.5931 - val_hausdorff95_infection: 106.1390 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9912 - val_f1_infection: 0.8159
# Epoch 65/100
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4260 - dice_coef_infection: 0.6001 - iou_coef_infection: 0.4630 - precision_infection: 0.6222 - recall_infection: 0.6425 - hausdorff95_infection: 75.1525 - specificity_infection: 0.9976 - accuracy_infection: 0.9949 - f1_infection: 0.8109 - val_loss: 0.5349 - val_dice_coef_infection: 0.5660 - val_iou_coef_infection: 0.5506 - val_precision_infection: 0.9280 - val_recall_infection: 0.5845 - val_hausdorff95_infection: 112.6891 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9902 - val_f1_infection: 0.7944
# Epoch 66/100
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 337s 295ms/step - loss: 0.4315 - dice_coef_infection: 0.5933 - iou_coef_infection: 0.4574 - precision_infection: 0.6228 - recall_infection: 0.6454 - hausdorff95_infection: 68.9771 - specificity_infection: 0.9976 - accuracy_infection: 0.9950 - f1_infection: 0.8042 - val_loss: 0.5622 - val_dice_coef_infection: 0.5138 - val_iou_coef_infection: 0.4915 - val_precision_infection: 0.7696 - val_recall_infection: 0.6000 - val_hausdorff95_infection: 103.1365 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9916 - val_f1_infection: 0.8009
# Epoch 67/100
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 337s 294ms/step - loss: 0.4310 - dice_coef_infection: 0.5933 - iou_coef_infection: 0.4580 - precision_infection: 0.6123 - recall_infection: 0.6596 - hausdorff95_infection: 78.5770 - specificity_infection: 0.9975 - accuracy_infection: 0.9950 - f1_infection: 0.8045 - val_loss: 0.5765 - val_dice_coef_infection: 0.5183 - val_iou_coef_infection: 0.5048 - val_precision_infection: 0.8149 - val_recall_infection: 0.5820 - val_hausdorff95_infection: 112.1692 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9904 - val_f1_infection: 0.7989
# Epoch 68/100
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4214 - dice_coef_infection: 0.6028 - iou_coef_infection: 0.4652 - precision_infection: 0.6318 - recall_infection: 0.6577 - hausdorff95_infection: 72.6945 - specificity_infection: 0.9976 - accuracy_infection: 0.9951 - f1_infection: 0.8039 - val_loss: 0.5975 - val_dice_coef_infection: 0.5091 - val_iou_coef_infection: 0.4943 - val_precision_infection: 0.8338 - val_recall_infection: 0.5833 - val_hausdorff95_infection: 110.3079 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9901 - val_f1_infection: 0.7817
# Epoch 69/100
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4119 - dice_coef_infection: 0.6123 - iou_coef_infection: 0.4745 - precision_infection: 0.6281 - recall_infection: 0.6641 - hausdorff95_infection: 71.5660 - specificity_infection: 0.9975 - accuracy_infection: 0.9950 - f1_infection: 0.8111 - val_loss: 0.5540 - val_dice_coef_infection: 0.5433 - val_iou_coef_infection: 0.5266 - val_precision_infection: 0.7975 - val_recall_infection: 0.5899 - val_hausdorff95_infection: 104.5722 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9910 - val_f1_infection: 0.8242
# Epoch 70/100
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 0.0001.
# ...
# Epoch 71/100
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4195 - dice_coef_infection: 0.6058 - iou_coef_infection: 0.4673 - precision_infection: 0.6294 - recall_infection: 0.6604 - hausdorff95_infection: 74.1042 - specificity_infection: 0.9975 - accuracy_infection: 0.9950 - f1_infection: 0.8051 - val_loss: 0.6016 - val_dice_coef_infection: 0.4935 - val_iou_coef_infection: 0.4768 - val_precision_infection: 0.7215 - val_recall_infection: 0.5875 - val_hausdorff95_infection: 110.0108 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9906 - val_f1_infection: 0.8139
# Epoch 72/100
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4333 - dice_coef_infection: 0.5926 - iou_coef_infection: 0.4575 - precision_infection: 0.6231 - recall_infection: 0.6358 - hausdorff95_infection: 73.9382 - specificity_infection: 0.9976 - accuracy_infection: 0.9951 - f1_infection: 0.8087 - val_loss: 0.5644 - val_dice_coef_infection: 0.5311 - val_iou_coef_infection: 0.5121 - val_precision_infection: 0.8329 - val_recall_infection: 0.5909 - val_hausdorff95_infection: 108.0054 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9905 - val_f1_infection: 0.7970
# Epoch 73/100
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 337s 294ms/step - loss: 0.4073 - dice_coef_infection: 0.6185 - iou_coef_infection: 0.4813 - precision_infection: 0.6399 - recall_infection: 0.6733 - hausdorff95_infection: 75.0499 - specificity_infection: 0.9975 - accuracy_infection: 0.9949 - f1_infection: 0.8094 - val_loss: 0.5149 - val_dice_coef_infection: 0.5655 - val_iou_coef_infection: 0.5437 - val_precision_infection: 0.8715 - val_recall_infection: 0.5982 - val_hausdorff95_infection: 104.8514 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9915 - val_f1_infection: 0.8059
# ✅ Model saved at epoch 73 with val_loss: 0.5149
# Epoch 74/100
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 337s 294ms/step - loss: 0.4152 - dice_coef_infection: 0.6082 - iou_coef_infection: 0.4722 - precision_infection: 0.6315 - recall_infection: 0.6615 - hausdorff95_infection: 66.8352 - specificity_infection: 0.9977 - accuracy_infection: 0.9953 - f1_infection: 0.8101 - val_loss: 0.5184 - val_dice_coef_infection: 0.5721 - val_iou_coef_infection: 0.5511 - val_precision_infection: 0.8890 - val_recall_infection: 0.5950 - val_hausdorff95_infection: 102.4060 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9908 - val_f1_infection: 0.8064
# Epoch 75/100
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4091 - dice_coef_infection: 0.6139 - iou_coef_infection: 0.4772 - precision_infection: 0.6330 - recall_infection: 0.6603 - hausdorff95_infection: 68.7618 - specificity_infection: 0.9977 - accuracy_infection: 0.9954 - f1_infection: 0.8128 - val_loss: 0.5708 - val_dice_coef_infection: 0.5279 - val_iou_coef_infection: 0.5095 - val_precision_infection: 0.7796 - val_recall_infection: 0.5901 - val_hausdorff95_infection: 99.9402 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9906 - val_f1_infection: 0.8182
# Epoch 76/100
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4189 - dice_coef_infection: 0.6061 - iou_coef_infection: 0.4698 - precision_infection: 0.6367 - recall_infection: 0.6673 - hausdorff95_infection: 69.8973 - specificity_infection: 0.9977 - accuracy_infection: 0.9952 - f1_infection: 0.8026 - val_loss: 0.5981 - val_dice_coef_infection: 0.5026 - val_iou_coef_infection: 0.4839 - val_precision_infection: 0.7560 - val_recall_infection: 0.5911 - val_hausdorff95_infection: 103.4762 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9907 - val_f1_infection: 0.8036
# Epoch 77/100
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4191 - dice_coef_infection: 0.6051 - iou_coef_infection: 0.4688 - precision_infection: 0.6391 - recall_infection: 0.6550 - hausdorff95_infection: 70.8287 - specificity_infection: 0.9978 - accuracy_infection: 0.9954 - f1_infection: 0.8072 - val_loss: 0.5635 - val_dice_coef_infection: 0.5579 - val_iou_coef_infection: 0.5498 - val_precision_infection: 0.9507 - val_recall_infection: 0.5736 - val_hausdorff95_infection: 119.8477 - val_specificity_infection: 1.0000 - val_accuracy_infection: 0.9893 - val_f1_infection: 0.7862
# Epoch 78/100
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4122 - dice_coef_infection: 0.6132 - iou_coef_infection: 0.4780 - precision_infection: 0.6468 - recall_infection: 0.6657 - hausdorff95_infection: 67.1859 - specificity_infection: 0.9977 - accuracy_infection: 0.9952 - f1_infection: 0.8081 - val_loss: 0.5474 - val_dice_coef_infection: 0.5630 - val_iou_coef_infection: 0.5466 - val_precision_infection: 0.9044 - val_recall_infection: 0.5865 - val_hausdorff95_infection: 108.8912 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9901 - val_f1_infection: 0.8001
# Epoch 79/100
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.3964 - dice_coef_infection: 0.6292 - iou_coef_infection: 0.4925 - precision_infection: 0.6479 - recall_infection: 0.6731 - hausdorff95_infection: 68.6825 - specificity_infection: 0.9974 - accuracy_infection: 0.9949 - f1_infection: 0.8188 - val_loss: 0.5694 - val_dice_coef_infection: 0.5325 - val_iou_coef_infection: 0.5173 - val_precision_infection: 0.8594 - val_recall_infection: 0.5842 - val_hausdorff95_infection: 108.4258 - val_specificity_infection: 1.0000 - val_accuracy_infection: 0.9901 - val_f1_infection: 0.7916
# Epoch 80/100
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4070 - dice_coef_infection: 0.6183 - iou_coef_infection: 0.4803 - precision_infection: 0.6483 - recall_infection: 0.6557 - hausdorff95_infection: 67.6380 - specificity_infection: 0.9977 - accuracy_infection: 0.9952 - f1_infection: 0.8130 - val_loss: 0.5353 - val_dice_coef_infection: 0.5722 - val_iou_coef_infection: 0.5575 - val_precision_infection: 0.9222 - val_recall_infection: 0.5837 - val_hausdorff95_infection: 111.3039 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9902 - val_f1_infection: 0.8016
# Epoch 81/100
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4180 - dice_coef_infection: 0.6069 - iou_coef_infection: 0.4710 - precision_infection: 0.6416 - recall_infection: 0.6494 - hausdorff95_infection: 66.8525 - specificity_infection: 0.9977 - accuracy_infection: 0.9952 - f1_infection: 0.8100 - val_loss: 0.5621 - val_dice_coef_infection: 0.5385 - val_iou_coef_infection: 0.5239 - val_precision_infection: 0.8906 - val_recall_infection: 0.5833 - val_hausdorff95_infection: 112.8089 - val_specificity_infection: 1.0000 - val_accuracy_infection: 0.9903 - val_f1_infection: 0.7866
# Epoch 82/100
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4177 - dice_coef_infection: 0.6072 - iou_coef_infection: 0.4747 - precision_infection: 0.6390 - recall_infection: 0.6654 - hausdorff95_infection: 68.4455 - specificity_infection: 0.9976 - accuracy_infection: 0.9952 - f1_infection: 0.8092 - val_loss: 0.5352 - val_dice_coef_infection: 0.5657 - val_iou_coef_infection: 0.5499 - val_precision_infection: 0.8827 - val_recall_infection: 0.5862 - val_hausdorff95_infection: 110.8355 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9907 - val_f1_infection: 0.8109
# Epoch 83/100
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4140 - dice_coef_infection: 0.6093 - iou_coef_infection: 0.4745 - precision_infection: 0.6335 - recall_infection: 0.6693 - hausdorff95_infection: 66.7876 - specificity_infection: 0.9978 - accuracy_infection: 0.9954 - f1_infection: 0.8079 - val_loss: 0.6007 - val_dice_coef_infection: 0.5037 - val_iou_coef_infection: 0.4872 - val_precision_infection: 0.8019 - val_recall_infection: 0.5863 - val_hausdorff95_infection: 109.1049 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9902 - val_f1_infection: 0.7873
# Epoch 84/100
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4127 - dice_coef_infection: 0.6128 - iou_coef_infection: 0.4786 - precision_infection: 0.6496 - recall_infection: 0.6605 - hausdorff95_infection: 70.9431 - specificity_infection: 0.9977 - accuracy_infection: 0.9952 - f1_infection: 0.8106 - val_loss: 0.5677 - val_dice_coef_infection: 0.5578 - val_iou_coef_infection: 0.5518 - val_precision_infection: 0.9456 - val_recall_infection: 0.5709 - val_hausdorff95_infection: 130.1900 - val_specificity_infection: 1.0000 - val_accuracy_infection: 0.9895 - val_f1_infection: 0.7914
# Epoch 85/100
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4546 - dice_coef_infection: 0.5729 - iou_coef_infection: 0.4415 - precision_infection: 0.6274 - recall_infection: 0.6173 - hausdorff95_infection: 72.5464 - specificity_infection: 0.9978 - accuracy_infection: 0.9951 - f1_infection: 0.7990 - val_loss: 0.5203 - val_dice_coef_infection: 0.5669 - val_iou_coef_infection: 0.5467 - val_precision_infection: 0.8762 - val_recall_infection: 0.5951 - val_hausdorff95_infection: 103.7018 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9911 - val_f1_infection: 0.8047
# Epoch 86/100
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4011 - dice_coef_infection: 0.6246 - iou_coef_infection: 0.4858 - precision_infection: 0.6553 - recall_infection: 0.6735 - hausdorff95_infection: 70.4221 - specificity_infection: 0.9976 - accuracy_infection: 0.9950 - f1_infection: 0.8088 - val_loss: 0.6204 - val_dice_coef_infection: 0.4777 - val_iou_coef_infection: 0.4576 - val_precision_infection: 0.7251 - val_recall_infection: 0.5927 - val_hausdorff95_infection: 106.5492 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9905 - val_f1_infection: 0.7925
# Epoch 87/100
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4105 - dice_coef_infection: 0.6160 - iou_coef_infection: 0.4797 - precision_infection: 0.6536 - recall_infection: 0.6623 - hausdorff95_infection: 67.5521 - specificity_infection: 0.9977 - accuracy_infection: 0.9951 - f1_infection: 0.8085 - val_loss: 0.5724 - val_dice_coef_infection: 0.5099 - val_iou_coef_infection: 0.4873 - val_precision_infection: 0.7212 - val_recall_infection: 0.6001 - val_hausdorff95_infection: 101.5708 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9914 - val_f1_infection: 0.8194
# Epoch 88/100
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4073 - dice_coef_infection: 0.6171 - iou_coef_infection: 0.4841 - precision_infection: 0.6394 - recall_infection: 0.6728 - hausdorff95_infection: 69.5114 - specificity_infection: 0.9976 - accuracy_infection: 0.9952 - f1_infection: 0.8153 - val_loss: 0.5761 - val_dice_coef_infection: 0.5409 - val_iou_coef_infection: 0.5273 - val_precision_infection: 0.8677 - val_recall_infection: 0.5821 - val_hausdorff95_infection: 110.1169 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9899 - val_f1_infection: 0.7956
# Epoch 89/100
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 337s 295ms/step - loss: 0.3933 - dice_coef_infection: 0.6307 - iou_coef_infection: 0.4944 - precision_infection: 0.6514 - recall_infection: 0.6785 - hausdorff95_infection: 66.1818 - specificity_infection: 0.9978 - accuracy_infection: 0.9954 - f1_infection: 0.8161 - val_loss: 0.5561 - val_dice_coef_infection: 0.5249 - val_iou_coef_infection: 0.4988 - val_precision_infection: 0.7871 - val_recall_infection: 0.6057 - val_hausdorff95_infection: 102.0563 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9912 - val_f1_infection: 0.7958
# Epoch 90/100
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 337s 295ms/step - loss: 0.4009 - dice_coef_infection: 0.6232 - iou_coef_infection: 0.4864 - precision_infection: 0.6351 - recall_infection: 0.6910 - hausdorff95_infection: 67.8772 - specificity_infection: 0.9976 - accuracy_infection: 0.9952 - f1_infection: 0.8103 - val_loss: 0.5662 - val_dice_coef_infection: 0.5269 - val_iou_coef_infection: 0.5080 - val_precision_infection: 0.7714 - val_recall_infection: 0.5915 - val_hausdorff95_infection: 104.2282 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9908 - val_f1_infection: 0.8154
# Epoch 91/100
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 337s 295ms/step - loss: 0.3989 - dice_coef_infection: 0.6262 - iou_coef_infection: 0.4861 - precision_infection: 0.6560 - recall_infection: 0.6683 - hausdorff95_infection: 68.2518 - specificity_infection: 0.9976 - accuracy_infection: 0.9951 - f1_infection: 0.8100 - val_loss: 0.5188 - val_dice_coef_infection: 0.5828 - val_iou_coef_infection: 0.5631 - val_precision_infection: 0.9154 - val_recall_infection: 0.5928 - val_hausdorff95_infection: 103.6049 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9905 - val_f1_infection: 0.8060
# Epoch 92/100
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 337s 295ms/step - loss: 0.3902 - dice_coef_infection: 0.6322 - iou_coef_infection: 0.4982 - precision_infection: 0.6511 - recall_infection: 0.6857 - hausdorff95_infection: 62.3333 - specificity_infection: 0.9977 - accuracy_infection: 0.9955 - f1_infection: 0.8183 - val_loss: 0.5639 - val_dice_coef_infection: 0.5328 - val_iou_coef_infection: 0.5131 - val_precision_infection: 0.7997 - val_recall_infection: 0.5917 - val_hausdorff95_infection: 97.8788 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9906 - val_f1_infection: 0.8113
# Epoch 93/100
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.3940 - dice_coef_infection: 0.6305 - iou_coef_infection: 0.4922 - precision_infection: 0.6589 - recall_infection: 0.6776 - hausdorff95_infection: 67.8314 - specificity_infection: 0.9978 - accuracy_infection: 0.9953 - f1_infection: 0.8118 - val_loss: 0.5686 - val_dice_coef_infection: 0.5309 - val_iou_coef_infection: 0.5133 - val_precision_infection: 0.8139 - val_recall_infection: 0.5903 - val_hausdorff95_infection: 106.8600 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9906 - val_f1_infection: 0.8035
# 🛑 Early stopping at epoch 93
# ✅ Total training time: 31340.43 seconds (522.34 minutes)

# %% [markdown]
# ## Plotting the performance metrics

# %%
plt.plot(history.history['dice_coef_infection'])
plt.plot(history.history['val_dice_coef_infection'])
plt.title('dice_coef_infection vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Dice_coef')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# %%
plt.plot(history.history['iou_coef_infection'])
plt.plot(history.history['val_iou_coef_infection'])
plt.title('iou_coef_infection vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Iou_coef')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Val'], loc = 'upper right')
plt.show()

# %% [markdown]
# ## Using our trained model for prediction

# %%
import numpy as np
import time

# Start timer (high precision)
start_time = time.perf_counter()

# Evaluate the model on the validation generator
results = model.evaluate(val_gen, verbose=1)

# End timer
end_time = time.perf_counter()

# Calculate evaluation time
eval_time = end_time - start_time

# Print metric names with results
print("\n===== Validation Metrics =====")
for name, value in zip(model.metrics_names, results):
    print(f"{name}: {value:.6f}")

print(f"\nEvaluation Time: {eval_time:.8f} seconds\n")
# Out:
# 128/128 [==============================] - 13s 104ms/step - loss: 0.4669 - dice_coef_infection: 0.5865 - iou_coef_infection: 0.5532 - precision_infection: 0.7582 - recall_infection: 0.6825 - hausdorff95_infection: 72.4440 - specificity_infection: 0.9998 - accuracy_infection: 0.9958 - f1_infection: 0.8299
#
# ===== Validation Metrics =====
# loss: 0.466892
# dice_coef_infection: 0.586523
# iou_coef_infection: 0.553178
# precision_infection: 0.758191
# recall_infection: 0.682460
# hausdorff95_infection: 72.443993
# specificity_infection: 0.999807
# accuracy_infection: 0.995832
# f1_infection: 0.829948
#
# Evaluation Time: 13.39030120 seconds

# %%
import matplotlib.pyplot as plt
import numpy as np

# Run inference if not already done
predicted = model.predict(lung_test)

# Selected indices to visualize (744 as 1st, 280 as 2nd, 230 as 3rd)
selected_indices = [744, 280, 230]
n_samples = len(selected_indices)

# Mapping indices to custom names
name_mapping = {
    0: ("Image1_Covid", "GT1_Covid", "Predict1_Covid_DSEG_Unet"),  # Index 744
    1: ("Image2_Covid", "GT2_Covid", "Predict2_Covid_DSEG_Unet"),  # Index 280
    2: ("Image3_Covid", "GT3_Covid", "Predict3_Covid_DSEG_Unet")   # Index 230
}

# Plot
for j, i in enumerate(selected_indices):
    lung_img = lung_test[i][..., 0].astype(np.float32)
    gt_infect = (infect_test[i][..., 0] > 0.5).astype(np.float32)
    pred_infect = predicted[i][..., 0].astype(np.float32)

    # Normalize lung image
    if lung_img.max() > lung_img.min():
        lung_img = (lung_img - lung_img.min()) / (lung_img.max() - lung_img.min())
    lung_img = np.clip(lung_img, 0, 1)
    pred_infect = np.clip(pred_infect, 0, 1)

    # Get custom names for this index
    input_name, gt_name, pred_name = name_mapping[j]

    # Save Original Lung
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{input_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

    # Save Ground Truth Infection
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.imshow(gt_infect, cmap='Reds', alpha=0.6)
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{gt_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

    # Save Predicted Infection
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.imshow(pred_infect, cmap='Reds', alpha=0.6)
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{pred_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

print("Separate JPEG files saved for input images (Image1_Covid, Image2_Covid, Image3_Covid), "
      "ground truths (GT1_Covid, GT2_Covid, GT3_Covid), and predictions "
      "(Predict1_Covid_DSEG_Unet, Predict2_Covid_DSEG_Unet, Predict3_Covid_DSEG_Unet).")
# Out:
# Separate JPEG files saved for input images (Image1_Covid, Image2_Covid, Image3_Covid), ground truths (GT1_Covid, GT2_Covid, GT3_Covid), and predictions (Predict1_Covid_DSEG_Unet, Predict2_Covid_DSEG_Unet, Predict3_Covid_DSEG_Unet).
