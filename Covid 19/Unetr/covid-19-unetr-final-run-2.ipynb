# %% [markdown]
# ## Importing important libraries

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import nibabel as nib #for loading nii files
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf #for deep learning

# %% [markdown]
# ## Reading the metadata

# %%
data = pd.read_csv('../input/covid19-ct-scans/metadata.csv')
data.head()
# Out:
#                                              ct_scan  \
# 0  ../input/covid19-ct-scans/ct_scans/coronacases...
# 1  ../input/covid19-ct-scans/ct_scans/coronacases...
# 2  ../input/covid19-ct-scans/ct_scans/coronacases...
# 3  ../input/covid19-ct-scans/ct_scans/coronacases...
# 4  ../input/covid19-ct-scans/ct_scans/coronacases...
#
#                                            lung_mask  \
# 0  ../input/covid19-ct-scans/lung_mask/coronacase...
# 1  ../input/covid19-ct-scans/lung_mask/coronacase...
# 2  ../input/covid19-ct-scans/lung_mask/coronacase...
# 3  ../input/covid19-ct-scans/lung_mask/coronacase...
# 4  ../input/covid19-ct-scans/lung_mask/coronacase...
#
#                                       infection_mask  \
# 0  ../input/covid19-ct-scans/infection_mask/coron...
# 1  ../input/covid19-ct-scans/infection_mask/coron...
# 2  ../input/covid19-ct-scans/infection_mask/coron...
# 3  ../input/covid19-ct-scans/infection_mask/coron...
# 4  ../input/covid19-ct-scans/infection_mask/coron...
#
#                              lung_and_infection_mask
# 0  ../input/covid19-ct-scans/lung_and_infection_m...
# 1  ../input/covid19-ct-scans/lung_and_infection_m...
# 2  ../input/covid19-ct-scans/lung_and_infection_m...
# 3  ../input/covid19-ct-scans/lung_and_infection_m...
# 4  ../input/covid19-ct-scans/lung_and_infection_m...

# %% [markdown]
# ## Defining function for readiing .nii files

# %%
def read_nii(filepath):
    '''
    Reads .nii file and returns pixel array
    '''
    ct_scan = nib.load(filepath)
    array   = ct_scan.get_fdata()
    array   = np.rot90(np.array(array))
    return(array)

# %% [markdown]
# ## Reading the chest ct scan data

# %%
# Read sample
sample_ct   = read_nii(data.loc[2,'ct_scan'])
sample_lung = read_nii(data.loc[2,'lung_mask'])
sample_infe = read_nii(data.loc[2,'infection_mask'])
sample_all  = read_nii(data.loc[2,'lung_and_infection_mask'])

# %% [markdown]
# ## Plotting the sample images

# %%
fig = plt.figure(figsize = (18,15))
plt.subplot(1,4,1)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.title('Original Image')

plt.subplot(1,4,2)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_lung[..., 150],alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung Mask')

plt.subplot(1,4,3)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_infe[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Infection Mask')

plt.subplot(1,4,4)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_all[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung and Infection Mask')
# Out:
# Text(0.5, 1.0, 'Lung and Infection Mask')

# %% [markdown]
# ## Converting the data into array for training model

# %%
import numpy as np
import cv2
import random
from scipy.ndimage import rotate, shift, zoom

lungs = []
infections = []
case_ids = []
img_size = 320

# ----------- Load and Resize Data -----------
for case_index in range(len(data)):
    ct = read_nii(data['ct_scan'][case_index])
    infect = read_nii(data['infection_mask'][case_index])

    for slice_index in range(ct.shape[0]):
        lung_img = cv2.resize(ct[slice_index], dsize=(img_size, img_size)).astype('float32')
        infec_img = cv2.resize(infect[slice_index], dsize=(img_size, img_size)).astype('float32')

        lungs.append(lung_img[..., np.newaxis])
        infections.append(infec_img[..., np.newaxis])
        case_ids.append(case_index)

# %%
import numpy as np

# case_ids should be a NumPy array telling which case each slice belongs to
# Convert and binarize
lungs = np.array(lungs, dtype=np.float32)
infections = (np.array(infections, dtype=np.uint8) > 0.5).astype(np.uint8)
case_ids = np.array(case_ids)

# %% [markdown]
# ## Performing test and train split

# %%
# ----------- Case-wise Split -----------
unique_cases = np.unique(case_ids)
train_cases = np.append(unique_cases[2:4], unique_cases[6:20])
temp_cases = unique_cases[4:6]
val_cases = unique_cases[:2]

train_mask = np.isin(case_ids, train_cases)
temp_mask = np.isin(case_ids, temp_cases)
val_mask = np.isin(case_ids, val_cases)

lung_train = lungs[train_mask]
infect_train = infections[train_mask]
lung_temp = lungs[temp_mask]
infect_temp = infections[temp_mask]
lung_test = lungs[val_mask]
infect_test = infections[val_mask]

print(f"✅ Train: {lung_train.shape[0]} slices from {len(train_cases)} cases")
print(f"✅ Validation: {lung_temp.shape[0]} slices from {len(temp_cases)} cases")
print(f"✅ Test: {lung_test.shape[0]} slices from {len(val_cases)} cases")

# ----------- Augmentation -----------
def augment_image(img, mask):
    if random.random() < 0.5:
        img = np.fliplr(img)
        mask = np.fliplr(mask)
    if random.random() < 0.5:
        img = np.flipud(img)
        mask = np.flipud(mask)

    angle = random.uniform(-15, 15)
    img = rotate(img, angle, reshape=False, order=1, mode='nearest')
    mask = rotate(mask, angle, reshape=False, order=0, mode='nearest')

    shift_val = np.random.uniform(-0.1, 0.1, size=2) * img.shape[:2]
    img = shift(img, shift=(*shift_val, 0), order=1, mode='nearest')
    mask = shift(mask, shift=(*shift_val, 0), order=0, mode='nearest')

    zoom_factor = random.uniform(0.9, 1.1)
    img = zoom(img, (zoom_factor, zoom_factor, 1), order=1)
    mask = zoom(mask, (zoom_factor, zoom_factor, 1), order=0)

    return fix_shape(img), fix_shape(mask)

def fix_shape(arr, target_size=(320, 320)):
    h, w, c = arr.shape
    th, tw = target_size
    dh = th - h
    dw = tw - w
    if dh > 0 or dw > 0:
        pad_h = (max(dh // 2, 0), max(dh - dh // 2, 0))
        pad_w = (max(dw // 2, 0), max(dw - dw // 2, 0))
        arr = np.pad(arr, (pad_h, pad_w, (0, 0)), mode='constant')
    arr = arr[:th, :tw, :]
    return arr.astype('float32')

# ----------- Apply Augmentation -----------
aug_lung_train = []
aug_infect_train = []

for i in range(len(lung_train)):
    img, mask = augment_image(lung_train[i], infect_train[i])
    aug_lung_train.append(img)
    aug_infect_train.append(mask)

lung_train = np.stack(aug_lung_train)
infect_train = np.stack(aug_infect_train)

# Final Binarization
infect_train = (infect_train > 0.5).astype(np.uint8)
infect_test = (infect_test > 0.5).astype(np.uint8)

print(f"✅ Augmented training shape: {lung_train.shape}")
print("✅ All preprocessing complete.")
# Out:
# ✅ Train: 9143 slices from 16 cases
# ✅ Validation: 1024 slices from 2 cases
# ✅ Test: 1024 slices from 2 cases
# ✅ Augmented training shape: (9143, 320, 320, 1)
# ✅ All preprocessing complete.

# %%
import tensorflow as tf
from tensorflow.keras import backend as K
import numpy as np
from scipy.spatial import cKDTree

smooth = 1.0

# Binary Dice coefficient (soft - commonly used during training)
def dice_coef_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# Binary IoU coefficient (soft)
def iou_coef_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# Soft Precision
def precision_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + smooth) / (K.sum(y_pred_f) + smooth)

# Soft Recall (Sensitivity)
def recall_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + smooth) / (K.sum(y_true_f) + smooth)

# Soft Specificity
def specificity_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    tn = K.sum((1 - y_true_f) * (1 - y_pred_f))
    fp = K.sum((1 - y_true_f) * y_pred_f)
    return (tn + smooth) / (tn + fp + smooth)

# Soft Accuracy
def accuracy_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    tp = K.sum(y_true_f * y_pred_f)
    tn = K.sum((1 - y_true_f) * (1 - y_pred_f))
    total = K.cast(K.shape(y_true_f)[0], 'float32')
    return (tp + tn + smooth) / (total + smooth)

# Soft F1-score (harmonic mean of precision & recall - very close to Dice, standard in many repos)
def f1_infection(y_true, y_pred):
    precision = precision_infection(y_true, y_pred)
    recall    = recall_infection(y_true, y_pred)
    return (2. * precision * recall + smooth) / (precision + recall + smooth)

# Hausdorff Distance 95 % (robust & most commonly used in medical imaging challenges)
# Lower = better. Returns the mean HD95 over the batch.
def _calculate_hd95(y_true, y_pred):
    hd_list = []
    for i in range(y_true.shape[0]):
        # Hard threshold at 0.5 (standard for evaluation metrics)
        gt = np.squeeze(y_true[i]) > 0.5
        pred = np.squeeze(y_pred[i]) > 0.5

        gt_pts = np.argwhere(gt)
        pred_pts = np.argwhere(pred)

        # Cases with empty masks
        if gt_pts.shape[0] == 0 and pred_pts.shape[0] == 0:
            hd_list.append(0.0)
            continue
        if gt_pts.shape[0] == 0 or pred_pts.shape[0] == 0:
            hd_list.append(400.0)  # large penalty - adjust to your image diagonal if needed (e.g. ~362 for 256×256, ~724 for 512×512)
            continue

        # Directed distances
        dist_gt_to_pred = cKDTree(pred_pts).query(gt_pts)[0]
        dist_pred_to_gt = cKDTree(gt_pts).query(pred_pts)[0]

        hd95 = max(
            np.percentile(dist_gt_to_pred, 95),
            np.percentile(dist_pred_to_gt, 95)
        )
        hd_list.append(hd95)

    return np.mean(hd_list, dtype=np.float32)

def hausdorff95_infection(y_true, y_pred):
    hd = tf.numpy_function(_calculate_hd95, [y_true, y_pred], tf.float32)
    hd.set_shape(())
    return hd

# Optional: KL Divergence (you already had this)
kld = tf.keras.losses.KLDivergence()

# %%
from tensorflow.keras.losses import BinaryCrossentropy

def loss_f(y_true, y_pred):
    bce = BinaryCrossentropy()
    return dice_loss(y_true, y_pred) + bce(y_true, y_pred) 

def loss_e(y_true, y_pred):
    bce = BinaryCrossentropy()
    return dice_loss(y_true, y_pred)  + kld(y_true, y_pred)
    
def dice_loss(y_true, y_pred):
    return 1. - dice_coef_infection(y_true, y_pred)

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Multiply, Conv2D, DepthwiseConv2D, Dense, Flatten, MaxPooling2D, UpSampling2D, concatenate, Activation, LayerNormalization, Add, Dropout, Conv2DTranspose, multiply, Reshape, GlobalAveragePooling2D, Permute, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Concatenate

def activation_block(x):
    x = Activation("gelu")(x)
    return LayerNormalization()(x)

def conv_stem(x, filters: int, patch_size: int):
    x = Conv2D(filters, kernel_size=patch_size,padding='same', strides=patch_size)(x)
    return activation_block(x)

def vector_block(xyz, cmf, red):
    # red means reduction
    # cmf means filters, denotes vector size
    opt1 = conv_stem(xyz, cmf, red)
    opt2 = conv_stem(xyz, cmf, red)
    
    o1 = GlobalAveragePooling2D()(opt1)
    o2 = GlobalAveragePooling2D()(opt2)

    o5 = concatenate([o1, o2], -1)
    return o5

def mlp_feature(vect, cmf):
    oo = Flatten()(vect)
    o6 = Dense(cmf, activation='gelu')(oo)
    o6 = Dropout(0.2)(o6)
    o6 = Dense(cmf * 2, activation='gelu')(o6)

    o6 = Reshape((1, cmf * 2))(o6)
    o7 = Permute((2, 1))(o6)

    o8 = multiply([o6, o7])
    
    o8 = Lambda(lambda x: tf.expand_dims(x, -1))(o8)
    
    o8 = Reshape((cmf, cmf, 4))(o8)

    return o8

def frz_block(xyz):
    shape = xyz.shape
    a1, a2, a3, a4 = shape[0], shape[1], shape[2], shape[3]
    cmf = a2
    o5 = vector_block(xyz, cmf, 5)
    o7 = mlp_feature(o5, cmf)

    o7 = concatenate([o7, xyz, o7], -1)
    return o7

def up_frz(x1, x2, n_filters):
    # Upsample x1 using Conv2DTranspose
    x1 = Conv2DTranspose(n_filters * 4, 3, strides=2, activation='gelu', padding="same")(x1)
    
    # Apply Conv2D to x2
    x2 = Conv2D(n_filters * 2, 3, activation='gelu', padding="same")(x2)
    
    # Apply attention mechanism
    x = concatenate([x1, x2])
    
    # Apply Dropout for regularization
    x = Dropout(0.3)(x)
    
    return x

# %%
import numpy as np
import tensorflow as tf
import tensorflow_addons as tfa
import keras
import keras.backend as K
from keras.layers import (Layer, BatchNormalization, LayerNormalization, Conv2D, Conv2DTranspose, Embedding, 
    Activation, Dense, Dropout, MultiHeadAttention, add, Input, concatenate, GlobalAveragePooling1D)
from keras.models import Model

def mlp(x, hidden_units, dropout_rate):
    if not isinstance(hidden_units, list): hidden_units = [hidden_units]
    for units in hidden_units:
        x = Dense(units, activation=tf.nn.gelu)(x)
        x = Dropout(dropout_rate)(x)
    return x

class Patches(Layer):
    def __init__(self, patch_size, **kwargs):
        super(Patches, self).__init__(**kwargs)
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding='VALID',
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

    def compute_output_shape(self, input_shape):
        batch_size, height, width, channels = input_shape
        patch_height = height // self.patch_size
        patch_width = width // self.patch_size
        patch_dim = channels * (self.patch_size ** 2)
        return (batch_size, patch_height * patch_width, patch_dim)

    def get_config(self):  # Add configuration for saving
        config = super(Patches, self).get_config()
        config.update({
            'patch_size': self.patch_size
        })
        return config



class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim, **kwargs):
        super().__init__(**kwargs)
        self.num_patches = num_patches
        self.projection_dim = projection_dim
        self.projection = layers.Dense(projection_dim)
        self.position_embedding = layers.Embedding(input_dim=num_patches, output_dim=projection_dim)

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

    # Add this method
    def get_config(self):
        config = super().get_config()
        config.update({
            'num_patches': self.num_patches,
            'projection_dim': self.projection_dim,
        })
        return config



def normalization(input_tensor, normalization, name=None):

    if normalization=='batch':
        return(BatchNormalization(name=None if name is None else name + '_batchnorm')(input_tensor))
    elif normalization=='layer':
        return(LayerNormalization(epsilon=1e-6, name=None if name is None else name + '_layernorm')(input_tensor))
    elif normalization=='group':
        return(tfa.layers.GroupNormalization(groups=8, name=None if name is None else name + '_groupnorm')(input_tensor))
    elif normalization == None:
        return input_tensor
    else:
        raise ValueError('Invalid normalization')

def conv_norm_act(input_tensor, filters, kernel_size , norm_type='batch', act_type='relu', dilation=1):
    '''
    Conv2d + Normalization(norm_type:str) + Activation(act_type:str)
    '''
    output_tensor = Conv2D(filters, kernel_size, padding='same', dilation_rate=(dilation, dilation), use_bias=False if norm_type is not None else True, kernel_initializer='he_normal')(input_tensor)
    output_tensor = normalization(output_tensor, normalization=norm_type)
    if act_type is not None: output_tensor = Activation(act_type)(output_tensor)

    return output_tensor

def conv2d_block(input_tensor, filters, kernel_size, 
                norm_type, use_residual, act_type='relu',
                double_features = False, dilation=[1, 1], name=None):

    x = Conv2D(filters, kernel_size, padding='same', dilation_rate=dilation[0], use_bias=False, kernel_initializer='he_normal', name=None if name is None else name + '_conv2d_0')(input_tensor)
    x = normalization(x, norm_type, name=None if name is None else name + '_0')
    x = Activation(act_type, name=None if name is None else name + act_type + '_0')(x)

    if double_features:
        filters *= 2

    x = Conv2D(filters, kernel_size, padding='same', dilation_rate=dilation[1], use_bias=False, kernel_initializer='he_normal', name=None if name is None else name + '_conv2d_1')(x)
    x = normalization(x, norm_type, name=None if name is None else name + '_1')

    if use_residual:
        if K.int_shape(input_tensor)[-1] != K.int_shape(x)[-1]:
            shortcut = Conv2D(filters, kernel_size=1, padding='same', use_bias=False, kernel_initializer='he_normal', name=None if name is None else name + '_shortcut_conv2d')(input_tensor)
            shortcut = normalization(shortcut, norm_type, name=None if name is None else name + '_shortcut')
            x = add([x, shortcut])
        else:
            x = add([x, input_tensor])

    x = Activation(act_type, name=None if name is None else name + act_type + '_0')(x)

    return x

def deconv_conv_block(x,
                      filters_list: list,
                      kernel_size,
                      norm_type,
                      act_type,
                      ):
    '''
    Corresponding to the blue block in the UNETR architecture diagram
    '''
    for filts in filters_list:
        x = Conv2DTranspose(filts, 2, (2, 2), kernel_initializer='he_normal')(x)
        x = conv_norm_act(x, filts, kernel_size, norm_type, act_type)
    return x

def conv_deconv_block(x,
                      filters,
                      kernel_size,
                      norm_type,
                      use_residual,
                      act_type,
                      ):
    '''
    Corresponding to the yellow + green block in the UNETR architecture diagram
    '''
    x = conv2d_block(x, filters, kernel_size, norm_type, use_residual, act_type)
    x = Conv2DTranspose(filters // 2, 2, (2, 2), kernel_initializer='he_normal')(x)
    return x


def create_vit(x,
               patch_size,
               num_patches,
               projection_dim,
               num_heads,
               transformer_units,
               transformer_layers,
               dropout_rate,
               extract_layers,
               ):
    skip_connections = []

    # Create patches.
    patches = Patches(patch_size)(x)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for layer in range(transformer_layers):
        # Layer normalization 1.
        x1 = LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim//num_heads, dropout=dropout_rate
        )(x1, x1)
        # Skip connection 1.
        x2 = add([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=dropout_rate)
        # Skip connection 2.
        encoded_patches = add([x3, x2])
        if layer + 1 in extract_layers:
            skip_connections.append(encoded_patches)

    return skip_connections


def build_model(
    # ↓ Base arguments
    input_shape,
    class_nums,
    # ↓ ViT arguments
    patch_size,
    projection_dim,
    num_heads,
    transformer_units,
    transformer_layers,
    extract_layers,
    dropout_rate=0.1,
    # ↓ Conv arguments
    kernel_size=3,
    conv_norm='batch',
    conv_act='relu',
    use_residual=False,
    # ↓ Other arguments
    show_summary=False,
    output_act='sigmoid',
):
    '''
    input_shape: tuple, (height, width, channel) note that this network is used for 2D image segmentation tasks
    class_nums: int, output channels
    patch_size: int, image partition size
    projection_dim: int, projection dimensions in ViT
    num_heads: int, nums of heads for MultiHeadAttention
    transformer_units: list, the number of hidden units of the MLP module in ViT, note that it is in the form of a list, should be [hidden units, projection_dims]
    transformer_layers: int, transformer stacking nums
    extract_layers: list, Determine which layers in ViT should be added to the "skip connection", the default is [3, 6, 9, 12]
    dropout_rate: float, dropout ratio for the ViT part
    kernel_size: int, kernel size for convolution block
    conv_norm: str, The normalization method of the convolutional layer, 'batch' or 'layer' or 'group'
    conv_act: str, activation function for convolution layer
    use_residual: bool, whether the convolution module uses residual connections
    show_summary: bool, whether to show the model overview
    output_act: str, The activation function of the output layer will be determined according to class_nums when 'auto'
      (i.e. 'sigmoid' for binary segmentation task, 'softmax' for multi-class segmentation task)
    '''

    z5_de_filts = 512
    z4_de_filts_list = [512]
    z3_de_filts_list = [512, 256]
    z2_de_filts_list = [512, 256, 128]
    z1_de_filts_list = [512, 256, 128, 64]
    z45_conv_filts = 512
    z34_conv_filts = 256
    z23_conv_filts = 128
    z12_conv_filts = 64
    z01_conv_filts = 32

    if output_act == 'auto':
        output_act = 'sigmoid' if class_nums == 1 else 'softmax'

    assert input_shape[0] == input_shape[1] and input_shape[0] % patch_size == 0
    num_patches = (input_shape[0] * input_shape[1]) // (patch_size ** 2)

    inputs = Input(input_shape)
    z0 = inputs

    z1, z2, z3, z4, z5 = create_vit(
        z0,
        patch_size,
        num_patches,
        projection_dim,
        num_heads,
        transformer_units,
        transformer_layers,
        dropout_rate,
        extract_layers
    )

    z1 = tf.reshape(z1, (-1, input_shape[0] // patch_size, input_shape[1] // patch_size, projection_dim))
    z2 = tf.reshape(z2, (-1, input_shape[0] // patch_size, input_shape[1] // patch_size, projection_dim))
    z3 = tf.reshape(z3, (-1, input_shape[0] // patch_size, input_shape[1] // patch_size, projection_dim))
    z4 = tf.reshape(z4, (-1, input_shape[0] // patch_size, input_shape[1] // patch_size, projection_dim))
    z5 = tf.reshape(z5, (-1, input_shape[0] // patch_size, input_shape[1] // patch_size, projection_dim))

    z5 = Conv2DTranspose(z5_de_filts, 2, (2, 2), kernel_initializer='he_normal')(z5)
    z4 = deconv_conv_block(z4, z4_de_filts_list, kernel_size, conv_norm, conv_act)
    z4 = concatenate([z4, z5])
    z4 = conv_deconv_block(z4, z45_conv_filts, kernel_size, conv_norm, use_residual, conv_act)
    z3 = deconv_conv_block(z3, z3_de_filts_list, kernel_size, conv_norm, conv_act)
    z3 = concatenate([z3, z4])
    z3 = conv_deconv_block(z3, z34_conv_filts, kernel_size, conv_norm, use_residual, conv_act)
    z2 = deconv_conv_block(z2, z2_de_filts_list, kernel_size, conv_norm, conv_act)
    z2 = concatenate([z2, z3])
    z2 = conv_deconv_block(z2, z23_conv_filts, kernel_size, conv_norm, use_residual, conv_act)
    z1 = deconv_conv_block(z1, z1_de_filts_list, kernel_size, conv_norm, conv_act)
    z1 = concatenate([z1, z2])
    z1 = conv_deconv_block(z1, z12_conv_filts, kernel_size, conv_norm, use_residual, conv_act)
    z0 = conv2d_block(z0, z01_conv_filts, kernel_size, conv_norm, use_residual, conv_act)
    z0 = concatenate([z0, z1])
    z0 = conv2d_block(z0, z01_conv_filts, kernel_size, conv_norm, use_residual, conv_act)

    outputs = Conv2D(class_nums, 1, activation=output_act)(z0)

    model = Model(inputs=inputs, outputs=outputs)

    if show_summary:
        model.summary()

    return model
    
model = build_model(
    input_shape=(320, 320, 1), 
    class_nums=1,
    patch_size=32,
    projection_dim=768,
    num_heads=1,
    transformer_units=[3072, 768],
    transformer_layers=10,
    extract_layers=[2, 4, 6, 8, 10],
    dropout_rate=0.0,
    kernel_size=3,
    conv_norm='batch',
    conv_act='relu',
    use_residual=False,
    show_summary=False,  # Turn on for debugging
    output_act='sigmoid'
)

# %%
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2_as_graph

def get_flops(model):
    """Calculate Floating Point Operations (FLOPs) of a Keras model in TensorFlow 2.x."""
    # Convert Keras model to a TensorFlow function
    concrete_func = tf.function(lambda inputs: model(inputs))
    concrete_func = concrete_func.get_concrete_function(
        tf.TensorSpec([1] + list(model.input_shape[1:]), model.input.dtype)
    )

    # Convert to frozen graph
    frozen_func, _ = convert_variables_to_constants_v2_as_graph(concrete_func)

    # Compute FLOPs
    flops = tf.compat.v1.profiler.profile(
        frozen_func.graph,
        options=tf.compat.v1.profiler.ProfileOptionBuilder.float_operation(),
    )

    return flops.total_float_ops

# Compute FLOPs
flops = get_flops(model)
print(f"Total FLOPs: {flops / 1e9:.2f} GFLOPs")  # Convert to GFLOPs

from tensorflow.keras.optimizers import Adam

optimizer = Adam(learning_rate=1e-3)
model.compile(optimizer=optimizer, loss=loss_f, metrics=[dice_coef_infection, iou_coef_infection, precision_infection, recall_infection, hausdorff95_infection, specificity_infection, accuracy_infection, f1_infection])

# Model summary
model.summary()
# Out:
# Total FLOPs: 64.54 GFLOPs
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 320, 320, 1) 0
# __________________________________________________________________________________________________
# patches (Patches)               (None, None, 1024)   0           input_1[0][0]
# __________________________________________________________________________________________________
# patch_encoder (PatchEncoder)    (None, 100, 768)     864000      patches[0][0]
# __________________________________________________________________________________________________
# layer_normalization (LayerNorma (None, 100, 768)     1536        patch_encoder[0][0]
# __________________________________________________________________________________________________
# multi_head_attention (MultiHead (None, 100, 768)     2362368     layer_normalization[0][0]
#                                                                  layer_normalization[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 100, 768)     0           multi_head_attention[0][0]
#                                                                  patch_encoder[0][0]
# __________________________________________________________________________________________________
# layer_normalization_1 (LayerNor (None, 100, 768)     1536        add[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100, 3072)    2362368     layer_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 100, 3072)    0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 100, 768)     2360064     dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 100, 768)     0           dense_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 100, 768)     0           dropout_1[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# layer_normalization_2 (LayerNor (None, 100, 768)     1536        add_1[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_1 (MultiHe (None, 100, 768)     2362368     layer_normalization_2[0][0]
#                                                                  layer_normalization_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 100, 768)     0           multi_head_attention_1[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# layer_normalization_3 (LayerNor (None, 100, 768)     1536        add_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 100, 3072)    2362368     layer_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 100, 3072)    0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 100, 768)     2360064     dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 100, 768)     0           dense_4[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 100, 768)     0           dropout_3[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# layer_normalization_4 (LayerNor (None, 100, 768)     1536        add_3[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_2 (MultiHe (None, 100, 768)     2362368     layer_normalization_4[0][0]
#                                                                  layer_normalization_4[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 100, 768)     0           multi_head_attention_2[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# layer_normalization_5 (LayerNor (None, 100, 768)     1536        add_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 100, 3072)    2362368     layer_normalization_5[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 100, 3072)    0           dense_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 100, 768)     2360064     dropout_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 100, 768)     0           dense_6[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 100, 768)     0           dropout_5[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# layer_normalization_6 (LayerNor (None, 100, 768)     1536        add_5[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_3 (MultiHe (None, 100, 768)     2362368     layer_normalization_6[0][0]
#                                                                  layer_normalization_6[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 100, 768)     0           multi_head_attention_3[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# layer_normalization_7 (LayerNor (None, 100, 768)     1536        add_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 100, 3072)    2362368     layer_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 100, 3072)    0           dense_7[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 100, 768)     2360064     dropout_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 100, 768)     0           dense_8[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 100, 768)     0           dropout_7[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# layer_normalization_8 (LayerNor (None, 100, 768)     1536        add_7[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_4 (MultiHe (None, 100, 768)     2362368     layer_normalization_8[0][0]
#                                                                  layer_normalization_8[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 100, 768)     0           multi_head_attention_4[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# layer_normalization_9 (LayerNor (None, 100, 768)     1536        add_8[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 100, 3072)    2362368     layer_normalization_9[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 100, 3072)    0           dense_9[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 100, 768)     2360064     dropout_8[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 100, 768)     0           dense_10[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 100, 768)     0           dropout_9[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# layer_normalization_10 (LayerNo (None, 100, 768)     1536        add_9[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_5 (MultiHe (None, 100, 768)     2362368     layer_normalization_10[0][0]
#                                                                  layer_normalization_10[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 100, 768)     0           multi_head_attention_5[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# layer_normalization_11 (LayerNo (None, 100, 768)     1536        add_10[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 100, 3072)    2362368     layer_normalization_11[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 100, 3072)    0           dense_11[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 100, 768)     2360064     dropout_10[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 100, 768)     0           dense_12[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 100, 768)     0           dropout_11[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# layer_normalization_12 (LayerNo (None, 100, 768)     1536        add_11[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_6 (MultiHe (None, 100, 768)     2362368     layer_normalization_12[0][0]
#                                                                  layer_normalization_12[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 100, 768)     0           multi_head_attention_6[0][0]
#                                                                  add_11[0][0]
# __________________________________________________________________________________________________
# layer_normalization_13 (LayerNo (None, 100, 768)     1536        add_12[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 100, 3072)    2362368     layer_normalization_13[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 100, 3072)    0           dense_13[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 100, 768)     2360064     dropout_12[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 100, 768)     0           dense_14[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 100, 768)     0           dropout_13[0][0]
#                                                                  add_12[0][0]
# __________________________________________________________________________________________________
# layer_normalization_14 (LayerNo (None, 100, 768)     1536        add_13[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_7 (MultiHe (None, 100, 768)     2362368     layer_normalization_14[0][0]
#                                                                  layer_normalization_14[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 100, 768)     0           multi_head_attention_7[0][0]
#                                                                  add_13[0][0]
# __________________________________________________________________________________________________
# layer_normalization_15 (LayerNo (None, 100, 768)     1536        add_14[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 100, 3072)    2362368     layer_normalization_15[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 100, 3072)    0           dense_15[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 100, 768)     2360064     dropout_14[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 100, 768)     0           dense_16[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 100, 768)     0           dropout_15[0][0]
#                                                                  add_14[0][0]
# __________________________________________________________________________________________________
# layer_normalization_16 (LayerNo (None, 100, 768)     1536        add_15[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_8 (MultiHe (None, 100, 768)     2362368     layer_normalization_16[0][0]
#                                                                  layer_normalization_16[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 100, 768)     0           multi_head_attention_8[0][0]
#                                                                  add_15[0][0]
# __________________________________________________________________________________________________
# layer_normalization_17 (LayerNo (None, 100, 768)     1536        add_16[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 100, 3072)    2362368     layer_normalization_17[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 100, 3072)    0           dense_17[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 100, 768)     2360064     dropout_16[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 100, 768)     0           dense_18[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 100, 768)     0           dropout_17[0][0]
#                                                                  add_16[0][0]
# __________________________________________________________________________________________________
# layer_normalization_18 (LayerNo (None, 100, 768)     1536        add_17[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_9 (MultiHe (None, 100, 768)     2362368     layer_normalization_18[0][0]
#                                                                  layer_normalization_18[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 100, 768)     0           multi_head_attention_9[0][0]
#                                                                  add_17[0][0]
# __________________________________________________________________________________________________
# layer_normalization_19 (LayerNo (None, 100, 768)     1536        add_18[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 100, 3072)    2362368     layer_normalization_19[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 100, 3072)    0           dense_19[0][0]
# __________________________________________________________________________________________________
# tf.reshape_3 (TFOpLambda)       (None, 10, 10, 768)  0           add_15[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 100, 768)     2360064     dropout_18[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 20, 20, 512)  1573376     tf.reshape_3[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 100, 768)     0           dense_20[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 20, 20, 512)  2359296     conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 100, 768)     0           dropout_19[0][0]
#                                                                  add_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 20, 20, 512)  2048        conv2d[0][0]
# __________________________________________________________________________________________________
# tf.reshape_4 (TFOpLambda)       (None, 10, 10, 768)  0           add_19[0][0]
# __________________________________________________________________________________________________
# tf.reshape_2 (TFOpLambda)       (None, 10, 10, 768)  0           add_11[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 20, 20, 512)  0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 20, 20, 512)  1573376     tf.reshape_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 20, 20, 512)  1573376     tf.reshape_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 20, 20, 1024) 0           activation[0][0]
#                                                                  conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 20, 20, 512)  2359296     conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 20, 20, 512)  4718592     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 20, 20, 512)  2048        conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 20, 20, 512)  2048        conv2d_1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_1 (TFOpLambda)       (None, 10, 10, 768)  0           add_7[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 20, 20, 512)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 20, 20, 512)  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 20, 20, 512)  1573376     tf.reshape_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 40, 40, 256)  524544      activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 20, 20, 512)  2359296     activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 20, 20, 512)  2359296     conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 40, 40, 256)  589824      conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 20, 20, 512)  2048        conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 20, 20, 512)  2048        conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 40, 40, 256)  1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 20, 20, 512)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# tf.reshape (TFOpLambda)         (None, 10, 10, 768)  0           add_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 20, 20, 512)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 40, 40, 256)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 40, 40, 256)  524544      activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTran (None, 20, 20, 512)  1573376     tf.reshape[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 40, 40, 256)  524544      activation_7[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 40, 40, 512)  0           activation_4[0][0]
#                                                                  conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 20, 20, 512)  2359296     conv2d_transpose_10[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 40, 40, 256)  589824      conv2d_transpose_7[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 40, 40, 256)  1179648     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 20, 20, 512)  2048        conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 40, 40, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 40, 40, 256)  1024        conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 20, 20, 512)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 40, 40, 256)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 40, 40, 256)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 40, 40, 256)  524544      activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 80, 80, 128)  131200      activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 40, 40, 256)  589824      activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 40, 40, 256)  589824      conv2d_transpose_11[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 80, 80, 128)  147456      conv2d_transpose_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 40, 40, 256)  1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 40, 40, 256)  1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 80, 80, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 40, 40, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 40, 40, 256)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 80, 80, 128)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 80, 80, 128)  131200      activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_12 (Conv2DTran (None, 80, 80, 128)  131200      activation_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 80, 80, 256)  0           activation_9[0][0]
#                                                                  conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 80, 80, 128)  147456      conv2d_transpose_12[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 80, 80, 128)  294912      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 80, 80, 128)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 80, 80, 128)  512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 80, 80, 128)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 80, 80, 128)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_13 (Conv2DTran (None, 160, 160, 64) 32832       activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 80, 80, 128)  147456      activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 160, 160, 64) 36864       conv2d_transpose_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 80, 80, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 160, 160, 64) 256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 80, 80, 128)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 160, 160, 64) 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 160, 160, 64) 32832       activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 160, 160, 128 0           activation_15[0][0]
#                                                                  conv2d_transpose_9[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 160, 160, 64) 73728       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 320, 320, 32) 288         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 160, 160, 64) 256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 320, 320, 32) 128         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 160, 160, 64) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 320, 320, 32) 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 160, 160, 64) 36864       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 320, 320, 32) 9216        activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 160, 160, 64) 256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 320, 320, 32) 128         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 160, 160, 64) 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 320, 320, 32) 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_14 (Conv2DTran (None, 320, 320, 32) 8224        activation_17[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 320, 320, 64) 0           activation_19[0][0]
#                                                                  conv2d_transpose_14[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 320, 320, 32) 18432       concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 320, 320, 32) 128         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 320, 320, 32) 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 320, 320, 32) 9216        activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 320, 320, 32) 128         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 320, 320, 32) 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 320, 320, 1)  33          activation_21[0][0]
# ==================================================================================================
# Total params: 103,171,937
# Trainable params: 103,161,569
# Non-trainable params: 10,368
# __________________________________________________________________________________________________

# %%
# Install required packages
# !pip install openpyxl

# Imports
import openpyxl  # required for reading .xlsx files
import pandas as pd
import tensorflow as tf
import os
import shutil
from tensorflow.keras.callbacks import LearningRateScheduler, ReduceLROnPlateau

# File paths
checkpoint_filepath = '/kaggle/working/checkpoint.h5.keras'
metrics_file = '/kaggle/working/training_metrics.xlsx'
pre_checkpoint_filepath = '/kaggle/input/swinunet-covid19-finalrun-1/checkpoint.h5.keras'
pre_metrics_file = '/kaggle/input/swinunet-covid19-finalrun-1/training_metrics.xlsx'

# Restore checkpoint and metrics if available
if os.path.exists(pre_checkpoint_filepath):
    shutil.copy(pre_checkpoint_filepath, checkpoint_filepath)
    print(f"Restored checkpoint from: {pre_checkpoint_filepath}")

if os.path.exists(pre_metrics_file):
    shutil.copy(pre_metrics_file, metrics_file)
    print(f"Restored metrics file from: {pre_metrics_file}")

# Load last epoch
def load_last_epoch():
    if os.path.exists(metrics_file):
        try:
            df = pd.read_excel(metrics_file, engine='openpyxl')
            if not df.empty and 'epoch' in df.columns:
                return df['epoch'].iloc[-1] + 1
        except Exception as e:
            print(f"⚠️ Could not read metrics file: {e}")
    return 0

last_epoch = load_last_epoch()

# Get best validation loss from previous runs
def get_best_val_loss():
    if os.path.exists(metrics_file):
        try:
            df = pd.read_excel(metrics_file, engine='openpyxl')
            if 'val_loss' in df.columns and not df['val_loss'].isnull().all():
                return df['val_loss'].min()
        except Exception as e:
            print(f"⚠️ Could not read val_loss from metrics file: {e}")
    return float('inf')

best_val_loss = get_best_val_loss()

# Custom model checkpoint
class CustomModelCheckpoint(tf.keras.callbacks.Callback):
    def __init__(self, filepath):
        super().__init__()
        self.filepath = filepath
        self.best_loss = best_val_loss

    def on_epoch_end(self, epoch, logs=None):
        current_loss = logs.get('val_loss')
        if current_loss is not None and current_loss < self.best_loss:
            self.best_loss = current_loss
            self.model.save(self.filepath)
            print(f"✅ Model saved at epoch {epoch + 1} with val_loss: {current_loss:.4f}")

# === Learning Rate Schedule ===
def lr_schedule(epoch, lr):
    return 1e-4 if epoch >= 1 else lr

lr_scheduler = LearningRateScheduler(lr_schedule, verbose=1)

# Logger for Excel
class MetricsLogger(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        df_new = pd.DataFrame([{**logs, 'epoch': epoch}])
        try:
            if os.path.exists(metrics_file):
                df = pd.read_excel(metrics_file, engine='openpyxl')
                df = pd.concat([df, df_new], ignore_index=True)
            else:
                df = df_new
            df.to_excel(metrics_file, index=False, engine='openpyxl')
        except Exception as e:
            print(f"⚠️ Failed to log metrics: {e}")

# Early stopping with patience and saving best weights
class CustomEarlyStopping(tf.keras.callbacks.Callback):
    def __init__(self, patience=20):
        super().__init__()
        self.patience = patience
        self.wait = 0
        self.best_loss = best_val_loss

    def on_epoch_end(self, epoch, logs=None):
        current_loss = logs.get('val_loss')
        if current_loss is None:
            return
        if current_loss < self.best_loss:
            self.best_loss = current_loss
            self.wait = 0
            self.model.save_weights(checkpoint_filepath)
        else:
            self.wait += 1
            if self.wait >= self.patience:
                print(f"🛑 Early stopping at epoch {epoch + 1}")
                self.model.stop_training = True


# Final callbacks list
callbacks = [
    CustomModelCheckpoint(filepath=checkpoint_filepath),
    MetricsLogger(),
    lr_scheduler,
    CustomEarlyStopping(patience=20)
]
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.3-py2.py3-none-any.whl (251 kB)
#      |████████████████████████████████| 251 kB 11.9 MB/s eta 0:00:01
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.3

# %% [markdown]
# ## Training the model

# %%
import time
import os
import pandas as pd
import numpy as np
from tensorflow.keras.utils import Sequence
from tensorflow.keras.models import load_model

EPOCHS = 100

# Record the start time
start_time = time.time()

# === Load last completed epoch from metrics file ===
def load_last_epoch():
    if os.path.exists(pre_metrics_file):
        try:
            df = pd.read_excel(pre_metrics_file, engine='openpyxl')
            if not df.empty and 'epoch' in df.columns:
                return int(df['epoch'].iloc[-1]) + 1
        except Exception as e:
            print(f"⚠️ Failed to read metrics file: {e}")
    return 0

last_epoch = load_last_epoch()

# === Load pretrained weights if available ===
if os.path.exists(pre_checkpoint_filepath):
    print("✅ Checkpoint found. Loading pretrained weights...")
    model.load_weights(pre_checkpoint_filepath)
    print(f"🔁 Resuming training from epoch {last_epoch}")
else:
    print("🆕 No checkpoint found. Starting training from scratch.")
    last_epoch = 0

# === Prepare input and label tensors ===
lung_train = np.asarray(lung_train, dtype=np.float16)
infect_train = np.asarray(infect_train, dtype=np.uint8)

lung_temp = np.asarray(lung_temp, dtype=np.float16)
infect_temp = np.asarray(infect_temp, dtype=np.uint8)

lung_test = np.asarray(lung_test, dtype=np.float16)
infect_test = np.asarray(infect_test, dtype=np.uint8)

# === Data Generator ===
class LungDataGenerator(Sequence):
    def __init__(self, X, Y, batch_size=8, shuffle=True):
        self.X = X
        self.Y = Y
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indices = np.arange(len(X))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.X) / self.batch_size))

    def __getitem__(self, index):
        batch_ids = self.indices[index * self.batch_size:(index + 1) * self.batch_size]
        X_batch = self.X[batch_ids]
        Y_batch = self.Y[batch_ids]
        return np.asarray(X_batch, dtype=np.float16), np.asarray(Y_batch, dtype=np.uint8)

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indices)

# === Create generators ===
train_gen = LungDataGenerator(lung_train, infect_train, batch_size=8)
temp_gen = LungDataGenerator(lung_temp, infect_temp, batch_size=8, shuffle=False)
val_gen = LungDataGenerator(lung_test, infect_test, batch_size=8, shuffle=False)

# === Train the model ===
history = model.fit(
    train_gen,
    validation_data=temp_gen,
    epochs=EPOCHS,
    initial_epoch=last_epoch,
    callbacks=callbacks
)

# === Timing info ===
end_time = time.time()
total_time = end_time - start_time
print(f"✅ Total training time: {total_time:.2f} seconds ({total_time / 60:.2f} minutes)")
# Out:
# 🆕 No checkpoint found. Starting training from scratch.
# Epoch 1/100
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 356s 295ms/step - loss: 1.0803 - dice_coef_infection: 0.0594 - iou_coef_infection: 0.0331 - precision_infection: 0.0463 - recall_infection: 0.2150 - hausdorff95_infection: 169.5006 - specificity_infection: 0.9019 - accuracy_infection: 0.8947 - f1_infection: 0.8298 - val_loss: 0.9945 - val_dice_coef_infection: 0.0294 - val_iou_coef_infection: 0.0168 - val_precision_infection: 0.0235 - val_recall_infection: 0.8375 - val_hausdorff95_infection: 274.0057 - val_specificity_infection: 0.9864 - val_accuracy_infection: 0.9849 - val_f1_infection: 0.5633
# ✅ Model saved at epoch 1 with val_loss: 0.9945
# Epoch 2/100
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 334s 293ms/step - loss: 0.7873 - dice_coef_infection: 0.2584 - iou_coef_infection: 0.1628 - precision_infection: 0.2409 - recall_infection: 0.4061 - hausdorff95_infection: 170.6768 - specificity_infection: 0.9879 - accuracy_infection: 0.9818 - f1_infection: 0.7543 - val_loss: 0.9669 - val_dice_coef_infection: 0.0422 - val_iou_coef_infection: 0.0259 - val_precision_infection: 0.0648 - val_recall_infection: 0.8130 - val_hausdorff95_infection: 152.9554 - val_specificity_infection: 0.9987 - val_accuracy_infection: 0.9969 - val_f1_infection: 0.5668
# ✅ Model saved at epoch 2 with val_loss: 0.9669
# Epoch 3/100
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.7300 - dice_coef_infection: 0.3083 - iou_coef_infection: 0.1989 - precision_infection: 0.2965 - recall_infection: 0.4397 - hausdorff95_infection: 158.2806 - specificity_infection: 0.9907 - accuracy_infection: 0.9851 - f1_infection: 0.7481 - val_loss: 0.9550 - val_dice_coef_infection: 0.0533 - val_iou_coef_infection: 0.0333 - val_precision_infection: 0.0689 - val_recall_infection: 0.8288 - val_hausdorff95_infection: 183.7556 - val_specificity_infection: 0.9983 - val_accuracy_infection: 0.9967 - val_f1_infection: 0.5643
# ✅ Model saved at epoch 3 with val_loss: 0.9550
# Epoch 4/100
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.6889 - dice_coef_infection: 0.3465 - iou_coef_infection: 0.2303 - precision_infection: 0.3400 - recall_infection: 0.4633 - hausdorff95_infection: 145.4709 - specificity_infection: 0.9921 - accuracy_infection: 0.9871 - f1_infection: 0.7534 - val_loss: 0.9535 - val_dice_coef_infection: 0.0547 - val_iou_coef_infection: 0.0354 - val_precision_infection: 0.0836 - val_recall_infection: 0.8229 - val_hausdorff95_infection: 136.1099 - val_specificity_infection: 0.9990 - val_accuracy_infection: 0.9974 - val_f1_infection: 0.5669
# ✅ Model saved at epoch 4 with val_loss: 0.9535
# Epoch 5/100
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.6790 - dice_coef_infection: 0.3548 - iou_coef_infection: 0.2366 - precision_infection: 0.3535 - recall_infection: 0.4789 - hausdorff95_infection: 141.4072 - specificity_infection: 0.9932 - accuracy_infection: 0.9885 - f1_infection: 0.7499 - val_loss: 0.9286 - val_dice_coef_infection: 0.0800 - val_iou_coef_infection: 0.0629 - val_precision_infection: 0.1304 - val_recall_infection: 0.8152 - val_hausdorff95_infection: 67.6286 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9980 - val_f1_infection: 0.5863
# ✅ Model saved at epoch 5 with val_loss: 0.9286
# Epoch 6/100
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.6411 - dice_coef_infection: 0.3937 - iou_coef_infection: 0.2677 - precision_infection: 0.3993 - recall_infection: 0.4948 - hausdorff95_infection: 138.4179 - specificity_infection: 0.9936 - accuracy_infection: 0.9889 - f1_infection: 0.7564 - val_loss: 0.9496 - val_dice_coef_infection: 0.0599 - val_iou_coef_infection: 0.0430 - val_precision_infection: 0.0868 - val_recall_infection: 0.8185 - val_hausdorff95_infection: 86.8925 - val_specificity_infection: 0.9992 - val_accuracy_infection: 0.9975 - val_f1_infection: 0.5768
# Epoch 7/100
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.6255 - dice_coef_infection: 0.4083 - iou_coef_infection: 0.2807 - precision_infection: 0.4200 - recall_infection: 0.5185 - hausdorff95_infection: 128.5733 - specificity_infection: 0.9943 - accuracy_infection: 0.9898 - f1_infection: 0.7518 - val_loss: 0.9246 - val_dice_coef_infection: 0.0831 - val_iou_coef_infection: 0.0631 - val_precision_infection: 0.1313 - val_recall_infection: 0.8261 - val_hausdorff95_infection: 77.7012 - val_specificity_infection: 0.9996 - val_accuracy_infection: 0.9982 - val_f1_infection: 0.5801
# ✅ Model saved at epoch 7 with val_loss: 0.9246
# Epoch 8/100
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.6225 - dice_coef_infection: 0.4117 - iou_coef_infection: 0.2833 - precision_infection: 0.4230 - recall_infection: 0.5087 - hausdorff95_infection: 133.2207 - specificity_infection: 0.9943 - accuracy_infection: 0.9899 - f1_infection: 0.7576 - val_loss: 0.8972 - val_dice_coef_infection: 0.1116 - val_iou_coef_infection: 0.0940 - val_precision_infection: 0.1753 - val_recall_infection: 0.8203 - val_hausdorff95_infection: 64.2865 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9983 - val_f1_infection: 0.6016
# ✅ Model saved at epoch 8 with val_loss: 0.8972
# Epoch 9/100
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.6001 - dice_coef_infection: 0.4347 - iou_coef_infection: 0.3027 - precision_infection: 0.4435 - recall_infection: 0.5334 - hausdorff95_infection: 123.5207 - specificity_infection: 0.9945 - accuracy_infection: 0.9900 - f1_infection: 0.7583 - val_loss: 0.8727 - val_dice_coef_infection: 0.1362 - val_iou_coef_infection: 0.1195 - val_precision_infection: 0.2060 - val_recall_infection: 0.8174 - val_hausdorff95_infection: 75.9318 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9983 - val_f1_infection: 0.6172
# ✅ Model saved at epoch 9 with val_loss: 0.8727
# Epoch 10/100
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.5872 - dice_coef_infection: 0.4467 - iou_coef_infection: 0.3144 - precision_infection: 0.4592 - recall_infection: 0.5367 - hausdorff95_infection: 120.4482 - specificity_infection: 0.9950 - accuracy_infection: 0.9905 - f1_infection: 0.7634 - val_loss: 0.7642 - val_dice_coef_infection: 0.2474 - val_iou_coef_infection: 0.2345 - val_precision_infection: 0.3278 - val_recall_infection: 0.8090 - val_hausdorff95_infection: 48.6813 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9982 - val_f1_infection: 0.6794
# ✅ Model saved at epoch 10 with val_loss: 0.7642
# Epoch 11/100
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.5912 - dice_coef_infection: 0.4423 - iou_coef_infection: 0.3113 - precision_infection: 0.4553 - recall_infection: 0.5382 - hausdorff95_infection: 121.5326 - specificity_infection: 0.9950 - accuracy_infection: 0.9908 - f1_infection: 0.7632 - val_loss: 0.8822 - val_dice_coef_infection: 0.1267 - val_iou_coef_infection: 0.1096 - val_precision_infection: 0.1925 - val_recall_infection: 0.8203 - val_hausdorff95_infection: 56.2380 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9983 - val_f1_infection: 0.6102
# Epoch 12/100
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.5741 - dice_coef_infection: 0.4587 - iou_coef_infection: 0.3251 - precision_infection: 0.4712 - recall_infection: 0.5415 - hausdorff95_infection: 115.5512 - specificity_infection: 0.9953 - accuracy_infection: 0.9912 - f1_infection: 0.7703 - val_loss: 0.8638 - val_dice_coef_infection: 0.1456 - val_iou_coef_infection: 0.1304 - val_precision_infection: 0.2197 - val_recall_infection: 0.8133 - val_hausdorff95_infection: 64.6253 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9983 - val_f1_infection: 0.6272
# Epoch 13/100
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.5690 - dice_coef_infection: 0.4653 - iou_coef_infection: 0.3318 - precision_infection: 0.4800 - recall_infection: 0.5574 - hausdorff95_infection: 113.3329 - specificity_infection: 0.9953 - accuracy_infection: 0.9910 - f1_infection: 0.7661 - val_loss: 0.9131 - val_dice_coef_infection: 0.0952 - val_iou_coef_infection: 0.0787 - val_precision_infection: 0.1614 - val_recall_infection: 0.8202 - val_hausdorff95_infection: 53.5570 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9984 - val_f1_infection: 0.5933
# Epoch 14/100
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.5696 - dice_coef_infection: 0.4639 - iou_coef_infection: 0.3304 - precision_infection: 0.4779 - recall_infection: 0.5615 - hausdorff95_infection: 111.0645 - specificity_infection: 0.9953 - accuracy_infection: 0.9912 - f1_infection: 0.7638 - val_loss: 0.9052 - val_dice_coef_infection: 0.1032 - val_iou_coef_infection: 0.0844 - val_precision_infection: 0.1703 - val_recall_infection: 0.8221 - val_hausdorff95_infection: 65.0255 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9983 - val_f1_infection: 0.5923
# Epoch 15/100
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.5618 - dice_coef_infection: 0.4708 - iou_coef_infection: 0.3363 - precision_infection: 0.4958 - recall_infection: 0.5523 - hausdorff95_infection: 110.1183 - specificity_infection: 0.9958 - accuracy_infection: 0.9916 - f1_infection: 0.7683 - val_loss: 0.8874 - val_dice_coef_infection: 0.1255 - val_iou_coef_infection: 0.1149 - val_precision_infection: 0.2054 - val_recall_infection: 0.7989 - val_hausdorff95_infection: 50.6147 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9980 - val_f1_infection: 0.6218
# Epoch 16/100
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.5669 - dice_coef_infection: 0.4657 - iou_coef_infection: 0.3321 - precision_infection: 0.4835 - recall_infection: 0.5580 - hausdorff95_infection: 109.6405 - specificity_infection: 0.9957 - accuracy_infection: 0.9917 - f1_infection: 0.7672 - val_loss: 0.8569 - val_dice_coef_infection: 0.1512 - val_iou_coef_infection: 0.1334 - val_precision_infection: 0.2225 - val_recall_infection: 0.8250 - val_hausdorff95_infection: 70.6846 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9984 - val_f1_infection: 0.6211
# Epoch 17/100
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.5467 - dice_coef_infection: 0.4843 - iou_coef_infection: 0.3478 - precision_infection: 0.5074 - recall_infection: 0.5732 - hausdorff95_infection: 106.4955 - specificity_infection: 0.9961 - accuracy_infection: 0.9922 - f1_infection: 0.7659 - val_loss: 0.8711 - val_dice_coef_infection: 0.1387 - val_iou_coef_infection: 0.1240 - val_precision_infection: 0.2206 - val_recall_infection: 0.8118 - val_hausdorff95_infection: 51.1617 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9983 - val_f1_infection: 0.6217
# Epoch 18/100
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.5530 - dice_coef_infection: 0.4813 - iou_coef_infection: 0.3458 - precision_infection: 0.5032 - recall_infection: 0.5537 - hausdorff95_infection: 108.9677 - specificity_infection: 0.9959 - accuracy_infection: 0.9916 - f1_infection: 0.7742 - val_loss: 0.8677 - val_dice_coef_infection: 0.1420 - val_iou_coef_infection: 0.1265 - val_precision_infection: 0.2235 - val_recall_infection: 0.8144 - val_hausdorff95_infection: 59.1774 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9983 - val_f1_infection: 0.6220
# Epoch 19/100
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.5424 - dice_coef_infection: 0.4892 - iou_coef_infection: 0.3534 - precision_infection: 0.5053 - recall_infection: 0.5571 - hausdorff95_infection: 107.0921 - specificity_infection: 0.9961 - accuracy_infection: 0.9923 - f1_infection: 0.7796 - val_loss: 0.8366 - val_dice_coef_infection: 0.1749 - val_iou_coef_infection: 0.1611 - val_precision_infection: 0.2626 - val_recall_infection: 0.8093 - val_hausdorff95_infection: 68.1163 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9982 - val_f1_infection: 0.6419
# Epoch 20/100
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 334s 293ms/step - loss: 0.5506 - dice_coef_infection: 0.4814 - iou_coef_infection: 0.3492 - precision_infection: 0.4993 - recall_infection: 0.5783 - hausdorff95_infection: 104.1374 - specificity_infection: 0.9961 - accuracy_infection: 0.9923 - f1_infection: 0.7712 - val_loss: 0.6603 - val_dice_coef_infection: 0.3516 - val_iou_coef_infection: 0.3377 - val_precision_infection: 0.4509 - val_recall_infection: 0.8098 - val_hausdorff95_infection: 43.3775 - val_specificity_infection: 1.0000 - val_accuracy_infection: 0.9983 - val_f1_infection: 0.7298
# ✅ Model saved at epoch 20 with val_loss: 0.6603
# Epoch 21/100
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 334s 292ms/step - loss: 0.5491 - dice_coef_infection: 0.4818 - iou_coef_infection: 0.3483 - precision_infection: 0.4952 - recall_infection: 0.5686 - hausdorff95_infection: 107.2169 - specificity_infection: 0.9961 - accuracy_infection: 0.9924 - f1_infection: 0.7737 - val_loss: 0.7540 - val_dice_coef_infection: 0.2566 - val_iou_coef_infection: 0.2428 - val_precision_infection: 0.3485 - val_recall_infection: 0.8113 - val_hausdorff95_infection: 45.9734 - val_specificity_infection: 1.0000 - val_accuracy_infection: 0.9983 - val_f1_infection: 0.6837
# Epoch 22/100
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 333s 292ms/step - loss: 0.5434 - dice_coef_infection: 0.4889 - iou_coef_infection: 0.3523 - precision_infection: 0.5052 - recall_infection: 0.5607 - hausdorff95_infection: 105.6801 - specificity_infection: 0.9961 - accuracy_infection: 0.9923 - f1_infection: 0.7765 - val_loss: 0.7149 - val_dice_coef_infection: 0.2933 - val_iou_coef_infection: 0.2753 - val_precision_infection: 0.3705 - val_recall_infection: 0.8291 - val_hausdorff95_infection: 77.9902 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9985 - val_f1_infection: 0.6895
# Epoch 23/100
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 333s 291ms/step - loss: 0.5421 - dice_coef_infection: 0.4892 - iou_coef_infection: 0.3553 - precision_infection: 0.5121 - recall_infection: 0.5700 - hausdorff95_infection: 104.3174 - specificity_infection: 0.9963 - accuracy_infection: 0.9926 - f1_infection: 0.7770 - val_loss: 0.7170 - val_dice_coef_infection: 0.2922 - val_iou_coef_infection: 0.2758 - val_precision_infection: 0.3746 - val_recall_infection: 0.8199 - val_hausdorff95_infection: 59.1246 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9984 - val_f1_infection: 0.6929
# Epoch 24/100
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 334s 292ms/step - loss: 0.5257 - dice_coef_infection: 0.5053 - iou_coef_infection: 0.3672 - precision_infection: 0.5206 - recall_infection: 0.5850 - hausdorff95_infection: 104.8426 - specificity_infection: 0.9962 - accuracy_infection: 0.9925 - f1_infection: 0.7752 - val_loss: 0.6770 - val_dice_coef_infection: 0.3321 - val_iou_coef_infection: 0.3148 - val_precision_infection: 0.4118 - val_recall_infection: 0.8246 - val_hausdorff95_infection: 65.9301 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9984 - val_f1_infection: 0.7081
# Epoch 25/100
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 334s 292ms/step - loss: 0.5191 - dice_coef_infection: 0.5119 - iou_coef_infection: 0.3758 - precision_infection: 0.5267 - recall_infection: 0.5844 - hausdorff95_infection: 100.5583 - specificity_infection: 0.9964 - accuracy_infection: 0.9927 - f1_infection: 0.7846 - val_loss: 0.6286 - val_dice_coef_infection: 0.3803 - val_iou_coef_infection: 0.3624 - val_precision_infection: 0.4640 - val_recall_infection: 0.8284 - val_hausdorff95_infection: 51.1019 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9985 - val_f1_infection: 0.7321
# ✅ Model saved at epoch 25 with val_loss: 0.6286
# Epoch 26/100
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 334s 293ms/step - loss: 0.5001 - dice_coef_infection: 0.5300 - iou_coef_infection: 0.3924 - precision_infection: 0.5460 - recall_infection: 0.6047 - hausdorff95_infection: 102.5189 - specificity_infection: 0.9965 - accuracy_infection: 0.9929 - f1_infection: 0.7850 - val_loss: 0.6757 - val_dice_coef_infection: 0.3337 - val_iou_coef_infection: 0.3164 - val_precision_infection: 0.4129 - val_recall_infection: 0.8251 - val_hausdorff95_infection: 78.1826 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9984 - val_f1_infection: 0.7092
# Epoch 27/100
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 334s 292ms/step - loss: 0.5095 - dice_coef_infection: 0.5206 - iou_coef_infection: 0.3840 - precision_infection: 0.5418 - recall_infection: 0.5969 - hausdorff95_infection: 99.6529 - specificity_infection: 0.9967 - accuracy_infection: 0.9931 - f1_infection: 0.7813 - val_loss: 0.6399 - val_dice_coef_infection: 0.3696 - val_iou_coef_infection: 0.3539 - val_precision_infection: 0.4552 - val_recall_infection: 0.8236 - val_hausdorff95_infection: 58.2511 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9985 - val_f1_infection: 0.7311
# Epoch 28/100
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 334s 292ms/step - loss: 0.4965 - dice_coef_infection: 0.5336 - iou_coef_infection: 0.3948 - precision_infection: 0.5509 - recall_infection: 0.5939 - hausdorff95_infection: 99.0412 - specificity_infection: 0.9966 - accuracy_infection: 0.9930 - f1_infection: 0.7872 - val_loss: 0.6634 - val_dice_coef_infection: 0.3464 - val_iou_coef_infection: 0.3298 - val_precision_infection: 0.4278 - val_recall_infection: 0.8230 - val_hausdorff95_infection: 65.5612 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9984 - val_f1_infection: 0.7243
# Epoch 29/100
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4857 - dice_coef_infection: 0.5447 - iou_coef_infection: 0.4061 - precision_infection: 0.5603 - recall_infection: 0.6096 - hausdorff95_infection: 97.9163 - specificity_infection: 0.9966 - accuracy_infection: 0.9931 - f1_infection: 0.7909 - val_loss: 0.7019 - val_dice_coef_infection: 0.3078 - val_iou_coef_infection: 0.2923 - val_precision_infection: 0.3987 - val_recall_infection: 0.8192 - val_hausdorff95_infection: 49.3036 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9984 - val_f1_infection: 0.7065
# Epoch 30/100
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4814 - dice_coef_infection: 0.5476 - iou_coef_infection: 0.4086 - precision_infection: 0.5650 - recall_infection: 0.6049 - hausdorff95_infection: 98.6498 - specificity_infection: 0.9968 - accuracy_infection: 0.9935 - f1_infection: 0.7903 - val_loss: 0.7232 - val_dice_coef_infection: 0.2839 - val_iou_coef_infection: 0.2625 - val_precision_infection: 0.3508 - val_recall_infection: 0.8411 - val_hausdorff95_infection: 68.2158 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9985 - val_f1_infection: 0.6804
# Epoch 31/100
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 334s 292ms/step - loss: 0.5016 - dice_coef_infection: 0.5271 - iou_coef_infection: 0.3915 - precision_infection: 0.5447 - recall_infection: 0.6019 - hausdorff95_infection: 96.5472 - specificity_infection: 0.9967 - accuracy_infection: 0.9935 - f1_infection: 0.7859 - val_loss: 0.5444 - val_dice_coef_infection: 0.4686 - val_iou_coef_infection: 0.4552 - val_precision_infection: 0.5711 - val_recall_infection: 0.8158 - val_hausdorff95_infection: 62.0693 - val_specificity_infection: 1.0000 - val_accuracy_infection: 0.9984 - val_f1_infection: 0.7786
# ✅ Model saved at epoch 31 with val_loss: 0.5444
# Epoch 32/100
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.5016 - dice_coef_infection: 0.5292 - iou_coef_infection: 0.3937 - precision_infection: 0.5498 - recall_infection: 0.6102 - hausdorff95_infection: 95.9259 - specificity_infection: 0.9968 - accuracy_infection: 0.9931 - f1_infection: 0.7843 - val_loss: 0.7232 - val_dice_coef_infection: 0.2863 - val_iou_coef_infection: 0.2686 - val_precision_infection: 0.3486 - val_recall_infection: 0.8271 - val_hausdorff95_infection: 90.4512 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9983 - val_f1_infection: 0.6894
# Epoch 33/100
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4913 - dice_coef_infection: 0.5377 - iou_coef_infection: 0.3975 - precision_infection: 0.5543 - recall_infection: 0.6043 - hausdorff95_infection: 96.7821 - specificity_infection: 0.9969 - accuracy_infection: 0.9935 - f1_infection: 0.7856 - val_loss: 0.7354 - val_dice_coef_infection: 0.2732 - val_iou_coef_infection: 0.2550 - val_precision_infection: 0.3442 - val_recall_infection: 0.8296 - val_hausdorff95_infection: 70.5799 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9985 - val_f1_infection: 0.6811
# Epoch 34/100
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 334s 292ms/step - loss: 0.4873 - dice_coef_infection: 0.5425 - iou_coef_infection: 0.4042 - precision_infection: 0.5628 - recall_infection: 0.5966 - hausdorff95_infection: 94.1723 - specificity_infection: 0.9969 - accuracy_infection: 0.9934 - f1_infection: 0.7940 - val_loss: 0.6511 - val_dice_coef_infection: 0.3599 - val_iou_coef_infection: 0.3438 - val_precision_infection: 0.4393 - val_recall_infection: 0.8209 - val_hausdorff95_infection: 75.6275 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9983 - val_f1_infection: 0.7290
# Epoch 35/100
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4854 - dice_coef_infection: 0.5437 - iou_coef_infection: 0.4048 - precision_infection: 0.5659 - recall_infection: 0.6018 - hausdorff95_infection: 96.4476 - specificity_infection: 0.9970 - accuracy_infection: 0.9936 - f1_infection: 0.7901 - val_loss: 0.7400 - val_dice_coef_infection: 0.2678 - val_iou_coef_infection: 0.2475 - val_precision_infection: 0.3342 - val_recall_infection: 0.8350 - val_hausdorff95_infection: 84.0199 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9984 - val_f1_infection: 0.6781
# Epoch 36/100
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4661 - dice_coef_infection: 0.5631 - iou_coef_infection: 0.4236 - precision_infection: 0.5774 - recall_infection: 0.6254 - hausdorff95_infection: 91.1515 - specificity_infection: 0.9968 - accuracy_infection: 0.9934 - f1_infection: 0.7941 - val_loss: 0.5975 - val_dice_coef_infection: 0.4126 - val_iou_coef_infection: 0.3950 - val_precision_infection: 0.5025 - val_recall_infection: 0.8210 - val_hausdorff95_infection: 56.1318 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9984 - val_f1_infection: 0.7462
# Epoch 37/100
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4772 - dice_coef_infection: 0.5503 - iou_coef_infection: 0.4128 - precision_infection: 0.5664 - recall_infection: 0.6124 - hausdorff95_infection: 89.9560 - specificity_infection: 0.9970 - accuracy_infection: 0.9938 - f1_infection: 0.7942 - val_loss: 0.7158 - val_dice_coef_infection: 0.2929 - val_iou_coef_infection: 0.2738 - val_precision_infection: 0.3701 - val_recall_infection: 0.8286 - val_hausdorff95_infection: 53.6742 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9985 - val_f1_infection: 0.6944
# Epoch 38/100
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4672 - dice_coef_infection: 0.5609 - iou_coef_infection: 0.4212 - precision_infection: 0.5775 - recall_infection: 0.6216 - hausdorff95_infection: 96.6941 - specificity_infection: 0.9970 - accuracy_infection: 0.9937 - f1_infection: 0.7937 - val_loss: 0.6571 - val_dice_coef_infection: 0.3524 - val_iou_coef_infection: 0.3353 - val_precision_infection: 0.4352 - val_recall_infection: 0.8246 - val_hausdorff95_infection: 72.9188 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9984 - val_f1_infection: 0.7173
# Epoch 39/100
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4840 - dice_coef_infection: 0.5449 - iou_coef_infection: 0.4085 - precision_infection: 0.5665 - recall_infection: 0.6130 - hausdorff95_infection: 90.1659 - specificity_infection: 0.9970 - accuracy_infection: 0.9937 - f1_infection: 0.7909 - val_loss: 0.6491 - val_dice_coef_infection: 0.3596 - val_iou_coef_infection: 0.3402 - val_precision_infection: 0.4317 - val_recall_infection: 0.8334 - val_hausdorff95_infection: 77.1181 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9984 - val_f1_infection: 0.7228
# Epoch 40/100
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4728 - dice_coef_infection: 0.5549 - iou_coef_infection: 0.4176 - precision_infection: 0.5668 - recall_infection: 0.6256 - hausdorff95_infection: 88.8061 - specificity_infection: 0.9970 - accuracy_infection: 0.9939 - f1_infection: 0.7940 - val_loss: 0.5333 - val_dice_coef_infection: 0.4764 - val_iou_coef_infection: 0.4572 - val_precision_infection: 0.5544 - val_recall_infection: 0.8310 - val_hausdorff95_infection: 53.6795 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9985 - val_f1_infection: 0.7787
# ✅ Model saved at epoch 40 with val_loss: 0.5333
# Epoch 41/100
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4599 - dice_coef_infection: 0.5695 - iou_coef_infection: 0.4302 - precision_infection: 0.5879 - recall_infection: 0.6325 - hausdorff95_infection: 86.8995 - specificity_infection: 0.9969 - accuracy_infection: 0.9934 - f1_infection: 0.7952 - val_loss: 0.6019 - val_dice_coef_infection: 0.4066 - val_iou_coef_infection: 0.3864 - val_precision_infection: 0.4827 - val_recall_infection: 0.8362 - val_hausdorff95_infection: 54.6740 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9986 - val_f1_infection: 0.7452
# Epoch 42/100
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4717 - dice_coef_infection: 0.5549 - iou_coef_infection: 0.4190 - precision_infection: 0.5729 - recall_infection: 0.6196 - hausdorff95_infection: 93.3738 - specificity_infection: 0.9971 - accuracy_infection: 0.9941 - f1_infection: 0.7956 - val_loss: 0.6191 - val_dice_coef_infection: 0.3917 - val_iou_coef_infection: 0.3749 - val_precision_infection: 0.4711 - val_recall_infection: 0.8226 - val_hausdorff95_infection: 61.0357 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9984 - val_f1_infection: 0.7398
# Epoch 43/100
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4687 - dice_coef_infection: 0.5585 - iou_coef_infection: 0.4221 - precision_infection: 0.5743 - recall_infection: 0.6310 - hausdorff95_infection: 87.6853 - specificity_infection: 0.9970 - accuracy_infection: 0.9939 - f1_infection: 0.7924 - val_loss: 0.5614 - val_dice_coef_infection: 0.4473 - val_iou_coef_infection: 0.4286 - val_precision_infection: 0.5313 - val_recall_infection: 0.8302 - val_hausdorff95_infection: 44.3018 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9986 - val_f1_infection: 0.7689
# Epoch 44/100
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4601 - dice_coef_infection: 0.5674 - iou_coef_infection: 0.4294 - precision_infection: 0.5834 - recall_infection: 0.6310 - hausdorff95_infection: 88.1399 - specificity_infection: 0.9972 - accuracy_infection: 0.9942 - f1_infection: 0.7967 - val_loss: 0.5941 - val_dice_coef_infection: 0.4161 - val_iou_coef_infection: 0.4000 - val_precision_infection: 0.5039 - val_recall_infection: 0.8249 - val_hausdorff95_infection: 60.7077 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9985 - val_f1_infection: 0.7498
# Epoch 45/100
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 294ms/step - loss: 0.4667 - dice_coef_infection: 0.5610 - iou_coef_infection: 0.4236 - precision_infection: 0.5805 - recall_infection: 0.6283 - hausdorff95_infection: 88.0863 - specificity_infection: 0.9971 - accuracy_infection: 0.9940 - f1_infection: 0.7943 - val_loss: 0.6708 - val_dice_coef_infection: 0.3376 - val_iou_coef_infection: 0.3173 - val_precision_infection: 0.4112 - val_recall_infection: 0.8366 - val_hausdorff95_infection: 74.5486 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9986 - val_f1_infection: 0.7081
# Epoch 46/100
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 294ms/step - loss: 0.4475 - dice_coef_infection: 0.5788 - iou_coef_infection: 0.4410 - precision_infection: 0.5940 - recall_infection: 0.6433 - hausdorff95_infection: 86.4193 - specificity_infection: 0.9972 - accuracy_infection: 0.9942 - f1_infection: 0.7990 - val_loss: 0.6287 - val_dice_coef_infection: 0.3797 - val_iou_coef_infection: 0.3605 - val_precision_infection: 0.4619 - val_recall_infection: 0.8291 - val_hausdorff95_infection: 45.4729 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9985 - val_f1_infection: 0.7346
# Epoch 47/100
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4376 - dice_coef_infection: 0.5895 - iou_coef_infection: 0.4493 - precision_infection: 0.6046 - recall_infection: 0.6395 - hausdorff95_infection: 85.4538 - specificity_infection: 0.9971 - accuracy_infection: 0.9941 - f1_infection: 0.8044 - val_loss: 0.5712 - val_dice_coef_infection: 0.4362 - val_iou_coef_infection: 0.4149 - val_precision_infection: 0.5157 - val_recall_infection: 0.8403 - val_hausdorff95_infection: 59.3109 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9986 - val_f1_infection: 0.7575
# Epoch 48/100
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4453 - dice_coef_infection: 0.5822 - iou_coef_infection: 0.4454 - precision_infection: 0.5988 - recall_infection: 0.6348 - hausdorff95_infection: 86.2109 - specificity_infection: 0.9971 - accuracy_infection: 0.9940 - f1_infection: 0.8065 - val_loss: 0.6990 - val_dice_coef_infection: 0.3100 - val_iou_coef_infection: 0.2902 - val_precision_infection: 0.3772 - val_recall_infection: 0.8327 - val_hausdorff95_infection: 90.4724 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9985 - val_f1_infection: 0.6951
# Epoch 49/100
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4655 - dice_coef_infection: 0.5609 - iou_coef_infection: 0.4262 - precision_infection: 0.5758 - recall_infection: 0.6278 - hausdorff95_infection: 86.4100 - specificity_infection: 0.9972 - accuracy_infection: 0.9942 - f1_infection: 0.7981 - val_loss: 0.4438 - val_dice_coef_infection: 0.5663 - val_iou_coef_infection: 0.5485 - val_precision_infection: 0.6714 - val_recall_infection: 0.8235 - val_hausdorff95_infection: 41.4030 - val_specificity_infection: 1.0000 - val_accuracy_infection: 0.9985 - val_f1_infection: 0.8187
# ✅ Model saved at epoch 49 with val_loss: 0.4438
# Epoch 50/100
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4402 - dice_coef_infection: 0.5854 - iou_coef_infection: 0.4441 - precision_infection: 0.5999 - recall_infection: 0.6400 - hausdorff95_infection: 81.9553 - specificity_infection: 0.9974 - accuracy_infection: 0.9944 - f1_infection: 0.7988 - val_loss: 0.5926 - val_dice_coef_infection: 0.4156 - val_iou_coef_infection: 0.3944 - val_precision_infection: 0.4866 - val_recall_infection: 0.8431 - val_hausdorff95_infection: 73.8192 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9986 - val_f1_infection: 0.7413
# Epoch 51/100
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4437 - dice_coef_infection: 0.5817 - iou_coef_infection: 0.4435 - precision_infection: 0.5936 - recall_infection: 0.6469 - hausdorff95_infection: 85.2945 - specificity_infection: 0.9972 - accuracy_infection: 0.9944 - f1_infection: 0.7987 - val_loss: 0.5534 - val_dice_coef_infection: 0.4574 - val_iou_coef_infection: 0.4410 - val_precision_infection: 0.5381 - val_recall_infection: 0.8282 - val_hausdorff95_infection: 65.9496 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9985 - val_f1_infection: 0.7695
# Epoch 52/100
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4525 - dice_coef_infection: 0.5755 - iou_coef_infection: 0.4388 - precision_infection: 0.5877 - recall_infection: 0.6501 - hausdorff95_infection: 83.8241 - specificity_infection: 0.9969 - accuracy_infection: 0.9939 - f1_infection: 0.7958 - val_loss: 0.5177 - val_dice_coef_infection: 0.4942 - val_iou_coef_infection: 0.4777 - val_precision_infection: 0.5864 - val_recall_infection: 0.8240 - val_hausdorff95_infection: 61.8037 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9985 - val_f1_infection: 0.7885
# Epoch 53/100
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4231 - dice_coef_infection: 0.6025 - iou_coef_infection: 0.4656 - precision_infection: 0.6146 - recall_infection: 0.6615 - hausdorff95_infection: 80.9485 - specificity_infection: 0.9973 - accuracy_infection: 0.9944 - f1_infection: 0.8068 - val_loss: 0.5400 - val_dice_coef_infection: 0.4701 - val_iou_coef_infection: 0.4516 - val_precision_infection: 0.5575 - val_recall_infection: 0.8274 - val_hausdorff95_infection: 58.8908 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9985 - val_f1_infection: 0.7758
# Epoch 54/100
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 294ms/step - loss: 0.4385 - dice_coef_infection: 0.5881 - iou_coef_infection: 0.4504 - precision_infection: 0.6042 - recall_infection: 0.6428 - hausdorff95_infection: 83.0638 - specificity_infection: 0.9973 - accuracy_infection: 0.9943 - f1_infection: 0.8031 - val_loss: 0.5380 - val_dice_coef_infection: 0.4728 - val_iou_coef_infection: 0.4547 - val_precision_infection: 0.5495 - val_recall_infection: 0.8317 - val_hausdorff95_infection: 61.9264 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9985 - val_f1_infection: 0.7782
# Epoch 55/100
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4151 - dice_coef_infection: 0.6109 - iou_coef_infection: 0.4697 - precision_infection: 0.6310 - recall_infection: 0.6597 - hausdorff95_infection: 78.9379 - specificity_infection: 0.9973 - accuracy_infection: 0.9944 - f1_infection: 0.8045 - val_loss: 0.4737 - val_dice_coef_infection: 0.5350 - val_iou_coef_infection: 0.5151 - val_precision_infection: 0.6198 - val_recall_infection: 0.8353 - val_hausdorff95_infection: 52.6266 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9986 - val_f1_infection: 0.8005
# Epoch 56/100
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4285 - dice_coef_infection: 0.5979 - iou_coef_infection: 0.4597 - precision_infection: 0.6159 - recall_infection: 0.6556 - hausdorff95_infection: 81.6710 - specificity_infection: 0.9972 - accuracy_infection: 0.9943 - f1_infection: 0.8026 - val_loss: 0.4886 - val_dice_coef_infection: 0.5232 - val_iou_coef_infection: 0.5068 - val_precision_infection: 0.6162 - val_recall_infection: 0.8268 - val_hausdorff95_infection: 49.9848 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9985 - val_f1_infection: 0.7982
# Epoch 57/100
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4441 - dice_coef_infection: 0.5825 - iou_coef_infection: 0.4455 - precision_infection: 0.5962 - recall_infection: 0.6472 - hausdorff95_infection: 85.1600 - specificity_infection: 0.9972 - accuracy_infection: 0.9943 - f1_infection: 0.8011 - val_loss: 0.5279 - val_dice_coef_infection: 0.4817 - val_iou_coef_infection: 0.4634 - val_precision_infection: 0.5697 - val_recall_infection: 0.8324 - val_hausdorff95_infection: 52.0668 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9986 - val_f1_infection: 0.7798
# Epoch 58/100
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4355 - dice_coef_infection: 0.5909 - iou_coef_infection: 0.4499 - precision_infection: 0.6114 - recall_infection: 0.6507 - hausdorff95_infection: 80.9682 - specificity_infection: 0.9974 - accuracy_infection: 0.9945 - f1_infection: 0.7966 - val_loss: 0.5902 - val_dice_coef_infection: 0.4187 - val_iou_coef_infection: 0.4001 - val_precision_infection: 0.4993 - val_recall_infection: 0.8347 - val_hausdorff95_infection: 55.4760 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9986 - val_f1_infection: 0.7512
# Epoch 59/100
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 336s 294ms/step - loss: 0.4329 - dice_coef_infection: 0.5927 - iou_coef_infection: 0.4556 - precision_infection: 0.6160 - recall_infection: 0.6463 - hausdorff95_infection: 78.9137 - specificity_infection: 0.9974 - accuracy_infection: 0.9946 - f1_infection: 0.8036 - val_loss: 0.4418 - val_dice_coef_infection: 0.5687 - val_iou_coef_infection: 0.5509 - val_precision_infection: 0.6589 - val_recall_infection: 0.8276 - val_hausdorff95_infection: 46.1339 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9985 - val_f1_infection: 0.8182
# ✅ Model saved at epoch 59 with val_loss: 0.4418
# Epoch 60/100
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4165 - dice_coef_infection: 0.6093 - iou_coef_infection: 0.4718 - precision_infection: 0.6270 - recall_infection: 0.6696 - hausdorff95_infection: 77.6187 - specificity_infection: 0.9973 - accuracy_infection: 0.9945 - f1_infection: 0.8064 - val_loss: 0.4953 - val_dice_coef_infection: 0.5126 - val_iou_coef_infection: 0.4927 - val_precision_infection: 0.5901 - val_recall_infection: 0.8428 - val_hausdorff95_infection: 74.4701 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9987 - val_f1_infection: 0.7873
# Epoch 61/100
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4155 - dice_coef_infection: 0.6088 - iou_coef_infection: 0.4703 - precision_infection: 0.6241 - recall_infection: 0.6582 - hausdorff95_infection: 77.5254 - specificity_infection: 0.9975 - accuracy_infection: 0.9948 - f1_infection: 0.8091 - val_loss: 0.5009 - val_dice_coef_infection: 0.5065 - val_iou_coef_infection: 0.4850 - val_precision_infection: 0.5772 - val_recall_infection: 0.8465 - val_hausdorff95_infection: 57.6247 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9987 - val_f1_infection: 0.7842
# Epoch 62/100
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4300 - dice_coef_infection: 0.5959 - iou_coef_infection: 0.4571 - precision_infection: 0.6171 - recall_infection: 0.6573 - hausdorff95_infection: 79.9647 - specificity_infection: 0.9975 - accuracy_infection: 0.9946 - f1_infection: 0.7996 - val_loss: 0.4941 - val_dice_coef_infection: 0.5164 - val_iou_coef_infection: 0.5001 - val_precision_infection: 0.6063 - val_recall_infection: 0.8264 - val_hausdorff95_infection: 63.4843 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9985 - val_f1_infection: 0.7983
# Epoch 63/100
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 334s 293ms/step - loss: 0.4114 - dice_coef_infection: 0.6156 - iou_coef_infection: 0.4759 - precision_infection: 0.6315 - recall_infection: 0.6673 - hausdorff95_infection: 77.8205 - specificity_infection: 0.9972 - accuracy_infection: 0.9943 - f1_infection: 0.8088 - val_loss: 0.6621 - val_dice_coef_infection: 0.3486 - val_iou_coef_infection: 0.3311 - val_precision_infection: 0.4253 - val_recall_infection: 0.8292 - val_hausdorff95_infection: 71.0407 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9985 - val_f1_infection: 0.7188
# Epoch 64/100
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4328 - dice_coef_infection: 0.5929 - iou_coef_infection: 0.4573 - precision_infection: 0.6104 - recall_infection: 0.6486 - hausdorff95_infection: 77.1352 - specificity_infection: 0.9974 - accuracy_infection: 0.9946 - f1_infection: 0.8070 - val_loss: 0.4890 - val_dice_coef_infection: 0.5224 - val_iou_coef_infection: 0.5050 - val_precision_infection: 0.6164 - val_recall_infection: 0.8256 - val_hausdorff95_infection: 54.2017 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9984 - val_f1_infection: 0.7961
# Epoch 65/100
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4065 - dice_coef_infection: 0.6187 - iou_coef_infection: 0.4812 - precision_infection: 0.6367 - recall_infection: 0.6606 - hausdorff95_infection: 78.0651 - specificity_infection: 0.9975 - accuracy_infection: 0.9947 - f1_infection: 0.8162 - val_loss: 0.6877 - val_dice_coef_infection: 0.3232 - val_iou_coef_infection: 0.3060 - val_precision_infection: 0.3906 - val_recall_infection: 0.8292 - val_hausdorff95_infection: 90.7698 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9984 - val_f1_infection: 0.7050
# Epoch 66/100
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4121 - dice_coef_infection: 0.6128 - iou_coef_infection: 0.4727 - precision_infection: 0.6292 - recall_infection: 0.6628 - hausdorff95_infection: 73.2803 - specificity_infection: 0.9975 - accuracy_infection: 0.9948 - f1_infection: 0.8073 - val_loss: 0.3856 - val_dice_coef_infection: 0.6262 - val_iou_coef_infection: 0.6096 - val_precision_infection: 0.7279 - val_recall_infection: 0.8228 - val_hausdorff95_infection: 42.2791 - val_specificity_infection: 1.0000 - val_accuracy_infection: 0.9985 - val_f1_infection: 0.8443
# ✅ Model saved at epoch 66 with val_loss: 0.3856
# Epoch 67/100
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 334s 293ms/step - loss: 0.4146 - dice_coef_infection: 0.6102 - iou_coef_infection: 0.4716 - precision_infection: 0.6338 - recall_infection: 0.6538 - hausdorff95_infection: 73.2881 - specificity_infection: 0.9976 - accuracy_infection: 0.9949 - f1_infection: 0.8092 - val_loss: 0.5326 - val_dice_coef_infection: 0.4763 - val_iou_coef_infection: 0.4574 - val_precision_infection: 0.5577 - val_recall_infection: 0.8371 - val_hausdorff95_infection: 57.5740 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9986 - val_f1_infection: 0.7731
# Epoch 68/100
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 334s 293ms/step - loss: 0.4063 - dice_coef_infection: 0.6191 - iou_coef_infection: 0.4782 - precision_infection: 0.6378 - recall_infection: 0.6548 - hausdorff95_infection: 75.1603 - specificity_infection: 0.9975 - accuracy_infection: 0.9947 - f1_infection: 0.8123 - val_loss: 0.4160 - val_dice_coef_infection: 0.5928 - val_iou_coef_infection: 0.5734 - val_precision_infection: 0.6771 - val_recall_infection: 0.8365 - val_hausdorff95_infection: 36.2309 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9986 - val_f1_infection: 0.8302
# Epoch 69/100
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 334s 293ms/step - loss: 0.4113 - dice_coef_infection: 0.6148 - iou_coef_infection: 0.4763 - precision_infection: 0.6350 - recall_infection: 0.6654 - hausdorff95_infection: 73.5025 - specificity_infection: 0.9973 - accuracy_infection: 0.9945 - f1_infection: 0.8088 - val_loss: 0.5466 - val_dice_coef_infection: 0.4626 - val_iou_coef_infection: 0.4447 - val_precision_infection: 0.5443 - val_recall_infection: 0.8370 - val_hausdorff95_infection: 52.4447 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9986 - val_f1_infection: 0.7693
# Epoch 70/100
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 0.0001.
# ...
# Epoch 78/100
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4032 - dice_coef_infection: 0.6229 - iou_coef_infection: 0.4823 - precision_infection: 0.6456 - recall_infection: 0.6621 - hausdorff95_infection: 75.2333 - specificity_infection: 0.9976 - accuracy_infection: 0.9947 - f1_infection: 0.8114 - val_loss: 0.4967 - val_dice_coef_infection: 0.5094 - val_iou_coef_infection: 0.4868 - val_precision_infection: 0.5694 - val_recall_infection: 0.8602 - val_hausdorff95_infection: 39.3136 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9989 - val_f1_infection: 0.7865
# Epoch 79/100
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 334s 292ms/step - loss: 0.4218 - dice_coef_infection: 0.6039 - iou_coef_infection: 0.4653 - precision_infection: 0.6297 - recall_infection: 0.6508 - hausdorff95_infection: 76.4834 - specificity_infection: 0.9976 - accuracy_infection: 0.9948 - f1_infection: 0.8051 - val_loss: 0.5377 - val_dice_coef_infection: 0.4725 - val_iou_coef_infection: 0.4554 - val_precision_infection: 0.5408 - val_recall_infection: 0.8377 - val_hausdorff95_infection: 73.6568 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9986 - val_f1_infection: 0.7748
# Epoch 80/100
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4003 - dice_coef_infection: 0.6240 - iou_coef_infection: 0.4872 - precision_infection: 0.6381 - recall_infection: 0.6767 - hausdorff95_infection: 69.7450 - specificity_infection: 0.9975 - accuracy_infection: 0.9949 - f1_infection: 0.8142 - val_loss: 0.6398 - val_dice_coef_infection: 0.3672 - val_iou_coef_infection: 0.3445 - val_precision_infection: 0.4180 - val_recall_infection: 0.8566 - val_hausdorff95_infection: 85.5347 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9987 - val_f1_infection: 0.7150
# Epoch 81/100
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.3979 - dice_coef_infection: 0.6273 - iou_coef_infection: 0.4886 - precision_infection: 0.6490 - recall_infection: 0.6716 - hausdorff95_infection: 68.5300 - specificity_infection: 0.9976 - accuracy_infection: 0.9948 - f1_infection: 0.8132 - val_loss: 0.5777 - val_dice_coef_infection: 0.4319 - val_iou_coef_infection: 0.4135 - val_precision_infection: 0.4916 - val_recall_infection: 0.8417 - val_hausdorff95_infection: 78.5252 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9986 - val_f1_infection: 0.7532
# Epoch 82/100
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.3902 - dice_coef_infection: 0.6352 - iou_coef_infection: 0.4948 - precision_infection: 0.6601 - recall_infection: 0.6733 - hausdorff95_infection: 74.3467 - specificity_infection: 0.9975 - accuracy_infection: 0.9948 - f1_infection: 0.8127 - val_loss: 0.3749 - val_dice_coef_infection: 0.6377 - val_iou_coef_infection: 0.6224 - val_precision_infection: 0.7647 - val_recall_infection: 0.8246 - val_hausdorff95_infection: 39.2584 - val_specificity_infection: 1.0000 - val_accuracy_infection: 0.9985 - val_f1_infection: 0.8400
# ✅ Model saved at epoch 82 with val_loss: 0.3749
# Epoch 83/100
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4013 - dice_coef_infection: 0.6259 - iou_coef_infection: 0.4850 - precision_infection: 0.6444 - recall_infection: 0.6726 - hausdorff95_infection: 75.8420 - specificity_infection: 0.9974 - accuracy_infection: 0.9946 - f1_infection: 0.8113 - val_loss: 0.3987 - val_dice_coef_infection: 0.6106 - val_iou_coef_infection: 0.5913 - val_precision_infection: 0.6951 - val_recall_infection: 0.8407 - val_hausdorff95_infection: 42.2491 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9987 - val_f1_infection: 0.8315
# Epoch 84/100
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4077 - dice_coef_infection: 0.6179 - iou_coef_infection: 0.4807 - precision_infection: 0.6412 - recall_infection: 0.6720 - hausdorff95_infection: 68.7124 - specificity_infection: 0.9976 - accuracy_infection: 0.9948 - f1_infection: 0.8071 - val_loss: 0.5245 - val_dice_coef_infection: 0.4837 - val_iou_coef_infection: 0.4632 - val_precision_infection: 0.5527 - val_recall_infection: 0.8485 - val_hausdorff95_infection: 61.3904 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9987 - val_f1_infection: 0.7748
# Epoch 85/100
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 334s 292ms/step - loss: 0.3861 - dice_coef_infection: 0.6383 - iou_coef_infection: 0.4997 - precision_infection: 0.6489 - recall_infection: 0.6856 - hausdorff95_infection: 67.6348 - specificity_infection: 0.9974 - accuracy_infection: 0.9949 - f1_infection: 0.8186 - val_loss: 0.3572 - val_dice_coef_infection: 0.6527 - val_iou_coef_infection: 0.6349 - val_precision_infection: 0.7471 - val_recall_infection: 0.8342 - val_hausdorff95_infection: 36.6877 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9987 - val_f1_infection: 0.8533
# ✅ Model saved at epoch 85 with val_loss: 0.3572
# Epoch 86/100
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 334s 292ms/step - loss: 0.3896 - dice_coef_infection: 0.6352 - iou_coef_infection: 0.4971 - precision_infection: 0.6567 - recall_infection: 0.6785 - hausdorff95_infection: 68.0930 - specificity_infection: 0.9977 - accuracy_infection: 0.9950 - f1_infection: 0.8142 - val_loss: 0.4229 - val_dice_coef_infection: 0.5862 - val_iou_coef_infection: 0.5666 - val_precision_infection: 0.6827 - val_recall_infection: 0.8337 - val_hausdorff95_infection: 42.0236 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9986 - val_f1_infection: 0.8184
# Epoch 87/100
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 334s 292ms/step - loss: 0.3822 - dice_coef_infection: 0.6430 - iou_coef_infection: 0.5023 - precision_infection: 0.6624 - recall_infection: 0.6864 - hausdorff95_infection: 68.5789 - specificity_infection: 0.9977 - accuracy_infection: 0.9950 - f1_infection: 0.8147 - val_loss: 0.4643 - val_dice_coef_infection: 0.5444 - val_iou_coef_infection: 0.5268 - val_precision_infection: 0.6177 - val_recall_infection: 0.8442 - val_hausdorff95_infection: 48.4939 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9987 - val_f1_infection: 0.8071
# Epoch 88/100
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 334s 292ms/step - loss: 0.3933 - dice_coef_infection: 0.6318 - iou_coef_infection: 0.4943 - precision_infection: 0.6538 - recall_infection: 0.6773 - hausdorff95_infection: 67.7648 - specificity_infection: 0.9976 - accuracy_infection: 0.9950 - f1_infection: 0.8141 - val_loss: 0.5258 - val_dice_coef_infection: 0.4835 - val_iou_coef_infection: 0.4639 - val_precision_infection: 0.5440 - val_recall_infection: 0.8428 - val_hausdorff95_infection: 65.9113 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9986 - val_f1_infection: 0.7740
# Epoch 89/100
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 334s 292ms/step - loss: 0.3883 - dice_coef_infection: 0.6362 - iou_coef_infection: 0.5001 - precision_infection: 0.6597 - recall_infection: 0.6784 - hausdorff95_infection: 67.3684 - specificity_infection: 0.9977 - accuracy_infection: 0.9951 - f1_infection: 0.8188 - val_loss: 0.3685 - val_dice_coef_infection: 0.6433 - val_iou_coef_infection: 0.6267 - val_precision_infection: 0.7475 - val_recall_infection: 0.8251 - val_hausdorff95_infection: 47.8028 - val_specificity_infection: 1.0000 - val_accuracy_infection: 0.9985 - val_f1_infection: 0.8497
# Epoch 90/100
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 334s 292ms/step - loss: 0.4004 - dice_coef_infection: 0.6253 - iou_coef_infection: 0.4877 - precision_infection: 0.6465 - recall_infection: 0.6685 - hausdorff95_infection: 68.7025 - specificity_infection: 0.9976 - accuracy_infection: 0.9950 - f1_infection: 0.8129 - val_loss: 0.3221 - val_dice_coef_infection: 0.6912 - val_iou_coef_infection: 0.6756 - val_precision_infection: 0.7951 - val_recall_infection: 0.8281 - val_hausdorff95_infection: 42.3064 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9985 - val_f1_infection: 0.8712
# ✅ Model saved at epoch 90 with val_loss: 0.3221
# Epoch 91/100
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 334s 292ms/step - loss: 0.3908 - dice_coef_infection: 0.6331 - iou_coef_infection: 0.4957 - precision_infection: 0.6548 - recall_infection: 0.6677 - hausdorff95_infection: 68.1527 - specificity_infection: 0.9977 - accuracy_infection: 0.9952 - f1_infection: 0.8186 - val_loss: 0.3686 - val_dice_coef_infection: 0.6447 - val_iou_coef_infection: 0.6308 - val_precision_infection: 0.7521 - val_recall_infection: 0.8274 - val_hausdorff95_infection: 47.2088 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9985 - val_f1_infection: 0.8488
# Epoch 92/100
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 334s 293ms/step - loss: 0.3838 - dice_coef_infection: 0.6403 - iou_coef_infection: 0.5020 - precision_infection: 0.6600 - recall_infection: 0.6824 - hausdorff95_infection: 65.5528 - specificity_infection: 0.9977 - accuracy_infection: 0.9951 - f1_infection: 0.8161 - val_loss: 0.3924 - val_dice_coef_infection: 0.6156 - val_iou_coef_infection: 0.5969 - val_precision_infection: 0.6939 - val_recall_infection: 0.8487 - val_hausdorff95_infection: 48.5732 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9988 - val_f1_infection: 0.8332
# Epoch 93/100
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4121 - dice_coef_infection: 0.6146 - iou_coef_infection: 0.4788 - precision_infection: 0.6389 - recall_infection: 0.6636 - hausdorff95_infection: 70.0107 - specificity_infection: 0.9976 - accuracy_infection: 0.9948 - f1_infection: 0.8114 - val_loss: 0.4752 - val_dice_coef_infection: 0.5338 - val_iou_coef_infection: 0.5153 - val_precision_infection: 0.6116 - val_recall_infection: 0.8442 - val_hausdorff95_infection: 67.8132 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9987 - val_f1_infection: 0.7953
# Epoch 94/100
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.3743 - dice_coef_infection: 0.6505 - iou_coef_infection: 0.5126 - precision_infection: 0.6661 - recall_infection: 0.6857 - hausdorff95_infection: 63.5317 - specificity_infection: 0.9977 - accuracy_infection: 0.9950 - f1_infection: 0.8218 - val_loss: 0.3082 - val_dice_coef_infection: 0.6985 - val_iou_coef_infection: 0.6788 - val_precision_infection: 0.7771 - val_recall_infection: 0.8547 - val_hausdorff95_infection: 32.2725 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9989 - val_f1_infection: 0.8719
# ✅ Model saved at epoch 94 with val_loss: 0.3082
# Epoch 95/100
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.3999 - dice_coef_infection: 0.6260 - iou_coef_infection: 0.4893 - precision_infection: 0.6515 - recall_infection: 0.6745 - hausdorff95_infection: 68.4520 - specificity_infection: 0.9976 - accuracy_infection: 0.9950 - f1_infection: 0.8118 - val_loss: 0.4555 - val_dice_coef_infection: 0.5557 - val_iou_coef_infection: 0.5392 - val_precision_infection: 0.6490 - val_recall_infection: 0.8326 - val_hausdorff95_infection: 67.8740 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9986 - val_f1_infection: 0.8077
# Epoch 96/100
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.4128 - dice_coef_infection: 0.6133 - iou_coef_infection: 0.4755 - precision_infection: 0.6407 - recall_infection: 0.6691 - hausdorff95_infection: 71.9278 - specificity_infection: 0.9977 - accuracy_infection: 0.9949 - f1_infection: 0.8050 - val_loss: 0.4733 - val_dice_coef_infection: 0.5331 - val_iou_coef_infection: 0.5120 - val_precision_infection: 0.5989 - val_recall_infection: 0.8589 - val_hausdorff95_infection: 47.9707 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9988 - val_f1_infection: 0.7976
# Epoch 97/100
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.3800 - dice_coef_infection: 0.6437 - iou_coef_infection: 0.5078 - precision_infection: 0.6661 - recall_infection: 0.6823 - hausdorff95_infection: 66.7650 - specificity_infection: 0.9977 - accuracy_infection: 0.9953 - f1_infection: 0.8209 - val_loss: 0.4509 - val_dice_coef_infection: 0.5567 - val_iou_coef_infection: 0.5357 - val_precision_infection: 0.6206 - val_recall_infection: 0.8534 - val_hausdorff95_infection: 56.8572 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9988 - val_f1_infection: 0.8080
# Epoch 98/100
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.3587 - dice_coef_infection: 0.6661 - iou_coef_infection: 0.5301 - precision_infection: 0.6812 - recall_infection: 0.7004 - hausdorff95_infection: 63.8549 - specificity_infection: 0.9975 - accuracy_infection: 0.9950 - f1_infection: 0.8296 - val_loss: 0.3228 - val_dice_coef_infection: 0.6861 - val_iou_coef_infection: 0.6657 - val_precision_infection: 0.7735 - val_recall_infection: 0.8427 - val_hausdorff95_infection: 30.8839 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9987 - val_f1_infection: 0.8671
# Epoch 99/100
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.3973 - dice_coef_infection: 0.6277 - iou_coef_infection: 0.4928 - precision_infection: 0.6558 - recall_infection: 0.6651 - hausdorff95_infection: 65.2619 - specificity_infection: 0.9978 - accuracy_infection: 0.9952 - f1_infection: 0.8171 - val_loss: 0.4850 - val_dice_coef_infection: 0.5253 - val_iou_coef_infection: 0.5080 - val_precision_infection: 0.6049 - val_recall_infection: 0.8371 - val_hausdorff95_infection: 59.9684 - val_specificity_infection: 0.9999 - val_accuracy_infection: 0.9987 - val_f1_infection: 0.7970
# Epoch 100/100
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 335s 293ms/step - loss: 0.3851 - dice_coef_infection: 0.6399 - iou_coef_infection: 0.5028 - precision_infection: 0.6587 - recall_infection: 0.6944 - hausdorff95_infection: 64.8677 - specificity_infection: 0.9976 - accuracy_infection: 0.9950 - f1_infection: 0.8132 - val_loss: 0.4105 - val_dice_coef_infection: 0.5961 - val_iou_coef_infection: 0.5778 - val_precision_infection: 0.6624 - val_recall_infection: 0.8571 - val_hausdorff95_infection: 51.9505 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9989 - val_f1_infection: 0.8280
# ✅ Total training time: 33621.33 seconds (560.36 minutes)

# %% [markdown]
# ## Plotting the performance metrics

# %%
plt.plot(history.history['dice_coef_infection'])
plt.plot(history.history['val_dice_coef_infection'])
plt.title('dice_coef_infection vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Dice_coef')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# %%
plt.plot(history.history['iou_coef_infection'])
plt.plot(history.history['val_iou_coef_infection'])
plt.title('iou_coef_infection vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Iou_coef')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Val'], loc = 'upper right')
plt.show()

# %% [markdown]
# ## Using our trained model for prediction

# %%
import numpy as np
import time

# Start timer (high precision)
start_time = time.perf_counter()

# Evaluate the model on the validation generator
results = model.evaluate(val_gen, verbose=1)

# End timer
end_time = time.perf_counter()

# Calculate evaluation time
eval_time = end_time - start_time

# Print metric names with results
print("\n===== Validation Metrics =====")
for name, value in zip(model.metrics_names, results):
    print(f"{name}: {value:.6f}")

print(f"\nEvaluation Time: {eval_time:.8f} seconds\n")
# Out:
# 128/128 [==============================] - 13s 104ms/step - loss: 0.4450 - dice_coef_infection: 0.5893 - iou_coef_infection: 0.5508 - precision_infection: 0.7677 - recall_infection: 0.7296 - hausdorff95_infection: 71.8025 - specificity_infection: 0.9995 - accuracy_infection: 0.9962 - f1_infection: 0.8089
#
# ===== Validation Metrics =====
# loss: 0.444961
# dice_coef_infection: 0.589307
# iou_coef_infection: 0.550829
# precision_infection: 0.767668
# recall_infection: 0.729641
# hausdorff95_infection: 71.802536
# specificity_infection: 0.999540
# accuracy_infection: 0.996249
# f1_infection: 0.808872
#
# Evaluation Time: 13.40969564 seconds

# %%
import matplotlib.pyplot as plt
import numpy as np

# Run inference if not already done
predicted = model.predict(lung_test)

# Selected indices to visualize (744 as 1st, 280 as 2nd, 230 as 3rd)
selected_indices = [744, 280, 230]
n_samples = len(selected_indices)

# Mapping indices to custom names
name_mapping = {
    0: ("Image1_Covid", "GT1_Covid", "Predict1_Covid_DSEG_Unet"),  # Index 744
    1: ("Image2_Covid", "GT2_Covid", "Predict2_Covid_DSEG_Unet"),  # Index 280
    2: ("Image3_Covid", "GT3_Covid", "Predict3_Covid_DSEG_Unet")   # Index 230
}

# Plot
for j, i in enumerate(selected_indices):
    lung_img = lung_test[i][..., 0].astype(np.float32)
    gt_infect = (infect_test[i][..., 0] > 0.5).astype(np.float32)
    pred_infect = predicted[i][..., 0].astype(np.float32)

    # Normalize lung image
    if lung_img.max() > lung_img.min():
        lung_img = (lung_img - lung_img.min()) / (lung_img.max() - lung_img.min())
    lung_img = np.clip(lung_img, 0, 1)
    pred_infect = np.clip(pred_infect, 0, 1)

    # Get custom names for this index
    input_name, gt_name, pred_name = name_mapping[j]

    # Save Original Lung
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{input_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

    # Save Ground Truth Infection
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.imshow(gt_infect, cmap='Reds', alpha=0.6)
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{gt_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

    # Save Predicted Infection
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.imshow(pred_infect, cmap='Reds', alpha=0.6)
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{pred_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

print("Separate JPEG files saved for input images (Image1_Covid, Image2_Covid, Image3_Covid), "
      "ground truths (GT1_Covid, GT2_Covid, GT3_Covid), and predictions "
      "(Predict1_Covid_DSEG_Unet, Predict2_Covid_DSEG_Unet, Predict3_Covid_DSEG_Unet).")
# Out:
# Separate JPEG files saved for input images (Image1_Covid, Image2_Covid, Image3_Covid), ground truths (GT1_Covid, GT2_Covid, GT3_Covid), and predictions (Predict1_Covid_DSEG_Unet, Predict2_Covid_DSEG_Unet, Predict3_Covid_DSEG_Unet).
