# %% [markdown]
# ## Importing important libraries

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import nibabel as nib #for loading nii files
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf #for deep learning

# %% [markdown]
# ## Reading the metadata

# %%
data = pd.read_csv('../input/covid19-ct-scans/metadata.csv')
data.head()
# Out:
#                                              ct_scan  \
# 0  ../input/covid19-ct-scans/ct_scans/coronacases...
# 1  ../input/covid19-ct-scans/ct_scans/coronacases...
# 2  ../input/covid19-ct-scans/ct_scans/coronacases...
# 3  ../input/covid19-ct-scans/ct_scans/coronacases...
# 4  ../input/covid19-ct-scans/ct_scans/coronacases...
#
#                                            lung_mask  \
# 0  ../input/covid19-ct-scans/lung_mask/coronacase...
# 1  ../input/covid19-ct-scans/lung_mask/coronacase...
# 2  ../input/covid19-ct-scans/lung_mask/coronacase...
# 3  ../input/covid19-ct-scans/lung_mask/coronacase...
# 4  ../input/covid19-ct-scans/lung_mask/coronacase...
#
#                                       infection_mask  \
# 0  ../input/covid19-ct-scans/infection_mask/coron...
# 1  ../input/covid19-ct-scans/infection_mask/coron...
# 2  ../input/covid19-ct-scans/infection_mask/coron...
# 3  ../input/covid19-ct-scans/infection_mask/coron...
# 4  ../input/covid19-ct-scans/infection_mask/coron...
#
#                              lung_and_infection_mask
# 0  ../input/covid19-ct-scans/lung_and_infection_m...
# 1  ../input/covid19-ct-scans/lung_and_infection_m...
# 2  ../input/covid19-ct-scans/lung_and_infection_m...
# 3  ../input/covid19-ct-scans/lung_and_infection_m...
# 4  ../input/covid19-ct-scans/lung_and_infection_m...

# %% [markdown]
# ## Defining function for readiing .nii files

# %%
def read_nii(filepath):
    '''
    Reads .nii file and returns pixel array
    '''
    ct_scan = nib.load(filepath)
    array   = ct_scan.get_fdata()
    array   = np.rot90(np.array(array))
    return(array)

# %% [markdown]
# ## Reading the chest ct scan data

# %%
# Read sample
sample_ct   = read_nii(data.loc[2,'ct_scan'])
sample_lung = read_nii(data.loc[2,'lung_mask'])
sample_infe = read_nii(data.loc[2,'infection_mask'])
sample_all  = read_nii(data.loc[2,'lung_and_infection_mask'])

# %% [markdown]
# ## Plotting the sample images

# %%
fig = plt.figure(figsize = (18,15))
plt.subplot(1,4,1)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.title('Original Image')

plt.subplot(1,4,2)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_lung[..., 150],alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung Mask')

plt.subplot(1,4,3)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_infe[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Infection Mask')

plt.subplot(1,4,4)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_all[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung and Infection Mask')
# Out:
# Text(0.5, 1.0, 'Lung and Infection Mask')

# %% [markdown]
# ## Converting the data into array for training model

# %%
import numpy as np
import cv2
import random
from scipy.ndimage import rotate, shift, zoom

lungs = []
infections = []
case_ids = []
img_size = 320

# ----------- Load and Resize Data -----------
for case_index in range(len(data)):
    ct = read_nii(data['ct_scan'][case_index])
    infect = read_nii(data['infection_mask'][case_index])

    for slice_index in range(ct.shape[0]):
        lung_img = cv2.resize(ct[slice_index], dsize=(img_size, img_size)).astype('float32')
        infec_img = cv2.resize(infect[slice_index], dsize=(img_size, img_size)).astype('float32')

        lungs.append(lung_img[..., np.newaxis])
        infections.append(infec_img[..., np.newaxis])
        case_ids.append(case_index)

# %%
import numpy as np

# case_ids should be a NumPy array telling which case each slice belongs to
# Convert and binarize
lungs = np.array(lungs, dtype=np.float32)
infections = (np.array(infections, dtype=np.uint8) > 0.5).astype(np.uint8)
case_ids = np.array(case_ids)

# %% [markdown]
# ## Performing test and train split

# %%
# ----------- Case-wise Split -----------
unique_cases = np.unique(case_ids)
train_cases = np.append(unique_cases[4:12], unique_cases[12:20])
temp_cases = unique_cases[2:4]
val_cases = unique_cases[:2]

train_mask = np.isin(case_ids, train_cases)
temp_mask = np.isin(case_ids, temp_cases)
val_mask = np.isin(case_ids, val_cases)

lung_train = lungs[train_mask]
infect_train = infections[train_mask]
lung_temp = lungs[temp_mask]
infect_temp = infections[temp_mask]
lung_test = lungs[val_mask]
infect_test = infections[val_mask]

print(f"✅ Train: {lung_train.shape[0]} slices from {len(train_cases)} cases")
print(f"✅ Validation: {lung_temp.shape[0]} slices from {len(temp_cases)} cases")
print(f"✅ Test: {lung_test.shape[0]} slices from {len(val_cases)} cases")

# ----------- Augmentation -----------
def augment_image(img, mask):
    if random.random() < 0.5:
        img = np.fliplr(img)
        mask = np.fliplr(mask)
    if random.random() < 0.5:
        img = np.flipud(img)
        mask = np.flipud(mask)

    angle = random.uniform(-15, 15)
    img = rotate(img, angle, reshape=False, order=1, mode='nearest')
    mask = rotate(mask, angle, reshape=False, order=0, mode='nearest')

    shift_val = np.random.uniform(-0.1, 0.1, size=2) * img.shape[:2]
    img = shift(img, shift=(*shift_val, 0), order=1, mode='nearest')
    mask = shift(mask, shift=(*shift_val, 0), order=0, mode='nearest')

    zoom_factor = random.uniform(0.9, 1.1)
    img = zoom(img, (zoom_factor, zoom_factor, 1), order=1)
    mask = zoom(mask, (zoom_factor, zoom_factor, 1), order=0)

    return fix_shape(img), fix_shape(mask)

def fix_shape(arr, target_size=(320, 320)):
    h, w, c = arr.shape
    th, tw = target_size
    dh = th - h
    dw = tw - w
    if dh > 0 or dw > 0:
        pad_h = (max(dh // 2, 0), max(dh - dh // 2, 0))
        pad_w = (max(dw // 2, 0), max(dw - dw // 2, 0))
        arr = np.pad(arr, (pad_h, pad_w, (0, 0)), mode='constant')
    arr = arr[:th, :tw, :]
    return arr.astype('float32')

# ----------- Apply Augmentation -----------
aug_lung_train = []
aug_infect_train = []

for i in range(len(lung_train)):
    img, mask = augment_image(lung_train[i], infect_train[i])
    aug_lung_train.append(img)
    aug_infect_train.append(mask)

lung_train = np.stack(aug_lung_train)
infect_train = np.stack(aug_infect_train)

# Final Binarization
infect_train = (infect_train > 0.5).astype(np.uint8)
infect_test = (infect_test > 0.5).astype(np.uint8)

print(f"✅ Augmented training shape: {lung_train.shape}")
print("✅ All preprocessing complete.")
# Out:
# ✅ Train: 9143 slices from 16 cases
# ✅ Validation: 1024 slices from 2 cases
# ✅ Test: 1024 slices from 2 cases
# ✅ Augmented training shape: (9143, 320, 320, 1)
# ✅ All preprocessing complete.

# %%
import tensorflow as tf
from tensorflow.keras import backend as K
import numpy as np
from scipy.spatial import cKDTree

smooth = 1.0

# Binary Dice coefficient (soft - commonly used during training)
def dice_coef_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# Binary IoU coefficient (soft)
def iou_coef_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# Soft Precision
def precision_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + smooth) / (K.sum(y_pred_f) + smooth)

# Soft Recall (Sensitivity)
def recall_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + smooth) / (K.sum(y_true_f) + smooth)

# Soft Specificity
def specificity_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    tn = K.sum((1 - y_true_f) * (1 - y_pred_f))
    fp = K.sum((1 - y_true_f) * y_pred_f)
    return (tn + smooth) / (tn + fp + smooth)

# Soft Accuracy
def accuracy_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    tp = K.sum(y_true_f * y_pred_f)
    tn = K.sum((1 - y_true_f) * (1 - y_pred_f))
    total = K.cast(K.shape(y_true_f)[0], 'float32')
    return (tp + tn + smooth) / (total + smooth)

# Soft F1-score (harmonic mean of precision & recall - very close to Dice, standard in many repos)
def f1_infection(y_true, y_pred):
    precision = precision_infection(y_true, y_pred)
    recall    = recall_infection(y_true, y_pred)
    return (2. * precision * recall + smooth) / (precision + recall + smooth)

# Hausdorff Distance 95 % (robust & most commonly used in medical imaging challenges)
# Lower = better. Returns the mean HD95 over the batch.
def _calculate_hd95(y_true, y_pred):
    hd_list = []
    for i in range(y_true.shape[0]):
        # Hard threshold at 0.5 (standard for evaluation metrics)
        gt = np.squeeze(y_true[i]) > 0.5
        pred = np.squeeze(y_pred[i]) > 0.5

        gt_pts = np.argwhere(gt)
        pred_pts = np.argwhere(pred)

        # Cases with empty masks
        if gt_pts.shape[0] == 0 and pred_pts.shape[0] == 0:
            hd_list.append(0.0)
            continue
        if gt_pts.shape[0] == 0 or pred_pts.shape[0] == 0:
            hd_list.append(400.0)  # large penalty - adjust to your image diagonal if needed (e.g. ~362 for 256×256, ~724 for 512×512)
            continue

        # Directed distances
        dist_gt_to_pred = cKDTree(pred_pts).query(gt_pts)[0]
        dist_pred_to_gt = cKDTree(gt_pts).query(pred_pts)[0]

        hd95 = max(
            np.percentile(dist_gt_to_pred, 95),
            np.percentile(dist_pred_to_gt, 95)
        )
        hd_list.append(hd95)

    return np.mean(hd_list, dtype=np.float32)

def hausdorff95_infection(y_true, y_pred):
    hd = tf.numpy_function(_calculate_hd95, [y_true, y_pred], tf.float32)
    hd.set_shape(())
    return hd

# Optional: KL Divergence (you already had this)
kld = tf.keras.losses.KLDivergence()

# %%
from tensorflow.keras.losses import BinaryCrossentropy

def loss_f(y_true, y_pred):
    bce = BinaryCrossentropy()
    return dice_loss(y_true, y_pred) + bce(y_true, y_pred) 

def loss_e(y_true, y_pred):
    bce = BinaryCrossentropy()
    return dice_loss(y_true, y_pred)  + kld(y_true, y_pred)
    
def dice_loss(y_true, y_pred):
    return 1. - dice_coef_infection(y_true, y_pred)

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Multiply, Conv2D, DepthwiseConv2D, Dense, Flatten, MaxPooling2D, UpSampling2D, concatenate, Activation, LayerNormalization, Add, Dropout, Conv2DTranspose, multiply, Reshape, GlobalAveragePooling2D, Permute, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Concatenate

def activation_block(x):
    x = Activation("gelu")(x)
    return LayerNormalization()(x)

def conv_stem(x, filters: int, patch_size: int):
    x = Conv2D(filters, kernel_size=patch_size,padding='same', strides=patch_size)(x)
    return activation_block(x)

def vector_block(xyz, cmf, red):
    # red means reduction
    # cmf means filters, denotes vector size
    opt1 = conv_stem(xyz, cmf, red)
    opt2 = conv_stem(xyz, cmf, red)
    opt3 = conv_stem(xyz, cmf, red)
    opt4 = conv_stem(xyz, cmf, red)
    
    o1 = GlobalAveragePooling2D()(opt1)
    o2 = GlobalAveragePooling2D()(opt2)
    o3 = GlobalAveragePooling2D()(opt3)
    o4 = GlobalAveragePooling2D()(opt4)

    o5 = concatenate([o1, o2, o3, o4], -1)
    return o5

def mlp_feature(vect, cmf):
    oo = Flatten()(vect)
    o6 = Dense(cmf * 2, activation='gelu')(oo)
    o6 = Dropout(0.2)(o6)
    o6 = Dense(cmf * 4, activation='gelu')(o6)

    o6 = Reshape((1, cmf * 4))(o6)
    o7 = Permute((2, 1))(o6)

    o8 = multiply([o6, o7])
    o8 = Lambda(lambda x: tf.expand_dims(x, -1))(o8)
    o8 = MaxPooling2D(4)(o8)

    return o8

def frz_block(xyz):
    shape = xyz.shape
    a1, a2, a3, a4 = shape[0], shape[1], shape[2], shape[3]
    cmf = a2
    o5 = vector_block(xyz, cmf, 5)
    o7 = mlp_feature(o5, cmf)

    o7 = concatenate([o7, xyz, o7], -1)
    return o7

def up_frz(x1, x2, n_filters):
    # Upsample x1 using Conv2DTranspose
    x1 = Conv2DTranspose(n_filters * 4, 3, strides=2, activation='gelu', padding="same")(x1)
    
    # Apply Conv2D to x2
    x2 = Conv2D(n_filters * 2, 3, activation='gelu', padding="same")(x2)
    
    # Apply attention mechanism
    x = concatenate([x1, x2])
    
    # Apply Dropout for regularization
    x = Dropout(0.3)(x)
    
    return x

def regu(xyz, filt):
    x = Conv2D(filt, (3, 3), activation='gelu', padding="same")(xyz)
    x = MaxPooling2D(2)(x)
    return x

# %%
def squeeze_and_excite_block(inputs, ratio=24):
    """ Squeeze and Excitation block to recalibrate channel-wise features """
    filters = inputs.shape[-1]  # Number of input channels
    se_shape = (1, 1, filters)

    # Squeeze: Global Average Pooling
    se = GlobalAveragePooling2D()(inputs)
    se = Reshape(se_shape)(se)

    a = filters // ratio

    # Excitation: Dense layers to capture channel-wise dependencies
    if a > 8:
        se = Conv2D(filters // ratio, kernel_size=1, activation='swish', padding='same')(se)
        se = Conv2D(filters, kernel_size=1, activation='sigmoid', padding='same')(se)
    else:
        se = Conv2D(8, kernel_size=1, activation='swish', padding='same')(se)
        se = Conv2D(filters, kernel_size=1, activation='sigmoid', padding='same')(se)

    # Scale the input by channel-wise weights
    x = multiply([inputs, se])

    return x

def residual_block(x, filters, stride=1, padding='same'):
    shortcut = x
    x = Conv2D(filters * 6, 1, strides=stride, padding=padding, use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)
    x = DepthwiseConv2D(kernel_size=3, strides=stride, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)
    x = squeeze_and_excite_block(x)
    x = Conv2D(filters, 1, strides=stride, padding=padding, use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)
    x = Add()([x, shortcut])
    return x

def dense_block(inputs, num_layers, growth_rate, ratio=16):
    """Dense block where each layer is connected to all previous layers."""
    concat_features = inputs
    for i in range(num_layers):
        # BatchNorm -> ReLU -> Conv2D
        x = Conv2D(growth_rate, 3, activation='gelu', padding='same')(concat_features)

        # Concatenate input with new output (dense connection)
        concat_features = Concatenate()([concat_features, x])

    x = squeeze_and_excite_block(concat_features)

    x = MaxPooling2D(2)(x)

    return x

inputs = (img_size, img_size, 1)

def model_build_func(input_shape, n_labels):
    inputs = Input(shape=input_shape, name='input_image')
    g_filter = 32
    u_filter = 8

    o1 = frz_block(regu(inputs, g_filter))  # 80

    o2 = frz_block(regu(o1, g_filter * 2))  # 40

    o3 = frz_block(regu(o2, g_filter * 4))  # 20

    o4 = frz_block(regu(o3, g_filter * 8))  # 10

    o5 = frz_block(regu(o4, g_filter * 16))  # 5

    # middle part

    u1 = up_frz(o5, o4, u_filter * 16)  # 10

    cu1 = concatenate([u1, o4])  # 10

    u2 = up_frz(cu1, o3, u_filter * 8)  # 20

    cu2 = concatenate([u2, o3])  # 20

    u3 = up_frz(cu2, o2, u_filter * 4)  # 40

    cu3 = concatenate([u3, o2])  # 40

    u4 = up_frz(cu3, o1, u_filter * 2)  # 40

    cu4 = concatenate([u4, o1])  # 40

    ex_u = UpSampling2D(2)(o1)

    u5 = up_frz(cu4, ex_u, u_filter)  # 40

    seg_map = Conv2D(n_labels, 3, activation='sigmoid', padding="same")(u5)

    model = Model(inputs=inputs, outputs=seg_map)

    return model


model = model_build_func(inputs, 1)

from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2_as_graph

def get_flops(model):
    """Calculate Floating Point Operations (FLOPs) of a Keras model in TensorFlow 2.x."""
    # Convert Keras model to a TensorFlow function
    concrete_func = tf.function(lambda inputs: model(inputs))
    concrete_func = concrete_func.get_concrete_function(
        tf.TensorSpec([1] + list(model.input_shape[1:]), model.input.dtype)
    )

    # Convert to frozen graph
    frozen_func, _ = convert_variables_to_constants_v2_as_graph(concrete_func)

    # Compute FLOPs
    flops = tf.compat.v1.profiler.profile(
        frozen_func.graph,
        options=tf.compat.v1.profiler.ProfileOptionBuilder.float_operation(),
    )

    return flops.total_float_ops

# Compute FLOPs
flops = get_flops(model)
print(f"Total FLOPs: {flops / 1e9:.2f} GFLOPs")  # Convert to GFLOPs

from tensorflow.keras.optimizers import Adam

optimizer = Adam(learning_rate=1e-3)
model.compile(optimizer=optimizer, loss=loss_f, metrics=[dice_coef_infection, iou_coef_infection, precision_infection, recall_infection, hausdorff95_infection, specificity_infection, accuracy_infection, f1_infection])

# Model summary
model.summary()
# Out:
# Total FLOPs: 16.53 GFLOPs
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_image (InputLayer)        [(None, 320, 320, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 320, 320, 32) 320         input_image[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 160, 160, 32) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 160)  128160      max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 160)  128160      max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 160)  128160      max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 160)  128160      max_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 160)  0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 160)  0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 160)  0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 160)  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# layer_normalization (LayerNorma (None, 32, 32, 160)  320         activation[0][0]
# __________________________________________________________________________________________________
# layer_normalization_1 (LayerNor (None, 32, 32, 160)  320         activation_1[0][0]
# __________________________________________________________________________________________________
# layer_normalization_2 (LayerNor (None, 32, 32, 160)  320         activation_2[0][0]
# __________________________________________________________________________________________________
# layer_normalization_3 (LayerNor (None, 32, 32, 160)  320         activation_3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 160)          0           layer_normalization[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 160)          0           layer_normalization_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 160)          0           layer_normalization_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 160)          0           layer_normalization_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 640)          0           global_average_pooling2d[0][0]
#                                                                  global_average_pooling2d_1[0][0]
#                                                                  global_average_pooling2d_2[0][0]
#                                                                  global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 640)          0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 320)          205120      flatten[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 320)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 640)          205440      dropout[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 640)       0           dense_1[0][0]
# __________________________________________________________________________________________________
# permute (Permute)               (None, 640, 1)       0           reshape[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 640, 640)     0           reshape[0][0]
#                                                                  permute[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 640, 640, 1)  0           multiply[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 160, 160, 1)  0           lambda[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 160, 160, 34) 0           max_pooling2d_1[0][0]
#                                                                  max_pooling2d[0][0]
#                                                                  max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 160, 160, 64) 19648       concatenate_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 80, 80, 64)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 80)   128080      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 80)   128080      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 80)   128080      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 80)   128080      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 16, 16, 80)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 16, 16, 80)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16, 16, 80)   0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 80)   0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# layer_normalization_4 (LayerNor (None, 16, 16, 80)   160         activation_4[0][0]
# __________________________________________________________________________________________________
# layer_normalization_5 (LayerNor (None, 16, 16, 80)   160         activation_5[0][0]
# __________________________________________________________________________________________________
# layer_normalization_6 (LayerNor (None, 16, 16, 80)   160         activation_6[0][0]
# __________________________________________________________________________________________________
# layer_normalization_7 (LayerNor (None, 16, 16, 80)   160         activation_7[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 80)           0           layer_normalization_4[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 80)           0           layer_normalization_5[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 80)           0           layer_normalization_6[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 80)           0           layer_normalization_7[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 320)          0           global_average_pooling2d_4[0][0]
#                                                                  global_average_pooling2d_5[0][0]
#                                                                  global_average_pooling2d_6[0][0]
#                                                                  global_average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 320)          0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 160)          51360       flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 160)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 320)          51520       dropout_1[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 320)       0           dense_3[0][0]
# __________________________________________________________________________________________________
# permute_1 (Permute)             (None, 320, 1)       0           reshape_1[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 320, 320)     0           reshape_1[0][0]
#                                                                  permute_1[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 320, 320, 1)  0           multiply_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 80, 80, 1)    0           lambda_1[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 80, 80, 66)   0           max_pooling2d_3[0][0]
#                                                                  max_pooling2d_2[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 80, 80, 128)  76160       concatenate_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 40, 40, 128)  0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 40)     128040      max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 8, 40)     128040      max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 40)     128040      max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 40)     128040      max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 8, 8, 40)     0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 8, 8, 40)     0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 8, 8, 40)     0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 8, 8, 40)     0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# layer_normalization_8 (LayerNor (None, 8, 8, 40)     80          activation_8[0][0]
# __________________________________________________________________________________________________
# layer_normalization_9 (LayerNor (None, 8, 8, 40)     80          activation_9[0][0]
# __________________________________________________________________________________________________
# layer_normalization_10 (LayerNo (None, 8, 8, 40)     80          activation_10[0][0]
# __________________________________________________________________________________________________
# layer_normalization_11 (LayerNo (None, 8, 8, 40)     80          activation_11[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_8 (Glo (None, 40)           0           layer_normalization_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_9 (Glo (None, 40)           0           layer_normalization_9[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_10 (Gl (None, 40)           0           layer_normalization_10[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_11 (Gl (None, 40)           0           layer_normalization_11[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 160)          0           global_average_pooling2d_8[0][0]
#                                                                  global_average_pooling2d_9[0][0]
#                                                                  global_average_pooling2d_10[0][0]
#                                                                  global_average_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 160)          0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 80)           12880       flatten_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 80)           0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 160)          12960       dropout_2[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 160)       0           dense_5[0][0]
# __________________________________________________________________________________________________
# permute_2 (Permute)             (None, 160, 1)       0           reshape_2[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 160, 160)     0           reshape_2[0][0]
#                                                                  permute_2[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 160, 160, 1)  0           multiply_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 40, 40, 1)    0           lambda_2[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 40, 40, 130)  0           max_pooling2d_5[0][0]
#                                                                  max_pooling2d_4[0][0]
#                                                                  max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 40, 40, 256)  299776      concatenate_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 20, 20, 256)  0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 4, 4, 20)     128020      max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 4, 4, 20)     128020      max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 4, 4, 20)     128020      max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 4, 4, 20)     128020      max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 4, 4, 20)     0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 4, 4, 20)     0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 4, 4, 20)     0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 4, 4, 20)     0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# layer_normalization_12 (LayerNo (None, 4, 4, 20)     40          activation_12[0][0]
# __________________________________________________________________________________________________
# layer_normalization_13 (LayerNo (None, 4, 4, 20)     40          activation_13[0][0]
# __________________________________________________________________________________________________
# layer_normalization_14 (LayerNo (None, 4, 4, 20)     40          activation_14[0][0]
# __________________________________________________________________________________________________
# layer_normalization_15 (LayerNo (None, 4, 4, 20)     40          activation_15[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_12 (Gl (None, 20)           0           layer_normalization_12[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_13 (Gl (None, 20)           0           layer_normalization_13[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_14 (Gl (None, 20)           0           layer_normalization_14[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_15 (Gl (None, 20)           0           layer_normalization_15[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 80)           0           global_average_pooling2d_12[0][0]
#                                                                  global_average_pooling2d_13[0][0]
#                                                                  global_average_pooling2d_14[0][0]
#                                                                  global_average_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 80)           0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 40)           3240        flatten_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 40)           0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 80)           3280        dropout_3[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1, 80)        0           dense_7[0][0]
# __________________________________________________________________________________________________
# permute_3 (Permute)             (None, 80, 1)        0           reshape_3[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 80, 80)       0           reshape_3[0][0]
#                                                                  permute_3[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 80, 80, 1)    0           multiply_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 20, 20, 1)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 20, 20, 258)  0           max_pooling2d_7[0][0]
#                                                                  max_pooling2d_6[0][0]
#                                                                  max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 20, 20, 512)  1189376     concatenate_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 10, 10, 512)  0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 2, 2, 10)     128010      max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 2, 2, 10)     128010      max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 2, 2, 10)     128010      max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 2, 2, 10)     128010      max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 2, 2, 10)     0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 2, 2, 10)     0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 2, 2, 10)     0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 2, 2, 10)     0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# layer_normalization_16 (LayerNo (None, 2, 2, 10)     20          activation_16[0][0]
# __________________________________________________________________________________________________
# layer_normalization_17 (LayerNo (None, 2, 2, 10)     20          activation_17[0][0]
# __________________________________________________________________________________________________
# layer_normalization_18 (LayerNo (None, 2, 2, 10)     20          activation_18[0][0]
# __________________________________________________________________________________________________
# layer_normalization_19 (LayerNo (None, 2, 2, 10)     20          activation_19[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_16 (Gl (None, 10)           0           layer_normalization_16[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_17 (Gl (None, 10)           0           layer_normalization_17[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_18 (Gl (None, 10)           0           layer_normalization_18[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_19 (Gl (None, 10)           0           layer_normalization_19[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 40)           0           global_average_pooling2d_16[0][0]
#                                                                  global_average_pooling2d_17[0][0]
#                                                                  global_average_pooling2d_18[0][0]
#                                                                  global_average_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 40)           0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 20)           820         flatten_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 20)           0           dense_8[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 40)           840         dropout_4[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1, 40)        0           dense_9[0][0]
# __________________________________________________________________________________________________
# permute_4 (Permute)             (None, 40, 1)        0           reshape_4[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 40, 40)       0           reshape_4[0][0]
#                                                                  permute_4[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 40, 40, 1)    0           multiply_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 10, 10, 1)    0           lambda_4[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 10, 10, 514)  0           max_pooling2d_9[0][0]
#                                                                  max_pooling2d_8[0][0]
#                                                                  max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 20, 20, 512)  2369024     concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 20, 20, 256)  594688      concatenate_7[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 20, 20, 768)  0           conv2d_transpose[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 20, 20, 768)  0           concatenate_10[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 20, 20, 1026) 0           dropout_5[0][0]
#                                                                  concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 40, 40, 256)  2364160     concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 40, 40, 128)  149888      concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 40, 40, 384)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 40, 40, 384)  0           concatenate_12[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 40, 40, 514)  0           dropout_6[0][0]
#                                                                  concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 80, 80, 128)  592256      concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 80, 80, 64)   38080       concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 80, 80, 192)  0           conv2d_transpose_2[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 80, 80, 192)  0           concatenate_14[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 80, 80, 258)  0           dropout_7[0][0]
#                                                                  concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 160, 160, 64) 148672      concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 160, 160, 32) 9824        concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 160, 160, 96) 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_28[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 160, 160, 96) 0           concatenate_16[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 160, 160, 130 0           dropout_8[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 320, 320, 34) 0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 320, 320, 32) 37472       concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 320, 320, 16) 4912        up_sampling2d[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 320, 320, 48) 0           conv2d_transpose_4[0][0]
#                                                                  conv2d_29[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 320, 320, 48) 0           concatenate_18[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 320, 320, 1)  433         dropout_9[0][0]
# ==================================================================================================
# Total params: 11,005,869
# Trainable params: 11,005,869
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Install required packages
# !pip install openpyxl

# Imports
import openpyxl  # required for reading .xlsx files
import pandas as pd
import tensorflow as tf
import os
import shutil
from tensorflow.keras.callbacks import LearningRateScheduler, ReduceLROnPlateau

# File paths
checkpoint_filepath = '/kaggle/working/checkpoint.h5.keras'
metrics_file = '/kaggle/working/training_metrics.xlsx'
pre_checkpoint_filepath = '/kaggle/input/dseg-unet-4channel-covid19/checkpoint.h5.keras'
pre_metrics_file = '/kaggle/input/dseg-unet-4channel-covid19/training_metrics.xlsx'

# Restore checkpoint and metrics if available
if os.path.exists(pre_checkpoint_filepath):
    shutil.copy(pre_checkpoint_filepath, checkpoint_filepath)
    print(f"Restored checkpoint from: {pre_checkpoint_filepath}")

if os.path.exists(pre_metrics_file):
    shutil.copy(pre_metrics_file, metrics_file)
    print(f"Restored metrics file from: {pre_metrics_file}")

# Load last epoch
def load_last_epoch():
    if os.path.exists(metrics_file):
        try:
            df = pd.read_excel(metrics_file, engine='openpyxl')
            if not df.empty and 'epoch' in df.columns:
                return df['epoch'].iloc[-1] + 1
        except Exception as e:
            print(f"⚠️ Could not read metrics file: {e}")
    return 0

last_epoch = load_last_epoch()

# Get best validation loss from previous runs
def get_best_val_loss():
    if os.path.exists(metrics_file):
        try:
            df = pd.read_excel(metrics_file, engine='openpyxl')
            if 'val_loss' in df.columns and not df['val_loss'].isnull().all():
                return df['val_loss'].min()
        except Exception as e:
            print(f"⚠️ Could not read val_loss from metrics file: {e}")
    return float('inf')

best_val_loss = get_best_val_loss()

# Custom model checkpoint
class CustomModelCheckpoint(tf.keras.callbacks.Callback):
    def __init__(self, filepath):
        super().__init__()
        self.filepath = filepath
        self.best_loss = best_val_loss

    def on_epoch_end(self, epoch, logs=None):
        current_loss = logs.get('val_loss')
        if current_loss is not None and current_loss < self.best_loss:
            self.best_loss = current_loss
            self.model.save(self.filepath)
            print(f"✅ Model saved at epoch {epoch + 1} with val_loss: {current_loss:.4f}")

# === Learning Rate Schedule ===
def lr_schedule(epoch, lr):
    return 1e-4 if epoch >= 5 else lr

lr_scheduler = LearningRateScheduler(lr_schedule, verbose=1)

# Logger for Excel
class MetricsLogger(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        df_new = pd.DataFrame([{**logs, 'epoch': epoch}])
        try:
            if os.path.exists(metrics_file):
                df = pd.read_excel(metrics_file, engine='openpyxl')
                df = pd.concat([df, df_new], ignore_index=True)
            else:
                df = df_new
            df.to_excel(metrics_file, index=False, engine='openpyxl')
        except Exception as e:
            print(f"⚠️ Failed to log metrics: {e}")

# Early stopping with patience and saving best weights
class CustomEarlyStopping(tf.keras.callbacks.Callback):
    def __init__(self, patience=20):
        super().__init__()
        self.patience = patience
        self.wait = 0
        self.best_loss = best_val_loss

    def on_epoch_end(self, epoch, logs=None):
        current_loss = logs.get('val_loss')
        if current_loss is None:
            return
        if current_loss < self.best_loss:
            self.best_loss = current_loss
            self.wait = 0
            self.model.save_weights(checkpoint_filepath)
        else:
            self.wait += 1
            if self.wait >= self.patience:
                print(f"🛑 Early stopping at epoch {epoch + 1}")
                self.model.stop_training = True


# Final callbacks list
callbacks = [
    CustomModelCheckpoint(filepath=checkpoint_filepath),
    MetricsLogger(),
    lr_scheduler,
    CustomEarlyStopping(patience=20)
]
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.3-py2.py3-none-any.whl (251 kB)
#      |████████████████████████████████| 251 kB 19.9 MB/s eta 0:00:01
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.3

# %% [markdown]
# ## Training the model

# %%
import time
import os
import pandas as pd
import numpy as np
from tensorflow.keras.utils import Sequence
from tensorflow.keras.models import load_model

EPOCHS = 100

# Record the start time
start_time = time.time()

# === Load last completed epoch from metrics file ===
def load_last_epoch():
    if os.path.exists(pre_metrics_file):
        try:
            df = pd.read_excel(pre_metrics_file, engine='openpyxl')
            if not df.empty and 'epoch' in df.columns:
                return int(df['epoch'].iloc[-1]) + 1
        except Exception as e:
            print(f"⚠️ Failed to read metrics file: {e}")
    return 0

last_epoch = load_last_epoch()

# === Load pretrained weights if available ===
if os.path.exists(pre_checkpoint_filepath):
    print("✅ Checkpoint found. Loading pretrained weights...")
    model.load_weights(pre_checkpoint_filepath)
    print(f"🔁 Resuming training from epoch {last_epoch}")
else:
    print("🆕 No checkpoint found. Starting training from scratch.")
    last_epoch = 0

# === Prepare input and label tensors ===
lung_train = np.asarray(lung_train, dtype=np.float16)
infect_train = np.asarray(infect_train, dtype=np.uint8)

lung_temp = np.asarray(lung_temp, dtype=np.float16)
infect_temp = np.asarray(infect_temp, dtype=np.uint8)

lung_test = np.asarray(lung_test, dtype=np.float16)
infect_test = np.asarray(infect_test, dtype=np.uint8)

# === Data Generator ===
class LungDataGenerator(Sequence):
    def __init__(self, X, Y, batch_size=8, shuffle=True):
        self.X = X
        self.Y = Y
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indices = np.arange(len(X))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.X) / self.batch_size))

    def __getitem__(self, index):
        batch_ids = self.indices[index * self.batch_size:(index + 1) * self.batch_size]
        X_batch = self.X[batch_ids]
        Y_batch = self.Y[batch_ids]
        return np.asarray(X_batch, dtype=np.float16), np.asarray(Y_batch, dtype=np.uint8)

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indices)

# === Create generators ===
train_gen = LungDataGenerator(lung_train, infect_train, batch_size=8)
temp_gen = LungDataGenerator(lung_temp, infect_temp, batch_size=8, shuffle=False)
val_gen = LungDataGenerator(lung_test, infect_test, batch_size=8, shuffle=False)

# === Train the model ===
history = model.fit(
    train_gen,
    validation_data=temp_gen,
    epochs=EPOCHS,
    initial_epoch=last_epoch,
    callbacks=callbacks
)

# === Timing info ===
end_time = time.time()
total_time = end_time - start_time
print(f"✅ Total training time: {total_time:.2f} seconds ({total_time / 60:.2f} minutes)")
# Out:
# 🆕 No checkpoint found. Starting training from scratch.
# Epoch 1/100
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 239s 196ms/step - loss: 1.3717 - dice_coef_infection: 0.0484 - iou_coef_infection: 0.0261 - precision_infection: 0.0487 - recall_infection: 0.1402 - hausdorff95_infection: 291.2961 - specificity_infection: 0.9801 - accuracy_infection: 0.9723 - f1_infection: 0.8784 - val_loss: 0.8241 - val_dice_coef_infection: 0.3417 - val_iou_coef_infection: 0.3152 - val_precision_infection: 0.3245 - val_recall_infection: 0.8213 - val_hausdorff95_infection: 130.1976 - val_specificity_infection: 0.9783 - val_accuracy_infection: 0.9777 - val_f1_infection: 0.7291
# ✅ Model saved at epoch 1 with val_loss: 0.8241
# Epoch 2/100
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 224s 196ms/step - loss: 0.8499 - dice_coef_infection: 0.2076 - iou_coef_infection: 0.1259 - precision_infection: 0.2056 - recall_infection: 0.3348 - hausdorff95_infection: 147.7871 - specificity_infection: 0.9877 - accuracy_infection: 0.9817 - f1_infection: 0.7630 - val_loss: 1.4291 - val_dice_coef_infection: 0.4703 - val_iou_coef_infection: 0.4503 - val_precision_infection: 0.4667 - val_recall_infection: 0.9159 - val_hausdorff95_infection: 121.1462 - val_specificity_infection: 0.9471 - val_accuracy_infection: 0.9478 - val_f1_infection: 0.7544
# Epoch 3/100
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 220s 192ms/step - loss: 0.7074 - dice_coef_infection: 0.3464 - iou_coef_infection: 0.2314 - precision_infection: 0.3779 - recall_infection: 0.4474 - hausdorff95_infection: 114.0931 - specificity_infection: 0.9936 - accuracy_infection: 0.9892 - f1_infection: 0.7538 - val_loss: 0.4168 - val_dice_coef_infection: 0.6490 - val_iou_coef_infection: 0.6137 - val_precision_infection: 0.7249 - val_recall_infection: 0.7322 - val_hausdorff95_infection: 67.2926 - val_specificity_infection: 0.9955 - val_accuracy_infection: 0.9943 - val_f1_infection: 0.8686
# ✅ Model saved at epoch 3 with val_loss: 0.4168
# Epoch 4/100
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.6135 - dice_coef_infection: 0.4400 - iou_coef_infection: 0.3107 - precision_infection: 0.4899 - recall_infection: 0.5333 - hausdorff95_infection: 96.0937 - specificity_infection: 0.9955 - accuracy_infection: 0.9916 - f1_infection: 0.7566 - val_loss: 0.4573 - val_dice_coef_infection: 0.5906 - val_iou_coef_infection: 0.5534 - val_precision_infection: 0.6392 - val_recall_infection: 0.7388 - val_hausdorff95_infection: 74.7789 - val_specificity_infection: 0.9954 - val_accuracy_infection: 0.9940 - val_f1_infection: 0.8484
# Epoch 5/100
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 219s 192ms/step - loss: 0.5387 - dice_coef_infection: 0.5038 - iou_coef_infection: 0.3682 - precision_infection: 0.5453 - recall_infection: 0.5640 - hausdorff95_infection: 87.2163 - specificity_infection: 0.9968 - accuracy_infection: 0.9935 - f1_infection: 0.7789 - val_loss: 0.4753 - val_dice_coef_infection: 0.5921 - val_iou_coef_infection: 0.5786 - val_precision_infection: 0.7780 - val_recall_infection: 0.6199 - val_hausdorff95_infection: 115.6003 - val_specificity_infection: 0.9990 - val_accuracy_infection: 0.9944 - val_f1_infection: 0.8663
# Epoch 6/100
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 219s 192ms/step - loss: 0.4652 - dice_coef_infection: 0.5682 - iou_coef_infection: 0.4328 - precision_infection: 0.6083 - recall_infection: 0.6165 - hausdorff95_infection: 66.9945 - specificity_infection: 0.9976 - accuracy_infection: 0.9948 - f1_infection: 0.7977 - val_loss: 0.4029 - val_dice_coef_infection: 0.6464 - val_iou_coef_infection: 0.6116 - val_precision_infection: 0.7488 - val_recall_infection: 0.7036 - val_hausdorff95_infection: 75.4383 - val_specificity_infection: 0.9968 - val_accuracy_infection: 0.9952 - val_f1_infection: 0.8662
# ✅ Model saved at epoch 6 with val_loss: 0.4029
# Epoch 7/100
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 220s 192ms/step - loss: 0.4161 - dice_coef_infection: 0.6144 - iou_coef_infection: 0.4812 - precision_infection: 0.6453 - recall_infection: 0.6418 - hausdorff95_infection: 59.0903 - specificity_infection: 0.9978 - accuracy_infection: 0.9954 - f1_infection: 0.8216 - val_loss: 0.3794 - val_dice_coef_infection: 0.6696 - val_iou_coef_infection: 0.6315 - val_precision_infection: 0.7560 - val_recall_infection: 0.7274 - val_hausdorff95_infection: 60.6716 - val_specificity_infection: 0.9961 - val_accuracy_infection: 0.9949 - val_f1_infection: 0.8691
# ✅ Model saved at epoch 7 with val_loss: 0.3794
# Epoch 8/100
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 219s 192ms/step - loss: 0.4023 - dice_coef_infection: 0.6299 - iou_coef_infection: 0.4973 - precision_infection: 0.6718 - recall_infection: 0.6598 - hausdorff95_infection: 57.3100 - specificity_infection: 0.9977 - accuracy_infection: 0.9952 - f1_infection: 0.8185 - val_loss: 0.3781 - val_dice_coef_infection: 0.6650 - val_iou_coef_infection: 0.6292 - val_precision_infection: 0.7720 - val_recall_infection: 0.7160 - val_hausdorff95_infection: 70.9637 - val_specificity_infection: 0.9968 - val_accuracy_infection: 0.9954 - val_f1_infection: 0.8678
# ✅ Model saved at epoch 8 with val_loss: 0.3781
# Epoch 9/100
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 220s 192ms/step - loss: 0.3961 - dice_coef_infection: 0.6317 - iou_coef_infection: 0.4983 - precision_infection: 0.6609 - recall_infection: 0.6778 - hausdorff95_infection: 57.8273 - specificity_infection: 0.9978 - accuracy_infection: 0.9956 - f1_infection: 0.8170 - val_loss: 0.3788 - val_dice_coef_infection: 0.6727 - val_iou_coef_infection: 0.6358 - val_precision_infection: 0.7787 - val_recall_infection: 0.7234 - val_hausdorff95_infection: 70.6524 - val_specificity_infection: 0.9966 - val_accuracy_infection: 0.9953 - val_f1_infection: 0.8671
# Epoch 10/100
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 220s 192ms/step - loss: 0.3784 - dice_coef_infection: 0.6503 - iou_coef_infection: 0.5149 - precision_infection: 0.6836 - recall_infection: 0.6818 - hausdorff95_infection: 53.4184 - specificity_infection: 0.9978 - accuracy_infection: 0.9956 - f1_infection: 0.8246 - val_loss: 0.3859 - val_dice_coef_infection: 0.6773 - val_iou_coef_infection: 0.6377 - val_precision_infection: 0.7893 - val_recall_infection: 0.7217 - val_hausdorff95_infection: 63.0192 - val_specificity_infection: 0.9969 - val_accuracy_infection: 0.9950 - val_f1_infection: 0.8629
# Epoch 11/100
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 220s 193ms/step - loss: 0.3769 - dice_coef_infection: 0.6501 - iou_coef_infection: 0.5152 - precision_infection: 0.6736 - recall_infection: 0.6946 - hausdorff95_infection: 50.6999 - specificity_infection: 0.9979 - accuracy_infection: 0.9958 - f1_infection: 0.8220 - val_loss: 0.3828 - val_dice_coef_infection: 0.6714 - val_iou_coef_infection: 0.6314 - val_precision_infection: 0.7590 - val_recall_infection: 0.7404 - val_hausdorff95_infection: 60.1744 - val_specificity_infection: 0.9959 - val_accuracy_infection: 0.9948 - val_f1_infection: 0.8627
# Epoch 12/100
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 220s 193ms/step - loss: 0.3597 - dice_coef_infection: 0.6687 - iou_coef_infection: 0.5351 - precision_infection: 0.6993 - recall_infection: 0.6985 - hausdorff95_infection: 46.3573 - specificity_infection: 0.9979 - accuracy_infection: 0.9957 - f1_infection: 0.8288 - val_loss: 0.4072 - val_dice_coef_infection: 0.6529 - val_iou_coef_infection: 0.6105 - val_precision_infection: 0.7186 - val_recall_infection: 0.7494 - val_hausdorff95_infection: 58.0487 - val_specificity_infection: 0.9958 - val_accuracy_infection: 0.9945 - val_f1_infection: 0.8589
# Epoch 13/100
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 220s 193ms/step - loss: 0.3649 - dice_coef_infection: 0.6642 - iou_coef_infection: 0.5317 - precision_infection: 0.7007 - recall_infection: 0.6982 - hausdorff95_infection: 44.1444 - specificity_infection: 0.9978 - accuracy_infection: 0.9956 - f1_infection: 0.8260 - val_loss: 0.3685 - val_dice_coef_infection: 0.6767 - val_iou_coef_infection: 0.6353 - val_precision_infection: 0.7708 - val_recall_infection: 0.7351 - val_hausdorff95_infection: 59.2663 - val_specificity_infection: 0.9965 - val_accuracy_infection: 0.9951 - val_f1_infection: 0.8636
# ✅ Model saved at epoch 13 with val_loss: 0.3685
# Epoch 14/100
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 220s 193ms/step - loss: 0.3615 - dice_coef_infection: 0.6638 - iou_coef_infection: 0.5317 - precision_infection: 0.6962 - recall_infection: 0.6899 - hausdorff95_infection: 46.8892 - specificity_infection: 0.9980 - accuracy_infection: 0.9960 - f1_infection: 0.8313 - val_loss: 0.3565 - val_dice_coef_infection: 0.6900 - val_iou_coef_infection: 0.6496 - val_precision_infection: 0.7919 - val_recall_infection: 0.7350 - val_hausdorff95_infection: 58.6745 - val_specificity_infection: 0.9964 - val_accuracy_infection: 0.9951 - val_f1_infection: 0.8676
# ✅ Model saved at epoch 14 with val_loss: 0.3565
# Epoch 15/100
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 220s 192ms/step - loss: 0.3439 - dice_coef_infection: 0.6820 - iou_coef_infection: 0.5467 - precision_infection: 0.7091 - recall_infection: 0.7078 - hausdorff95_infection: 45.0691 - specificity_infection: 0.9980 - accuracy_infection: 0.9959 - f1_infection: 0.8335 - val_loss: 0.3692 - val_dice_coef_infection: 0.6801 - val_iou_coef_infection: 0.6381 - val_precision_infection: 0.7961 - val_recall_infection: 0.7289 - val_hausdorff95_infection: 60.8382 - val_specificity_infection: 0.9971 - val_accuracy_infection: 0.9951 - val_f1_infection: 0.8590
# Epoch 16/100
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 220s 193ms/step - loss: 0.3446 - dice_coef_infection: 0.6827 - iou_coef_infection: 0.5514 - precision_infection: 0.7207 - recall_infection: 0.7071 - hausdorff95_infection: 42.8766 - specificity_infection: 0.9980 - accuracy_infection: 0.9959 - f1_infection: 0.8342 - val_loss: 0.3589 - val_dice_coef_infection: 0.6902 - val_iou_coef_infection: 0.6509 - val_precision_infection: 0.8146 - val_recall_infection: 0.7372 - val_hausdorff95_infection: 64.4781 - val_specificity_infection: 0.9961 - val_accuracy_infection: 0.9948 - val_f1_infection: 0.8596
# Epoch 17/100
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 220s 192ms/step - loss: 0.3379 - dice_coef_infection: 0.6899 - iou_coef_infection: 0.5568 - precision_infection: 0.7262 - recall_infection: 0.7077 - hausdorff95_infection: 42.1533 - specificity_infection: 0.9980 - accuracy_infection: 0.9959 - f1_infection: 0.8364 - val_loss: 0.3661 - val_dice_coef_infection: 0.6953 - val_iou_coef_infection: 0.6558 - val_precision_infection: 0.8375 - val_recall_infection: 0.7178 - val_hausdorff95_infection: 62.7778 - val_specificity_infection: 0.9974 - val_accuracy_infection: 0.9948 - val_f1_infection: 0.8622
# Epoch 18/100
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 220s 192ms/step - loss: 0.3467 - dice_coef_infection: 0.6789 - iou_coef_infection: 0.5484 - precision_infection: 0.7065 - recall_infection: 0.7060 - hausdorff95_infection: 39.0420 - specificity_infection: 0.9980 - accuracy_infection: 0.9961 - f1_infection: 0.8369 - val_loss: 0.3622 - val_dice_coef_infection: 0.6841 - val_iou_coef_infection: 0.6431 - val_precision_infection: 0.8160 - val_recall_infection: 0.7240 - val_hausdorff95_infection: 62.4749 - val_specificity_infection: 0.9973 - val_accuracy_infection: 0.9953 - val_f1_infection: 0.8570
# Epoch 19/100
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 220s 193ms/step - loss: 0.3365 - dice_coef_infection: 0.6908 - iou_coef_infection: 0.5591 - precision_infection: 0.7315 - recall_infection: 0.7026 - hausdorff95_infection: 36.9841 - specificity_infection: 0.9980 - accuracy_infection: 0.9959 - f1_infection: 0.8396 - val_loss: 0.3725 - val_dice_coef_infection: 0.6861 - val_iou_coef_infection: 0.6462 - val_precision_infection: 0.8084 - val_recall_infection: 0.7234 - val_hausdorff95_infection: 62.7903 - val_specificity_infection: 0.9971 - val_accuracy_infection: 0.9947 - val_f1_infection: 0.8636
# Epoch 20/100
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.3452 - dice_coef_infection: 0.6824 - iou_coef_infection: 0.5519 - precision_infection: 0.7202 - recall_infection: 0.7087 - hausdorff95_infection: 37.5364 - specificity_infection: 0.9980 - accuracy_infection: 0.9959 - f1_infection: 0.8339 - val_loss: 0.3752 - val_dice_coef_infection: 0.6901 - val_iou_coef_infection: 0.6536 - val_precision_infection: 0.8404 - val_recall_infection: 0.7080 - val_hausdorff95_infection: 73.7147 - val_specificity_infection: 0.9975 - val_accuracy_infection: 0.9953 - val_f1_infection: 0.8639
# Epoch 21/100
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 220s 193ms/step - loss: 0.3299 - dice_coef_infection: 0.6956 - iou_coef_infection: 0.5655 - precision_infection: 0.7184 - recall_infection: 0.7225 - hausdorff95_infection: 35.5615 - specificity_infection: 0.9980 - accuracy_infection: 0.9960 - f1_infection: 0.8427 - val_loss: 0.3729 - val_dice_coef_infection: 0.6905 - val_iou_coef_infection: 0.6513 - val_precision_infection: 0.8540 - val_recall_infection: 0.6973 - val_hausdorff95_infection: 67.8605 - val_specificity_infection: 0.9982 - val_accuracy_infection: 0.9948 - val_f1_infection: 0.8608
# Epoch 22/100
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.3150 - dice_coef_infection: 0.7085 - iou_coef_infection: 0.5787 - precision_infection: 0.7340 - recall_infection: 0.7276 - hausdorff95_infection: 34.7279 - specificity_infection: 0.9981 - accuracy_infection: 0.9964 - f1_infection: 0.8461 - val_loss: 0.3505 - val_dice_coef_infection: 0.6956 - val_iou_coef_infection: 0.6566 - val_precision_infection: 0.8391 - val_recall_infection: 0.7188 - val_hausdorff95_infection: 63.0468 - val_specificity_infection: 0.9976 - val_accuracy_infection: 0.9952 - val_f1_infection: 0.8633
# ✅ Model saved at epoch 22 with val_loss: 0.3505
# Epoch 23/100
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.3322 - dice_coef_infection: 0.6940 - iou_coef_infection: 0.5638 - precision_infection: 0.7368 - recall_infection: 0.7091 - hausdorff95_infection: 36.3163 - specificity_infection: 0.9981 - accuracy_infection: 0.9961 - f1_infection: 0.8386 - val_loss: 0.3505 - val_dice_coef_infection: 0.6975 - val_iou_coef_infection: 0.6616 - val_precision_infection: 0.8698 - val_recall_infection: 0.7124 - val_hausdorff95_infection: 71.6272 - val_specificity_infection: 0.9976 - val_accuracy_infection: 0.9956 - val_f1_infection: 0.8581
# ✅ Model saved at epoch 23 with val_loss: 0.3505
# Epoch 24/100
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.3176 - dice_coef_infection: 0.7088 - iou_coef_infection: 0.5774 - precision_infection: 0.7350 - recall_infection: 0.7298 - hausdorff95_infection: 33.2529 - specificity_infection: 0.9979 - accuracy_infection: 0.9960 - f1_infection: 0.8426 - val_loss: 0.3558 - val_dice_coef_infection: 0.6989 - val_iou_coef_infection: 0.6583 - val_precision_infection: 0.8410 - val_recall_infection: 0.7220 - val_hausdorff95_infection: 63.2148 - val_specificity_infection: 0.9976 - val_accuracy_infection: 0.9952 - val_f1_infection: 0.8620
# Epoch 25/100
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.3221 - dice_coef_infection: 0.7009 - iou_coef_infection: 0.5708 - precision_infection: 0.7233 - recall_infection: 0.7322 - hausdorff95_infection: 34.0790 - specificity_infection: 0.9980 - accuracy_infection: 0.9962 - f1_infection: 0.8406 - val_loss: 0.3407 - val_dice_coef_infection: 0.7061 - val_iou_coef_infection: 0.6654 - val_precision_infection: 0.8422 - val_recall_infection: 0.7272 - val_hausdorff95_infection: 60.7139 - val_specificity_infection: 0.9973 - val_accuracy_infection: 0.9953 - val_f1_infection: 0.8657
# ✅ Model saved at epoch 25 with val_loss: 0.3407
# Epoch 26/100
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 220s 193ms/step - loss: 0.3382 - dice_coef_infection: 0.6875 - iou_coef_infection: 0.5590 - precision_infection: 0.7188 - recall_infection: 0.7243 - hausdorff95_infection: 35.1116 - specificity_infection: 0.9980 - accuracy_infection: 0.9961 - f1_infection: 0.8361 - val_loss: 0.3457 - val_dice_coef_infection: 0.6944 - val_iou_coef_infection: 0.6564 - val_precision_infection: 0.8534 - val_recall_infection: 0.7127 - val_hausdorff95_infection: 68.2302 - val_specificity_infection: 0.9978 - val_accuracy_infection: 0.9958 - val_f1_infection: 0.8608
# Epoch 27/100
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 220s 193ms/step - loss: 0.3175 - dice_coef_infection: 0.7065 - iou_coef_infection: 0.5790 - precision_infection: 0.7504 - recall_infection: 0.7203 - hausdorff95_infection: 29.7070 - specificity_infection: 0.9981 - accuracy_infection: 0.9962 - f1_infection: 0.8424 - val_loss: 0.3696 - val_dice_coef_infection: 0.6906 - val_iou_coef_infection: 0.6480 - val_precision_infection: 0.8010 - val_recall_infection: 0.7232 - val_hausdorff95_infection: 57.5404 - val_specificity_infection: 0.9972 - val_accuracy_infection: 0.9947 - val_f1_infection: 0.8682
# Epoch 28/100
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.3020 - dice_coef_infection: 0.7226 - iou_coef_infection: 0.5932 - precision_infection: 0.7526 - recall_infection: 0.7358 - hausdorff95_infection: 30.9693 - specificity_infection: 0.9980 - accuracy_infection: 0.9961 - f1_infection: 0.8488 - val_loss: 0.3669 - val_dice_coef_infection: 0.6825 - val_iou_coef_infection: 0.6451 - val_precision_infection: 0.8333 - val_recall_infection: 0.7164 - val_hausdorff95_infection: 74.2197 - val_specificity_infection: 0.9975 - val_accuracy_infection: 0.9956 - val_f1_infection: 0.8592
# Epoch 29/100
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.2991 - dice_coef_infection: 0.7253 - iou_coef_infection: 0.5968 - precision_infection: 0.7540 - recall_infection: 0.7466 - hausdorff95_infection: 30.0172 - specificity_infection: 0.9981 - accuracy_infection: 0.9964 - f1_infection: 0.8480 - val_loss: 0.3527 - val_dice_coef_infection: 0.6993 - val_iou_coef_infection: 0.6624 - val_precision_infection: 0.8752 - val_recall_infection: 0.7084 - val_hausdorff95_infection: 69.3371 - val_specificity_infection: 0.9978 - val_accuracy_infection: 0.9956 - val_f1_infection: 0.8606
# Epoch 30/100
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.2927 - dice_coef_infection: 0.7311 - iou_coef_infection: 0.6057 - precision_infection: 0.7585 - recall_infection: 0.7501 - hausdorff95_infection: 30.9400 - specificity_infection: 0.9981 - accuracy_infection: 0.9964 - f1_infection: 0.8541 - val_loss: 0.3835 - val_dice_coef_infection: 0.6897 - val_iou_coef_infection: 0.6488 - val_precision_infection: 0.8673 - val_recall_infection: 0.6933 - val_hausdorff95_infection: 67.9424 - val_specificity_infection: 0.9985 - val_accuracy_infection: 0.9945 - val_f1_infection: 0.8562
# Epoch 31/100
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 194ms/step - loss: 0.3202 - dice_coef_infection: 0.7055 - iou_coef_infection: 0.5781 - precision_infection: 0.7340 - recall_infection: 0.7331 - hausdorff95_infection: 31.9568 - specificity_infection: 0.9980 - accuracy_infection: 0.9962 - f1_infection: 0.8435 - val_loss: 0.3450 - val_dice_coef_infection: 0.7191 - val_iou_coef_infection: 0.6744 - val_precision_infection: 0.8422 - val_recall_infection: 0.7184 - val_hausdorff95_infection: 50.8915 - val_specificity_infection: 0.9979 - val_accuracy_infection: 0.9946 - val_f1_infection: 0.8772
# Epoch 32/100
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 194ms/step - loss: 0.2851 - dice_coef_infection: 0.7378 - iou_coef_infection: 0.6129 - precision_infection: 0.7574 - recall_infection: 0.7594 - hausdorff95_infection: 27.2757 - specificity_infection: 0.9980 - accuracy_infection: 0.9962 - f1_infection: 0.8567 - val_loss: 0.3415 - val_dice_coef_infection: 0.7122 - val_iou_coef_infection: 0.6697 - val_precision_infection: 0.8665 - val_recall_infection: 0.7180 - val_hausdorff95_infection: 58.9178 - val_specificity_infection: 0.9979 - val_accuracy_infection: 0.9952 - val_f1_infection: 0.8653
# Epoch 33/100
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 194ms/step - loss: 0.2914 - dice_coef_infection: 0.7300 - iou_coef_infection: 0.6041 - precision_infection: 0.7619 - recall_infection: 0.7429 - hausdorff95_infection: 28.2320 - specificity_infection: 0.9981 - accuracy_infection: 0.9965 - f1_infection: 0.8534 - val_loss: 0.3653 - val_dice_coef_infection: 0.6980 - val_iou_coef_infection: 0.6533 - val_precision_infection: 0.8482 - val_recall_infection: 0.7093 - val_hausdorff95_infection: 58.7876 - val_specificity_infection: 0.9984 - val_accuracy_infection: 0.9945 - val_f1_infection: 0.8608
# Epoch 34/100
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 194ms/step - loss: 0.2835 - dice_coef_infection: 0.7385 - iou_coef_infection: 0.6108 - precision_infection: 0.7618 - recall_infection: 0.7563 - hausdorff95_infection: 29.0776 - specificity_infection: 0.9981 - accuracy_infection: 0.9964 - f1_infection: 0.8537 - val_loss: 0.3749 - val_dice_coef_infection: 0.6848 - val_iou_coef_infection: 0.6469 - val_precision_infection: 0.8755 - val_recall_infection: 0.6955 - val_hausdorff95_infection: 72.9090 - val_specificity_infection: 0.9984 - val_accuracy_infection: 0.9955 - val_f1_infection: 0.8518
# Epoch 35/100
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 194ms/step - loss: 0.2970 - dice_coef_infection: 0.7241 - iou_coef_infection: 0.5950 - precision_infection: 0.7380 - recall_infection: 0.7594 - hausdorff95_infection: 29.4189 - specificity_infection: 0.9980 - accuracy_infection: 0.9964 - f1_infection: 0.8483 - val_loss: 0.3857 - val_dice_coef_infection: 0.6845 - val_iou_coef_infection: 0.6408 - val_precision_infection: 0.8308 - val_recall_infection: 0.6985 - val_hausdorff95_infection: 60.4575 - val_specificity_infection: 0.9986 - val_accuracy_infection: 0.9945 - val_f1_infection: 0.8623
# Epoch 36/100
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 222s 194ms/step - loss: 0.2738 - dice_coef_infection: 0.7468 - iou_coef_infection: 0.6189 - precision_infection: 0.7688 - recall_infection: 0.7609 - hausdorff95_infection: 25.5927 - specificity_infection: 0.9982 - accuracy_infection: 0.9965 - f1_infection: 0.8571 - val_loss: 0.3694 - val_dice_coef_infection: 0.6803 - val_iou_coef_infection: 0.6393 - val_precision_infection: 0.7911 - val_recall_infection: 0.7292 - val_hausdorff95_infection: 58.3871 - val_specificity_infection: 0.9966 - val_accuracy_infection: 0.9949 - val_f1_infection: 0.8629
# Epoch 37/100
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.2824 - dice_coef_infection: 0.7394 - iou_coef_infection: 0.6145 - precision_infection: 0.7710 - recall_infection: 0.7475 - hausdorff95_infection: 26.6366 - specificity_infection: 0.9982 - accuracy_infection: 0.9965 - f1_infection: 0.8568 - val_loss: 0.4267 - val_dice_coef_infection: 0.6324 - val_iou_coef_infection: 0.6000 - val_precision_infection: 0.8577 - val_recall_infection: 0.6733 - val_hausdorff95_infection: 94.3509 - val_specificity_infection: 0.9988 - val_accuracy_infection: 0.9953 - val_f1_infection: 0.8288
# Epoch 38/100
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 194ms/step - loss: 0.2718 - dice_coef_infection: 0.7489 - iou_coef_infection: 0.6230 - precision_infection: 0.7744 - recall_infection: 0.7605 - hausdorff95_infection: 24.8230 - specificity_infection: 0.9983 - accuracy_infection: 0.9967 - f1_infection: 0.8591 - val_loss: 0.3898 - val_dice_coef_infection: 0.6616 - val_iou_coef_infection: 0.6223 - val_precision_infection: 0.8116 - val_recall_infection: 0.7115 - val_hausdorff95_infection: 70.3315 - val_specificity_infection: 0.9978 - val_accuracy_infection: 0.9955 - val_f1_infection: 0.8482
# Epoch 39/100
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 194ms/step - loss: 0.2677 - dice_coef_infection: 0.7525 - iou_coef_infection: 0.6264 - precision_infection: 0.7751 - recall_infection: 0.7670 - hausdorff95_infection: 24.8140 - specificity_infection: 0.9982 - accuracy_infection: 0.9966 - f1_infection: 0.8600 - val_loss: 0.3962 - val_dice_coef_infection: 0.6848 - val_iou_coef_infection: 0.6473 - val_precision_infection: 0.8826 - val_recall_infection: 0.6809 - val_hausdorff95_infection: 78.5455 - val_specificity_infection: 0.9986 - val_accuracy_infection: 0.9946 - val_f1_infection: 0.8551
# Epoch 40/100
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 194ms/step - loss: 0.2853 - dice_coef_infection: 0.7364 - iou_coef_infection: 0.6111 - precision_infection: 0.7708 - recall_infection: 0.7498 - hausdorff95_infection: 26.5831 - specificity_infection: 0.9983 - accuracy_infection: 0.9966 - f1_infection: 0.8530 - val_loss: 0.3655 - val_dice_coef_infection: 0.6773 - val_iou_coef_infection: 0.6393 - val_precision_infection: 0.8398 - val_recall_infection: 0.7019 - val_hausdorff95_infection: 72.5595 - val_specificity_infection: 0.9983 - val_accuracy_infection: 0.9958 - val_f1_infection: 0.8573
# Epoch 41/100
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 194ms/step - loss: 0.2523 - dice_coef_infection: 0.7681 - iou_coef_infection: 0.6432 - precision_infection: 0.7858 - recall_infection: 0.7777 - hausdorff95_infection: 23.1363 - specificity_infection: 0.9982 - accuracy_infection: 0.9966 - f1_infection: 0.8668 - val_loss: 0.4200 - val_dice_coef_infection: 0.6324 - val_iou_coef_infection: 0.5941 - val_precision_infection: 0.7835 - val_recall_infection: 0.7037 - val_hausdorff95_infection: 78.3024 - val_specificity_infection: 0.9982 - val_accuracy_infection: 0.9955 - val_f1_infection: 0.8396
# Epoch 42/100
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 194ms/step - loss: 0.2758 - dice_coef_infection: 0.7446 - iou_coef_infection: 0.6198 - precision_infection: 0.7729 - recall_infection: 0.7540 - hausdorff95_infection: 26.8513 - specificity_infection: 0.9983 - accuracy_infection: 0.9966 - f1_infection: 0.8588 - val_loss: 0.3516 - val_dice_coef_infection: 0.7170 - val_iou_coef_infection: 0.6750 - val_precision_infection: 0.8467 - val_recall_infection: 0.7204 - val_hausdorff95_infection: 59.7220 - val_specificity_infection: 0.9977 - val_accuracy_infection: 0.9951 - val_f1_infection: 0.8764
# Epoch 43/100
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 194ms/step - loss: 0.2757 - dice_coef_infection: 0.7452 - iou_coef_infection: 0.6193 - precision_infection: 0.7663 - recall_infection: 0.7599 - hausdorff95_infection: 27.1116 - specificity_infection: 0.9982 - accuracy_infection: 0.9967 - f1_infection: 0.8593 - val_loss: 0.3308 - val_dice_coef_infection: 0.7309 - val_iou_coef_infection: 0.6849 - val_precision_infection: 0.8623 - val_recall_infection: 0.7222 - val_hausdorff95_infection: 51.0632 - val_specificity_infection: 0.9979 - val_accuracy_infection: 0.9952 - val_f1_infection: 0.8775
# ✅ Model saved at epoch 43 with val_loss: 0.3308
# Epoch 44/100
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 222s 194ms/step - loss: 0.2596 - dice_coef_infection: 0.7598 - iou_coef_infection: 0.6378 - precision_infection: 0.7843 - recall_infection: 0.7677 - hausdorff95_infection: 22.5449 - specificity_infection: 0.9983 - accuracy_infection: 0.9967 - f1_infection: 0.8654 - val_loss: 0.3402 - val_dice_coef_infection: 0.7089 - val_iou_coef_infection: 0.6661 - val_precision_infection: 0.8353 - val_recall_infection: 0.7277 - val_hausdorff95_infection: 54.6431 - val_specificity_infection: 0.9973 - val_accuracy_infection: 0.9954 - val_f1_infection: 0.8698
# Epoch 45/100
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 194ms/step - loss: 0.2693 - dice_coef_infection: 0.7508 - iou_coef_infection: 0.6284 - precision_infection: 0.7807 - recall_infection: 0.7637 - hausdorff95_infection: 22.9750 - specificity_infection: 0.9982 - accuracy_infection: 0.9966 - f1_infection: 0.8600 - val_loss: 0.3322 - val_dice_coef_infection: 0.7140 - val_iou_coef_infection: 0.6736 - val_precision_infection: 0.8673 - val_recall_infection: 0.7101 - val_hausdorff95_infection: 61.6670 - val_specificity_infection: 0.9980 - val_accuracy_infection: 0.9956 - val_f1_infection: 0.8722
# Epoch 46/100
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 194ms/step - loss: 0.2456 - dice_coef_infection: 0.7735 - iou_coef_infection: 0.6530 - precision_infection: 0.7890 - recall_infection: 0.7833 - hausdorff95_infection: 22.9062 - specificity_infection: 0.9983 - accuracy_infection: 0.9967 - f1_infection: 0.8704 - val_loss: 0.3501 - val_dice_coef_infection: 0.7085 - val_iou_coef_infection: 0.6678 - val_precision_infection: 0.8501 - val_recall_infection: 0.7070 - val_hausdorff95_infection: 62.4852 - val_specificity_infection: 0.9980 - val_accuracy_infection: 0.9950 - val_f1_infection: 0.8744
# Epoch 47/100
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 194ms/step - loss: 0.2580 - dice_coef_infection: 0.7628 - iou_coef_infection: 0.6403 - precision_infection: 0.7919 - recall_infection: 0.7742 - hausdorff95_infection: 23.2409 - specificity_infection: 0.9983 - accuracy_infection: 0.9967 - f1_infection: 0.8634 - val_loss: 0.3438 - val_dice_coef_infection: 0.7213 - val_iou_coef_infection: 0.6792 - val_precision_infection: 0.8731 - val_recall_infection: 0.7035 - val_hausdorff95_infection: 64.7872 - val_specificity_infection: 0.9984 - val_accuracy_infection: 0.9947 - val_f1_infection: 0.8764
# Epoch 48/100
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.2446 - dice_coef_infection: 0.7737 - iou_coef_infection: 0.6525 - precision_infection: 0.7931 - recall_infection: 0.7827 - hausdorff95_infection: 21.5281 - specificity_infection: 0.9983 - accuracy_infection: 0.9969 - f1_infection: 0.8695 - val_loss: 0.3695 - val_dice_coef_infection: 0.6914 - val_iou_coef_infection: 0.6508 - val_precision_infection: 0.8571 - val_recall_infection: 0.6977 - val_hausdorff95_infection: 65.4555 - val_specificity_infection: 0.9985 - val_accuracy_infection: 0.9953 - val_f1_infection: 0.8626
# Epoch 49/100
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.2639 - dice_coef_infection: 0.7551 - iou_coef_infection: 0.6333 - precision_infection: 0.7777 - recall_infection: 0.7690 - hausdorff95_infection: 24.7136 - specificity_infection: 0.9984 - accuracy_infection: 0.9969 - f1_infection: 0.8641 - val_loss: 0.4526 - val_dice_coef_infection: 0.6927 - val_iou_coef_infection: 0.6500 - val_precision_infection: 0.8537 - val_recall_infection: 0.6885 - val_hausdorff95_infection: 66.0573 - val_specificity_infection: 0.9984 - val_accuracy_infection: 0.9934 - val_f1_infection: 0.8655
# Epoch 50/100
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.2602 - dice_coef_infection: 0.7599 - iou_coef_infection: 0.6371 - precision_infection: 0.7856 - recall_infection: 0.7749 - hausdorff95_infection: 23.8466 - specificity_infection: 0.9983 - accuracy_infection: 0.9967 - f1_infection: 0.8633 - val_loss: 0.3764 - val_dice_coef_infection: 0.7068 - val_iou_coef_infection: 0.6649 - val_precision_infection: 0.8805 - val_recall_infection: 0.6997 - val_hausdorff95_infection: 63.2639 - val_specificity_infection: 0.9984 - val_accuracy_infection: 0.9944 - val_f1_infection: 0.8635
# Epoch 51/100
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.2541 - dice_coef_infection: 0.7646 - iou_coef_infection: 0.6451 - precision_infection: 0.7899 - recall_infection: 0.7753 - hausdorff95_infection: 22.4206 - specificity_infection: 0.9984 - accuracy_infection: 0.9970 - f1_infection: 0.8685 - val_loss: 0.4417 - val_dice_coef_infection: 0.6877 - val_iou_coef_infection: 0.6512 - val_precision_infection: 0.9344 - val_recall_infection: 0.6594 - val_hausdorff95_infection: 82.5265 - val_specificity_infection: 0.9992 - val_accuracy_infection: 0.9938 - val_f1_infection: 0.8492
# Epoch 52/100
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 194ms/step - loss: 0.2336 - dice_coef_infection: 0.7861 - iou_coef_infection: 0.6662 - precision_infection: 0.8040 - recall_infection: 0.7939 - hausdorff95_infection: 19.1505 - specificity_infection: 0.9984 - accuracy_infection: 0.9968 - f1_infection: 0.8749 - val_loss: 0.3472 - val_dice_coef_infection: 0.7124 - val_iou_coef_infection: 0.6682 - val_precision_infection: 0.8443 - val_recall_infection: 0.7193 - val_hausdorff95_infection: 53.3389 - val_specificity_infection: 0.9979 - val_accuracy_infection: 0.9952 - val_f1_infection: 0.8717
# Epoch 53/100
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 194ms/step - loss: 0.2356 - dice_coef_infection: 0.7824 - iou_coef_infection: 0.6662 - precision_infection: 0.8012 - recall_infection: 0.7924 - hausdorff95_infection: 22.3983 - specificity_infection: 0.9983 - accuracy_infection: 0.9969 - f1_infection: 0.8765 - val_loss: 0.3644 - val_dice_coef_infection: 0.6935 - val_iou_coef_infection: 0.6565 - val_precision_infection: 0.8813 - val_recall_infection: 0.6900 - val_hausdorff95_infection: 73.3602 - val_specificity_infection: 0.9986 - val_accuracy_infection: 0.9953 - val_f1_infection: 0.8611
# Epoch 54/100
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.2511 - dice_coef_infection: 0.7681 - iou_coef_infection: 0.6493 - precision_infection: 0.7933 - recall_infection: 0.7790 - hausdorff95_infection: 24.2399 - specificity_infection: 0.9984 - accuracy_infection: 0.9970 - f1_infection: 0.8694 - val_loss: 0.3643 - val_dice_coef_infection: 0.6815 - val_iou_coef_infection: 0.6429 - val_precision_infection: 0.8459 - val_recall_infection: 0.7024 - val_hausdorff95_infection: 69.5260 - val_specificity_infection: 0.9982 - val_accuracy_infection: 0.9956 - val_f1_infection: 0.8579
# Epoch 55/100
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 220s 193ms/step - loss: 0.2321 - dice_coef_infection: 0.7853 - iou_coef_infection: 0.6672 - precision_infection: 0.8011 - recall_infection: 0.7953 - hausdorff95_infection: 20.5601 - specificity_infection: 0.9984 - accuracy_infection: 0.9970 - f1_infection: 0.8764 - val_loss: 0.3574 - val_dice_coef_infection: 0.6993 - val_iou_coef_infection: 0.6612 - val_precision_infection: 0.8824 - val_recall_infection: 0.6963 - val_hausdorff95_infection: 70.5646 - val_specificity_infection: 0.9982 - val_accuracy_infection: 0.9952 - val_f1_infection: 0.8618
# Epoch 56/100
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 220s 193ms/step - loss: 0.2365 - dice_coef_infection: 0.7806 - iou_coef_infection: 0.6642 - precision_infection: 0.8052 - recall_infection: 0.7917 - hausdorff95_infection: 19.4314 - specificity_infection: 0.9985 - accuracy_infection: 0.9971 - f1_infection: 0.8739 - val_loss: 0.3692 - val_dice_coef_infection: 0.6881 - val_iou_coef_infection: 0.6491 - val_precision_infection: 0.8652 - val_recall_infection: 0.6974 - val_hausdorff95_infection: 69.3333 - val_specificity_infection: 0.9984 - val_accuracy_infection: 0.9954 - val_f1_infection: 0.8575
# Epoch 57/100
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 220s 193ms/step - loss: 0.2311 - dice_coef_infection: 0.7876 - iou_coef_infection: 0.6676 - precision_infection: 0.7998 - recall_infection: 0.8000 - hausdorff95_infection: 22.7143 - specificity_infection: 0.9984 - accuracy_infection: 0.9968 - f1_infection: 0.8763 - val_loss: 0.3688 - val_dice_coef_infection: 0.6884 - val_iou_coef_infection: 0.6491 - val_precision_infection: 0.8402 - val_recall_infection: 0.6997 - val_hausdorff95_infection: 70.3836 - val_specificity_infection: 0.9983 - val_accuracy_infection: 0.9951 - val_f1_infection: 0.8673
# Epoch 58/100
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 220s 193ms/step - loss: 0.2393 - dice_coef_infection: 0.7786 - iou_coef_infection: 0.6620 - precision_infection: 0.8013 - recall_infection: 0.7879 - hausdorff95_infection: 20.5800 - specificity_infection: 0.9985 - accuracy_infection: 0.9971 - f1_infection: 0.8738 - val_loss: 0.3505 - val_dice_coef_infection: 0.7171 - val_iou_coef_infection: 0.6745 - val_precision_infection: 0.8842 - val_recall_infection: 0.6994 - val_hausdorff95_infection: 60.1594 - val_specificity_infection: 0.9984 - val_accuracy_infection: 0.9949 - val_f1_infection: 0.8715
# Epoch 59/100
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 220s 193ms/step - loss: 0.2273 - dice_coef_infection: 0.7891 - iou_coef_infection: 0.6695 - precision_infection: 0.8041 - recall_infection: 0.7952 - hausdorff95_infection: 19.1801 - specificity_infection: 0.9985 - accuracy_infection: 0.9972 - f1_infection: 0.8767 - val_loss: 0.3730 - val_dice_coef_infection: 0.6871 - val_iou_coef_infection: 0.6495 - val_precision_infection: 0.8473 - val_recall_infection: 0.6990 - val_hausdorff95_infection: 72.3218 - val_specificity_infection: 0.9981 - val_accuracy_infection: 0.9953 - val_f1_infection: 0.8652
# Epoch 60/100
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 220s 193ms/step - loss: 0.2446 - dice_coef_infection: 0.7736 - iou_coef_infection: 0.6553 - precision_infection: 0.7903 - recall_infection: 0.7925 - hausdorff95_infection: 21.7137 - specificity_infection: 0.9984 - accuracy_infection: 0.9970 - f1_infection: 0.8706 - val_loss: 0.4004 - val_dice_coef_infection: 0.6770 - val_iou_coef_infection: 0.6363 - val_precision_infection: 0.8356 - val_recall_infection: 0.7003 - val_hausdorff95_infection: 68.5338 - val_specificity_infection: 0.9982 - val_accuracy_infection: 0.9946 - val_f1_infection: 0.8569
# Epoch 61/100
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 220s 193ms/step - loss: 0.2307 - dice_coef_infection: 0.7877 - iou_coef_infection: 0.6708 - precision_infection: 0.8110 - recall_infection: 0.7952 - hausdorff95_infection: 18.3262 - specificity_infection: 0.9984 - accuracy_infection: 0.9970 - f1_infection: 0.8763 - val_loss: 0.3993 - val_dice_coef_infection: 0.6914 - val_iou_coef_infection: 0.6507 - val_precision_infection: 0.8814 - val_recall_infection: 0.6890 - val_hausdorff95_infection: 68.3149 - val_specificity_infection: 0.9986 - val_accuracy_infection: 0.9945 - val_f1_infection: 0.8554
# Epoch 62/100
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.2193 - dice_coef_infection: 0.7976 - iou_coef_infection: 0.6831 - precision_infection: 0.8183 - recall_infection: 0.8024 - hausdorff95_infection: 19.8175 - specificity_infection: 0.9985 - accuracy_infection: 0.9971 - f1_infection: 0.8814 - val_loss: 0.3780 - val_dice_coef_infection: 0.7030 - val_iou_coef_infection: 0.6585 - val_precision_infection: 0.8542 - val_recall_infection: 0.7046 - val_hausdorff95_infection: 57.2144 - val_specificity_infection: 0.9984 - val_accuracy_infection: 0.9947 - val_f1_infection: 0.8670
# Epoch 63/100
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.2205 - dice_coef_infection: 0.7960 - iou_coef_infection: 0.6824 - precision_infection: 0.8154 - recall_infection: 0.8032 - hausdorff95_infection: 17.7587 - specificity_infection: 0.9985 - accuracy_infection: 0.9972 - f1_infection: 0.8818 - val_loss: 0.3590 - val_dice_coef_infection: 0.6989 - val_iou_coef_infection: 0.6627 - val_precision_infection: 0.8684 - val_recall_infection: 0.6996 - val_hausdorff95_infection: 72.3313 - val_specificity_infection: 0.9979 - val_accuracy_infection: 0.9954 - val_f1_infection: 0.8667
# 🛑 Early stopping at epoch 63
# ✅ Total training time: 13937.00 seconds (232.28 minutes)

# %% [markdown]
# ## Plotting the performance metrics

# %%
plt.plot(history.history['dice_coef_infection'])
plt.plot(history.history['val_dice_coef_infection'])
plt.title('dice_coef_infection vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Dice_coef')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# %%
plt.plot(history.history['iou_coef_infection'])
plt.plot(history.history['val_iou_coef_infection'])
plt.title('iou_coef_infection vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Iou_coef')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Val'], loc = 'upper right')
plt.show()

# %% [markdown]
# ## Using our trained model for prediction

# %%
import numpy as np
import time

# Start timer (high precision)
start_time = time.perf_counter()

# Evaluate the model on the validation generator
results = model.evaluate(val_gen, verbose=1)

# End timer
end_time = time.perf_counter()

# Calculate evaluation time
eval_time = end_time - start_time

# Print metric names with results
print("\n===== Validation Metrics =====")
for name, value in zip(model.metrics_names, results):
    print(f"{name}: {value:.6f}")

print(f"\nEvaluation Time: {eval_time:.8f} seconds\n")
# Out:
# 128/128 [==============================] - 9s 74ms/step - loss: 0.3451 - dice_coef_infection: 0.7037 - iou_coef_infection: 0.6552 - precision_infection: 0.8076 - recall_infection: 0.7879 - hausdorff95_infection: 54.4325 - specificity_infection: 0.9983 - accuracy_infection: 0.9962 - f1_infection: 0.8589
#
# ===== Validation Metrics =====
# loss: 0.345144
# dice_coef_infection: 0.703693
# iou_coef_infection: 0.655181
# precision_infection: 0.807630
# recall_infection: 0.787939
# hausdorff95_infection: 54.432549
# specificity_infection: 0.998348
# accuracy_infection: 0.996210
# f1_infection: 0.858860
#
# Evaluation Time: 9.49957255 seconds

# %%
import matplotlib.pyplot as plt
import numpy as np

# Run inference if not already done
predicted = model.predict(lung_test)

# Selected indices to visualize (744 as 1st, 280 as 2nd, 230 as 3rd)
selected_indices = [744, 280, 230]
n_samples = len(selected_indices)

# Mapping indices to custom names
name_mapping = {
    0: ("Image1_Covid", "GT1_Covid", "Predict1_Covid_DSEG_Unet"),  # Index 744
    1: ("Image2_Covid", "GT2_Covid", "Predict2_Covid_DSEG_Unet"),  # Index 280
    2: ("Image3_Covid", "GT3_Covid", "Predict3_Covid_DSEG_Unet")   # Index 230
}

# Plot
for j, i in enumerate(selected_indices):
    lung_img = lung_test[i][..., 0].astype(np.float32)
    gt_infect = (infect_test[i][..., 0] > 0.5).astype(np.float32)
    pred_infect = predicted[i][..., 0].astype(np.float32)

    # Normalize lung image
    if lung_img.max() > lung_img.min():
        lung_img = (lung_img - lung_img.min()) / (lung_img.max() - lung_img.min())
    lung_img = np.clip(lung_img, 0, 1)
    pred_infect = np.clip(pred_infect, 0, 1)

    # Get custom names for this index
    input_name, gt_name, pred_name = name_mapping[j]

    # Save Original Lung
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{input_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

    # Save Ground Truth Infection
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.imshow(gt_infect, cmap='Reds', alpha=0.6)
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{gt_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

    # Save Predicted Infection
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.imshow(pred_infect, cmap='Reds', alpha=0.6)
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{pred_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

print("Separate JPEG files saved for input images (Image1_Covid, Image2_Covid, Image3_Covid), "
      "ground truths (GT1_Covid, GT2_Covid, GT3_Covid), and predictions "
      "(Predict1_Covid_DSEG_Unet, Predict2_Covid_DSEG_Unet, Predict3_Covid_DSEG_Unet).")
# Out:
# Separate JPEG files saved for input images (Image1_Covid, Image2_Covid, Image3_Covid), ground truths (GT1_Covid, GT2_Covid, GT3_Covid), and predictions (Predict1_Covid_DSEG_Unet, Predict2_Covid_DSEG_Unet, Predict3_Covid_DSEG_Unet).
