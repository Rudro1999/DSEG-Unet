# %% [markdown]
# ## Importing important libraries

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import nibabel as nib #for loading nii files
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf #for deep learning

# %% [markdown]
# ## Reading the metadata

# %%
data = pd.read_csv('../input/covid19-ct-scans/metadata.csv')
data.head()
# Out:
#                                              ct_scan  \
# 0  ../input/covid19-ct-scans/ct_scans/coronacases...
# 1  ../input/covid19-ct-scans/ct_scans/coronacases...
# 2  ../input/covid19-ct-scans/ct_scans/coronacases...
# 3  ../input/covid19-ct-scans/ct_scans/coronacases...
# 4  ../input/covid19-ct-scans/ct_scans/coronacases...
#
#                                            lung_mask  \
# 0  ../input/covid19-ct-scans/lung_mask/coronacase...
# 1  ../input/covid19-ct-scans/lung_mask/coronacase...
# 2  ../input/covid19-ct-scans/lung_mask/coronacase...
# 3  ../input/covid19-ct-scans/lung_mask/coronacase...
# 4  ../input/covid19-ct-scans/lung_mask/coronacase...
#
#                                       infection_mask  \
# 0  ../input/covid19-ct-scans/infection_mask/coron...
# 1  ../input/covid19-ct-scans/infection_mask/coron...
# 2  ../input/covid19-ct-scans/infection_mask/coron...
# 3  ../input/covid19-ct-scans/infection_mask/coron...
# 4  ../input/covid19-ct-scans/infection_mask/coron...
#
#                              lung_and_infection_mask
# 0  ../input/covid19-ct-scans/lung_and_infection_m...
# 1  ../input/covid19-ct-scans/lung_and_infection_m...
# 2  ../input/covid19-ct-scans/lung_and_infection_m...
# 3  ../input/covid19-ct-scans/lung_and_infection_m...
# 4  ../input/covid19-ct-scans/lung_and_infection_m...

# %% [markdown]
# ## Defining function for readiing .nii files

# %%
def read_nii(filepath):
    '''
    Reads .nii file and returns pixel array
    '''
    ct_scan = nib.load(filepath)
    array   = ct_scan.get_fdata()
    array   = np.rot90(np.array(array))
    return(array)

# %% [markdown]
# ## Reading the chest ct scan data

# %%
# Read sample
sample_ct   = read_nii(data.loc[2,'ct_scan'])
sample_lung = read_nii(data.loc[2,'lung_mask'])
sample_infe = read_nii(data.loc[2,'infection_mask'])
sample_all  = read_nii(data.loc[2,'lung_and_infection_mask'])

# %% [markdown]
# ## Plotting the sample images

# %%
fig = plt.figure(figsize = (18,15))
plt.subplot(1,4,1)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.title('Original Image')

plt.subplot(1,4,2)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_lung[..., 150],alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung Mask')

plt.subplot(1,4,3)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_infe[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Infection Mask')

plt.subplot(1,4,4)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_all[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung and Infection Mask')
# Out:
# Text(0.5, 1.0, 'Lung and Infection Mask')

# %% [markdown]
# ## Converting the data into array for training model

# %%
import numpy as np
import cv2
import random
from scipy.ndimage import rotate, shift, zoom

lungs = []
infections = []
case_ids = []
img_size = 320

# ----------- Load and Resize Data -----------
for case_index in range(len(data)):
    ct = read_nii(data['ct_scan'][case_index])
    infect = read_nii(data['infection_mask'][case_index])

    for slice_index in range(ct.shape[0]):
        lung_img = cv2.resize(ct[slice_index], dsize=(img_size, img_size)).astype('float32')
        infec_img = cv2.resize(infect[slice_index], dsize=(img_size, img_size)).astype('float32')

        lungs.append(lung_img[..., np.newaxis])
        infections.append(infec_img[..., np.newaxis])
        case_ids.append(case_index)

# %%
import numpy as np

# case_ids should be a NumPy array telling which case each slice belongs to
# Convert and binarize
lungs = np.array(lungs, dtype=np.float32)
infections = (np.array(infections, dtype=np.uint8) > 0.5).astype(np.uint8)
case_ids = np.array(case_ids)

# %% [markdown]
# ## Performing test and train split

# %%
# ----------- Case-wise Split -----------
unique_cases = np.unique(case_ids)
train_cases = np.append(unique_cases[2:4], unique_cases[6:20])
temp_cases = unique_cases[4:6]
val_cases = unique_cases[:2]

train_mask = np.isin(case_ids, train_cases)
temp_mask = np.isin(case_ids, temp_cases)
val_mask = np.isin(case_ids, val_cases)

lung_train = lungs[train_mask]
infect_train = infections[train_mask]
lung_temp = lungs[temp_mask]
infect_temp = infections[temp_mask]
lung_test = lungs[val_mask]
infect_test = infections[val_mask]

print(f"✅ Train: {lung_train.shape[0]} slices from {len(train_cases)} cases")
print(f"✅ Validation: {lung_temp.shape[0]} slices from {len(temp_cases)} cases")
print(f"✅ Test: {lung_test.shape[0]} slices from {len(val_cases)} cases")

# ----------- Augmentation -----------
def augment_image(img, mask):
    if random.random() < 0.5:
        img = np.fliplr(img)
        mask = np.fliplr(mask)
    if random.random() < 0.5:
        img = np.flipud(img)
        mask = np.flipud(mask)

    angle = random.uniform(-15, 15)
    img = rotate(img, angle, reshape=False, order=1, mode='nearest')
    mask = rotate(mask, angle, reshape=False, order=0, mode='nearest')

    shift_val = np.random.uniform(-0.1, 0.1, size=2) * img.shape[:2]
    img = shift(img, shift=(*shift_val, 0), order=1, mode='nearest')
    mask = shift(mask, shift=(*shift_val, 0), order=0, mode='nearest')

    zoom_factor = random.uniform(0.9, 1.1)
    img = zoom(img, (zoom_factor, zoom_factor, 1), order=1)
    mask = zoom(mask, (zoom_factor, zoom_factor, 1), order=0)

    return fix_shape(img), fix_shape(mask)

def fix_shape(arr, target_size=(320, 320)):
    h, w, c = arr.shape
    th, tw = target_size
    dh = th - h
    dw = tw - w
    if dh > 0 or dw > 0:
        pad_h = (max(dh // 2, 0), max(dh - dh // 2, 0))
        pad_w = (max(dw // 2, 0), max(dw - dw // 2, 0))
        arr = np.pad(arr, (pad_h, pad_w, (0, 0)), mode='constant')
    arr = arr[:th, :tw, :]
    return arr.astype('float32')

# ----------- Apply Augmentation -----------
aug_lung_train = []
aug_infect_train = []

for i in range(len(lung_train)):
    img, mask = augment_image(lung_train[i], infect_train[i])
    aug_lung_train.append(img)
    aug_infect_train.append(mask)

lung_train = np.stack(aug_lung_train)
infect_train = np.stack(aug_infect_train)

# Final Binarization
infect_train = (infect_train > 0.5).astype(np.uint8)
infect_test = (infect_test > 0.5).astype(np.uint8)

print(f"✅ Augmented training shape: {lung_train.shape}")
print("✅ All preprocessing complete.")
# Out:
# ✅ Train: 9143 slices from 16 cases
# ✅ Validation: 1024 slices from 2 cases
# ✅ Test: 1024 slices from 2 cases
# ✅ Augmented training shape: (9143, 320, 320, 1)
# ✅ All preprocessing complete.

# %%
import tensorflow as tf
from tensorflow.keras import backend as K
import numpy as np
from scipy.spatial import cKDTree

smooth = 1.0

# Binary Dice coefficient (soft - commonly used during training)
def dice_coef_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# Binary IoU coefficient (soft)
def iou_coef_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# Soft Precision
def precision_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + smooth) / (K.sum(y_pred_f) + smooth)

# Soft Recall (Sensitivity)
def recall_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + smooth) / (K.sum(y_true_f) + smooth)

# Soft Specificity
def specificity_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    tn = K.sum((1 - y_true_f) * (1 - y_pred_f))
    fp = K.sum((1 - y_true_f) * y_pred_f)
    return (tn + smooth) / (tn + fp + smooth)

# Soft Accuracy
def accuracy_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    tp = K.sum(y_true_f * y_pred_f)
    tn = K.sum((1 - y_true_f) * (1 - y_pred_f))
    total = K.cast(K.shape(y_true_f)[0], 'float32')
    return (tp + tn + smooth) / (total + smooth)

# Soft F1-score (harmonic mean of precision & recall - very close to Dice, standard in many repos)
def f1_infection(y_true, y_pred):
    precision = precision_infection(y_true, y_pred)
    recall    = recall_infection(y_true, y_pred)
    return (2. * precision * recall + smooth) / (precision + recall + smooth)

# Hausdorff Distance 95 % (robust & most commonly used in medical imaging challenges)
# Lower = better. Returns the mean HD95 over the batch.
def _calculate_hd95(y_true, y_pred):
    hd_list = []
    for i in range(y_true.shape[0]):
        # Hard threshold at 0.5 (standard for evaluation metrics)
        gt = np.squeeze(y_true[i]) > 0.5
        pred = np.squeeze(y_pred[i]) > 0.5

        gt_pts = np.argwhere(gt)
        pred_pts = np.argwhere(pred)

        # Cases with empty masks
        if gt_pts.shape[0] == 0 and pred_pts.shape[0] == 0:
            hd_list.append(0.0)
            continue
        if gt_pts.shape[0] == 0 or pred_pts.shape[0] == 0:
            hd_list.append(400.0)  # large penalty - adjust to your image diagonal if needed (e.g. ~362 for 256×256, ~724 for 512×512)
            continue

        # Directed distances
        dist_gt_to_pred = cKDTree(pred_pts).query(gt_pts)[0]
        dist_pred_to_gt = cKDTree(gt_pts).query(pred_pts)[0]

        hd95 = max(
            np.percentile(dist_gt_to_pred, 95),
            np.percentile(dist_pred_to_gt, 95)
        )
        hd_list.append(hd95)

    return np.mean(hd_list, dtype=np.float32)

def hausdorff95_infection(y_true, y_pred):
    hd = tf.numpy_function(_calculate_hd95, [y_true, y_pred], tf.float32)
    hd.set_shape(())
    return hd

# Optional: KL Divergence (you already had this)
kld = tf.keras.losses.KLDivergence()

# %%
from tensorflow.keras.losses import BinaryCrossentropy

def loss_f(y_true, y_pred):
    bce = BinaryCrossentropy()
    return dice_loss(y_true, y_pred) + bce(y_true, y_pred) 

def loss_e(y_true, y_pred):
    bce = BinaryCrossentropy()
    return dice_loss(y_true, y_pred)  + kld(y_true, y_pred)
    
def dice_loss(y_true, y_pred):
    return 1. - dice_coef_infection(y_true, y_pred)

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Multiply, Conv2D, DepthwiseConv2D, Dense, Flatten, MaxPooling2D, UpSampling2D, concatenate, Activation, LayerNormalization, Add, Dropout, Conv2DTranspose, multiply, Reshape, GlobalAveragePooling2D, Permute, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Concatenate

def activation_block(x):
    x = Activation("gelu")(x)
    return LayerNormalization()(x)

def conv_stem(x, filters: int, patch_size: int):
    x = Conv2D(filters, kernel_size=patch_size,padding='same', strides=patch_size)(x)
    return activation_block(x)

def vector_block(xyz, cmf, red):
    # red means reduction
    # cmf means filters, denotes vector size
    opt1 = conv_stem(xyz, cmf, red)
    opt2 = conv_stem(xyz, cmf, red)
    
    o1 = GlobalAveragePooling2D()(opt1)
    o2 = GlobalAveragePooling2D()(opt2)

    o5 = concatenate([o1, o2], -1)
    return o5

def mlp_feature(vect, cmf):
    oo = Flatten()(vect)
    o6 = Dense(cmf, activation='gelu')(oo)
    o6 = Dropout(0.2)(o6)
    o6 = Dense(cmf * 2, activation='gelu')(o6)

    o6 = Reshape((1, cmf * 2))(o6)
    o7 = Permute((2, 1))(o6)

    o8 = multiply([o6, o7])
    
    o8 = Lambda(lambda x: tf.expand_dims(x, -1))(o8)
    
    o8 = Reshape((cmf, cmf, 4))(o8)

    return o8

def frz_block(xyz):
    shape = xyz.shape
    a1, a2, a3, a4 = shape[0], shape[1], shape[2], shape[3]
    cmf = a2
    o5 = vector_block(xyz, cmf, 5)
    o7 = mlp_feature(o5, cmf)

    o7 = concatenate([o7, xyz, o7], -1)
    return o7

def up_frz(x1, x2, n_filters):
    # Upsample x1 using Conv2DTranspose
    x1 = Conv2DTranspose(n_filters * 4, 3, strides=2, activation='gelu', padding="same")(x1)
    
    # Apply Conv2D to x2
    x2 = Conv2D(n_filters * 2, 3, activation='gelu', padding="same")(x2)
    
    # Apply attention mechanism
    x = concatenate([x1, x2])
    
    # Apply Dropout for regularization
    x = Dropout(0.3)(x)
    
    return x

def regu(x):
    filters = x.shape[-1]
    shortcut = x
    x = Conv2D(filters, (3, 3), activation='gelu', padding="same")(x)
    x = Add()([x, shortcut])
    return x

# %%
def squeeze_and_excite_block(inputs, ratio=24):
    """ Squeeze and Excitation block to recalibrate channel-wise features """
    filters = inputs.shape[-1]  # Number of input channels
    se_shape = (1, 1, filters)

    # Squeeze: Global Average Pooling
    se = GlobalAveragePooling2D()(inputs)
    se = Reshape(se_shape)(se)

    a = filters // ratio

    # Excitation: Dense layers to capture channel-wise dependencies
    if a > 8:
        se = Conv2D(filters // ratio, kernel_size=1, activation='swish', padding='same')(se)
        se = Conv2D(filters, kernel_size=1, activation='sigmoid', padding='same')(se)
    else:
        se = Conv2D(8, kernel_size=1, activation='swish', padding='same')(se)
        se = Conv2D(filters, kernel_size=1, activation='sigmoid', padding='same')(se)

    # Scale the input by channel-wise weights
    x = multiply([inputs, se])

    return x

def residual_block(x, filters, stride=1, padding='same'):
    shortcut = x
    x = Conv2D(filters * 6, 1, strides=stride, padding=padding, use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)
    x = DepthwiseConv2D(kernel_size=3, strides=stride, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)
    x = squeeze_and_excite_block(x)
    x = Conv2D(filters, 1, strides=stride, padding=padding, use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)
    x = Add()([x, shortcut])
    return x

def dense_block(inputs, num_layers, growth_rate, ratio=16):
    """Dense block where each layer is connected to all previous layers."""
    concat_features = inputs
    for i in range(num_layers):
        # BatchNorm -> ReLU -> Conv2D
        x = Conv2D(growth_rate, 3, activation='gelu', padding='same')(concat_features)

        # Concatenate input with new output (dense connection)
        concat_features = Concatenate()([concat_features, x])
        
    x = concat_features

    return x

def attention_gate(X, g, channel,  
                   activation='ReLU', 
                   attention='add', name='att'):
    '''
    Self-attention gate modified from Oktay et al. 2018.
    
    attention_gate(X, g, channel,  activation='ReLU', attention='add', name='att')
    
    Input
    ----------
        X: input tensor, i.e., key and value.
        g: gated tensor, i.e., query.
        channel: number of intermediate channel.
                 Oktay et al. (2018) did not specify (denoted as F_int).
                 intermediate channel is expected to be smaller than the input channel.
        activation: a nonlinear attnetion activation.
                    The `sigma_1` in Oktay et al. 2018. Default is 'ReLU'.
        attention: 'add' for additive attention; 'multiply' for multiplicative attention.
                   Oktay et al. 2018 applied additive attention.
        name: prefix of the created keras layers.
        
    Output
    ----------
        X_att: output tensor.
    
    '''

    attention_func = eval(attention)
    
    # mapping the input tensor to the intermediate channel
    theta_att = Conv2D(channel, 1, use_bias=True)(X)
    
    # mapping the gate tensor
    phi_g = Conv2D(channel, 1, use_bias=True)(g)
    
    # ----- attention learning ----- #
    query = attention_func([theta_att, phi_g])
    
    # nonlinear activation
    f = Activation('gelu')(query)
    
    # linear transformation
    psi_f = Conv2D(1, 1, use_bias=True)(f)
    # ------------------------------ #
    
    # sigmoid activation as attention coefficients
    coef_att = Activation('sigmoid')(psi_f)
    
    # multiplicative attention masking
    X_att = multiply([X, coef_att])
    
    return X_att

inputs = (img_size, img_size, 1)

def model_build_func(input_shape, n_labels):
    inputs = Input(shape=input_shape, name='input_image')
    g_filter = 16
    u_filter = 8

    # Initial convolution
    initial = Conv2D(g_filter, (3, 3), activation='gelu', padding="same")(inputs)
    initial = dense_block(initial, 2, g_filter // 2)  # 80

    # Down-sampling path
    o1 = MaxPooling2D(2)(initial)
    o1 = frz_block(dense_block(o1, 2, g_filter))  # 40
    #o1 = squeeze_and_excite_block(o1)

    o2 = MaxPooling2D(2)(o1)
    o2 = frz_block(dense_block(o2, 2, g_filter * 2))  # 20
    #o2 = squeeze_and_excite_block(o2)

    o3 = MaxPooling2D(2)(o2)
    o3 = frz_block(dense_block(o3, 2, g_filter * 4))  # 10
    #o3 = squeeze_and_excite_block(o3)

    o4 = MaxPooling2D(2)(o3)
    o4 = frz_block(dense_block(o4, 2, g_filter * 8))  # 5
    #o4 = squeeze_and_excite_block(o4)

    o5 = MaxPooling2D(2)(o4)
    o5 = frz_block(dense_block(o5, 2, g_filter * 16))  # 5
    #o5 = squeeze_and_excite_block(o5)

    # Up-sampling path
    u1 = up_frz(o5, o4, u_filter * 16)  # 10
    #gate1 = attention_gate(o4, u1, u_filter * 16, attention='add')
    cu1 = concatenate([u1, o4])

    u2 = up_frz(cu1, o3, u_filter * 8)  # 20
    #gate2 = attention_gate(o3, u2, u_filter * 8, attention='add')
    cu2 = concatenate([u2, o3])  # 20

    u3 = up_frz(cu2, o2, u_filter * 4)  # 40
    #gate3 = attention_gate(o2, u3, u_filter * 4, attention='add')
    cu3 = concatenate([u3, o2])  # 40

    u4 = up_frz(cu3, o1, u_filter * 2)  # 80
    #gate4 = attention_gate(o1, u4, u_filter * 2, attention='add')
    cu4 = concatenate([u4, o1])  # 80

    u5 = Conv2DTranspose(u_filter * 4, 3, strides=2, activation='gelu', padding="same")(cu4)  # 80
    #gate5 = attention_gate(initial, u5, u_filter, attention='add')
    cu5 = concatenate([u5, initial])  # 80

    # Final segmentation map
    seg_map = Conv2D(n_labels, 3, activation='sigmoid', padding="same")(cu5)

    # Model definition
    model = Model(inputs=inputs, outputs=seg_map)

    return model


model = model_build_func(inputs, 1)

from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2_as_graph

def get_flops(model):
    """Calculate Floating Point Operations (FLOPs) of a Keras model in TensorFlow 2.x."""
    # Convert Keras model to a TensorFlow function
    concrete_func = tf.function(lambda inputs: model(inputs))
    concrete_func = concrete_func.get_concrete_function(
        tf.TensorSpec([1] + list(model.input_shape[1:]), model.input.dtype)
    )

    # Convert to frozen graph
    frozen_func, _ = convert_variables_to_constants_v2_as_graph(concrete_func)

    # Compute FLOPs
    flops = tf.compat.v1.profiler.profile(
        frozen_func.graph,
        options=tf.compat.v1.profiler.ProfileOptionBuilder.float_operation(),
    )

    return flops.total_float_ops

# Compute FLOPs
flops = get_flops(model)
print(f"Total FLOPs: {flops / 1e9:.2f} GFLOPs")  # Convert to GFLOPs

from tensorflow.keras.optimizers import Adam

optimizer = Adam(learning_rate=1e-3)
model.compile(optimizer=optimizer, loss=loss_f, metrics=[dice_coef_infection, iou_coef_infection, precision_infection, recall_infection, hausdorff95_infection, specificity_infection, accuracy_infection, f1_infection])

# Model summary
model.summary()
# Out:
# Total FLOPs: 20.32 GFLOPs
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_image (InputLayer)        [(None, 320, 320, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 320, 320, 16) 160         input_image[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 320, 320, 8)  1160        conv2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 320, 320, 24) 0           conv2d[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 320, 320, 8)  1736        concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 320, 320, 32) 0           concatenate[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 160, 160, 32) 0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 160, 160, 16) 4624        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 160, 160, 48) 0           max_pooling2d[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 160, 160, 16) 6928        concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 160, 160, 64) 0           concatenate_2[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 160)  256160      concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 160)  256160      concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 160)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 160)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# layer_normalization (LayerNorma (None, 32, 32, 160)  320         activation[0][0]
# __________________________________________________________________________________________________
# layer_normalization_1 (LayerNor (None, 32, 32, 160)  320         activation_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 160)          0           layer_normalization[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 160)          0           layer_normalization_1[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 320)          0           global_average_pooling2d[0][0]
#                                                                  global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 320)          0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 160)          51360       flatten[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 160)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 320)          51520       dropout[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 320)       0           dense_1[0][0]
# __________________________________________________________________________________________________
# permute (Permute)               (None, 320, 1)       0           reshape[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 320, 320)     0           reshape[0][0]
#                                                                  permute[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 320, 320, 1)  0           multiply[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 160, 160, 4)  0           lambda[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 160, 160, 72) 0           reshape_1[0][0]
#                                                                  concatenate_3[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 80, 80, 72)   0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 80, 80, 32)   20768       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 80, 80, 104)  0           max_pooling2d_1[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 80, 80, 32)   29984       concatenate_6[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 80, 80, 136)  0           concatenate_6[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 80)   272080      concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 80)   272080      concatenate_7[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 16, 16, 80)   0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 16, 16, 80)   0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# layer_normalization_2 (LayerNor (None, 16, 16, 80)   160         activation_2[0][0]
# __________________________________________________________________________________________________
# layer_normalization_3 (LayerNor (None, 16, 16, 80)   160         activation_3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 80)           0           layer_normalization_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 80)           0           layer_normalization_3[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 160)          0           global_average_pooling2d_2[0][0]
#                                                                  global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 160)          0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 80)           12880       flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 80)           0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 160)          12960       dropout_1[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 160)       0           dense_3[0][0]
# __________________________________________________________________________________________________
# permute_1 (Permute)             (None, 160, 1)       0           reshape_2[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 160, 160)     0           reshape_2[0][0]
#                                                                  permute_1[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 160, 160, 1)  0           multiply_1[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 80, 80, 4)    0           lambda_1[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 80, 80, 144)  0           reshape_3[0][0]
#                                                                  concatenate_7[0][0]
#                                                                  reshape_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 40, 40, 144)  0           concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 40, 40, 64)   83008       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 40, 40, 208)  0           max_pooling2d_2[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 40, 40, 64)   119872      concatenate_10[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 40, 40, 272)  0           concatenate_10[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 40)     272040      concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 40)     272040      concatenate_11[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 8, 8, 40)     0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 8, 8, 40)     0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# layer_normalization_4 (LayerNor (None, 8, 8, 40)     80          activation_4[0][0]
# __________________________________________________________________________________________________
# layer_normalization_5 (LayerNor (None, 8, 8, 40)     80          activation_5[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 40)           0           layer_normalization_4[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 40)           0           layer_normalization_5[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 80)           0           global_average_pooling2d_4[0][0]
#                                                                  global_average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 80)           0           concatenate_12[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 40)           3240        flatten_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 40)           0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 80)           3280        dropout_2[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1, 80)        0           dense_5[0][0]
# __________________________________________________________________________________________________
# permute_2 (Permute)             (None, 80, 1)        0           reshape_4[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 80, 80)       0           reshape_4[0][0]
#                                                                  permute_2[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 80, 80, 1)    0           multiply_2[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 40, 40, 4)    0           lambda_2[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 40, 40, 280)  0           reshape_5[0][0]
#                                                                  concatenate_11[0][0]
#                                                                  reshape_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 20, 20, 280)  0           concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 20, 20, 128)  322688      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 20, 20, 408)  0           max_pooling2d_3[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 20, 20, 128)  470144      concatenate_14[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 20, 20, 536)  0           concatenate_14[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 4, 4, 20)     268020      concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 4, 4, 20)     268020      concatenate_15[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 4, 4, 20)     0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 4, 4, 20)     0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# layer_normalization_6 (LayerNor (None, 4, 4, 20)     40          activation_6[0][0]
# __________________________________________________________________________________________________
# layer_normalization_7 (LayerNor (None, 4, 4, 20)     40          activation_7[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 20)           0           layer_normalization_6[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 20)           0           layer_normalization_7[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 40)           0           global_average_pooling2d_6[0][0]
#                                                                  global_average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 40)           0           concatenate_16[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 20)           820         flatten_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 20)           0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 40)           840         dropout_3[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 1, 40)        0           dense_7[0][0]
# __________________________________________________________________________________________________
# permute_3 (Permute)             (None, 40, 1)        0           reshape_6[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 40, 40)       0           reshape_6[0][0]
#                                                                  permute_3[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 40, 40, 1)    0           multiply_3[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 20, 20, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 20, 20, 544)  0           reshape_7[0][0]
#                                                                  concatenate_15[0][0]
#                                                                  reshape_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 10, 10, 544)  0           concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 10, 10, 256)  1253632     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 10, 10, 800)  0           max_pooling2d_4[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 10, 10, 256)  1843456     concatenate_18[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 10, 10, 1056) 0           concatenate_18[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 2, 2, 10)     264010      concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 2, 2, 10)     264010      concatenate_19[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 2, 2, 10)     0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 2, 2, 10)     0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# layer_normalization_8 (LayerNor (None, 2, 2, 10)     20          activation_8[0][0]
# __________________________________________________________________________________________________
# layer_normalization_9 (LayerNor (None, 2, 2, 10)     20          activation_9[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_8 (Glo (None, 10)           0           layer_normalization_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_9 (Glo (None, 10)           0           layer_normalization_9[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 20)           0           global_average_pooling2d_8[0][0]
#                                                                  global_average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 20)           0           concatenate_20[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 10)           210         flatten_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 10)           0           dense_8[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 20)           220         dropout_4[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 1, 20)        0           dense_9[0][0]
# __________________________________________________________________________________________________
# permute_4 (Permute)             (None, 20, 1)        0           reshape_8[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 20, 20)       0           reshape_8[0][0]
#                                                                  permute_4[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 20, 20, 1)    0           multiply_4[0][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 10, 10, 4)    0           lambda_4[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 10, 10, 1064) 0           reshape_9[0][0]
#                                                                  concatenate_19[0][0]
#                                                                  reshape_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 20, 20, 512)  4903424     concatenate_21[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 20, 20, 256)  1253632     concatenate_17[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 20, 20, 768)  0           conv2d_transpose[0][0]
#                                                                  conv2d_23[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 20, 20, 768)  0           concatenate_22[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 20, 20, 1312) 0           dropout_5[0][0]
#                                                                  concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 40, 40, 256)  3023104     concatenate_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 40, 40, 128)  322688      concatenate_13[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 40, 40, 384)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 40, 40, 384)  0           concatenate_24[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 40, 40, 664)  0           dropout_6[0][0]
#                                                                  concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 80, 80, 128)  765056      concatenate_25[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 80, 80, 64)   83008       concatenate_9[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 80, 80, 192)  0           conv2d_transpose_2[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 80, 80, 192)  0           concatenate_26[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 80, 80, 336)  0           dropout_7[0][0]
#                                                                  concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 160, 160, 64) 193600      concatenate_27[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 160, 160, 32) 20768       concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 160, 160, 96) 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 160, 160, 96) 0           concatenate_28[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 160, 160, 168 0           dropout_8[0][0]
#                                                                  concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 320, 320, 32) 48416       concatenate_29[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 320, 320, 64) 0           conv2d_transpose_4[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 320, 320, 1)  577         concatenate_30[0][0]
# ==================================================================================================
# Total params: 17,575,623
# Trainable params: 17,575,623
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Install required packages
# !pip install openpyxl

# Imports
import openpyxl  # required for reading .xlsx files
import pandas as pd
import tensorflow as tf
import os
import shutil
from tensorflow.keras.callbacks import LearningRateScheduler, ReduceLROnPlateau

# File paths
checkpoint_filepath = '/kaggle/working/checkpoint.h5.keras'
metrics_file = '/kaggle/working/training_metrics.xlsx'
pre_checkpoint_filepath = '/kaggle/input/dseg-unet-4channel-covid19/checkpoint.h5.keras'
pre_metrics_file = '/kaggle/input/dseg-unet-4channel-covid19/training_metrics.xlsx'

# Restore checkpoint and metrics if available
if os.path.exists(pre_checkpoint_filepath):
    shutil.copy(pre_checkpoint_filepath, checkpoint_filepath)
    print(f"Restored checkpoint from: {pre_checkpoint_filepath}")

if os.path.exists(pre_metrics_file):
    shutil.copy(pre_metrics_file, metrics_file)
    print(f"Restored metrics file from: {pre_metrics_file}")

# Load last epoch
def load_last_epoch():
    if os.path.exists(metrics_file):
        try:
            df = pd.read_excel(metrics_file, engine='openpyxl')
            if not df.empty and 'epoch' in df.columns:
                return df['epoch'].iloc[-1] + 1
        except Exception as e:
            print(f"⚠️ Could not read metrics file: {e}")
    return 0

last_epoch = load_last_epoch()

# Get best validation loss from previous runs
def get_best_val_loss():
    if os.path.exists(metrics_file):
        try:
            df = pd.read_excel(metrics_file, engine='openpyxl')
            if 'val_loss' in df.columns and not df['val_loss'].isnull().all():
                return df['val_loss'].min()
        except Exception as e:
            print(f"⚠️ Could not read val_loss from metrics file: {e}")
    return float('inf')

best_val_loss = get_best_val_loss()

# Custom model checkpoint
class CustomModelCheckpoint(tf.keras.callbacks.Callback):
    def __init__(self, filepath):
        super().__init__()
        self.filepath = filepath
        self.best_loss = best_val_loss

    def on_epoch_end(self, epoch, logs=None):
        current_loss = logs.get('val_loss')
        if current_loss is not None and current_loss < self.best_loss:
            self.best_loss = current_loss
            self.model.save(self.filepath)
            print(f"✅ Model saved at epoch {epoch + 1} with val_loss: {current_loss:.4f}")

# === Learning Rate Schedule ===
def lr_schedule(epoch, lr):
    return 1e-4 if epoch >= 5 else lr

lr_scheduler = LearningRateScheduler(lr_schedule, verbose=1)

# Logger for Excel
class MetricsLogger(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        df_new = pd.DataFrame([{**logs, 'epoch': epoch}])
        try:
            if os.path.exists(metrics_file):
                df = pd.read_excel(metrics_file, engine='openpyxl')
                df = pd.concat([df, df_new], ignore_index=True)
            else:
                df = df_new
            df.to_excel(metrics_file, index=False, engine='openpyxl')
        except Exception as e:
            print(f"⚠️ Failed to log metrics: {e}")

# Early stopping with patience and saving best weights
class CustomEarlyStopping(tf.keras.callbacks.Callback):
    def __init__(self, patience=20):
        super().__init__()
        self.patience = patience
        self.wait = 0
        self.best_loss = best_val_loss

    def on_epoch_end(self, epoch, logs=None):
        current_loss = logs.get('val_loss')
        if current_loss is None:
            return
        if current_loss < self.best_loss:
            self.best_loss = current_loss
            self.wait = 0
            self.model.save_weights(checkpoint_filepath)
        else:
            self.wait += 1
            if self.wait >= self.patience:
                print(f"🛑 Early stopping at epoch {epoch + 1}")
                self.model.stop_training = True


# Final callbacks list
callbacks = [
    CustomModelCheckpoint(filepath=checkpoint_filepath),
    MetricsLogger(),
    lr_scheduler,
    CustomEarlyStopping(patience=20)
]
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.3-py2.py3-none-any.whl (251 kB)
#      |████████████████████████████████| 251 kB 8.5 MB/s eta 0:00:01
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.3

# %% [markdown]
# ## Training the model

# %%
import time
import os
import pandas as pd
import numpy as np
from tensorflow.keras.utils import Sequence
from tensorflow.keras.models import load_model

EPOCHS = 100

# Record the start time
start_time = time.time()

# === Load last completed epoch from metrics file ===
def load_last_epoch():
    if os.path.exists(pre_metrics_file):
        try:
            df = pd.read_excel(pre_metrics_file, engine='openpyxl')
            if not df.empty and 'epoch' in df.columns:
                return int(df['epoch'].iloc[-1]) + 1
        except Exception as e:
            print(f"⚠️ Failed to read metrics file: {e}")
    return 0

last_epoch = load_last_epoch()

# === Load pretrained weights if available ===
if os.path.exists(pre_checkpoint_filepath):
    print("✅ Checkpoint found. Loading pretrained weights...")
    model.load_weights(pre_checkpoint_filepath)
    print(f"🔁 Resuming training from epoch {last_epoch}")
else:
    print("🆕 No checkpoint found. Starting training from scratch.")
    last_epoch = 0

# === Prepare input and label tensors ===
lung_train = np.asarray(lung_train, dtype=np.float16)
infect_train = np.asarray(infect_train, dtype=np.uint8)

lung_temp = np.asarray(lung_temp, dtype=np.float16)
infect_temp = np.asarray(infect_temp, dtype=np.uint8)

lung_test = np.asarray(lung_test, dtype=np.float16)
infect_test = np.asarray(infect_test, dtype=np.uint8)

# === Data Generator ===
class LungDataGenerator(Sequence):
    def __init__(self, X, Y, batch_size=8, shuffle=True):
        self.X = X
        self.Y = Y
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indices = np.arange(len(X))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.X) / self.batch_size))

    def __getitem__(self, index):
        batch_ids = self.indices[index * self.batch_size:(index + 1) * self.batch_size]
        X_batch = self.X[batch_ids]
        Y_batch = self.Y[batch_ids]
        return np.asarray(X_batch, dtype=np.float16), np.asarray(Y_batch, dtype=np.uint8)

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indices)

# === Create generators ===
train_gen = LungDataGenerator(lung_train, infect_train, batch_size=8)
temp_gen = LungDataGenerator(lung_temp, infect_temp, batch_size=8, shuffle=False)
val_gen = LungDataGenerator(lung_test, infect_test, batch_size=8, shuffle=False)

# === Train the model ===
history = model.fit(
    train_gen,
    validation_data=temp_gen,
    epochs=EPOCHS,
    initial_epoch=last_epoch,
    callbacks=callbacks
)

# === Timing info ===
end_time = time.time()
total_time = end_time - start_time
print(f"✅ Total training time: {total_time:.2f} seconds ({total_time / 60:.2f} minutes)")
# Out:
# 🆕 No checkpoint found. Starting training from scratch.
# Epoch 1/100
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 239s 197ms/step - loss: 1.2437 - dice_coef_infection: 0.0627 - iou_coef_infection: 0.0347 - precision_infection: 0.0754 - recall_infection: 0.1327 - hausdorff95_infection: 252.1825 - specificity_infection: 0.9804 - accuracy_infection: 0.9721 - f1_infection: 0.8706 - val_loss: 0.8223 - val_dice_coef_infection: 0.2481 - val_iou_coef_infection: 0.2268 - val_precision_infection: 0.2310 - val_recall_infection: 0.9385 - val_hausdorff95_infection: 262.1785 - val_specificity_infection: 0.9923 - val_accuracy_infection: 0.9919 - val_f1_infection: 0.6369
# ✅ Model saved at epoch 1 with val_loss: 0.8223
# Epoch 2/100
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 222s 194ms/step - loss: 0.7649 - dice_coef_infection: 0.3093 - iou_coef_infection: 0.2078 - precision_infection: 0.3384 - recall_infection: 0.3928 - hausdorff95_infection: 167.1077 - specificity_infection: 0.9923 - accuracy_infection: 0.9869 - f1_infection: 0.7752 - val_loss: 0.7623 - val_dice_coef_infection: 0.2775 - val_iou_coef_infection: 0.2537 - val_precision_infection: 0.2721 - val_recall_infection: 0.8944 - val_hausdorff95_infection: 254.1493 - val_specificity_infection: 0.9950 - val_accuracy_infection: 0.9942 - val_f1_infection: 0.6626
# ✅ Model saved at epoch 2 with val_loss: 0.7623
# Epoch 3/100
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.5765 - dice_coef_infection: 0.4791 - iou_coef_infection: 0.3467 - precision_infection: 0.5188 - recall_infection: 0.5425 - hausdorff95_infection: 114.7157 - specificity_infection: 0.9959 - accuracy_infection: 0.9923 - f1_infection: 0.7749 - val_loss: 0.5807 - val_dice_coef_infection: 0.4358 - val_iou_coef_infection: 0.4099 - val_precision_infection: 0.4274 - val_recall_infection: 0.9102 - val_hausdorff95_infection: 180.6336 - val_specificity_infection: 0.9981 - val_accuracy_infection: 0.9975 - val_f1_infection: 0.7392
# ✅ Model saved at epoch 3 with val_loss: 0.5807
# Epoch 4/100
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.4676 - dice_coef_infection: 0.5715 - iou_coef_infection: 0.4352 - precision_infection: 0.6117 - recall_infection: 0.6177 - hausdorff95_infection: 79.1776 - specificity_infection: 0.9971 - accuracy_infection: 0.9942 - f1_infection: 0.7992 - val_loss: 0.4394 - val_dice_coef_infection: 0.5762 - val_iou_coef_infection: 0.5520 - val_precision_infection: 0.5843 - val_recall_infection: 0.8888 - val_hausdorff95_infection: 110.7814 - val_specificity_infection: 0.9994 - val_accuracy_infection: 0.9986 - val_f1_infection: 0.8151
# ✅ Model saved at epoch 4 with val_loss: 0.4394
# Epoch 5/100
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.4499 - dice_coef_infection: 0.5972 - iou_coef_infection: 0.4581 - precision_infection: 0.6345 - recall_infection: 0.6365 - hausdorff95_infection: 83.0798 - specificity_infection: 0.9972 - accuracy_infection: 0.9943 - f1_infection: 0.8037 - val_loss: 0.6019 - val_dice_coef_infection: 0.4634 - val_iou_coef_infection: 0.4371 - val_precision_infection: 0.4431 - val_recall_infection: 0.9321 - val_hausdorff95_infection: 142.0959 - val_specificity_infection: 0.9963 - val_accuracy_infection: 0.9960 - val_f1_infection: 0.7490
# Epoch 6/100
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.4398 - dice_coef_infection: 0.6097 - iou_coef_infection: 0.4745 - precision_infection: 0.6369 - recall_infection: 0.6449 - hausdorff95_infection: 68.2310 - specificity_infection: 0.9973 - accuracy_infection: 0.9946 - f1_infection: 0.8171 - val_loss: 0.4821 - val_dice_coef_infection: 0.5335 - val_iou_coef_infection: 0.5085 - val_precision_infection: 0.5519 - val_recall_infection: 0.8838 - val_hausdorff95_infection: 117.4906 - val_specificity_infection: 0.9993 - val_accuracy_infection: 0.9986 - val_f1_infection: 0.7878
# Epoch 7/100
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.3850 - dice_coef_infection: 0.6471 - iou_coef_infection: 0.5145 - precision_infection: 0.6834 - recall_infection: 0.6803 - hausdorff95_infection: 58.0142 - specificity_infection: 0.9977 - accuracy_infection: 0.9954 - f1_infection: 0.8229 - val_loss: 0.4688 - val_dice_coef_infection: 0.5480 - val_iou_coef_infection: 0.5202 - val_precision_infection: 0.5527 - val_recall_infection: 0.8989 - val_hausdorff95_infection: 132.1893 - val_specificity_infection: 0.9989 - val_accuracy_infection: 0.9983 - val_f1_infection: 0.7887
# Epoch 8/100
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.3543 - dice_coef_infection: 0.6754 - iou_coef_infection: 0.5406 - precision_infection: 0.6940 - recall_infection: 0.7070 - hausdorff95_infection: 55.9241 - specificity_infection: 0.9977 - accuracy_infection: 0.9955 - f1_infection: 0.8320 - val_loss: 0.4829 - val_dice_coef_infection: 0.5386 - val_iou_coef_infection: 0.5090 - val_precision_infection: 0.5199 - val_recall_infection: 0.9333 - val_hausdorff95_infection: 154.4370 - val_specificity_infection: 0.9976 - val_accuracy_infection: 0.9973 - val_f1_infection: 0.7778
# Epoch 9/100
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.3665 - dice_coef_infection: 0.6625 - iou_coef_infection: 0.5279 - precision_infection: 0.6885 - recall_infection: 0.6932 - hausdorff95_infection: 53.2396 - specificity_infection: 0.9978 - accuracy_infection: 0.9956 - f1_infection: 0.8274 - val_loss: 0.4737 - val_dice_coef_infection: 0.5393 - val_iou_coef_infection: 0.5120 - val_precision_infection: 0.5390 - val_recall_infection: 0.9036 - val_hausdorff95_infection: 146.8991 - val_specificity_infection: 0.9989 - val_accuracy_infection: 0.9984 - val_f1_infection: 0.7855
# Epoch 10/100
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.3555 - dice_coef_infection: 0.6727 - iou_coef_infection: 0.5394 - precision_infection: 0.6937 - recall_infection: 0.7023 - hausdorff95_infection: 50.7992 - specificity_infection: 0.9977 - accuracy_infection: 0.9954 - f1_infection: 0.8319 - val_loss: 0.4465 - val_dice_coef_infection: 0.5642 - val_iou_coef_infection: 0.5388 - val_precision_infection: 0.5758 - val_recall_infection: 0.8976 - val_hausdorff95_infection: 112.1838 - val_specificity_infection: 0.9994 - val_accuracy_infection: 0.9988 - val_f1_infection: 0.8004
# Epoch 11/100
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.3464 - dice_coef_infection: 0.6835 - iou_coef_infection: 0.5525 - precision_infection: 0.7165 - recall_infection: 0.7083 - hausdorff95_infection: 47.9377 - specificity_infection: 0.9979 - accuracy_infection: 0.9956 - f1_infection: 0.8363 - val_loss: 0.4464 - val_dice_coef_infection: 0.5640 - val_iou_coef_infection: 0.5380 - val_precision_infection: 0.5764 - val_recall_infection: 0.8960 - val_hausdorff95_infection: 118.1214 - val_specificity_infection: 0.9994 - val_accuracy_infection: 0.9988 - val_f1_infection: 0.7989
# Epoch 12/100
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.3455 - dice_coef_infection: 0.6826 - iou_coef_infection: 0.5495 - precision_infection: 0.7135 - recall_infection: 0.7064 - hausdorff95_infection: 48.6925 - specificity_infection: 0.9980 - accuracy_infection: 0.9958 - f1_infection: 0.8337 - val_loss: 0.4585 - val_dice_coef_infection: 0.5554 - val_iou_coef_infection: 0.5269 - val_precision_infection: 0.5449 - val_recall_infection: 0.9256 - val_hausdorff95_infection: 141.7169 - val_specificity_infection: 0.9987 - val_accuracy_infection: 0.9983 - val_f1_infection: 0.7876
# Epoch 13/100
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.3253 - dice_coef_infection: 0.7026 - iou_coef_infection: 0.5680 - precision_infection: 0.7221 - recall_infection: 0.7275 - hausdorff95_infection: 48.5864 - specificity_infection: 0.9978 - accuracy_infection: 0.9958 - f1_infection: 0.8390 - val_loss: 0.4512 - val_dice_coef_infection: 0.5584 - val_iou_coef_infection: 0.5328 - val_precision_infection: 0.5698 - val_recall_infection: 0.8950 - val_hausdorff95_infection: 125.5919 - val_specificity_infection: 0.9994 - val_accuracy_infection: 0.9988 - val_f1_infection: 0.7970
# Epoch 14/100
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.3227 - dice_coef_infection: 0.7029 - iou_coef_infection: 0.5681 - precision_infection: 0.7164 - recall_infection: 0.7300 - hausdorff95_infection: 46.7385 - specificity_infection: 0.9978 - accuracy_infection: 0.9958 - f1_infection: 0.8400 - val_loss: 0.4672 - val_dice_coef_infection: 0.5428 - val_iou_coef_infection: 0.5173 - val_precision_infection: 0.5464 - val_recall_infection: 0.8970 - val_hausdorff95_infection: 147.5616 - val_specificity_infection: 0.9992 - val_accuracy_infection: 0.9986 - val_f1_infection: 0.7904
# Epoch 15/100
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.3311 - dice_coef_infection: 0.6966 - iou_coef_infection: 0.5653 - precision_infection: 0.7316 - recall_infection: 0.7100 - hausdorff95_infection: 43.4229 - specificity_infection: 0.9980 - accuracy_infection: 0.9958 - f1_infection: 0.8440 - val_loss: 0.4537 - val_dice_coef_infection: 0.5556 - val_iou_coef_infection: 0.5314 - val_precision_infection: 0.5751 - val_recall_infection: 0.8853 - val_hausdorff95_infection: 121.1362 - val_specificity_infection: 0.9995 - val_accuracy_infection: 0.9988 - val_f1_infection: 0.7984
# Epoch 16/100
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.3231 - dice_coef_infection: 0.7026 - iou_coef_infection: 0.5702 - precision_infection: 0.7305 - recall_infection: 0.7199 - hausdorff95_infection: 40.3877 - specificity_infection: 0.9980 - accuracy_infection: 0.9959 - f1_infection: 0.8433 - val_loss: 0.4737 - val_dice_coef_infection: 0.5358 - val_iou_coef_infection: 0.5118 - val_precision_infection: 0.5529 - val_recall_infection: 0.8875 - val_hausdorff95_infection: 137.4350 - val_specificity_infection: 0.9995 - val_accuracy_infection: 0.9988 - val_f1_infection: 0.7883
# Epoch 17/100
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.3264 - dice_coef_infection: 0.7001 - iou_coef_infection: 0.5696 - precision_infection: 0.7221 - recall_infection: 0.7222 - hausdorff95_infection: 41.6573 - specificity_infection: 0.9979 - accuracy_infection: 0.9958 - f1_infection: 0.8442 - val_loss: 0.4624 - val_dice_coef_infection: 0.5471 - val_iou_coef_infection: 0.5234 - val_precision_infection: 0.5571 - val_recall_infection: 0.8929 - val_hausdorff95_infection: 136.8984 - val_specificity_infection: 0.9994 - val_accuracy_infection: 0.9988 - val_f1_infection: 0.7945
# Epoch 18/100
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.3270 - dice_coef_infection: 0.6990 - iou_coef_infection: 0.5655 - precision_infection: 0.7221 - recall_infection: 0.7195 - hausdorff95_infection: 42.8334 - specificity_infection: 0.9981 - accuracy_infection: 0.9961 - f1_infection: 0.8411 - val_loss: 0.4252 - val_dice_coef_infection: 0.5837 - val_iou_coef_infection: 0.5605 - val_precision_infection: 0.5997 - val_recall_infection: 0.8916 - val_hausdorff95_infection: 106.6389 - val_specificity_infection: 0.9996 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.8134
# ✅ Model saved at epoch 18 with val_loss: 0.4252
# Epoch 19/100
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.3269 - dice_coef_infection: 0.7011 - iou_coef_infection: 0.5738 - precision_infection: 0.7448 - recall_infection: 0.7180 - hausdorff95_infection: 40.2558 - specificity_infection: 0.9981 - accuracy_infection: 0.9959 - f1_infection: 0.8417 - val_loss: 0.4602 - val_dice_coef_infection: 0.5489 - val_iou_coef_infection: 0.5244 - val_precision_infection: 0.5598 - val_recall_infection: 0.8920 - val_hausdorff95_infection: 140.4904 - val_specificity_infection: 0.9993 - val_accuracy_infection: 0.9987 - val_f1_infection: 0.7940
# Epoch 20/100
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.3175 - dice_coef_infection: 0.7077 - iou_coef_infection: 0.5755 - precision_infection: 0.7272 - recall_infection: 0.7275 - hausdorff95_infection: 38.7629 - specificity_infection: 0.9979 - accuracy_infection: 0.9959 - f1_infection: 0.8458 - val_loss: 0.4740 - val_dice_coef_infection: 0.5359 - val_iou_coef_infection: 0.5101 - val_precision_infection: 0.5409 - val_recall_infection: 0.8946 - val_hausdorff95_infection: 145.7518 - val_specificity_infection: 0.9991 - val_accuracy_infection: 0.9985 - val_f1_infection: 0.7869
# Epoch 21/100
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.3170 - dice_coef_infection: 0.7091 - iou_coef_infection: 0.5771 - precision_infection: 0.7404 - recall_infection: 0.7264 - hausdorff95_infection: 39.0310 - specificity_infection: 0.9981 - accuracy_infection: 0.9961 - f1_infection: 0.8423 - val_loss: 0.4590 - val_dice_coef_infection: 0.5494 - val_iou_coef_infection: 0.5249 - val_precision_infection: 0.5599 - val_recall_infection: 0.8941 - val_hausdorff95_infection: 135.7201 - val_specificity_infection: 0.9994 - val_accuracy_infection: 0.9988 - val_f1_infection: 0.7940
# Epoch 22/100
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 194ms/step - loss: 0.3162 - dice_coef_infection: 0.7104 - iou_coef_infection: 0.5780 - precision_infection: 0.7377 - recall_infection: 0.7244 - hausdorff95_infection: 38.5004 - specificity_infection: 0.9981 - accuracy_infection: 0.9960 - f1_infection: 0.8439 - val_loss: 0.4046 - val_dice_coef_infection: 0.6055 - val_iou_coef_infection: 0.5798 - val_precision_infection: 0.6203 - val_recall_infection: 0.8969 - val_hausdorff95_infection: 91.2090 - val_specificity_infection: 0.9995 - val_accuracy_infection: 0.9989 - val_f1_infection: 0.8185
# ✅ Model saved at epoch 22 with val_loss: 0.4046
# Epoch 23/100
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 222s 194ms/step - loss: 0.3022 - dice_coef_infection: 0.7237 - iou_coef_infection: 0.5914 - precision_infection: 0.7433 - recall_infection: 0.7445 - hausdorff95_infection: 38.2625 - specificity_infection: 0.9980 - accuracy_infection: 0.9960 - f1_infection: 0.8470 - val_loss: 0.4464 - val_dice_coef_infection: 0.5625 - val_iou_coef_infection: 0.5375 - val_precision_infection: 0.5747 - val_recall_infection: 0.8961 - val_hausdorff95_infection: 128.6084 - val_specificity_infection: 0.9994 - val_accuracy_infection: 0.9988 - val_f1_infection: 0.7996
# Epoch 24/100
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 222s 194ms/step - loss: 0.3051 - dice_coef_infection: 0.7196 - iou_coef_infection: 0.5890 - precision_infection: 0.7400 - recall_infection: 0.7375 - hausdorff95_infection: 36.6127 - specificity_infection: 0.9979 - accuracy_infection: 0.9961 - f1_infection: 0.8490 - val_loss: 0.4468 - val_dice_coef_infection: 0.5639 - val_iou_coef_infection: 0.5398 - val_precision_infection: 0.5902 - val_recall_infection: 0.8825 - val_hausdorff95_infection: 119.8014 - val_specificity_infection: 0.9994 - val_accuracy_infection: 0.9987 - val_f1_infection: 0.8018
# Epoch 25/100
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 222s 194ms/step - loss: 0.3291 - dice_coef_infection: 0.6982 - iou_coef_infection: 0.5685 - precision_infection: 0.7405 - recall_infection: 0.7153 - hausdorff95_infection: 38.0791 - specificity_infection: 0.9981 - accuracy_infection: 0.9960 - f1_infection: 0.8387 - val_loss: 0.4310 - val_dice_coef_infection: 0.5773 - val_iou_coef_infection: 0.5535 - val_precision_infection: 0.5946 - val_recall_infection: 0.8920 - val_hausdorff95_infection: 112.5207 - val_specificity_infection: 0.9995 - val_accuracy_infection: 0.9989 - val_f1_infection: 0.8079
# Epoch 26/100
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 194ms/step - loss: 0.2943 - dice_coef_infection: 0.7293 - iou_coef_infection: 0.5993 - precision_infection: 0.7552 - recall_infection: 0.7425 - hausdorff95_infection: 34.7029 - specificity_infection: 0.9981 - accuracy_infection: 0.9962 - f1_infection: 0.8507 - val_loss: 0.4381 - val_dice_coef_infection: 0.5706 - val_iou_coef_infection: 0.5476 - val_precision_infection: 0.5880 - val_recall_infection: 0.8934 - val_hausdorff95_infection: 100.5826 - val_specificity_infection: 0.9996 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.8058
# Epoch 27/100
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 222s 194ms/step - loss: 0.3053 - dice_coef_infection: 0.7189 - iou_coef_infection: 0.5882 - precision_infection: 0.7368 - recall_infection: 0.7424 - hausdorff95_infection: 34.0082 - specificity_infection: 0.9979 - accuracy_infection: 0.9960 - f1_infection: 0.8479 - val_loss: 0.4284 - val_dice_coef_infection: 0.5817 - val_iou_coef_infection: 0.5593 - val_precision_infection: 0.6181 - val_recall_infection: 0.8751 - val_hausdorff95_infection: 86.3210 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.8141
# Epoch 28/100
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 222s 194ms/step - loss: 0.2984 - dice_coef_infection: 0.7267 - iou_coef_infection: 0.5954 - precision_infection: 0.7498 - recall_infection: 0.7384 - hausdorff95_infection: 33.4789 - specificity_infection: 0.9979 - accuracy_infection: 0.9959 - f1_infection: 0.8507 - val_loss: 0.4388 - val_dice_coef_infection: 0.5712 - val_iou_coef_infection: 0.5471 - val_precision_infection: 0.5961 - val_recall_infection: 0.8881 - val_hausdorff95_infection: 79.3297 - val_specificity_infection: 0.9996 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.8048
# Epoch 29/100
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 222s 194ms/step - loss: 0.3002 - dice_coef_infection: 0.7247 - iou_coef_infection: 0.5937 - precision_infection: 0.7470 - recall_infection: 0.7435 - hausdorff95_infection: 34.3078 - specificity_infection: 0.9980 - accuracy_infection: 0.9961 - f1_infection: 0.8483 - val_loss: 0.3136 - val_dice_coef_infection: 0.6966 - val_iou_coef_infection: 0.6746 - val_precision_infection: 0.7252 - val_recall_infection: 0.8838 - val_hausdorff95_infection: 45.8209 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.8740
# ✅ Model saved at epoch 29 with val_loss: 0.3136
# Epoch 30/100
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.2936 - dice_coef_infection: 0.7314 - iou_coef_infection: 0.6011 - precision_infection: 0.7593 - recall_infection: 0.7447 - hausdorff95_infection: 33.2924 - specificity_infection: 0.9981 - accuracy_infection: 0.9963 - f1_infection: 0.8498 - val_loss: 0.4301 - val_dice_coef_infection: 0.5800 - val_iou_coef_infection: 0.5551 - val_precision_infection: 0.5979 - val_recall_infection: 0.8925 - val_hausdorff95_infection: 112.4518 - val_specificity_infection: 0.9995 - val_accuracy_infection: 0.9989 - val_f1_infection: 0.8073
# Epoch 31/100
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.2962 - dice_coef_infection: 0.7298 - iou_coef_infection: 0.6000 - precision_infection: 0.7546 - recall_infection: 0.7413 - hausdorff95_infection: 33.0029 - specificity_infection: 0.9981 - accuracy_infection: 0.9961 - f1_infection: 0.8519 - val_loss: 0.4001 - val_dice_coef_infection: 0.6087 - val_iou_coef_infection: 0.5860 - val_precision_infection: 0.6411 - val_recall_infection: 0.8770 - val_hausdorff95_infection: 59.6171 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.8293
# Epoch 32/100
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.2828 - dice_coef_infection: 0.7431 - iou_coef_infection: 0.6126 - precision_infection: 0.7668 - recall_infection: 0.7500 - hausdorff95_infection: 31.5766 - specificity_infection: 0.9981 - accuracy_infection: 0.9961 - f1_infection: 0.8559 - val_loss: 0.4303 - val_dice_coef_infection: 0.5801 - val_iou_coef_infection: 0.5579 - val_precision_infection: 0.6197 - val_recall_infection: 0.8750 - val_hausdorff95_infection: 87.3848 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9989 - val_f1_infection: 0.8112
# Epoch 33/100
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.2922 - dice_coef_infection: 0.7308 - iou_coef_infection: 0.5996 - precision_infection: 0.7557 - recall_infection: 0.7423 - hausdorff95_infection: 32.1152 - specificity_infection: 0.9981 - accuracy_infection: 0.9963 - f1_infection: 0.8508 - val_loss: 0.3637 - val_dice_coef_infection: 0.6457 - val_iou_coef_infection: 0.6243 - val_precision_infection: 0.6902 - val_recall_infection: 0.8721 - val_hausdorff95_infection: 53.7299 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.8456
# Epoch 34/100
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 194ms/step - loss: 0.2890 - dice_coef_infection: 0.7361 - iou_coef_infection: 0.6035 - precision_infection: 0.7666 - recall_infection: 0.7409 - hausdorff95_infection: 31.8777 - specificity_infection: 0.9982 - accuracy_infection: 0.9962 - f1_infection: 0.8503 - val_loss: 0.4257 - val_dice_coef_infection: 0.5859 - val_iou_coef_infection: 0.5662 - val_precision_infection: 0.6308 - val_recall_infection: 0.8687 - val_hausdorff95_infection: 78.2585 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9989 - val_f1_infection: 0.8179
# Epoch 35/100
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.2865 - dice_coef_infection: 0.7385 - iou_coef_infection: 0.6088 - precision_infection: 0.7621 - recall_infection: 0.7442 - hausdorff95_infection: 32.0042 - specificity_infection: 0.9981 - accuracy_infection: 0.9962 - f1_infection: 0.8567 - val_loss: 0.4436 - val_dice_coef_infection: 0.5673 - val_iou_coef_infection: 0.5412 - val_precision_infection: 0.5712 - val_recall_infection: 0.9031 - val_hausdorff95_infection: 136.5257 - val_specificity_infection: 0.9990 - val_accuracy_infection: 0.9985 - val_f1_infection: 0.7993
# Epoch 36/100
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 194ms/step - loss: 0.2885 - dice_coef_infection: 0.7361 - iou_coef_infection: 0.6065 - precision_infection: 0.7523 - recall_infection: 0.7500 - hausdorff95_infection: 31.5849 - specificity_infection: 0.9980 - accuracy_infection: 0.9961 - f1_infection: 0.8554 - val_loss: 0.4164 - val_dice_coef_infection: 0.5930 - val_iou_coef_infection: 0.5716 - val_precision_infection: 0.6278 - val_recall_infection: 0.8768 - val_hausdorff95_infection: 58.9987 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.8226
# Epoch 37/100
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 194ms/step - loss: 0.2716 - dice_coef_infection: 0.7521 - iou_coef_infection: 0.6236 - precision_infection: 0.7650 - recall_infection: 0.7707 - hausdorff95_infection: 33.7189 - specificity_infection: 0.9980 - accuracy_infection: 0.9961 - f1_infection: 0.8599 - val_loss: 0.4150 - val_dice_coef_infection: 0.5935 - val_iou_coef_infection: 0.5703 - val_precision_infection: 0.6148 - val_recall_infection: 0.8859 - val_hausdorff95_infection: 109.9745 - val_specificity_infection: 0.9996 - val_accuracy_infection: 0.9989 - val_f1_infection: 0.8164
# Epoch 38/100
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 194ms/step - loss: 0.2676 - dice_coef_infection: 0.7539 - iou_coef_infection: 0.6267 - precision_infection: 0.7710 - recall_infection: 0.7680 - hausdorff95_infection: 30.6373 - specificity_infection: 0.9982 - accuracy_infection: 0.9965 - f1_infection: 0.8605 - val_loss: 0.4093 - val_dice_coef_infection: 0.5991 - val_iou_coef_infection: 0.5779 - val_precision_infection: 0.6304 - val_recall_infection: 0.8758 - val_hausdorff95_infection: 100.7701 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.8238
# Epoch 39/100
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 194ms/step - loss: 0.2851 - dice_coef_infection: 0.7381 - iou_coef_infection: 0.6131 - precision_infection: 0.7636 - recall_infection: 0.7515 - hausdorff95_infection: 28.6929 - specificity_infection: 0.9982 - accuracy_infection: 0.9963 - f1_infection: 0.8576 - val_loss: 0.4253 - val_dice_coef_infection: 0.5839 - val_iou_coef_infection: 0.5620 - val_precision_infection: 0.6173 - val_recall_infection: 0.8749 - val_hausdorff95_infection: 95.2650 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9989 - val_f1_infection: 0.8155
# Epoch 40/100
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 194ms/step - loss: 0.2839 - dice_coef_infection: 0.7385 - iou_coef_infection: 0.6124 - precision_infection: 0.7607 - recall_infection: 0.7571 - hausdorff95_infection: 27.2313 - specificity_infection: 0.9981 - accuracy_infection: 0.9963 - f1_infection: 0.8558 - val_loss: 0.4286 - val_dice_coef_infection: 0.5789 - val_iou_coef_infection: 0.5559 - val_precision_infection: 0.5962 - val_recall_infection: 0.8870 - val_hausdorff95_infection: 115.7170 - val_specificity_infection: 0.9996 - val_accuracy_infection: 0.9989 - val_f1_infection: 0.8116
# Epoch 41/100
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 194ms/step - loss: 0.2828 - dice_coef_infection: 0.7396 - iou_coef_infection: 0.6126 - precision_infection: 0.7587 - recall_infection: 0.7602 - hausdorff95_infection: 30.0959 - specificity_infection: 0.9980 - accuracy_infection: 0.9962 - f1_infection: 0.8554 - val_loss: 0.3730 - val_dice_coef_infection: 0.6364 - val_iou_coef_infection: 0.6127 - val_precision_infection: 0.6531 - val_recall_infection: 0.8956 - val_hausdorff95_infection: 56.3719 - val_specificity_infection: 0.9996 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.8374
# Epoch 42/100
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 194ms/step - loss: 0.2666 - dice_coef_infection: 0.7559 - iou_coef_infection: 0.6292 - precision_infection: 0.7687 - recall_infection: 0.7687 - hausdorff95_infection: 29.6412 - specificity_infection: 0.9981 - accuracy_infection: 0.9964 - f1_infection: 0.8624 - val_loss: 0.4131 - val_dice_coef_infection: 0.5956 - val_iou_coef_infection: 0.5718 - val_precision_infection: 0.6203 - val_recall_infection: 0.8834 - val_hausdorff95_infection: 94.0010 - val_specificity_infection: 0.9996 - val_accuracy_infection: 0.9989 - val_f1_infection: 0.8177
# Epoch 43/100
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.2763 - dice_coef_infection: 0.7471 - iou_coef_infection: 0.6194 - precision_infection: 0.7659 - recall_infection: 0.7575 - hausdorff95_infection: 26.3135 - specificity_infection: 0.9981 - accuracy_infection: 0.9963 - f1_infection: 0.8600 - val_loss: 0.3564 - val_dice_coef_infection: 0.6535 - val_iou_coef_infection: 0.6316 - val_precision_infection: 0.6865 - val_recall_infection: 0.8805 - val_hausdorff95_infection: 44.6418 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.8512
# Epoch 44/100
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 194ms/step - loss: 0.2720 - dice_coef_infection: 0.7500 - iou_coef_infection: 0.6213 - precision_infection: 0.7674 - recall_infection: 0.7579 - hausdorff95_infection: 27.7014 - specificity_infection: 0.9981 - accuracy_infection: 0.9964 - f1_infection: 0.8608 - val_loss: 0.4134 - val_dice_coef_infection: 0.5946 - val_iou_coef_infection: 0.5726 - val_precision_infection: 0.6251 - val_recall_infection: 0.8802 - val_hausdorff95_infection: 74.3708 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.8212
# Epoch 45/100
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 194ms/step - loss: 0.2727 - dice_coef_infection: 0.7489 - iou_coef_infection: 0.6242 - precision_infection: 0.7807 - recall_infection: 0.7577 - hausdorff95_infection: 27.5877 - specificity_infection: 0.9983 - accuracy_infection: 0.9965 - f1_infection: 0.8584 - val_loss: 0.3813 - val_dice_coef_infection: 0.6269 - val_iou_coef_infection: 0.6042 - val_precision_infection: 0.6520 - val_recall_infection: 0.8823 - val_hausdorff95_infection: 71.9792 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.8361
# Epoch 46/100
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.2679 - dice_coef_infection: 0.7546 - iou_coef_infection: 0.6248 - precision_infection: 0.7729 - recall_infection: 0.7621 - hausdorff95_infection: 25.4235 - specificity_infection: 0.9982 - accuracy_infection: 0.9964 - f1_infection: 0.8592 - val_loss: 0.3607 - val_dice_coef_infection: 0.6477 - val_iou_coef_infection: 0.6255 - val_precision_infection: 0.6788 - val_recall_infection: 0.8798 - val_hausdorff95_infection: 66.4580 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.8483
# Epoch 47/100
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.2626 - dice_coef_infection: 0.7589 - iou_coef_infection: 0.6324 - precision_infection: 0.7740 - recall_infection: 0.7712 - hausdorff95_infection: 26.5554 - specificity_infection: 0.9981 - accuracy_infection: 0.9964 - f1_infection: 0.8635 - val_loss: 0.2591 - val_dice_coef_infection: 0.7514 - val_iou_coef_infection: 0.7301 - val_precision_infection: 0.7788 - val_recall_infection: 0.8790 - val_hausdorff95_infection: 24.2336 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.9047
# ✅ Model saved at epoch 47 with val_loss: 0.2591
# Epoch 48/100
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 194ms/step - loss: 0.2766 - dice_coef_infection: 0.7474 - iou_coef_infection: 0.6213 - precision_infection: 0.7728 - recall_infection: 0.7587 - hausdorff95_infection: 29.0642 - specificity_infection: 0.9981 - accuracy_infection: 0.9963 - f1_infection: 0.8590 - val_loss: 0.4298 - val_dice_coef_infection: 0.5797 - val_iou_coef_infection: 0.5571 - val_precision_infection: 0.6087 - val_recall_infection: 0.8794 - val_hausdorff95_infection: 97.6356 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9989 - val_f1_infection: 0.8121
# Epoch 49/100
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.2653 - dice_coef_infection: 0.7570 - iou_coef_infection: 0.6317 - precision_infection: 0.7796 - recall_infection: 0.7691 - hausdorff95_infection: 26.0365 - specificity_infection: 0.9981 - accuracy_infection: 0.9964 - f1_infection: 0.8614 - val_loss: 0.4058 - val_dice_coef_infection: 0.6024 - val_iou_coef_infection: 0.5797 - val_precision_infection: 0.6315 - val_recall_infection: 0.8800 - val_hausdorff95_infection: 80.1526 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9989 - val_f1_infection: 0.8235
# Epoch 50/100
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 222s 194ms/step - loss: 0.2615 - dice_coef_infection: 0.7589 - iou_coef_infection: 0.6331 - precision_infection: 0.7656 - recall_infection: 0.7761 - hausdorff95_infection: 26.6869 - specificity_infection: 0.9981 - accuracy_infection: 0.9965 - f1_infection: 0.8655 - val_loss: 0.3637 - val_dice_coef_infection: 0.6491 - val_iou_coef_infection: 0.6267 - val_precision_infection: 0.6928 - val_recall_infection: 0.8730 - val_hausdorff95_infection: 41.6074 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.8454
# Epoch 51/100
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 222s 194ms/step - loss: 0.2614 - dice_coef_infection: 0.7611 - iou_coef_infection: 0.6350 - precision_infection: 0.7741 - recall_infection: 0.7744 - hausdorff95_infection: 24.7732 - specificity_infection: 0.9982 - accuracy_infection: 0.9964 - f1_infection: 0.8648 - val_loss: 0.4140 - val_dice_coef_infection: 0.5949 - val_iou_coef_infection: 0.5723 - val_precision_infection: 0.6241 - val_recall_infection: 0.8829 - val_hausdorff95_infection: 68.6894 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.8203
# Epoch 52/100
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 222s 194ms/step - loss: 0.2524 - dice_coef_infection: 0.7689 - iou_coef_infection: 0.6443 - precision_infection: 0.7815 - recall_infection: 0.7801 - hausdorff95_infection: 21.9499 - specificity_infection: 0.9981 - accuracy_infection: 0.9965 - f1_infection: 0.8671 - val_loss: 0.3967 - val_dice_coef_infection: 0.6125 - val_iou_coef_infection: 0.5903 - val_precision_infection: 0.6475 - val_recall_infection: 0.8789 - val_hausdorff95_infection: 59.1610 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.8290
# Epoch 53/100
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 222s 194ms/step - loss: 0.2625 - dice_coef_infection: 0.7602 - iou_coef_infection: 0.6341 - precision_infection: 0.7825 - recall_infection: 0.7712 - hausdorff95_infection: 25.7428 - specificity_infection: 0.9982 - accuracy_infection: 0.9964 - f1_infection: 0.8630 - val_loss: 0.4135 - val_dice_coef_infection: 0.5951 - val_iou_coef_infection: 0.5719 - val_precision_infection: 0.6150 - val_recall_infection: 0.8870 - val_hausdorff95_infection: 107.6924 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9989 - val_f1_infection: 0.8187
# Epoch 54/100
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 222s 194ms/step - loss: 0.2733 - dice_coef_infection: 0.7502 - iou_coef_infection: 0.6228 - precision_infection: 0.7822 - recall_infection: 0.7538 - hausdorff95_infection: 26.9423 - specificity_infection: 0.9982 - accuracy_infection: 0.9964 - f1_infection: 0.8580 - val_loss: 0.3715 - val_dice_coef_infection: 0.6392 - val_iou_coef_infection: 0.6169 - val_precision_infection: 0.6794 - val_recall_infection: 0.8767 - val_hausdorff95_infection: 54.7564 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9989 - val_f1_infection: 0.8404
# Epoch 55/100
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 222s 194ms/step - loss: 0.2604 - dice_coef_infection: 0.7638 - iou_coef_infection: 0.6383 - precision_infection: 0.7878 - recall_infection: 0.7647 - hausdorff95_infection: 25.3636 - specificity_infection: 0.9982 - accuracy_infection: 0.9964 - f1_infection: 0.8667 - val_loss: 0.4278 - val_dice_coef_infection: 0.5820 - val_iou_coef_infection: 0.5602 - val_precision_infection: 0.6248 - val_recall_infection: 0.8691 - val_hausdorff95_infection: 79.2923 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9989 - val_f1_infection: 0.8135
# Epoch 56/100
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.2460 - dice_coef_infection: 0.7755 - iou_coef_infection: 0.6492 - precision_infection: 0.7908 - recall_infection: 0.7803 - hausdorff95_infection: 23.8408 - specificity_infection: 0.9983 - accuracy_infection: 0.9966 - f1_infection: 0.8696 - val_loss: 0.4221 - val_dice_coef_infection: 0.5877 - val_iou_coef_infection: 0.5638 - val_precision_infection: 0.6058 - val_recall_infection: 0.8946 - val_hausdorff95_infection: 96.0602 - val_specificity_infection: 0.9995 - val_accuracy_infection: 0.9989 - val_f1_infection: 0.8131
# Epoch 57/100
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 194ms/step - loss: 0.2441 - dice_coef_infection: 0.7775 - iou_coef_infection: 0.6539 - precision_infection: 0.7923 - recall_infection: 0.7882 - hausdorff95_infection: 22.7169 - specificity_infection: 0.9982 - accuracy_infection: 0.9965 - f1_infection: 0.8706 - val_loss: 0.3632 - val_dice_coef_infection: 0.6476 - val_iou_coef_infection: 0.6258 - val_precision_infection: 0.6754 - val_recall_infection: 0.8843 - val_hausdorff95_infection: 55.4693 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.8475
# Epoch 58/100
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 194ms/step - loss: 0.2477 - dice_coef_infection: 0.7727 - iou_coef_infection: 0.6487 - precision_infection: 0.7902 - recall_infection: 0.7790 - hausdorff95_infection: 20.8179 - specificity_infection: 0.9983 - accuracy_infection: 0.9968 - f1_infection: 0.8696 - val_loss: 0.4121 - val_dice_coef_infection: 0.5953 - val_iou_coef_infection: 0.5721 - val_precision_infection: 0.6083 - val_recall_infection: 0.8991 - val_hausdorff95_infection: 84.7772 - val_specificity_infection: 0.9996 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.8173
# Epoch 59/100
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.2622 - dice_coef_infection: 0.7593 - iou_coef_infection: 0.6329 - precision_infection: 0.7757 - recall_infection: 0.7764 - hausdorff95_infection: 25.6233 - specificity_infection: 0.9982 - accuracy_infection: 0.9964 - f1_infection: 0.8621 - val_loss: 0.3673 - val_dice_coef_infection: 0.6422 - val_iou_coef_infection: 0.6199 - val_precision_infection: 0.6812 - val_recall_infection: 0.8774 - val_hausdorff95_infection: 44.5102 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.8430
# Epoch 60/100
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.2486 - dice_coef_infection: 0.7714 - iou_coef_infection: 0.6519 - precision_infection: 0.7888 - recall_infection: 0.7860 - hausdorff95_infection: 21.6331 - specificity_infection: 0.9982 - accuracy_infection: 0.9966 - f1_infection: 0.8702 - val_loss: 0.3872 - val_dice_coef_infection: 0.6236 - val_iou_coef_infection: 0.6031 - val_precision_infection: 0.6715 - val_recall_infection: 0.8640 - val_hausdorff95_infection: 53.0310 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9989 - val_f1_infection: 0.8394
# Epoch 61/100
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.2460 - dice_coef_infection: 0.7739 - iou_coef_infection: 0.6528 - precision_infection: 0.7870 - recall_infection: 0.7862 - hausdorff95_infection: 22.4634 - specificity_infection: 0.9982 - accuracy_infection: 0.9966 - f1_infection: 0.8716 - val_loss: 0.4195 - val_dice_coef_infection: 0.5896 - val_iou_coef_infection: 0.5680 - val_precision_infection: 0.6347 - val_recall_infection: 0.8708 - val_hausdorff95_infection: 70.4556 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9989 - val_f1_infection: 0.8154
# Epoch 62/100
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.2476 - dice_coef_infection: 0.7744 - iou_coef_infection: 0.6507 - precision_infection: 0.7946 - recall_infection: 0.7808 - hausdorff95_infection: 20.6567 - specificity_infection: 0.9982 - accuracy_infection: 0.9965 - f1_infection: 0.8691 - val_loss: 0.3834 - val_dice_coef_infection: 0.6258 - val_iou_coef_infection: 0.6028 - val_precision_infection: 0.6381 - val_recall_infection: 0.8962 - val_hausdorff95_infection: 64.4634 - val_specificity_infection: 0.9995 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.8360
# Epoch 63/100
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.2509 - dice_coef_infection: 0.7700 - iou_coef_infection: 0.6474 - precision_infection: 0.7894 - recall_infection: 0.7794 - hausdorff95_infection: 21.2938 - specificity_infection: 0.9982 - accuracy_infection: 0.9966 - f1_infection: 0.8683 - val_loss: 0.4221 - val_dice_coef_infection: 0.5870 - val_iou_coef_infection: 0.5633 - val_precision_infection: 0.6078 - val_recall_infection: 0.8920 - val_hausdorff95_infection: 74.3029 - val_specificity_infection: 0.9996 - val_accuracy_infection: 0.9989 - val_f1_infection: 0.8123
# Epoch 64/100
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.2445 - dice_coef_infection: 0.7743 - iou_coef_infection: 0.6508 - precision_infection: 0.7824 - recall_infection: 0.7877 - hausdorff95_infection: 19.0465 - specificity_infection: 0.9982 - accuracy_infection: 0.9967 - f1_infection: 0.8701 - val_loss: 0.4148 - val_dice_coef_infection: 0.5967 - val_iou_coef_infection: 0.5736 - val_precision_infection: 0.6430 - val_recall_infection: 0.8696 - val_hausdorff95_infection: 71.3582 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9988 - val_f1_infection: 0.8187
# Epoch 65/100
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 194ms/step - loss: 0.2453 - dice_coef_infection: 0.7744 - iou_coef_infection: 0.6517 - precision_infection: 0.7903 - recall_infection: 0.7849 - hausdorff95_infection: 22.2457 - specificity_infection: 0.9982 - accuracy_infection: 0.9966 - f1_infection: 0.8696 - val_loss: 0.3953 - val_dice_coef_infection: 0.6144 - val_iou_coef_infection: 0.5920 - val_precision_infection: 0.6609 - val_recall_infection: 0.8647 - val_hausdorff95_infection: 59.0074 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9989 - val_f1_infection: 0.8312
# Epoch 66/100
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.2565 - dice_coef_infection: 0.7648 - iou_coef_infection: 0.6442 - precision_infection: 0.7899 - recall_infection: 0.7748 - hausdorff95_infection: 22.3350 - specificity_infection: 0.9983 - accuracy_infection: 0.9966 - f1_infection: 0.8673 - val_loss: 0.3449 - val_dice_coef_infection: 0.6654 - val_iou_coef_infection: 0.6444 - val_precision_infection: 0.7157 - val_recall_infection: 0.8660 - val_hausdorff95_infection: 44.3334 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9989 - val_f1_infection: 0.8585
# Epoch 67/100
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 221s 193ms/step - loss: 0.2389 - dice_coef_infection: 0.7812 - iou_coef_infection: 0.6602 - precision_infection: 0.7938 - recall_infection: 0.7917 - hausdorff95_infection: 20.4726 - specificity_infection: 0.9981 - accuracy_infection: 0.9965 - f1_infection: 0.8735 - val_loss: 0.3584 - val_dice_coef_infection: 0.6500 - val_iou_coef_infection: 0.6276 - val_precision_infection: 0.6822 - val_recall_infection: 0.8796 - val_hausdorff95_infection: 46.2142 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.8491
# 🛑 Early stopping at epoch 67
# ✅ Total training time: 14851.95 seconds (247.53 minutes)

# %% [markdown]
# ## Plotting the performance metrics

# %%
plt.plot(history.history['dice_coef_infection'])
plt.plot(history.history['val_dice_coef_infection'])
plt.title('dice_coef_infection vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Dice_coef')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# %%
plt.plot(history.history['iou_coef_infection'])
plt.plot(history.history['val_iou_coef_infection'])
plt.title('iou_coef_infection vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Iou_coef')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Val'], loc = 'upper right')
plt.show()

# %% [markdown]
# ## Using our trained model for prediction

# %%
import numpy as np
import time

# Start timer (high precision)
start_time = time.perf_counter()

# Evaluate the model on the validation generator
results = model.evaluate(val_gen, verbose=1)

# End timer
end_time = time.perf_counter()

# Calculate evaluation time
eval_time = end_time - start_time

# Print metric names with results
print("\n===== Validation Metrics =====")
for name, value in zip(model.metrics_names, results):
    print(f"{name}: {value:.6f}")

print(f"\nEvaluation Time: {eval_time:.8f} seconds\n")
# Out:
# 128/128 [==============================] - 9s 72ms/step - loss: 0.3055 - dice_coef_infection: 0.7285 - iou_coef_infection: 0.6798 - precision_infection: 0.8451 - recall_infection: 0.7619 - hausdorff95_infection: 43.2509 - specificity_infection: 0.9994 - accuracy_infection: 0.9967 - f1_infection: 0.8731
#
# ===== Validation Metrics =====
# loss: 0.305454
# dice_coef_infection: 0.728525
# iou_coef_infection: 0.679762
# precision_infection: 0.845135
# recall_infection: 0.761852
# hausdorff95_infection: 43.250854
# specificity_infection: 0.999433
# accuracy_infection: 0.996693
# f1_infection: 0.873075
#
# Evaluation Time: 9.25543387 seconds

# %%
import matplotlib.pyplot as plt
import numpy as np

# Run inference if not already done
predicted = model.predict(lung_test)

# Selected indices to visualize (744 as 1st, 280 as 2nd, 230 as 3rd)
selected_indices = [744, 280, 230]
n_samples = len(selected_indices)

# Mapping indices to custom names
name_mapping = {
    0: ("Image1_Covid", "GT1_Covid", "Predict1_Covid_DSEG_Unet"),  # Index 744
    1: ("Image2_Covid", "GT2_Covid", "Predict2_Covid_DSEG_Unet"),  # Index 280
    2: ("Image3_Covid", "GT3_Covid", "Predict3_Covid_DSEG_Unet")   # Index 230
}

# Plot
for j, i in enumerate(selected_indices):
    lung_img = lung_test[i][..., 0].astype(np.float32)
    gt_infect = (infect_test[i][..., 0] > 0.5).astype(np.float32)
    pred_infect = predicted[i][..., 0].astype(np.float32)

    # Normalize lung image
    if lung_img.max() > lung_img.min():
        lung_img = (lung_img - lung_img.min()) / (lung_img.max() - lung_img.min())
    lung_img = np.clip(lung_img, 0, 1)
    pred_infect = np.clip(pred_infect, 0, 1)

    # Get custom names for this index
    input_name, gt_name, pred_name = name_mapping[j]

    # Save Original Lung
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{input_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

    # Save Ground Truth Infection
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.imshow(gt_infect, cmap='Reds', alpha=0.6)
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{gt_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

    # Save Predicted Infection
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.imshow(pred_infect, cmap='Reds', alpha=0.6)
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{pred_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

print("Separate JPEG files saved for input images (Image1_Covid, Image2_Covid, Image3_Covid), "
      "ground truths (GT1_Covid, GT2_Covid, GT3_Covid), and predictions "
      "(Predict1_Covid_DSEG_Unet, Predict2_Covid_DSEG_Unet, Predict3_Covid_DSEG_Unet).")
# Out:
# Separate JPEG files saved for input images (Image1_Covid, Image2_Covid, Image3_Covid), ground truths (GT1_Covid, GT2_Covid, GT3_Covid), and predictions (Predict1_Covid_DSEG_Unet, Predict2_Covid_DSEG_Unet, Predict3_Covid_DSEG_Unet).
