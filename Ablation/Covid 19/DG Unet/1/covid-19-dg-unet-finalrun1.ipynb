# %% [markdown]
# ## Importing important libraries

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import nibabel as nib #for loading nii files
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf #for deep learning

# %% [markdown]
# ## Reading the metadata

# %%
data = pd.read_csv('../input/covid19-ct-scans/metadata.csv')
data.head()
# Out:
#                                              ct_scan  \
# 0  ../input/covid19-ct-scans/ct_scans/coronacases...
# 1  ../input/covid19-ct-scans/ct_scans/coronacases...
# 2  ../input/covid19-ct-scans/ct_scans/coronacases...
# 3  ../input/covid19-ct-scans/ct_scans/coronacases...
# 4  ../input/covid19-ct-scans/ct_scans/coronacases...
#
#                                            lung_mask  \
# 0  ../input/covid19-ct-scans/lung_mask/coronacase...
# 1  ../input/covid19-ct-scans/lung_mask/coronacase...
# 2  ../input/covid19-ct-scans/lung_mask/coronacase...
# 3  ../input/covid19-ct-scans/lung_mask/coronacase...
# 4  ../input/covid19-ct-scans/lung_mask/coronacase...
#
#                                       infection_mask  \
# 0  ../input/covid19-ct-scans/infection_mask/coron...
# 1  ../input/covid19-ct-scans/infection_mask/coron...
# 2  ../input/covid19-ct-scans/infection_mask/coron...
# 3  ../input/covid19-ct-scans/infection_mask/coron...
# 4  ../input/covid19-ct-scans/infection_mask/coron...
#
#                              lung_and_infection_mask
# 0  ../input/covid19-ct-scans/lung_and_infection_m...
# 1  ../input/covid19-ct-scans/lung_and_infection_m...
# 2  ../input/covid19-ct-scans/lung_and_infection_m...
# 3  ../input/covid19-ct-scans/lung_and_infection_m...
# 4  ../input/covid19-ct-scans/lung_and_infection_m...

# %% [markdown]
# ## Defining function for readiing .nii files

# %%
def read_nii(filepath):
    '''
    Reads .nii file and returns pixel array
    '''
    ct_scan = nib.load(filepath)
    array   = ct_scan.get_fdata()
    array   = np.rot90(np.array(array))
    return(array)

# %% [markdown]
# ## Reading the chest ct scan data

# %%
# Read sample
sample_ct   = read_nii(data.loc[2,'ct_scan'])
sample_lung = read_nii(data.loc[2,'lung_mask'])
sample_infe = read_nii(data.loc[2,'infection_mask'])
sample_all  = read_nii(data.loc[2,'lung_and_infection_mask'])

# %% [markdown]
# ## Plotting the sample images

# %%
fig = plt.figure(figsize = (18,15))
plt.subplot(1,4,1)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.title('Original Image')

plt.subplot(1,4,2)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_lung[..., 150],alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung Mask')

plt.subplot(1,4,3)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_infe[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Infection Mask')

plt.subplot(1,4,4)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_all[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung and Infection Mask')
# Out:
# Text(0.5, 1.0, 'Lung and Infection Mask')

# %% [markdown]
# ## Converting the data into array for training model

# %%
import numpy as np
import cv2
import random
from scipy.ndimage import rotate, shift, zoom

lungs = []
infections = []
case_ids = []
img_size = 320

# ----------- Load and Resize Data -----------
for case_index in range(len(data)):
    ct = read_nii(data['ct_scan'][case_index])
    infect = read_nii(data['infection_mask'][case_index])

    for slice_index in range(ct.shape[0]):
        lung_img = cv2.resize(ct[slice_index], dsize=(img_size, img_size)).astype('float32')
        infec_img = cv2.resize(infect[slice_index], dsize=(img_size, img_size)).astype('float32')

        lungs.append(lung_img[..., np.newaxis])
        infections.append(infec_img[..., np.newaxis])
        case_ids.append(case_index)

# %%
import numpy as np

# case_ids should be a NumPy array telling which case each slice belongs to
# Convert and binarize
lungs = np.array(lungs, dtype=np.float32)
infections = (np.array(infections, dtype=np.uint8) > 0.5).astype(np.uint8)
case_ids = np.array(case_ids)

# %% [markdown]
# ## Performing test and train split

# %%
# ----------- Case-wise Split -----------
unique_cases = np.unique(case_ids)
train_cases = np.append(unique_cases[4:12], unique_cases[12:20])
temp_cases = unique_cases[2:4]
val_cases = unique_cases[:2]

train_mask = np.isin(case_ids, train_cases)
temp_mask = np.isin(case_ids, temp_cases)
val_mask = np.isin(case_ids, val_cases)

lung_train = lungs[train_mask]
infect_train = infections[train_mask]
lung_temp = lungs[temp_mask]
infect_temp = infections[temp_mask]
lung_test = lungs[val_mask]
infect_test = infections[val_mask]

print(f"✅ Train: {lung_train.shape[0]} slices from {len(train_cases)} cases")
print(f"✅ Validation: {lung_temp.shape[0]} slices from {len(temp_cases)} cases")
print(f"✅ Test: {lung_test.shape[0]} slices from {len(val_cases)} cases")

# ----------- Augmentation -----------
def augment_image(img, mask):
    if random.random() < 0.5:
        img = np.fliplr(img)
        mask = np.fliplr(mask)
    if random.random() < 0.5:
        img = np.flipud(img)
        mask = np.flipud(mask)

    angle = random.uniform(-15, 15)
    img = rotate(img, angle, reshape=False, order=1, mode='nearest')
    mask = rotate(mask, angle, reshape=False, order=0, mode='nearest')

    shift_val = np.random.uniform(-0.1, 0.1, size=2) * img.shape[:2]
    img = shift(img, shift=(*shift_val, 0), order=1, mode='nearest')
    mask = shift(mask, shift=(*shift_val, 0), order=0, mode='nearest')

    zoom_factor = random.uniform(0.9, 1.1)
    img = zoom(img, (zoom_factor, zoom_factor, 1), order=1)
    mask = zoom(mask, (zoom_factor, zoom_factor, 1), order=0)

    return fix_shape(img), fix_shape(mask)

def fix_shape(arr, target_size=(320, 320)):
    h, w, c = arr.shape
    th, tw = target_size
    dh = th - h
    dw = tw - w
    if dh > 0 or dw > 0:
        pad_h = (max(dh // 2, 0), max(dh - dh // 2, 0))
        pad_w = (max(dw // 2, 0), max(dw - dw // 2, 0))
        arr = np.pad(arr, (pad_h, pad_w, (0, 0)), mode='constant')
    arr = arr[:th, :tw, :]
    return arr.astype('float32')

# ----------- Apply Augmentation -----------
aug_lung_train = []
aug_infect_train = []

for i in range(len(lung_train)):
    img, mask = augment_image(lung_train[i], infect_train[i])
    aug_lung_train.append(img)
    aug_infect_train.append(mask)

lung_train = np.stack(aug_lung_train)
infect_train = np.stack(aug_infect_train)

# Final Binarization
infect_train = (infect_train > 0.5).astype(np.uint8)
infect_test = (infect_test > 0.5).astype(np.uint8)

print(f"✅ Augmented training shape: {lung_train.shape}")
print("✅ All preprocessing complete.")
# Out:
# ✅ Train: 9143 slices from 16 cases
# ✅ Validation: 1024 slices from 2 cases
# ✅ Test: 1024 slices from 2 cases
# ✅ Augmented training shape: (9143, 320, 320, 1)
# ✅ All preprocessing complete.

# %%
import tensorflow as tf
from tensorflow.keras import backend as K
import numpy as np
from scipy.spatial import cKDTree

smooth = 1.0

# Binary Dice coefficient (soft - commonly used during training)
def dice_coef_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# Binary IoU coefficient (soft)
def iou_coef_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# Soft Precision
def precision_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + smooth) / (K.sum(y_pred_f) + smooth)

# Soft Recall (Sensitivity)
def recall_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + smooth) / (K.sum(y_true_f) + smooth)

# Soft Specificity
def specificity_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    tn = K.sum((1 - y_true_f) * (1 - y_pred_f))
    fp = K.sum((1 - y_true_f) * y_pred_f)
    return (tn + smooth) / (tn + fp + smooth)

# Soft Accuracy
def accuracy_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    tp = K.sum(y_true_f * y_pred_f)
    tn = K.sum((1 - y_true_f) * (1 - y_pred_f))
    total = K.cast(K.shape(y_true_f)[0], 'float32')
    return (tp + tn + smooth) / (total + smooth)

# Soft F1-score (harmonic mean of precision & recall - very close to Dice, standard in many repos)
def f1_infection(y_true, y_pred):
    precision = precision_infection(y_true, y_pred)
    recall    = recall_infection(y_true, y_pred)
    return (2. * precision * recall + smooth) / (precision + recall + smooth)

# Hausdorff Distance 95 % (robust & most commonly used in medical imaging challenges)
# Lower = better. Returns the mean HD95 over the batch.
def _calculate_hd95(y_true, y_pred):
    hd_list = []
    for i in range(y_true.shape[0]):
        # Hard threshold at 0.5 (standard for evaluation metrics)
        gt = np.squeeze(y_true[i]) > 0.5
        pred = np.squeeze(y_pred[i]) > 0.5

        gt_pts = np.argwhere(gt)
        pred_pts = np.argwhere(pred)

        # Cases with empty masks
        if gt_pts.shape[0] == 0 and pred_pts.shape[0] == 0:
            hd_list.append(0.0)
            continue
        if gt_pts.shape[0] == 0 or pred_pts.shape[0] == 0:
            hd_list.append(400.0)  # large penalty - adjust to your image diagonal if needed (e.g. ~362 for 256×256, ~724 for 512×512)
            continue

        # Directed distances
        dist_gt_to_pred = cKDTree(pred_pts).query(gt_pts)[0]
        dist_pred_to_gt = cKDTree(gt_pts).query(pred_pts)[0]

        hd95 = max(
            np.percentile(dist_gt_to_pred, 95),
            np.percentile(dist_pred_to_gt, 95)
        )
        hd_list.append(hd95)

    return np.mean(hd_list, dtype=np.float32)

def hausdorff95_infection(y_true, y_pred):
    hd = tf.numpy_function(_calculate_hd95, [y_true, y_pred], tf.float32)
    hd.set_shape(())
    return hd

# Optional: KL Divergence (you already had this)
kld = tf.keras.losses.KLDivergence()

# %%
from tensorflow.keras.losses import BinaryCrossentropy

def loss_f(y_true, y_pred):
    bce = BinaryCrossentropy()
    return dice_loss(y_true, y_pred) + bce(y_true, y_pred) 

def loss_e(y_true, y_pred):
    bce = BinaryCrossentropy()
    return dice_loss(y_true, y_pred)  + kld(y_true, y_pred)
    
def dice_loss(y_true, y_pred):
    return 1. - dice_coef_infection(y_true, y_pred)

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Multiply, Conv2D, DepthwiseConv2D, Dense, Flatten, MaxPooling2D, UpSampling2D, concatenate, Activation, LayerNormalization, Add, Dropout, Conv2DTranspose, multiply, Reshape, GlobalAveragePooling2D, Permute, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Concatenate

def activation_block(x):
    x = Activation("gelu")(x)
    return LayerNormalization()(x)

def conv_stem(x, filters: int, patch_size: int):
    x = Conv2D(filters, kernel_size=patch_size,padding='same', strides=patch_size)(x)
    return activation_block(x)

def vector_block(xyz, cmf, red):
    # red means reduction
    # cmf means filters, denotes vector size
    opt1 = conv_stem(xyz, cmf, red)
    opt2 = conv_stem(xyz, cmf, red)
    
    o1 = GlobalAveragePooling2D()(opt1)
    o2 = GlobalAveragePooling2D()(opt2)

    o5 = concatenate([o1, o2], -1)
    return o5

def mlp_feature(vect, cmf):
    oo = Flatten()(vect)
    o6 = Dense(cmf, activation='gelu')(oo)
    o6 = Dropout(0.2)(o6)
    o6 = Dense(cmf * 2, activation='gelu')(o6)

    o6 = Reshape((1, cmf * 2))(o6)
    o7 = Permute((2, 1))(o6)

    o8 = multiply([o6, o7])
    
    o8 = Lambda(lambda x: tf.expand_dims(x, -1))(o8)
    
    o8 = Reshape((cmf, cmf, 4))(o8)

    return o8

def frz_block(xyz):
    shape = xyz.shape
    a1, a2, a3, a4 = shape[0], shape[1], shape[2], shape[3]
    cmf = a2
    o5 = vector_block(xyz, cmf, 5)
    o7 = mlp_feature(o5, cmf)

    o7 = concatenate([o7, xyz, o7], -1)
    return o7

def up_frz(x1, x2, n_filters):
    # Upsample x1 using Conv2DTranspose
    x1 = Conv2DTranspose(n_filters * 4, 3, strides=2, activation='gelu', padding="same")(x1)
    
    # Apply Conv2D to x2
    x2 = Conv2D(n_filters * 2, 3, activation='gelu', padding="same")(x2)
    
    # Apply attention mechanism
    x = concatenate([x1, x2])
    
    # Apply Dropout for regularization
    x = Dropout(0.3)(x)
    
    return x

def regu(x):
    filters = x.shape[-1]
    shortcut = x
    x = Conv2D(filters, (3, 3), activation='gelu', padding="same")(x)
    x = Add()([x, shortcut])
    return x

# %%
def squeeze_and_excite_block(inputs, ratio=24):
    """ Squeeze and Excitation block to recalibrate channel-wise features """
    filters = inputs.shape[-1]  # Number of input channels
    se_shape = (1, 1, filters)

    # Squeeze: Global Average Pooling
    se = GlobalAveragePooling2D()(inputs)
    se = Reshape(se_shape)(se)

    a = filters // ratio

    # Excitation: Dense layers to capture channel-wise dependencies
    if a > 8:
        se = Conv2D(filters // ratio, kernel_size=1, activation='swish', padding='same')(se)
        se = Conv2D(filters, kernel_size=1, activation='sigmoid', padding='same')(se)
    else:
        se = Conv2D(8, kernel_size=1, activation='swish', padding='same')(se)
        se = Conv2D(filters, kernel_size=1, activation='sigmoid', padding='same')(se)

    # Scale the input by channel-wise weights
    x = multiply([inputs, se])

    return x

def residual_block(x, filters, stride=1, padding='same'):
    shortcut = x
    x = Conv2D(filters * 6, 1, strides=stride, padding=padding, use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)
    x = DepthwiseConv2D(kernel_size=3, strides=stride, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)
    x = squeeze_and_excite_block(x)
    x = Conv2D(filters, 1, strides=stride, padding=padding, use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)
    x = Add()([x, shortcut])
    return x

def dense_block(inputs, num_layers, growth_rate, ratio=16):
    """Dense block where each layer is connected to all previous layers."""
    concat_features = inputs
    for i in range(num_layers):
        # BatchNorm -> ReLU -> Conv2D
        x = Conv2D(growth_rate, 3, activation='gelu', padding='same')(concat_features)

        # Concatenate input with new output (dense connection)
        concat_features = Concatenate()([concat_features, x])
        
    x = concat_features

    return x

def attention_gate(X, g, channel,  
                   activation='ReLU', 
                   attention='add', name='att'):
    '''
    Self-attention gate modified from Oktay et al. 2018.
    
    attention_gate(X, g, channel,  activation='ReLU', attention='add', name='att')
    
    Input
    ----------
        X: input tensor, i.e., key and value.
        g: gated tensor, i.e., query.
        channel: number of intermediate channel.
                 Oktay et al. (2018) did not specify (denoted as F_int).
                 intermediate channel is expected to be smaller than the input channel.
        activation: a nonlinear attnetion activation.
                    The `sigma_1` in Oktay et al. 2018. Default is 'ReLU'.
        attention: 'add' for additive attention; 'multiply' for multiplicative attention.
                   Oktay et al. 2018 applied additive attention.
        name: prefix of the created keras layers.
        
    Output
    ----------
        X_att: output tensor.
    
    '''

    attention_func = eval(attention)
    
    # mapping the input tensor to the intermediate channel
    theta_att = Conv2D(channel, 1, use_bias=True)(X)
    
    # mapping the gate tensor
    phi_g = Conv2D(channel, 1, use_bias=True)(g)
    
    # ----- attention learning ----- #
    query = attention_func([theta_att, phi_g])
    
    # nonlinear activation
    f = Activation('gelu')(query)
    
    # linear transformation
    psi_f = Conv2D(1, 1, use_bias=True)(f)
    # ------------------------------ #
    
    # sigmoid activation as attention coefficients
    coef_att = Activation('sigmoid')(psi_f)
    
    # multiplicative attention masking
    X_att = multiply([X, coef_att])
    
    return X_att

inputs = (img_size, img_size, 1)

def model_build_func(input_shape, n_labels):
    inputs = Input(shape=input_shape, name='input_image')
    g_filter = 16
    u_filter = 8

    # Initial convolution
    initial = Conv2D(g_filter, (3, 3), activation='gelu', padding="same")(inputs)
    initial = dense_block(initial, 2, g_filter // 2)  # 80

    # Down-sampling path
    o1 = MaxPooling2D(2)(initial)
    o1 = frz_block(dense_block(o1, 2, g_filter))  # 40
    #o1 = squeeze_and_excite_block(o1)

    o2 = MaxPooling2D(2)(o1)
    o2 = frz_block(dense_block(o2, 2, g_filter * 2))  # 20
    #o2 = squeeze_and_excite_block(o2)

    o3 = MaxPooling2D(2)(o2)
    o3 = frz_block(dense_block(o3, 2, g_filter * 4))  # 10
    #o3 = squeeze_and_excite_block(o3)

    o4 = MaxPooling2D(2)(o3)
    o4 = frz_block(dense_block(o4, 2, g_filter * 8))  # 5
    #o4 = squeeze_and_excite_block(o4)

    o5 = MaxPooling2D(2)(o4)
    o5 = frz_block(dense_block(o5, 2, g_filter * 16))  # 5
    #o5 = squeeze_and_excite_block(o5)

    # Up-sampling path
    u1 = up_frz(o5, o4, u_filter * 16)  # 10
    #gate1 = attention_gate(o4, u1, u_filter * 16, attention='add')
    cu1 = concatenate([u1, o4])

    u2 = up_frz(cu1, o3, u_filter * 8)  # 20
    #gate2 = attention_gate(o3, u2, u_filter * 8, attention='add')
    cu2 = concatenate([u2, o3])  # 20

    u3 = up_frz(cu2, o2, u_filter * 4)  # 40
    #gate3 = attention_gate(o2, u3, u_filter * 4, attention='add')
    cu3 = concatenate([u3, o2])  # 40

    u4 = up_frz(cu3, o1, u_filter * 2)  # 80
    #gate4 = attention_gate(o1, u4, u_filter * 2, attention='add')
    cu4 = concatenate([u4, o1])  # 80

    u5 = Conv2DTranspose(u_filter * 4, 3, strides=2, activation='gelu', padding="same")(cu4)  # 80
    #gate5 = attention_gate(initial, u5, u_filter, attention='add')
    cu5 = concatenate([u5, initial])  # 80

    # Final segmentation map
    seg_map = Conv2D(n_labels, 3, activation='sigmoid', padding="same")(cu5)

    # Model definition
    model = Model(inputs=inputs, outputs=seg_map)

    return model


model = model_build_func(inputs, 1)

from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2_as_graph

def get_flops(model):
    """Calculate Floating Point Operations (FLOPs) of a Keras model in TensorFlow 2.x."""
    # Convert Keras model to a TensorFlow function
    concrete_func = tf.function(lambda inputs: model(inputs))
    concrete_func = concrete_func.get_concrete_function(
        tf.TensorSpec([1] + list(model.input_shape[1:]), model.input.dtype)
    )

    # Convert to frozen graph
    frozen_func, _ = convert_variables_to_constants_v2_as_graph(concrete_func)

    # Compute FLOPs
    flops = tf.compat.v1.profiler.profile(
        frozen_func.graph,
        options=tf.compat.v1.profiler.ProfileOptionBuilder.float_operation(),
    )

    return flops.total_float_ops

# Compute FLOPs
flops = get_flops(model)
print(f"Total FLOPs: {flops / 1e9:.2f} GFLOPs")  # Convert to GFLOPs

from tensorflow.keras.optimizers import Adam

optimizer = Adam(learning_rate=1e-3)
model.compile(optimizer=optimizer, loss=loss_f, metrics=[dice_coef_infection, iou_coef_infection, precision_infection, recall_infection, hausdorff95_infection, specificity_infection, accuracy_infection, f1_infection])

# Model summary
model.summary()
# Out:
# Total FLOPs: 20.32 GFLOPs
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_image (InputLayer)        [(None, 320, 320, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 320, 320, 16) 160         input_image[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 320, 320, 8)  1160        conv2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 320, 320, 24) 0           conv2d[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 320, 320, 8)  1736        concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 320, 320, 32) 0           concatenate[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 160, 160, 32) 0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 160, 160, 16) 4624        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 160, 160, 48) 0           max_pooling2d[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 160, 160, 16) 6928        concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 160, 160, 64) 0           concatenate_2[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 160)  256160      concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 160)  256160      concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 160)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 160)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# layer_normalization (LayerNorma (None, 32, 32, 160)  320         activation[0][0]
# __________________________________________________________________________________________________
# layer_normalization_1 (LayerNor (None, 32, 32, 160)  320         activation_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 160)          0           layer_normalization[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 160)          0           layer_normalization_1[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 320)          0           global_average_pooling2d[0][0]
#                                                                  global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 320)          0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 160)          51360       flatten[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 160)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 320)          51520       dropout[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 320)       0           dense_1[0][0]
# __________________________________________________________________________________________________
# permute (Permute)               (None, 320, 1)       0           reshape[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 320, 320)     0           reshape[0][0]
#                                                                  permute[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 320, 320, 1)  0           multiply[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 160, 160, 4)  0           lambda[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 160, 160, 72) 0           reshape_1[0][0]
#                                                                  concatenate_3[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 80, 80, 72)   0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 80, 80, 32)   20768       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 80, 80, 104)  0           max_pooling2d_1[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 80, 80, 32)   29984       concatenate_6[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 80, 80, 136)  0           concatenate_6[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 80)   272080      concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 80)   272080      concatenate_7[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 16, 16, 80)   0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 16, 16, 80)   0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# layer_normalization_2 (LayerNor (None, 16, 16, 80)   160         activation_2[0][0]
# __________________________________________________________________________________________________
# layer_normalization_3 (LayerNor (None, 16, 16, 80)   160         activation_3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 80)           0           layer_normalization_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 80)           0           layer_normalization_3[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 160)          0           global_average_pooling2d_2[0][0]
#                                                                  global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 160)          0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 80)           12880       flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 80)           0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 160)          12960       dropout_1[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 160)       0           dense_3[0][0]
# __________________________________________________________________________________________________
# permute_1 (Permute)             (None, 160, 1)       0           reshape_2[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 160, 160)     0           reshape_2[0][0]
#                                                                  permute_1[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 160, 160, 1)  0           multiply_1[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 80, 80, 4)    0           lambda_1[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 80, 80, 144)  0           reshape_3[0][0]
#                                                                  concatenate_7[0][0]
#                                                                  reshape_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 40, 40, 144)  0           concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 40, 40, 64)   83008       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 40, 40, 208)  0           max_pooling2d_2[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 40, 40, 64)   119872      concatenate_10[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 40, 40, 272)  0           concatenate_10[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 40)     272040      concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 40)     272040      concatenate_11[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 8, 8, 40)     0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 8, 8, 40)     0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# layer_normalization_4 (LayerNor (None, 8, 8, 40)     80          activation_4[0][0]
# __________________________________________________________________________________________________
# layer_normalization_5 (LayerNor (None, 8, 8, 40)     80          activation_5[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 40)           0           layer_normalization_4[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 40)           0           layer_normalization_5[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 80)           0           global_average_pooling2d_4[0][0]
#                                                                  global_average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 80)           0           concatenate_12[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 40)           3240        flatten_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 40)           0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 80)           3280        dropout_2[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1, 80)        0           dense_5[0][0]
# __________________________________________________________________________________________________
# permute_2 (Permute)             (None, 80, 1)        0           reshape_4[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 80, 80)       0           reshape_4[0][0]
#                                                                  permute_2[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 80, 80, 1)    0           multiply_2[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 40, 40, 4)    0           lambda_2[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 40, 40, 280)  0           reshape_5[0][0]
#                                                                  concatenate_11[0][0]
#                                                                  reshape_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 20, 20, 280)  0           concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 20, 20, 128)  322688      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 20, 20, 408)  0           max_pooling2d_3[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 20, 20, 128)  470144      concatenate_14[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 20, 20, 536)  0           concatenate_14[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 4, 4, 20)     268020      concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 4, 4, 20)     268020      concatenate_15[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 4, 4, 20)     0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 4, 4, 20)     0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# layer_normalization_6 (LayerNor (None, 4, 4, 20)     40          activation_6[0][0]
# __________________________________________________________________________________________________
# layer_normalization_7 (LayerNor (None, 4, 4, 20)     40          activation_7[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 20)           0           layer_normalization_6[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 20)           0           layer_normalization_7[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 40)           0           global_average_pooling2d_6[0][0]
#                                                                  global_average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 40)           0           concatenate_16[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 20)           820         flatten_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 20)           0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 40)           840         dropout_3[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 1, 40)        0           dense_7[0][0]
# __________________________________________________________________________________________________
# permute_3 (Permute)             (None, 40, 1)        0           reshape_6[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 40, 40)       0           reshape_6[0][0]
#                                                                  permute_3[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 40, 40, 1)    0           multiply_3[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 20, 20, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 20, 20, 544)  0           reshape_7[0][0]
#                                                                  concatenate_15[0][0]
#                                                                  reshape_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 10, 10, 544)  0           concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 10, 10, 256)  1253632     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 10, 10, 800)  0           max_pooling2d_4[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 10, 10, 256)  1843456     concatenate_18[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 10, 10, 1056) 0           concatenate_18[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 2, 2, 10)     264010      concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 2, 2, 10)     264010      concatenate_19[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 2, 2, 10)     0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 2, 2, 10)     0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# layer_normalization_8 (LayerNor (None, 2, 2, 10)     20          activation_8[0][0]
# __________________________________________________________________________________________________
# layer_normalization_9 (LayerNor (None, 2, 2, 10)     20          activation_9[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_8 (Glo (None, 10)           0           layer_normalization_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_9 (Glo (None, 10)           0           layer_normalization_9[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 20)           0           global_average_pooling2d_8[0][0]
#                                                                  global_average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 20)           0           concatenate_20[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 10)           210         flatten_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 10)           0           dense_8[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 20)           220         dropout_4[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 1, 20)        0           dense_9[0][0]
# __________________________________________________________________________________________________
# permute_4 (Permute)             (None, 20, 1)        0           reshape_8[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 20, 20)       0           reshape_8[0][0]
#                                                                  permute_4[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 20, 20, 1)    0           multiply_4[0][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 10, 10, 4)    0           lambda_4[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 10, 10, 1064) 0           reshape_9[0][0]
#                                                                  concatenate_19[0][0]
#                                                                  reshape_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 20, 20, 512)  4903424     concatenate_21[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 20, 20, 256)  1253632     concatenate_17[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 20, 20, 768)  0           conv2d_transpose[0][0]
#                                                                  conv2d_23[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 20, 20, 768)  0           concatenate_22[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 20, 20, 1312) 0           dropout_5[0][0]
#                                                                  concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 40, 40, 256)  3023104     concatenate_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 40, 40, 128)  322688      concatenate_13[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 40, 40, 384)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 40, 40, 384)  0           concatenate_24[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 40, 40, 664)  0           dropout_6[0][0]
#                                                                  concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 80, 80, 128)  765056      concatenate_25[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 80, 80, 64)   83008       concatenate_9[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 80, 80, 192)  0           conv2d_transpose_2[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 80, 80, 192)  0           concatenate_26[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 80, 80, 336)  0           dropout_7[0][0]
#                                                                  concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 160, 160, 64) 193600      concatenate_27[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 160, 160, 32) 20768       concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 160, 160, 96) 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 160, 160, 96) 0           concatenate_28[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 160, 160, 168 0           dropout_8[0][0]
#                                                                  concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 320, 320, 32) 48416       concatenate_29[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 320, 320, 64) 0           conv2d_transpose_4[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 320, 320, 1)  577         concatenate_30[0][0]
# ==================================================================================================
# Total params: 17,575,623
# Trainable params: 17,575,623
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Install required packages
# !pip install openpyxl

# Imports
import openpyxl  # required for reading .xlsx files
import pandas as pd
import tensorflow as tf
import os
import shutil
from tensorflow.keras.callbacks import LearningRateScheduler, ReduceLROnPlateau

# File paths
checkpoint_filepath = '/kaggle/working/checkpoint.h5.keras'
metrics_file = '/kaggle/working/training_metrics.xlsx'
pre_checkpoint_filepath = '/kaggle/input/dseg-unet-4channel-covid19/checkpoint.h5.keras'
pre_metrics_file = '/kaggle/input/dseg-unet-4channel-covid19/training_metrics.xlsx'

# Restore checkpoint and metrics if available
if os.path.exists(pre_checkpoint_filepath):
    shutil.copy(pre_checkpoint_filepath, checkpoint_filepath)
    print(f"Restored checkpoint from: {pre_checkpoint_filepath}")

if os.path.exists(pre_metrics_file):
    shutil.copy(pre_metrics_file, metrics_file)
    print(f"Restored metrics file from: {pre_metrics_file}")

# Load last epoch
def load_last_epoch():
    if os.path.exists(metrics_file):
        try:
            df = pd.read_excel(metrics_file, engine='openpyxl')
            if not df.empty and 'epoch' in df.columns:
                return df['epoch'].iloc[-1] + 1
        except Exception as e:
            print(f"⚠️ Could not read metrics file: {e}")
    return 0

last_epoch = load_last_epoch()

# Get best validation loss from previous runs
def get_best_val_loss():
    if os.path.exists(metrics_file):
        try:
            df = pd.read_excel(metrics_file, engine='openpyxl')
            if 'val_loss' in df.columns and not df['val_loss'].isnull().all():
                return df['val_loss'].min()
        except Exception as e:
            print(f"⚠️ Could not read val_loss from metrics file: {e}")
    return float('inf')

best_val_loss = get_best_val_loss()

# Custom model checkpoint
class CustomModelCheckpoint(tf.keras.callbacks.Callback):
    def __init__(self, filepath):
        super().__init__()
        self.filepath = filepath
        self.best_loss = best_val_loss

    def on_epoch_end(self, epoch, logs=None):
        current_loss = logs.get('val_loss')
        if current_loss is not None and current_loss < self.best_loss:
            self.best_loss = current_loss
            self.model.save(self.filepath)
            print(f"✅ Model saved at epoch {epoch + 1} with val_loss: {current_loss:.4f}")

# === Learning Rate Schedule ===
def lr_schedule(epoch, lr):
    return 1e-4 if epoch >= 5 else lr

lr_scheduler = LearningRateScheduler(lr_schedule, verbose=1)

# Logger for Excel
class MetricsLogger(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        df_new = pd.DataFrame([{**logs, 'epoch': epoch}])
        try:
            if os.path.exists(metrics_file):
                df = pd.read_excel(metrics_file, engine='openpyxl')
                df = pd.concat([df, df_new], ignore_index=True)
            else:
                df = df_new
            df.to_excel(metrics_file, index=False, engine='openpyxl')
        except Exception as e:
            print(f"⚠️ Failed to log metrics: {e}")

# Early stopping with patience and saving best weights
class CustomEarlyStopping(tf.keras.callbacks.Callback):
    def __init__(self, patience=20):
        super().__init__()
        self.patience = patience
        self.wait = 0
        self.best_loss = best_val_loss

    def on_epoch_end(self, epoch, logs=None):
        current_loss = logs.get('val_loss')
        if current_loss is None:
            return
        if current_loss < self.best_loss:
            self.best_loss = current_loss
            self.wait = 0
            self.model.save_weights(checkpoint_filepath)
        else:
            self.wait += 1
            if self.wait >= self.patience:
                print(f"🛑 Early stopping at epoch {epoch + 1}")
                self.model.stop_training = True


# Final callbacks list
callbacks = [
    CustomModelCheckpoint(filepath=checkpoint_filepath),
    MetricsLogger(),
    lr_scheduler,
    CustomEarlyStopping(patience=20)
]
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.3-py2.py3-none-any.whl (251 kB)
#      |████████████████████████████████| 251 kB 8.3 MB/s eta 0:00:01
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.3

# %% [markdown]
# ## Training the model

# %%
import time
import os
import pandas as pd
import numpy as np
from tensorflow.keras.utils import Sequence
from tensorflow.keras.models import load_model

EPOCHS = 100

# Record the start time
start_time = time.time()

# === Load last completed epoch from metrics file ===
def load_last_epoch():
    if os.path.exists(pre_metrics_file):
        try:
            df = pd.read_excel(pre_metrics_file, engine='openpyxl')
            if not df.empty and 'epoch' in df.columns:
                return int(df['epoch'].iloc[-1]) + 1
        except Exception as e:
            print(f"⚠️ Failed to read metrics file: {e}")
    return 0

last_epoch = load_last_epoch()

# === Load pretrained weights if available ===
if os.path.exists(pre_checkpoint_filepath):
    print("✅ Checkpoint found. Loading pretrained weights...")
    model.load_weights(pre_checkpoint_filepath)
    print(f"🔁 Resuming training from epoch {last_epoch}")
else:
    print("🆕 No checkpoint found. Starting training from scratch.")
    last_epoch = 0

# === Prepare input and label tensors ===
lung_train = np.asarray(lung_train, dtype=np.float16)
infect_train = np.asarray(infect_train, dtype=np.uint8)

lung_temp = np.asarray(lung_temp, dtype=np.float16)
infect_temp = np.asarray(infect_temp, dtype=np.uint8)

lung_test = np.asarray(lung_test, dtype=np.float16)
infect_test = np.asarray(infect_test, dtype=np.uint8)

# === Data Generator ===
class LungDataGenerator(Sequence):
    def __init__(self, X, Y, batch_size=8, shuffle=True):
        self.X = X
        self.Y = Y
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indices = np.arange(len(X))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.X) / self.batch_size))

    def __getitem__(self, index):
        batch_ids = self.indices[index * self.batch_size:(index + 1) * self.batch_size]
        X_batch = self.X[batch_ids]
        Y_batch = self.Y[batch_ids]
        return np.asarray(X_batch, dtype=np.float16), np.asarray(Y_batch, dtype=np.uint8)

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indices)

# === Create generators ===
train_gen = LungDataGenerator(lung_train, infect_train, batch_size=8)
temp_gen = LungDataGenerator(lung_temp, infect_temp, batch_size=8, shuffle=False)
val_gen = LungDataGenerator(lung_test, infect_test, batch_size=8, shuffle=False)

# === Train the model ===
history = model.fit(
    train_gen,
    validation_data=temp_gen,
    epochs=EPOCHS,
    initial_epoch=last_epoch,
    callbacks=callbacks
)

# === Timing info ===
end_time = time.time()
total_time = end_time - start_time
print(f"✅ Total training time: {total_time:.2f} seconds ({total_time / 60:.2f} minutes)")
# Out:
# 🆕 No checkpoint found. Starting training from scratch.
# Epoch 1/100
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 240s 198ms/step - loss: 1.7429 - dice_coef_infection: 0.0600 - iou_coef_infection: 0.0331 - precision_infection: 0.0709 - recall_infection: 0.1367 - hausdorff95_infection: 271.6639 - specificity_infection: 0.9763 - accuracy_infection: 0.9687 - f1_infection: 0.8723 - val_loss: 0.8468 - val_dice_coef_infection: 0.2613 - val_iou_coef_infection: 0.2303 - val_precision_infection: 0.2500 - val_recall_infection: 0.7617 - val_hausdorff95_infection: 201.6613 - val_specificity_infection: 0.9909 - val_accuracy_infection: 0.9886 - val_f1_infection: 0.7049
# ✅ Model saved at epoch 1 with val_loss: 0.8468
# Epoch 2/100
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.8555 - dice_coef_infection: 0.2198 - iou_coef_infection: 0.1371 - precision_infection: 0.2552 - recall_infection: 0.3362 - hausdorff95_infection: 184.4154 - specificity_infection: 0.9915 - accuracy_infection: 0.9857 - f1_infection: 0.7628 - val_loss: 0.5813 - val_dice_coef_infection: 0.4903 - val_iou_coef_infection: 0.4537 - val_precision_infection: 0.5727 - val_recall_infection: 0.6896 - val_hausdorff95_infection: 80.0416 - val_specificity_infection: 0.9981 - val_accuracy_infection: 0.9950 - val_f1_infection: 0.8061
# ✅ Model saved at epoch 2 with val_loss: 0.5813
# Epoch 3/100
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 224s 196ms/step - loss: 0.5764 - dice_coef_infection: 0.4760 - iou_coef_infection: 0.3424 - precision_infection: 0.5091 - recall_infection: 0.5408 - hausdorff95_infection: 117.8164 - specificity_infection: 0.9956 - accuracy_infection: 0.9920 - f1_infection: 0.7763 - val_loss: 0.6345 - val_dice_coef_infection: 0.4909 - val_iou_coef_infection: 0.4506 - val_precision_infection: 0.5109 - val_recall_infection: 0.7785 - val_hausdorff95_infection: 102.6834 - val_specificity_infection: 0.9935 - val_accuracy_infection: 0.9927 - val_f1_infection: 0.7868
# Epoch 4/100
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 224s 196ms/step - loss: 0.5403 - dice_coef_infection: 0.5173 - iou_coef_infection: 0.3853 - precision_infection: 0.5705 - recall_infection: 0.5783 - hausdorff95_infection: 93.1387 - specificity_infection: 0.9969 - accuracy_infection: 0.9938 - f1_infection: 0.7845 - val_loss: 0.5016 - val_dice_coef_infection: 0.5904 - val_iou_coef_infection: 0.5488 - val_precision_infection: 0.6223 - val_recall_infection: 0.7564 - val_hausdorff95_infection: 79.8222 - val_specificity_infection: 0.9957 - val_accuracy_infection: 0.9944 - val_f1_infection: 0.8376
# ✅ Model saved at epoch 4 with val_loss: 0.5016
# Epoch 5/100
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 224s 196ms/step - loss: 0.4868 - dice_coef_infection: 0.5607 - iou_coef_infection: 0.4236 - precision_infection: 0.6083 - recall_infection: 0.6076 - hausdorff95_infection: 79.4725 - specificity_infection: 0.9969 - accuracy_infection: 0.9939 - f1_infection: 0.7946 - val_loss: 0.5099 - val_dice_coef_infection: 0.5658 - val_iou_coef_infection: 0.5218 - val_precision_infection: 0.5972 - val_recall_infection: 0.7526 - val_hausdorff95_infection: 81.7106 - val_specificity_infection: 0.9965 - val_accuracy_infection: 0.9949 - val_f1_infection: 0.8259
# Epoch 6/100
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 224s 196ms/step - loss: 0.4103 - dice_coef_infection: 0.6270 - iou_coef_infection: 0.4903 - precision_infection: 0.6584 - recall_infection: 0.6568 - hausdorff95_infection: 59.3729 - specificity_infection: 0.9977 - accuracy_infection: 0.9952 - f1_infection: 0.8200 - val_loss: 0.3955 - val_dice_coef_infection: 0.6700 - val_iou_coef_infection: 0.6205 - val_precision_infection: 0.7343 - val_recall_infection: 0.7604 - val_hausdorff95_infection: 41.0248 - val_specificity_infection: 0.9968 - val_accuracy_infection: 0.9950 - val_f1_infection: 0.8562
# ✅ Model saved at epoch 6 with val_loss: 0.3955
# Epoch 7/100
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 224s 196ms/step - loss: 0.3740 - dice_coef_infection: 0.6548 - iou_coef_infection: 0.5170 - precision_infection: 0.6843 - recall_infection: 0.6805 - hausdorff95_infection: 56.3283 - specificity_infection: 0.9979 - accuracy_infection: 0.9956 - f1_infection: 0.8258 - val_loss: 0.3522 - val_dice_coef_infection: 0.7180 - val_iou_coef_infection: 0.6714 - val_precision_infection: 0.8110 - val_recall_infection: 0.7444 - val_hausdorff95_infection: 41.6013 - val_specificity_infection: 0.9972 - val_accuracy_infection: 0.9952 - val_f1_infection: 0.8779
# ✅ Model saved at epoch 7 with val_loss: 0.3522
# Epoch 8/100
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 224s 196ms/step - loss: 0.3845 - dice_coef_infection: 0.6461 - iou_coef_infection: 0.5140 - precision_infection: 0.6850 - recall_infection: 0.6848 - hausdorff95_infection: 47.9900 - specificity_infection: 0.9980 - accuracy_infection: 0.9957 - f1_infection: 0.8216 - val_loss: 0.3822 - val_dice_coef_infection: 0.6817 - val_iou_coef_infection: 0.6353 - val_precision_infection: 0.7538 - val_recall_infection: 0.7578 - val_hausdorff95_infection: 39.9362 - val_specificity_infection: 0.9964 - val_accuracy_infection: 0.9948 - val_f1_infection: 0.8638
# Epoch 9/100
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 224s 196ms/step - loss: 0.3654 - dice_coef_infection: 0.6626 - iou_coef_infection: 0.5303 - precision_infection: 0.6975 - recall_infection: 0.6965 - hausdorff95_infection: 48.2466 - specificity_infection: 0.9980 - accuracy_infection: 0.9959 - f1_infection: 0.8279 - val_loss: 0.4187 - val_dice_coef_infection: 0.6483 - val_iou_coef_infection: 0.6100 - val_precision_infection: 0.7368 - val_recall_infection: 0.7304 - val_hausdorff95_infection: 60.1351 - val_specificity_infection: 0.9965 - val_accuracy_infection: 0.9950 - val_f1_infection: 0.8599
# Epoch 10/100
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 224s 196ms/step - loss: 0.3652 - dice_coef_infection: 0.6618 - iou_coef_infection: 0.5281 - precision_infection: 0.6873 - recall_infection: 0.6956 - hausdorff95_infection: 48.9542 - specificity_infection: 0.9980 - accuracy_infection: 0.9959 - f1_infection: 0.8304 - val_loss: 0.3656 - val_dice_coef_infection: 0.7050 - val_iou_coef_infection: 0.6596 - val_precision_infection: 0.7976 - val_recall_infection: 0.7442 - val_hausdorff95_infection: 41.4488 - val_specificity_infection: 0.9970 - val_accuracy_infection: 0.9953 - val_f1_infection: 0.8728
# Epoch 11/100
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.3571 - dice_coef_infection: 0.6722 - iou_coef_infection: 0.5402 - precision_infection: 0.7147 - recall_infection: 0.6929 - hausdorff95_infection: 43.1261 - specificity_infection: 0.9980 - accuracy_infection: 0.9959 - f1_infection: 0.8299 - val_loss: 0.3545 - val_dice_coef_infection: 0.7017 - val_iou_coef_infection: 0.6554 - val_precision_infection: 0.8048 - val_recall_infection: 0.7327 - val_hausdorff95_infection: 42.5013 - val_specificity_infection: 0.9978 - val_accuracy_infection: 0.9955 - val_f1_infection: 0.8725
# Epoch 12/100
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.3417 - dice_coef_infection: 0.6852 - iou_coef_infection: 0.5512 - precision_infection: 0.7070 - recall_infection: 0.7120 - hausdorff95_infection: 43.0199 - specificity_infection: 0.9979 - accuracy_infection: 0.9959 - f1_infection: 0.8363 - val_loss: 0.3502 - val_dice_coef_infection: 0.7114 - val_iou_coef_infection: 0.6616 - val_precision_infection: 0.7978 - val_recall_infection: 0.7518 - val_hausdorff95_infection: 37.5110 - val_specificity_infection: 0.9976 - val_accuracy_infection: 0.9954 - val_f1_infection: 0.8719
# ✅ Model saved at epoch 12 with val_loss: 0.3502
# Epoch 13/100
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.3537 - dice_coef_infection: 0.6756 - iou_coef_infection: 0.5429 - precision_infection: 0.7112 - recall_infection: 0.6972 - hausdorff95_infection: 46.0664 - specificity_infection: 0.9980 - accuracy_infection: 0.9958 - f1_infection: 0.8333 - val_loss: 0.3846 - val_dice_coef_infection: 0.6798 - val_iou_coef_infection: 0.6293 - val_precision_infection: 0.7307 - val_recall_infection: 0.7697 - val_hausdorff95_infection: 44.9516 - val_specificity_infection: 0.9966 - val_accuracy_infection: 0.9948 - val_f1_infection: 0.8624
# Epoch 14/100
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.3341 - dice_coef_infection: 0.6923 - iou_coef_infection: 0.5592 - precision_infection: 0.7161 - recall_infection: 0.7161 - hausdorff95_infection: 42.2789 - specificity_infection: 0.9979 - accuracy_infection: 0.9958 - f1_infection: 0.8389 - val_loss: 0.3579 - val_dice_coef_infection: 0.7137 - val_iou_coef_infection: 0.6626 - val_precision_infection: 0.7576 - val_recall_infection: 0.7842 - val_hausdorff95_infection: 37.2421 - val_specificity_infection: 0.9961 - val_accuracy_infection: 0.9947 - val_f1_infection: 0.8753
# Epoch 15/100
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.3514 - dice_coef_infection: 0.6758 - iou_coef_infection: 0.5448 - precision_infection: 0.7054 - recall_infection: 0.7046 - hausdorff95_infection: 41.5336 - specificity_infection: 0.9980 - accuracy_infection: 0.9960 - f1_infection: 0.8349 - val_loss: 0.3507 - val_dice_coef_infection: 0.7062 - val_iou_coef_infection: 0.6559 - val_precision_infection: 0.7776 - val_recall_infection: 0.7592 - val_hausdorff95_infection: 37.4897 - val_specificity_infection: 0.9972 - val_accuracy_infection: 0.9953 - val_f1_infection: 0.8731
# Epoch 16/100
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 222s 195ms/step - loss: 0.3286 - dice_coef_infection: 0.6996 - iou_coef_infection: 0.5662 - precision_infection: 0.7375 - recall_infection: 0.7172 - hausdorff95_infection: 36.0450 - specificity_infection: 0.9980 - accuracy_infection: 0.9959 - f1_infection: 0.8380 - val_loss: 0.3807 - val_dice_coef_infection: 0.6838 - val_iou_coef_infection: 0.6360 - val_precision_infection: 0.7753 - val_recall_infection: 0.7402 - val_hausdorff95_infection: 44.3790 - val_specificity_infection: 0.9976 - val_accuracy_infection: 0.9953 - val_f1_infection: 0.8632
# Epoch 17/100
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.3227 - dice_coef_infection: 0.7038 - iou_coef_infection: 0.5718 - precision_infection: 0.7346 - recall_infection: 0.7212 - hausdorff95_infection: 38.1113 - specificity_infection: 0.9980 - accuracy_infection: 0.9959 - f1_infection: 0.8410 - val_loss: 0.3592 - val_dice_coef_infection: 0.7151 - val_iou_coef_infection: 0.6754 - val_precision_infection: 0.8932 - val_recall_infection: 0.7088 - val_hausdorff95_infection: 58.2249 - val_specificity_infection: 0.9981 - val_accuracy_infection: 0.9957 - val_f1_infection: 0.8638
# Epoch 18/100
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.3302 - dice_coef_infection: 0.6972 - iou_coef_infection: 0.5644 - precision_infection: 0.7225 - recall_infection: 0.7206 - hausdorff95_infection: 38.9175 - specificity_infection: 0.9978 - accuracy_infection: 0.9959 - f1_infection: 0.8398 - val_loss: 0.3446 - val_dice_coef_infection: 0.7161 - val_iou_coef_infection: 0.6696 - val_precision_infection: 0.8080 - val_recall_infection: 0.7498 - val_hausdorff95_infection: 45.2254 - val_specificity_infection: 0.9971 - val_accuracy_infection: 0.9955 - val_f1_infection: 0.8766
# ✅ Model saved at epoch 18 with val_loss: 0.3446
# Epoch 19/100
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 196ms/step - loss: 0.3282 - dice_coef_infection: 0.6975 - iou_coef_infection: 0.5665 - precision_infection: 0.7140 - recall_infection: 0.7218 - hausdorff95_infection: 40.6877 - specificity_infection: 0.9979 - accuracy_infection: 0.9960 - f1_infection: 0.8446 - val_loss: 0.3714 - val_dice_coef_infection: 0.6957 - val_iou_coef_infection: 0.6476 - val_precision_infection: 0.7715 - val_recall_infection: 0.7512 - val_hausdorff95_infection: 47.4046 - val_specificity_infection: 0.9971 - val_accuracy_infection: 0.9951 - val_f1_infection: 0.8693
# Epoch 20/100
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.3120 - dice_coef_infection: 0.7125 - iou_coef_infection: 0.5811 - precision_infection: 0.7315 - recall_infection: 0.7305 - hausdorff95_infection: 37.1229 - specificity_infection: 0.9980 - accuracy_infection: 0.9961 - f1_infection: 0.8489 - val_loss: 0.3633 - val_dice_coef_infection: 0.7200 - val_iou_coef_infection: 0.6754 - val_precision_infection: 0.8416 - val_recall_infection: 0.7291 - val_hausdorff95_infection: 48.8106 - val_specificity_infection: 0.9977 - val_accuracy_infection: 0.9951 - val_f1_infection: 0.8730
# Epoch 21/100
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.3292 - dice_coef_infection: 0.6954 - iou_coef_infection: 0.5631 - precision_infection: 0.7311 - recall_infection: 0.7132 - hausdorff95_infection: 36.3049 - specificity_infection: 0.9981 - accuracy_infection: 0.9962 - f1_infection: 0.8380 - val_loss: 0.3585 - val_dice_coef_infection: 0.7088 - val_iou_coef_infection: 0.6633 - val_precision_infection: 0.8075 - val_recall_infection: 0.7413 - val_hausdorff95_infection: 42.7908 - val_specificity_infection: 0.9971 - val_accuracy_infection: 0.9951 - val_f1_infection: 0.8741
# Epoch 22/100
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.3065 - dice_coef_infection: 0.7175 - iou_coef_infection: 0.5860 - precision_infection: 0.7422 - recall_infection: 0.7339 - hausdorff95_infection: 35.9485 - specificity_infection: 0.9981 - accuracy_infection: 0.9964 - f1_infection: 0.8465 - val_loss: 0.3640 - val_dice_coef_infection: 0.7013 - val_iou_coef_infection: 0.6609 - val_precision_infection: 0.8115 - val_recall_infection: 0.7278 - val_hausdorff95_infection: 52.5274 - val_specificity_infection: 0.9972 - val_accuracy_infection: 0.9951 - val_f1_infection: 0.8743
# Epoch 23/100
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.3253 - dice_coef_infection: 0.6985 - iou_coef_infection: 0.5697 - precision_infection: 0.7127 - recall_infection: 0.7354 - hausdorff95_infection: 37.9062 - specificity_infection: 0.9980 - accuracy_infection: 0.9962 - f1_infection: 0.8425 - val_loss: 0.3896 - val_dice_coef_infection: 0.6729 - val_iou_coef_infection: 0.6249 - val_precision_infection: 0.7778 - val_recall_infection: 0.7319 - val_hausdorff95_infection: 45.4484 - val_specificity_infection: 0.9982 - val_accuracy_infection: 0.9955 - val_f1_infection: 0.8541
# Epoch 24/100
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.3183 - dice_coef_infection: 0.7067 - iou_coef_infection: 0.5786 - precision_infection: 0.7347 - recall_infection: 0.7347 - hausdorff95_infection: 35.8260 - specificity_infection: 0.9981 - accuracy_infection: 0.9963 - f1_infection: 0.8427 - val_loss: 0.3518 - val_dice_coef_infection: 0.7095 - val_iou_coef_infection: 0.6591 - val_precision_infection: 0.7753 - val_recall_infection: 0.7691 - val_hausdorff95_infection: 40.0469 - val_specificity_infection: 0.9971 - val_accuracy_infection: 0.9955 - val_f1_infection: 0.8704
# Epoch 25/100
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.3279 - dice_coef_infection: 0.6968 - iou_coef_infection: 0.5664 - precision_infection: 0.7338 - recall_infection: 0.7185 - hausdorff95_infection: 34.0937 - specificity_infection: 0.9982 - accuracy_infection: 0.9963 - f1_infection: 0.8391 - val_loss: 0.3548 - val_dice_coef_infection: 0.7159 - val_iou_coef_infection: 0.6737 - val_precision_infection: 0.8666 - val_recall_infection: 0.7149 - val_hausdorff95_infection: 53.9422 - val_specificity_infection: 0.9982 - val_accuracy_infection: 0.9957 - val_f1_infection: 0.8704
# Epoch 26/100
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.3100 - dice_coef_infection: 0.7142 - iou_coef_infection: 0.5876 - precision_infection: 0.7517 - recall_infection: 0.7373 - hausdorff95_infection: 32.4682 - specificity_infection: 0.9982 - accuracy_infection: 0.9963 - f1_infection: 0.8438 - val_loss: 0.3465 - val_dice_coef_infection: 0.7185 - val_iou_coef_infection: 0.6676 - val_precision_infection: 0.7760 - val_recall_infection: 0.7717 - val_hausdorff95_infection: 43.6733 - val_specificity_infection: 0.9974 - val_accuracy_infection: 0.9953 - val_f1_infection: 0.8760
# Epoch 27/100
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 224s 196ms/step - loss: 0.3038 - dice_coef_infection: 0.7221 - iou_coef_infection: 0.5923 - precision_infection: 0.7468 - recall_infection: 0.7422 - hausdorff95_infection: 34.2731 - specificity_infection: 0.9981 - accuracy_infection: 0.9962 - f1_infection: 0.8481 - val_loss: 0.3398 - val_dice_coef_infection: 0.7263 - val_iou_coef_infection: 0.6820 - val_precision_infection: 0.8638 - val_recall_infection: 0.7239 - val_hausdorff95_infection: 46.8764 - val_specificity_infection: 0.9981 - val_accuracy_infection: 0.9956 - val_f1_infection: 0.8749
# ✅ Model saved at epoch 27 with val_loss: 0.3398
# Epoch 28/100
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.3058 - dice_coef_infection: 0.7185 - iou_coef_infection: 0.5904 - precision_infection: 0.7478 - recall_infection: 0.7359 - hausdorff95_infection: 29.5084 - specificity_infection: 0.9981 - accuracy_infection: 0.9963 - f1_infection: 0.8487 - val_loss: 0.3269 - val_dice_coef_infection: 0.7344 - val_iou_coef_infection: 0.6860 - val_precision_infection: 0.8417 - val_recall_infection: 0.7424 - val_hausdorff95_infection: 41.9682 - val_specificity_infection: 0.9978 - val_accuracy_infection: 0.9955 - val_f1_infection: 0.8794
# ✅ Model saved at epoch 28 with val_loss: 0.3269
# Epoch 29/100
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.3032 - dice_coef_infection: 0.7217 - iou_coef_infection: 0.5899 - precision_infection: 0.7469 - recall_infection: 0.7335 - hausdorff95_infection: 32.5573 - specificity_infection: 0.9982 - accuracy_infection: 0.9963 - f1_infection: 0.8497 - val_loss: 0.3712 - val_dice_coef_infection: 0.7033 - val_iou_coef_infection: 0.6564 - val_precision_infection: 0.7636 - val_recall_infection: 0.7623 - val_hausdorff95_infection: 42.0116 - val_specificity_infection: 0.9963 - val_accuracy_infection: 0.9945 - val_f1_infection: 0.8760
# Epoch 30/100
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2987 - dice_coef_infection: 0.7260 - iou_coef_infection: 0.5958 - precision_infection: 0.7521 - recall_infection: 0.7433 - hausdorff95_infection: 31.5612 - specificity_infection: 0.9981 - accuracy_infection: 0.9963 - f1_infection: 0.8493 - val_loss: 0.3430 - val_dice_coef_infection: 0.7194 - val_iou_coef_infection: 0.6786 - val_precision_infection: 0.8798 - val_recall_infection: 0.7169 - val_hausdorff95_infection: 55.9819 - val_specificity_infection: 0.9981 - val_accuracy_infection: 0.9957 - val_f1_infection: 0.8681
# Epoch 31/100
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.3033 - dice_coef_infection: 0.7206 - iou_coef_infection: 0.5936 - precision_infection: 0.7505 - recall_infection: 0.7337 - hausdorff95_infection: 31.6288 - specificity_infection: 0.9981 - accuracy_infection: 0.9964 - f1_infection: 0.8515 - val_loss: 0.3688 - val_dice_coef_infection: 0.7007 - val_iou_coef_infection: 0.6546 - val_precision_infection: 0.7959 - val_recall_infection: 0.7424 - val_hausdorff95_infection: 46.6212 - val_specificity_infection: 0.9972 - val_accuracy_infection: 0.9951 - val_f1_infection: 0.8704
# Epoch 32/100
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.3035 - dice_coef_infection: 0.7209 - iou_coef_infection: 0.5945 - precision_infection: 0.7516 - recall_infection: 0.7432 - hausdorff95_infection: 28.8084 - specificity_infection: 0.9981 - accuracy_infection: 0.9963 - f1_infection: 0.8485 - val_loss: 0.3507 - val_dice_coef_infection: 0.7134 - val_iou_coef_infection: 0.6695 - val_precision_infection: 0.8392 - val_recall_infection: 0.7292 - val_hausdorff95_infection: 49.0744 - val_specificity_infection: 0.9977 - val_accuracy_infection: 0.9954 - val_f1_infection: 0.8711
# Epoch 33/100
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.3002 - dice_coef_infection: 0.7232 - iou_coef_infection: 0.5987 - precision_infection: 0.7580 - recall_infection: 0.7404 - hausdorff95_infection: 29.5701 - specificity_infection: 0.9981 - accuracy_infection: 0.9963 - f1_infection: 0.8506 - val_loss: 0.3696 - val_dice_coef_infection: 0.7227 - val_iou_coef_infection: 0.6789 - val_precision_infection: 0.8424 - val_recall_infection: 0.7269 - val_hausdorff95_infection: 49.9894 - val_specificity_infection: 0.9977 - val_accuracy_infection: 0.9951 - val_f1_infection: 0.8776
# Epoch 34/100
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 224s 196ms/step - loss: 0.2951 - dice_coef_infection: 0.7296 - iou_coef_infection: 0.6026 - precision_infection: 0.7563 - recall_infection: 0.7406 - hausdorff95_infection: 28.8869 - specificity_infection: 0.9981 - accuracy_infection: 0.9964 - f1_infection: 0.8551 - val_loss: 0.4221 - val_dice_coef_infection: 0.6751 - val_iou_coef_infection: 0.6300 - val_precision_infection: 0.7123 - val_recall_infection: 0.7778 - val_hausdorff95_infection: 57.8948 - val_specificity_infection: 0.9951 - val_accuracy_infection: 0.9934 - val_f1_infection: 0.8643
# Epoch 35/100
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.3098 - dice_coef_infection: 0.7176 - iou_coef_infection: 0.5882 - precision_infection: 0.7388 - recall_infection: 0.7387 - hausdorff95_infection: 35.9660 - specificity_infection: 0.9982 - accuracy_infection: 0.9964 - f1_infection: 0.8491 - val_loss: 0.3124 - val_dice_coef_infection: 0.7504 - val_iou_coef_infection: 0.7017 - val_precision_infection: 0.8803 - val_recall_infection: 0.7397 - val_hausdorff95_infection: 44.4650 - val_specificity_infection: 0.9982 - val_accuracy_infection: 0.9956 - val_f1_infection: 0.8789
# ✅ Model saved at epoch 35 with val_loss: 0.3124
# Epoch 36/100
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2958 - dice_coef_infection: 0.7286 - iou_coef_infection: 0.6003 - precision_infection: 0.7582 - recall_infection: 0.7472 - hausdorff95_infection: 27.5534 - specificity_infection: 0.9982 - accuracy_infection: 0.9964 - f1_infection: 0.8501 - val_loss: 0.3347 - val_dice_coef_infection: 0.7318 - val_iou_coef_infection: 0.6817 - val_precision_infection: 0.8293 - val_recall_infection: 0.7512 - val_hausdorff95_infection: 43.1065 - val_specificity_infection: 0.9977 - val_accuracy_infection: 0.9953 - val_f1_infection: 0.8752
# Epoch 37/100
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.3078 - dice_coef_infection: 0.7165 - iou_coef_infection: 0.5887 - precision_infection: 0.7485 - recall_infection: 0.7345 - hausdorff95_infection: 29.7565 - specificity_infection: 0.9982 - accuracy_infection: 0.9964 - f1_infection: 0.8471 - val_loss: 0.3709 - val_dice_coef_infection: 0.6852 - val_iou_coef_infection: 0.6387 - val_precision_infection: 0.7858 - val_recall_infection: 0.7440 - val_hausdorff95_infection: 50.1361 - val_specificity_infection: 0.9976 - val_accuracy_infection: 0.9956 - val_f1_infection: 0.8595
# Epoch 38/100
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2911 - dice_coef_infection: 0.7313 - iou_coef_infection: 0.6027 - precision_infection: 0.7500 - recall_infection: 0.7555 - hausdorff95_infection: 27.4623 - specificity_infection: 0.9982 - accuracy_infection: 0.9965 - f1_infection: 0.8513 - val_loss: 0.3761 - val_dice_coef_infection: 0.6836 - val_iou_coef_infection: 0.6354 - val_precision_infection: 0.7880 - val_recall_infection: 0.7398 - val_hausdorff95_infection: 49.3504 - val_specificity_infection: 0.9978 - val_accuracy_infection: 0.9957 - val_f1_infection: 0.8568
# Epoch 39/100
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2944 - dice_coef_infection: 0.7305 - iou_coef_infection: 0.6030 - precision_infection: 0.7726 - recall_infection: 0.7382 - hausdorff95_infection: 30.2323 - specificity_infection: 0.9982 - accuracy_infection: 0.9963 - f1_infection: 0.8504 - val_loss: 0.3799 - val_dice_coef_infection: 0.6850 - val_iou_coef_infection: 0.6389 - val_precision_infection: 0.8057 - val_recall_infection: 0.7202 - val_hausdorff95_infection: 51.1318 - val_specificity_infection: 0.9984 - val_accuracy_infection: 0.9955 - val_f1_infection: 0.8631
# Epoch 40/100
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.3014 - dice_coef_infection: 0.7223 - iou_coef_infection: 0.5963 - precision_infection: 0.7601 - recall_infection: 0.7397 - hausdorff95_infection: 29.6923 - specificity_infection: 0.9983 - accuracy_infection: 0.9966 - f1_infection: 0.8495 - val_loss: 0.3645 - val_dice_coef_infection: 0.6943 - val_iou_coef_infection: 0.6576 - val_precision_infection: 0.8574 - val_recall_infection: 0.7150 - val_hausdorff95_infection: 66.7013 - val_specificity_infection: 0.9977 - val_accuracy_infection: 0.9960 - val_f1_infection: 0.8610
# Epoch 41/100
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2869 - dice_coef_infection: 0.7356 - iou_coef_infection: 0.6074 - precision_infection: 0.7546 - recall_infection: 0.7552 - hausdorff95_infection: 27.9528 - specificity_infection: 0.9982 - accuracy_infection: 0.9965 - f1_infection: 0.8548 - val_loss: 0.3537 - val_dice_coef_infection: 0.7067 - val_iou_coef_infection: 0.6664 - val_precision_infection: 0.8706 - val_recall_infection: 0.7071 - val_hausdorff95_infection: 60.6856 - val_specificity_infection: 0.9985 - val_accuracy_infection: 0.9959 - val_f1_infection: 0.8653
# Epoch 42/100
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.3041 - dice_coef_infection: 0.7194 - iou_coef_infection: 0.5929 - precision_infection: 0.7568 - recall_infection: 0.7410 - hausdorff95_infection: 28.5918 - specificity_infection: 0.9982 - accuracy_infection: 0.9964 - f1_infection: 0.8467 - val_loss: 0.3341 - val_dice_coef_infection: 0.7225 - val_iou_coef_infection: 0.6772 - val_precision_infection: 0.8202 - val_recall_infection: 0.7428 - val_hausdorff95_infection: 43.3424 - val_specificity_infection: 0.9972 - val_accuracy_infection: 0.9954 - val_f1_infection: 0.8813
# Epoch 43/100
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2776 - dice_coef_infection: 0.7460 - iou_coef_infection: 0.6177 - precision_infection: 0.7784 - recall_infection: 0.7486 - hausdorff95_infection: 27.2647 - specificity_infection: 0.9984 - accuracy_infection: 0.9965 - f1_infection: 0.8573 - val_loss: 0.3370 - val_dice_coef_infection: 0.7323 - val_iou_coef_infection: 0.6819 - val_precision_infection: 0.8137 - val_recall_infection: 0.7474 - val_hausdorff95_infection: 37.7166 - val_specificity_infection: 0.9976 - val_accuracy_infection: 0.9950 - val_f1_infection: 0.8824
# Epoch 44/100
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2938 - dice_coef_infection: 0.7298 - iou_coef_infection: 0.6024 - precision_infection: 0.7705 - recall_infection: 0.7373 - hausdorff95_infection: 25.8451 - specificity_infection: 0.9983 - accuracy_infection: 0.9966 - f1_infection: 0.8507 - val_loss: 0.3326 - val_dice_coef_infection: 0.7297 - val_iou_coef_infection: 0.6815 - val_precision_infection: 0.7970 - val_recall_infection: 0.7717 - val_hausdorff95_infection: 44.3949 - val_specificity_infection: 0.9960 - val_accuracy_infection: 0.9948 - val_f1_infection: 0.8810
# Epoch 45/100
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2761 - dice_coef_infection: 0.7461 - iou_coef_infection: 0.6176 - precision_infection: 0.7672 - recall_infection: 0.7623 - hausdorff95_infection: 26.2905 - specificity_infection: 0.9981 - accuracy_infection: 0.9964 - f1_infection: 0.8557 - val_loss: 0.3501 - val_dice_coef_infection: 0.7079 - val_iou_coef_infection: 0.6616 - val_precision_infection: 0.8289 - val_recall_infection: 0.7285 - val_hausdorff95_infection: 47.5261 - val_specificity_infection: 0.9983 - val_accuracy_infection: 0.9958 - val_f1_infection: 0.8694
# Epoch 46/100
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2715 - dice_coef_infection: 0.7506 - iou_coef_infection: 0.6249 - precision_infection: 0.7752 - recall_infection: 0.7582 - hausdorff95_infection: 25.9903 - specificity_infection: 0.9983 - accuracy_infection: 0.9966 - f1_infection: 0.8615 - val_loss: 0.3454 - val_dice_coef_infection: 0.7123 - val_iou_coef_infection: 0.6654 - val_precision_infection: 0.8173 - val_recall_infection: 0.7506 - val_hausdorff95_infection: 44.0229 - val_specificity_infection: 0.9973 - val_accuracy_infection: 0.9957 - val_f1_infection: 0.8680
# Epoch 47/100
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2607 - dice_coef_infection: 0.7613 - iou_coef_infection: 0.6342 - precision_infection: 0.7769 - recall_infection: 0.7761 - hausdorff95_infection: 24.3409 - specificity_infection: 0.9981 - accuracy_infection: 0.9964 - f1_infection: 0.8627 - val_loss: 0.3555 - val_dice_coef_infection: 0.7014 - val_iou_coef_infection: 0.6625 - val_precision_infection: 0.8656 - val_recall_infection: 0.7096 - val_hausdorff95_infection: 63.0673 - val_specificity_infection: 0.9982 - val_accuracy_infection: 0.9961 - val_f1_infection: 0.8649
# Epoch 48/100
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2742 - dice_coef_infection: 0.7477 - iou_coef_infection: 0.6230 - precision_infection: 0.7744 - recall_infection: 0.7631 - hausdorff95_infection: 24.2421 - specificity_infection: 0.9983 - accuracy_infection: 0.9967 - f1_infection: 0.8587 - val_loss: 0.3433 - val_dice_coef_infection: 0.7286 - val_iou_coef_infection: 0.6848 - val_precision_infection: 0.8798 - val_recall_infection: 0.7154 - val_hausdorff95_infection: 53.0562 - val_specificity_infection: 0.9983 - val_accuracy_infection: 0.9957 - val_f1_infection: 0.8747
# Epoch 49/100
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 222s 195ms/step - loss: 0.2567 - dice_coef_infection: 0.7655 - iou_coef_infection: 0.6399 - precision_infection: 0.7804 - recall_infection: 0.7751 - hausdorff95_infection: 22.5237 - specificity_infection: 0.9981 - accuracy_infection: 0.9965 - f1_infection: 0.8680 - val_loss: 0.3610 - val_dice_coef_infection: 0.7071 - val_iou_coef_infection: 0.6662 - val_precision_infection: 0.8905 - val_recall_infection: 0.7017 - val_hausdorff95_infection: 62.4480 - val_specificity_infection: 0.9987 - val_accuracy_infection: 0.9955 - val_f1_infection: 0.8615
# Epoch 50/100
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2775 - dice_coef_infection: 0.7462 - iou_coef_infection: 0.6203 - precision_infection: 0.7773 - recall_infection: 0.7534 - hausdorff95_infection: 23.6352 - specificity_infection: 0.9983 - accuracy_infection: 0.9965 - f1_infection: 0.8601 - val_loss: 0.3574 - val_dice_coef_infection: 0.7038 - val_iou_coef_infection: 0.6604 - val_precision_infection: 0.8470 - val_recall_infection: 0.7180 - val_hausdorff95_infection: 51.5854 - val_specificity_infection: 0.9984 - val_accuracy_infection: 0.9956 - val_f1_infection: 0.8670
# Epoch 51/100
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2668 - dice_coef_infection: 0.7545 - iou_coef_infection: 0.6281 - precision_infection: 0.7771 - recall_infection: 0.7672 - hausdorff95_infection: 25.5329 - specificity_infection: 0.9983 - accuracy_infection: 0.9967 - f1_infection: 0.8600 - val_loss: 0.3326 - val_dice_coef_infection: 0.7278 - val_iou_coef_infection: 0.6849 - val_precision_infection: 0.8668 - val_recall_infection: 0.7259 - val_hausdorff95_infection: 51.5839 - val_specificity_infection: 0.9977 - val_accuracy_infection: 0.9954 - val_f1_infection: 0.8750
# Epoch 52/100
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2870 - dice_coef_infection: 0.7356 - iou_coef_infection: 0.6071 - precision_infection: 0.7671 - recall_infection: 0.7500 - hausdorff95_infection: 27.6411 - specificity_infection: 0.9983 - accuracy_infection: 0.9966 - f1_infection: 0.8526 - val_loss: 0.3469 - val_dice_coef_infection: 0.7249 - val_iou_coef_infection: 0.6794 - val_precision_infection: 0.8741 - val_recall_infection: 0.7136 - val_hausdorff95_infection: 48.8277 - val_specificity_infection: 0.9987 - val_accuracy_infection: 0.9953 - val_f1_infection: 0.8735
# Epoch 53/100
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2689 - dice_coef_infection: 0.7517 - iou_coef_infection: 0.6284 - precision_infection: 0.7818 - recall_infection: 0.7662 - hausdorff95_infection: 26.3247 - specificity_infection: 0.9984 - accuracy_infection: 0.9969 - f1_infection: 0.8602 - val_loss: 0.3223 - val_dice_coef_infection: 0.7387 - val_iou_coef_infection: 0.6935 - val_precision_infection: 0.8879 - val_recall_infection: 0.7272 - val_hausdorff95_infection: 50.6582 - val_specificity_infection: 0.9983 - val_accuracy_infection: 0.9959 - val_f1_infection: 0.8746
# Epoch 54/100
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 222s 195ms/step - loss: 0.2676 - dice_coef_infection: 0.7546 - iou_coef_infection: 0.6306 - precision_infection: 0.7808 - recall_infection: 0.7646 - hausdorff95_infection: 23.4110 - specificity_infection: 0.9984 - accuracy_infection: 0.9967 - f1_infection: 0.8619 - val_loss: 0.3313 - val_dice_coef_infection: 0.7275 - val_iou_coef_infection: 0.6815 - val_precision_infection: 0.8727 - val_recall_infection: 0.7192 - val_hausdorff95_infection: 49.5023 - val_specificity_infection: 0.9986 - val_accuracy_infection: 0.9957 - val_f1_infection: 0.8744
# Epoch 55/100
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2538 - dice_coef_infection: 0.7651 - iou_coef_infection: 0.6417 - precision_infection: 0.7845 - recall_infection: 0.7804 - hausdorff95_infection: 21.9095 - specificity_infection: 0.9983 - accuracy_infection: 0.9968 - f1_infection: 0.8648 - val_loss: 0.3329 - val_dice_coef_infection: 0.7221 - val_iou_coef_infection: 0.6769 - val_precision_infection: 0.8522 - val_recall_infection: 0.7277 - val_hausdorff95_infection: 49.1678 - val_specificity_infection: 0.9979 - val_accuracy_infection: 0.9958 - val_f1_infection: 0.8740
# 🛑 Early stopping at epoch 55
# ✅ Total training time: 12302.23 seconds (205.04 minutes)

# %% [markdown]
# ## Plotting the performance metrics

# %%
plt.plot(history.history['dice_coef_infection'])
plt.plot(history.history['val_dice_coef_infection'])
plt.title('dice_coef_infection vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Dice_coef')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# %%
plt.plot(history.history['iou_coef_infection'])
plt.plot(history.history['val_iou_coef_infection'])
plt.title('iou_coef_infection vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Iou_coef')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Val'], loc = 'upper right')
plt.show()

# %% [markdown]
# ## Using our trained model for prediction

# %%
import numpy as np
import time

# Start timer (high precision)
start_time = time.perf_counter()

# Evaluate the model on the validation generator
results = model.evaluate(val_gen, verbose=1)

# End timer
end_time = time.perf_counter()

# Calculate evaluation time
eval_time = end_time - start_time

# Print metric names with results
print("\n===== Validation Metrics =====")
for name, value in zip(model.metrics_names, results):
    print(f"{name}: {value:.6f}")

print(f"\nEvaluation Time: {eval_time:.8f} seconds\n")
# Out:
# 128/128 [==============================] - 9s 74ms/step - loss: 0.3081 - dice_coef_infection: 0.7389 - iou_coef_infection: 0.6886 - precision_infection: 0.8374 - recall_infection: 0.7955 - hausdorff95_infection: 39.2168 - specificity_infection: 0.9984 - accuracy_infection: 0.9963 - f1_infection: 0.8705
#
# ===== Validation Metrics =====
# loss: 0.308143
# dice_coef_infection: 0.738872
# iou_coef_infection: 0.688594
# precision_infection: 0.837423
# recall_infection: 0.795473
# hausdorff95_infection: 39.216846
# specificity_infection: 0.998374
# accuracy_infection: 0.996281
# f1_infection: 0.870459
#
# Evaluation Time: 9.49643859 seconds

# %%
import matplotlib.pyplot as plt
import numpy as np

# Run inference if not already done
predicted = model.predict(lung_test)

# Selected indices to visualize (744 as 1st, 280 as 2nd, 230 as 3rd)
selected_indices = [744, 280, 230]
n_samples = len(selected_indices)

# Mapping indices to custom names
name_mapping = {
    0: ("Image1_Covid", "GT1_Covid", "Predict1_Covid_DSEG_Unet"),  # Index 744
    1: ("Image2_Covid", "GT2_Covid", "Predict2_Covid_DSEG_Unet"),  # Index 280
    2: ("Image3_Covid", "GT3_Covid", "Predict3_Covid_DSEG_Unet")   # Index 230
}

# Plot
for j, i in enumerate(selected_indices):
    lung_img = lung_test[i][..., 0].astype(np.float32)
    gt_infect = (infect_test[i][..., 0] > 0.5).astype(np.float32)
    pred_infect = predicted[i][..., 0].astype(np.float32)

    # Normalize lung image
    if lung_img.max() > lung_img.min():
        lung_img = (lung_img - lung_img.min()) / (lung_img.max() - lung_img.min())
    lung_img = np.clip(lung_img, 0, 1)
    pred_infect = np.clip(pred_infect, 0, 1)

    # Get custom names for this index
    input_name, gt_name, pred_name = name_mapping[j]

    # Save Original Lung
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{input_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

    # Save Ground Truth Infection
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.imshow(gt_infect, cmap='Reds', alpha=0.6)
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{gt_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

    # Save Predicted Infection
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.imshow(pred_infect, cmap='Reds', alpha=0.6)
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{pred_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

print("Separate JPEG files saved for input images (Image1_Covid, Image2_Covid, Image3_Covid), "
      "ground truths (GT1_Covid, GT2_Covid, GT3_Covid), and predictions "
      "(Predict1_Covid_DSEG_Unet, Predict2_Covid_DSEG_Unet, Predict3_Covid_DSEG_Unet).")
# Out:
# Separate JPEG files saved for input images (Image1_Covid, Image2_Covid, Image3_Covid), ground truths (GT1_Covid, GT2_Covid, GT3_Covid), and predictions (Predict1_Covid_DSEG_Unet, Predict2_Covid_DSEG_Unet, Predict3_Covid_DSEG_Unet).
