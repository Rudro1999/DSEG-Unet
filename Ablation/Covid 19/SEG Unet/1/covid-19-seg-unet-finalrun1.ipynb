# %% [markdown]
# ## Importing important libraries

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import nibabel as nib #for loading nii files
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf #for deep learning

# %% [markdown]
# ## Reading the metadata

# %%
data = pd.read_csv('../input/covid19-ct-scans/metadata.csv')
data.head()
# Out:
#                                              ct_scan  \
# 0  ../input/covid19-ct-scans/ct_scans/coronacases...
# 1  ../input/covid19-ct-scans/ct_scans/coronacases...
# 2  ../input/covid19-ct-scans/ct_scans/coronacases...
# 3  ../input/covid19-ct-scans/ct_scans/coronacases...
# 4  ../input/covid19-ct-scans/ct_scans/coronacases...
#
#                                            lung_mask  \
# 0  ../input/covid19-ct-scans/lung_mask/coronacase...
# 1  ../input/covid19-ct-scans/lung_mask/coronacase...
# 2  ../input/covid19-ct-scans/lung_mask/coronacase...
# 3  ../input/covid19-ct-scans/lung_mask/coronacase...
# 4  ../input/covid19-ct-scans/lung_mask/coronacase...
#
#                                       infection_mask  \
# 0  ../input/covid19-ct-scans/infection_mask/coron...
# 1  ../input/covid19-ct-scans/infection_mask/coron...
# 2  ../input/covid19-ct-scans/infection_mask/coron...
# 3  ../input/covid19-ct-scans/infection_mask/coron...
# 4  ../input/covid19-ct-scans/infection_mask/coron...
#
#                              lung_and_infection_mask
# 0  ../input/covid19-ct-scans/lung_and_infection_m...
# 1  ../input/covid19-ct-scans/lung_and_infection_m...
# 2  ../input/covid19-ct-scans/lung_and_infection_m...
# 3  ../input/covid19-ct-scans/lung_and_infection_m...
# 4  ../input/covid19-ct-scans/lung_and_infection_m...

# %% [markdown]
# ## Defining function for readiing .nii files

# %%
def read_nii(filepath):
    '''
    Reads .nii file and returns pixel array
    '''
    ct_scan = nib.load(filepath)
    array   = ct_scan.get_fdata()
    array   = np.rot90(np.array(array))
    return(array)

# %% [markdown]
# ## Reading the chest ct scan data

# %%
# Read sample
sample_ct   = read_nii(data.loc[2,'ct_scan'])
sample_lung = read_nii(data.loc[2,'lung_mask'])
sample_infe = read_nii(data.loc[2,'infection_mask'])
sample_all  = read_nii(data.loc[2,'lung_and_infection_mask'])

# %% [markdown]
# ## Plotting the sample images

# %%
fig = plt.figure(figsize = (18,15))
plt.subplot(1,4,1)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.title('Original Image')

plt.subplot(1,4,2)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_lung[..., 150],alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung Mask')

plt.subplot(1,4,3)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_infe[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Infection Mask')

plt.subplot(1,4,4)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_all[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung and Infection Mask')
# Out:
# Text(0.5, 1.0, 'Lung and Infection Mask')

# %% [markdown]
# ## Converting the data into array for training model

# %%
import numpy as np
import cv2
import random
from scipy.ndimage import rotate, shift, zoom

lungs = []
infections = []
case_ids = []
img_size = 320

# ----------- Load and Resize Data -----------
for case_index in range(len(data)):
    ct = read_nii(data['ct_scan'][case_index])
    infect = read_nii(data['infection_mask'][case_index])

    for slice_index in range(ct.shape[0]):
        lung_img = cv2.resize(ct[slice_index], dsize=(img_size, img_size)).astype('float32')
        infec_img = cv2.resize(infect[slice_index], dsize=(img_size, img_size)).astype('float32')

        lungs.append(lung_img[..., np.newaxis])
        infections.append(infec_img[..., np.newaxis])
        case_ids.append(case_index)

# %%
import numpy as np

# case_ids should be a NumPy array telling which case each slice belongs to
# Convert and binarize
lungs = np.array(lungs, dtype=np.float32)
infections = (np.array(infections, dtype=np.uint8) > 0.5).astype(np.uint8)
case_ids = np.array(case_ids)

# %% [markdown]
# ## Performing test and train split

# %%
# ----------- Case-wise Split -----------
unique_cases = np.unique(case_ids)
train_cases = np.append(unique_cases[4:12], unique_cases[12:20])
temp_cases = unique_cases[2:4]
val_cases = unique_cases[:2]

train_mask = np.isin(case_ids, train_cases)
temp_mask = np.isin(case_ids, temp_cases)
val_mask = np.isin(case_ids, val_cases)

lung_train = lungs[train_mask]
infect_train = infections[train_mask]
lung_temp = lungs[temp_mask]
infect_temp = infections[temp_mask]
lung_test = lungs[val_mask]
infect_test = infections[val_mask]

print(f"✅ Train: {lung_train.shape[0]} slices from {len(train_cases)} cases")
print(f"✅ Validation: {lung_temp.shape[0]} slices from {len(temp_cases)} cases")
print(f"✅ Test: {lung_test.shape[0]} slices from {len(val_cases)} cases")

# ----------- Augmentation -----------
def augment_image(img, mask):
    if random.random() < 0.5:
        img = np.fliplr(img)
        mask = np.fliplr(mask)
    if random.random() < 0.5:
        img = np.flipud(img)
        mask = np.flipud(mask)

    angle = random.uniform(-15, 15)
    img = rotate(img, angle, reshape=False, order=1, mode='nearest')
    mask = rotate(mask, angle, reshape=False, order=0, mode='nearest')

    shift_val = np.random.uniform(-0.1, 0.1, size=2) * img.shape[:2]
    img = shift(img, shift=(*shift_val, 0), order=1, mode='nearest')
    mask = shift(mask, shift=(*shift_val, 0), order=0, mode='nearest')

    zoom_factor = random.uniform(0.9, 1.1)
    img = zoom(img, (zoom_factor, zoom_factor, 1), order=1)
    mask = zoom(mask, (zoom_factor, zoom_factor, 1), order=0)

    return fix_shape(img), fix_shape(mask)

def fix_shape(arr, target_size=(320, 320)):
    h, w, c = arr.shape
    th, tw = target_size
    dh = th - h
    dw = tw - w
    if dh > 0 or dw > 0:
        pad_h = (max(dh // 2, 0), max(dh - dh // 2, 0))
        pad_w = (max(dw // 2, 0), max(dw - dw // 2, 0))
        arr = np.pad(arr, (pad_h, pad_w, (0, 0)), mode='constant')
    arr = arr[:th, :tw, :]
    return arr.astype('float32')

# ----------- Apply Augmentation -----------
aug_lung_train = []
aug_infect_train = []

for i in range(len(lung_train)):
    img, mask = augment_image(lung_train[i], infect_train[i])
    aug_lung_train.append(img)
    aug_infect_train.append(mask)

lung_train = np.stack(aug_lung_train)
infect_train = np.stack(aug_infect_train)

# Final Binarization
infect_train = (infect_train > 0.5).astype(np.uint8)
infect_test = (infect_test > 0.5).astype(np.uint8)

print(f"✅ Augmented training shape: {lung_train.shape}")
print("✅ All preprocessing complete.")
# Out:
# ✅ Train: 9143 slices from 16 cases
# ✅ Validation: 1024 slices from 2 cases
# ✅ Test: 1024 slices from 2 cases
# ✅ Augmented training shape: (9143, 320, 320, 1)
# ✅ All preprocessing complete.

# %%
import tensorflow as tf
from tensorflow.keras import backend as K
import numpy as np
from scipy.spatial import cKDTree

smooth = 1.0

# Binary Dice coefficient (soft - commonly used during training)
def dice_coef_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# Binary IoU coefficient (soft)
def iou_coef_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# Soft Precision
def precision_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + smooth) / (K.sum(y_pred_f) + smooth)

# Soft Recall (Sensitivity)
def recall_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + smooth) / (K.sum(y_true_f) + smooth)

# Soft Specificity
def specificity_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    tn = K.sum((1 - y_true_f) * (1 - y_pred_f))
    fp = K.sum((1 - y_true_f) * y_pred_f)
    return (tn + smooth) / (tn + fp + smooth)

# Soft Accuracy
def accuracy_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    tp = K.sum(y_true_f * y_pred_f)
    tn = K.sum((1 - y_true_f) * (1 - y_pred_f))
    total = K.cast(K.shape(y_true_f)[0], 'float32')
    return (tp + tn + smooth) / (total + smooth)

# Soft F1-score (harmonic mean of precision & recall - very close to Dice, standard in many repos)
def f1_infection(y_true, y_pred):
    precision = precision_infection(y_true, y_pred)
    recall    = recall_infection(y_true, y_pred)
    return (2. * precision * recall + smooth) / (precision + recall + smooth)

# Hausdorff Distance 95 % (robust & most commonly used in medical imaging challenges)
# Lower = better. Returns the mean HD95 over the batch.
def _calculate_hd95(y_true, y_pred):
    hd_list = []
    for i in range(y_true.shape[0]):
        # Hard threshold at 0.5 (standard for evaluation metrics)
        gt = np.squeeze(y_true[i]) > 0.5
        pred = np.squeeze(y_pred[i]) > 0.5

        gt_pts = np.argwhere(gt)
        pred_pts = np.argwhere(pred)

        # Cases with empty masks
        if gt_pts.shape[0] == 0 and pred_pts.shape[0] == 0:
            hd_list.append(0.0)
            continue
        if gt_pts.shape[0] == 0 or pred_pts.shape[0] == 0:
            hd_list.append(400.0)  # large penalty - adjust to your image diagonal if needed (e.g. ~362 for 256×256, ~724 for 512×512)
            continue

        # Directed distances
        dist_gt_to_pred = cKDTree(pred_pts).query(gt_pts)[0]
        dist_pred_to_gt = cKDTree(gt_pts).query(pred_pts)[0]

        hd95 = max(
            np.percentile(dist_gt_to_pred, 95),
            np.percentile(dist_pred_to_gt, 95)
        )
        hd_list.append(hd95)

    return np.mean(hd_list, dtype=np.float32)

def hausdorff95_infection(y_true, y_pred):
    hd = tf.numpy_function(_calculate_hd95, [y_true, y_pred], tf.float32)
    hd.set_shape(())
    return hd

# Optional: KL Divergence (you already had this)
kld = tf.keras.losses.KLDivergence()

# %%
from tensorflow.keras.losses import BinaryCrossentropy

def loss_f(y_true, y_pred):
    bce = BinaryCrossentropy()
    return dice_loss(y_true, y_pred) + bce(y_true, y_pred) 

def loss_e(y_true, y_pred):
    bce = BinaryCrossentropy()
    return dice_loss(y_true, y_pred)  + kld(y_true, y_pred)
    
def dice_loss(y_true, y_pred):
    return 1. - dice_coef_infection(y_true, y_pred)

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Multiply, Conv2D, DepthwiseConv2D, Dense, Flatten, MaxPooling2D, UpSampling2D, concatenate, Activation, LayerNormalization, Add, Dropout, Conv2DTranspose, multiply, Reshape, GlobalAveragePooling2D, Permute, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Concatenate

def activation_block(x):
    x = Activation("gelu")(x)
    return LayerNormalization()(x)

def conv_stem(x, filters: int, patch_size: int):
    x = Conv2D(filters, kernel_size=patch_size,padding='same', strides=patch_size)(x)
    return activation_block(x)

def vector_block(xyz, cmf, red):
    # red means reduction
    # cmf means filters, denotes vector size
    opt1 = conv_stem(xyz, cmf, red)
    opt2 = conv_stem(xyz, cmf, red)
    
    o1 = GlobalAveragePooling2D()(opt1)
    o2 = GlobalAveragePooling2D()(opt2)

    o5 = concatenate([o1, o2], -1)
    return o5

def mlp_feature(vect, cmf):
    oo = Flatten()(vect)
    o6 = Dense(cmf, activation='gelu')(oo)
    o6 = Dropout(0.2)(o6)
    o6 = Dense(cmf * 2, activation='gelu')(o6)

    o6 = Reshape((1, cmf * 2))(o6)
    o7 = Permute((2, 1))(o6)

    o8 = multiply([o6, o7])
    
    o8 = Lambda(lambda x: tf.expand_dims(x, -1))(o8)
    
    o8 = Reshape((cmf, cmf, 4))(o8)

    return o8

def frz_block(xyz):
    shape = xyz.shape
    a1, a2, a3, a4 = shape[0], shape[1], shape[2], shape[3]
    cmf = a2
    o5 = vector_block(xyz, cmf, 5)
    o7 = mlp_feature(o5, cmf)

    o7 = concatenate([o7, xyz, o7], -1)
    return o7

def up_frz(x1, x2, n_filters):
    # Upsample x1 using Conv2DTranspose
    x1 = Conv2DTranspose(n_filters * 4, 3, strides=2, activation='gelu', padding="same")(x1)
    
    # Apply Conv2D to x2
    x2 = Conv2D(n_filters * 2, 3, activation='gelu', padding="same")(x2)
    
    # Apply attention mechanism
    x = concatenate([x1, x2])
    
    # Apply Dropout for regularization
    x = Dropout(0.3)(x)
    
    return x

def regu(xyz, filt):
    x = Conv2D(filt, (3, 3), activation='gelu', padding="same")(xyz)
    return x

# %%
def squeeze_and_excite_block(inputs, ratio=24):
    """ Squeeze and Excitation block to recalibrate channel-wise features """
    filters = inputs.shape[-1]  # Number of input channels
    se_shape = (1, 1, filters)

    # Squeeze: Global Average Pooling
    se = GlobalAveragePooling2D()(inputs)
    se = Reshape(se_shape)(se)

    a = filters // ratio

    # Excitation: Dense layers to capture channel-wise dependencies
    if a > 8:
        se = Conv2D(filters // ratio, kernel_size=1, activation='swish', padding='same')(se)
        se = Conv2D(filters, kernel_size=1, activation='sigmoid', padding='same')(se)
    else:
        se = Conv2D(8, kernel_size=1, activation='swish', padding='same')(se)
        se = Conv2D(filters, kernel_size=1, activation='sigmoid', padding='same')(se)

    # Scale the input by channel-wise weights
    x = multiply([inputs, se])

    return x

def residual_block(x, filters, stride=1, padding='same'):
    shortcut = x
    x = Conv2D(filters * 6, 1, strides=stride, padding=padding, use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)
    x = DepthwiseConv2D(kernel_size=3, strides=stride, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)
    x = squeeze_and_excite_block(x)
    x = Conv2D(filters, 1, strides=stride, padding=padding, use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)
    x = Add()([x, shortcut])
    return x

def dense_block(inputs, num_layers, growth_rate, ratio=16):
    """Dense block where each layer is connected to all previous layers."""
    concat_features = inputs
    for i in range(num_layers):
        # BatchNorm -> ReLU -> Conv2D
        x = Conv2D(growth_rate, 3, activation='gelu', padding='same')(concat_features)

        # Concatenate input with new output (dense connection)
        concat_features = Concatenate()([concat_features, x])
        
    x = squeeze_and_excite_block(concat_features)

    return x

def attention_gate(X, g, channel,  
                   activation='ReLU', 
                   attention='add', name='att'):
    '''
    Self-attention gate modified from Oktay et al. 2018.
    
    attention_gate(X, g, channel,  activation='ReLU', attention='add', name='att')
    
    Input
    ----------
        X: input tensor, i.e., key and value.
        g: gated tensor, i.e., query.
        channel: number of intermediate channel.
                 Oktay et al. (2018) did not specify (denoted as F_int).
                 intermediate channel is expected to be smaller than the input channel.
        activation: a nonlinear attnetion activation.
                    The `sigma_1` in Oktay et al. 2018. Default is 'ReLU'.
        attention: 'add' for additive attention; 'multiply' for multiplicative attention.
                   Oktay et al. 2018 applied additive attention.
        name: prefix of the created keras layers.
        
    Output
    ----------
        X_att: output tensor.
    
    '''

    attention_func = eval(attention)
    
    # mapping the input tensor to the intermediate channel
    theta_att = Conv2D(channel, 1, use_bias=True)(X)
    
    # mapping the gate tensor
    phi_g = Conv2D(channel, 1, use_bias=True)(g)
    
    # ----- attention learning ----- #
    query = attention_func([theta_att, phi_g])
    
    # nonlinear activation
    f = Activation('gelu')(query)
    
    # linear transformation
    psi_f = Conv2D(1, 1, use_bias=True)(f)
    # ------------------------------ #
    
    # sigmoid activation as attention coefficients
    coef_att = Activation('sigmoid')(psi_f)
    
    # multiplicative attention masking
    X_att = multiply([X, coef_att])
    
    return X_att

inputs = (img_size, img_size, 1)

def model_build_func(input_shape, n_labels):
    inputs = Input(shape=input_shape, name='input_image')
    g_filter = 16
    u_filter = 8

    # Initial convolution
    initial = Conv2D(g_filter, (3, 3), activation='gelu', padding="same")(inputs)
    initial = regu(initial, g_filter * 2)  # 80

    # Down-sampling path
    o1 = MaxPooling2D(2)(initial)
    o1 = o1 = frz_block(regu(o1, g_filter * 4))  # 40
    #o1 = squeeze_and_excite_block(o1)

    o2 = MaxPooling2D(2)(o1)
    o2 = frz_block(regu(o2, g_filter * 8))  # 20
    #o2 = squeeze_and_excite_block(o2)

    o3 = MaxPooling2D(2)(o2)
    o3 = frz_block(regu(o3, g_filter * 16))  # 10
    #o3 = squeeze_and_excite_block(o3)

    o4 = MaxPooling2D(2)(o3)
    o4 = frz_block(regu(o4, g_filter * 32))  # 5
    #o4 = squeeze_and_excite_block(o4)

    o5 = MaxPooling2D(2)(o4)
    o5 = frz_block(regu(o5, g_filter * 64))  # 5
    #o5 = squeeze_and_excite_block(o5)

    # Up-sampling path
    u1 = up_frz(o5, o4, u_filter * 16)  # 10
    #gate1 = attention_gate(o4, u1, u_filter * 16, attention='add')
    cu1 = concatenate([u1, o4])

    u2 = up_frz(cu1, o3, u_filter * 8)  # 20
    #gate2 = attention_gate(o3, u2, u_filter * 8, attention='add')
    cu2 = concatenate([u2, o3])  # 20

    u3 = up_frz(cu2, o2, u_filter * 4)  # 40
    #gate3 = attention_gate(o2, u3, u_filter * 4, attention='add')
    cu3 = concatenate([u3, o2])  # 40

    u4 = up_frz(cu3, o1, u_filter * 2)  # 80
    #gate4 = attention_gate(o1, u4, u_filter * 2, attention='add')
    cu4 = concatenate([u4, o1])  # 80

    u5 = Conv2DTranspose(u_filter * 4, 3, strides=2, activation='gelu', padding="same")(cu4)  # 80
    #gate5 = attention_gate(initial, u5, u_filter, attention='add')
    cu5 = concatenate([u5, initial])  # 80

    # Final segmentation map
    seg_map = Conv2D(n_labels, 3, activation='sigmoid', padding="same")(cu5)

    # Model definition
    model = Model(inputs=inputs, outputs=seg_map)

    return model


model = model_build_func(inputs, 1)

from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2_as_graph

def get_flops(model):
    """Calculate Floating Point Operations (FLOPs) of a Keras model in TensorFlow 2.x."""
    # Convert Keras model to a TensorFlow function
    concrete_func = tf.function(lambda inputs: model(inputs))
    concrete_func = concrete_func.get_concrete_function(
        tf.TensorSpec([1] + list(model.input_shape[1:]), model.input.dtype)
    )

    # Convert to frozen graph
    frozen_func, _ = convert_variables_to_constants_v2_as_graph(concrete_func)

    # Compute FLOPs
    flops = tf.compat.v1.profiler.profile(
        frozen_func.graph,
        options=tf.compat.v1.profiler.ProfileOptionBuilder.float_operation(),
    )

    return flops.total_float_ops

# Compute FLOPs
flops = get_flops(model)
print(f"Total FLOPs: {flops / 1e9:.2f} GFLOPs")  # Convert to GFLOPs

from tensorflow.keras.optimizers import Adam

optimizer = Adam(learning_rate=1e-3)
model.compile(optimizer=optimizer, loss=loss_f, metrics=[dice_coef_infection, iou_coef_infection, precision_infection, recall_infection, hausdorff95_infection, specificity_infection, accuracy_infection, f1_infection])

# Model summary
model.summary()
# Out:
# Total FLOPs: 22.11 GFLOPs
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_image (InputLayer)        [(None, 320, 320, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 320, 320, 16) 160         input_image[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 320, 320, 32) 4640        conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 160, 160, 32) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 160, 160, 64) 18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 160)  256160      conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 160)  256160      conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 160)  0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 160)  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# layer_normalization (LayerNorma (None, 32, 32, 160)  320         activation[0][0]
# __________________________________________________________________________________________________
# layer_normalization_1 (LayerNor (None, 32, 32, 160)  320         activation_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 160)          0           layer_normalization[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 160)          0           layer_normalization_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 320)          0           global_average_pooling2d[0][0]
#                                                                  global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 320)          0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 160)          51360       flatten[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 160)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 320)          51520       dropout[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 320)       0           dense_1[0][0]
# __________________________________________________________________________________________________
# permute (Permute)               (None, 320, 1)       0           reshape[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 320, 320)     0           reshape[0][0]
#                                                                  permute[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 320, 320, 1)  0           multiply[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 160, 160, 4)  0           lambda[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 160, 160, 72) 0           reshape_1[0][0]
#                                                                  conv2d_2[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 80, 80, 72)   0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 80, 80, 128)  83072       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 80)   256080      conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 80)   256080      conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 16, 16, 80)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 16, 16, 80)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# layer_normalization_2 (LayerNor (None, 16, 16, 80)   160         activation_2[0][0]
# __________________________________________________________________________________________________
# layer_normalization_3 (LayerNor (None, 16, 16, 80)   160         activation_3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 80)           0           layer_normalization_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 80)           0           layer_normalization_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 160)          0           global_average_pooling2d_2[0][0]
#                                                                  global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 160)          0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 80)           12880       flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 80)           0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 160)          12960       dropout_1[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 160)       0           dense_3[0][0]
# __________________________________________________________________________________________________
# permute_1 (Permute)             (None, 160, 1)       0           reshape_2[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 160, 160)     0           reshape_2[0][0]
#                                                                  permute_1[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 160, 160, 1)  0           multiply_1[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 80, 80, 4)    0           lambda_1[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 80, 80, 136)  0           reshape_3[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  reshape_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 40, 40, 136)  0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 40, 40, 256)  313600      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 40)     256040      conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 40)     256040      conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 8, 8, 40)     0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 8, 8, 40)     0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# layer_normalization_4 (LayerNor (None, 8, 8, 40)     80          activation_4[0][0]
# __________________________________________________________________________________________________
# layer_normalization_5 (LayerNor (None, 8, 8, 40)     80          activation_5[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 40)           0           layer_normalization_4[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 40)           0           layer_normalization_5[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 80)           0           global_average_pooling2d_4[0][0]
#                                                                  global_average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 80)           0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 40)           3240        flatten_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 40)           0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 80)           3280        dropout_2[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1, 80)        0           dense_5[0][0]
# __________________________________________________________________________________________________
# permute_2 (Permute)             (None, 80, 1)        0           reshape_4[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 80, 80)       0           reshape_4[0][0]
#                                                                  permute_2[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 80, 80, 1)    0           multiply_2[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 40, 40, 4)    0           lambda_2[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 40, 40, 264)  0           reshape_5[0][0]
#                                                                  conv2d_8[0][0]
#                                                                  reshape_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 20, 20, 264)  0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 20, 20, 512)  1217024     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 4, 4, 20)     256020      conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 4, 4, 20)     256020      conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 4, 4, 20)     0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 4, 4, 20)     0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# layer_normalization_6 (LayerNor (None, 4, 4, 20)     40          activation_6[0][0]
# __________________________________________________________________________________________________
# layer_normalization_7 (LayerNor (None, 4, 4, 20)     40          activation_7[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 20)           0           layer_normalization_6[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 20)           0           layer_normalization_7[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 40)           0           global_average_pooling2d_6[0][0]
#                                                                  global_average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 40)           0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 20)           820         flatten_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 20)           0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 40)           840         dropout_3[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 1, 40)        0           dense_7[0][0]
# __________________________________________________________________________________________________
# permute_3 (Permute)             (None, 40, 1)        0           reshape_6[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 40, 40)       0           reshape_6[0][0]
#                                                                  permute_3[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 40, 40, 1)    0           multiply_3[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 20, 20, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 20, 20, 520)  0           reshape_7[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  reshape_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 10, 10, 520)  0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 10, 10, 1024) 4793344     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 2, 2, 10)     256010      conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 2, 2, 10)     256010      conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 2, 2, 10)     0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 2, 2, 10)     0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# layer_normalization_8 (LayerNor (None, 2, 2, 10)     20          activation_8[0][0]
# __________________________________________________________________________________________________
# layer_normalization_9 (LayerNor (None, 2, 2, 10)     20          activation_9[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_8 (Glo (None, 10)           0           layer_normalization_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_9 (Glo (None, 10)           0           layer_normalization_9[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 20)           0           global_average_pooling2d_8[0][0]
#                                                                  global_average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 20)           0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 10)           210         flatten_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 10)           0           dense_8[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 20)           220         dropout_4[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 1, 20)        0           dense_9[0][0]
# __________________________________________________________________________________________________
# permute_4 (Permute)             (None, 20, 1)        0           reshape_8[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 20, 20)       0           reshape_8[0][0]
#                                                                  permute_4[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 20, 20, 1)    0           multiply_4[0][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 10, 10, 4)    0           lambda_4[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 10, 10, 1032) 0           reshape_9[0][0]
#                                                                  conv2d_14[0][0]
#                                                                  reshape_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 20, 20, 512)  4755968     concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 20, 20, 256)  1198336     concatenate_7[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 20, 20, 768)  0           conv2d_transpose[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 20, 20, 768)  0           concatenate_10[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 20, 20, 1288) 0           dropout_5[0][0]
#                                                                  concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 40, 40, 256)  2967808     concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 40, 40, 128)  304256      concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 40, 40, 384)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 40, 40, 384)  0           concatenate_12[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 40, 40, 648)  0           dropout_6[0][0]
#                                                                  concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 80, 80, 128)  746624      concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 80, 80, 64)   78400       concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 80, 80, 192)  0           conv2d_transpose_2[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 80, 80, 192)  0           concatenate_14[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 80, 80, 328)  0           dropout_7[0][0]
#                                                                  concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 160, 160, 64) 188992      concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 160, 160, 32) 20768       concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 160, 160, 96) 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 160, 160, 96) 0           concatenate_16[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 160, 160, 168 0           dropout_8[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 320, 320, 32) 48416       concatenate_17[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 320, 320, 64) 0           conv2d_transpose_4[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 320, 320, 1)  577         concatenate_18[0][0]
# ==================================================================================================
# Total params: 19,439,671
# Trainable params: 19,439,671
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Install required packages
# !pip install openpyxl

# Imports
import openpyxl  # required for reading .xlsx files
import pandas as pd
import tensorflow as tf
import os
import shutil
from tensorflow.keras.callbacks import LearningRateScheduler, ReduceLROnPlateau

# File paths
checkpoint_filepath = '/kaggle/working/checkpoint.h5.keras'
metrics_file = '/kaggle/working/training_metrics.xlsx'
pre_checkpoint_filepath = '/kaggle/input/dseg-unet-4channel-covid19/checkpoint.h5.keras'
pre_metrics_file = '/kaggle/input/dseg-unet-4channel-covid19/training_metrics.xlsx'

# Restore checkpoint and metrics if available
if os.path.exists(pre_checkpoint_filepath):
    shutil.copy(pre_checkpoint_filepath, checkpoint_filepath)
    print(f"Restored checkpoint from: {pre_checkpoint_filepath}")

if os.path.exists(pre_metrics_file):
    shutil.copy(pre_metrics_file, metrics_file)
    print(f"Restored metrics file from: {pre_metrics_file}")

# Load last epoch
def load_last_epoch():
    if os.path.exists(metrics_file):
        try:
            df = pd.read_excel(metrics_file, engine='openpyxl')
            if not df.empty and 'epoch' in df.columns:
                return df['epoch'].iloc[-1] + 1
        except Exception as e:
            print(f"⚠️ Could not read metrics file: {e}")
    return 0

last_epoch = load_last_epoch()

# Get best validation loss from previous runs
def get_best_val_loss():
    if os.path.exists(metrics_file):
        try:
            df = pd.read_excel(metrics_file, engine='openpyxl')
            if 'val_loss' in df.columns and not df['val_loss'].isnull().all():
                return df['val_loss'].min()
        except Exception as e:
            print(f"⚠️ Could not read val_loss from metrics file: {e}")
    return float('inf')

best_val_loss = get_best_val_loss()

# Custom model checkpoint
class CustomModelCheckpoint(tf.keras.callbacks.Callback):
    def __init__(self, filepath):
        super().__init__()
        self.filepath = filepath
        self.best_loss = best_val_loss

    def on_epoch_end(self, epoch, logs=None):
        current_loss = logs.get('val_loss')
        if current_loss is not None and current_loss < self.best_loss:
            self.best_loss = current_loss
            self.model.save(self.filepath)
            print(f"✅ Model saved at epoch {epoch + 1} with val_loss: {current_loss:.4f}")

# === Learning Rate Schedule ===
def lr_schedule(epoch, lr):
    return 1e-4 if epoch >= 5 else lr

lr_scheduler = LearningRateScheduler(lr_schedule, verbose=1)

# Logger for Excel
class MetricsLogger(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        df_new = pd.DataFrame([{**logs, 'epoch': epoch}])
        try:
            if os.path.exists(metrics_file):
                df = pd.read_excel(metrics_file, engine='openpyxl')
                df = pd.concat([df, df_new], ignore_index=True)
            else:
                df = df_new
            df.to_excel(metrics_file, index=False, engine='openpyxl')
        except Exception as e:
            print(f"⚠️ Failed to log metrics: {e}")

# Early stopping with patience and saving best weights
class CustomEarlyStopping(tf.keras.callbacks.Callback):
    def __init__(self, patience=20):
        super().__init__()
        self.patience = patience
        self.wait = 0
        self.best_loss = best_val_loss

    def on_epoch_end(self, epoch, logs=None):
        current_loss = logs.get('val_loss')
        if current_loss is None:
            return
        if current_loss < self.best_loss:
            self.best_loss = current_loss
            self.wait = 0
            self.model.save_weights(checkpoint_filepath)
        else:
            self.wait += 1
            if self.wait >= self.patience:
                print(f"🛑 Early stopping at epoch {epoch + 1}")
                self.model.stop_training = True


# Final callbacks list
callbacks = [
    CustomModelCheckpoint(filepath=checkpoint_filepath),
    MetricsLogger(),
    lr_scheduler,
    CustomEarlyStopping(patience=20)
]
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.3-py2.py3-none-any.whl (251 kB)
#      |████████████████████████████████| 251 kB 5.2 MB/s eta 0:00:01
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.3

# %% [markdown]
# ## Training the model

# %%
import time
import os
import pandas as pd
import numpy as np
from tensorflow.keras.utils import Sequence
from tensorflow.keras.models import load_model

EPOCHS = 100

# Record the start time
start_time = time.time()

# === Load last completed epoch from metrics file ===
def load_last_epoch():
    if os.path.exists(pre_metrics_file):
        try:
            df = pd.read_excel(pre_metrics_file, engine='openpyxl')
            if not df.empty and 'epoch' in df.columns:
                return int(df['epoch'].iloc[-1]) + 1
        except Exception as e:
            print(f"⚠️ Failed to read metrics file: {e}")
    return 0

last_epoch = load_last_epoch()

# === Load pretrained weights if available ===
if os.path.exists(pre_checkpoint_filepath):
    print("✅ Checkpoint found. Loading pretrained weights...")
    model.load_weights(pre_checkpoint_filepath)
    print(f"🔁 Resuming training from epoch {last_epoch}")
else:
    print("🆕 No checkpoint found. Starting training from scratch.")
    last_epoch = 0

# === Prepare input and label tensors ===
lung_train = np.asarray(lung_train, dtype=np.float16)
infect_train = np.asarray(infect_train, dtype=np.uint8)

lung_temp = np.asarray(lung_temp, dtype=np.float16)
infect_temp = np.asarray(infect_temp, dtype=np.uint8)

lung_test = np.asarray(lung_test, dtype=np.float16)
infect_test = np.asarray(infect_test, dtype=np.uint8)

# === Data Generator ===
class LungDataGenerator(Sequence):
    def __init__(self, X, Y, batch_size=8, shuffle=True):
        self.X = X
        self.Y = Y
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indices = np.arange(len(X))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.X) / self.batch_size))

    def __getitem__(self, index):
        batch_ids = self.indices[index * self.batch_size:(index + 1) * self.batch_size]
        X_batch = self.X[batch_ids]
        Y_batch = self.Y[batch_ids]
        return np.asarray(X_batch, dtype=np.float16), np.asarray(Y_batch, dtype=np.uint8)

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indices)

# === Create generators ===
train_gen = LungDataGenerator(lung_train, infect_train, batch_size=8)
temp_gen = LungDataGenerator(lung_temp, infect_temp, batch_size=8, shuffle=False)
val_gen = LungDataGenerator(lung_test, infect_test, batch_size=8, shuffle=False)

# === Train the model ===
history = model.fit(
    train_gen,
    validation_data=temp_gen,
    epochs=EPOCHS,
    initial_epoch=last_epoch,
    callbacks=callbacks
)

# === Timing info ===
end_time = time.time()
total_time = end_time - start_time
print(f"✅ Total training time: {total_time:.2f} seconds ({total_time / 60:.2f} minutes)")
# Out:
# 🆕 No checkpoint found. Starting training from scratch.
# Epoch 1/100
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 242s 200ms/step - loss: 1.1226 - dice_coef_infection: 0.0871 - iou_coef_infection: 0.0504 - precision_infection: 0.0953 - recall_infection: 0.1743 - hausdorff95_infection: 229.2891 - specificity_infection: 0.9773 - accuracy_infection: 0.9700 - f1_infection: 0.8570 - val_loss: 1.6311 - val_dice_coef_infection: 0.0798 - val_iou_coef_infection: 0.0584 - val_precision_infection: 0.0657 - val_recall_infection: 0.8962 - val_hausdorff95_infection: 284.3871 - val_specificity_infection: 0.9483 - val_accuracy_infection: 0.9475 - val_f1_infection: 0.5688
# ✅ Model saved at epoch 1 with val_loss: 1.6311
# Epoch 2/100
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.7209 - dice_coef_infection: 0.3440 - iou_coef_infection: 0.2309 - precision_infection: 0.3778 - recall_infection: 0.4581 - hausdorff95_infection: 126.2163 - specificity_infection: 0.9927 - accuracy_infection: 0.9881 - f1_infection: 0.7496 - val_loss: 0.7263 - val_dice_coef_infection: 0.3566 - val_iou_coef_infection: 0.3174 - val_precision_infection: 0.4130 - val_recall_infection: 0.6825 - val_hausdorff95_infection: 124.9678 - val_specificity_infection: 0.9980 - val_accuracy_infection: 0.9935 - val_f1_infection: 0.7522
# ✅ Model saved at epoch 2 with val_loss: 0.7263
# Epoch 3/100
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.5503 - dice_coef_infection: 0.4928 - iou_coef_infection: 0.3589 - precision_infection: 0.5249 - recall_infection: 0.5790 - hausdorff95_infection: 86.7549 - specificity_infection: 0.9962 - accuracy_infection: 0.9931 - f1_infection: 0.7724 - val_loss: 0.5990 - val_dice_coef_infection: 0.4616 - val_iou_coef_infection: 0.4281 - val_precision_infection: 0.5167 - val_recall_infection: 0.6971 - val_hausdorff95_infection: 67.1852 - val_specificity_infection: 0.9974 - val_accuracy_infection: 0.9953 - val_f1_infection: 0.8075
# ✅ Model saved at epoch 3 with val_loss: 0.5990
# Epoch 4/100
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.6048 - dice_coef_infection: 0.4586 - iou_coef_infection: 0.3313 - precision_infection: 0.5049 - recall_infection: 0.5290 - hausdorff95_infection: 106.9515 - specificity_infection: 0.9958 - accuracy_infection: 0.9923 - f1_infection: 0.7769 - val_loss: 0.4948 - val_dice_coef_infection: 0.5865 - val_iou_coef_infection: 0.5564 - val_precision_infection: 0.7380 - val_recall_infection: 0.6751 - val_hausdorff95_infection: 96.2183 - val_specificity_infection: 0.9982 - val_accuracy_infection: 0.9953 - val_f1_infection: 0.8407
# ✅ Model saved at epoch 4 with val_loss: 0.4948
# Epoch 5/100
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.5047 - dice_coef_infection: 0.5368 - iou_coef_infection: 0.4015 - precision_infection: 0.5687 - recall_infection: 0.6102 - hausdorff95_infection: 76.4554 - specificity_infection: 0.9966 - accuracy_infection: 0.9938 - f1_infection: 0.7866 - val_loss: 0.4315 - val_dice_coef_infection: 0.6475 - val_iou_coef_infection: 0.6198 - val_precision_infection: 0.8331 - val_recall_infection: 0.6721 - val_hausdorff95_infection: 94.6961 - val_specificity_infection: 0.9985 - val_accuracy_infection: 0.9958 - val_f1_infection: 0.8576
# ✅ Model saved at epoch 5 with val_loss: 0.4315
# Epoch 6/100
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.3910 - dice_coef_infection: 0.6361 - iou_coef_infection: 0.5013 - precision_infection: 0.6615 - recall_infection: 0.6702 - hausdorff95_infection: 53.9070 - specificity_infection: 0.9979 - accuracy_infection: 0.9956 - f1_infection: 0.8231 - val_loss: 0.3707 - val_dice_coef_infection: 0.6829 - val_iou_coef_infection: 0.6393 - val_precision_infection: 0.7760 - val_recall_infection: 0.7335 - val_hausdorff95_infection: 56.8910 - val_specificity_infection: 0.9977 - val_accuracy_infection: 0.9958 - val_f1_infection: 0.8647
# ✅ Model saved at epoch 6 with val_loss: 0.3707
# Epoch 7/100
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.3592 - dice_coef_infection: 0.6674 - iou_coef_infection: 0.5360 - precision_infection: 0.6949 - recall_infection: 0.6970 - hausdorff95_infection: 45.0170 - specificity_infection: 0.9980 - accuracy_infection: 0.9959 - f1_infection: 0.8328 - val_loss: 0.3723 - val_dice_coef_infection: 0.6855 - val_iou_coef_infection: 0.6439 - val_precision_infection: 0.7952 - val_recall_infection: 0.7251 - val_hausdorff95_infection: 58.9906 - val_specificity_infection: 0.9978 - val_accuracy_infection: 0.9959 - val_f1_infection: 0.8635
# Epoch 8/100
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.3452 - dice_coef_infection: 0.6812 - iou_coef_infection: 0.5506 - precision_infection: 0.7106 - recall_infection: 0.7088 - hausdorff95_infection: 39.9660 - specificity_infection: 0.9980 - accuracy_infection: 0.9960 - f1_infection: 0.8351 - val_loss: 0.3796 - val_dice_coef_infection: 0.6821 - val_iou_coef_infection: 0.6397 - val_precision_infection: 0.8114 - val_recall_infection: 0.7210 - val_hausdorff95_infection: 60.8384 - val_specificity_infection: 0.9980 - val_accuracy_infection: 0.9955 - val_f1_infection: 0.8556
# Epoch 9/100
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.3353 - dice_coef_infection: 0.6905 - iou_coef_infection: 0.5600 - precision_infection: 0.7262 - recall_infection: 0.7122 - hausdorff95_infection: 38.9370 - specificity_infection: 0.9980 - accuracy_infection: 0.9960 - f1_infection: 0.8384 - val_loss: 0.3452 - val_dice_coef_infection: 0.7046 - val_iou_coef_infection: 0.6653 - val_precision_infection: 0.8632 - val_recall_infection: 0.7092 - val_hausdorff95_infection: 62.7190 - val_specificity_infection: 0.9984 - val_accuracy_infection: 0.9957 - val_f1_infection: 0.8653
# ✅ Model saved at epoch 9 with val_loss: 0.3452
# Epoch 10/100
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.3129 - dice_coef_infection: 0.7098 - iou_coef_infection: 0.5769 - precision_infection: 0.7346 - recall_infection: 0.7244 - hausdorff95_infection: 36.7459 - specificity_infection: 0.9982 - accuracy_infection: 0.9963 - f1_infection: 0.8464 - val_loss: 0.3620 - val_dice_coef_infection: 0.6992 - val_iou_coef_infection: 0.6595 - val_precision_infection: 0.8637 - val_recall_infection: 0.7139 - val_hausdorff95_infection: 65.1817 - val_specificity_infection: 0.9980 - val_accuracy_infection: 0.9958 - val_f1_infection: 0.8573
# Epoch 11/100
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.3157 - dice_coef_infection: 0.7093 - iou_coef_infection: 0.5797 - precision_infection: 0.7430 - recall_infection: 0.7293 - hausdorff95_infection: 34.5868 - specificity_infection: 0.9981 - accuracy_infection: 0.9962 - f1_infection: 0.8435 - val_loss: 0.3517 - val_dice_coef_infection: 0.7087 - val_iou_coef_infection: 0.6709 - val_precision_infection: 0.8731 - val_recall_infection: 0.7095 - val_hausdorff95_infection: 66.5070 - val_specificity_infection: 0.9981 - val_accuracy_infection: 0.9959 - val_f1_infection: 0.8647
# Epoch 12/100
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.3193 - dice_coef_infection: 0.7058 - iou_coef_infection: 0.5770 - precision_infection: 0.7403 - recall_infection: 0.7228 - hausdorff95_infection: 32.9592 - specificity_infection: 0.9981 - accuracy_infection: 0.9962 - f1_infection: 0.8434 - val_loss: 0.3493 - val_dice_coef_infection: 0.7095 - val_iou_coef_infection: 0.6667 - val_precision_infection: 0.8548 - val_recall_infection: 0.7197 - val_hausdorff95_infection: 62.8602 - val_specificity_infection: 0.9981 - val_accuracy_infection: 0.9956 - val_f1_infection: 0.8637
# Epoch 13/100
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.3176 - dice_coef_infection: 0.7056 - iou_coef_infection: 0.5752 - precision_infection: 0.7435 - recall_infection: 0.7210 - hausdorff95_infection: 32.6020 - specificity_infection: 0.9982 - accuracy_infection: 0.9964 - f1_infection: 0.8406 - val_loss: 0.3635 - val_dice_coef_infection: 0.6911 - val_iou_coef_infection: 0.6581 - val_precision_infection: 0.8706 - val_recall_infection: 0.6888 - val_hausdorff95_infection: 81.2354 - val_specificity_infection: 0.9981 - val_accuracy_infection: 0.9958 - val_f1_infection: 0.8634
# Epoch 14/100
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.3078 - dice_coef_infection: 0.7151 - iou_coef_infection: 0.5870 - precision_infection: 0.7437 - recall_infection: 0.7294 - hausdorff95_infection: 31.3804 - specificity_infection: 0.9982 - accuracy_infection: 0.9964 - f1_infection: 0.8491 - val_loss: 0.3403 - val_dice_coef_infection: 0.7174 - val_iou_coef_infection: 0.6795 - val_precision_infection: 0.8881 - val_recall_infection: 0.7107 - val_hausdorff95_infection: 69.2037 - val_specificity_infection: 0.9980 - val_accuracy_infection: 0.9958 - val_f1_infection: 0.8672
# ✅ Model saved at epoch 14 with val_loss: 0.3403
# Epoch 15/100
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.3071 - dice_coef_infection: 0.7150 - iou_coef_infection: 0.5886 - precision_infection: 0.7625 - recall_infection: 0.7162 - hausdorff95_infection: 30.6131 - specificity_infection: 0.9983 - accuracy_infection: 0.9966 - f1_infection: 0.8471 - val_loss: 0.3590 - val_dice_coef_infection: 0.7073 - val_iou_coef_infection: 0.6732 - val_precision_infection: 0.9132 - val_recall_infection: 0.6943 - val_hausdorff95_infection: 80.7915 - val_specificity_infection: 0.9982 - val_accuracy_infection: 0.9958 - val_f1_infection: 0.8593
# Epoch 16/100
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.3037 - dice_coef_infection: 0.7208 - iou_coef_infection: 0.5927 - precision_infection: 0.7580 - recall_infection: 0.7319 - hausdorff95_infection: 28.4758 - specificity_infection: 0.9981 - accuracy_infection: 0.9961 - f1_infection: 0.8481 - val_loss: 0.3691 - val_dice_coef_infection: 0.6935 - val_iou_coef_infection: 0.6614 - val_precision_infection: 0.9017 - val_recall_infection: 0.6963 - val_hausdorff95_infection: 79.8354 - val_specificity_infection: 0.9981 - val_accuracy_infection: 0.9960 - val_f1_infection: 0.8530
# Epoch 17/100
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2876 - dice_coef_infection: 0.7344 - iou_coef_infection: 0.6060 - precision_infection: 0.7633 - recall_infection: 0.7427 - hausdorff95_infection: 27.4477 - specificity_infection: 0.9982 - accuracy_infection: 0.9965 - f1_infection: 0.8532 - val_loss: 0.3741 - val_dice_coef_infection: 0.6830 - val_iou_coef_infection: 0.6377 - val_precision_infection: 0.8070 - val_recall_infection: 0.7210 - val_hausdorff95_infection: 58.7930 - val_specificity_infection: 0.9983 - val_accuracy_infection: 0.9953 - val_f1_infection: 0.8578
# Epoch 18/100
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2960 - dice_coef_infection: 0.7264 - iou_coef_infection: 0.6002 - precision_infection: 0.7576 - recall_infection: 0.7373 - hausdorff95_infection: 28.3269 - specificity_infection: 0.9982 - accuracy_infection: 0.9964 - f1_infection: 0.8529 - val_loss: 0.3435 - val_dice_coef_infection: 0.7159 - val_iou_coef_infection: 0.6790 - val_precision_infection: 0.8936 - val_recall_infection: 0.7082 - val_hausdorff95_infection: 70.9224 - val_specificity_infection: 0.9982 - val_accuracy_infection: 0.9960 - val_f1_infection: 0.8663
# Epoch 19/100
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2777 - dice_coef_infection: 0.7437 - iou_coef_infection: 0.6202 - precision_infection: 0.7733 - recall_infection: 0.7592 - hausdorff95_infection: 29.5380 - specificity_infection: 0.9983 - accuracy_infection: 0.9966 - f1_infection: 0.8568 - val_loss: 0.3249 - val_dice_coef_infection: 0.7342 - val_iou_coef_infection: 0.6931 - val_precision_infection: 0.8919 - val_recall_infection: 0.7186 - val_hausdorff95_infection: 62.8689 - val_specificity_infection: 0.9981 - val_accuracy_infection: 0.9960 - val_f1_infection: 0.8730
# ✅ Model saved at epoch 19 with val_loss: 0.3249
# Epoch 20/100
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2608 - dice_coef_infection: 0.7604 - iou_coef_infection: 0.6353 - precision_infection: 0.7795 - recall_infection: 0.7686 - hausdorff95_infection: 27.3224 - specificity_infection: 0.9982 - accuracy_infection: 0.9966 - f1_infection: 0.8634 - val_loss: 0.3350 - val_dice_coef_infection: 0.7194 - val_iou_coef_infection: 0.6803 - val_precision_infection: 0.9018 - val_recall_infection: 0.7065 - val_hausdorff95_infection: 67.0214 - val_specificity_infection: 0.9985 - val_accuracy_infection: 0.9960 - val_f1_infection: 0.8651
# Epoch 21/100
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2694 - dice_coef_infection: 0.7506 - iou_coef_infection: 0.6257 - precision_infection: 0.7726 - recall_infection: 0.7634 - hausdorff95_infection: 24.3856 - specificity_infection: 0.9982 - accuracy_infection: 0.9966 - f1_infection: 0.8604 - val_loss: 0.3236 - val_dice_coef_infection: 0.7284 - val_iou_coef_infection: 0.6878 - val_precision_infection: 0.8916 - val_recall_infection: 0.7153 - val_hausdorff95_infection: 61.9669 - val_specificity_infection: 0.9983 - val_accuracy_infection: 0.9961 - val_f1_infection: 0.8713
# ✅ Model saved at epoch 21 with val_loss: 0.3236
# Epoch 22/100
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2740 - dice_coef_infection: 0.7470 - iou_coef_infection: 0.6239 - precision_infection: 0.7715 - recall_infection: 0.7602 - hausdorff95_infection: 26.0310 - specificity_infection: 0.9982 - accuracy_infection: 0.9965 - f1_infection: 0.8606 - val_loss: 0.3368 - val_dice_coef_infection: 0.7189 - val_iou_coef_infection: 0.6805 - val_precision_infection: 0.9030 - val_recall_infection: 0.7063 - val_hausdorff95_infection: 67.7701 - val_specificity_infection: 0.9984 - val_accuracy_infection: 0.9961 - val_f1_infection: 0.8655
# Epoch 23/100
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2827 - dice_coef_infection: 0.7396 - iou_coef_infection: 0.6128 - precision_infection: 0.7681 - recall_infection: 0.7564 - hausdorff95_infection: 26.9381 - specificity_infection: 0.9981 - accuracy_infection: 0.9964 - f1_infection: 0.8538 - val_loss: 0.3454 - val_dice_coef_infection: 0.7121 - val_iou_coef_infection: 0.6780 - val_precision_infection: 0.9195 - val_recall_infection: 0.6947 - val_hausdorff95_infection: 74.4124 - val_specificity_infection: 0.9985 - val_accuracy_infection: 0.9962 - val_f1_infection: 0.8620
# Epoch 24/100
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2835 - dice_coef_infection: 0.7371 - iou_coef_infection: 0.6139 - precision_infection: 0.7722 - recall_infection: 0.7525 - hausdorff95_infection: 26.9983 - specificity_infection: 0.9983 - accuracy_infection: 0.9967 - f1_infection: 0.8542 - val_loss: 0.3207 - val_dice_coef_infection: 0.7348 - val_iou_coef_infection: 0.6884 - val_precision_infection: 0.8503 - val_recall_infection: 0.7357 - val_hausdorff95_infection: 53.2475 - val_specificity_infection: 0.9979 - val_accuracy_infection: 0.9957 - val_f1_infection: 0.8779
# ✅ Model saved at epoch 24 with val_loss: 0.3207
# Epoch 25/100
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2621 - dice_coef_infection: 0.7585 - iou_coef_infection: 0.6354 - precision_infection: 0.7805 - recall_infection: 0.7714 - hausdorff95_infection: 24.9701 - specificity_infection: 0.9982 - accuracy_infection: 0.9965 - f1_infection: 0.8638 - val_loss: 0.3126 - val_dice_coef_infection: 0.7378 - val_iou_coef_infection: 0.6929 - val_precision_infection: 0.8862 - val_recall_infection: 0.7278 - val_hausdorff95_infection: 57.7940 - val_specificity_infection: 0.9983 - val_accuracy_infection: 0.9960 - val_f1_infection: 0.8722
# ✅ Model saved at epoch 25 with val_loss: 0.3126
# Epoch 26/100
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2493 - dice_coef_infection: 0.7706 - iou_coef_infection: 0.6457 - precision_infection: 0.7850 - recall_infection: 0.7787 - hausdorff95_infection: 24.4465 - specificity_infection: 0.9983 - accuracy_infection: 0.9967 - f1_infection: 0.8692 - val_loss: 0.3287 - val_dice_coef_infection: 0.7274 - val_iou_coef_infection: 0.6854 - val_precision_infection: 0.8982 - val_recall_infection: 0.7126 - val_hausdorff95_infection: 61.2246 - val_specificity_infection: 0.9985 - val_accuracy_infection: 0.9960 - val_f1_infection: 0.8678
# Epoch 27/100
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2644 - dice_coef_infection: 0.7537 - iou_coef_infection: 0.6318 - precision_infection: 0.7781 - recall_infection: 0.7626 - hausdorff95_infection: 22.4058 - specificity_infection: 0.9983 - accuracy_infection: 0.9969 - f1_infection: 0.8643 - val_loss: 0.3392 - val_dice_coef_infection: 0.7176 - val_iou_coef_infection: 0.6775 - val_precision_infection: 0.8995 - val_recall_infection: 0.7030 - val_hausdorff95_infection: 64.6523 - val_specificity_infection: 0.9985 - val_accuracy_infection: 0.9960 - val_f1_infection: 0.8643
# Epoch 28/100
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2502 - dice_coef_infection: 0.7692 - iou_coef_infection: 0.6481 - precision_infection: 0.7898 - recall_infection: 0.7783 - hausdorff95_infection: 22.1970 - specificity_infection: 0.9983 - accuracy_infection: 0.9967 - f1_infection: 0.8688 - val_loss: 0.3683 - val_dice_coef_infection: 0.6983 - val_iou_coef_infection: 0.6644 - val_precision_infection: 0.8823 - val_recall_infection: 0.7023 - val_hausdorff95_infection: 75.6026 - val_specificity_infection: 0.9980 - val_accuracy_infection: 0.9959 - val_f1_infection: 0.8593
# Epoch 29/100
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2517 - dice_coef_infection: 0.7664 - iou_coef_infection: 0.6420 - precision_infection: 0.7762 - recall_infection: 0.7784 - hausdorff95_infection: 22.0698 - specificity_infection: 0.9983 - accuracy_infection: 0.9969 - f1_infection: 0.8679 - val_loss: 0.3520 - val_dice_coef_infection: 0.7115 - val_iou_coef_infection: 0.6731 - val_precision_infection: 0.8851 - val_recall_infection: 0.7008 - val_hausdorff95_infection: 67.6867 - val_specificity_infection: 0.9986 - val_accuracy_infection: 0.9959 - val_f1_infection: 0.8671
# Epoch 30/100
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2485 - dice_coef_infection: 0.7710 - iou_coef_infection: 0.6507 - precision_infection: 0.7923 - recall_infection: 0.7769 - hausdorff95_infection: 22.4144 - specificity_infection: 0.9982 - accuracy_infection: 0.9967 - f1_infection: 0.8712 - val_loss: 0.3465 - val_dice_coef_infection: 0.7111 - val_iou_coef_infection: 0.6711 - val_precision_infection: 0.8834 - val_recall_infection: 0.7056 - val_hausdorff95_infection: 64.6145 - val_specificity_infection: 0.9986 - val_accuracy_infection: 0.9961 - val_f1_infection: 0.8634
# Epoch 31/100
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2435 - dice_coef_infection: 0.7740 - iou_coef_infection: 0.6526 - precision_infection: 0.7917 - recall_infection: 0.7812 - hausdorff95_infection: 21.3496 - specificity_infection: 0.9983 - accuracy_infection: 0.9969 - f1_infection: 0.8714 - val_loss: 0.3658 - val_dice_coef_infection: 0.7081 - val_iou_coef_infection: 0.6715 - val_precision_infection: 0.8893 - val_recall_infection: 0.6960 - val_hausdorff95_infection: 70.1928 - val_specificity_infection: 0.9986 - val_accuracy_infection: 0.9959 - val_f1_infection: 0.8682
# Epoch 32/100
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2659 - dice_coef_infection: 0.7548 - iou_coef_infection: 0.6331 - precision_infection: 0.7848 - recall_infection: 0.7651 - hausdorff95_infection: 22.8600 - specificity_infection: 0.9982 - accuracy_infection: 0.9966 - f1_infection: 0.8623 - val_loss: 0.3720 - val_dice_coef_infection: 0.6938 - val_iou_coef_infection: 0.6648 - val_precision_infection: 0.9194 - val_recall_infection: 0.6873 - val_hausdorff95_infection: 85.7412 - val_specificity_infection: 0.9983 - val_accuracy_infection: 0.9961 - val_f1_infection: 0.8529
# Epoch 33/100
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2262 - dice_coef_infection: 0.7913 - iou_coef_infection: 0.6737 - precision_infection: 0.8103 - recall_infection: 0.7980 - hausdorff95_infection: 20.1782 - specificity_infection: 0.9984 - accuracy_infection: 0.9970 - f1_infection: 0.8773 - val_loss: 0.3439 - val_dice_coef_infection: 0.7194 - val_iou_coef_infection: 0.6787 - val_precision_infection: 0.8544 - val_recall_infection: 0.7215 - val_hausdorff95_infection: 60.2548 - val_specificity_infection: 0.9977 - val_accuracy_infection: 0.9957 - val_f1_infection: 0.8754
# Epoch 34/100
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2502 - dice_coef_infection: 0.7668 - iou_coef_infection: 0.6483 - precision_infection: 0.7905 - recall_infection: 0.7801 - hausdorff95_infection: 21.3771 - specificity_infection: 0.9984 - accuracy_infection: 0.9970 - f1_infection: 0.8683 - val_loss: 0.3486 - val_dice_coef_infection: 0.7099 - val_iou_coef_infection: 0.6746 - val_precision_infection: 0.9031 - val_recall_infection: 0.7021 - val_hausdorff95_infection: 70.8347 - val_specificity_infection: 0.9982 - val_accuracy_infection: 0.9961 - val_f1_infection: 0.8626
# Epoch 35/100
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2331 - dice_coef_infection: 0.7836 - iou_coef_infection: 0.6689 - precision_infection: 0.8062 - recall_infection: 0.7936 - hausdorff95_infection: 20.4336 - specificity_infection: 0.9985 - accuracy_infection: 0.9971 - f1_infection: 0.8762 - val_loss: 0.3481 - val_dice_coef_infection: 0.7072 - val_iou_coef_infection: 0.6669 - val_precision_infection: 0.8134 - val_recall_infection: 0.7306 - val_hausdorff95_infection: 58.4820 - val_specificity_infection: 0.9967 - val_accuracy_infection: 0.9953 - val_f1_infection: 0.8766
# Epoch 36/100
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2405 - dice_coef_infection: 0.7762 - iou_coef_infection: 0.6591 - precision_infection: 0.7998 - recall_infection: 0.7876 - hausdorff95_infection: 20.5316 - specificity_infection: 0.9984 - accuracy_infection: 0.9971 - f1_infection: 0.8716 - val_loss: 0.3307 - val_dice_coef_infection: 0.7189 - val_iou_coef_infection: 0.6806 - val_precision_infection: 0.9008 - val_recall_infection: 0.7090 - val_hausdorff95_infection: 66.5294 - val_specificity_infection: 0.9982 - val_accuracy_infection: 0.9962 - val_f1_infection: 0.8647
# Epoch 37/100
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2159 - dice_coef_infection: 0.8005 - iou_coef_infection: 0.6849 - precision_infection: 0.8142 - recall_infection: 0.8085 - hausdorff95_infection: 19.0271 - specificity_infection: 0.9984 - accuracy_infection: 0.9970 - f1_infection: 0.8823 - val_loss: 0.3484 - val_dice_coef_infection: 0.7073 - val_iou_coef_infection: 0.6725 - val_precision_infection: 0.9068 - val_recall_infection: 0.6971 - val_hausdorff95_infection: 70.6571 - val_specificity_infection: 0.9983 - val_accuracy_infection: 0.9962 - val_f1_infection: 0.8612
# Epoch 38/100
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2426 - dice_coef_infection: 0.7747 - iou_coef_infection: 0.6587 - precision_infection: 0.8002 - recall_infection: 0.7828 - hausdorff95_infection: 22.9882 - specificity_infection: 0.9985 - accuracy_infection: 0.9971 - f1_infection: 0.8733 - val_loss: 0.3501 - val_dice_coef_infection: 0.7084 - val_iou_coef_infection: 0.6738 - val_precision_infection: 0.9096 - val_recall_infection: 0.6966 - val_hausdorff95_infection: 72.2209 - val_specificity_infection: 0.9984 - val_accuracy_infection: 0.9961 - val_f1_infection: 0.8618
# Epoch 39/100
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2355 - dice_coef_infection: 0.7807 - iou_coef_infection: 0.6644 - precision_infection: 0.8041 - recall_infection: 0.7905 - hausdorff95_infection: 20.2699 - specificity_infection: 0.9985 - accuracy_infection: 0.9972 - f1_infection: 0.8746 - val_loss: 0.3334 - val_dice_coef_infection: 0.7193 - val_iou_coef_infection: 0.6797 - val_precision_infection: 0.8919 - val_recall_infection: 0.7182 - val_hausdorff95_infection: 65.5301 - val_specificity_infection: 0.9979 - val_accuracy_infection: 0.9962 - val_f1_infection: 0.8647
# Epoch 40/100
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2134 - dice_coef_infection: 0.8021 - iou_coef_infection: 0.6871 - precision_infection: 0.8203 - recall_infection: 0.8053 - hausdorff95_infection: 18.8153 - specificity_infection: 0.9986 - accuracy_infection: 0.9973 - f1_infection: 0.8839 - val_loss: 0.3263 - val_dice_coef_infection: 0.7266 - val_iou_coef_infection: 0.6859 - val_precision_infection: 0.8972 - val_recall_infection: 0.7153 - val_hausdorff95_infection: 63.7989 - val_specificity_infection: 0.9984 - val_accuracy_infection: 0.9961 - val_f1_infection: 0.8684
# Epoch 41/100
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2181 - dice_coef_infection: 0.7973 - iou_coef_infection: 0.6828 - precision_infection: 0.8195 - recall_infection: 0.8010 - hausdorff95_infection: 20.1853 - specificity_infection: 0.9985 - accuracy_infection: 0.9972 - f1_infection: 0.8812 - val_loss: 0.3263 - val_dice_coef_infection: 0.7253 - val_iou_coef_infection: 0.6842 - val_precision_infection: 0.8965 - val_recall_infection: 0.7144 - val_hausdorff95_infection: 62.1828 - val_specificity_infection: 0.9982 - val_accuracy_infection: 0.9961 - val_f1_infection: 0.8665
# Epoch 42/100
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2247 - dice_coef_infection: 0.7916 - iou_coef_infection: 0.6759 - precision_infection: 0.8024 - recall_infection: 0.7999 - hausdorff95_infection: 19.7454 - specificity_infection: 0.9984 - accuracy_infection: 0.9970 - f1_infection: 0.8821 - val_loss: 0.3333 - val_dice_coef_infection: 0.7278 - val_iou_coef_infection: 0.6861 - val_precision_infection: 0.8771 - val_recall_infection: 0.7222 - val_hausdorff95_infection: 62.6630 - val_specificity_infection: 0.9980 - val_accuracy_infection: 0.9958 - val_f1_infection: 0.8730
# Epoch 43/100
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2155 - dice_coef_infection: 0.8009 - iou_coef_infection: 0.6861 - precision_infection: 0.8117 - recall_infection: 0.8061 - hausdorff95_infection: 20.2915 - specificity_infection: 0.9985 - accuracy_infection: 0.9971 - f1_infection: 0.8849 - val_loss: 0.3339 - val_dice_coef_infection: 0.7247 - val_iou_coef_infection: 0.6845 - val_precision_infection: 0.8722 - val_recall_infection: 0.7276 - val_hausdorff95_infection: 63.3849 - val_specificity_infection: 0.9974 - val_accuracy_infection: 0.9958 - val_f1_infection: 0.8725
# Epoch 44/100
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2159 - dice_coef_infection: 0.7999 - iou_coef_infection: 0.6869 - precision_infection: 0.8199 - recall_infection: 0.8059 - hausdorff95_infection: 18.9080 - specificity_infection: 0.9985 - accuracy_infection: 0.9972 - f1_infection: 0.8826 - val_loss: 0.3572 - val_dice_coef_infection: 0.7096 - val_iou_coef_infection: 0.6733 - val_precision_infection: 0.8940 - val_recall_infection: 0.6991 - val_hausdorff95_infection: 71.9643 - val_specificity_infection: 0.9983 - val_accuracy_infection: 0.9960 - val_f1_infection: 0.8662
# Epoch 45/100
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 223s 195ms/step - loss: 0.2097 - dice_coef_infection: 0.8054 - iou_coef_infection: 0.6914 - precision_infection: 0.8147 - recall_infection: 0.8157 - hausdorff95_infection: 17.1696 - specificity_infection: 0.9985 - accuracy_infection: 0.9973 - f1_infection: 0.8853 - val_loss: 0.3472 - val_dice_coef_infection: 0.7123 - val_iou_coef_infection: 0.6753 - val_precision_infection: 0.9024 - val_recall_infection: 0.7027 - val_hausdorff95_infection: 69.8847 - val_specificity_infection: 0.9984 - val_accuracy_infection: 0.9961 - val_f1_infection: 0.8625
# 🛑 Early stopping at epoch 45
# ✅ Total training time: 10068.68 seconds (167.81 minutes)

# %% [markdown]
# ## Plotting the performance metrics

# %%
plt.plot(history.history['dice_coef_infection'])
plt.plot(history.history['val_dice_coef_infection'])
plt.title('dice_coef_infection vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Dice_coef')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# %%
plt.plot(history.history['iou_coef_infection'])
plt.plot(history.history['val_iou_coef_infection'])
plt.title('iou_coef_infection vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Iou_coef')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Val'], loc = 'upper right')
plt.show()

# %% [markdown]
# ## Using our trained model for prediction

# %%
import numpy as np
import time

# Start timer (high precision)
start_time = time.perf_counter()

# Evaluate the model on the validation generator
results = model.evaluate(val_gen, verbose=1)

# End timer
end_time = time.perf_counter()

# Calculate evaluation time
eval_time = end_time - start_time

# Print metric names with results
print("\n===== Validation Metrics =====")
for name, value in zip(model.metrics_names, results):
    print(f"{name}: {value:.6f}")

print(f"\nEvaluation Time: {eval_time:.8f} seconds\n")
# Out:
# 128/128 [==============================] - 9s 73ms/step - loss: 0.3050 - dice_coef_infection: 0.7506 - iou_coef_infection: 0.7045 - precision_infection: 0.8733 - recall_infection: 0.7754 - hausdorff95_infection: 47.2026 - specificity_infection: 0.9990 - accuracy_infection: 0.9965 - f1_infection: 0.8788
#
# ===== Validation Metrics =====
# loss: 0.305045
# dice_coef_infection: 0.750575
# iou_coef_infection: 0.704527
# precision_infection: 0.873332
# recall_infection: 0.775364
# hausdorff95_infection: 47.202610
# specificity_infection: 0.998964
# accuracy_infection: 0.996508
# f1_infection: 0.878788
#
# Evaluation Time: 9.41595573 seconds

# %%
import matplotlib.pyplot as plt
import numpy as np

# Run inference if not already done
predicted = model.predict(lung_test)

# Selected indices to visualize (744 as 1st, 280 as 2nd, 230 as 3rd)
selected_indices = [744, 280, 230]
n_samples = len(selected_indices)

# Mapping indices to custom names
name_mapping = {
    0: ("Image1_Covid", "GT1_Covid", "Predict1_Covid_DSEG_Unet"),  # Index 744
    1: ("Image2_Covid", "GT2_Covid", "Predict2_Covid_DSEG_Unet"),  # Index 280
    2: ("Image3_Covid", "GT3_Covid", "Predict3_Covid_DSEG_Unet")   # Index 230
}

# Plot
for j, i in enumerate(selected_indices):
    lung_img = lung_test[i][..., 0].astype(np.float32)
    gt_infect = (infect_test[i][..., 0] > 0.5).astype(np.float32)
    pred_infect = predicted[i][..., 0].astype(np.float32)

    # Normalize lung image
    if lung_img.max() > lung_img.min():
        lung_img = (lung_img - lung_img.min()) / (lung_img.max() - lung_img.min())
    lung_img = np.clip(lung_img, 0, 1)
    pred_infect = np.clip(pred_infect, 0, 1)

    # Get custom names for this index
    input_name, gt_name, pred_name = name_mapping[j]

    # Save Original Lung
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{input_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

    # Save Ground Truth Infection
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.imshow(gt_infect, cmap='Reds', alpha=0.6)
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{gt_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

    # Save Predicted Infection
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.imshow(pred_infect, cmap='Reds', alpha=0.6)
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{pred_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

print("Separate JPEG files saved for input images (Image1_Covid, Image2_Covid, Image3_Covid), "
      "ground truths (GT1_Covid, GT2_Covid, GT3_Covid), and predictions "
      "(Predict1_Covid_DSEG_Unet, Predict2_Covid_DSEG_Unet, Predict3_Covid_DSEG_Unet).")
# Out:
# Separate JPEG files saved for input images (Image1_Covid, Image2_Covid, Image3_Covid), ground truths (GT1_Covid, GT2_Covid, GT3_Covid), and predictions (Predict1_Covid_DSEG_Unet, Predict2_Covid_DSEG_Unet, Predict3_Covid_DSEG_Unet).
