# %% [markdown]
# ## Importing important libraries

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import nibabel as nib #for loading nii files
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf #for deep learning

# %% [markdown]
# ## Reading the metadata

# %%
data = pd.read_csv('../input/covid19-ct-scans/metadata.csv')
data.head()
# Out:
#                                              ct_scan  \
# 0  ../input/covid19-ct-scans/ct_scans/coronacases...
# 1  ../input/covid19-ct-scans/ct_scans/coronacases...
# 2  ../input/covid19-ct-scans/ct_scans/coronacases...
# 3  ../input/covid19-ct-scans/ct_scans/coronacases...
# 4  ../input/covid19-ct-scans/ct_scans/coronacases...
#
#                                            lung_mask  \
# 0  ../input/covid19-ct-scans/lung_mask/coronacase...
# 1  ../input/covid19-ct-scans/lung_mask/coronacase...
# 2  ../input/covid19-ct-scans/lung_mask/coronacase...
# 3  ../input/covid19-ct-scans/lung_mask/coronacase...
# 4  ../input/covid19-ct-scans/lung_mask/coronacase...
#
#                                       infection_mask  \
# 0  ../input/covid19-ct-scans/infection_mask/coron...
# 1  ../input/covid19-ct-scans/infection_mask/coron...
# 2  ../input/covid19-ct-scans/infection_mask/coron...
# 3  ../input/covid19-ct-scans/infection_mask/coron...
# 4  ../input/covid19-ct-scans/infection_mask/coron...
#
#                              lung_and_infection_mask
# 0  ../input/covid19-ct-scans/lung_and_infection_m...
# 1  ../input/covid19-ct-scans/lung_and_infection_m...
# 2  ../input/covid19-ct-scans/lung_and_infection_m...
# 3  ../input/covid19-ct-scans/lung_and_infection_m...
# 4  ../input/covid19-ct-scans/lung_and_infection_m...

# %% [markdown]
# ## Defining function for readiing .nii files

# %%
def read_nii(filepath):
    '''
    Reads .nii file and returns pixel array
    '''
    ct_scan = nib.load(filepath)
    array   = ct_scan.get_fdata()
    array   = np.rot90(np.array(array))
    return(array)

# %% [markdown]
# ## Reading the chest ct scan data

# %%
# Read sample
sample_ct   = read_nii(data.loc[2,'ct_scan'])
sample_lung = read_nii(data.loc[2,'lung_mask'])
sample_infe = read_nii(data.loc[2,'infection_mask'])
sample_all  = read_nii(data.loc[2,'lung_and_infection_mask'])

# %% [markdown]
# ## Plotting the sample images

# %%
fig = plt.figure(figsize = (18,15))
plt.subplot(1,4,1)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.title('Original Image')

plt.subplot(1,4,2)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_lung[..., 150],alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung Mask')

plt.subplot(1,4,3)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_infe[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Infection Mask')

plt.subplot(1,4,4)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_all[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung and Infection Mask')
# Out:
# Text(0.5, 1.0, 'Lung and Infection Mask')

# %% [markdown]
# ## Converting the data into array for training model

# %%
import numpy as np
import cv2
import random
from scipy.ndimage import rotate, shift, zoom

lungs = []
infections = []
case_ids = []
img_size = 320

# ----------- Load and Resize Data -----------
for case_index in range(len(data)):
    ct = read_nii(data['ct_scan'][case_index])
    infect = read_nii(data['infection_mask'][case_index])

    for slice_index in range(ct.shape[0]):
        lung_img = cv2.resize(ct[slice_index], dsize=(img_size, img_size)).astype('float32')
        infec_img = cv2.resize(infect[slice_index], dsize=(img_size, img_size)).astype('float32')

        lungs.append(lung_img[..., np.newaxis])
        infections.append(infec_img[..., np.newaxis])
        case_ids.append(case_index)

# %%
import numpy as np

# case_ids should be a NumPy array telling which case each slice belongs to
# Convert and binarize
lungs = np.array(lungs, dtype=np.float32)
infections = (np.array(infections, dtype=np.uint8) > 0.5).astype(np.uint8)
case_ids = np.array(case_ids)

# %% [markdown]
# ## Performing test and train split

# %%
# ----------- Case-wise Split -----------
unique_cases = np.unique(case_ids)
train_cases = np.append(unique_cases[2:4], unique_cases[6:20])
temp_cases = unique_cases[4:6]
val_cases = unique_cases[:2]

train_mask = np.isin(case_ids, train_cases)
temp_mask = np.isin(case_ids, temp_cases)
val_mask = np.isin(case_ids, val_cases)

lung_train = lungs[train_mask]
infect_train = infections[train_mask]
lung_temp = lungs[temp_mask]
infect_temp = infections[temp_mask]
lung_test = lungs[val_mask]
infect_test = infections[val_mask]

print(f"✅ Train: {lung_train.shape[0]} slices from {len(train_cases)} cases")
print(f"✅ Validation: {lung_temp.shape[0]} slices from {len(temp_cases)} cases")
print(f"✅ Test: {lung_test.shape[0]} slices from {len(val_cases)} cases")

# ----------- Augmentation -----------
def augment_image(img, mask):
    if random.random() < 0.5:
        img = np.fliplr(img)
        mask = np.fliplr(mask)
    if random.random() < 0.5:
        img = np.flipud(img)
        mask = np.flipud(mask)

    angle = random.uniform(-15, 15)
    img = rotate(img, angle, reshape=False, order=1, mode='nearest')
    mask = rotate(mask, angle, reshape=False, order=0, mode='nearest')

    shift_val = np.random.uniform(-0.1, 0.1, size=2) * img.shape[:2]
    img = shift(img, shift=(*shift_val, 0), order=1, mode='nearest')
    mask = shift(mask, shift=(*shift_val, 0), order=0, mode='nearest')

    zoom_factor = random.uniform(0.9, 1.1)
    img = zoom(img, (zoom_factor, zoom_factor, 1), order=1)
    mask = zoom(mask, (zoom_factor, zoom_factor, 1), order=0)

    return fix_shape(img), fix_shape(mask)

def fix_shape(arr, target_size=(320, 320)):
    h, w, c = arr.shape
    th, tw = target_size
    dh = th - h
    dw = tw - w
    if dh > 0 or dw > 0:
        pad_h = (max(dh // 2, 0), max(dh - dh // 2, 0))
        pad_w = (max(dw // 2, 0), max(dw - dw // 2, 0))
        arr = np.pad(arr, (pad_h, pad_w, (0, 0)), mode='constant')
    arr = arr[:th, :tw, :]
    return arr.astype('float32')

# ----------- Apply Augmentation -----------
aug_lung_train = []
aug_infect_train = []

for i in range(len(lung_train)):
    img, mask = augment_image(lung_train[i], infect_train[i])
    aug_lung_train.append(img)
    aug_infect_train.append(mask)

lung_train = np.stack(aug_lung_train)
infect_train = np.stack(aug_infect_train)

# Final Binarization
infect_train = (infect_train > 0.5).astype(np.uint8)
infect_test = (infect_test > 0.5).astype(np.uint8)

print(f"✅ Augmented training shape: {lung_train.shape}")
print("✅ All preprocessing complete.")
# Out:
# ✅ Train: 9143 slices from 16 cases
# ✅ Validation: 1024 slices from 2 cases
# ✅ Test: 1024 slices from 2 cases
# ✅ Augmented training shape: (9143, 320, 320, 1)
# ✅ All preprocessing complete.

# %%
import tensorflow as tf
from tensorflow.keras import backend as K
import numpy as np
from scipy.spatial import cKDTree

smooth = 1.0

# Binary Dice coefficient (soft - commonly used during training)
def dice_coef_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# Binary IoU coefficient (soft)
def iou_coef_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# Soft Precision
def precision_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + smooth) / (K.sum(y_pred_f) + smooth)

# Soft Recall (Sensitivity)
def recall_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + smooth) / (K.sum(y_true_f) + smooth)

# Soft Specificity
def specificity_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    tn = K.sum((1 - y_true_f) * (1 - y_pred_f))
    fp = K.sum((1 - y_true_f) * y_pred_f)
    return (tn + smooth) / (tn + fp + smooth)

# Soft Accuracy
def accuracy_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    tp = K.sum(y_true_f * y_pred_f)
    tn = K.sum((1 - y_true_f) * (1 - y_pred_f))
    total = K.cast(K.shape(y_true_f)[0], 'float32')
    return (tp + tn + smooth) / (total + smooth)

# Soft F1-score (harmonic mean of precision & recall - very close to Dice, standard in many repos)
def f1_infection(y_true, y_pred):
    precision = precision_infection(y_true, y_pred)
    recall    = recall_infection(y_true, y_pred)
    return (2. * precision * recall + smooth) / (precision + recall + smooth)

# Hausdorff Distance 95 % (robust & most commonly used in medical imaging challenges)
# Lower = better. Returns the mean HD95 over the batch.
def _calculate_hd95(y_true, y_pred):
    hd_list = []
    for i in range(y_true.shape[0]):
        # Hard threshold at 0.5 (standard for evaluation metrics)
        gt = np.squeeze(y_true[i]) > 0.5
        pred = np.squeeze(y_pred[i]) > 0.5

        gt_pts = np.argwhere(gt)
        pred_pts = np.argwhere(pred)

        # Cases with empty masks
        if gt_pts.shape[0] == 0 and pred_pts.shape[0] == 0:
            hd_list.append(0.0)
            continue
        if gt_pts.shape[0] == 0 or pred_pts.shape[0] == 0:
            hd_list.append(400.0)  # large penalty - adjust to your image diagonal if needed (e.g. ~362 for 256×256, ~724 for 512×512)
            continue

        # Directed distances
        dist_gt_to_pred = cKDTree(pred_pts).query(gt_pts)[0]
        dist_pred_to_gt = cKDTree(gt_pts).query(pred_pts)[0]

        hd95 = max(
            np.percentile(dist_gt_to_pred, 95),
            np.percentile(dist_pred_to_gt, 95)
        )
        hd_list.append(hd95)

    return np.mean(hd_list, dtype=np.float32)

def hausdorff95_infection(y_true, y_pred):
    hd = tf.numpy_function(_calculate_hd95, [y_true, y_pred], tf.float32)
    hd.set_shape(())
    return hd

# Optional: KL Divergence (you already had this)
kld = tf.keras.losses.KLDivergence()

# %%
from tensorflow.keras.losses import BinaryCrossentropy

def loss_f(y_true, y_pred):
    bce = BinaryCrossentropy()
    return dice_loss(y_true, y_pred) + bce(y_true, y_pred) 

def loss_e(y_true, y_pred):
    bce = BinaryCrossentropy()
    return dice_loss(y_true, y_pred)  + kld(y_true, y_pred)
    
def dice_loss(y_true, y_pred):
    return 1. - dice_coef_infection(y_true, y_pred)

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Multiply, Conv2D, DepthwiseConv2D, Dense, Flatten, MaxPooling2D, UpSampling2D, concatenate, Activation, LayerNormalization, Add, Dropout, Conv2DTranspose, multiply, Reshape, GlobalAveragePooling2D, Permute, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Concatenate

def activation_block(x):
    x = Activation("gelu")(x)
    return LayerNormalization()(x)

def conv_stem(x, filters: int, patch_size: int):
    x = Conv2D(filters, kernel_size=patch_size,padding='same', strides=patch_size)(x)
    return activation_block(x)

def vector_block(xyz, cmf, red):
    # red means reduction
    # cmf means filters, denotes vector size
    opt1 = conv_stem(xyz, cmf, red)
    opt2 = conv_stem(xyz, cmf, red)
    
    o1 = GlobalAveragePooling2D()(opt1)
    o2 = GlobalAveragePooling2D()(opt2)

    o5 = concatenate([o1, o2], -1)
    return o5

def mlp_feature(vect, cmf):
    oo = Flatten()(vect)
    o6 = Dense(cmf, activation='gelu')(oo)
    o6 = Dropout(0.2)(o6)
    o6 = Dense(cmf * 2, activation='gelu')(o6)

    o6 = Reshape((1, cmf * 2))(o6)
    o7 = Permute((2, 1))(o6)

    o8 = multiply([o6, o7])
    
    o8 = Lambda(lambda x: tf.expand_dims(x, -1))(o8)
    
    o8 = Reshape((cmf, cmf, 4))(o8)

    return o8

def frz_block(xyz):
    shape = xyz.shape
    a1, a2, a3, a4 = shape[0], shape[1], shape[2], shape[3]
    cmf = a2
    o5 = vector_block(xyz, cmf, 5)
    o7 = mlp_feature(o5, cmf)

    o7 = concatenate([o7, xyz, o7], -1)
    return o7

def up_frz(x1, x2, n_filters):
    # Upsample x1 using Conv2DTranspose
    x1 = Conv2DTranspose(n_filters * 4, 3, strides=2, activation='gelu', padding="same")(x1)
    
    # Apply Conv2D to x2
    x2 = Conv2D(n_filters * 2, 3, activation='gelu', padding="same")(x2)
    
    # Apply attention mechanism
    x = concatenate([x1, x2])
    
    # Apply Dropout for regularization
    x = Dropout(0.3)(x)
    
    return x

def regu(x):
    filters = x.shape[-1]
    shortcut = x
    x = Conv2D(filters, (3, 3), activation='gelu', padding="same")(x)
    x = Add()([x, shortcut])
    return x

# %%
def squeeze_and_excite_block(inputs, ratio=24):
    """ Squeeze and Excitation block to recalibrate channel-wise features """
    filters = inputs.shape[-1]  # Number of input channels
    se_shape = (1, 1, filters)

    # Squeeze: Global Average Pooling
    se = GlobalAveragePooling2D()(inputs)
    se = Reshape(se_shape)(se)

    a = filters // ratio

    # Excitation: Dense layers to capture channel-wise dependencies
    if a > 8:
        se = Conv2D(filters // ratio, kernel_size=1, activation='swish', padding='same')(se)
        se = Conv2D(filters, kernel_size=1, activation='sigmoid', padding='same')(se)
    else:
        se = Conv2D(8, kernel_size=1, activation='swish', padding='same')(se)
        se = Conv2D(filters, kernel_size=1, activation='sigmoid', padding='same')(se)

    # Scale the input by channel-wise weights
    x = multiply([inputs, se])

    return x

def residual_block(x, filters, stride=1, padding='same'):
    shortcut = x
    x = Conv2D(filters * 6, 1, strides=stride, padding=padding, use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)
    x = DepthwiseConv2D(kernel_size=3, strides=stride, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)
    x = squeeze_and_excite_block(x)
    x = Conv2D(filters, 1, strides=stride, padding=padding, use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)
    x = Add()([x, shortcut])
    return x

def dense_block(inputs, num_layers, growth_rate, ratio=16):
    """Dense block where each layer is connected to all previous layers."""
    concat_features = inputs
    for i in range(num_layers):
        # BatchNorm -> ReLU -> Conv2D
        x = Conv2D(growth_rate, 3, activation='gelu', padding='same')(concat_features)

        # Concatenate input with new output (dense connection)
        concat_features = Concatenate()([concat_features, x])
        
    x = squeeze_and_excite_block(concat_features)

    return x

def attention_gate(X, g, channel,  
                   activation='ReLU', 
                   attention='add', name='att'):
    '''
    Self-attention gate modified from Oktay et al. 2018.
    
    attention_gate(X, g, channel,  activation='ReLU', attention='add', name='att')
    
    Input
    ----------
        X: input tensor, i.e., key and value.
        g: gated tensor, i.e., query.
        channel: number of intermediate channel.
                 Oktay et al. (2018) did not specify (denoted as F_int).
                 intermediate channel is expected to be smaller than the input channel.
        activation: a nonlinear attnetion activation.
                    The `sigma_1` in Oktay et al. 2018. Default is 'ReLU'.
        attention: 'add' for additive attention; 'multiply' for multiplicative attention.
                   Oktay et al. 2018 applied additive attention.
        name: prefix of the created keras layers.
        
    Output
    ----------
        X_att: output tensor.
    
    '''

    attention_func = eval(attention)
    
    # mapping the input tensor to the intermediate channel
    theta_att = Conv2D(channel, 1, use_bias=True)(X)
    
    # mapping the gate tensor
    phi_g = Conv2D(channel, 1, use_bias=True)(g)
    
    # ----- attention learning ----- #
    query = attention_func([theta_att, phi_g])
    
    # nonlinear activation
    f = Activation('gelu')(query)
    
    # linear transformation
    psi_f = Conv2D(1, 1, use_bias=True)(f)
    # ------------------------------ #
    
    # sigmoid activation as attention coefficients
    coef_att = Activation('sigmoid')(psi_f)
    
    # multiplicative attention masking
    X_att = multiply([X, coef_att])
    
    return X_att

inputs = (img_size, img_size, 1)

def model_build_func(input_shape, n_labels):
    inputs = Input(shape=input_shape, name='input_image')
    g_filter = 16
    u_filter = 8

    # Initial convolution
    initial = Conv2D(g_filter, (3, 3), activation='gelu', padding="same")(inputs)
    initial = dense_block(initial, 2, g_filter // 2)  # 80

    # Down-sampling path
    o1 = MaxPooling2D(2)(initial)
    o1 = dense_block(o1, 2, g_filter)  # 40
    #o1 = squeeze_and_excite_block(o1)

    o2 = MaxPooling2D(2)(o1)
    o2 = dense_block(o2, 2, g_filter * 2)  # 20
    #o2 = squeeze_and_excite_block(o2)

    o3 = MaxPooling2D(2)(o2)
    o3 = dense_block(o3, 2, g_filter * 4)  # 10
    #o3 = squeeze_and_excite_block(o3)

    o4 = MaxPooling2D(2)(o3)
    o4 = dense_block(o4, 2, g_filter * 8)  # 5
    #o4 = squeeze_and_excite_block(o4)

    o5 = MaxPooling2D(2)(o4)
    o5 = dense_block(o5, 2, g_filter * 16)  # 5
    #o5 = squeeze_and_excite_block(o5)

    # Up-sampling path
    u1 = up_frz(o5, o4, u_filter * 16)  # 10
    #gate1 = attention_gate(o4, u1, u_filter * 16, attention='add')
    cu1 = concatenate([u1, o4])

    u2 = up_frz(cu1, o3, u_filter * 8)  # 20
    #gate2 = attention_gate(o3, u2, u_filter * 8, attention='add')
    cu2 = concatenate([u2, o3])  # 20

    u3 = up_frz(cu2, o2, u_filter * 4)  # 40
    #gate3 = attention_gate(o2, u3, u_filter * 4, attention='add')
    cu3 = concatenate([u3, o2])  # 40

    u4 = up_frz(cu3, o1, u_filter * 2)  # 80
    #gate4 = attention_gate(o1, u4, u_filter * 2, attention='add')
    cu4 = concatenate([u4, o1])  # 80

    u5 = Conv2DTranspose(u_filter * 4, 3, strides=2, activation='gelu', padding="same")(cu4)  # 80
    #gate5 = attention_gate(initial, u5, u_filter, attention='add')
    cu5 = concatenate([u5, initial])  # 80

    # Final segmentation map
    seg_map = Conv2D(n_labels, 3, activation='sigmoid', padding="same")(cu5)

    # Model definition
    model = Model(inputs=inputs, outputs=seg_map)

    return model


model = model_build_func(inputs, 1)

from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2_as_graph

def get_flops(model):
    """Calculate Floating Point Operations (FLOPs) of a Keras model in TensorFlow 2.x."""
    # Convert Keras model to a TensorFlow function
    concrete_func = tf.function(lambda inputs: model(inputs))
    concrete_func = concrete_func.get_concrete_function(
        tf.TensorSpec([1] + list(model.input_shape[1:]), model.input.dtype)
    )

    # Convert to frozen graph
    frozen_func, _ = convert_variables_to_constants_v2_as_graph(concrete_func)

    # Compute FLOPs
    flops = tf.compat.v1.profiler.profile(
        frozen_func.graph,
        options=tf.compat.v1.profiler.ProfileOptionBuilder.float_operation(),
    )

    return flops.total_float_ops

# Compute FLOPs
flops = get_flops(model)
print(f"Total FLOPs: {flops / 1e9:.2f} GFLOPs")  # Convert to GFLOPs

from tensorflow.keras.optimizers import Adam

optimizer = Adam(learning_rate=1e-3)
model.compile(optimizer=optimizer, loss=loss_f, metrics=[dice_coef_infection, iou_coef_infection, precision_infection, recall_infection, hausdorff95_infection, specificity_infection, accuracy_infection, f1_infection])

# Model summary
model.summary()
# Out:
# Total FLOPs: 17.91 GFLOPs
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_image (InputLayer)        [(None, 320, 320, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 320, 320, 16) 160         input_image[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 320, 320, 8)  1160        conv2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 320, 320, 24) 0           conv2d[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 320, 320, 8)  1736        concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 320, 320, 32) 0           concatenate[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 32)           0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 1, 32)     0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 1, 1, 8)      264         reshape[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 1, 1, 32)     288         conv2d_3[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 320, 320, 32) 0           concatenate_1[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 160, 160, 32) 0           multiply[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 160, 160, 16) 4624        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 160, 160, 48) 0           max_pooling2d[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 160, 160, 16) 6928        concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 160, 160, 64) 0           concatenate_2[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 64)           0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 1, 64)     0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 1, 1, 8)      520         reshape_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 1, 1, 64)     576         conv2d_7[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 160, 160, 64) 0           concatenate_3[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 80, 80, 64)   0           multiply_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 80, 80, 32)   18464       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 80, 80, 96)   0           max_pooling2d_1[0][0]
#                                                                  conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 80, 80, 32)   27680       concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 80, 80, 128)  0           concatenate_4[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 128)          0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 1, 128)    0           global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 1, 1, 8)      1032        reshape_2[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 1, 1, 128)    1152        conv2d_11[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 80, 80, 128)  0           concatenate_5[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 40, 40, 128)  0           multiply_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 40, 40, 64)   73792       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 40, 40, 192)  0           max_pooling2d_2[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 40, 40, 64)   110656      concatenate_6[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 40, 40, 256)  0           concatenate_6[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 256)          0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1, 1, 256)    0           global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 1, 1, 10)     2570        reshape_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 1, 1, 256)    2816        conv2d_15[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 40, 40, 256)  0           concatenate_7[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 20, 20, 256)  0           multiply_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 20, 20, 128)  295040      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 20, 20, 384)  0           max_pooling2d_3[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 20, 20, 128)  442496      concatenate_8[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 20, 20, 512)  0           concatenate_8[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 512)          0           concatenate_9[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1, 1, 512)    0           global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 1, 1, 21)     10773       reshape_4[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 1, 1, 512)    11264       conv2d_19[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 20, 20, 512)  0           concatenate_9[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 10, 10, 512)  0           multiply_4[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 10, 10, 256)  1179904     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 10, 10, 768)  0           max_pooling2d_4[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 10, 10, 256)  1769728     concatenate_10[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 10, 10, 1024) 0           concatenate_10[0][0]
#                                                                  conv2d_22[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 1024)         0           concatenate_11[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 1, 1, 1024)   0           global_average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 1, 1, 42)     43050       reshape_5[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 1, 1, 1024)   44032       conv2d_23[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 10, 10, 1024) 0           concatenate_11[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 20, 20, 512)  4719104     multiply_5[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 20, 20, 256)  1179904     multiply_4[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 20, 20, 768)  0           conv2d_transpose[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 20, 20, 768)  0           concatenate_12[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 20, 20, 1280) 0           dropout[0][0]
#                                                                  multiply_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 40, 40, 256)  2949376     concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 40, 40, 128)  295040      multiply_3[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 40, 40, 384)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 40, 40, 384)  0           concatenate_14[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 40, 40, 640)  0           dropout_1[0][0]
#                                                                  multiply_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 80, 80, 128)  737408      concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 80, 80, 64)   73792       multiply_2[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 80, 80, 192)  0           conv2d_transpose_2[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 80, 80, 192)  0           concatenate_16[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 80, 80, 320)  0           dropout_2[0][0]
#                                                                  multiply_2[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 160, 160, 64) 184384      concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 160, 160, 32) 18464       multiply_1[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 160, 160, 96) 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_28[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 160, 160, 96) 0           concatenate_18[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 160, 160, 160 0           dropout_3[0][0]
#                                                                  multiply_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 320, 320, 32) 46112       concatenate_19[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 320, 320, 64) 0           conv2d_transpose_4[0][0]
#                                                                  multiply[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 320, 320, 1)  577         concatenate_20[0][0]
# ==================================================================================================
# Total params: 14,254,866
# Trainable params: 14,254,866
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Install required packages
# !pip install openpyxl

# Imports
import openpyxl  # required for reading .xlsx files
import pandas as pd
import tensorflow as tf
import os
import shutil
from tensorflow.keras.callbacks import LearningRateScheduler, ReduceLROnPlateau

# File paths
checkpoint_filepath = '/kaggle/working/checkpoint.h5.keras'
metrics_file = '/kaggle/working/training_metrics.xlsx'
pre_checkpoint_filepath = '/kaggle/input/dseg-unet-4channel-covid19/checkpoint.h5.keras'
pre_metrics_file = '/kaggle/input/dseg-unet-4channel-covid19/training_metrics.xlsx'

# Restore checkpoint and metrics if available
if os.path.exists(pre_checkpoint_filepath):
    shutil.copy(pre_checkpoint_filepath, checkpoint_filepath)
    print(f"Restored checkpoint from: {pre_checkpoint_filepath}")

if os.path.exists(pre_metrics_file):
    shutil.copy(pre_metrics_file, metrics_file)
    print(f"Restored metrics file from: {pre_metrics_file}")

# Load last epoch
def load_last_epoch():
    if os.path.exists(metrics_file):
        try:
            df = pd.read_excel(metrics_file, engine='openpyxl')
            if not df.empty and 'epoch' in df.columns:
                return df['epoch'].iloc[-1] + 1
        except Exception as e:
            print(f"⚠️ Could not read metrics file: {e}")
    return 0

last_epoch = load_last_epoch()

# Get best validation loss from previous runs
def get_best_val_loss():
    if os.path.exists(metrics_file):
        try:
            df = pd.read_excel(metrics_file, engine='openpyxl')
            if 'val_loss' in df.columns and not df['val_loss'].isnull().all():
                return df['val_loss'].min()
        except Exception as e:
            print(f"⚠️ Could not read val_loss from metrics file: {e}")
    return float('inf')

best_val_loss = get_best_val_loss()

# Custom model checkpoint
class CustomModelCheckpoint(tf.keras.callbacks.Callback):
    def __init__(self, filepath):
        super().__init__()
        self.filepath = filepath
        self.best_loss = best_val_loss

    def on_epoch_end(self, epoch, logs=None):
        current_loss = logs.get('val_loss')
        if current_loss is not None and current_loss < self.best_loss:
            self.best_loss = current_loss
            self.model.save(self.filepath)
            print(f"✅ Model saved at epoch {epoch + 1} with val_loss: {current_loss:.4f}")

# === Learning Rate Schedule ===
def lr_schedule(epoch, lr):
    return 1e-4 if epoch >= 5 else lr

lr_scheduler = LearningRateScheduler(lr_schedule, verbose=1)

# Logger for Excel
class MetricsLogger(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        df_new = pd.DataFrame([{**logs, 'epoch': epoch}])
        try:
            if os.path.exists(metrics_file):
                df = pd.read_excel(metrics_file, engine='openpyxl')
                df = pd.concat([df, df_new], ignore_index=True)
            else:
                df = df_new
            df.to_excel(metrics_file, index=False, engine='openpyxl')
        except Exception as e:
            print(f"⚠️ Failed to log metrics: {e}")

# Early stopping with patience and saving best weights
class CustomEarlyStopping(tf.keras.callbacks.Callback):
    def __init__(self, patience=20):
        super().__init__()
        self.patience = patience
        self.wait = 0
        self.best_loss = best_val_loss

    def on_epoch_end(self, epoch, logs=None):
        current_loss = logs.get('val_loss')
        if current_loss is None:
            return
        if current_loss < self.best_loss:
            self.best_loss = current_loss
            self.wait = 0
            self.model.save_weights(checkpoint_filepath)
        else:
            self.wait += 1
            if self.wait >= self.patience:
                print(f"🛑 Early stopping at epoch {epoch + 1}")
                self.model.stop_training = True


# Final callbacks list
callbacks = [
    CustomModelCheckpoint(filepath=checkpoint_filepath),
    MetricsLogger(),
    lr_scheduler,
    CustomEarlyStopping(patience=20)
]
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.3-py2.py3-none-any.whl (251 kB)
#      |████████████████████████████████| 251 kB 9.1 MB/s eta 0:00:01
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.3

# %% [markdown]
# ## Training the model

# %%
import time
import os
import pandas as pd
import numpy as np
from tensorflow.keras.utils import Sequence
from tensorflow.keras.models import load_model

EPOCHS = 100

# Record the start time
start_time = time.time()

# === Load last completed epoch from metrics file ===
def load_last_epoch():
    if os.path.exists(pre_metrics_file):
        try:
            df = pd.read_excel(pre_metrics_file, engine='openpyxl')
            if not df.empty and 'epoch' in df.columns:
                return int(df['epoch'].iloc[-1]) + 1
        except Exception as e:
            print(f"⚠️ Failed to read metrics file: {e}")
    return 0

last_epoch = load_last_epoch()

# === Load pretrained weights if available ===
if os.path.exists(pre_checkpoint_filepath):
    print("✅ Checkpoint found. Loading pretrained weights...")
    model.load_weights(pre_checkpoint_filepath)
    print(f"🔁 Resuming training from epoch {last_epoch}")
else:
    print("🆕 No checkpoint found. Starting training from scratch.")
    last_epoch = 0

# === Prepare input and label tensors ===
lung_train = np.asarray(lung_train, dtype=np.float16)
infect_train = np.asarray(infect_train, dtype=np.uint8)

lung_temp = np.asarray(lung_temp, dtype=np.float16)
infect_temp = np.asarray(infect_temp, dtype=np.uint8)

lung_test = np.asarray(lung_test, dtype=np.float16)
infect_test = np.asarray(infect_test, dtype=np.uint8)

# === Data Generator ===
class LungDataGenerator(Sequence):
    def __init__(self, X, Y, batch_size=8, shuffle=True):
        self.X = X
        self.Y = Y
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indices = np.arange(len(X))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.X) / self.batch_size))

    def __getitem__(self, index):
        batch_ids = self.indices[index * self.batch_size:(index + 1) * self.batch_size]
        X_batch = self.X[batch_ids]
        Y_batch = self.Y[batch_ids]
        return np.asarray(X_batch, dtype=np.float16), np.asarray(Y_batch, dtype=np.uint8)

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indices)

# === Create generators ===
train_gen = LungDataGenerator(lung_train, infect_train, batch_size=8)
temp_gen = LungDataGenerator(lung_temp, infect_temp, batch_size=8, shuffle=False)
val_gen = LungDataGenerator(lung_test, infect_test, batch_size=8, shuffle=False)

# === Train the model ===
history = model.fit(
    train_gen,
    validation_data=temp_gen,
    epochs=EPOCHS,
    initial_epoch=last_epoch,
    callbacks=callbacks
)

# === Timing info ===
end_time = time.time()
total_time = end_time - start_time
print(f"✅ Total training time: {total_time:.2f} seconds ({total_time / 60:.2f} minutes)")
# Out:
# 🆕 No checkpoint found. Starting training from scratch.
# Epoch 1/100
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 208s 173ms/step - loss: 1.5183 - dice_coef_infection: 0.0481 - iou_coef_infection: 0.0271 - precision_infection: 0.0498 - recall_infection: 0.1144 - hausdorff95_infection: 265.1710 - specificity_infection: 0.9633 - accuracy_infection: 0.9548 - f1_infection: 0.9008 - val_loss: 0.8279 - val_dice_coef_infection: 0.1996 - val_iou_coef_infection: 0.1781 - val_precision_infection: 0.1879 - val_recall_infection: 0.8845 - val_hausdorff95_infection: 258.8695 - val_specificity_infection: 0.9958 - val_accuracy_infection: 0.9949 - val_f1_infection: 0.6274
# ✅ Model saved at epoch 1 with val_loss: 0.8279
# Epoch 2/100
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 195s 171ms/step - loss: 0.7684 - dice_coef_infection: 0.2998 - iou_coef_infection: 0.1975 - precision_infection: 0.3330 - recall_infection: 0.3852 - hausdorff95_infection: 140.7493 - specificity_infection: 0.9922 - accuracy_infection: 0.9867 - f1_infection: 0.7629 - val_loss: 0.6048 - val_dice_coef_infection: 0.4174 - val_iou_coef_infection: 0.3907 - val_precision_infection: 0.4014 - val_recall_infection: 0.9269 - val_hausdorff95_infection: 145.9106 - val_specificity_infection: 0.9963 - val_accuracy_infection: 0.9959 - val_f1_infection: 0.7308
# ✅ Model saved at epoch 2 with val_loss: 0.6048
# Epoch 3/100
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 195s 171ms/step - loss: 0.6054 - dice_coef_infection: 0.4523 - iou_coef_infection: 0.3247 - precision_infection: 0.4853 - recall_infection: 0.5290 - hausdorff95_infection: 117.2426 - specificity_infection: 0.9955 - accuracy_infection: 0.9914 - f1_infection: 0.7752 - val_loss: 0.4881 - val_dice_coef_infection: 0.5210 - val_iou_coef_infection: 0.4958 - val_precision_infection: 0.5466 - val_recall_infection: 0.8842 - val_hausdorff95_infection: 61.6111 - val_specificity_infection: 0.9994 - val_accuracy_infection: 0.9987 - val_f1_infection: 0.7927
# ✅ Model saved at epoch 3 with val_loss: 0.4881
# Epoch 4/100
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 195s 171ms/step - loss: 0.5522 - dice_coef_infection: 0.4934 - iou_coef_infection: 0.3598 - precision_infection: 0.5290 - recall_infection: 0.5512 - hausdorff95_infection: 111.9874 - specificity_infection: 0.9964 - accuracy_infection: 0.9928 - f1_infection: 0.7839 - val_loss: 0.7185 - val_dice_coef_infection: 0.3066 - val_iou_coef_infection: 0.2814 - val_precision_infection: 0.2919 - val_recall_infection: 0.9194 - val_hausdorff95_infection: 165.7440 - val_specificity_infection: 0.9970 - val_accuracy_infection: 0.9966 - val_f1_infection: 0.6855
# Epoch 5/100
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 197s 173ms/step - loss: 0.4987 - dice_coef_infection: 0.5424 - iou_coef_infection: 0.4029 - precision_infection: 0.5783 - recall_infection: 0.5915 - hausdorff95_infection: 91.3452 - specificity_infection: 0.9966 - accuracy_infection: 0.9932 - f1_infection: 0.7905 - val_loss: 1.0189 - val_dice_coef_infection: 0.2738 - val_iou_coef_infection: 0.2604 - val_precision_infection: 0.2605 - val_recall_infection: 0.9887 - val_hausdorff95_infection: 177.6299 - val_specificity_infection: 0.9690 - val_accuracy_infection: 0.9693 - val_f1_infection: 0.6396
# Epoch 6/100
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 196s 172ms/step - loss: 0.4160 - dice_coef_infection: 0.6176 - iou_coef_infection: 0.4800 - precision_infection: 0.6412 - recall_infection: 0.6552 - hausdorff95_infection: 66.5661 - specificity_infection: 0.9973 - accuracy_infection: 0.9946 - f1_infection: 0.8153 - val_loss: 0.3888 - val_dice_coef_infection: 0.6369 - val_iou_coef_infection: 0.6099 - val_precision_infection: 0.6162 - val_recall_infection: 0.9486 - val_hausdorff95_infection: 96.2842 - val_specificity_infection: 0.9956 - val_accuracy_infection: 0.9954 - val_f1_infection: 0.8272
# ✅ Model saved at epoch 6 with val_loss: 0.3888
# Epoch 7/100
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 196s 172ms/step - loss: 0.4030 - dice_coef_infection: 0.6272 - iou_coef_infection: 0.4919 - precision_infection: 0.6564 - recall_infection: 0.6724 - hausdorff95_infection: 62.6713 - specificity_infection: 0.9975 - accuracy_infection: 0.9949 - f1_infection: 0.8143 - val_loss: 0.4932 - val_dice_coef_infection: 0.5279 - val_iou_coef_infection: 0.4995 - val_precision_infection: 0.5088 - val_recall_infection: 0.9436 - val_hausdorff95_infection: 123.0797 - val_specificity_infection: 0.9962 - val_accuracy_infection: 0.9959 - val_f1_infection: 0.7757
# Epoch 8/100
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 196s 172ms/step - loss: 0.3865 - dice_coef_infection: 0.6415 - iou_coef_infection: 0.5053 - precision_infection: 0.6629 - recall_infection: 0.6877 - hausdorff95_infection: 60.4242 - specificity_infection: 0.9976 - accuracy_infection: 0.9951 - f1_infection: 0.8197 - val_loss: 0.5061 - val_dice_coef_infection: 0.5073 - val_iou_coef_infection: 0.4780 - val_precision_infection: 0.4927 - val_recall_infection: 0.9305 - val_hausdorff95_infection: 138.1479 - val_specificity_infection: 0.9973 - val_accuracy_infection: 0.9969 - val_f1_infection: 0.7663
# Epoch 9/100
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 196s 172ms/step - loss: 0.3761 - dice_coef_infection: 0.6512 - iou_coef_infection: 0.5143 - precision_infection: 0.6717 - recall_infection: 0.6798 - hausdorff95_infection: 61.2112 - specificity_infection: 0.9977 - accuracy_infection: 0.9952 - f1_infection: 0.8270 - val_loss: 0.4526 - val_dice_coef_infection: 0.5597 - val_iou_coef_infection: 0.5303 - val_precision_infection: 0.5481 - val_recall_infection: 0.9232 - val_hausdorff95_infection: 114.0007 - val_specificity_infection: 0.9978 - val_accuracy_infection: 0.9974 - val_f1_infection: 0.7945
# Epoch 10/100
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 196s 172ms/step - loss: 0.3708 - dice_coef_infection: 0.6577 - iou_coef_infection: 0.5211 - precision_infection: 0.6848 - recall_infection: 0.6872 - hausdorff95_infection: 56.8776 - specificity_infection: 0.9977 - accuracy_infection: 0.9952 - f1_infection: 0.8251 - val_loss: 0.4465 - val_dice_coef_infection: 0.5737 - val_iou_coef_infection: 0.5460 - val_precision_infection: 0.5570 - val_recall_infection: 0.9354 - val_hausdorff95_infection: 129.5964 - val_specificity_infection: 0.9962 - val_accuracy_infection: 0.9959 - val_f1_infection: 0.7967
# Epoch 11/100
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 196s 171ms/step - loss: 0.3611 - dice_coef_infection: 0.6667 - iou_coef_infection: 0.5285 - precision_infection: 0.6896 - recall_infection: 0.6853 - hausdorff95_infection: 54.7093 - specificity_infection: 0.9977 - accuracy_infection: 0.9953 - f1_infection: 0.8307 - val_loss: 0.3989 - val_dice_coef_infection: 0.6081 - val_iou_coef_infection: 0.5800 - val_precision_infection: 0.6144 - val_recall_infection: 0.8985 - val_hausdorff95_infection: 91.0032 - val_specificity_infection: 0.9991 - val_accuracy_infection: 0.9985 - val_f1_infection: 0.8209
# Epoch 12/100
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 196s 172ms/step - loss: 0.3672 - dice_coef_infection: 0.6580 - iou_coef_infection: 0.5235 - precision_infection: 0.6770 - recall_infection: 0.6850 - hausdorff95_infection: 55.2336 - specificity_infection: 0.9978 - accuracy_infection: 0.9955 - f1_infection: 0.8326 - val_loss: 0.4682 - val_dice_coef_infection: 0.5479 - val_iou_coef_infection: 0.5195 - val_precision_infection: 0.5298 - val_recall_infection: 0.9354 - val_hausdorff95_infection: 136.3140 - val_specificity_infection: 0.9970 - val_accuracy_infection: 0.9967 - val_f1_infection: 0.7872
# Epoch 13/100
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 196s 171ms/step - loss: 0.3530 - dice_coef_infection: 0.6731 - iou_coef_infection: 0.5394 - precision_infection: 0.6969 - recall_infection: 0.7047 - hausdorff95_infection: 55.9753 - specificity_infection: 0.9978 - accuracy_infection: 0.9955 - f1_infection: 0.8309 - val_loss: 0.4414 - val_dice_coef_infection: 0.5672 - val_iou_coef_infection: 0.5377 - val_precision_infection: 0.5623 - val_recall_infection: 0.9145 - val_hausdorff95_infection: 103.4252 - val_specificity_infection: 0.9987 - val_accuracy_infection: 0.9982 - val_f1_infection: 0.7990
# Epoch 14/100
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 196s 171ms/step - loss: 0.3744 - dice_coef_infection: 0.6513 - iou_coef_infection: 0.5189 - precision_infection: 0.6718 - recall_infection: 0.6909 - hausdorff95_infection: 53.9828 - specificity_infection: 0.9977 - accuracy_infection: 0.9955 - f1_infection: 0.8261 - val_loss: 0.3883 - val_dice_coef_infection: 0.6204 - val_iou_coef_infection: 0.5906 - val_precision_infection: 0.6067 - val_recall_infection: 0.9259 - val_hausdorff95_infection: 100.2797 - val_specificity_infection: 0.9983 - val_accuracy_infection: 0.9980 - val_f1_infection: 0.8223
# ✅ Model saved at epoch 14 with val_loss: 0.3883
# Epoch 15/100
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 196s 171ms/step - loss: 0.3624 - dice_coef_infection: 0.6636 - iou_coef_infection: 0.5311 - precision_infection: 0.6939 - recall_infection: 0.6972 - hausdorff95_infection: 53.3801 - specificity_infection: 0.9978 - accuracy_infection: 0.9955 - f1_infection: 0.8288 - val_loss: 0.4047 - val_dice_coef_infection: 0.6027 - val_iou_coef_infection: 0.5744 - val_precision_infection: 0.6025 - val_recall_infection: 0.9050 - val_hausdorff95_infection: 95.4711 - val_specificity_infection: 0.9989 - val_accuracy_infection: 0.9984 - val_f1_infection: 0.8188
# Epoch 16/100
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 196s 172ms/step - loss: 0.3455 - dice_coef_infection: 0.6794 - iou_coef_infection: 0.5473 - precision_infection: 0.7050 - recall_infection: 0.7147 - hausdorff95_infection: 50.2552 - specificity_infection: 0.9979 - accuracy_infection: 0.9958 - f1_infection: 0.8315 - val_loss: 0.4260 - val_dice_coef_infection: 0.5845 - val_iou_coef_infection: 0.5555 - val_precision_infection: 0.5704 - val_recall_infection: 0.9253 - val_hausdorff95_infection: 119.6268 - val_specificity_infection: 0.9980 - val_accuracy_infection: 0.9977 - val_f1_infection: 0.8061
# Epoch 17/100
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 196s 171ms/step - loss: 0.3445 - dice_coef_infection: 0.6802 - iou_coef_infection: 0.5429 - precision_infection: 0.7053 - recall_infection: 0.7024 - hausdorff95_infection: 47.6109 - specificity_infection: 0.9979 - accuracy_infection: 0.9958 - f1_infection: 0.8297 - val_loss: 0.3331 - val_dice_coef_infection: 0.6729 - val_iou_coef_infection: 0.6450 - val_precision_infection: 0.6677 - val_recall_infection: 0.9130 - val_hausdorff95_infection: 72.1072 - val_specificity_infection: 0.9991 - val_accuracy_infection: 0.9986 - val_f1_infection: 0.8538
# ✅ Model saved at epoch 17 with val_loss: 0.3331
# Epoch 18/100
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 196s 171ms/step - loss: 0.3413 - dice_coef_infection: 0.6829 - iou_coef_infection: 0.5505 - precision_infection: 0.7077 - recall_infection: 0.7050 - hausdorff95_infection: 48.5655 - specificity_infection: 0.9978 - accuracy_infection: 0.9958 - f1_infection: 0.8371 - val_loss: 0.4104 - val_dice_coef_infection: 0.5973 - val_iou_coef_infection: 0.5688 - val_precision_infection: 0.5936 - val_recall_infection: 0.9169 - val_hausdorff95_infection: 115.0043 - val_specificity_infection: 0.9989 - val_accuracy_infection: 0.9985 - val_f1_infection: 0.8124
# Epoch 19/100
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 197s 172ms/step - loss: 0.3451 - dice_coef_infection: 0.6813 - iou_coef_infection: 0.5499 - precision_infection: 0.7007 - recall_infection: 0.7047 - hausdorff95_infection: 49.4317 - specificity_infection: 0.9978 - accuracy_infection: 0.9956 - f1_infection: 0.8420 - val_loss: 0.5768 - val_dice_coef_infection: 0.4653 - val_iou_coef_infection: 0.4424 - val_precision_infection: 0.4443 - val_recall_infection: 0.9571 - val_hausdorff95_infection: 154.8610 - val_specificity_infection: 0.9912 - val_accuracy_infection: 0.9911 - val_f1_infection: 0.7436
# Epoch 20/100
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 196s 171ms/step - loss: 0.3382 - dice_coef_infection: 0.6876 - iou_coef_infection: 0.5570 - precision_infection: 0.7188 - recall_infection: 0.7051 - hausdorff95_infection: 45.5872 - specificity_infection: 0.9979 - accuracy_infection: 0.9958 - f1_infection: 0.8386 - val_loss: 0.3909 - val_dice_coef_infection: 0.6188 - val_iou_coef_infection: 0.5900 - val_precision_infection: 0.6036 - val_recall_infection: 0.9298 - val_hausdorff95_infection: 97.7695 - val_specificity_infection: 0.9984 - val_accuracy_infection: 0.9981 - val_f1_infection: 0.8230
# Epoch 21/100
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 196s 172ms/step - loss: 0.3494 - dice_coef_infection: 0.6764 - iou_coef_infection: 0.5449 - precision_infection: 0.7079 - recall_infection: 0.7039 - hausdorff95_infection: 41.2287 - specificity_infection: 0.9979 - accuracy_infection: 0.9959 - f1_infection: 0.8319 - val_loss: 0.5444 - val_dice_coef_infection: 0.4837 - val_iou_coef_infection: 0.4575 - val_precision_infection: 0.4658 - val_recall_infection: 0.9384 - val_hausdorff95_infection: 151.1864 - val_specificity_infection: 0.9941 - val_accuracy_infection: 0.9938 - val_f1_infection: 0.7550
# Epoch 22/100
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 196s 171ms/step - loss: 0.3121 - dice_coef_infection: 0.7122 - iou_coef_infection: 0.5798 - precision_infection: 0.7307 - recall_infection: 0.7349 - hausdorff95_infection: 43.3512 - specificity_infection: 0.9978 - accuracy_infection: 0.9959 - f1_infection: 0.8439 - val_loss: 0.4804 - val_dice_coef_infection: 0.5269 - val_iou_coef_infection: 0.4978 - val_precision_infection: 0.5207 - val_recall_infection: 0.9146 - val_hausdorff95_infection: 119.6724 - val_specificity_infection: 0.9988 - val_accuracy_infection: 0.9983 - val_f1_infection: 0.7786
# Epoch 23/100
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 196s 171ms/step - loss: 0.3249 - dice_coef_infection: 0.6988 - iou_coef_infection: 0.5673 - precision_infection: 0.7189 - recall_infection: 0.7245 - hausdorff95_infection: 41.8811 - specificity_infection: 0.9979 - accuracy_infection: 0.9960 - f1_infection: 0.8414 - val_loss: 0.4105 - val_dice_coef_infection: 0.5975 - val_iou_coef_infection: 0.5681 - val_precision_infection: 0.5913 - val_recall_infection: 0.9144 - val_hausdorff95_infection: 115.9963 - val_specificity_infection: 0.9985 - val_accuracy_infection: 0.9980 - val_f1_infection: 0.8126
# Epoch 24/100
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 196s 171ms/step - loss: 0.3064 - dice_coef_infection: 0.7170 - iou_coef_infection: 0.5842 - precision_infection: 0.7317 - recall_infection: 0.7379 - hausdorff95_infection: 38.1476 - specificity_infection: 0.9978 - accuracy_infection: 0.9959 - f1_infection: 0.8456 - val_loss: 0.4189 - val_dice_coef_infection: 0.5896 - val_iou_coef_infection: 0.5599 - val_precision_infection: 0.5823 - val_recall_infection: 0.9164 - val_hausdorff95_infection: 111.3873 - val_specificity_infection: 0.9985 - val_accuracy_infection: 0.9980 - val_f1_infection: 0.8102
# Epoch 25/100
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 195s 171ms/step - loss: 0.3087 - dice_coef_infection: 0.7156 - iou_coef_infection: 0.5851 - precision_infection: 0.7408 - recall_infection: 0.7312 - hausdorff95_infection: 37.9576 - specificity_infection: 0.9980 - accuracy_infection: 0.9959 - f1_infection: 0.8475 - val_loss: 0.4226 - val_dice_coef_infection: 0.5858 - val_iou_coef_infection: 0.5571 - val_precision_infection: 0.5698 - val_recall_infection: 0.9292 - val_hausdorff95_infection: 115.8712 - val_specificity_infection: 0.9984 - val_accuracy_infection: 0.9981 - val_f1_infection: 0.8078
# Epoch 26/100
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 195s 170ms/step - loss: 0.3144 - dice_coef_infection: 0.7078 - iou_coef_infection: 0.5757 - precision_infection: 0.7358 - recall_infection: 0.7278 - hausdorff95_infection: 37.0679 - specificity_infection: 0.9979 - accuracy_infection: 0.9961 - f1_infection: 0.8408 - val_loss: 0.4744 - val_dice_coef_infection: 0.5332 - val_iou_coef_infection: 0.5037 - val_precision_infection: 0.5266 - val_recall_infection: 0.9175 - val_hausdorff95_infection: 120.7870 - val_specificity_infection: 0.9987 - val_accuracy_infection: 0.9982 - val_f1_infection: 0.7801
# Epoch 27/100
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 194s 170ms/step - loss: 0.3098 - dice_coef_infection: 0.7148 - iou_coef_infection: 0.5874 - precision_infection: 0.7563 - recall_infection: 0.7276 - hausdorff95_infection: 36.9003 - specificity_infection: 0.9980 - accuracy_infection: 0.9961 - f1_infection: 0.8453 - val_loss: 0.3814 - val_dice_coef_infection: 0.6249 - val_iou_coef_infection: 0.5969 - val_precision_infection: 0.6231 - val_recall_infection: 0.9124 - val_hausdorff95_infection: 81.8768 - val_specificity_infection: 0.9991 - val_accuracy_infection: 0.9987 - val_f1_infection: 0.8282
# Epoch 28/100
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 194s 170ms/step - loss: 0.2997 - dice_coef_infection: 0.7242 - iou_coef_infection: 0.5948 - precision_infection: 0.7398 - recall_infection: 0.7465 - hausdorff95_infection: 34.9199 - specificity_infection: 0.9978 - accuracy_infection: 0.9960 - f1_infection: 0.8518 - val_loss: 0.4212 - val_dice_coef_infection: 0.5855 - val_iou_coef_infection: 0.5575 - val_precision_infection: 0.5851 - val_recall_infection: 0.9111 - val_hausdorff95_infection: 77.0009 - val_specificity_infection: 0.9992 - val_accuracy_infection: 0.9987 - val_f1_infection: 0.8100
# Epoch 29/100
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 195s 170ms/step - loss: 0.3021 - dice_coef_infection: 0.7208 - iou_coef_infection: 0.5934 - precision_infection: 0.7384 - recall_infection: 0.7516 - hausdorff95_infection: 36.4880 - specificity_infection: 0.9979 - accuracy_infection: 0.9960 - f1_infection: 0.8485 - val_loss: 0.3742 - val_dice_coef_infection: 0.6322 - val_iou_coef_infection: 0.6040 - val_precision_infection: 0.6280 - val_recall_infection: 0.9176 - val_hausdorff95_infection: 73.2248 - val_specificity_infection: 0.9991 - val_accuracy_infection: 0.9987 - val_f1_infection: 0.8330
# Epoch 30/100
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 194s 170ms/step - loss: 0.3038 - dice_coef_infection: 0.7202 - iou_coef_infection: 0.5919 - precision_infection: 0.7492 - recall_infection: 0.7353 - hausdorff95_infection: 33.8898 - specificity_infection: 0.9980 - accuracy_infection: 0.9961 - f1_infection: 0.8481 - val_loss: 0.4033 - val_dice_coef_infection: 0.6055 - val_iou_coef_infection: 0.5765 - val_precision_infection: 0.5940 - val_recall_infection: 0.9244 - val_hausdorff95_infection: 105.1191 - val_specificity_infection: 0.9986 - val_accuracy_infection: 0.9982 - val_f1_infection: 0.8159
# Epoch 31/100
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 195s 170ms/step - loss: 0.3008 - dice_coef_infection: 0.7208 - iou_coef_infection: 0.5917 - precision_infection: 0.7370 - recall_infection: 0.7386 - hausdorff95_infection: 37.2184 - specificity_infection: 0.9979 - accuracy_infection: 0.9962 - f1_infection: 0.8512 - val_loss: 0.4470 - val_dice_coef_infection: 0.5608 - val_iou_coef_infection: 0.5316 - val_precision_infection: 0.5495 - val_recall_infection: 0.9245 - val_hausdorff95_infection: 113.3439 - val_specificity_infection: 0.9985 - val_accuracy_infection: 0.9982 - val_f1_infection: 0.7933
# Epoch 32/100
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 194s 170ms/step - loss: 0.3118 - dice_coef_infection: 0.7129 - iou_coef_infection: 0.5849 - precision_infection: 0.7526 - recall_infection: 0.7233 - hausdorff95_infection: 35.4871 - specificity_infection: 0.9980 - accuracy_infection: 0.9960 - f1_infection: 0.8474 - val_loss: 0.3948 - val_dice_coef_infection: 0.6124 - val_iou_coef_infection: 0.5841 - val_precision_infection: 0.6106 - val_recall_infection: 0.9124 - val_hausdorff95_infection: 98.2805 - val_specificity_infection: 0.9990 - val_accuracy_infection: 0.9986 - val_f1_infection: 0.8211
# Epoch 33/100
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 194s 170ms/step - loss: 0.2902 - dice_coef_infection: 0.7329 - iou_coef_infection: 0.6020 - precision_infection: 0.7530 - recall_infection: 0.7447 - hausdorff95_infection: 33.4462 - specificity_infection: 0.9980 - accuracy_infection: 0.9961 - f1_infection: 0.8527 - val_loss: 0.3732 - val_dice_coef_infection: 0.6333 - val_iou_coef_infection: 0.6072 - val_precision_infection: 0.6577 - val_recall_infection: 0.8896 - val_hausdorff95_infection: 52.3591 - val_specificity_infection: 0.9995 - val_accuracy_infection: 0.9988 - val_f1_infection: 0.8362
# Epoch 34/100
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 195s 170ms/step - loss: 0.2850 - dice_coef_infection: 0.7380 - iou_coef_infection: 0.6069 - precision_infection: 0.7624 - recall_infection: 0.7501 - hausdorff95_infection: 31.8781 - specificity_infection: 0.9980 - accuracy_infection: 0.9962 - f1_infection: 0.8528 - val_loss: 0.3895 - val_dice_coef_infection: 0.6178 - val_iou_coef_infection: 0.5889 - val_precision_infection: 0.6220 - val_recall_infection: 0.9070 - val_hausdorff95_infection: 92.0150 - val_specificity_infection: 0.9991 - val_accuracy_infection: 0.9986 - val_f1_infection: 0.8226
# Epoch 35/100
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 194s 170ms/step - loss: 0.2926 - dice_coef_infection: 0.7281 - iou_coef_infection: 0.6027 - precision_infection: 0.7441 - recall_infection: 0.7506 - hausdorff95_infection: 31.8948 - specificity_infection: 0.9980 - accuracy_infection: 0.9963 - f1_infection: 0.8556 - val_loss: 0.3931 - val_dice_coef_infection: 0.6141 - val_iou_coef_infection: 0.5846 - val_precision_infection: 0.6149 - val_recall_infection: 0.9108 - val_hausdorff95_infection: 88.0986 - val_specificity_infection: 0.9990 - val_accuracy_infection: 0.9985 - val_f1_infection: 0.8216
# Epoch 36/100
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 194s 170ms/step - loss: 0.2793 - dice_coef_infection: 0.7423 - iou_coef_infection: 0.6156 - precision_infection: 0.7661 - recall_infection: 0.7516 - hausdorff95_infection: 30.1958 - specificity_infection: 0.9981 - accuracy_infection: 0.9964 - f1_infection: 0.8578 - val_loss: 0.4290 - val_dice_coef_infection: 0.5778 - val_iou_coef_infection: 0.5513 - val_precision_infection: 0.5864 - val_recall_infection: 0.9011 - val_hausdorff95_infection: 65.8040 - val_specificity_infection: 0.9992 - val_accuracy_infection: 0.9987 - val_f1_infection: 0.8093
# Epoch 37/100
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 194s 170ms/step - loss: 0.2777 - dice_coef_infection: 0.7448 - iou_coef_infection: 0.6166 - precision_infection: 0.7672 - recall_infection: 0.7520 - hausdorff95_infection: 31.6043 - specificity_infection: 0.9980 - accuracy_infection: 0.9962 - f1_infection: 0.8581 - val_loss: 0.3105 - val_dice_coef_infection: 0.6950 - val_iou_coef_infection: 0.6696 - val_precision_infection: 0.7033 - val_recall_infection: 0.9080 - val_hausdorff95_infection: 34.9839 - val_specificity_infection: 0.9995 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.8676
# ✅ Model saved at epoch 37 with val_loss: 0.3105
# Epoch 38/100
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 194s 170ms/step - loss: 0.2778 - dice_coef_infection: 0.7447 - iou_coef_infection: 0.6172 - precision_infection: 0.7625 - recall_infection: 0.7605 - hausdorff95_infection: 31.1731 - specificity_infection: 0.9981 - accuracy_infection: 0.9963 - f1_infection: 0.8582 - val_loss: 0.3457 - val_dice_coef_infection: 0.6601 - val_iou_coef_infection: 0.6330 - val_precision_infection: 0.6610 - val_recall_infection: 0.9137 - val_hausdorff95_infection: 65.8635 - val_specificity_infection: 0.9993 - val_accuracy_infection: 0.9988 - val_f1_infection: 0.8448
# Epoch 39/100
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 195s 170ms/step - loss: 0.2808 - dice_coef_infection: 0.7411 - iou_coef_infection: 0.6132 - precision_infection: 0.7587 - recall_infection: 0.7538 - hausdorff95_infection: 30.2065 - specificity_infection: 0.9981 - accuracy_infection: 0.9964 - f1_infection: 0.8574 - val_loss: 0.4093 - val_dice_coef_infection: 0.5969 - val_iou_coef_infection: 0.5699 - val_precision_infection: 0.5969 - val_recall_infection: 0.9130 - val_hausdorff95_infection: 84.6934 - val_specificity_infection: 0.9992 - val_accuracy_infection: 0.9987 - val_f1_infection: 0.8151
# Epoch 40/100
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 195s 171ms/step - loss: 0.2549 - dice_coef_infection: 0.7657 - iou_coef_infection: 0.6395 - precision_infection: 0.7771 - recall_infection: 0.7768 - hausdorff95_infection: 27.8560 - specificity_infection: 0.9981 - accuracy_infection: 0.9964 - f1_infection: 0.8656 - val_loss: 0.3746 - val_dice_coef_infection: 0.6311 - val_iou_coef_infection: 0.6061 - val_precision_infection: 0.6433 - val_recall_infection: 0.9039 - val_hausdorff95_infection: 59.7552 - val_specificity_infection: 0.9995 - val_accuracy_infection: 0.9989 - val_f1_infection: 0.8342
# Epoch 41/100
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 196s 171ms/step - loss: 0.2825 - dice_coef_infection: 0.7402 - iou_coef_infection: 0.6141 - precision_infection: 0.7663 - recall_infection: 0.7521 - hausdorff95_infection: 31.0572 - specificity_infection: 0.9981 - accuracy_infection: 0.9963 - f1_infection: 0.8567 - val_loss: 0.3910 - val_dice_coef_infection: 0.6152 - val_iou_coef_infection: 0.5891 - val_precision_infection: 0.6218 - val_recall_infection: 0.9068 - val_hausdorff95_infection: 49.9402 - val_specificity_infection: 0.9993 - val_accuracy_infection: 0.9988 - val_f1_infection: 0.8264
# Epoch 42/100
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 195s 171ms/step - loss: 0.2842 - dice_coef_infection: 0.7404 - iou_coef_infection: 0.6111 - precision_infection: 0.7652 - recall_infection: 0.7498 - hausdorff95_infection: 26.6979 - specificity_infection: 0.9981 - accuracy_infection: 0.9961 - f1_infection: 0.8556 - val_loss: 0.4193 - val_dice_coef_infection: 0.5884 - val_iou_coef_infection: 0.5600 - val_precision_infection: 0.5974 - val_recall_infection: 0.9013 - val_hausdorff95_infection: 82.9999 - val_specificity_infection: 0.9992 - val_accuracy_infection: 0.9986 - val_f1_infection: 0.8103
# Epoch 43/100
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 195s 171ms/step - loss: 0.2727 - dice_coef_infection: 0.7470 - iou_coef_infection: 0.6223 - precision_infection: 0.7675 - recall_infection: 0.7608 - hausdorff95_infection: 26.1673 - specificity_infection: 0.9982 - accuracy_infection: 0.9966 - f1_infection: 0.8598 - val_loss: 0.3756 - val_dice_coef_infection: 0.6307 - val_iou_coef_infection: 0.6038 - val_precision_infection: 0.6425 - val_recall_infection: 0.9020 - val_hausdorff95_infection: 60.4393 - val_specificity_infection: 0.9994 - val_accuracy_infection: 0.9988 - val_f1_infection: 0.8321
# Epoch 44/100
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 195s 170ms/step - loss: 0.2677 - dice_coef_infection: 0.7532 - iou_coef_infection: 0.6269 - precision_infection: 0.7735 - recall_infection: 0.7694 - hausdorff95_infection: 29.0152 - specificity_infection: 0.9981 - accuracy_infection: 0.9964 - f1_infection: 0.8588 - val_loss: 0.4078 - val_dice_coef_infection: 0.5977 - val_iou_coef_infection: 0.5721 - val_precision_infection: 0.6103 - val_recall_infection: 0.9022 - val_hausdorff95_infection: 67.6267 - val_specificity_infection: 0.9996 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.8162
# Epoch 45/100
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 194s 170ms/step - loss: 0.2684 - dice_coef_infection: 0.7528 - iou_coef_infection: 0.6286 - precision_infection: 0.7764 - recall_infection: 0.7635 - hausdorff95_infection: 29.5125 - specificity_infection: 0.9982 - accuracy_infection: 0.9965 - f1_infection: 0.8613 - val_loss: 0.4026 - val_dice_coef_infection: 0.6043 - val_iou_coef_infection: 0.5756 - val_precision_infection: 0.6119 - val_recall_infection: 0.9020 - val_hausdorff95_infection: 71.3113 - val_specificity_infection: 0.9993 - val_accuracy_infection: 0.9987 - val_f1_infection: 0.8186
# Epoch 46/100
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 194s 170ms/step - loss: 0.2714 - dice_coef_infection: 0.7518 - iou_coef_infection: 0.6272 - precision_infection: 0.7824 - recall_infection: 0.7608 - hausdorff95_infection: 26.0377 - specificity_infection: 0.9982 - accuracy_infection: 0.9964 - f1_infection: 0.8599 - val_loss: 0.4186 - val_dice_coef_infection: 0.5877 - val_iou_coef_infection: 0.5611 - val_precision_infection: 0.6001 - val_recall_infection: 0.8998 - val_hausdorff95_infection: 73.7553 - val_specificity_infection: 0.9994 - val_accuracy_infection: 0.9988 - val_f1_infection: 0.8123
# Epoch 47/100
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 195s 170ms/step - loss: 0.2713 - dice_coef_infection: 0.7503 - iou_coef_infection: 0.6233 - precision_infection: 0.7749 - recall_infection: 0.7592 - hausdorff95_infection: 26.4993 - specificity_infection: 0.9982 - accuracy_infection: 0.9965 - f1_infection: 0.8588 - val_loss: 0.3429 - val_dice_coef_infection: 0.6645 - val_iou_coef_infection: 0.6378 - val_precision_infection: 0.6899 - val_recall_infection: 0.8885 - val_hausdorff95_infection: 42.3858 - val_specificity_infection: 0.9995 - val_accuracy_infection: 0.9988 - val_f1_infection: 0.8511
# Epoch 48/100
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 195s 171ms/step - loss: 0.2721 - dice_coef_infection: 0.7492 - iou_coef_infection: 0.6262 - precision_infection: 0.7773 - recall_infection: 0.7571 - hausdorff95_infection: 27.6092 - specificity_infection: 0.9983 - accuracy_infection: 0.9966 - f1_infection: 0.8608 - val_loss: 0.3905 - val_dice_coef_infection: 0.6166 - val_iou_coef_infection: 0.5913 - val_precision_infection: 0.6438 - val_recall_infection: 0.8860 - val_hausdorff95_infection: 55.1474 - val_specificity_infection: 0.9996 - val_accuracy_infection: 0.9988 - val_f1_infection: 0.8282
# Epoch 49/100
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 195s 171ms/step - loss: 0.2527 - dice_coef_infection: 0.7669 - iou_coef_infection: 0.6409 - precision_infection: 0.7819 - recall_infection: 0.7761 - hausdorff95_infection: 25.3841 - specificity_infection: 0.9982 - accuracy_infection: 0.9966 - f1_infection: 0.8662 - val_loss: 0.3533 - val_dice_coef_infection: 0.6544 - val_iou_coef_infection: 0.6288 - val_precision_infection: 0.6847 - val_recall_infection: 0.8818 - val_hausdorff95_infection: 48.1308 - val_specificity_infection: 0.9996 - val_accuracy_infection: 0.9987 - val_f1_infection: 0.8477
# Epoch 50/100
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 195s 171ms/step - loss: 0.2650 - dice_coef_infection: 0.7561 - iou_coef_infection: 0.6325 - precision_infection: 0.7771 - recall_infection: 0.7657 - hausdorff95_infection: 28.0421 - specificity_infection: 0.9981 - accuracy_infection: 0.9965 - f1_infection: 0.8637 - val_loss: 0.3472 - val_dice_coef_infection: 0.6595 - val_iou_coef_infection: 0.6341 - val_precision_infection: 0.6836 - val_recall_infection: 0.8877 - val_hausdorff95_infection: 50.3759 - val_specificity_infection: 0.9995 - val_accuracy_infection: 0.9988 - val_f1_infection: 0.8499
# Epoch 51/100
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 196s 171ms/step - loss: 0.2625 - dice_coef_infection: 0.7595 - iou_coef_infection: 0.6355 - precision_infection: 0.7790 - recall_infection: 0.7728 - hausdorff95_infection: 27.0683 - specificity_infection: 0.9980 - accuracy_infection: 0.9963 - f1_infection: 0.8630 - val_loss: 0.3622 - val_dice_coef_infection: 0.6434 - val_iou_coef_infection: 0.6180 - val_precision_infection: 0.6620 - val_recall_infection: 0.8942 - val_hausdorff95_infection: 61.2735 - val_specificity_infection: 0.9996 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.8386
# Epoch 52/100
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 195s 171ms/step - loss: 0.2648 - dice_coef_infection: 0.7560 - iou_coef_infection: 0.6312 - precision_infection: 0.7769 - recall_infection: 0.7696 - hausdorff95_infection: 25.9897 - specificity_infection: 0.9982 - accuracy_infection: 0.9965 - f1_infection: 0.8627 - val_loss: 0.3821 - val_dice_coef_infection: 0.6249 - val_iou_coef_infection: 0.5980 - val_precision_infection: 0.6404 - val_recall_infection: 0.8916 - val_hausdorff95_infection: 66.6301 - val_specificity_infection: 0.9994 - val_accuracy_infection: 0.9987 - val_f1_infection: 0.8307
# Epoch 53/100
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 196s 171ms/step - loss: 0.2603 - dice_coef_infection: 0.7596 - iou_coef_infection: 0.6357 - precision_infection: 0.7873 - recall_infection: 0.7670 - hausdorff95_infection: 25.3270 - specificity_infection: 0.9982 - accuracy_infection: 0.9966 - f1_infection: 0.8634 - val_loss: 0.3659 - val_dice_coef_infection: 0.6409 - val_iou_coef_infection: 0.6146 - val_precision_infection: 0.6637 - val_recall_infection: 0.8872 - val_hausdorff95_infection: 56.9088 - val_specificity_infection: 0.9995 - val_accuracy_infection: 0.9988 - val_f1_infection: 0.8375
# Epoch 54/100
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 196s 171ms/step - loss: 0.2647 - dice_coef_infection: 0.7546 - iou_coef_infection: 0.6355 - precision_infection: 0.7825 - recall_infection: 0.7643 - hausdorff95_infection: 24.5221 - specificity_infection: 0.9982 - accuracy_infection: 0.9967 - f1_infection: 0.8647 - val_loss: 0.3622 - val_dice_coef_infection: 0.6446 - val_iou_coef_infection: 0.6180 - val_precision_infection: 0.6580 - val_recall_infection: 0.8944 - val_hausdorff95_infection: 55.1341 - val_specificity_infection: 0.9993 - val_accuracy_infection: 0.9987 - val_f1_infection: 0.8415
# Epoch 55/100
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 196s 171ms/step - loss: 0.2641 - dice_coef_infection: 0.7581 - iou_coef_infection: 0.6336 - precision_infection: 0.7828 - recall_infection: 0.7661 - hausdorff95_infection: 26.0562 - specificity_infection: 0.9981 - accuracy_infection: 0.9963 - f1_infection: 0.8626 - val_loss: 0.4051 - val_dice_coef_infection: 0.6009 - val_iou_coef_infection: 0.5762 - val_precision_infection: 0.6216 - val_recall_infection: 0.8878 - val_hausdorff95_infection: 76.5175 - val_specificity_infection: 0.9996 - val_accuracy_infection: 0.9989 - val_f1_infection: 0.8212
# Epoch 56/100
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 196s 171ms/step - loss: 0.2569 - dice_coef_infection: 0.7629 - iou_coef_infection: 0.6409 - precision_infection: 0.7815 - recall_infection: 0.7787 - hausdorff95_infection: 24.8698 - specificity_infection: 0.9982 - accuracy_infection: 0.9966 - f1_infection: 0.8658 - val_loss: 0.3703 - val_dice_coef_infection: 0.6372 - val_iou_coef_infection: 0.6105 - val_precision_infection: 0.6567 - val_recall_infection: 0.8912 - val_hausdorff95_infection: 54.1122 - val_specificity_infection: 0.9994 - val_accuracy_infection: 0.9987 - val_f1_infection: 0.8363
# Epoch 57/100
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 195s 171ms/step - loss: 0.2427 - dice_coef_infection: 0.7764 - iou_coef_infection: 0.6518 - precision_infection: 0.7913 - recall_infection: 0.7810 - hausdorff95_infection: 21.5000 - specificity_infection: 0.9983 - accuracy_infection: 0.9967 - f1_infection: 0.8699 - val_loss: 0.4323 - val_dice_coef_infection: 0.5762 - val_iou_coef_infection: 0.5519 - val_precision_infection: 0.6054 - val_recall_infection: 0.8800 - val_hausdorff95_infection: 83.6544 - val_specificity_infection: 0.9995 - val_accuracy_infection: 0.9987 - val_f1_infection: 0.8081
# 🛑 Early stopping at epoch 57
# ✅ Total training time: 11161.65 seconds (186.03 minutes)

# %% [markdown]
# ## Plotting the performance metrics

# %%
plt.plot(history.history['dice_coef_infection'])
plt.plot(history.history['val_dice_coef_infection'])
plt.title('dice_coef_infection vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Dice_coef')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# %%
plt.plot(history.history['iou_coef_infection'])
plt.plot(history.history['val_iou_coef_infection'])
plt.title('iou_coef_infection vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Iou_coef')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Val'], loc = 'upper right')
plt.show()

# %% [markdown]
# ## Using our trained model for prediction

# %%
import numpy as np
import time

# Start timer (high precision)
start_time = time.perf_counter()

# Evaluate the model on the validation generator
results = model.evaluate(val_gen, verbose=1)

# End timer
end_time = time.perf_counter()

# Calculate evaluation time
eval_time = end_time - start_time

# Print metric names with results
print("\n===== Validation Metrics =====")
for name, value in zip(model.metrics_names, results):
    print(f"{name}: {value:.6f}")

print(f"\nEvaluation Time: {eval_time:.8f} seconds\n")
# Out:
# 128/128 [==============================] - 8s 62ms/step - loss: 0.4077 - dice_coef_infection: 0.6239 - iou_coef_infection: 0.5743 - precision_infection: 0.7001 - recall_infection: 0.7843 - hausdorff95_infection: 57.4151 - specificity_infection: 0.9988 - accuracy_infection: 0.9964 - f1_infection: 0.8255
#
# ===== Validation Metrics =====
# loss: 0.407677
# dice_coef_infection: 0.623885
# iou_coef_infection: 0.574266
# precision_infection: 0.700100
# recall_infection: 0.784271
# hausdorff95_infection: 57.415142
# specificity_infection: 0.998828
# accuracy_infection: 0.996392
# f1_infection: 0.825482
#
# Evaluation Time: 7.96875445 seconds

# %%
import matplotlib.pyplot as plt
import numpy as np

# Run inference if not already done
predicted = model.predict(lung_test)

# Selected indices to visualize (744 as 1st, 280 as 2nd, 230 as 3rd)
selected_indices = [744, 280, 230]
n_samples = len(selected_indices)

# Mapping indices to custom names
name_mapping = {
    0: ("Image1_Covid", "GT1_Covid", "Predict1_Covid_DSEG_Unet"),  # Index 744
    1: ("Image2_Covid", "GT2_Covid", "Predict2_Covid_DSEG_Unet"),  # Index 280
    2: ("Image3_Covid", "GT3_Covid", "Predict3_Covid_DSEG_Unet")   # Index 230
}

# Plot
for j, i in enumerate(selected_indices):
    lung_img = lung_test[i][..., 0].astype(np.float32)
    gt_infect = (infect_test[i][..., 0] > 0.5).astype(np.float32)
    pred_infect = predicted[i][..., 0].astype(np.float32)

    # Normalize lung image
    if lung_img.max() > lung_img.min():
        lung_img = (lung_img - lung_img.min()) / (lung_img.max() - lung_img.min())
    lung_img = np.clip(lung_img, 0, 1)
    pred_infect = np.clip(pred_infect, 0, 1)

    # Get custom names for this index
    input_name, gt_name, pred_name = name_mapping[j]

    # Save Original Lung
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{input_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

    # Save Ground Truth Infection
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.imshow(gt_infect, cmap='Reds', alpha=0.6)
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{gt_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

    # Save Predicted Infection
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.imshow(pred_infect, cmap='Reds', alpha=0.6)
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{pred_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

print("Separate JPEG files saved for input images (Image1_Covid, Image2_Covid, Image3_Covid), "
      "ground truths (GT1_Covid, GT2_Covid, GT3_Covid), and predictions "
      "(Predict1_Covid_DSEG_Unet, Predict2_Covid_DSEG_Unet, Predict3_Covid_DSEG_Unet).")
# Out:
# Separate JPEG files saved for input images (Image1_Covid, Image2_Covid, Image3_Covid), ground truths (GT1_Covid, GT2_Covid, GT3_Covid), and predictions (Predict1_Covid_DSEG_Unet, Predict2_Covid_DSEG_Unet, Predict3_Covid_DSEG_Unet).
