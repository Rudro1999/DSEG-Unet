# %% [markdown]
# ## Importing important libraries

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import nibabel as nib #for loading nii files
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf #for deep learning

# %% [markdown]
# ## Reading the metadata

# %%
data = pd.read_csv('../input/covid19-ct-scans/metadata.csv')
data.head()
# Out:
#                                              ct_scan  \
# 0  ../input/covid19-ct-scans/ct_scans/coronacases...
# 1  ../input/covid19-ct-scans/ct_scans/coronacases...
# 2  ../input/covid19-ct-scans/ct_scans/coronacases...
# 3  ../input/covid19-ct-scans/ct_scans/coronacases...
# 4  ../input/covid19-ct-scans/ct_scans/coronacases...
#
#                                            lung_mask  \
# 0  ../input/covid19-ct-scans/lung_mask/coronacase...
# 1  ../input/covid19-ct-scans/lung_mask/coronacase...
# 2  ../input/covid19-ct-scans/lung_mask/coronacase...
# 3  ../input/covid19-ct-scans/lung_mask/coronacase...
# 4  ../input/covid19-ct-scans/lung_mask/coronacase...
#
#                                       infection_mask  \
# 0  ../input/covid19-ct-scans/infection_mask/coron...
# 1  ../input/covid19-ct-scans/infection_mask/coron...
# 2  ../input/covid19-ct-scans/infection_mask/coron...
# 3  ../input/covid19-ct-scans/infection_mask/coron...
# 4  ../input/covid19-ct-scans/infection_mask/coron...
#
#                              lung_and_infection_mask
# 0  ../input/covid19-ct-scans/lung_and_infection_m...
# 1  ../input/covid19-ct-scans/lung_and_infection_m...
# 2  ../input/covid19-ct-scans/lung_and_infection_m...
# 3  ../input/covid19-ct-scans/lung_and_infection_m...
# 4  ../input/covid19-ct-scans/lung_and_infection_m...

# %% [markdown]
# ## Defining function for readiing .nii files

# %%
def read_nii(filepath):
    '''
    Reads .nii file and returns pixel array
    '''
    ct_scan = nib.load(filepath)
    array   = ct_scan.get_fdata()
    array   = np.rot90(np.array(array))
    return(array)

# %% [markdown]
# ## Reading the chest ct scan data

# %%
# Read sample
sample_ct   = read_nii(data.loc[2,'ct_scan'])
sample_lung = read_nii(data.loc[2,'lung_mask'])
sample_infe = read_nii(data.loc[2,'infection_mask'])
sample_all  = read_nii(data.loc[2,'lung_and_infection_mask'])

# %% [markdown]
# ## Plotting the sample images

# %%
fig = plt.figure(figsize = (18,15))
plt.subplot(1,4,1)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.title('Original Image')

plt.subplot(1,4,2)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_lung[..., 150],alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung Mask')

plt.subplot(1,4,3)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_infe[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Infection Mask')

plt.subplot(1,4,4)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_all[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung and Infection Mask')
# Out:
# Text(0.5, 1.0, 'Lung and Infection Mask')

# %% [markdown]
# ## Converting the data into array for training model

# %%
import numpy as np
import cv2
import random
from scipy.ndimage import rotate, shift, zoom

lungs = []
infections = []
case_ids = []
img_size = 320

# ----------- Load and Resize Data -----------
for case_index in range(len(data)):
    ct = read_nii(data['ct_scan'][case_index])
    infect = read_nii(data['infection_mask'][case_index])

    for slice_index in range(ct.shape[0]):
        lung_img = cv2.resize(ct[slice_index], dsize=(img_size, img_size)).astype('float32')
        infec_img = cv2.resize(infect[slice_index], dsize=(img_size, img_size)).astype('float32')

        lungs.append(lung_img[..., np.newaxis])
        infections.append(infec_img[..., np.newaxis])
        case_ids.append(case_index)

# %%
import numpy as np

# case_ids should be a NumPy array telling which case each slice belongs to
# Convert and binarize
lungs = np.array(lungs, dtype=np.float32)
infections = (np.array(infections, dtype=np.uint8) > 0.5).astype(np.uint8)
case_ids = np.array(case_ids)

# %% [markdown]
# ## Performing test and train split

# %%
# ----------- Case-wise Split -----------
unique_cases = np.unique(case_ids)
train_cases = np.append(unique_cases[4:12], unique_cases[12:20])
temp_cases = unique_cases[2:4]
val_cases = unique_cases[:2]

train_mask = np.isin(case_ids, train_cases)
temp_mask = np.isin(case_ids, temp_cases)
val_mask = np.isin(case_ids, val_cases)

lung_train = lungs[train_mask]
infect_train = infections[train_mask]
lung_temp = lungs[temp_mask]
infect_temp = infections[temp_mask]
lung_test = lungs[val_mask]
infect_test = infections[val_mask]

print(f"✅ Train: {lung_train.shape[0]} slices from {len(train_cases)} cases")
print(f"✅ Validation: {lung_temp.shape[0]} slices from {len(temp_cases)} cases")
print(f"✅ Test: {lung_test.shape[0]} slices from {len(val_cases)} cases")

# ----------- Augmentation -----------
def augment_image(img, mask):
    if random.random() < 0.5:
        img = np.fliplr(img)
        mask = np.fliplr(mask)
    if random.random() < 0.5:
        img = np.flipud(img)
        mask = np.flipud(mask)

    angle = random.uniform(-15, 15)
    img = rotate(img, angle, reshape=False, order=1, mode='nearest')
    mask = rotate(mask, angle, reshape=False, order=0, mode='nearest')

    shift_val = np.random.uniform(-0.1, 0.1, size=2) * img.shape[:2]
    img = shift(img, shift=(*shift_val, 0), order=1, mode='nearest')
    mask = shift(mask, shift=(*shift_val, 0), order=0, mode='nearest')

    zoom_factor = random.uniform(0.9, 1.1)
    img = zoom(img, (zoom_factor, zoom_factor, 1), order=1)
    mask = zoom(mask, (zoom_factor, zoom_factor, 1), order=0)

    return fix_shape(img), fix_shape(mask)

def fix_shape(arr, target_size=(320, 320)):
    h, w, c = arr.shape
    th, tw = target_size
    dh = th - h
    dw = tw - w
    if dh > 0 or dw > 0:
        pad_h = (max(dh // 2, 0), max(dh - dh // 2, 0))
        pad_w = (max(dw // 2, 0), max(dw - dw // 2, 0))
        arr = np.pad(arr, (pad_h, pad_w, (0, 0)), mode='constant')
    arr = arr[:th, :tw, :]
    return arr.astype('float32')

# ----------- Apply Augmentation -----------
aug_lung_train = []
aug_infect_train = []

for i in range(len(lung_train)):
    img, mask = augment_image(lung_train[i], infect_train[i])
    aug_lung_train.append(img)
    aug_infect_train.append(mask)

lung_train = np.stack(aug_lung_train)
infect_train = np.stack(aug_infect_train)

# Final Binarization
infect_train = (infect_train > 0.5).astype(np.uint8)
infect_test = (infect_test > 0.5).astype(np.uint8)

print(f"✅ Augmented training shape: {lung_train.shape}")
print("✅ All preprocessing complete.")
# Out:
# ✅ Train: 9143 slices from 16 cases
# ✅ Validation: 1024 slices from 2 cases
# ✅ Test: 1024 slices from 2 cases
# ✅ Augmented training shape: (9143, 320, 320, 1)
# ✅ All preprocessing complete.

# %%
import tensorflow as tf
from tensorflow.keras import backend as K
import numpy as np
from scipy.spatial import cKDTree

smooth = 1.0

# Binary Dice coefficient (soft - commonly used during training)
def dice_coef_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# Binary IoU coefficient (soft)
def iou_coef_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# Soft Precision
def precision_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + smooth) / (K.sum(y_pred_f) + smooth)

# Soft Recall (Sensitivity)
def recall_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + smooth) / (K.sum(y_true_f) + smooth)

# Soft Specificity
def specificity_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    tn = K.sum((1 - y_true_f) * (1 - y_pred_f))
    fp = K.sum((1 - y_true_f) * y_pred_f)
    return (tn + smooth) / (tn + fp + smooth)

# Soft Accuracy
def accuracy_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    tp = K.sum(y_true_f * y_pred_f)
    tn = K.sum((1 - y_true_f) * (1 - y_pred_f))
    total = K.cast(K.shape(y_true_f)[0], 'float32')
    return (tp + tn + smooth) / (total + smooth)

# Soft F1-score (harmonic mean of precision & recall - very close to Dice, standard in many repos)
def f1_infection(y_true, y_pred):
    precision = precision_infection(y_true, y_pred)
    recall    = recall_infection(y_true, y_pred)
    return (2. * precision * recall + smooth) / (precision + recall + smooth)

# Hausdorff Distance 95 % (robust & most commonly used in medical imaging challenges)
# Lower = better. Returns the mean HD95 over the batch.
def _calculate_hd95(y_true, y_pred):
    hd_list = []
    for i in range(y_true.shape[0]):
        # Hard threshold at 0.5 (standard for evaluation metrics)
        gt = np.squeeze(y_true[i]) > 0.5
        pred = np.squeeze(y_pred[i]) > 0.5

        gt_pts = np.argwhere(gt)
        pred_pts = np.argwhere(pred)

        # Cases with empty masks
        if gt_pts.shape[0] == 0 and pred_pts.shape[0] == 0:
            hd_list.append(0.0)
            continue
        if gt_pts.shape[0] == 0 or pred_pts.shape[0] == 0:
            hd_list.append(400.0)  # large penalty - adjust to your image diagonal if needed (e.g. ~362 for 256×256, ~724 for 512×512)
            continue

        # Directed distances
        dist_gt_to_pred = cKDTree(pred_pts).query(gt_pts)[0]
        dist_pred_to_gt = cKDTree(gt_pts).query(pred_pts)[0]

        hd95 = max(
            np.percentile(dist_gt_to_pred, 95),
            np.percentile(dist_pred_to_gt, 95)
        )
        hd_list.append(hd95)

    return np.mean(hd_list, dtype=np.float32)

def hausdorff95_infection(y_true, y_pred):
    hd = tf.numpy_function(_calculate_hd95, [y_true, y_pred], tf.float32)
    hd.set_shape(())
    return hd

# Optional: KL Divergence (you already had this)
kld = tf.keras.losses.KLDivergence()

# %%
from tensorflow.keras.losses import BinaryCrossentropy

def loss_f(y_true, y_pred):
    bce = BinaryCrossentropy()
    return dice_loss(y_true, y_pred) + bce(y_true, y_pred) 

def loss_e(y_true, y_pred):
    bce = BinaryCrossentropy()
    return dice_loss(y_true, y_pred)  + kld(y_true, y_pred)
    
def dice_loss(y_true, y_pred):
    return 1. - dice_coef_infection(y_true, y_pred)

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Multiply, Conv2D, DepthwiseConv2D, Dense, Flatten, MaxPooling2D, UpSampling2D, concatenate, Activation, LayerNormalization, Add, Dropout, Conv2DTranspose, multiply, Reshape, GlobalAveragePooling2D, Permute, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Concatenate

def activation_block(x):
    x = Activation("gelu")(x)
    return LayerNormalization()(x)

def conv_stem(x, filters: int, patch_size: int):
    x = Conv2D(filters, kernel_size=patch_size,padding='same', strides=patch_size)(x)
    return activation_block(x)

def vector_block(xyz, cmf, red):
    # red means reduction
    # cmf means filters, denotes vector size
    opt1 = conv_stem(xyz, cmf, red)
    opt2 = conv_stem(xyz, cmf, red)
    
    o1 = GlobalAveragePooling2D()(opt1)
    o2 = GlobalAveragePooling2D()(opt2)

    o5 = concatenate([o1, o2], -1)
    return o5

def mlp_feature(vect, cmf):
    oo = Flatten()(vect)
    o6 = Dense(cmf, activation='gelu')(oo)
    o6 = Dropout(0.2)(o6)
    o6 = Dense(cmf * 2, activation='gelu')(o6)

    o6 = Reshape((1, cmf * 2))(o6)
    o7 = Permute((2, 1))(o6)

    o8 = multiply([o6, o7])
    
    o8 = Lambda(lambda x: tf.expand_dims(x, -1))(o8)
    
    o8 = Reshape((cmf, cmf, 4))(o8)

    return o8

def frz_block(xyz):
    shape = xyz.shape
    a1, a2, a3, a4 = shape[0], shape[1], shape[2], shape[3]
    cmf = a2
    o5 = vector_block(xyz, cmf, 5)
    o7 = mlp_feature(o5, cmf)

    o7 = concatenate([o7, xyz, o7], -1)
    return o7

def up_frz(x1, x2, n_filters):
    # Upsample x1 using Conv2DTranspose
    x1 = Conv2DTranspose(n_filters * 4, 3, strides=2, activation='gelu', padding="same")(x1)
    
    # Apply Conv2D to x2
    x2 = Conv2D(n_filters * 2, 3, activation='gelu', padding="same")(x2)
    
    # Apply attention mechanism
    x = concatenate([x1, x2])
    
    # Apply Dropout for regularization
    x = Dropout(0.3)(x)
    
    return x

def regu(x):
    filters = x.shape[-1]
    shortcut = x
    x = Conv2D(filters, (3, 3), activation='gelu', padding="same")(x)
    x = Add()([x, shortcut])
    return x

# %%
def squeeze_and_excite_block(inputs, ratio=24):
    """ Squeeze and Excitation block to recalibrate channel-wise features """
    filters = inputs.shape[-1]  # Number of input channels
    se_shape = (1, 1, filters)

    # Squeeze: Global Average Pooling
    se = GlobalAveragePooling2D()(inputs)
    se = Reshape(se_shape)(se)

    a = filters // ratio

    # Excitation: Dense layers to capture channel-wise dependencies
    if a > 8:
        se = Conv2D(filters // ratio, kernel_size=1, activation='swish', padding='same')(se)
        se = Conv2D(filters, kernel_size=1, activation='sigmoid', padding='same')(se)
    else:
        se = Conv2D(8, kernel_size=1, activation='swish', padding='same')(se)
        se = Conv2D(filters, kernel_size=1, activation='sigmoid', padding='same')(se)

    # Scale the input by channel-wise weights
    x = multiply([inputs, se])

    return x

def residual_block(x, filters, stride=1, padding='same'):
    shortcut = x
    x = Conv2D(filters * 6, 1, strides=stride, padding=padding, use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)
    x = DepthwiseConv2D(kernel_size=3, strides=stride, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)
    x = squeeze_and_excite_block(x)
    x = Conv2D(filters, 1, strides=stride, padding=padding, use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)
    x = Add()([x, shortcut])
    return x

def dense_block(inputs, num_layers, growth_rate, ratio=16):
    """Dense block where each layer is connected to all previous layers."""
    concat_features = inputs
    for i in range(num_layers):
        # BatchNorm -> ReLU -> Conv2D
        x = Conv2D(growth_rate, 3, activation='gelu', padding='same')(concat_features)

        # Concatenate input with new output (dense connection)
        concat_features = Concatenate()([concat_features, x])
        
    x = squeeze_and_excite_block(concat_features)

    return x

def attention_gate(X, g, channel,  
                   activation='ReLU', 
                   attention='add', name='att'):
    '''
    Self-attention gate modified from Oktay et al. 2018.
    
    attention_gate(X, g, channel,  activation='ReLU', attention='add', name='att')
    
    Input
    ----------
        X: input tensor, i.e., key and value.
        g: gated tensor, i.e., query.
        channel: number of intermediate channel.
                 Oktay et al. (2018) did not specify (denoted as F_int).
                 intermediate channel is expected to be smaller than the input channel.
        activation: a nonlinear attnetion activation.
                    The `sigma_1` in Oktay et al. 2018. Default is 'ReLU'.
        attention: 'add' for additive attention; 'multiply' for multiplicative attention.
                   Oktay et al. 2018 applied additive attention.
        name: prefix of the created keras layers.
        
    Output
    ----------
        X_att: output tensor.
    
    '''

    attention_func = eval(attention)
    
    # mapping the input tensor to the intermediate channel
    theta_att = Conv2D(channel, 1, use_bias=True)(X)
    
    # mapping the gate tensor
    phi_g = Conv2D(channel, 1, use_bias=True)(g)
    
    # ----- attention learning ----- #
    query = attention_func([theta_att, phi_g])
    
    # nonlinear activation
    f = Activation('gelu')(query)
    
    # linear transformation
    psi_f = Conv2D(1, 1, use_bias=True)(f)
    # ------------------------------ #
    
    # sigmoid activation as attention coefficients
    coef_att = Activation('sigmoid')(psi_f)
    
    # multiplicative attention masking
    X_att = multiply([X, coef_att])
    
    return X_att

inputs = (img_size, img_size, 1)

def model_build_func(input_shape, n_labels):
    inputs = Input(shape=input_shape, name='input_image')
    g_filter = 16
    u_filter = 8

    # Initial convolution
    initial = Conv2D(g_filter, (3, 3), activation='gelu', padding="same")(inputs)
    initial = dense_block(initial, 2, g_filter // 2)  # 80

    # Down-sampling path
    o1 = MaxPooling2D(2)(initial)
    o1 = dense_block(o1, 2, g_filter)  # 40
    #o1 = squeeze_and_excite_block(o1)

    o2 = MaxPooling2D(2)(o1)
    o2 = dense_block(o2, 2, g_filter * 2)  # 20
    #o2 = squeeze_and_excite_block(o2)

    o3 = MaxPooling2D(2)(o2)
    o3 = dense_block(o3, 2, g_filter * 4)  # 10
    #o3 = squeeze_and_excite_block(o3)

    o4 = MaxPooling2D(2)(o3)
    o4 = dense_block(o4, 2, g_filter * 8)  # 5
    #o4 = squeeze_and_excite_block(o4)

    o5 = MaxPooling2D(2)(o4)
    o5 = dense_block(o5, 2, g_filter * 16)  # 5
    #o5 = squeeze_and_excite_block(o5)

    # Up-sampling path
    u1 = up_frz(o5, o4, u_filter * 16)  # 10
    #gate1 = attention_gate(o4, u1, u_filter * 16, attention='add')
    cu1 = concatenate([u1, o4])

    u2 = up_frz(cu1, o3, u_filter * 8)  # 20
    #gate2 = attention_gate(o3, u2, u_filter * 8, attention='add')
    cu2 = concatenate([u2, o3])  # 20

    u3 = up_frz(cu2, o2, u_filter * 4)  # 40
    #gate3 = attention_gate(o2, u3, u_filter * 4, attention='add')
    cu3 = concatenate([u3, o2])  # 40

    u4 = up_frz(cu3, o1, u_filter * 2)  # 80
    #gate4 = attention_gate(o1, u4, u_filter * 2, attention='add')
    cu4 = concatenate([u4, o1])  # 80

    u5 = Conv2DTranspose(u_filter * 4, 3, strides=2, activation='gelu', padding="same")(cu4)  # 80
    #gate5 = attention_gate(initial, u5, u_filter, attention='add')
    cu5 = concatenate([u5, initial])  # 80

    # Final segmentation map
    seg_map = Conv2D(n_labels, 3, activation='sigmoid', padding="same")(cu5)

    # Model definition
    model = Model(inputs=inputs, outputs=seg_map)

    return model


model = model_build_func(inputs, 1)

from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2_as_graph

def get_flops(model):
    """Calculate Floating Point Operations (FLOPs) of a Keras model in TensorFlow 2.x."""
    # Convert Keras model to a TensorFlow function
    concrete_func = tf.function(lambda inputs: model(inputs))
    concrete_func = concrete_func.get_concrete_function(
        tf.TensorSpec([1] + list(model.input_shape[1:]), model.input.dtype)
    )

    # Convert to frozen graph
    frozen_func, _ = convert_variables_to_constants_v2_as_graph(concrete_func)

    # Compute FLOPs
    flops = tf.compat.v1.profiler.profile(
        frozen_func.graph,
        options=tf.compat.v1.profiler.ProfileOptionBuilder.float_operation(),
    )

    return flops.total_float_ops

# Compute FLOPs
flops = get_flops(model)
print(f"Total FLOPs: {flops / 1e9:.2f} GFLOPs")  # Convert to GFLOPs

from tensorflow.keras.optimizers import Adam

optimizer = Adam(learning_rate=1e-3)
model.compile(optimizer=optimizer, loss=loss_f, metrics=[dice_coef_infection, iou_coef_infection, precision_infection, recall_infection, hausdorff95_infection, specificity_infection, accuracy_infection, f1_infection])

# Model summary
model.summary()
# Out:
# Total FLOPs: 17.91 GFLOPs
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_image (InputLayer)        [(None, 320, 320, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 320, 320, 16) 160         input_image[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 320, 320, 8)  1160        conv2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 320, 320, 24) 0           conv2d[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 320, 320, 8)  1736        concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 320, 320, 32) 0           concatenate[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 32)           0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 1, 32)     0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 1, 1, 8)      264         reshape[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 1, 1, 32)     288         conv2d_3[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 320, 320, 32) 0           concatenate_1[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 160, 160, 32) 0           multiply[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 160, 160, 16) 4624        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 160, 160, 48) 0           max_pooling2d[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 160, 160, 16) 6928        concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 160, 160, 64) 0           concatenate_2[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 64)           0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 1, 64)     0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 1, 1, 8)      520         reshape_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 1, 1, 64)     576         conv2d_7[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 160, 160, 64) 0           concatenate_3[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 80, 80, 64)   0           multiply_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 80, 80, 32)   18464       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 80, 80, 96)   0           max_pooling2d_1[0][0]
#                                                                  conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 80, 80, 32)   27680       concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 80, 80, 128)  0           concatenate_4[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 128)          0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 1, 128)    0           global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 1, 1, 8)      1032        reshape_2[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 1, 1, 128)    1152        conv2d_11[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 80, 80, 128)  0           concatenate_5[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 40, 40, 128)  0           multiply_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 40, 40, 64)   73792       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 40, 40, 192)  0           max_pooling2d_2[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 40, 40, 64)   110656      concatenate_6[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 40, 40, 256)  0           concatenate_6[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 256)          0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1, 1, 256)    0           global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 1, 1, 10)     2570        reshape_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 1, 1, 256)    2816        conv2d_15[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 40, 40, 256)  0           concatenate_7[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 20, 20, 256)  0           multiply_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 20, 20, 128)  295040      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 20, 20, 384)  0           max_pooling2d_3[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 20, 20, 128)  442496      concatenate_8[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 20, 20, 512)  0           concatenate_8[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 512)          0           concatenate_9[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1, 1, 512)    0           global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 1, 1, 21)     10773       reshape_4[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 1, 1, 512)    11264       conv2d_19[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 20, 20, 512)  0           concatenate_9[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 10, 10, 512)  0           multiply_4[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 10, 10, 256)  1179904     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 10, 10, 768)  0           max_pooling2d_4[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 10, 10, 256)  1769728     concatenate_10[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 10, 10, 1024) 0           concatenate_10[0][0]
#                                                                  conv2d_22[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 1024)         0           concatenate_11[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 1, 1, 1024)   0           global_average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 1, 1, 42)     43050       reshape_5[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 1, 1, 1024)   44032       conv2d_23[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 10, 10, 1024) 0           concatenate_11[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 20, 20, 512)  4719104     multiply_5[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 20, 20, 256)  1179904     multiply_4[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 20, 20, 768)  0           conv2d_transpose[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 20, 20, 768)  0           concatenate_12[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 20, 20, 1280) 0           dropout[0][0]
#                                                                  multiply_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 40, 40, 256)  2949376     concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 40, 40, 128)  295040      multiply_3[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 40, 40, 384)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 40, 40, 384)  0           concatenate_14[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 40, 40, 640)  0           dropout_1[0][0]
#                                                                  multiply_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 80, 80, 128)  737408      concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 80, 80, 64)   73792       multiply_2[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 80, 80, 192)  0           conv2d_transpose_2[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 80, 80, 192)  0           concatenate_16[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 80, 80, 320)  0           dropout_2[0][0]
#                                                                  multiply_2[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 160, 160, 64) 184384      concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 160, 160, 32) 18464       multiply_1[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 160, 160, 96) 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_28[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 160, 160, 96) 0           concatenate_18[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 160, 160, 160 0           dropout_3[0][0]
#                                                                  multiply_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 320, 320, 32) 46112       concatenate_19[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 320, 320, 64) 0           conv2d_transpose_4[0][0]
#                                                                  multiply[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 320, 320, 1)  577         concatenate_20[0][0]
# ==================================================================================================
# Total params: 14,254,866
# Trainable params: 14,254,866
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Install required packages
# !pip install openpyxl

# Imports
import openpyxl  # required for reading .xlsx files
import pandas as pd
import tensorflow as tf
import os
import shutil
from tensorflow.keras.callbacks import LearningRateScheduler, ReduceLROnPlateau

# File paths
checkpoint_filepath = '/kaggle/working/checkpoint.h5.keras'
metrics_file = '/kaggle/working/training_metrics.xlsx'
pre_checkpoint_filepath = '/kaggle/input/dseg-unet-4channel-covid19/checkpoint.h5.keras'
pre_metrics_file = '/kaggle/input/dseg-unet-4channel-covid19/training_metrics.xlsx'

# Restore checkpoint and metrics if available
if os.path.exists(pre_checkpoint_filepath):
    shutil.copy(pre_checkpoint_filepath, checkpoint_filepath)
    print(f"Restored checkpoint from: {pre_checkpoint_filepath}")

if os.path.exists(pre_metrics_file):
    shutil.copy(pre_metrics_file, metrics_file)
    print(f"Restored metrics file from: {pre_metrics_file}")

# Load last epoch
def load_last_epoch():
    if os.path.exists(metrics_file):
        try:
            df = pd.read_excel(metrics_file, engine='openpyxl')
            if not df.empty and 'epoch' in df.columns:
                return df['epoch'].iloc[-1] + 1
        except Exception as e:
            print(f"⚠️ Could not read metrics file: {e}")
    return 0

last_epoch = load_last_epoch()

# Get best validation loss from previous runs
def get_best_val_loss():
    if os.path.exists(metrics_file):
        try:
            df = pd.read_excel(metrics_file, engine='openpyxl')
            if 'val_loss' in df.columns and not df['val_loss'].isnull().all():
                return df['val_loss'].min()
        except Exception as e:
            print(f"⚠️ Could not read val_loss from metrics file: {e}")
    return float('inf')

best_val_loss = get_best_val_loss()

# Custom model checkpoint
class CustomModelCheckpoint(tf.keras.callbacks.Callback):
    def __init__(self, filepath):
        super().__init__()
        self.filepath = filepath
        self.best_loss = best_val_loss

    def on_epoch_end(self, epoch, logs=None):
        current_loss = logs.get('val_loss')
        if current_loss is not None and current_loss < self.best_loss:
            self.best_loss = current_loss
            self.model.save(self.filepath)
            print(f"✅ Model saved at epoch {epoch + 1} with val_loss: {current_loss:.4f}")

# === Learning Rate Schedule ===
def lr_schedule(epoch, lr):
    return 1e-4 if epoch >= 5 else lr

lr_scheduler = LearningRateScheduler(lr_schedule, verbose=1)

# Logger for Excel
class MetricsLogger(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        df_new = pd.DataFrame([{**logs, 'epoch': epoch}])
        try:
            if os.path.exists(metrics_file):
                df = pd.read_excel(metrics_file, engine='openpyxl')
                df = pd.concat([df, df_new], ignore_index=True)
            else:
                df = df_new
            df.to_excel(metrics_file, index=False, engine='openpyxl')
        except Exception as e:
            print(f"⚠️ Failed to log metrics: {e}")

# Early stopping with patience and saving best weights
class CustomEarlyStopping(tf.keras.callbacks.Callback):
    def __init__(self, patience=20):
        super().__init__()
        self.patience = patience
        self.wait = 0
        self.best_loss = best_val_loss

    def on_epoch_end(self, epoch, logs=None):
        current_loss = logs.get('val_loss')
        if current_loss is None:
            return
        if current_loss < self.best_loss:
            self.best_loss = current_loss
            self.wait = 0
            self.model.save_weights(checkpoint_filepath)
        else:
            self.wait += 1
            if self.wait >= self.patience:
                print(f"🛑 Early stopping at epoch {epoch + 1}")
                self.model.stop_training = True


# Final callbacks list
callbacks = [
    CustomModelCheckpoint(filepath=checkpoint_filepath),
    MetricsLogger(),
    lr_scheduler,
    CustomEarlyStopping(patience=20)
]
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.3-py2.py3-none-any.whl (251 kB)
#      |████████████████████████████████| 251 kB 20.2 MB/s eta 0:00:01
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.3

# %% [markdown]
# ## Training the model

# %%
import time
import os
import pandas as pd
import numpy as np
from tensorflow.keras.utils import Sequence
from tensorflow.keras.models import load_model

EPOCHS = 100

# Record the start time
start_time = time.time()

# === Load last completed epoch from metrics file ===
def load_last_epoch():
    if os.path.exists(pre_metrics_file):
        try:
            df = pd.read_excel(pre_metrics_file, engine='openpyxl')
            if not df.empty and 'epoch' in df.columns:
                return int(df['epoch'].iloc[-1]) + 1
        except Exception as e:
            print(f"⚠️ Failed to read metrics file: {e}")
    return 0

last_epoch = load_last_epoch()

# === Load pretrained weights if available ===
if os.path.exists(pre_checkpoint_filepath):
    print("✅ Checkpoint found. Loading pretrained weights...")
    model.load_weights(pre_checkpoint_filepath)
    print(f"🔁 Resuming training from epoch {last_epoch}")
else:
    print("🆕 No checkpoint found. Starting training from scratch.")
    last_epoch = 0

# === Prepare input and label tensors ===
lung_train = np.asarray(lung_train, dtype=np.float16)
infect_train = np.asarray(infect_train, dtype=np.uint8)

lung_temp = np.asarray(lung_temp, dtype=np.float16)
infect_temp = np.asarray(infect_temp, dtype=np.uint8)

lung_test = np.asarray(lung_test, dtype=np.float16)
infect_test = np.asarray(infect_test, dtype=np.uint8)

# === Data Generator ===
class LungDataGenerator(Sequence):
    def __init__(self, X, Y, batch_size=8, shuffle=True):
        self.X = X
        self.Y = Y
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indices = np.arange(len(X))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.X) / self.batch_size))

    def __getitem__(self, index):
        batch_ids = self.indices[index * self.batch_size:(index + 1) * self.batch_size]
        X_batch = self.X[batch_ids]
        Y_batch = self.Y[batch_ids]
        return np.asarray(X_batch, dtype=np.float16), np.asarray(Y_batch, dtype=np.uint8)

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indices)

# === Create generators ===
train_gen = LungDataGenerator(lung_train, infect_train, batch_size=8)
temp_gen = LungDataGenerator(lung_temp, infect_temp, batch_size=8, shuffle=False)
val_gen = LungDataGenerator(lung_test, infect_test, batch_size=8, shuffle=False)

# === Train the model ===
history = model.fit(
    train_gen,
    validation_data=temp_gen,
    epochs=EPOCHS,
    initial_epoch=last_epoch,
    callbacks=callbacks
)

# === Timing info ===
end_time = time.time()
total_time = end_time - start_time
print(f"✅ Total training time: {total_time:.2f} seconds ({total_time / 60:.2f} minutes)")
# Out:
# 🆕 No checkpoint found. Starting training from scratch.
# Epoch 1/100
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 210s 174ms/step - loss: 1.3516 - dice_coef_infection: 0.0720 - iou_coef_infection: 0.0415 - precision_infection: 0.0760 - recall_infection: 0.1562 - hausdorff95_infection: 214.3571 - specificity_infection: 0.9669 - accuracy_infection: 0.9596 - f1_infection: 0.8720 - val_loss: 0.7374 - val_dice_coef_infection: 0.3685 - val_iou_coef_infection: 0.3391 - val_precision_infection: 0.4362 - val_recall_infection: 0.6382 - val_hausdorff95_infection: 120.9970 - val_specificity_infection: 0.9979 - val_accuracy_infection: 0.9914 - val_f1_infection: 0.7839
# ✅ Model saved at epoch 1 with val_loss: 0.7374
# Epoch 2/100
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 197s 172ms/step - loss: 0.6709 - dice_coef_infection: 0.3844 - iou_coef_infection: 0.2628 - precision_infection: 0.4100 - recall_infection: 0.4801 - hausdorff95_infection: 110.1570 - specificity_infection: 0.9944 - accuracy_infection: 0.9906 - f1_infection: 0.7619 - val_loss: 0.5090 - val_dice_coef_infection: 0.6464 - val_iou_coef_infection: 0.6230 - val_precision_infection: 0.8691 - val_recall_infection: 0.6690 - val_hausdorff95_infection: 95.9948 - val_specificity_infection: 0.9969 - val_accuracy_infection: 0.9949 - val_f1_infection: 0.8441
# ✅ Model saved at epoch 2 with val_loss: 0.5090
# Epoch 3/100
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 196s 171ms/step - loss: 0.5509 - dice_coef_infection: 0.4978 - iou_coef_infection: 0.3674 - precision_infection: 0.5359 - recall_infection: 0.5664 - hausdorff95_infection: 84.5506 - specificity_infection: 0.9963 - accuracy_infection: 0.9928 - f1_infection: 0.7860 - val_loss: 0.9024 - val_dice_coef_infection: 0.3703 - val_iou_coef_infection: 0.3576 - val_precision_infection: 0.4606 - val_recall_infection: 0.5829 - val_hausdorff95_infection: 112.4842 - val_specificity_infection: 0.9995 - val_accuracy_infection: 0.9902 - val_f1_infection: 0.8288
# Epoch 4/100
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 196s 171ms/step - loss: 0.5802 - dice_coef_infection: 0.4994 - iou_coef_infection: 0.3692 - precision_infection: 0.5458 - recall_infection: 0.5520 - hausdorff95_infection: 93.7910 - specificity_infection: 0.9961 - accuracy_infection: 0.9927 - f1_infection: 0.7868 - val_loss: 0.6043 - val_dice_coef_infection: 0.6209 - val_iou_coef_infection: 0.5964 - val_precision_infection: 0.9325 - val_recall_infection: 0.6303 - val_hausdorff95_infection: 105.1372 - val_specificity_infection: 0.9997 - val_accuracy_infection: 0.9944 - val_f1_infection: 0.8162
# Epoch 5/100
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 197s 172ms/step - loss: 0.4501 - dice_coef_infection: 0.5943 - iou_coef_infection: 0.4568 - precision_infection: 0.6309 - recall_infection: 0.6510 - hausdorff95_infection: 70.9185 - specificity_infection: 0.9974 - accuracy_infection: 0.9948 - f1_infection: 0.8001 - val_loss: 0.4336 - val_dice_coef_infection: 0.6261 - val_iou_coef_infection: 0.5838 - val_precision_infection: 0.7109 - val_recall_infection: 0.7185 - val_hausdorff95_infection: 51.8165 - val_specificity_infection: 0.9980 - val_accuracy_infection: 0.9955 - val_f1_infection: 0.8517
# ✅ Model saved at epoch 5 with val_loss: 0.4336
# Epoch 6/100
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.3704 - dice_coef_infection: 0.6546 - iou_coef_infection: 0.5228 - precision_infection: 0.6769 - recall_infection: 0.7006 - hausdorff95_infection: 48.1836 - specificity_infection: 0.9978 - accuracy_infection: 0.9959 - f1_infection: 0.8281 - val_loss: 0.3866 - val_dice_coef_infection: 0.7063 - val_iou_coef_infection: 0.6662 - val_precision_infection: 0.8564 - val_recall_infection: 0.7087 - val_hausdorff95_infection: 59.4569 - val_specificity_infection: 0.9983 - val_accuracy_infection: 0.9955 - val_f1_infection: 0.8690
# ✅ Model saved at epoch 6 with val_loss: 0.3866
# Epoch 7/100
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.3362 - dice_coef_infection: 0.6900 - iou_coef_infection: 0.5594 - precision_infection: 0.7185 - recall_infection: 0.7189 - hausdorff95_infection: 38.2782 - specificity_infection: 0.9982 - accuracy_infection: 0.9961 - f1_infection: 0.8373 - val_loss: 0.4019 - val_dice_coef_infection: 0.6942 - val_iou_coef_infection: 0.6543 - val_precision_infection: 0.8679 - val_recall_infection: 0.6931 - val_hausdorff95_infection: 58.7870 - val_specificity_infection: 0.9988 - val_accuracy_infection: 0.9953 - val_f1_infection: 0.8599
# Epoch 8/100
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.3233 - dice_coef_infection: 0.7025 - iou_coef_infection: 0.5739 - precision_infection: 0.7369 - recall_infection: 0.7239 - hausdorff95_infection: 37.3984 - specificity_infection: 0.9981 - accuracy_infection: 0.9961 - f1_infection: 0.8426 - val_loss: 0.3873 - val_dice_coef_infection: 0.6973 - val_iou_coef_infection: 0.6567 - val_precision_infection: 0.8065 - val_recall_infection: 0.7104 - val_hausdorff95_infection: 50.8331 - val_specificity_infection: 0.9982 - val_accuracy_infection: 0.9954 - val_f1_infection: 0.8820
# Epoch 9/100
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.3308 - dice_coef_infection: 0.6931 - iou_coef_infection: 0.5639 - precision_infection: 0.7209 - recall_infection: 0.7210 - hausdorff95_infection: 33.7983 - specificity_infection: 0.9982 - accuracy_infection: 0.9963 - f1_infection: 0.8387 - val_loss: 0.3782 - val_dice_coef_infection: 0.6969 - val_iou_coef_infection: 0.6572 - val_precision_infection: 0.8382 - val_recall_infection: 0.6999 - val_hausdorff95_infection: 57.8017 - val_specificity_infection: 0.9985 - val_accuracy_infection: 0.9955 - val_f1_infection: 0.8721
# ✅ Model saved at epoch 9 with val_loss: 0.3782
# Epoch 10/100
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.3078 - dice_coef_infection: 0.7147 - iou_coef_infection: 0.5833 - precision_infection: 0.7350 - recall_infection: 0.7417 - hausdorff95_infection: 34.8046 - specificity_infection: 0.9981 - accuracy_infection: 0.9963 - f1_infection: 0.8431 - val_loss: 0.4235 - val_dice_coef_infection: 0.6907 - val_iou_coef_infection: 0.6520 - val_precision_infection: 0.8676 - val_recall_infection: 0.6844 - val_hausdorff95_infection: 65.0295 - val_specificity_infection: 0.9989 - val_accuracy_infection: 0.9948 - val_f1_infection: 0.8631
# Epoch 11/100
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.3120 - dice_coef_infection: 0.7119 - iou_coef_infection: 0.5807 - precision_infection: 0.7399 - recall_infection: 0.7260 - hausdorff95_infection: 32.4445 - specificity_infection: 0.9982 - accuracy_infection: 0.9963 - f1_infection: 0.8468 - val_loss: 0.4159 - val_dice_coef_infection: 0.7051 - val_iou_coef_infection: 0.6633 - val_precision_infection: 0.8911 - val_recall_infection: 0.6827 - val_hausdorff95_infection: 59.4794 - val_specificity_infection: 0.9992 - val_accuracy_infection: 0.9943 - val_f1_infection: 0.8657
# Epoch 12/100
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.2941 - dice_coef_infection: 0.7293 - iou_coef_infection: 0.6006 - precision_infection: 0.7498 - recall_infection: 0.7539 - hausdorff95_infection: 34.2885 - specificity_infection: 0.9980 - accuracy_infection: 0.9961 - f1_infection: 0.8498 - val_loss: 0.4330 - val_dice_coef_infection: 0.6778 - val_iou_coef_infection: 0.6427 - val_precision_infection: 0.8748 - val_recall_infection: 0.6696 - val_hausdorff95_infection: 66.7277 - val_specificity_infection: 0.9991 - val_accuracy_infection: 0.9951 - val_f1_infection: 0.8594
# Epoch 13/100
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.3005 - dice_coef_infection: 0.7245 - iou_coef_infection: 0.5946 - precision_infection: 0.7615 - recall_infection: 0.7332 - hausdorff95_infection: 30.0476 - specificity_infection: 0.9983 - accuracy_infection: 0.9964 - f1_infection: 0.8485 - val_loss: 0.4261 - val_dice_coef_infection: 0.6992 - val_iou_coef_infection: 0.6598 - val_precision_infection: 0.9161 - val_recall_infection: 0.6743 - val_hausdorff95_infection: 64.1543 - val_specificity_infection: 0.9993 - val_accuracy_infection: 0.9944 - val_f1_infection: 0.8570
# Epoch 14/100
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 197s 173ms/step - loss: 0.2957 - dice_coef_infection: 0.7271 - iou_coef_infection: 0.5977 - precision_infection: 0.7497 - recall_infection: 0.7426 - hausdorff95_infection: 27.5703 - specificity_infection: 0.9981 - accuracy_infection: 0.9963 - f1_infection: 0.8506 - val_loss: 0.4464 - val_dice_coef_infection: 0.6861 - val_iou_coef_infection: 0.6485 - val_precision_infection: 0.8622 - val_recall_infection: 0.6769 - val_hausdorff95_infection: 64.3102 - val_specificity_infection: 0.9991 - val_accuracy_infection: 0.9943 - val_f1_infection: 0.8675
# Epoch 15/100
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.2943 - dice_coef_infection: 0.7281 - iou_coef_infection: 0.6017 - precision_infection: 0.7601 - recall_infection: 0.7397 - hausdorff95_infection: 29.0283 - specificity_infection: 0.9981 - accuracy_infection: 0.9964 - f1_infection: 0.8521 - val_loss: 0.4466 - val_dice_coef_infection: 0.6752 - val_iou_coef_infection: 0.6397 - val_precision_infection: 0.8783 - val_recall_infection: 0.6656 - val_hausdorff95_infection: 66.6982 - val_specificity_infection: 0.9993 - val_accuracy_infection: 0.9943 - val_f1_infection: 0.8582
# Epoch 16/100
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.2826 - dice_coef_infection: 0.7396 - iou_coef_infection: 0.6138 - precision_infection: 0.7695 - recall_infection: 0.7499 - hausdorff95_infection: 27.5672 - specificity_infection: 0.9982 - accuracy_infection: 0.9966 - f1_infection: 0.8567 - val_loss: 0.3862 - val_dice_coef_infection: 0.7008 - val_iou_coef_infection: 0.6609 - val_precision_infection: 0.8490 - val_recall_infection: 0.6971 - val_hausdorff95_infection: 59.2083 - val_specificity_infection: 0.9987 - val_accuracy_infection: 0.9954 - val_f1_infection: 0.8757
# Epoch 17/100
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.2853 - dice_coef_infection: 0.7372 - iou_coef_infection: 0.6093 - precision_infection: 0.7635 - recall_infection: 0.7490 - hausdorff95_infection: 26.5422 - specificity_infection: 0.9983 - accuracy_infection: 0.9966 - f1_infection: 0.8540 - val_loss: 0.4012 - val_dice_coef_infection: 0.6889 - val_iou_coef_infection: 0.6492 - val_precision_infection: 0.8099 - val_recall_infection: 0.7155 - val_hausdorff95_infection: 56.7116 - val_specificity_infection: 0.9978 - val_accuracy_infection: 0.9950 - val_f1_infection: 0.8710
# Epoch 18/100
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.2914 - dice_coef_infection: 0.7304 - iou_coef_infection: 0.6024 - precision_infection: 0.7548 - recall_infection: 0.7495 - hausdorff95_infection: 26.6919 - specificity_infection: 0.9982 - accuracy_infection: 0.9966 - f1_infection: 0.8514 - val_loss: 0.4006 - val_dice_coef_infection: 0.6820 - val_iou_coef_infection: 0.6444 - val_precision_infection: 0.8573 - val_recall_infection: 0.6868 - val_hausdorff95_infection: 66.9871 - val_specificity_infection: 0.9988 - val_accuracy_infection: 0.9955 - val_f1_infection: 0.8604
# Epoch 19/100
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.2879 - dice_coef_infection: 0.7329 - iou_coef_infection: 0.6068 - precision_infection: 0.7572 - recall_infection: 0.7495 - hausdorff95_infection: 26.9234 - specificity_infection: 0.9982 - accuracy_infection: 0.9966 - f1_infection: 0.8539 - val_loss: 0.4007 - val_dice_coef_infection: 0.7118 - val_iou_coef_infection: 0.6726 - val_precision_infection: 0.9170 - val_recall_infection: 0.6841 - val_hausdorff95_infection: 63.3780 - val_specificity_infection: 0.9992 - val_accuracy_infection: 0.9950 - val_f1_infection: 0.8640
# Epoch 20/100
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.2883 - dice_coef_infection: 0.7330 - iou_coef_infection: 0.6134 - precision_infection: 0.7623 - recall_infection: 0.7539 - hausdorff95_infection: 22.6280 - specificity_infection: 0.9982 - accuracy_infection: 0.9966 - f1_infection: 0.8568 - val_loss: 0.4390 - val_dice_coef_infection: 0.6838 - val_iou_coef_infection: 0.6524 - val_precision_infection: 0.9387 - val_recall_infection: 0.6697 - val_hausdorff95_infection: 86.3578 - val_specificity_infection: 0.9991 - val_accuracy_infection: 0.9950 - val_f1_infection: 0.8448
# Epoch 21/100
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.2756 - dice_coef_infection: 0.7448 - iou_coef_infection: 0.6173 - precision_infection: 0.7661 - recall_infection: 0.7583 - hausdorff95_infection: 23.3374 - specificity_infection: 0.9983 - accuracy_infection: 0.9967 - f1_infection: 0.8584 - val_loss: 0.3870 - val_dice_coef_infection: 0.6977 - val_iou_coef_infection: 0.6611 - val_precision_infection: 0.8849 - val_recall_infection: 0.6918 - val_hausdorff95_infection: 70.7744 - val_specificity_infection: 0.9989 - val_accuracy_infection: 0.9954 - val_f1_infection: 0.8625
# Epoch 22/100
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.2795 - dice_coef_infection: 0.7413 - iou_coef_infection: 0.6189 - precision_infection: 0.7708 - recall_infection: 0.7605 - hausdorff95_infection: 24.2603 - specificity_infection: 0.9983 - accuracy_infection: 0.9967 - f1_infection: 0.8570 - val_loss: 0.4410 - val_dice_coef_infection: 0.6778 - val_iou_coef_infection: 0.6486 - val_precision_infection: 0.9533 - val_recall_infection: 0.6586 - val_hausdorff95_infection: 94.8341 - val_specificity_infection: 0.9994 - val_accuracy_infection: 0.9949 - val_f1_infection: 0.8411
# Epoch 23/100
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.2703 - dice_coef_infection: 0.7529 - iou_coef_infection: 0.6267 - precision_infection: 0.7807 - recall_infection: 0.7584 - hausdorff95_infection: 23.3980 - specificity_infection: 0.9982 - accuracy_infection: 0.9964 - f1_infection: 0.8602 - val_loss: 0.4128 - val_dice_coef_infection: 0.6922 - val_iou_coef_infection: 0.6562 - val_precision_infection: 0.9223 - val_recall_infection: 0.6730 - val_hausdorff95_infection: 74.7822 - val_specificity_infection: 0.9992 - val_accuracy_infection: 0.9949 - val_f1_infection: 0.8521
# Epoch 24/100
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.2597 - dice_coef_infection: 0.7603 - iou_coef_infection: 0.6378 - precision_infection: 0.7869 - recall_infection: 0.7685 - hausdorff95_infection: 22.1838 - specificity_infection: 0.9982 - accuracy_infection: 0.9967 - f1_infection: 0.8651 - val_loss: 0.4020 - val_dice_coef_infection: 0.6992 - val_iou_coef_infection: 0.6601 - val_precision_infection: 0.9284 - val_recall_infection: 0.6740 - val_hausdorff95_infection: 72.8921 - val_specificity_infection: 0.9993 - val_accuracy_infection: 0.9944 - val_f1_infection: 0.8534
# Epoch 25/100
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.2634 - dice_coef_infection: 0.7572 - iou_coef_infection: 0.6329 - precision_infection: 0.7764 - recall_infection: 0.7711 - hausdorff95_infection: 23.4208 - specificity_infection: 0.9983 - accuracy_infection: 0.9967 - f1_infection: 0.8634 - val_loss: 0.4179 - val_dice_coef_infection: 0.6885 - val_iou_coef_infection: 0.6532 - val_precision_infection: 0.9341 - val_recall_infection: 0.6615 - val_hausdorff95_infection: 78.4842 - val_specificity_infection: 0.9995 - val_accuracy_infection: 0.9942 - val_f1_infection: 0.8504
# Epoch 26/100
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.2656 - dice_coef_infection: 0.7538 - iou_coef_infection: 0.6309 - precision_infection: 0.7784 - recall_infection: 0.7723 - hausdorff95_infection: 21.6154 - specificity_infection: 0.9983 - accuracy_infection: 0.9968 - f1_infection: 0.8613 - val_loss: 0.4034 - val_dice_coef_infection: 0.6955 - val_iou_coef_infection: 0.6555 - val_precision_infection: 0.9196 - val_recall_infection: 0.6791 - val_hausdorff95_infection: 67.3561 - val_specificity_infection: 0.9994 - val_accuracy_infection: 0.9949 - val_f1_infection: 0.8514
# Epoch 27/100
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.2557 - dice_coef_infection: 0.7643 - iou_coef_infection: 0.6391 - precision_infection: 0.7776 - recall_infection: 0.7763 - hausdorff95_infection: 20.0415 - specificity_infection: 0.9982 - accuracy_infection: 0.9967 - f1_infection: 0.8666 - val_loss: 0.4241 - val_dice_coef_infection: 0.6854 - val_iou_coef_infection: 0.6442 - val_precision_infection: 0.8901 - val_recall_infection: 0.6735 - val_hausdorff95_infection: 68.1422 - val_specificity_infection: 0.9995 - val_accuracy_infection: 0.9942 - val_f1_infection: 0.8549
# Epoch 28/100
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.2596 - dice_coef_infection: 0.7596 - iou_coef_infection: 0.6379 - precision_infection: 0.7786 - recall_infection: 0.7778 - hausdorff95_infection: 22.5251 - specificity_infection: 0.9983 - accuracy_infection: 0.9968 - f1_infection: 0.8648 - val_loss: 0.4420 - val_dice_coef_infection: 0.6888 - val_iou_coef_infection: 0.6531 - val_precision_infection: 0.9362 - val_recall_infection: 0.6640 - val_hausdorff95_infection: 79.0280 - val_specificity_infection: 0.9994 - val_accuracy_infection: 0.9942 - val_f1_infection: 0.8488
# Epoch 29/100
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.2475 - dice_coef_infection: 0.7716 - iou_coef_infection: 0.6471 - precision_infection: 0.7877 - recall_infection: 0.7799 - hausdorff95_infection: 19.5118 - specificity_infection: 0.9983 - accuracy_infection: 0.9968 - f1_infection: 0.8683 - val_loss: 0.3657 - val_dice_coef_infection: 0.7254 - val_iou_coef_infection: 0.6811 - val_precision_infection: 0.9078 - val_recall_infection: 0.6968 - val_hausdorff95_infection: 60.8178 - val_specificity_infection: 0.9991 - val_accuracy_infection: 0.9950 - val_f1_infection: 0.8684
# ✅ Model saved at epoch 29 with val_loss: 0.3657
# Epoch 30/100
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.2426 - dice_coef_infection: 0.7760 - iou_coef_infection: 0.6545 - precision_infection: 0.7905 - recall_infection: 0.7886 - hausdorff95_infection: 20.9023 - specificity_infection: 0.9984 - accuracy_infection: 0.9969 - f1_infection: 0.8708 - val_loss: 0.3649 - val_dice_coef_infection: 0.7078 - val_iou_coef_infection: 0.6630 - val_precision_infection: 0.8714 - val_recall_infection: 0.6995 - val_hausdorff95_infection: 56.9716 - val_specificity_infection: 0.9992 - val_accuracy_infection: 0.9949 - val_f1_infection: 0.8669
# ✅ Model saved at epoch 30 with val_loss: 0.3649
# Epoch 31/100
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.2363 - dice_coef_infection: 0.7824 - iou_coef_infection: 0.6616 - precision_infection: 0.7850 - recall_infection: 0.7993 - hausdorff95_infection: 18.3126 - specificity_infection: 0.9982 - accuracy_infection: 0.9967 - f1_infection: 0.8750 - val_loss: 0.3947 - val_dice_coef_infection: 0.7079 - val_iou_coef_infection: 0.6693 - val_precision_infection: 0.9376 - val_recall_infection: 0.6797 - val_hausdorff95_infection: 72.0939 - val_specificity_infection: 0.9993 - val_accuracy_infection: 0.9951 - val_f1_infection: 0.8560
# Epoch 32/100
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.2535 - dice_coef_infection: 0.7678 - iou_coef_infection: 0.6458 - precision_infection: 0.7959 - recall_infection: 0.7732 - hausdorff95_infection: 20.0423 - specificity_infection: 0.9984 - accuracy_infection: 0.9968 - f1_infection: 0.8677 - val_loss: 0.3612 - val_dice_coef_infection: 0.7112 - val_iou_coef_infection: 0.6734 - val_precision_infection: 0.9212 - val_recall_infection: 0.6905 - val_hausdorff95_infection: 69.3356 - val_specificity_infection: 0.9989 - val_accuracy_infection: 0.9958 - val_f1_infection: 0.8606
# ✅ Model saved at epoch 32 with val_loss: 0.3612
# Epoch 33/100
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.2486 - dice_coef_infection: 0.7693 - iou_coef_infection: 0.6472 - precision_infection: 0.7848 - recall_infection: 0.7773 - hausdorff95_infection: 18.8613 - specificity_infection: 0.9983 - accuracy_infection: 0.9969 - f1_infection: 0.8705 - val_loss: 0.4104 - val_dice_coef_infection: 0.6859 - val_iou_coef_infection: 0.6540 - val_precision_infection: 0.9395 - val_recall_infection: 0.6700 - val_hausdorff95_infection: 83.9824 - val_specificity_infection: 0.9991 - val_accuracy_infection: 0.9954 - val_f1_infection: 0.8458
# Epoch 34/100
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.2426 - dice_coef_infection: 0.7745 - iou_coef_infection: 0.6575 - precision_infection: 0.7949 - recall_infection: 0.7892 - hausdorff95_infection: 17.3568 - specificity_infection: 0.9984 - accuracy_infection: 0.9971 - f1_infection: 0.8716 - val_loss: 0.3922 - val_dice_coef_infection: 0.6895 - val_iou_coef_infection: 0.6521 - val_precision_infection: 0.9128 - val_recall_infection: 0.6787 - val_hausdorff95_infection: 72.0266 - val_specificity_infection: 0.9993 - val_accuracy_infection: 0.9951 - val_f1_infection: 0.8506
# Epoch 35/100
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.2291 - dice_coef_infection: 0.7882 - iou_coef_infection: 0.6699 - precision_infection: 0.8015 - recall_infection: 0.8010 - hausdorff95_infection: 16.8076 - specificity_infection: 0.9984 - accuracy_infection: 0.9970 - f1_infection: 0.8768 - val_loss: 0.4914 - val_dice_coef_infection: 0.6605 - val_iou_coef_infection: 0.6234 - val_precision_infection: 0.8637 - val_recall_infection: 0.6725 - val_hausdorff95_infection: 78.6151 - val_specificity_infection: 0.9991 - val_accuracy_infection: 0.9942 - val_f1_infection: 0.8450
# Epoch 36/100
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.2527 - dice_coef_infection: 0.7661 - iou_coef_infection: 0.6461 - precision_infection: 0.7837 - recall_infection: 0.7800 - hausdorff95_infection: 19.2314 - specificity_infection: 0.9984 - accuracy_infection: 0.9970 - f1_infection: 0.8698 - val_loss: 0.3732 - val_dice_coef_infection: 0.7094 - val_iou_coef_infection: 0.6701 - val_precision_infection: 0.9222 - val_recall_infection: 0.6900 - val_hausdorff95_infection: 71.1576 - val_specificity_infection: 0.9990 - val_accuracy_infection: 0.9956 - val_f1_infection: 0.8581
# Epoch 37/100
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.2303 - dice_coef_infection: 0.7858 - iou_coef_infection: 0.6676 - precision_infection: 0.7956 - recall_infection: 0.8007 - hausdorff95_infection: 17.9788 - specificity_infection: 0.9985 - accuracy_infection: 0.9972 - f1_infection: 0.8761 - val_loss: 0.3860 - val_dice_coef_infection: 0.6980 - val_iou_coef_infection: 0.6579 - val_precision_infection: 0.8945 - val_recall_infection: 0.6846 - val_hausdorff95_infection: 64.9691 - val_specificity_infection: 0.9992 - val_accuracy_infection: 0.9954 - val_f1_infection: 0.8599
# Epoch 38/100
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.2358 - dice_coef_infection: 0.7815 - iou_coef_infection: 0.6624 - precision_infection: 0.7978 - recall_infection: 0.7913 - hausdorff95_infection: 18.6923 - specificity_infection: 0.9984 - accuracy_infection: 0.9970 - f1_infection: 0.8744 - val_loss: 0.3674 - val_dice_coef_infection: 0.7117 - val_iou_coef_infection: 0.6716 - val_precision_infection: 0.9018 - val_recall_infection: 0.6930 - val_hausdorff95_infection: 65.6999 - val_specificity_infection: 0.9989 - val_accuracy_infection: 0.9956 - val_f1_infection: 0.8649
# Epoch 39/100
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.2329 - dice_coef_infection: 0.7839 - iou_coef_infection: 0.6648 - precision_infection: 0.7998 - recall_infection: 0.7922 - hausdorff95_infection: 17.4464 - specificity_infection: 0.9984 - accuracy_infection: 0.9970 - f1_infection: 0.8754 - val_loss: 0.3855 - val_dice_coef_infection: 0.7149 - val_iou_coef_infection: 0.6719 - val_precision_infection: 0.9086 - val_recall_infection: 0.6900 - val_hausdorff95_infection: 63.9467 - val_specificity_infection: 0.9993 - val_accuracy_infection: 0.9949 - val_f1_infection: 0.8645
# Epoch 40/100
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.2317 - dice_coef_infection: 0.7855 - iou_coef_infection: 0.6632 - precision_infection: 0.7952 - recall_infection: 0.7922 - hausdorff95_infection: 19.1600 - specificity_infection: 0.9984 - accuracy_infection: 0.9970 - f1_infection: 0.8753 - val_loss: 0.3963 - val_dice_coef_infection: 0.6845 - val_iou_coef_infection: 0.6531 - val_precision_infection: 0.9238 - val_recall_infection: 0.6699 - val_hausdorff95_infection: 82.7636 - val_specificity_infection: 0.9993 - val_accuracy_infection: 0.9956 - val_f1_infection: 0.8503
# Epoch 41/100
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 197s 173ms/step - loss: 0.2362 - dice_coef_infection: 0.7830 - iou_coef_infection: 0.6611 - precision_infection: 0.8013 - recall_infection: 0.7875 - hausdorff95_infection: 20.5258 - specificity_infection: 0.9983 - accuracy_infection: 0.9968 - f1_infection: 0.8738 - val_loss: 0.4063 - val_dice_coef_infection: 0.6876 - val_iou_coef_infection: 0.6489 - val_precision_infection: 0.9046 - val_recall_infection: 0.6764 - val_hausdorff95_infection: 72.5138 - val_specificity_infection: 0.9993 - val_accuracy_infection: 0.9952 - val_f1_infection: 0.8522
# Epoch 42/100
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 197s 173ms/step - loss: 0.2199 - dice_coef_infection: 0.7968 - iou_coef_infection: 0.6787 - precision_infection: 0.8074 - recall_infection: 0.8051 - hausdorff95_infection: 16.0087 - specificity_infection: 0.9985 - accuracy_infection: 0.9971 - f1_infection: 0.8812 - val_loss: 0.3971 - val_dice_coef_infection: 0.6886 - val_iou_coef_infection: 0.6530 - val_precision_infection: 0.9287 - val_recall_infection: 0.6687 - val_hausdorff95_infection: 80.9952 - val_specificity_infection: 0.9993 - val_accuracy_infection: 0.9952 - val_f1_infection: 0.8510
# Epoch 43/100
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.2179 - dice_coef_infection: 0.7992 - iou_coef_infection: 0.6810 - precision_infection: 0.8139 - recall_infection: 0.8023 - hausdorff95_infection: 16.4224 - specificity_infection: 0.9984 - accuracy_infection: 0.9971 - f1_infection: 0.8817 - val_loss: 0.3806 - val_dice_coef_infection: 0.6896 - val_iou_coef_infection: 0.6527 - val_precision_infection: 0.8766 - val_recall_infection: 0.6883 - val_hausdorff95_infection: 71.6910 - val_specificity_infection: 0.9988 - val_accuracy_infection: 0.9958 - val_f1_infection: 0.8601
# Epoch 44/100
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 197s 173ms/step - loss: 0.2288 - dice_coef_infection: 0.7881 - iou_coef_infection: 0.6717 - precision_infection: 0.8062 - recall_infection: 0.7984 - hausdorff95_infection: 18.5552 - specificity_infection: 0.9984 - accuracy_infection: 0.9970 - f1_infection: 0.8770 - val_loss: 0.3865 - val_dice_coef_infection: 0.6952 - val_iou_coef_infection: 0.6570 - val_precision_infection: 0.9160 - val_recall_infection: 0.6754 - val_hausdorff95_infection: 71.9034 - val_specificity_infection: 0.9993 - val_accuracy_infection: 0.9952 - val_f1_infection: 0.8543
# Epoch 45/100
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.2265 - dice_coef_infection: 0.7906 - iou_coef_infection: 0.6742 - precision_infection: 0.8103 - recall_infection: 0.7975 - hausdorff95_infection: 18.0259 - specificity_infection: 0.9984 - accuracy_infection: 0.9971 - f1_infection: 0.8782 - val_loss: 0.3846 - val_dice_coef_infection: 0.7012 - val_iou_coef_infection: 0.6644 - val_precision_infection: 0.9122 - val_recall_infection: 0.6824 - val_hausdorff95_infection: 74.2686 - val_specificity_infection: 0.9993 - val_accuracy_infection: 0.9954 - val_f1_infection: 0.8594
# Epoch 46/100
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.2319 - dice_coef_infection: 0.7863 - iou_coef_infection: 0.6697 - precision_infection: 0.8034 - recall_infection: 0.7977 - hausdorff95_infection: 16.8629 - specificity_infection: 0.9985 - accuracy_infection: 0.9970 - f1_infection: 0.8778 - val_loss: 0.3701 - val_dice_coef_infection: 0.7155 - val_iou_coef_infection: 0.6758 - val_precision_infection: 0.9282 - val_recall_infection: 0.6859 - val_hausdorff95_infection: 67.7125 - val_specificity_infection: 0.9993 - val_accuracy_infection: 0.9957 - val_f1_infection: 0.8623
# Epoch 47/100
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 197s 173ms/step - loss: 0.2183 - dice_coef_infection: 0.7985 - iou_coef_infection: 0.6822 - precision_infection: 0.8088 - recall_infection: 0.8086 - hausdorff95_infection: 16.6009 - specificity_infection: 0.9984 - accuracy_infection: 0.9971 - f1_infection: 0.8820 - val_loss: 0.4044 - val_dice_coef_infection: 0.6916 - val_iou_coef_infection: 0.6555 - val_precision_infection: 0.9397 - val_recall_infection: 0.6668 - val_hausdorff95_infection: 73.7801 - val_specificity_infection: 0.9994 - val_accuracy_infection: 0.9950 - val_f1_infection: 0.8489
# Epoch 48/100
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.2096 - dice_coef_infection: 0.8056 - iou_coef_infection: 0.6924 - precision_infection: 0.8195 - recall_infection: 0.8122 - hausdorff95_infection: 15.7000 - specificity_infection: 0.9985 - accuracy_infection: 0.9973 - f1_infection: 0.8861 - val_loss: 0.3727 - val_dice_coef_infection: 0.7085 - val_iou_coef_infection: 0.6699 - val_precision_infection: 0.9065 - val_recall_infection: 0.6916 - val_hausdorff95_infection: 68.1019 - val_specificity_infection: 0.9990 - val_accuracy_infection: 0.9958 - val_f1_infection: 0.8621
# Epoch 49/100
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.2024 - dice_coef_infection: 0.8132 - iou_coef_infection: 0.6990 - precision_infection: 0.8210 - recall_infection: 0.8203 - hausdorff95_infection: 16.0409 - specificity_infection: 0.9985 - accuracy_infection: 0.9973 - f1_infection: 0.8884 - val_loss: 0.4105 - val_dice_coef_infection: 0.6900 - val_iou_coef_infection: 0.6506 - val_precision_infection: 0.9144 - val_recall_infection: 0.6761 - val_hausdorff95_infection: 75.4120 - val_specificity_infection: 0.9993 - val_accuracy_infection: 0.9950 - val_f1_infection: 0.8501
# Epoch 50/100
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.2098 - dice_coef_infection: 0.8059 - iou_coef_infection: 0.6928 - precision_infection: 0.8167 - recall_infection: 0.8161 - hausdorff95_infection: 14.7108 - specificity_infection: 0.9986 - accuracy_infection: 0.9973 - f1_infection: 0.8856 - val_loss: 0.3738 - val_dice_coef_infection: 0.7088 - val_iou_coef_infection: 0.6677 - val_precision_infection: 0.9003 - val_recall_infection: 0.6919 - val_hausdorff95_infection: 64.7722 - val_specificity_infection: 0.9991 - val_accuracy_infection: 0.9951 - val_f1_infection: 0.8625
# Epoch 51/100
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.2065 - dice_coef_infection: 0.8095 - iou_coef_infection: 0.6983 - precision_infection: 0.8216 - recall_infection: 0.8167 - hausdorff95_infection: 15.5757 - specificity_infection: 0.9985 - accuracy_infection: 0.9972 - f1_infection: 0.8885 - val_loss: 0.4055 - val_dice_coef_infection: 0.6804 - val_iou_coef_infection: 0.6457 - val_precision_infection: 0.9318 - val_recall_infection: 0.6695 - val_hausdorff95_infection: 83.2294 - val_specificity_infection: 0.9993 - val_accuracy_infection: 0.9951 - val_f1_infection: 0.8422
# Epoch 52/100
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 198s 173ms/step - loss: 0.2029 - dice_coef_infection: 0.8120 - iou_coef_infection: 0.6973 - precision_infection: 0.8183 - recall_infection: 0.8199 - hausdorff95_infection: 14.9518 - specificity_infection: 0.9985 - accuracy_infection: 0.9973 - f1_infection: 0.8876 - val_loss: 0.4201 - val_dice_coef_infection: 0.6785 - val_iou_coef_infection: 0.6417 - val_precision_infection: 0.8948 - val_recall_infection: 0.6763 - val_hausdorff95_infection: 81.1115 - val_specificity_infection: 0.9992 - val_accuracy_infection: 0.9948 - val_f1_infection: 0.8471
# 🛑 Early stopping at epoch 52
# ✅ Total training time: 10299.44 seconds (171.66 minutes)

# %% [markdown]
# ## Plotting the performance metrics

# %%
plt.plot(history.history['dice_coef_infection'])
plt.plot(history.history['val_dice_coef_infection'])
plt.title('dice_coef_infection vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Dice_coef')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# %%
plt.plot(history.history['iou_coef_infection'])
plt.plot(history.history['val_iou_coef_infection'])
plt.title('iou_coef_infection vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Iou_coef')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Val'], loc = 'upper right')
plt.show()

# %% [markdown]
# ## Using our trained model for prediction

# %%
import numpy as np
import time

# Start timer (high precision)
start_time = time.perf_counter()

# Evaluate the model on the validation generator
results = model.evaluate(val_gen, verbose=1)

# End timer
end_time = time.perf_counter()

# Calculate evaluation time
eval_time = end_time - start_time

# Print metric names with results
print("\n===== Validation Metrics =====")
for name, value in zip(model.metrics_names, results):
    print(f"{name}: {value:.6f}")

print(f"\nEvaluation Time: {eval_time:.8f} seconds\n")
# Out:
# 128/128 [==============================] - 8s 61ms/step - loss: 0.3148 - dice_coef_infection: 0.7443 - iou_coef_infection: 0.6978 - precision_infection: 0.9035 - recall_infection: 0.7406 - hausdorff95_infection: 59.4525 - specificity_infection: 0.9994 - accuracy_infection: 0.9964 - f1_infection: 0.8726
#
# ===== Validation Metrics =====
# loss: 0.314780
# dice_coef_infection: 0.744257
# iou_coef_infection: 0.697784
# precision_infection: 0.903509
# recall_infection: 0.740646
# hausdorff95_infection: 59.452484
# specificity_infection: 0.999397
# accuracy_infection: 0.996396
# f1_infection: 0.872551
#
# Evaluation Time: 7.87854960 seconds

# %%
import matplotlib.pyplot as plt
import numpy as np

# Run inference if not already done
predicted = model.predict(lung_test)

# Selected indices to visualize (744 as 1st, 280 as 2nd, 230 as 3rd)
selected_indices = [744, 280, 230]
n_samples = len(selected_indices)

# Mapping indices to custom names
name_mapping = {
    0: ("Image1_Covid", "GT1_Covid", "Predict1_Covid_DSEG_Unet"),  # Index 744
    1: ("Image2_Covid", "GT2_Covid", "Predict2_Covid_DSEG_Unet"),  # Index 280
    2: ("Image3_Covid", "GT3_Covid", "Predict3_Covid_DSEG_Unet")   # Index 230
}

# Plot
for j, i in enumerate(selected_indices):
    lung_img = lung_test[i][..., 0].astype(np.float32)
    gt_infect = (infect_test[i][..., 0] > 0.5).astype(np.float32)
    pred_infect = predicted[i][..., 0].astype(np.float32)

    # Normalize lung image
    if lung_img.max() > lung_img.min():
        lung_img = (lung_img - lung_img.min()) / (lung_img.max() - lung_img.min())
    lung_img = np.clip(lung_img, 0, 1)
    pred_infect = np.clip(pred_infect, 0, 1)

    # Get custom names for this index
    input_name, gt_name, pred_name = name_mapping[j]

    # Save Original Lung
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{input_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

    # Save Ground Truth Infection
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.imshow(gt_infect, cmap='Reds', alpha=0.6)
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{gt_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

    # Save Predicted Infection
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.imshow(pred_infect, cmap='Reds', alpha=0.6)
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{pred_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

print("Separate JPEG files saved for input images (Image1_Covid, Image2_Covid, Image3_Covid), "
      "ground truths (GT1_Covid, GT2_Covid, GT3_Covid), and predictions "
      "(Predict1_Covid_DSEG_Unet, Predict2_Covid_DSEG_Unet, Predict3_Covid_DSEG_Unet).")
# Out:
# Separate JPEG files saved for input images (Image1_Covid, Image2_Covid, Image3_Covid), ground truths (GT1_Covid, GT2_Covid, GT3_Covid), and predictions (Predict1_Covid_DSEG_Unet, Predict2_Covid_DSEG_Unet, Predict3_Covid_DSEG_Unet).
