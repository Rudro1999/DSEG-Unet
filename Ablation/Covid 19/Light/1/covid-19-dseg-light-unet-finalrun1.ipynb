# %% [markdown]
# ## Importing important libraries

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import nibabel as nib #for loading nii files
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf #for deep learning

# %% [markdown]
# ## Reading the metadata

# %%
data = pd.read_csv('../input/covid19-ct-scans/metadata.csv')
data.head()
# Out:
#                                              ct_scan  \
# 0  ../input/covid19-ct-scans/ct_scans/coronacases...
# 1  ../input/covid19-ct-scans/ct_scans/coronacases...
# 2  ../input/covid19-ct-scans/ct_scans/coronacases...
# 3  ../input/covid19-ct-scans/ct_scans/coronacases...
# 4  ../input/covid19-ct-scans/ct_scans/coronacases...
#
#                                            lung_mask  \
# 0  ../input/covid19-ct-scans/lung_mask/coronacase...
# 1  ../input/covid19-ct-scans/lung_mask/coronacase...
# 2  ../input/covid19-ct-scans/lung_mask/coronacase...
# 3  ../input/covid19-ct-scans/lung_mask/coronacase...
# 4  ../input/covid19-ct-scans/lung_mask/coronacase...
#
#                                       infection_mask  \
# 0  ../input/covid19-ct-scans/infection_mask/coron...
# 1  ../input/covid19-ct-scans/infection_mask/coron...
# 2  ../input/covid19-ct-scans/infection_mask/coron...
# 3  ../input/covid19-ct-scans/infection_mask/coron...
# 4  ../input/covid19-ct-scans/infection_mask/coron...
#
#                              lung_and_infection_mask
# 0  ../input/covid19-ct-scans/lung_and_infection_m...
# 1  ../input/covid19-ct-scans/lung_and_infection_m...
# 2  ../input/covid19-ct-scans/lung_and_infection_m...
# 3  ../input/covid19-ct-scans/lung_and_infection_m...
# 4  ../input/covid19-ct-scans/lung_and_infection_m...

# %% [markdown]
# ## Defining function for readiing .nii files

# %%
def read_nii(filepath):
    '''
    Reads .nii file and returns pixel array
    '''
    ct_scan = nib.load(filepath)
    array   = ct_scan.get_fdata()
    array   = np.rot90(np.array(array))
    return(array)

# %% [markdown]
# ## Reading the chest ct scan data

# %%
# Read sample
sample_ct   = read_nii(data.loc[2,'ct_scan'])
sample_lung = read_nii(data.loc[2,'lung_mask'])
sample_infe = read_nii(data.loc[2,'infection_mask'])
sample_all  = read_nii(data.loc[2,'lung_and_infection_mask'])

# %% [markdown]
# ## Plotting the sample images

# %%
fig = plt.figure(figsize = (18,15))
plt.subplot(1,4,1)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.title('Original Image')

plt.subplot(1,4,2)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_lung[..., 150],alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung Mask')

plt.subplot(1,4,3)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_infe[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Infection Mask')

plt.subplot(1,4,4)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_all[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung and Infection Mask')
# Out:
# Text(0.5, 1.0, 'Lung and Infection Mask')

# %% [markdown]
# ## Converting the data into array for training model

# %%
import numpy as np
import cv2
import random
from scipy.ndimage import rotate, shift, zoom

lungs = []
infections = []
case_ids = []
img_size = 320

# ----------- Load and Resize Data -----------
for case_index in range(len(data)):
    ct = read_nii(data['ct_scan'][case_index])
    infect = read_nii(data['infection_mask'][case_index])

    for slice_index in range(ct.shape[0]):
        lung_img = cv2.resize(ct[slice_index], dsize=(img_size, img_size)).astype('float32')
        infec_img = cv2.resize(infect[slice_index], dsize=(img_size, img_size)).astype('float32')

        lungs.append(lung_img[..., np.newaxis])
        infections.append(infec_img[..., np.newaxis])
        case_ids.append(case_index)

# %%
import numpy as np

# case_ids should be a NumPy array telling which case each slice belongs to
# Convert and binarize
lungs = np.array(lungs, dtype=np.float32)
infections = (np.array(infections, dtype=np.uint8) > 0.5).astype(np.uint8)
case_ids = np.array(case_ids)

# %% [markdown]
# ## Performing test and train split

# %%
# ----------- Case-wise Split -----------
unique_cases = np.unique(case_ids)
train_cases = np.append(unique_cases[4:12], unique_cases[12:20])
temp_cases = unique_cases[2:4]
val_cases = unique_cases[:2]

train_mask = np.isin(case_ids, train_cases)
temp_mask = np.isin(case_ids, temp_cases)
val_mask = np.isin(case_ids, val_cases)

lung_train = lungs[train_mask]
infect_train = infections[train_mask]
lung_temp = lungs[temp_mask]
infect_temp = infections[temp_mask]
lung_test = lungs[val_mask]
infect_test = infections[val_mask]

print(f"✅ Train: {lung_train.shape[0]} slices from {len(train_cases)} cases")
print(f"✅ Validation: {lung_temp.shape[0]} slices from {len(temp_cases)} cases")
print(f"✅ Test: {lung_test.shape[0]} slices from {len(val_cases)} cases")

# ----------- Augmentation -----------
def augment_image(img, mask):
    if random.random() < 0.5:
        img = np.fliplr(img)
        mask = np.fliplr(mask)
    if random.random() < 0.5:
        img = np.flipud(img)
        mask = np.flipud(mask)

    angle = random.uniform(-15, 15)
    img = rotate(img, angle, reshape=False, order=1, mode='nearest')
    mask = rotate(mask, angle, reshape=False, order=0, mode='nearest')

    shift_val = np.random.uniform(-0.1, 0.1, size=2) * img.shape[:2]
    img = shift(img, shift=(*shift_val, 0), order=1, mode='nearest')
    mask = shift(mask, shift=(*shift_val, 0), order=0, mode='nearest')

    zoom_factor = random.uniform(0.9, 1.1)
    img = zoom(img, (zoom_factor, zoom_factor, 1), order=1)
    mask = zoom(mask, (zoom_factor, zoom_factor, 1), order=0)

    return fix_shape(img), fix_shape(mask)

def fix_shape(arr, target_size=(320, 320)):
    h, w, c = arr.shape
    th, tw = target_size
    dh = th - h
    dw = tw - w
    if dh > 0 or dw > 0:
        pad_h = (max(dh // 2, 0), max(dh - dh // 2, 0))
        pad_w = (max(dw // 2, 0), max(dw - dw // 2, 0))
        arr = np.pad(arr, (pad_h, pad_w, (0, 0)), mode='constant')
    arr = arr[:th, :tw, :]
    return arr.astype('float32')

# ----------- Apply Augmentation -----------
aug_lung_train = []
aug_infect_train = []

for i in range(len(lung_train)):
    img, mask = augment_image(lung_train[i], infect_train[i])
    aug_lung_train.append(img)
    aug_infect_train.append(mask)

lung_train = np.stack(aug_lung_train)
infect_train = np.stack(aug_infect_train)

# Final Binarization
infect_train = (infect_train > 0.5).astype(np.uint8)
infect_test = (infect_test > 0.5).astype(np.uint8)

print(f"✅ Augmented training shape: {lung_train.shape}")
print("✅ All preprocessing complete.")
# Out:
# ✅ Train: 9143 slices from 16 cases
# ✅ Validation: 1024 slices from 2 cases
# ✅ Test: 1024 slices from 2 cases
# ✅ Augmented training shape: (9143, 320, 320, 1)
# ✅ All preprocessing complete.

# %%
import tensorflow as tf
from tensorflow.keras import backend as K
import numpy as np
from scipy.spatial import cKDTree

smooth = 1.0

# Binary Dice coefficient (soft - commonly used during training)
def dice_coef_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# Binary IoU coefficient (soft)
def iou_coef_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# Soft Precision
def precision_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + smooth) / (K.sum(y_pred_f) + smooth)

# Soft Recall (Sensitivity)
def recall_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + smooth) / (K.sum(y_true_f) + smooth)

# Soft Specificity
def specificity_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    tn = K.sum((1 - y_true_f) * (1 - y_pred_f))
    fp = K.sum((1 - y_true_f) * y_pred_f)
    return (tn + smooth) / (tn + fp + smooth)

# Soft Accuracy
def accuracy_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    tp = K.sum(y_true_f * y_pred_f)
    tn = K.sum((1 - y_true_f) * (1 - y_pred_f))
    total = K.cast(K.shape(y_true_f)[0], 'float32')
    return (tp + tn + smooth) / (total + smooth)

# Soft F1-score (harmonic mean of precision & recall - very close to Dice, standard in many repos)
def f1_infection(y_true, y_pred):
    precision = precision_infection(y_true, y_pred)
    recall    = recall_infection(y_true, y_pred)
    return (2. * precision * recall + smooth) / (precision + recall + smooth)

# Hausdorff Distance 95 % (robust & most commonly used in medical imaging challenges)
# Lower = better. Returns the mean HD95 over the batch.
def _calculate_hd95(y_true, y_pred):
    hd_list = []
    for i in range(y_true.shape[0]):
        # Hard threshold at 0.5 (standard for evaluation metrics)
        gt = np.squeeze(y_true[i]) > 0.5
        pred = np.squeeze(y_pred[i]) > 0.5

        gt_pts = np.argwhere(gt)
        pred_pts = np.argwhere(pred)

        # Cases with empty masks
        if gt_pts.shape[0] == 0 and pred_pts.shape[0] == 0:
            hd_list.append(0.0)
            continue
        if gt_pts.shape[0] == 0 or pred_pts.shape[0] == 0:
            hd_list.append(400.0)  # large penalty - adjust to your image diagonal if needed (e.g. ~362 for 256×256, ~724 for 512×512)
            continue

        # Directed distances
        dist_gt_to_pred = cKDTree(pred_pts).query(gt_pts)[0]
        dist_pred_to_gt = cKDTree(gt_pts).query(pred_pts)[0]

        hd95 = max(
            np.percentile(dist_gt_to_pred, 95),
            np.percentile(dist_pred_to_gt, 95)
        )
        hd_list.append(hd95)

    return np.mean(hd_list, dtype=np.float32)

def hausdorff95_infection(y_true, y_pred):
    hd = tf.numpy_function(_calculate_hd95, [y_true, y_pred], tf.float32)
    hd.set_shape(())
    return hd

# Optional: KL Divergence (you already had this)
kld = tf.keras.losses.KLDivergence()

# %%
from tensorflow.keras.losses import BinaryCrossentropy

def loss_f(y_true, y_pred):
    bce = BinaryCrossentropy()
    return dice_loss(y_true, y_pred) + bce(y_true, y_pred) 

def loss_e(y_true, y_pred):
    bce = BinaryCrossentropy()
    return dice_loss(y_true, y_pred)  + kld(y_true, y_pred)
    
def dice_loss(y_true, y_pred):
    return 1. - dice_coef_infection(y_true, y_pred)

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Multiply, Conv2D, DepthwiseConv2D, Dense, Flatten, MaxPooling2D, UpSampling2D, concatenate, Activation, LayerNormalization, Add, Dropout, Conv2DTranspose, multiply, Reshape, GlobalAveragePooling2D, Permute, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Concatenate

def activation_block(x):
    x = Activation("gelu")(x)
    return LayerNormalization()(x)

def conv_stem(x, filters: int, patch_size: int):
    x = Conv2D(filters, kernel_size=patch_size,padding='same', strides=patch_size)(x)
    return activation_block(x)

def vector_block(xyz, cmf, red):
    # red means reduction
    # cmf means filters, denotes vector size
    opt1 = conv_stem(xyz, cmf, red)
    opt2 = conv_stem(xyz, cmf, red)
    
    o1 = GlobalAveragePooling2D()(opt1)
    o2 = GlobalAveragePooling2D()(opt2)

    o5 = concatenate([o1, o2], -1)
    return o5

def mlp_feature(vect, cmf):
    oo = Flatten()(vect)
    o6 = Dense(cmf, activation='gelu')(oo)
    o6 = Dropout(0.2)(o6)
    o6 = Dense(cmf * 2, activation='gelu')(o6)

    o6 = Reshape((1, cmf * 2))(o6)
    o7 = Permute((2, 1))(o6)

    o8 = multiply([o6, o7])
    
    o8 = Lambda(lambda x: tf.expand_dims(x, -1))(o8)
    
    o8 = Reshape((cmf, cmf, 4))(o8)

    return o8

def frz_block(xyz):
    shape = xyz.shape
    a1, a2, a3, a4 = shape[0], shape[1], shape[2], shape[3]
    cmf = a2
    o5 = vector_block(xyz, cmf, 5)
    o7 = mlp_feature(o5, cmf)

    o7 = concatenate([o7, xyz, o7], -1)
    return o7

def up_frz(x1, x2, n_filters):
    # Upsample x1 using Conv2DTranspose
    x1 = Conv2DTranspose(n_filters * 4, 3, strides=2, activation='gelu', padding="same")(x1)
    
    # Apply Conv2D to x2
    x2 = Conv2D(n_filters * 2, 3, activation='gelu', padding="same")(x2)
    
    # Apply attention mechanism
    x = concatenate([x1, x2])
    
    # Apply Dropout for regularization
    x = Dropout(0.3)(x)
    
    return x

def regu(x):
    filters = x.shape[-1]
    shortcut = x
    x = Conv2D(filters, (3, 3), activation='gelu', padding="same")(x)
    x = Add()([x, shortcut])
    return x

# %%
def squeeze_and_excite_block(inputs, ratio=24):
    """ Squeeze and Excitation block to recalibrate channel-wise features """
    filters = inputs.shape[-1]  # Number of input channels
    se_shape = (1, 1, filters)

    # Squeeze: Global Average Pooling
    se = GlobalAveragePooling2D()(inputs)
    se = Reshape(se_shape)(se)

    a = filters // ratio

    # Excitation: Dense layers to capture channel-wise dependencies
    if a > 8:
        se = Conv2D(filters // ratio, kernel_size=1, activation='swish', padding='same')(se)
        se = Conv2D(filters, kernel_size=1, activation='sigmoid', padding='same')(se)
    else:
        se = Conv2D(8, kernel_size=1, activation='swish', padding='same')(se)
        se = Conv2D(filters, kernel_size=1, activation='sigmoid', padding='same')(se)

    # Scale the input by channel-wise weights
    x = multiply([inputs, se])

    return x

def residual_block(x, filters, stride=1, padding='same'):
    shortcut = x
    x = Conv2D(filters * 6, 1, strides=stride, padding=padding, use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)
    x = DepthwiseConv2D(kernel_size=3, strides=stride, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)
    x = squeeze_and_excite_block(x)
    x = Conv2D(filters, 1, strides=stride, padding=padding, use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)
    x = Add()([x, shortcut])
    return x

def dense_block(inputs, num_layers, growth_rate, ratio=16):
    """Dense block where each layer is connected to all previous layers."""
    concat_features = inputs
    for i in range(num_layers):
        # BatchNorm -> ReLU -> Conv2D
        x = Conv2D(growth_rate, 3, activation='gelu', padding='same')(concat_features)

        # Concatenate input with new output (dense connection)
        concat_features = Concatenate()([concat_features, x])
        
    x = squeeze_and_excite_block(concat_features)

    return x

def attention_gate(X, g, channel,  
                   activation='ReLU', 
                   attention='add', name='att'):
    '''
    Self-attention gate modified from Oktay et al. 2018.
    
    attention_gate(X, g, channel,  activation='ReLU', attention='add', name='att')
    
    Input
    ----------
        X: input tensor, i.e., key and value.
        g: gated tensor, i.e., query.
        channel: number of intermediate channel.
                 Oktay et al. (2018) did not specify (denoted as F_int).
                 intermediate channel is expected to be smaller than the input channel.
        activation: a nonlinear attnetion activation.
                    The `sigma_1` in Oktay et al. 2018. Default is 'ReLU'.
        attention: 'add' for additive attention; 'multiply' for multiplicative attention.
                   Oktay et al. 2018 applied additive attention.
        name: prefix of the created keras layers.
        
    Output
    ----------
        X_att: output tensor.
    
    '''

    attention_func = eval(attention)
    
    # mapping the input tensor to the intermediate channel
    theta_att = Conv2D(channel, 1, use_bias=True)(X)
    
    # mapping the gate tensor
    phi_g = Conv2D(channel, 1, use_bias=True)(g)
    
    # ----- attention learning ----- #
    query = attention_func([theta_att, phi_g])
    
    # nonlinear activation
    f = Activation('gelu')(query)
    
    # linear transformation
    psi_f = Conv2D(1, 1, use_bias=True)(f)
    # ------------------------------ #
    
    # sigmoid activation as attention coefficients
    coef_att = Activation('sigmoid')(psi_f)
    
    # multiplicative attention masking
    X_att = multiply([X, coef_att])
    
    return X_att

inputs = (img_size, img_size, 1)

def model_build_func(input_shape, n_labels):
    inputs = Input(shape=input_shape, name='input_image')
    g_filter = 8
    u_filter = 8

    # Initial convolution
    initial = Conv2D(g_filter, (3, 3), activation='gelu', padding="same")(inputs)
    initial = dense_block(initial, 2, g_filter // 2)  # 80

    # Down-sampling path
    o1 = MaxPooling2D(2)(initial)
    o1 = frz_block(dense_block(o1, 2, g_filter))  # 40
    #o1 = squeeze_and_excite_block(o1)

    o2 = MaxPooling2D(2)(o1)
    o2 = frz_block(dense_block(o2, 2, g_filter * 2))  # 20
    #o2 = squeeze_and_excite_block(o2)

    o3 = MaxPooling2D(2)(o2)
    o3 = frz_block(dense_block(o3, 2, g_filter * 4))  # 10
    #o3 = squeeze_and_excite_block(o3)

    o4 = MaxPooling2D(2)(o3)
    o4 = frz_block(dense_block(o4, 2, g_filter * 8))  # 5
    #o4 = squeeze_and_excite_block(o4)

    o5 = MaxPooling2D(2)(o4)
    o5 = frz_block(dense_block(o5, 2, g_filter * 16))  # 5
    #o5 = squeeze_and_excite_block(o5)

    # Up-sampling path
    u1 = up_frz(o5, o4, u_filter * 16)  # 10
    #gate1 = attention_gate(o4, u1, u_filter * 16, attention='add')
    cu1 = concatenate([u1, o4])

    u2 = up_frz(cu1, o3, u_filter * 8)  # 20
    #gate2 = attention_gate(o3, u2, u_filter * 8, attention='add')
    cu2 = concatenate([u2, o3])  # 20

    u3 = up_frz(cu2, o2, u_filter * 4)  # 40
    #gate3 = attention_gate(o2, u3, u_filter * 4, attention='add')
    cu3 = concatenate([u3, o2])  # 40

    u4 = up_frz(cu3, o1, u_filter * 2)  # 80
    #gate4 = attention_gate(o1, u4, u_filter * 2, attention='add')
    cu4 = concatenate([u4, o1])  # 80

    u5 = Conv2DTranspose(u_filter * 4, 3, strides=2, activation='gelu', padding="same")(cu4)  # 80
    #gate5 = attention_gate(initial, u5, u_filter, attention='add')
    cu5 = concatenate([u5, initial])  # 80

    # Final segmentation map
    seg_map = Conv2D(n_labels, 3, activation='sigmoid', padding="same")(cu5)

    # Model definition
    model = Model(inputs=inputs, outputs=seg_map)

    return model


model = model_build_func(inputs, 1)

from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2_as_graph

def get_flops(model):
    """Calculate Floating Point Operations (FLOPs) of a Keras model in TensorFlow 2.x."""
    # Convert Keras model to a TensorFlow function
    concrete_func = tf.function(lambda inputs: model(inputs))
    concrete_func = concrete_func.get_concrete_function(
        tf.TensorSpec([1] + list(model.input_shape[1:]), model.input.dtype)
    )

    # Convert to frozen graph
    frozen_func, _ = convert_variables_to_constants_v2_as_graph(concrete_func)

    # Compute FLOPs
    flops = tf.compat.v1.profiler.profile(
        frozen_func.graph,
        options=tf.compat.v1.profiler.ProfileOptionBuilder.float_operation(),
    )

    return flops.total_float_ops

# Compute FLOPs
flops = get_flops(model)
print(f"Total FLOPs: {flops / 1e9:.2f} GFLOPs")  # Convert to GFLOPs

from tensorflow.keras.optimizers import Adam

optimizer = Adam(learning_rate=1e-3)
model.compile(optimizer=optimizer, loss=loss_f, metrics=[dice_coef_infection, iou_coef_infection, precision_infection, recall_infection, hausdorff95_infection, specificity_infection, accuracy_infection, f1_infection])

# Model summary
model.summary()
# Out:
# Total FLOPs: 12.57 GFLOPs
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_image (InputLayer)        [(None, 320, 320, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 320, 320, 8)  80          input_image[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 320, 320, 4)  292         conv2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 320, 320, 12) 0           conv2d[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 320, 320, 4)  436         concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 320, 320, 16) 0           concatenate[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 16)           0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 1, 16)     0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 1, 1, 8)      136         reshape[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 1, 1, 16)     144         conv2d_3[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 320, 320, 16) 0           concatenate_1[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 160, 160, 16) 0           multiply[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 160, 160, 8)  1160        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 160, 160, 24) 0           max_pooling2d[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 160, 160, 8)  1736        concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 160, 160, 32) 0           concatenate_2[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 32)           0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 1, 32)     0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 1, 1, 8)      264         reshape_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 1, 1, 32)     288         conv2d_7[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 160, 160, 32) 0           concatenate_3[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 160)  128160      multiply_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 160)  128160      multiply_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 160)  0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 160)  0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# layer_normalization (LayerNorma (None, 32, 32, 160)  320         activation[0][0]
# __________________________________________________________________________________________________
# layer_normalization_1 (LayerNor (None, 32, 32, 160)  320         activation_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 160)          0           layer_normalization[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 160)          0           layer_normalization_1[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 320)          0           global_average_pooling2d_2[0][0]
#                                                                  global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 320)          0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 160)          51360       flatten[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 160)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 320)          51520       dropout[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 320)       0           dense_1[0][0]
# __________________________________________________________________________________________________
# permute (Permute)               (None, 320, 1)       0           reshape_2[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 320, 320)     0           reshape_2[0][0]
#                                                                  permute[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 320, 320, 1)  0           multiply_2[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 160, 160, 4)  0           lambda[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 160, 160, 40) 0           reshape_3[0][0]
#                                                                  multiply_1[0][0]
#                                                                  reshape_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 80, 80, 40)   0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 80, 80, 16)   5776        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 80, 80, 56)   0           max_pooling2d_1[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 80, 80, 16)   8080        concatenate_6[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 80, 80, 72)   0           concatenate_6[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 72)           0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1, 1, 72)     0           global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 1, 1, 8)      584         reshape_4[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 1, 1, 72)     648         conv2d_13[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 80, 80, 72)   0           concatenate_7[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 80)   144080      multiply_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 80)   144080      multiply_3[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 16, 16, 80)   0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 16, 16, 80)   0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# layer_normalization_2 (LayerNor (None, 16, 16, 80)   160         activation_2[0][0]
# __________________________________________________________________________________________________
# layer_normalization_3 (LayerNor (None, 16, 16, 80)   160         activation_3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 80)           0           layer_normalization_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 80)           0           layer_normalization_3[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 160)          0           global_average_pooling2d_5[0][0]
#                                                                  global_average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 160)          0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 80)           12880       flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 80)           0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 160)          12960       dropout_1[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 1, 160)       0           dense_3[0][0]
# __________________________________________________________________________________________________
# permute_1 (Permute)             (None, 160, 1)       0           reshape_5[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 160, 160)     0           reshape_5[0][0]
#                                                                  permute_1[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 160, 160, 1)  0           multiply_4[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 80, 80, 4)    0           lambda_1[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 80, 80, 80)   0           reshape_6[0][0]
#                                                                  multiply_3[0][0]
#                                                                  reshape_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 40, 40, 80)   0           concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 40, 40, 32)   23072       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 40, 40, 112)  0           max_pooling2d_2[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 40, 40, 32)   32288       concatenate_10[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 40, 40, 144)  0           concatenate_10[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 144)          0           concatenate_11[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 1, 1, 144)    0           global_average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 1, 1, 8)      1160        reshape_7[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 1, 1, 144)    1296        conv2d_19[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 40, 40, 144)  0           concatenate_11[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 8, 8, 40)     144040      multiply_5[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 8, 8, 40)     144040      multiply_5[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 8, 8, 40)     0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 8, 8, 40)     0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# layer_normalization_4 (LayerNor (None, 8, 8, 40)     80          activation_4[0][0]
# __________________________________________________________________________________________________
# layer_normalization_5 (LayerNor (None, 8, 8, 40)     80          activation_5[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_8 (Glo (None, 40)           0           layer_normalization_4[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_9 (Glo (None, 40)           0           layer_normalization_5[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 80)           0           global_average_pooling2d_8[0][0]
#                                                                  global_average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 80)           0           concatenate_12[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 40)           3240        flatten_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 40)           0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 80)           3280        dropout_2[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 1, 80)        0           dense_5[0][0]
# __________________________________________________________________________________________________
# permute_2 (Permute)             (None, 80, 1)        0           reshape_8[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 80, 80)       0           reshape_8[0][0]
#                                                                  permute_2[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 80, 80, 1)    0           multiply_6[0][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 40, 40, 4)    0           lambda_2[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 40, 40, 152)  0           reshape_9[0][0]
#                                                                  multiply_5[0][0]
#                                                                  reshape_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 20, 20, 152)  0           concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 20, 20, 64)   87616       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 20, 20, 216)  0           max_pooling2d_3[0][0]
#                                                                  conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 20, 20, 64)   124480      concatenate_14[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 20, 20, 280)  0           concatenate_14[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_10 (Gl (None, 280)          0           concatenate_15[0][0]
# __________________________________________________________________________________________________
# reshape_10 (Reshape)            (None, 1, 1, 280)    0           global_average_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 1, 1, 11)     3091        reshape_10[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 1, 1, 280)    3360        conv2d_25[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 20, 20, 280)  0           concatenate_15[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 4, 4, 20)     140020      multiply_7[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 4, 4, 20)     140020      multiply_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 4, 4, 20)     0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 4, 4, 20)     0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# layer_normalization_6 (LayerNor (None, 4, 4, 20)     40          activation_6[0][0]
# __________________________________________________________________________________________________
# layer_normalization_7 (LayerNor (None, 4, 4, 20)     40          activation_7[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_11 (Gl (None, 20)           0           layer_normalization_6[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_12 (Gl (None, 20)           0           layer_normalization_7[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 40)           0           global_average_pooling2d_11[0][0]
#                                                                  global_average_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 40)           0           concatenate_16[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 20)           820         flatten_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 20)           0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 40)           840         dropout_3[0][0]
# __________________________________________________________________________________________________
# reshape_11 (Reshape)            (None, 1, 40)        0           dense_7[0][0]
# __________________________________________________________________________________________________
# permute_3 (Permute)             (None, 40, 1)        0           reshape_11[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 40, 40)       0           reshape_11[0][0]
#                                                                  permute_3[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 40, 40, 1)    0           multiply_8[0][0]
# __________________________________________________________________________________________________
# reshape_12 (Reshape)            (None, 20, 20, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 20, 20, 288)  0           reshape_12[0][0]
#                                                                  multiply_7[0][0]
#                                                                  reshape_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 10, 10, 288)  0           concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 10, 10, 128)  331904      max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 10, 10, 416)  0           max_pooling2d_4[0][0]
#                                                                  conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 10, 10, 128)  479360      concatenate_18[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 10, 10, 544)  0           concatenate_18[0][0]
#                                                                  conv2d_30[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_13 (Gl (None, 544)          0           concatenate_19[0][0]
# __________________________________________________________________________________________________
# reshape_13 (Reshape)            (None, 1, 1, 544)    0           global_average_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 1, 1, 22)     11990       reshape_13[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 1, 1, 544)    12512       conv2d_31[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 10, 10, 544)  0           concatenate_19[0][0]
#                                                                  conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 2, 2, 10)     136010      multiply_9[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 2, 2, 10)     136010      multiply_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 2, 2, 10)     0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 2, 2, 10)     0           conv2d_34[0][0]
# __________________________________________________________________________________________________
# layer_normalization_8 (LayerNor (None, 2, 2, 10)     20          activation_8[0][0]
# __________________________________________________________________________________________________
# layer_normalization_9 (LayerNor (None, 2, 2, 10)     20          activation_9[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_14 (Gl (None, 10)           0           layer_normalization_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_15 (Gl (None, 10)           0           layer_normalization_9[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 20)           0           global_average_pooling2d_14[0][0]
#                                                                  global_average_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 20)           0           concatenate_20[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 10)           210         flatten_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 10)           0           dense_8[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 20)           220         dropout_4[0][0]
# __________________________________________________________________________________________________
# reshape_14 (Reshape)            (None, 1, 20)        0           dense_9[0][0]
# __________________________________________________________________________________________________
# permute_4 (Permute)             (None, 20, 1)        0           reshape_14[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 20, 20)       0           reshape_14[0][0]
#                                                                  permute_4[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 20, 20, 1)    0           multiply_10[0][0]
# __________________________________________________________________________________________________
# reshape_15 (Reshape)            (None, 10, 10, 4)    0           lambda_4[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 10, 10, 552)  0           reshape_15[0][0]
#                                                                  multiply_9[0][0]
#                                                                  reshape_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 20, 20, 512)  2544128     concatenate_21[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 20, 20, 256)  663808      concatenate_17[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 20, 20, 768)  0           conv2d_transpose[0][0]
#                                                                  conv2d_35[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 20, 20, 768)  0           concatenate_22[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 20, 20, 1056) 0           dropout_5[0][0]
#                                                                  concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 40, 40, 256)  2433280     concatenate_23[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 40, 40, 128)  175232      concatenate_13[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 40, 40, 384)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_36[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 40, 40, 384)  0           concatenate_24[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 40, 40, 536)  0           dropout_6[0][0]
#                                                                  concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 80, 80, 128)  617600      concatenate_25[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 80, 80, 64)   46144       concatenate_9[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 80, 80, 192)  0           conv2d_transpose_2[0][0]
#                                                                  conv2d_37[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 80, 80, 192)  0           concatenate_26[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 80, 80, 272)  0           dropout_7[0][0]
#                                                                  concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 160, 160, 64) 156736      concatenate_27[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 160, 160, 32) 11552       concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 160, 160, 96) 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_38[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 160, 160, 96) 0           concatenate_28[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 160, 160, 136 0           dropout_8[0][0]
#                                                                  concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 320, 320, 32) 39200       concatenate_29[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 320, 320, 48) 0           conv2d_transpose_4[0][0]
#                                                                  multiply[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 320, 320, 1)  433         concatenate_30[0][0]
# ==================================================================================================
# Total params: 9,343,056
# Trainable params: 9,343,056
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Install required packages
# !pip install openpyxl

# Imports
import openpyxl  # required for reading .xlsx files
import pandas as pd
import tensorflow as tf
import os
import shutil
from tensorflow.keras.callbacks import LearningRateScheduler, ReduceLROnPlateau

# File paths
checkpoint_filepath = '/kaggle/working/checkpoint.h5.keras'
metrics_file = '/kaggle/working/training_metrics.xlsx'
pre_checkpoint_filepath = '/kaggle/input/dseg-unet-4channel-covid19/checkpoint.h5.keras'
pre_metrics_file = '/kaggle/input/dseg-unet-4channel-covid19/training_metrics.xlsx'

# Restore checkpoint and metrics if available
if os.path.exists(pre_checkpoint_filepath):
    shutil.copy(pre_checkpoint_filepath, checkpoint_filepath)
    print(f"Restored checkpoint from: {pre_checkpoint_filepath}")

if os.path.exists(pre_metrics_file):
    shutil.copy(pre_metrics_file, metrics_file)
    print(f"Restored metrics file from: {pre_metrics_file}")

# Load last epoch
def load_last_epoch():
    if os.path.exists(metrics_file):
        try:
            df = pd.read_excel(metrics_file, engine='openpyxl')
            if not df.empty and 'epoch' in df.columns:
                return df['epoch'].iloc[-1] + 1
        except Exception as e:
            print(f"⚠️ Could not read metrics file: {e}")
    return 0

last_epoch = load_last_epoch()

# Get best validation loss from previous runs
def get_best_val_loss():
    if os.path.exists(metrics_file):
        try:
            df = pd.read_excel(metrics_file, engine='openpyxl')
            if 'val_loss' in df.columns and not df['val_loss'].isnull().all():
                return df['val_loss'].min()
        except Exception as e:
            print(f"⚠️ Could not read val_loss from metrics file: {e}")
    return float('inf')

best_val_loss = get_best_val_loss()

# Custom model checkpoint
class CustomModelCheckpoint(tf.keras.callbacks.Callback):
    def __init__(self, filepath):
        super().__init__()
        self.filepath = filepath
        self.best_loss = best_val_loss

    def on_epoch_end(self, epoch, logs=None):
        current_loss = logs.get('val_loss')
        if current_loss is not None and current_loss < self.best_loss:
            self.best_loss = current_loss
            self.model.save(self.filepath)
            print(f"✅ Model saved at epoch {epoch + 1} with val_loss: {current_loss:.4f}")

# === Learning Rate Schedule ===
def lr_schedule(epoch, lr):
    return 1e-4 if epoch >= 5 else lr

lr_scheduler = LearningRateScheduler(lr_schedule, verbose=1)

# Logger for Excel
class MetricsLogger(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        df_new = pd.DataFrame([{**logs, 'epoch': epoch}])
        try:
            if os.path.exists(metrics_file):
                df = pd.read_excel(metrics_file, engine='openpyxl')
                df = pd.concat([df, df_new], ignore_index=True)
            else:
                df = df_new
            df.to_excel(metrics_file, index=False, engine='openpyxl')
        except Exception as e:
            print(f"⚠️ Failed to log metrics: {e}")

# Early stopping with patience and saving best weights
class CustomEarlyStopping(tf.keras.callbacks.Callback):
    def __init__(self, patience=20):
        super().__init__()
        self.patience = patience
        self.wait = 0
        self.best_loss = best_val_loss

    def on_epoch_end(self, epoch, logs=None):
        current_loss = logs.get('val_loss')
        if current_loss is None:
            return
        if current_loss < self.best_loss:
            self.best_loss = current_loss
            self.wait = 0
            self.model.save_weights(checkpoint_filepath)
        else:
            self.wait += 1
            if self.wait >= self.patience:
                print(f"🛑 Early stopping at epoch {epoch + 1}")
                self.model.stop_training = True


# Final callbacks list
callbacks = [
    CustomModelCheckpoint(filepath=checkpoint_filepath),
    MetricsLogger(),
    lr_scheduler,
    CustomEarlyStopping(patience=20)
]
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.3-py2.py3-none-any.whl (251 kB)
#      |████████████████████████████████| 251 kB 20.2 MB/s eta 0:00:01
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.3

# %% [markdown]
# ## Training the model

# %%
import time
import os
import pandas as pd
import numpy as np
from tensorflow.keras.utils import Sequence
from tensorflow.keras.models import load_model

EPOCHS = 100

# Record the start time
start_time = time.time()

# === Load last completed epoch from metrics file ===
def load_last_epoch():
    if os.path.exists(pre_metrics_file):
        try:
            df = pd.read_excel(pre_metrics_file, engine='openpyxl')
            if not df.empty and 'epoch' in df.columns:
                return int(df['epoch'].iloc[-1]) + 1
        except Exception as e:
            print(f"⚠️ Failed to read metrics file: {e}")
    return 0

last_epoch = load_last_epoch()

# === Load pretrained weights if available ===
if os.path.exists(pre_checkpoint_filepath):
    print("✅ Checkpoint found. Loading pretrained weights...")
    model.load_weights(pre_checkpoint_filepath)
    print(f"🔁 Resuming training from epoch {last_epoch}")
else:
    print("🆕 No checkpoint found. Starting training from scratch.")
    last_epoch = 0

# === Prepare input and label tensors ===
lung_train = np.asarray(lung_train, dtype=np.float16)
infect_train = np.asarray(infect_train, dtype=np.uint8)

lung_temp = np.asarray(lung_temp, dtype=np.float16)
infect_temp = np.asarray(infect_temp, dtype=np.uint8)

lung_test = np.asarray(lung_test, dtype=np.float16)
infect_test = np.asarray(infect_test, dtype=np.uint8)

# === Data Generator ===
class LungDataGenerator(Sequence):
    def __init__(self, X, Y, batch_size=8, shuffle=True):
        self.X = X
        self.Y = Y
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indices = np.arange(len(X))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.X) / self.batch_size))

    def __getitem__(self, index):
        batch_ids = self.indices[index * self.batch_size:(index + 1) * self.batch_size]
        X_batch = self.X[batch_ids]
        Y_batch = self.Y[batch_ids]
        return np.asarray(X_batch, dtype=np.float16), np.asarray(Y_batch, dtype=np.uint8)

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indices)

# === Create generators ===
train_gen = LungDataGenerator(lung_train, infect_train, batch_size=8)
temp_gen = LungDataGenerator(lung_temp, infect_temp, batch_size=8, shuffle=False)
val_gen = LungDataGenerator(lung_test, infect_test, batch_size=8, shuffle=False)

# === Train the model ===
history = model.fit(
    train_gen,
    validation_data=temp_gen,
    epochs=EPOCHS,
    initial_epoch=last_epoch,
    callbacks=callbacks
)

# === Timing info ===
end_time = time.time()
total_time = end_time - start_time
print(f"✅ Total training time: {total_time:.2f} seconds ({total_time / 60:.2f} minutes)")
# Out:
# 🆕 No checkpoint found. Starting training from scratch.
# Epoch 1/100
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 196s 159ms/step - loss: 1.0836 - dice_coef_infection: 0.0650 - iou_coef_infection: 0.0357 - precision_infection: 0.0681 - recall_infection: 0.1625 - hausdorff95_infection: 203.8548 - specificity_infection: 0.9774 - accuracy_infection: 0.9700 - f1_infection: 0.8578 - val_loss: 0.8381 - val_dice_coef_infection: 0.2706 - val_iou_coef_infection: 0.2423 - val_precision_infection: 0.2611 - val_recall_infection: 0.7424 - val_hausdorff95_infection: 159.4120 - val_specificity_infection: 0.9850 - val_accuracy_infection: 0.9824 - val_f1_infection: 0.7274
# ✅ Model saved at epoch 1 with val_loss: 0.8381
# Epoch 2/100
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 177s 155ms/step - loss: 0.7944 - dice_coef_infection: 0.2609 - iou_coef_infection: 0.1674 - precision_infection: 0.2846 - recall_infection: 0.3978 - hausdorff95_infection: 120.8054 - specificity_infection: 0.9918 - accuracy_infection: 0.9869 - f1_infection: 0.7516 - val_loss: 0.5871 - val_dice_coef_infection: 0.4792 - val_iou_coef_infection: 0.4451 - val_precision_infection: 0.5377 - val_recall_infection: 0.6846 - val_hausdorff95_infection: 95.4921 - val_specificity_infection: 0.9972 - val_accuracy_infection: 0.9929 - val_f1_infection: 0.8173
# ✅ Model saved at epoch 2 with val_loss: 0.5871
# Epoch 3/100
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 178s 155ms/step - loss: 0.6618 - dice_coef_infection: 0.3891 - iou_coef_infection: 0.2727 - precision_infection: 0.4261 - recall_infection: 0.4731 - hausdorff95_infection: 110.8674 - specificity_infection: 0.9950 - accuracy_infection: 0.9909 - f1_infection: 0.7748 - val_loss: 0.6102 - val_dice_coef_infection: 0.5147 - val_iou_coef_infection: 0.4716 - val_precision_infection: 0.5304 - val_recall_infection: 0.7832 - val_hausdorff95_infection: 106.6367 - val_specificity_infection: 0.9931 - val_accuracy_infection: 0.9892 - val_f1_infection: 0.7944
# Epoch 4/100
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 178s 156ms/step - loss: 0.5484 - dice_coef_infection: 0.4894 - iou_coef_infection: 0.3604 - precision_infection: 0.5286 - recall_infection: 0.5637 - hausdorff95_infection: 91.5041 - specificity_infection: 0.9968 - accuracy_infection: 0.9936 - f1_infection: 0.7830 - val_loss: 0.5768 - val_dice_coef_infection: 0.5237 - val_iou_coef_infection: 0.4835 - val_precision_infection: 0.5519 - val_recall_infection: 0.7088 - val_hausdorff95_infection: 100.8992 - val_specificity_infection: 0.9968 - val_accuracy_infection: 0.9918 - val_f1_infection: 0.8286
# ✅ Model saved at epoch 4 with val_loss: 0.5768
# Epoch 5/100
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 178s 155ms/step - loss: 0.5253 - dice_coef_infection: 0.5133 - iou_coef_infection: 0.3781 - precision_infection: 0.5550 - recall_infection: 0.5877 - hausdorff95_infection: 86.0764 - specificity_infection: 0.9969 - accuracy_infection: 0.9939 - f1_infection: 0.7771 - val_loss: 0.5101 - val_dice_coef_infection: 0.5845 - val_iou_coef_infection: 0.5410 - val_precision_infection: 0.6666 - val_recall_infection: 0.6935 - val_hausdorff95_infection: 72.7672 - val_specificity_infection: 0.9983 - val_accuracy_infection: 0.9924 - val_f1_infection: 0.8396
# ✅ Model saved at epoch 5 with val_loss: 0.5101
# Epoch 6/100
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 177s 155ms/step - loss: 0.4014 - dice_coef_infection: 0.6243 - iou_coef_infection: 0.4880 - precision_infection: 0.6461 - recall_infection: 0.6645 - hausdorff95_infection: 64.2206 - specificity_infection: 0.9978 - accuracy_infection: 0.9954 - f1_infection: 0.8178 - val_loss: 0.4475 - val_dice_coef_infection: 0.6269 - val_iou_coef_infection: 0.5838 - val_precision_infection: 0.7096 - val_recall_infection: 0.7138 - val_hausdorff95_infection: 74.5094 - val_specificity_infection: 0.9979 - val_accuracy_infection: 0.9940 - val_f1_infection: 0.8522
# ✅ Model saved at epoch 6 with val_loss: 0.4475
# Epoch 7/100
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 155ms/step - loss: 0.3829 - dice_coef_infection: 0.6421 - iou_coef_infection: 0.5085 - precision_infection: 0.6647 - recall_infection: 0.6926 - hausdorff95_infection: 61.6249 - specificity_infection: 0.9979 - accuracy_infection: 0.9957 - f1_infection: 0.8201 - val_loss: 0.4305 - val_dice_coef_infection: 0.6459 - val_iou_coef_infection: 0.5989 - val_precision_infection: 0.7082 - val_recall_infection: 0.7362 - val_hausdorff95_infection: 66.3160 - val_specificity_infection: 0.9975 - val_accuracy_infection: 0.9939 - val_f1_infection: 0.8556
# ✅ Model saved at epoch 7 with val_loss: 0.4305
# Epoch 8/100
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 156ms/step - loss: 0.3748 - dice_coef_infection: 0.6522 - iou_coef_infection: 0.5176 - precision_infection: 0.6868 - recall_infection: 0.6825 - hausdorff95_infection: 54.0599 - specificity_infection: 0.9980 - accuracy_infection: 0.9958 - f1_infection: 0.8229 - val_loss: 0.4154 - val_dice_coef_infection: 0.6600 - val_iou_coef_infection: 0.6127 - val_precision_infection: 0.7273 - val_recall_infection: 0.7393 - val_hausdorff95_infection: 59.6979 - val_specificity_infection: 0.9976 - val_accuracy_infection: 0.9941 - val_f1_infection: 0.8586
# ✅ Model saved at epoch 8 with val_loss: 0.4154
# Epoch 9/100
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 179s 156ms/step - loss: 0.3817 - dice_coef_infection: 0.6444 - iou_coef_infection: 0.5113 - precision_infection: 0.6715 - recall_infection: 0.6829 - hausdorff95_infection: 52.6155 - specificity_infection: 0.9979 - accuracy_infection: 0.9958 - f1_infection: 0.8238 - val_loss: 0.4266 - val_dice_coef_infection: 0.6535 - val_iou_coef_infection: 0.6061 - val_precision_infection: 0.7355 - val_recall_infection: 0.7278 - val_hausdorff95_infection: 58.0310 - val_specificity_infection: 0.9980 - val_accuracy_infection: 0.9939 - val_f1_infection: 0.8537
# Epoch 10/100
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 179s 156ms/step - loss: 0.3564 - dice_coef_infection: 0.6696 - iou_coef_infection: 0.5374 - precision_infection: 0.6987 - recall_infection: 0.6994 - hausdorff95_infection: 51.1019 - specificity_infection: 0.9981 - accuracy_infection: 0.9959 - f1_infection: 0.8328 - val_loss: 0.4191 - val_dice_coef_infection: 0.6579 - val_iou_coef_infection: 0.6082 - val_precision_infection: 0.7146 - val_recall_infection: 0.7513 - val_hausdorff95_infection: 50.9166 - val_specificity_infection: 0.9978 - val_accuracy_infection: 0.9939 - val_f1_infection: 0.8557
# Epoch 11/100
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 156ms/step - loss: 0.3624 - dice_coef_infection: 0.6616 - iou_coef_infection: 0.5310 - precision_infection: 0.6798 - recall_infection: 0.7082 - hausdorff95_infection: 49.5828 - specificity_infection: 0.9980 - accuracy_infection: 0.9960 - f1_infection: 0.8299 - val_loss: 0.4051 - val_dice_coef_infection: 0.6674 - val_iou_coef_infection: 0.6210 - val_precision_infection: 0.7587 - val_recall_infection: 0.7203 - val_hausdorff95_infection: 59.6352 - val_specificity_infection: 0.9983 - val_accuracy_infection: 0.9943 - val_f1_infection: 0.8634
# ✅ Model saved at epoch 11 with val_loss: 0.4051
# Epoch 12/100
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 156ms/step - loss: 0.3617 - dice_coef_infection: 0.6636 - iou_coef_infection: 0.5339 - precision_infection: 0.6910 - recall_infection: 0.6933 - hausdorff95_infection: 49.5302 - specificity_infection: 0.9981 - accuracy_infection: 0.9960 - f1_infection: 0.8353 - val_loss: 0.3990 - val_dice_coef_infection: 0.6708 - val_iou_coef_infection: 0.6251 - val_precision_infection: 0.7621 - val_recall_infection: 0.7264 - val_hausdorff95_infection: 60.1325 - val_specificity_infection: 0.9981 - val_accuracy_infection: 0.9945 - val_f1_infection: 0.8615
# ✅ Model saved at epoch 12 with val_loss: 0.3990
# Epoch 13/100
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 179s 156ms/step - loss: 0.3468 - dice_coef_infection: 0.6764 - iou_coef_infection: 0.5438 - precision_infection: 0.6977 - recall_infection: 0.7100 - hausdorff95_infection: 48.0980 - specificity_infection: 0.9981 - accuracy_infection: 0.9961 - f1_infection: 0.8348 - val_loss: 0.4179 - val_dice_coef_infection: 0.6623 - val_iou_coef_infection: 0.6155 - val_precision_infection: 0.7645 - val_recall_infection: 0.7204 - val_hausdorff95_infection: 56.5628 - val_specificity_infection: 0.9985 - val_accuracy_infection: 0.9943 - val_f1_infection: 0.8549
# Epoch 14/100
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 179s 156ms/step - loss: 0.3393 - dice_coef_infection: 0.6863 - iou_coef_infection: 0.5561 - precision_infection: 0.7203 - recall_infection: 0.7106 - hausdorff95_infection: 45.2250 - specificity_infection: 0.9982 - accuracy_infection: 0.9960 - f1_infection: 0.8382 - val_loss: 0.4255 - val_dice_coef_infection: 0.6413 - val_iou_coef_infection: 0.5971 - val_precision_infection: 0.7545 - val_recall_infection: 0.7111 - val_hausdorff95_infection: 64.6386 - val_specificity_infection: 0.9984 - val_accuracy_infection: 0.9945 - val_f1_infection: 0.8472
# Epoch 15/100
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 156ms/step - loss: 0.3419 - dice_coef_infection: 0.6831 - iou_coef_infection: 0.5499 - precision_infection: 0.7179 - recall_infection: 0.7085 - hausdorff95_infection: 42.4187 - specificity_infection: 0.9980 - accuracy_infection: 0.9960 - f1_infection: 0.8317 - val_loss: 0.3821 - val_dice_coef_infection: 0.6867 - val_iou_coef_infection: 0.6447 - val_precision_infection: 0.8221 - val_recall_infection: 0.7148 - val_hausdorff95_infection: 64.2296 - val_specificity_infection: 0.9982 - val_accuracy_infection: 0.9950 - val_f1_infection: 0.8610
# ✅ Model saved at epoch 15 with val_loss: 0.3821
# Epoch 16/100
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 156ms/step - loss: 0.3272 - dice_coef_infection: 0.6978 - iou_coef_infection: 0.5639 - precision_infection: 0.7295 - recall_infection: 0.7216 - hausdorff95_infection: 40.2983 - specificity_infection: 0.9982 - accuracy_infection: 0.9962 - f1_infection: 0.8362 - val_loss: 0.3899 - val_dice_coef_infection: 0.6989 - val_iou_coef_infection: 0.6522 - val_precision_infection: 0.8103 - val_recall_infection: 0.7175 - val_hausdorff95_infection: 55.2623 - val_specificity_infection: 0.9986 - val_accuracy_infection: 0.9943 - val_f1_infection: 0.8719
# Epoch 17/100
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 156ms/step - loss: 0.3525 - dice_coef_infection: 0.6749 - iou_coef_infection: 0.5431 - precision_infection: 0.7313 - recall_infection: 0.6944 - hausdorff95_infection: 41.7330 - specificity_infection: 0.9983 - accuracy_infection: 0.9961 - f1_infection: 0.8281 - val_loss: 0.3900 - val_dice_coef_infection: 0.6836 - val_iou_coef_infection: 0.6407 - val_precision_infection: 0.8181 - val_recall_infection: 0.7066 - val_hausdorff95_infection: 65.6641 - val_specificity_infection: 0.9986 - val_accuracy_infection: 0.9945 - val_f1_infection: 0.8630
# Epoch 18/100
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 156ms/step - loss: 0.3105 - dice_coef_infection: 0.7135 - iou_coef_infection: 0.5830 - precision_infection: 0.7407 - recall_infection: 0.7328 - hausdorff95_infection: 39.6318 - specificity_infection: 0.9981 - accuracy_infection: 0.9962 - f1_infection: 0.8456 - val_loss: 0.3803 - val_dice_coef_infection: 0.6988 - val_iou_coef_infection: 0.6534 - val_precision_infection: 0.8205 - val_recall_infection: 0.7114 - val_hausdorff95_infection: 56.9368 - val_specificity_infection: 0.9986 - val_accuracy_infection: 0.9943 - val_f1_infection: 0.8701
# ✅ Model saved at epoch 18 with val_loss: 0.3803
# Epoch 19/100
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 156ms/step - loss: 0.3259 - dice_coef_infection: 0.6976 - iou_coef_infection: 0.5679 - precision_infection: 0.7200 - recall_infection: 0.7312 - hausdorff95_infection: 39.6484 - specificity_infection: 0.9980 - accuracy_infection: 0.9962 - f1_infection: 0.8392 - val_loss: 0.3856 - val_dice_coef_infection: 0.6943 - val_iou_coef_infection: 0.6516 - val_precision_infection: 0.8277 - val_recall_infection: 0.7077 - val_hausdorff95_infection: 63.0822 - val_specificity_infection: 0.9984 - val_accuracy_infection: 0.9943 - val_f1_infection: 0.8685
# Epoch 20/100
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 156ms/step - loss: 0.3154 - dice_coef_infection: 0.7082 - iou_coef_infection: 0.5778 - precision_infection: 0.7370 - recall_infection: 0.7344 - hausdorff95_infection: 39.2607 - specificity_infection: 0.9982 - accuracy_infection: 0.9963 - f1_infection: 0.8416 - val_loss: 0.4119 - val_dice_coef_infection: 0.6775 - val_iou_coef_infection: 0.6322 - val_precision_infection: 0.8205 - val_recall_infection: 0.7037 - val_hausdorff95_infection: 63.9853 - val_specificity_infection: 0.9987 - val_accuracy_infection: 0.9940 - val_f1_infection: 0.8546
# Epoch 21/100
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 156ms/step - loss: 0.3106 - dice_coef_infection: 0.7134 - iou_coef_infection: 0.5857 - precision_infection: 0.7463 - recall_infection: 0.7327 - hausdorff95_infection: 34.3455 - specificity_infection: 0.9981 - accuracy_infection: 0.9963 - f1_infection: 0.8460 - val_loss: 0.3926 - val_dice_coef_infection: 0.6854 - val_iou_coef_infection: 0.6417 - val_precision_infection: 0.8142 - val_recall_infection: 0.7106 - val_hausdorff95_infection: 65.3614 - val_specificity_infection: 0.9982 - val_accuracy_infection: 0.9942 - val_f1_infection: 0.8630
# Epoch 22/100
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 156ms/step - loss: 0.3349 - dice_coef_infection: 0.6894 - iou_coef_infection: 0.5615 - precision_infection: 0.7334 - recall_infection: 0.7119 - hausdorff95_infection: 34.7820 - specificity_infection: 0.9982 - accuracy_infection: 0.9963 - f1_infection: 0.8367 - val_loss: 0.4166 - val_dice_coef_infection: 0.6666 - val_iou_coef_infection: 0.6281 - val_precision_infection: 0.8703 - val_recall_infection: 0.6836 - val_hausdorff95_infection: 74.4276 - val_specificity_infection: 0.9989 - val_accuracy_infection: 0.9943 - val_f1_infection: 0.8418
# Epoch 23/100
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 156ms/step - loss: 0.3040 - dice_coef_infection: 0.7193 - iou_coef_infection: 0.5911 - precision_infection: 0.7432 - recall_infection: 0.7428 - hausdorff95_infection: 33.8337 - specificity_infection: 0.9981 - accuracy_infection: 0.9963 - f1_infection: 0.8488 - val_loss: 0.3910 - val_dice_coef_infection: 0.6874 - val_iou_coef_infection: 0.6429 - val_precision_infection: 0.8429 - val_recall_infection: 0.7023 - val_hausdorff95_infection: 65.4425 - val_specificity_infection: 0.9987 - val_accuracy_infection: 0.9943 - val_f1_infection: 0.8561
# Epoch 24/100
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 156ms/step - loss: 0.2992 - dice_coef_infection: 0.7225 - iou_coef_infection: 0.5950 - precision_infection: 0.7566 - recall_infection: 0.7406 - hausdorff95_infection: 35.0913 - specificity_infection: 0.9982 - accuracy_infection: 0.9965 - f1_infection: 0.8478 - val_loss: 0.3941 - val_dice_coef_infection: 0.6904 - val_iou_coef_infection: 0.6435 - val_precision_infection: 0.8090 - val_recall_infection: 0.7142 - val_hausdorff95_infection: 58.7340 - val_specificity_infection: 0.9986 - val_accuracy_infection: 0.9938 - val_f1_infection: 0.8655
# Epoch 25/100
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 156ms/step - loss: 0.3001 - dice_coef_infection: 0.7225 - iou_coef_infection: 0.5949 - precision_infection: 0.7446 - recall_infection: 0.7488 - hausdorff95_infection: 35.1746 - specificity_infection: 0.9980 - accuracy_infection: 0.9963 - f1_infection: 0.8487 - val_loss: 0.3985 - val_dice_coef_infection: 0.6832 - val_iou_coef_infection: 0.6489 - val_precision_infection: 0.8947 - val_recall_infection: 0.6785 - val_hausdorff95_infection: 80.6085 - val_specificity_infection: 0.9989 - val_accuracy_infection: 0.9947 - val_f1_infection: 0.8543
# Epoch 26/100
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 156ms/step - loss: 0.3051 - dice_coef_infection: 0.7177 - iou_coef_infection: 0.5905 - precision_infection: 0.7570 - recall_infection: 0.7302 - hausdorff95_infection: 32.6395 - specificity_infection: 0.9982 - accuracy_infection: 0.9965 - f1_infection: 0.8479 - val_loss: 0.3671 - val_dice_coef_infection: 0.7093 - val_iou_coef_infection: 0.6613 - val_precision_infection: 0.8274 - val_recall_infection: 0.7152 - val_hausdorff95_infection: 53.7931 - val_specificity_infection: 0.9987 - val_accuracy_infection: 0.9941 - val_f1_infection: 0.8747
# ✅ Model saved at epoch 26 with val_loss: 0.3671
# Epoch 27/100
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 156ms/step - loss: 0.2973 - dice_coef_infection: 0.7262 - iou_coef_infection: 0.5998 - precision_infection: 0.7608 - recall_infection: 0.7395 - hausdorff95_infection: 33.6242 - specificity_infection: 0.9983 - accuracy_infection: 0.9964 - f1_infection: 0.8517 - val_loss: 0.3625 - val_dice_coef_infection: 0.7083 - val_iou_coef_infection: 0.6603 - val_precision_infection: 0.8233 - val_recall_infection: 0.7188 - val_hausdorff95_infection: 52.5105 - val_specificity_infection: 0.9986 - val_accuracy_infection: 0.9941 - val_f1_infection: 0.8733
# ✅ Model saved at epoch 27 with val_loss: 0.3625
# Epoch 28/100
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 156ms/step - loss: 0.2959 - dice_coef_infection: 0.7262 - iou_coef_infection: 0.6004 - precision_infection: 0.7472 - recall_infection: 0.7532 - hausdorff95_infection: 30.5852 - specificity_infection: 0.9982 - accuracy_infection: 0.9964 - f1_infection: 0.8504 - val_loss: 0.3862 - val_dice_coef_infection: 0.6821 - val_iou_coef_infection: 0.6346 - val_precision_infection: 0.8025 - val_recall_infection: 0.7198 - val_hausdorff95_infection: 61.1685 - val_specificity_infection: 0.9982 - val_accuracy_infection: 0.9943 - val_f1_infection: 0.8559
# Epoch 29/100
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 156ms/step - loss: 0.2933 - dice_coef_infection: 0.7304 - iou_coef_infection: 0.6007 - precision_infection: 0.7588 - recall_infection: 0.7467 - hausdorff95_infection: 32.0873 - specificity_infection: 0.9982 - accuracy_infection: 0.9964 - f1_infection: 0.8491 - val_loss: 0.3660 - val_dice_coef_infection: 0.7033 - val_iou_coef_infection: 0.6588 - val_precision_infection: 0.8484 - val_recall_infection: 0.7067 - val_hausdorff95_infection: 60.6368 - val_specificity_infection: 0.9986 - val_accuracy_infection: 0.9943 - val_f1_infection: 0.8663
# Epoch 30/100
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 156ms/step - loss: 0.2926 - dice_coef_infection: 0.7282 - iou_coef_infection: 0.6006 - precision_infection: 0.7559 - recall_infection: 0.7443 - hausdorff95_infection: 27.4367 - specificity_infection: 0.9982 - accuracy_infection: 0.9966 - f1_infection: 0.8514 - val_loss: 0.3583 - val_dice_coef_infection: 0.7099 - val_iou_coef_infection: 0.6661 - val_precision_infection: 0.8589 - val_recall_infection: 0.7063 - val_hausdorff95_infection: 62.3126 - val_specificity_infection: 0.9985 - val_accuracy_infection: 0.9946 - val_f1_infection: 0.8693
# ✅ Model saved at epoch 30 with val_loss: 0.3583
# Epoch 31/100
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 156ms/step - loss: 0.2834 - dice_coef_infection: 0.7373 - iou_coef_infection: 0.6123 - precision_infection: 0.7648 - recall_infection: 0.7516 - hausdorff95_infection: 29.7491 - specificity_infection: 0.9981 - accuracy_infection: 0.9965 - f1_infection: 0.8562 - val_loss: 0.3725 - val_dice_coef_infection: 0.7068 - val_iou_coef_infection: 0.6623 - val_precision_infection: 0.8610 - val_recall_infection: 0.6992 - val_hausdorff95_infection: 63.5292 - val_specificity_infection: 0.9988 - val_accuracy_infection: 0.9941 - val_f1_infection: 0.8672
# Epoch 32/100
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 179s 156ms/step - loss: 0.2782 - dice_coef_infection: 0.7427 - iou_coef_infection: 0.6168 - precision_infection: 0.7657 - recall_infection: 0.7543 - hausdorff95_infection: 28.4103 - specificity_infection: 0.9982 - accuracy_infection: 0.9965 - f1_infection: 0.8587 - val_loss: 0.3812 - val_dice_coef_infection: 0.6951 - val_iou_coef_infection: 0.6452 - val_precision_infection: 0.7815 - val_recall_infection: 0.7349 - val_hausdorff95_infection: 49.6620 - val_specificity_infection: 0.9981 - val_accuracy_infection: 0.9939 - val_f1_infection: 0.8686
# Epoch 33/100
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 156ms/step - loss: 0.2802 - dice_coef_infection: 0.7414 - iou_coef_infection: 0.6142 - precision_infection: 0.7603 - recall_infection: 0.7560 - hausdorff95_infection: 27.7270 - specificity_infection: 0.9982 - accuracy_infection: 0.9964 - f1_infection: 0.8579 - val_loss: 0.3762 - val_dice_coef_infection: 0.7005 - val_iou_coef_infection: 0.6590 - val_precision_infection: 0.8554 - val_recall_infection: 0.7015 - val_hausdorff95_infection: 71.4016 - val_specificity_infection: 0.9987 - val_accuracy_infection: 0.9946 - val_f1_infection: 0.8672
# Epoch 34/100
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 156ms/step - loss: 0.2784 - dice_coef_infection: 0.7427 - iou_coef_infection: 0.6194 - precision_infection: 0.7671 - recall_infection: 0.7580 - hausdorff95_infection: 27.6240 - specificity_infection: 0.9983 - accuracy_infection: 0.9966 - f1_infection: 0.8604 - val_loss: 0.3775 - val_dice_coef_infection: 0.6907 - val_iou_coef_infection: 0.6417 - val_precision_infection: 0.7976 - val_recall_infection: 0.7254 - val_hausdorff95_infection: 51.7271 - val_specificity_infection: 0.9984 - val_accuracy_infection: 0.9946 - val_f1_infection: 0.8627
# Epoch 35/100
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 156ms/step - loss: 0.2786 - dice_coef_infection: 0.7418 - iou_coef_infection: 0.6119 - precision_infection: 0.7530 - recall_infection: 0.7599 - hausdorff95_infection: 28.3209 - specificity_infection: 0.9981 - accuracy_infection: 0.9965 - f1_infection: 0.8569 - val_loss: 0.3891 - val_dice_coef_infection: 0.6914 - val_iou_coef_infection: 0.6430 - val_precision_infection: 0.8156 - val_recall_infection: 0.7107 - val_hausdorff95_infection: 59.2711 - val_specificity_infection: 0.9988 - val_accuracy_infection: 0.9943 - val_f1_infection: 0.8654
# Epoch 36/100
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 156ms/step - loss: 0.2756 - dice_coef_infection: 0.7464 - iou_coef_infection: 0.6222 - precision_infection: 0.7720 - recall_infection: 0.7587 - hausdorff95_infection: 28.6033 - specificity_infection: 0.9982 - accuracy_infection: 0.9964 - f1_infection: 0.8594 - val_loss: 0.3822 - val_dice_coef_infection: 0.6856 - val_iou_coef_infection: 0.6380 - val_precision_infection: 0.8025 - val_recall_infection: 0.7204 - val_hausdorff95_infection: 53.8816 - val_specificity_infection: 0.9985 - val_accuracy_infection: 0.9946 - val_f1_infection: 0.8603
# Epoch 37/100
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 156ms/step - loss: 0.2784 - dice_coef_infection: 0.7419 - iou_coef_infection: 0.6178 - precision_infection: 0.7649 - recall_infection: 0.7586 - hausdorff95_infection: 27.1840 - specificity_infection: 0.9982 - accuracy_infection: 0.9966 - f1_infection: 0.8574 - val_loss: 0.3661 - val_dice_coef_infection: 0.7124 - val_iou_coef_infection: 0.6656 - val_precision_infection: 0.8464 - val_recall_infection: 0.7135 - val_hausdorff95_infection: 57.5498 - val_specificity_infection: 0.9987 - val_accuracy_infection: 0.9945 - val_f1_infection: 0.8689
# Epoch 38/100
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 156ms/step - loss: 0.2866 - dice_coef_infection: 0.7347 - iou_coef_infection: 0.6096 - precision_infection: 0.7507 - recall_infection: 0.7605 - hausdorff95_infection: 29.2612 - specificity_infection: 0.9981 - accuracy_infection: 0.9964 - f1_infection: 0.8569 - val_loss: 0.3759 - val_dice_coef_infection: 0.6951 - val_iou_coef_infection: 0.6470 - val_precision_infection: 0.8209 - val_recall_infection: 0.7196 - val_hausdorff95_infection: 57.3001 - val_specificity_infection: 0.9986 - val_accuracy_infection: 0.9948 - val_f1_infection: 0.8613
# Epoch 39/100
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 156ms/step - loss: 0.2575 - dice_coef_infection: 0.7622 - iou_coef_infection: 0.6376 - precision_infection: 0.7797 - recall_infection: 0.7720 - hausdorff95_infection: 25.7492 - specificity_infection: 0.9983 - accuracy_infection: 0.9967 - f1_infection: 0.8661 - val_loss: 0.3656 - val_dice_coef_infection: 0.7057 - val_iou_coef_infection: 0.6585 - val_precision_infection: 0.8374 - val_recall_infection: 0.7185 - val_hausdorff95_infection: 56.1693 - val_specificity_infection: 0.9984 - val_accuracy_infection: 0.9948 - val_f1_infection: 0.8653
# Epoch 40/100
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 156ms/step - loss: 0.2659 - dice_coef_infection: 0.7548 - iou_coef_infection: 0.6296 - precision_infection: 0.7756 - recall_infection: 0.7654 - hausdorff95_infection: 26.5818 - specificity_infection: 0.9981 - accuracy_infection: 0.9965 - f1_infection: 0.8620 - val_loss: 0.3985 - val_dice_coef_infection: 0.6818 - val_iou_coef_infection: 0.6347 - val_precision_infection: 0.8213 - val_recall_infection: 0.7150 - val_hausdorff95_infection: 59.6717 - val_specificity_infection: 0.9987 - val_accuracy_infection: 0.9946 - val_f1_infection: 0.8522
# Epoch 41/100
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 156ms/step - loss: 0.2652 - dice_coef_infection: 0.7541 - iou_coef_infection: 0.6287 - precision_infection: 0.7652 - recall_infection: 0.7741 - hausdorff95_infection: 25.1803 - specificity_infection: 0.9983 - accuracy_infection: 0.9968 - f1_infection: 0.8626 - val_loss: 0.3752 - val_dice_coef_infection: 0.6921 - val_iou_coef_infection: 0.6450 - val_precision_infection: 0.8263 - val_recall_infection: 0.7147 - val_hausdorff95_infection: 58.2417 - val_specificity_infection: 0.9984 - val_accuracy_infection: 0.9947 - val_f1_infection: 0.8588
# Epoch 42/100
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 156ms/step - loss: 0.2542 - dice_coef_infection: 0.7663 - iou_coef_infection: 0.6423 - precision_infection: 0.7813 - recall_infection: 0.7753 - hausdorff95_infection: 25.4298 - specificity_infection: 0.9982 - accuracy_infection: 0.9965 - f1_infection: 0.8682 - val_loss: 0.3736 - val_dice_coef_infection: 0.6880 - val_iou_coef_infection: 0.6436 - val_precision_infection: 0.8426 - val_recall_infection: 0.7087 - val_hausdorff95_infection: 62.1039 - val_specificity_infection: 0.9984 - val_accuracy_infection: 0.9950 - val_f1_infection: 0.8557
# Epoch 43/100
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 179s 156ms/step - loss: 0.2670 - dice_coef_infection: 0.7538 - iou_coef_infection: 0.6291 - precision_infection: 0.7815 - recall_infection: 0.7628 - hausdorff95_infection: 25.8557 - specificity_infection: 0.9983 - accuracy_infection: 0.9967 - f1_infection: 0.8620 - val_loss: 0.3736 - val_dice_coef_infection: 0.6884 - val_iou_coef_infection: 0.6424 - val_precision_infection: 0.8390 - val_recall_infection: 0.7135 - val_hausdorff95_infection: 61.2545 - val_specificity_infection: 0.9982 - val_accuracy_infection: 0.9948 - val_f1_infection: 0.8524
# Epoch 44/100
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 156ms/step - loss: 0.2588 - dice_coef_infection: 0.7609 - iou_coef_infection: 0.6379 - precision_infection: 0.7803 - recall_infection: 0.7771 - hausdorff95_infection: 24.7579 - specificity_infection: 0.9982 - accuracy_infection: 0.9967 - f1_infection: 0.8640 - val_loss: 0.4328 - val_dice_coef_infection: 0.6644 - val_iou_coef_infection: 0.6204 - val_precision_infection: 0.8503 - val_recall_infection: 0.6691 - val_hausdorff95_infection: 74.2041 - val_specificity_infection: 0.9994 - val_accuracy_infection: 0.9933 - val_f1_infection: 0.8504
# Epoch 45/100
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 177s 155ms/step - loss: 0.2618 - dice_coef_infection: 0.7581 - iou_coef_infection: 0.6323 - precision_infection: 0.7786 - recall_infection: 0.7654 - hausdorff95_infection: 25.5758 - specificity_infection: 0.9983 - accuracy_infection: 0.9966 - f1_infection: 0.8642 - val_loss: 0.3537 - val_dice_coef_infection: 0.7109 - val_iou_coef_infection: 0.6652 - val_precision_infection: 0.8668 - val_recall_infection: 0.7079 - val_hausdorff95_infection: 61.3088 - val_specificity_infection: 0.9987 - val_accuracy_infection: 0.9947 - val_f1_infection: 0.8635
# ✅ Model saved at epoch 45 with val_loss: 0.3537
# Epoch 46/100
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 177s 155ms/step - loss: 0.2519 - dice_coef_infection: 0.7685 - iou_coef_infection: 0.6455 - precision_infection: 0.7870 - recall_infection: 0.7780 - hausdorff95_infection: 22.8083 - specificity_infection: 0.9983 - accuracy_infection: 0.9967 - f1_infection: 0.8678 - val_loss: 0.3820 - val_dice_coef_infection: 0.6953 - val_iou_coef_infection: 0.6494 - val_precision_infection: 0.8670 - val_recall_infection: 0.6961 - val_hausdorff95_infection: 62.2819 - val_specificity_infection: 0.9989 - val_accuracy_infection: 0.9941 - val_f1_infection: 0.8564
# Epoch 47/100
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 177s 155ms/step - loss: 0.2518 - dice_coef_infection: 0.7669 - iou_coef_infection: 0.6473 - precision_infection: 0.7913 - recall_infection: 0.7790 - hausdorff95_infection: 23.1042 - specificity_infection: 0.9983 - accuracy_infection: 0.9968 - f1_infection: 0.8673 - val_loss: 0.3553 - val_dice_coef_infection: 0.7120 - val_iou_coef_infection: 0.6658 - val_precision_infection: 0.8719 - val_recall_infection: 0.7109 - val_hausdorff95_infection: 59.2282 - val_specificity_infection: 0.9983 - val_accuracy_infection: 0.9946 - val_f1_infection: 0.8617
# Epoch 48/100
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 177s 155ms/step - loss: 0.2522 - dice_coef_infection: 0.7671 - iou_coef_infection: 0.6438 - precision_infection: 0.7854 - recall_infection: 0.7769 - hausdorff95_infection: 21.4274 - specificity_infection: 0.9982 - accuracy_infection: 0.9967 - f1_infection: 0.8677 - val_loss: 0.3706 - val_dice_coef_infection: 0.6942 - val_iou_coef_infection: 0.6488 - val_precision_infection: 0.8583 - val_recall_infection: 0.7047 - val_hausdorff95_infection: 65.3977 - val_specificity_infection: 0.9987 - val_accuracy_infection: 0.9949 - val_f1_infection: 0.8560
# Epoch 49/100
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 177s 155ms/step - loss: 0.3050 - dice_coef_infection: 0.7190 - iou_coef_infection: 0.5926 - precision_infection: 0.7471 - recall_infection: 0.7399 - hausdorff95_infection: 35.4521 - specificity_infection: 0.9982 - accuracy_infection: 0.9965 - f1_infection: 0.8508 - val_loss: 0.3997 - val_dice_coef_infection: 0.6854 - val_iou_coef_infection: 0.6433 - val_precision_infection: 0.8892 - val_recall_infection: 0.6780 - val_hausdorff95_infection: 72.7570 - val_specificity_infection: 0.9992 - val_accuracy_infection: 0.9939 - val_f1_infection: 0.8502
# Epoch 50/100
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 177s 155ms/step - loss: 0.2632 - dice_coef_infection: 0.7570 - iou_coef_infection: 0.6332 - precision_infection: 0.7909 - recall_infection: 0.7640 - hausdorff95_infection: 22.5065 - specificity_infection: 0.9983 - accuracy_infection: 0.9967 - f1_infection: 0.8610 - val_loss: 0.3680 - val_dice_coef_infection: 0.7035 - val_iou_coef_infection: 0.6565 - val_precision_infection: 0.8624 - val_recall_infection: 0.7078 - val_hausdorff95_infection: 59.8114 - val_specificity_infection: 0.9987 - val_accuracy_infection: 0.9945 - val_f1_infection: 0.8586
# Epoch 51/100
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 177s 155ms/step - loss: 0.2434 - dice_coef_infection: 0.7750 - iou_coef_infection: 0.6536 - precision_infection: 0.7913 - recall_infection: 0.7860 - hausdorff95_infection: 22.2087 - specificity_infection: 0.9984 - accuracy_infection: 0.9969 - f1_infection: 0.8706 - val_loss: 0.3734 - val_dice_coef_infection: 0.7010 - val_iou_coef_infection: 0.6605 - val_precision_infection: 0.9126 - val_recall_infection: 0.6868 - val_hausdorff95_infection: 72.6815 - val_specificity_infection: 0.9990 - val_accuracy_infection: 0.9946 - val_f1_infection: 0.8536
# Epoch 52/100
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 177s 155ms/step - loss: 0.2642 - dice_coef_infection: 0.7553 - iou_coef_infection: 0.6335 - precision_infection: 0.7869 - recall_infection: 0.7626 - hausdorff95_infection: 23.3172 - specificity_infection: 0.9984 - accuracy_infection: 0.9968 - f1_infection: 0.8628 - val_loss: 0.3896 - val_dice_coef_infection: 0.6737 - val_iou_coef_infection: 0.6222 - val_precision_infection: 0.7857 - val_recall_infection: 0.7301 - val_hausdorff95_infection: 54.5014 - val_specificity_infection: 0.9985 - val_accuracy_infection: 0.9946 - val_f1_infection: 0.8484
# Epoch 53/100
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 177s 155ms/step - loss: 0.2495 - dice_coef_infection: 0.7697 - iou_coef_infection: 0.6491 - precision_infection: 0.7897 - recall_infection: 0.7794 - hausdorff95_infection: 24.0170 - specificity_infection: 0.9983 - accuracy_infection: 0.9968 - f1_infection: 0.8703 - val_loss: 0.3659 - val_dice_coef_infection: 0.7035 - val_iou_coef_infection: 0.6578 - val_precision_infection: 0.8597 - val_recall_infection: 0.7057 - val_hausdorff95_infection: 62.7817 - val_specificity_infection: 0.9986 - val_accuracy_infection: 0.9945 - val_f1_infection: 0.8623
# Epoch 54/100
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 177s 155ms/step - loss: 0.2483 - dice_coef_infection: 0.7700 - iou_coef_infection: 0.6497 - precision_infection: 0.7891 - recall_infection: 0.7805 - hausdorff95_infection: 22.0615 - specificity_infection: 0.9983 - accuracy_infection: 0.9969 - f1_infection: 0.8700 - val_loss: 0.3714 - val_dice_coef_infection: 0.6952 - val_iou_coef_infection: 0.6502 - val_precision_infection: 0.8591 - val_recall_infection: 0.7012 - val_hausdorff95_infection: 61.7809 - val_specificity_infection: 0.9986 - val_accuracy_infection: 0.9946 - val_f1_infection: 0.8572
# Epoch 55/100
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 177s 155ms/step - loss: 0.2628 - dice_coef_infection: 0.7583 - iou_coef_infection: 0.6338 - precision_infection: 0.7816 - recall_infection: 0.7726 - hausdorff95_infection: 24.2327 - specificity_infection: 0.9983 - accuracy_infection: 0.9967 - f1_infection: 0.8625 - val_loss: 0.4225 - val_dice_coef_infection: 0.6565 - val_iou_coef_infection: 0.6081 - val_precision_infection: 0.8159 - val_recall_infection: 0.6952 - val_hausdorff95_infection: 64.1392 - val_specificity_infection: 0.9990 - val_accuracy_infection: 0.9938 - val_f1_infection: 0.8387
# Epoch 56/100
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 177s 155ms/step - loss: 0.2532 - dice_coef_infection: 0.7657 - iou_coef_infection: 0.6442 - precision_infection: 0.7893 - recall_infection: 0.7738 - hausdorff95_infection: 21.2392 - specificity_infection: 0.9984 - accuracy_infection: 0.9968 - f1_infection: 0.8675 - val_loss: 0.3670 - val_dice_coef_infection: 0.7019 - val_iou_coef_infection: 0.6557 - val_precision_infection: 0.8563 - val_recall_infection: 0.7110 - val_hausdorff95_infection: 60.4539 - val_specificity_infection: 0.9987 - val_accuracy_infection: 0.9948 - val_f1_infection: 0.8588
# Epoch 57/100
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 177s 155ms/step - loss: 0.2656 - dice_coef_infection: 0.7548 - iou_coef_infection: 0.6302 - precision_infection: 0.7763 - recall_infection: 0.7699 - hausdorff95_infection: 25.8319 - specificity_infection: 0.9983 - accuracy_infection: 0.9967 - f1_infection: 0.8612 - val_loss: 0.3785 - val_dice_coef_infection: 0.6981 - val_iou_coef_infection: 0.6512 - val_precision_infection: 0.8480 - val_recall_infection: 0.7072 - val_hausdorff95_infection: 60.0677 - val_specificity_infection: 0.9987 - val_accuracy_infection: 0.9945 - val_f1_infection: 0.8593
# Epoch 58/100
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 177s 155ms/step - loss: 0.2377 - dice_coef_infection: 0.7800 - iou_coef_infection: 0.6623 - precision_infection: 0.7989 - recall_infection: 0.7906 - hausdorff95_infection: 21.0671 - specificity_infection: 0.9983 - accuracy_infection: 0.9969 - f1_infection: 0.8743 - val_loss: 0.3607 - val_dice_coef_infection: 0.7136 - val_iou_coef_infection: 0.6650 - val_precision_infection: 0.8507 - val_recall_infection: 0.7149 - val_hausdorff95_infection: 58.5735 - val_specificity_infection: 0.9987 - val_accuracy_infection: 0.9945 - val_f1_infection: 0.8663
# Epoch 59/100
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 177s 155ms/step - loss: 0.2478 - dice_coef_infection: 0.7706 - iou_coef_infection: 0.6505 - precision_infection: 0.7948 - recall_infection: 0.7848 - hausdorff95_infection: 22.0973 - specificity_infection: 0.9984 - accuracy_infection: 0.9969 - f1_infection: 0.8677 - val_loss: 0.3506 - val_dice_coef_infection: 0.7125 - val_iou_coef_infection: 0.6665 - val_precision_infection: 0.8638 - val_recall_infection: 0.7110 - val_hausdorff95_infection: 59.9590 - val_specificity_infection: 0.9984 - val_accuracy_infection: 0.9948 - val_f1_infection: 0.8647
# ✅ Model saved at epoch 59 with val_loss: 0.3506
# Epoch 60/100
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 177s 155ms/step - loss: 0.2519 - dice_coef_infection: 0.7674 - iou_coef_infection: 0.6419 - precision_infection: 0.7869 - recall_infection: 0.7748 - hausdorff95_infection: 23.8125 - specificity_infection: 0.9984 - accuracy_infection: 0.9968 - f1_infection: 0.8660 - val_loss: 0.3661 - val_dice_coef_infection: 0.7024 - val_iou_coef_infection: 0.6560 - val_precision_infection: 0.8600 - val_recall_infection: 0.7024 - val_hausdorff95_infection: 60.7038 - val_specificity_infection: 0.9987 - val_accuracy_infection: 0.9944 - val_f1_infection: 0.8609
# Epoch 61/100
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 177s 155ms/step - loss: 0.2366 - dice_coef_infection: 0.7801 - iou_coef_infection: 0.6635 - precision_infection: 0.7942 - recall_infection: 0.7945 - hausdorff95_infection: 19.9362 - specificity_infection: 0.9985 - accuracy_infection: 0.9971 - f1_infection: 0.8751 - val_loss: 0.3577 - val_dice_coef_infection: 0.7082 - val_iou_coef_infection: 0.6629 - val_precision_infection: 0.8599 - val_recall_infection: 0.7083 - val_hausdorff95_infection: 58.9961 - val_specificity_infection: 0.9983 - val_accuracy_infection: 0.9946 - val_f1_infection: 0.8637
# Epoch 62/100
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 177s 155ms/step - loss: 0.2241 - dice_coef_infection: 0.7937 - iou_coef_infection: 0.6767 - precision_infection: 0.8072 - recall_infection: 0.8063 - hausdorff95_infection: 18.9335 - specificity_infection: 0.9984 - accuracy_infection: 0.9969 - f1_infection: 0.8789 - val_loss: 0.3545 - val_dice_coef_infection: 0.7100 - val_iou_coef_infection: 0.6684 - val_precision_infection: 0.8751 - val_recall_infection: 0.7040 - val_hausdorff95_infection: 66.8023 - val_specificity_infection: 0.9984 - val_accuracy_infection: 0.9951 - val_f1_infection: 0.8654
# Epoch 63/100
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 155ms/step - loss: 0.2248 - dice_coef_infection: 0.7920 - iou_coef_infection: 0.6723 - precision_infection: 0.8047 - recall_infection: 0.7990 - hausdorff95_infection: 20.0280 - specificity_infection: 0.9984 - accuracy_infection: 0.9970 - f1_infection: 0.8782 - val_loss: 0.3689 - val_dice_coef_infection: 0.6872 - val_iou_coef_infection: 0.6452 - val_precision_infection: 0.8271 - val_recall_infection: 0.7104 - val_hausdorff95_infection: 63.4296 - val_specificity_infection: 0.9975 - val_accuracy_infection: 0.9950 - val_f1_infection: 0.8606
# Epoch 64/100
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 177s 155ms/step - loss: 0.2386 - dice_coef_infection: 0.7790 - iou_coef_infection: 0.6607 - precision_infection: 0.8027 - recall_infection: 0.7877 - hausdorff95_infection: 23.1044 - specificity_infection: 0.9984 - accuracy_infection: 0.9969 - f1_infection: 0.8726 - val_loss: 0.3730 - val_dice_coef_infection: 0.7000 - val_iou_coef_infection: 0.6496 - val_precision_infection: 0.8136 - val_recall_infection: 0.7281 - val_hausdorff95_infection: 56.2043 - val_specificity_infection: 0.9983 - val_accuracy_infection: 0.9945 - val_f1_infection: 0.8616
# Epoch 65/100
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 177s 155ms/step - loss: 0.2257 - dice_coef_infection: 0.7915 - iou_coef_infection: 0.6736 - precision_infection: 0.8072 - recall_infection: 0.7975 - hausdorff95_infection: 17.8191 - specificity_infection: 0.9983 - accuracy_infection: 0.9969 - f1_infection: 0.8785 - val_loss: 0.3555 - val_dice_coef_infection: 0.7053 - val_iou_coef_infection: 0.6572 - val_precision_infection: 0.8307 - val_recall_infection: 0.7195 - val_hausdorff95_infection: 55.6504 - val_specificity_infection: 0.9986 - val_accuracy_infection: 0.9949 - val_f1_infection: 0.8677
# Epoch 66/100
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 177s 155ms/step - loss: 0.2407 - dice_coef_infection: 0.7766 - iou_coef_infection: 0.6579 - precision_infection: 0.7956 - recall_infection: 0.7936 - hausdorff95_infection: 21.1505 - specificity_infection: 0.9985 - accuracy_infection: 0.9970 - f1_infection: 0.8708 - val_loss: 0.3630 - val_dice_coef_infection: 0.7092 - val_iou_coef_infection: 0.6634 - val_precision_infection: 0.8669 - val_recall_infection: 0.7028 - val_hausdorff95_infection: 60.5060 - val_specificity_infection: 0.9987 - val_accuracy_infection: 0.9946 - val_f1_infection: 0.8649
# Epoch 67/100
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 177s 155ms/step - loss: 0.2245 - dice_coef_infection: 0.7930 - iou_coef_infection: 0.6759 - precision_infection: 0.8078 - recall_infection: 0.8013 - hausdorff95_infection: 18.0099 - specificity_infection: 0.9984 - accuracy_infection: 0.9970 - f1_infection: 0.8798 - val_loss: 0.3849 - val_dice_coef_infection: 0.6902 - val_iou_coef_infection: 0.6480 - val_precision_infection: 0.8569 - val_recall_infection: 0.6942 - val_hausdorff95_infection: 66.3010 - val_specificity_infection: 0.9986 - val_accuracy_infection: 0.9943 - val_f1_infection: 0.8609
# Epoch 68/100
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 177s 155ms/step - loss: 0.2164 - dice_coef_infection: 0.8004 - iou_coef_infection: 0.6823 - precision_infection: 0.8042 - recall_infection: 0.8091 - hausdorff95_infection: 17.3116 - specificity_infection: 0.9983 - accuracy_infection: 0.9970 - f1_infection: 0.8837 - val_loss: 0.3638 - val_dice_coef_infection: 0.7103 - val_iou_coef_infection: 0.6650 - val_precision_infection: 0.8759 - val_recall_infection: 0.7005 - val_hausdorff95_infection: 62.2492 - val_specificity_infection: 0.9988 - val_accuracy_infection: 0.9944 - val_f1_infection: 0.8633
# Epoch 69/100
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 177s 155ms/step - loss: 0.2246 - dice_coef_infection: 0.7921 - iou_coef_infection: 0.6734 - precision_infection: 0.8087 - recall_infection: 0.8014 - hausdorff95_infection: 20.0030 - specificity_infection: 0.9985 - accuracy_infection: 0.9971 - f1_infection: 0.8777 - val_loss: 0.3674 - val_dice_coef_infection: 0.6998 - val_iou_coef_infection: 0.6529 - val_precision_infection: 0.8384 - val_recall_infection: 0.7112 - val_hausdorff95_infection: 62.2301 - val_specificity_infection: 0.9987 - val_accuracy_infection: 0.9949 - val_f1_infection: 0.8644
# Epoch 70/100
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 177s 155ms/step - loss: 0.2360 - dice_coef_infection: 0.7825 - iou_coef_infection: 0.6631 - precision_infection: 0.8021 - recall_infection: 0.7895 - hausdorff95_infection: 22.9814 - specificity_infection: 0.9985 - accuracy_infection: 0.9970 - f1_infection: 0.8746 - val_loss: 0.3605 - val_dice_coef_infection: 0.7006 - val_iou_coef_infection: 0.6544 - val_precision_infection: 0.8335 - val_recall_infection: 0.7140 - val_hausdorff95_infection: 62.1036 - val_specificity_infection: 0.9984 - val_accuracy_infection: 0.9951 - val_f1_infection: 0.8655
# Epoch 71/100
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 177s 155ms/step - loss: 0.2182 - dice_coef_infection: 0.7976 - iou_coef_infection: 0.6847 - precision_infection: 0.8189 - recall_infection: 0.8052 - hausdorff95_infection: 18.4341 - specificity_infection: 0.9985 - accuracy_infection: 0.9972 - f1_infection: 0.8815 - val_loss: 0.3700 - val_dice_coef_infection: 0.7011 - val_iou_coef_infection: 0.6596 - val_precision_infection: 0.8642 - val_recall_infection: 0.6961 - val_hausdorff95_infection: 67.7968 - val_specificity_infection: 0.9980 - val_accuracy_infection: 0.9944 - val_f1_infection: 0.8641
# Epoch 72/100
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 155ms/step - loss: 0.2106 - dice_coef_infection: 0.8058 - iou_coef_infection: 0.6905 - precision_infection: 0.8179 - recall_infection: 0.8131 - hausdorff95_infection: 17.9801 - specificity_infection: 0.9984 - accuracy_infection: 0.9971 - f1_infection: 0.8847 - val_loss: 0.3619 - val_dice_coef_infection: 0.7153 - val_iou_coef_infection: 0.6675 - val_precision_infection: 0.8377 - val_recall_infection: 0.7168 - val_hausdorff95_infection: 53.3885 - val_specificity_infection: 0.9984 - val_accuracy_infection: 0.9945 - val_f1_infection: 0.8733
# Epoch 73/100
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 155ms/step - loss: 0.2184 - dice_coef_infection: 0.7984 - iou_coef_infection: 0.6856 - precision_infection: 0.8133 - recall_infection: 0.8024 - hausdorff95_infection: 18.8735 - specificity_infection: 0.9985 - accuracy_infection: 0.9972 - f1_infection: 0.8850 - val_loss: 0.3860 - val_dice_coef_infection: 0.6888 - val_iou_coef_infection: 0.6423 - val_precision_infection: 0.8305 - val_recall_infection: 0.7043 - val_hausdorff95_infection: 61.4410 - val_specificity_infection: 0.9985 - val_accuracy_infection: 0.9944 - val_f1_infection: 0.8597
# Epoch 74/100
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 177s 155ms/step - loss: 0.2237 - dice_coef_infection: 0.7929 - iou_coef_infection: 0.6758 - precision_infection: 0.8112 - recall_infection: 0.8022 - hausdorff95_infection: 19.3012 - specificity_infection: 0.9985 - accuracy_infection: 0.9972 - f1_infection: 0.8780 - val_loss: 0.3645 - val_dice_coef_infection: 0.7120 - val_iou_coef_infection: 0.6660 - val_precision_infection: 0.8690 - val_recall_infection: 0.7053 - val_hausdorff95_infection: 60.7970 - val_specificity_infection: 0.9986 - val_accuracy_infection: 0.9946 - val_f1_infection: 0.8654
# Epoch 75/100
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 155ms/step - loss: 0.2375 - dice_coef_infection: 0.7806 - iou_coef_infection: 0.6650 - precision_infection: 0.8113 - recall_infection: 0.7889 - hausdorff95_infection: 18.3829 - specificity_infection: 0.9985 - accuracy_infection: 0.9970 - f1_infection: 0.8735 - val_loss: 0.3702 - val_dice_coef_infection: 0.7082 - val_iou_coef_infection: 0.6592 - val_precision_infection: 0.8350 - val_recall_infection: 0.7133 - val_hausdorff95_infection: 55.9009 - val_specificity_infection: 0.9986 - val_accuracy_infection: 0.9943 - val_f1_infection: 0.8692
# Epoch 76/100
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 177s 155ms/step - loss: 0.2193 - dice_coef_infection: 0.7973 - iou_coef_infection: 0.6824 - precision_infection: 0.8131 - recall_infection: 0.8063 - hausdorff95_infection: 16.5008 - specificity_infection: 0.9985 - accuracy_infection: 0.9971 - f1_infection: 0.8815 - val_loss: 0.4186 - val_dice_coef_infection: 0.6628 - val_iou_coef_infection: 0.6169 - val_precision_infection: 0.8236 - val_recall_infection: 0.6952 - val_hausdorff95_infection: 65.7090 - val_specificity_infection: 0.9990 - val_accuracy_infection: 0.9940 - val_f1_infection: 0.8443
# Epoch 77/100
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 155ms/step - loss: 0.2237 - dice_coef_infection: 0.7917 - iou_coef_infection: 0.6790 - precision_infection: 0.8136 - recall_infection: 0.8068 - hausdorff95_infection: 18.8352 - specificity_infection: 0.9985 - accuracy_infection: 0.9972 - f1_infection: 0.8787 - val_loss: 0.3573 - val_dice_coef_infection: 0.7059 - val_iou_coef_infection: 0.6611 - val_precision_infection: 0.8579 - val_recall_infection: 0.7127 - val_hausdorff95_infection: 62.3606 - val_specificity_infection: 0.9984 - val_accuracy_infection: 0.9952 - val_f1_infection: 0.8616
# Epoch 78/100
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 177s 155ms/step - loss: 0.2155 - dice_coef_infection: 0.8010 - iou_coef_infection: 0.6881 - precision_infection: 0.8119 - recall_infection: 0.8130 - hausdorff95_infection: 17.0693 - specificity_infection: 0.9984 - accuracy_infection: 0.9971 - f1_infection: 0.8849 - val_loss: 0.3764 - val_dice_coef_infection: 0.6996 - val_iou_coef_infection: 0.6498 - val_precision_infection: 0.8224 - val_recall_infection: 0.7144 - val_hausdorff95_infection: 52.2354 - val_specificity_infection: 0.9982 - val_accuracy_infection: 0.9940 - val_f1_infection: 0.8646
# Epoch 79/100
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 178s 155ms/step - loss: 0.2142 - dice_coef_infection: 0.8026 - iou_coef_infection: 0.6850 - precision_infection: 0.8157 - recall_infection: 0.8097 - hausdorff95_infection: 17.3231 - specificity_infection: 0.9984 - accuracy_infection: 0.9970 - f1_infection: 0.8823 - val_loss: 0.3560 - val_dice_coef_infection: 0.7094 - val_iou_coef_infection: 0.6583 - val_precision_infection: 0.8213 - val_recall_infection: 0.7325 - val_hausdorff95_infection: 49.3803 - val_specificity_infection: 0.9984 - val_accuracy_infection: 0.9948 - val_f1_infection: 0.8638
# 🛑 Early stopping at epoch 79
# ✅ Total training time: 14087.17 seconds (234.79 minutes)

# %% [markdown]
# ## Plotting the performance metrics

# %%
plt.plot(history.history['dice_coef_infection'])
plt.plot(history.history['val_dice_coef_infection'])
plt.title('dice_coef_infection vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Dice_coef')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# %%
plt.plot(history.history['iou_coef_infection'])
plt.plot(history.history['val_iou_coef_infection'])
plt.title('iou_coef_infection vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Iou_coef')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Val'], loc = 'upper right')
plt.show()

# %% [markdown]
# ## Using our trained model for prediction

# %%
import numpy as np
import time

# Start timer (high precision)
start_time = time.perf_counter()

# Evaluate the model on the validation generator
results = model.evaluate(val_gen, verbose=1)

# End timer
end_time = time.perf_counter()

# Calculate evaluation time
eval_time = end_time - start_time

# Print metric names with results
print("\n===== Validation Metrics =====")
for name, value in zip(model.metrics_names, results):
    print(f"{name}: {value:.6f}")

print(f"\nEvaluation Time: {eval_time:.8f} seconds\n")
# Out:
# 128/128 [==============================] - 8s 60ms/step - loss: 0.3124 - dice_coef_infection: 0.7302 - iou_coef_infection: 0.6798 - precision_infection: 0.8234 - recall_infection: 0.7983 - hausdorff95_infection: 49.9257 - specificity_infection: 0.9982 - accuracy_infection: 0.9963 - f1_infection: 0.8672
#
# ===== Validation Metrics =====
# loss: 0.312394
# dice_coef_infection: 0.730178
# iou_coef_infection: 0.679812
# precision_infection: 0.823417
# recall_infection: 0.798252
# hausdorff95_infection: 49.925659
# specificity_infection: 0.998239
# accuracy_infection: 0.996259
# f1_infection: 0.867159
#
# Evaluation Time: 7.71444450 seconds

# %%
import matplotlib.pyplot as plt
import numpy as np

# Run inference if not already done
predicted = model.predict(lung_test)

# Selected indices to visualize (744 as 1st, 280 as 2nd, 230 as 3rd)
selected_indices = [744, 280, 230]
n_samples = len(selected_indices)

# Mapping indices to custom names
name_mapping = {
    0: ("Image1_Covid", "GT1_Covid", "Predict1_Covid_DSEG_Unet"),  # Index 744
    1: ("Image2_Covid", "GT2_Covid", "Predict2_Covid_DSEG_Unet"),  # Index 280
    2: ("Image3_Covid", "GT3_Covid", "Predict3_Covid_DSEG_Unet")   # Index 230
}

# Plot
for j, i in enumerate(selected_indices):
    lung_img = lung_test[i][..., 0].astype(np.float32)
    gt_infect = (infect_test[i][..., 0] > 0.5).astype(np.float32)
    pred_infect = predicted[i][..., 0].astype(np.float32)

    # Normalize lung image
    if lung_img.max() > lung_img.min():
        lung_img = (lung_img - lung_img.min()) / (lung_img.max() - lung_img.min())
    lung_img = np.clip(lung_img, 0, 1)
    pred_infect = np.clip(pred_infect, 0, 1)

    # Get custom names for this index
    input_name, gt_name, pred_name = name_mapping[j]

    # Save Original Lung
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{input_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

    # Save Ground Truth Infection
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.imshow(gt_infect, cmap='Reds', alpha=0.6)
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{gt_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

    # Save Predicted Infection
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.imshow(pred_infect, cmap='Reds', alpha=0.6)
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{pred_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

print("Separate JPEG files saved for input images (Image1_Covid, Image2_Covid, Image3_Covid), "
      "ground truths (GT1_Covid, GT2_Covid, GT3_Covid), and predictions "
      "(Predict1_Covid_DSEG_Unet, Predict2_Covid_DSEG_Unet, Predict3_Covid_DSEG_Unet).")
# Out:
# Separate JPEG files saved for input images (Image1_Covid, Image2_Covid, Image3_Covid), ground truths (GT1_Covid, GT2_Covid, GT3_Covid), and predictions (Predict1_Covid_DSEG_Unet, Predict2_Covid_DSEG_Unet, Predict3_Covid_DSEG_Unet).
