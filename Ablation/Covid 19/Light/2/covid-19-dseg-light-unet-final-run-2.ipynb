# %% [markdown]
# ## Importing important libraries

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import nibabel as nib #for loading nii files
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf #for deep learning

# %% [markdown]
# ## Reading the metadata

# %%
data = pd.read_csv('../input/covid19-ct-scans/metadata.csv')
data.head()
# Out:
#                                              ct_scan  \
# 0  ../input/covid19-ct-scans/ct_scans/coronacases...
# 1  ../input/covid19-ct-scans/ct_scans/coronacases...
# 2  ../input/covid19-ct-scans/ct_scans/coronacases...
# 3  ../input/covid19-ct-scans/ct_scans/coronacases...
# 4  ../input/covid19-ct-scans/ct_scans/coronacases...
#
#                                            lung_mask  \
# 0  ../input/covid19-ct-scans/lung_mask/coronacase...
# 1  ../input/covid19-ct-scans/lung_mask/coronacase...
# 2  ../input/covid19-ct-scans/lung_mask/coronacase...
# 3  ../input/covid19-ct-scans/lung_mask/coronacase...
# 4  ../input/covid19-ct-scans/lung_mask/coronacase...
#
#                                       infection_mask  \
# 0  ../input/covid19-ct-scans/infection_mask/coron...
# 1  ../input/covid19-ct-scans/infection_mask/coron...
# 2  ../input/covid19-ct-scans/infection_mask/coron...
# 3  ../input/covid19-ct-scans/infection_mask/coron...
# 4  ../input/covid19-ct-scans/infection_mask/coron...
#
#                              lung_and_infection_mask
# 0  ../input/covid19-ct-scans/lung_and_infection_m...
# 1  ../input/covid19-ct-scans/lung_and_infection_m...
# 2  ../input/covid19-ct-scans/lung_and_infection_m...
# 3  ../input/covid19-ct-scans/lung_and_infection_m...
# 4  ../input/covid19-ct-scans/lung_and_infection_m...

# %% [markdown]
# ## Defining function for readiing .nii files

# %%
def read_nii(filepath):
    '''
    Reads .nii file and returns pixel array
    '''
    ct_scan = nib.load(filepath)
    array   = ct_scan.get_fdata()
    array   = np.rot90(np.array(array))
    return(array)

# %% [markdown]
# ## Reading the chest ct scan data

# %%
# Read sample
sample_ct   = read_nii(data.loc[2,'ct_scan'])
sample_lung = read_nii(data.loc[2,'lung_mask'])
sample_infe = read_nii(data.loc[2,'infection_mask'])
sample_all  = read_nii(data.loc[2,'lung_and_infection_mask'])

# %% [markdown]
# ## Plotting the sample images

# %%
fig = plt.figure(figsize = (18,15))
plt.subplot(1,4,1)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.title('Original Image')

plt.subplot(1,4,2)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_lung[..., 150],alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung Mask')

plt.subplot(1,4,3)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_infe[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Infection Mask')

plt.subplot(1,4,4)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_all[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung and Infection Mask')
# Out:
# Text(0.5, 1.0, 'Lung and Infection Mask')

# %% [markdown]
# ## Converting the data into array for training model

# %%
import numpy as np
import cv2
import random
from scipy.ndimage import rotate, shift, zoom

lungs = []
infections = []
case_ids = []
img_size = 320

# ----------- Load and Resize Data -----------
for case_index in range(len(data)):
    ct = read_nii(data['ct_scan'][case_index])
    infect = read_nii(data['infection_mask'][case_index])

    for slice_index in range(ct.shape[0]):
        lung_img = cv2.resize(ct[slice_index], dsize=(img_size, img_size)).astype('float32')
        infec_img = cv2.resize(infect[slice_index], dsize=(img_size, img_size)).astype('float32')

        lungs.append(lung_img[..., np.newaxis])
        infections.append(infec_img[..., np.newaxis])
        case_ids.append(case_index)

# %%
import numpy as np

# case_ids should be a NumPy array telling which case each slice belongs to
# Convert and binarize
lungs = np.array(lungs, dtype=np.float32)
infections = (np.array(infections, dtype=np.uint8) > 0.5).astype(np.uint8)
case_ids = np.array(case_ids)

# %% [markdown]
# ## Performing test and train split

# %%
# ----------- Case-wise Split -----------
unique_cases = np.unique(case_ids)
train_cases = np.append(unique_cases[2:4], unique_cases[6:20])
temp_cases = unique_cases[4:6]
val_cases = unique_cases[:2]

train_mask = np.isin(case_ids, train_cases)
temp_mask = np.isin(case_ids, temp_cases)
val_mask = np.isin(case_ids, val_cases)

lung_train = lungs[train_mask]
infect_train = infections[train_mask]
lung_temp = lungs[temp_mask]
infect_temp = infections[temp_mask]
lung_test = lungs[val_mask]
infect_test = infections[val_mask]

print(f"✅ Train: {lung_train.shape[0]} slices from {len(train_cases)} cases")
print(f"✅ Validation: {lung_temp.shape[0]} slices from {len(temp_cases)} cases")
print(f"✅ Test: {lung_test.shape[0]} slices from {len(val_cases)} cases")

# ----------- Augmentation -----------
def augment_image(img, mask):
    if random.random() < 0.5:
        img = np.fliplr(img)
        mask = np.fliplr(mask)
    if random.random() < 0.5:
        img = np.flipud(img)
        mask = np.flipud(mask)

    angle = random.uniform(-15, 15)
    img = rotate(img, angle, reshape=False, order=1, mode='nearest')
    mask = rotate(mask, angle, reshape=False, order=0, mode='nearest')

    shift_val = np.random.uniform(-0.1, 0.1, size=2) * img.shape[:2]
    img = shift(img, shift=(*shift_val, 0), order=1, mode='nearest')
    mask = shift(mask, shift=(*shift_val, 0), order=0, mode='nearest')

    zoom_factor = random.uniform(0.9, 1.1)
    img = zoom(img, (zoom_factor, zoom_factor, 1), order=1)
    mask = zoom(mask, (zoom_factor, zoom_factor, 1), order=0)

    return fix_shape(img), fix_shape(mask)

def fix_shape(arr, target_size=(320, 320)):
    h, w, c = arr.shape
    th, tw = target_size
    dh = th - h
    dw = tw - w
    if dh > 0 or dw > 0:
        pad_h = (max(dh // 2, 0), max(dh - dh // 2, 0))
        pad_w = (max(dw // 2, 0), max(dw - dw // 2, 0))
        arr = np.pad(arr, (pad_h, pad_w, (0, 0)), mode='constant')
    arr = arr[:th, :tw, :]
    return arr.astype('float32')

# ----------- Apply Augmentation -----------
aug_lung_train = []
aug_infect_train = []

for i in range(len(lung_train)):
    img, mask = augment_image(lung_train[i], infect_train[i])
    aug_lung_train.append(img)
    aug_infect_train.append(mask)

lung_train = np.stack(aug_lung_train)
infect_train = np.stack(aug_infect_train)

# Final Binarization
infect_train = (infect_train > 0.5).astype(np.uint8)
infect_test = (infect_test > 0.5).astype(np.uint8)

print(f"✅ Augmented training shape: {lung_train.shape}")
print("✅ All preprocessing complete.")
# Out:
# ✅ Train: 9143 slices from 16 cases
# ✅ Validation: 1024 slices from 2 cases
# ✅ Test: 1024 slices from 2 cases
# ✅ Augmented training shape: (9143, 320, 320, 1)
# ✅ All preprocessing complete.

# %%
import tensorflow as tf
from tensorflow.keras import backend as K
import numpy as np
from scipy.spatial import cKDTree

smooth = 1.0

# Binary Dice coefficient (soft - commonly used during training)
def dice_coef_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# Binary IoU coefficient (soft)
def iou_coef_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# Soft Precision
def precision_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + smooth) / (K.sum(y_pred_f) + smooth)

# Soft Recall (Sensitivity)
def recall_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + smooth) / (K.sum(y_true_f) + smooth)

# Soft Specificity
def specificity_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    tn = K.sum((1 - y_true_f) * (1 - y_pred_f))
    fp = K.sum((1 - y_true_f) * y_pred_f)
    return (tn + smooth) / (tn + fp + smooth)

# Soft Accuracy
def accuracy_infection(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    tp = K.sum(y_true_f * y_pred_f)
    tn = K.sum((1 - y_true_f) * (1 - y_pred_f))
    total = K.cast(K.shape(y_true_f)[0], 'float32')
    return (tp + tn + smooth) / (total + smooth)

# Soft F1-score (harmonic mean of precision & recall - very close to Dice, standard in many repos)
def f1_infection(y_true, y_pred):
    precision = precision_infection(y_true, y_pred)
    recall    = recall_infection(y_true, y_pred)
    return (2. * precision * recall + smooth) / (precision + recall + smooth)

# Hausdorff Distance 95 % (robust & most commonly used in medical imaging challenges)
# Lower = better. Returns the mean HD95 over the batch.
def _calculate_hd95(y_true, y_pred):
    hd_list = []
    for i in range(y_true.shape[0]):
        # Hard threshold at 0.5 (standard for evaluation metrics)
        gt = np.squeeze(y_true[i]) > 0.5
        pred = np.squeeze(y_pred[i]) > 0.5

        gt_pts = np.argwhere(gt)
        pred_pts = np.argwhere(pred)

        # Cases with empty masks
        if gt_pts.shape[0] == 0 and pred_pts.shape[0] == 0:
            hd_list.append(0.0)
            continue
        if gt_pts.shape[0] == 0 or pred_pts.shape[0] == 0:
            hd_list.append(400.0)  # large penalty - adjust to your image diagonal if needed (e.g. ~362 for 256×256, ~724 for 512×512)
            continue

        # Directed distances
        dist_gt_to_pred = cKDTree(pred_pts).query(gt_pts)[0]
        dist_pred_to_gt = cKDTree(gt_pts).query(pred_pts)[0]

        hd95 = max(
            np.percentile(dist_gt_to_pred, 95),
            np.percentile(dist_pred_to_gt, 95)
        )
        hd_list.append(hd95)

    return np.mean(hd_list, dtype=np.float32)

def hausdorff95_infection(y_true, y_pred):
    hd = tf.numpy_function(_calculate_hd95, [y_true, y_pred], tf.float32)
    hd.set_shape(())
    return hd

# Optional: KL Divergence (you already had this)
kld = tf.keras.losses.KLDivergence()

# %%
from tensorflow.keras.losses import BinaryCrossentropy

def loss_f(y_true, y_pred):
    bce = BinaryCrossentropy()
    return dice_loss(y_true, y_pred) + bce(y_true, y_pred) 

def loss_e(y_true, y_pred):
    bce = BinaryCrossentropy()
    return dice_loss(y_true, y_pred)  + kld(y_true, y_pred)
    
def dice_loss(y_true, y_pred):
    return 1. - dice_coef_infection(y_true, y_pred)

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Multiply, Conv2D, DepthwiseConv2D, Dense, Flatten, MaxPooling2D, UpSampling2D, concatenate, Activation, LayerNormalization, Add, Dropout, Conv2DTranspose, multiply, Reshape, GlobalAveragePooling2D, Permute, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Concatenate

def activation_block(x):
    x = Activation("gelu")(x)
    return LayerNormalization()(x)

def conv_stem(x, filters: int, patch_size: int):
    x = Conv2D(filters, kernel_size=patch_size,padding='same', strides=patch_size)(x)
    return activation_block(x)

def vector_block(xyz, cmf, red):
    # red means reduction
    # cmf means filters, denotes vector size
    opt1 = conv_stem(xyz, cmf, red)
    opt2 = conv_stem(xyz, cmf, red)
    
    o1 = GlobalAveragePooling2D()(opt1)
    o2 = GlobalAveragePooling2D()(opt2)

    o5 = concatenate([o1, o2], -1)
    return o5

def mlp_feature(vect, cmf):
    oo = Flatten()(vect)
    o6 = Dense(cmf, activation='gelu')(oo)
    o6 = Dropout(0.2)(o6)
    o6 = Dense(cmf * 2, activation='gelu')(o6)

    o6 = Reshape((1, cmf * 2))(o6)
    o7 = Permute((2, 1))(o6)

    o8 = multiply([o6, o7])
    
    o8 = Lambda(lambda x: tf.expand_dims(x, -1))(o8)
    
    o8 = Reshape((cmf, cmf, 4))(o8)

    return o8

def frz_block(xyz):
    shape = xyz.shape
    a1, a2, a3, a4 = shape[0], shape[1], shape[2], shape[3]
    cmf = a2
    o5 = vector_block(xyz, cmf, 5)
    o7 = mlp_feature(o5, cmf)

    o7 = concatenate([o7, xyz, o7], -1)
    return o7

def up_frz(x1, x2, n_filters):
    # Upsample x1 using Conv2DTranspose
    x1 = Conv2DTranspose(n_filters * 4, 3, strides=2, activation='gelu', padding="same")(x1)
    
    # Apply Conv2D to x2
    x2 = Conv2D(n_filters * 2, 3, activation='gelu', padding="same")(x2)
    
    # Apply attention mechanism
    x = concatenate([x1, x2])
    
    # Apply Dropout for regularization
    x = Dropout(0.3)(x)
    
    return x

def regu(x):
    filters = x.shape[-1]
    shortcut = x
    x = Conv2D(filters, (3, 3), activation='gelu', padding="same")(x)
    x = Add()([x, shortcut])
    return x

# %%
def squeeze_and_excite_block(inputs, ratio=24):
    """ Squeeze and Excitation block to recalibrate channel-wise features """
    filters = inputs.shape[-1]  # Number of input channels
    se_shape = (1, 1, filters)

    # Squeeze: Global Average Pooling
    se = GlobalAveragePooling2D()(inputs)
    se = Reshape(se_shape)(se)

    a = filters // ratio

    # Excitation: Dense layers to capture channel-wise dependencies
    if a > 8:
        se = Conv2D(filters // ratio, kernel_size=1, activation='swish', padding='same')(se)
        se = Conv2D(filters, kernel_size=1, activation='sigmoid', padding='same')(se)
    else:
        se = Conv2D(8, kernel_size=1, activation='swish', padding='same')(se)
        se = Conv2D(filters, kernel_size=1, activation='sigmoid', padding='same')(se)

    # Scale the input by channel-wise weights
    x = multiply([inputs, se])

    return x

def residual_block(x, filters, stride=1, padding='same'):
    shortcut = x
    x = Conv2D(filters * 6, 1, strides=stride, padding=padding, use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)
    x = DepthwiseConv2D(kernel_size=3, strides=stride, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)
    x = squeeze_and_excite_block(x)
    x = Conv2D(filters, 1, strides=stride, padding=padding, use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)
    x = Add()([x, shortcut])
    return x

def dense_block(inputs, num_layers, growth_rate, ratio=16):
    """Dense block where each layer is connected to all previous layers."""
    concat_features = inputs
    for i in range(num_layers):
        # BatchNorm -> ReLU -> Conv2D
        x = Conv2D(growth_rate, 3, activation='gelu', padding='same')(concat_features)

        # Concatenate input with new output (dense connection)
        concat_features = Concatenate()([concat_features, x])
        
    x = squeeze_and_excite_block(concat_features)

    return x

def attention_gate(X, g, channel,  
                   activation='ReLU', 
                   attention='add', name='att'):
    '''
    Self-attention gate modified from Oktay et al. 2018.
    
    attention_gate(X, g, channel,  activation='ReLU', attention='add', name='att')
    
    Input
    ----------
        X: input tensor, i.e., key and value.
        g: gated tensor, i.e., query.
        channel: number of intermediate channel.
                 Oktay et al. (2018) did not specify (denoted as F_int).
                 intermediate channel is expected to be smaller than the input channel.
        activation: a nonlinear attnetion activation.
                    The `sigma_1` in Oktay et al. 2018. Default is 'ReLU'.
        attention: 'add' for additive attention; 'multiply' for multiplicative attention.
                   Oktay et al. 2018 applied additive attention.
        name: prefix of the created keras layers.
        
    Output
    ----------
        X_att: output tensor.
    
    '''

    attention_func = eval(attention)
    
    # mapping the input tensor to the intermediate channel
    theta_att = Conv2D(channel, 1, use_bias=True)(X)
    
    # mapping the gate tensor
    phi_g = Conv2D(channel, 1, use_bias=True)(g)
    
    # ----- attention learning ----- #
    query = attention_func([theta_att, phi_g])
    
    # nonlinear activation
    f = Activation('gelu')(query)
    
    # linear transformation
    psi_f = Conv2D(1, 1, use_bias=True)(f)
    # ------------------------------ #
    
    # sigmoid activation as attention coefficients
    coef_att = Activation('sigmoid')(psi_f)
    
    # multiplicative attention masking
    X_att = multiply([X, coef_att])
    
    return X_att

inputs = (img_size, img_size, 1)

def model_build_func(input_shape, n_labels):
    inputs = Input(shape=input_shape, name='input_image')
    g_filter = 8
    u_filter = 8

    # Initial convolution
    initial = Conv2D(g_filter, (3, 3), activation='gelu', padding="same")(inputs)
    initial = dense_block(initial, 2, g_filter // 2)  # 80

    # Down-sampling path
    o1 = MaxPooling2D(2)(initial)
    o1 = frz_block(dense_block(o1, 2, g_filter))  # 40
    #o1 = squeeze_and_excite_block(o1)

    o2 = MaxPooling2D(2)(o1)
    o2 = frz_block(dense_block(o2, 2, g_filter * 2))  # 20
    #o2 = squeeze_and_excite_block(o2)

    o3 = MaxPooling2D(2)(o2)
    o3 = frz_block(dense_block(o3, 2, g_filter * 4))  # 10
    #o3 = squeeze_and_excite_block(o3)

    o4 = MaxPooling2D(2)(o3)
    o4 = frz_block(dense_block(o4, 2, g_filter * 8))  # 5
    #o4 = squeeze_and_excite_block(o4)

    o5 = MaxPooling2D(2)(o4)
    o5 = frz_block(dense_block(o5, 2, g_filter * 16))  # 5
    #o5 = squeeze_and_excite_block(o5)

    # Up-sampling path
    u1 = up_frz(o5, o4, u_filter * 16)  # 10
    #gate1 = attention_gate(o4, u1, u_filter * 16, attention='add')
    cu1 = concatenate([u1, o4])

    u2 = up_frz(cu1, o3, u_filter * 8)  # 20
    #gate2 = attention_gate(o3, u2, u_filter * 8, attention='add')
    cu2 = concatenate([u2, o3])  # 20

    u3 = up_frz(cu2, o2, u_filter * 4)  # 40
    #gate3 = attention_gate(o2, u3, u_filter * 4, attention='add')
    cu3 = concatenate([u3, o2])  # 40

    u4 = up_frz(cu3, o1, u_filter * 2)  # 80
    #gate4 = attention_gate(o1, u4, u_filter * 2, attention='add')
    cu4 = concatenate([u4, o1])  # 80

    u5 = Conv2DTranspose(u_filter * 4, 3, strides=2, activation='gelu', padding="same")(cu4)  # 80
    #gate5 = attention_gate(initial, u5, u_filter, attention='add')
    cu5 = concatenate([u5, initial])  # 80

    # Final segmentation map
    seg_map = Conv2D(n_labels, 3, activation='sigmoid', padding="same")(cu5)

    # Model definition
    model = Model(inputs=inputs, outputs=seg_map)

    return model


model = model_build_func(inputs, 1)

from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2_as_graph

def get_flops(model):
    """Calculate Floating Point Operations (FLOPs) of a Keras model in TensorFlow 2.x."""
    # Convert Keras model to a TensorFlow function
    concrete_func = tf.function(lambda inputs: model(inputs))
    concrete_func = concrete_func.get_concrete_function(
        tf.TensorSpec([1] + list(model.input_shape[1:]), model.input.dtype)
    )

    # Convert to frozen graph
    frozen_func, _ = convert_variables_to_constants_v2_as_graph(concrete_func)

    # Compute FLOPs
    flops = tf.compat.v1.profiler.profile(
        frozen_func.graph,
        options=tf.compat.v1.profiler.ProfileOptionBuilder.float_operation(),
    )

    return flops.total_float_ops

# Compute FLOPs
flops = get_flops(model)
print(f"Total FLOPs: {flops / 1e9:.2f} GFLOPs")  # Convert to GFLOPs

from tensorflow.keras.optimizers import Adam

optimizer = Adam(learning_rate=1e-3)
model.compile(optimizer=optimizer, loss=loss_f, metrics=[dice_coef_infection, iou_coef_infection, precision_infection, recall_infection, hausdorff95_infection, specificity_infection, accuracy_infection, f1_infection])

# Model summary
model.summary()
# Out:
# Total FLOPs: 12.57 GFLOPs
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_image (InputLayer)        [(None, 320, 320, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 320, 320, 8)  80          input_image[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 320, 320, 4)  292         conv2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 320, 320, 12) 0           conv2d[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 320, 320, 4)  436         concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 320, 320, 16) 0           concatenate[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 16)           0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 1, 16)     0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 1, 1, 8)      136         reshape[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 1, 1, 16)     144         conv2d_3[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 320, 320, 16) 0           concatenate_1[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 160, 160, 16) 0           multiply[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 160, 160, 8)  1160        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 160, 160, 24) 0           max_pooling2d[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 160, 160, 8)  1736        concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 160, 160, 32) 0           concatenate_2[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 32)           0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 1, 32)     0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 1, 1, 8)      264         reshape_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 1, 1, 32)     288         conv2d_7[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 160, 160, 32) 0           concatenate_3[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 160)  128160      multiply_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 160)  128160      multiply_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 160)  0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 160)  0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# layer_normalization (LayerNorma (None, 32, 32, 160)  320         activation[0][0]
# __________________________________________________________________________________________________
# layer_normalization_1 (LayerNor (None, 32, 32, 160)  320         activation_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 160)          0           layer_normalization[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 160)          0           layer_normalization_1[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 320)          0           global_average_pooling2d_2[0][0]
#                                                                  global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 320)          0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 160)          51360       flatten[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 160)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 320)          51520       dropout[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 320)       0           dense_1[0][0]
# __________________________________________________________________________________________________
# permute (Permute)               (None, 320, 1)       0           reshape_2[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 320, 320)     0           reshape_2[0][0]
#                                                                  permute[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 320, 320, 1)  0           multiply_2[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 160, 160, 4)  0           lambda[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 160, 160, 40) 0           reshape_3[0][0]
#                                                                  multiply_1[0][0]
#                                                                  reshape_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 80, 80, 40)   0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 80, 80, 16)   5776        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 80, 80, 56)   0           max_pooling2d_1[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 80, 80, 16)   8080        concatenate_6[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 80, 80, 72)   0           concatenate_6[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 72)           0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1, 1, 72)     0           global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 1, 1, 8)      584         reshape_4[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 1, 1, 72)     648         conv2d_13[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 80, 80, 72)   0           concatenate_7[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 80)   144080      multiply_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 80)   144080      multiply_3[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 16, 16, 80)   0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 16, 16, 80)   0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# layer_normalization_2 (LayerNor (None, 16, 16, 80)   160         activation_2[0][0]
# __________________________________________________________________________________________________
# layer_normalization_3 (LayerNor (None, 16, 16, 80)   160         activation_3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 80)           0           layer_normalization_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 80)           0           layer_normalization_3[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 160)          0           global_average_pooling2d_5[0][0]
#                                                                  global_average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 160)          0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 80)           12880       flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 80)           0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 160)          12960       dropout_1[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 1, 160)       0           dense_3[0][0]
# __________________________________________________________________________________________________
# permute_1 (Permute)             (None, 160, 1)       0           reshape_5[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 160, 160)     0           reshape_5[0][0]
#                                                                  permute_1[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 160, 160, 1)  0           multiply_4[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 80, 80, 4)    0           lambda_1[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 80, 80, 80)   0           reshape_6[0][0]
#                                                                  multiply_3[0][0]
#                                                                  reshape_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 40, 40, 80)   0           concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 40, 40, 32)   23072       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 40, 40, 112)  0           max_pooling2d_2[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 40, 40, 32)   32288       concatenate_10[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 40, 40, 144)  0           concatenate_10[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 144)          0           concatenate_11[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 1, 1, 144)    0           global_average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 1, 1, 8)      1160        reshape_7[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 1, 1, 144)    1296        conv2d_19[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 40, 40, 144)  0           concatenate_11[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 8, 8, 40)     144040      multiply_5[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 8, 8, 40)     144040      multiply_5[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 8, 8, 40)     0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 8, 8, 40)     0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# layer_normalization_4 (LayerNor (None, 8, 8, 40)     80          activation_4[0][0]
# __________________________________________________________________________________________________
# layer_normalization_5 (LayerNor (None, 8, 8, 40)     80          activation_5[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_8 (Glo (None, 40)           0           layer_normalization_4[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_9 (Glo (None, 40)           0           layer_normalization_5[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 80)           0           global_average_pooling2d_8[0][0]
#                                                                  global_average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 80)           0           concatenate_12[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 40)           3240        flatten_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 40)           0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 80)           3280        dropout_2[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 1, 80)        0           dense_5[0][0]
# __________________________________________________________________________________________________
# permute_2 (Permute)             (None, 80, 1)        0           reshape_8[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 80, 80)       0           reshape_8[0][0]
#                                                                  permute_2[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 80, 80, 1)    0           multiply_6[0][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 40, 40, 4)    0           lambda_2[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 40, 40, 152)  0           reshape_9[0][0]
#                                                                  multiply_5[0][0]
#                                                                  reshape_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 20, 20, 152)  0           concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 20, 20, 64)   87616       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 20, 20, 216)  0           max_pooling2d_3[0][0]
#                                                                  conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 20, 20, 64)   124480      concatenate_14[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 20, 20, 280)  0           concatenate_14[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_10 (Gl (None, 280)          0           concatenate_15[0][0]
# __________________________________________________________________________________________________
# reshape_10 (Reshape)            (None, 1, 1, 280)    0           global_average_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 1, 1, 11)     3091        reshape_10[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 1, 1, 280)    3360        conv2d_25[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 20, 20, 280)  0           concatenate_15[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 4, 4, 20)     140020      multiply_7[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 4, 4, 20)     140020      multiply_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 4, 4, 20)     0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 4, 4, 20)     0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# layer_normalization_6 (LayerNor (None, 4, 4, 20)     40          activation_6[0][0]
# __________________________________________________________________________________________________
# layer_normalization_7 (LayerNor (None, 4, 4, 20)     40          activation_7[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_11 (Gl (None, 20)           0           layer_normalization_6[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_12 (Gl (None, 20)           0           layer_normalization_7[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 40)           0           global_average_pooling2d_11[0][0]
#                                                                  global_average_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 40)           0           concatenate_16[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 20)           820         flatten_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 20)           0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 40)           840         dropout_3[0][0]
# __________________________________________________________________________________________________
# reshape_11 (Reshape)            (None, 1, 40)        0           dense_7[0][0]
# __________________________________________________________________________________________________
# permute_3 (Permute)             (None, 40, 1)        0           reshape_11[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 40, 40)       0           reshape_11[0][0]
#                                                                  permute_3[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 40, 40, 1)    0           multiply_8[0][0]
# __________________________________________________________________________________________________
# reshape_12 (Reshape)            (None, 20, 20, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 20, 20, 288)  0           reshape_12[0][0]
#                                                                  multiply_7[0][0]
#                                                                  reshape_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 10, 10, 288)  0           concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 10, 10, 128)  331904      max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 10, 10, 416)  0           max_pooling2d_4[0][0]
#                                                                  conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 10, 10, 128)  479360      concatenate_18[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 10, 10, 544)  0           concatenate_18[0][0]
#                                                                  conv2d_30[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_13 (Gl (None, 544)          0           concatenate_19[0][0]
# __________________________________________________________________________________________________
# reshape_13 (Reshape)            (None, 1, 1, 544)    0           global_average_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 1, 1, 22)     11990       reshape_13[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 1, 1, 544)    12512       conv2d_31[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 10, 10, 544)  0           concatenate_19[0][0]
#                                                                  conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 2, 2, 10)     136010      multiply_9[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 2, 2, 10)     136010      multiply_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 2, 2, 10)     0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 2, 2, 10)     0           conv2d_34[0][0]
# __________________________________________________________________________________________________
# layer_normalization_8 (LayerNor (None, 2, 2, 10)     20          activation_8[0][0]
# __________________________________________________________________________________________________
# layer_normalization_9 (LayerNor (None, 2, 2, 10)     20          activation_9[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_14 (Gl (None, 10)           0           layer_normalization_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_15 (Gl (None, 10)           0           layer_normalization_9[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 20)           0           global_average_pooling2d_14[0][0]
#                                                                  global_average_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 20)           0           concatenate_20[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 10)           210         flatten_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 10)           0           dense_8[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 20)           220         dropout_4[0][0]
# __________________________________________________________________________________________________
# reshape_14 (Reshape)            (None, 1, 20)        0           dense_9[0][0]
# __________________________________________________________________________________________________
# permute_4 (Permute)             (None, 20, 1)        0           reshape_14[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 20, 20)       0           reshape_14[0][0]
#                                                                  permute_4[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 20, 20, 1)    0           multiply_10[0][0]
# __________________________________________________________________________________________________
# reshape_15 (Reshape)            (None, 10, 10, 4)    0           lambda_4[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 10, 10, 552)  0           reshape_15[0][0]
#                                                                  multiply_9[0][0]
#                                                                  reshape_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 20, 20, 512)  2544128     concatenate_21[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 20, 20, 256)  663808      concatenate_17[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 20, 20, 768)  0           conv2d_transpose[0][0]
#                                                                  conv2d_35[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 20, 20, 768)  0           concatenate_22[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 20, 20, 1056) 0           dropout_5[0][0]
#                                                                  concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 40, 40, 256)  2433280     concatenate_23[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 40, 40, 128)  175232      concatenate_13[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 40, 40, 384)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_36[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 40, 40, 384)  0           concatenate_24[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 40, 40, 536)  0           dropout_6[0][0]
#                                                                  concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 80, 80, 128)  617600      concatenate_25[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 80, 80, 64)   46144       concatenate_9[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 80, 80, 192)  0           conv2d_transpose_2[0][0]
#                                                                  conv2d_37[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 80, 80, 192)  0           concatenate_26[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 80, 80, 272)  0           dropout_7[0][0]
#                                                                  concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 160, 160, 64) 156736      concatenate_27[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 160, 160, 32) 11552       concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 160, 160, 96) 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_38[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 160, 160, 96) 0           concatenate_28[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 160, 160, 136 0           dropout_8[0][0]
#                                                                  concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 320, 320, 32) 39200       concatenate_29[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 320, 320, 48) 0           conv2d_transpose_4[0][0]
#                                                                  multiply[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 320, 320, 1)  433         concatenate_30[0][0]
# ==================================================================================================
# Total params: 9,343,056
# Trainable params: 9,343,056
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Install required packages
# !pip install openpyxl

# Imports
import openpyxl  # required for reading .xlsx files
import pandas as pd
import tensorflow as tf
import os
import shutil
from tensorflow.keras.callbacks import LearningRateScheduler, ReduceLROnPlateau

# File paths
checkpoint_filepath = '/kaggle/working/checkpoint.h5.keras'
metrics_file = '/kaggle/working/training_metrics.xlsx'
pre_checkpoint_filepath = '/kaggle/input/dseg-unet-4channel-covid19/checkpoint.h5.keras'
pre_metrics_file = '/kaggle/input/dseg-unet-4channel-covid19/training_metrics.xlsx'

# Restore checkpoint and metrics if available
if os.path.exists(pre_checkpoint_filepath):
    shutil.copy(pre_checkpoint_filepath, checkpoint_filepath)
    print(f"Restored checkpoint from: {pre_checkpoint_filepath}")

if os.path.exists(pre_metrics_file):
    shutil.copy(pre_metrics_file, metrics_file)
    print(f"Restored metrics file from: {pre_metrics_file}")

# Load last epoch
def load_last_epoch():
    if os.path.exists(metrics_file):
        try:
            df = pd.read_excel(metrics_file, engine='openpyxl')
            if not df.empty and 'epoch' in df.columns:
                return df['epoch'].iloc[-1] + 1
        except Exception as e:
            print(f"⚠️ Could not read metrics file: {e}")
    return 0

last_epoch = load_last_epoch()

# Get best validation loss from previous runs
def get_best_val_loss():
    if os.path.exists(metrics_file):
        try:
            df = pd.read_excel(metrics_file, engine='openpyxl')
            if 'val_loss' in df.columns and not df['val_loss'].isnull().all():
                return df['val_loss'].min()
        except Exception as e:
            print(f"⚠️ Could not read val_loss from metrics file: {e}")
    return float('inf')

best_val_loss = get_best_val_loss()

# Custom model checkpoint
class CustomModelCheckpoint(tf.keras.callbacks.Callback):
    def __init__(self, filepath):
        super().__init__()
        self.filepath = filepath
        self.best_loss = best_val_loss

    def on_epoch_end(self, epoch, logs=None):
        current_loss = logs.get('val_loss')
        if current_loss is not None and current_loss < self.best_loss:
            self.best_loss = current_loss
            self.model.save(self.filepath)
            print(f"✅ Model saved at epoch {epoch + 1} with val_loss: {current_loss:.4f}")

# === Learning Rate Schedule ===
def lr_schedule(epoch, lr):
    return 1e-4 if epoch >= 5 else lr

lr_scheduler = LearningRateScheduler(lr_schedule, verbose=1)

# Logger for Excel
class MetricsLogger(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        df_new = pd.DataFrame([{**logs, 'epoch': epoch}])
        try:
            if os.path.exists(metrics_file):
                df = pd.read_excel(metrics_file, engine='openpyxl')
                df = pd.concat([df, df_new], ignore_index=True)
            else:
                df = df_new
            df.to_excel(metrics_file, index=False, engine='openpyxl')
        except Exception as e:
            print(f"⚠️ Failed to log metrics: {e}")

# Early stopping with patience and saving best weights
class CustomEarlyStopping(tf.keras.callbacks.Callback):
    def __init__(self, patience=20):
        super().__init__()
        self.patience = patience
        self.wait = 0
        self.best_loss = best_val_loss

    def on_epoch_end(self, epoch, logs=None):
        current_loss = logs.get('val_loss')
        if current_loss is None:
            return
        if current_loss < self.best_loss:
            self.best_loss = current_loss
            self.wait = 0
            self.model.save_weights(checkpoint_filepath)
        else:
            self.wait += 1
            if self.wait >= self.patience:
                print(f"🛑 Early stopping at epoch {epoch + 1}")
                self.model.stop_training = True


# Final callbacks list
callbacks = [
    CustomModelCheckpoint(filepath=checkpoint_filepath),
    MetricsLogger(),
    lr_scheduler,
    CustomEarlyStopping(patience=20)
]
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.3-py2.py3-none-any.whl (251 kB)
#      |████████████████████████████████| 251 kB 4.9 MB/s eta 0:00:01
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.3

# %% [markdown]
# ## Training the model

# %%
import time
import os
import pandas as pd
import numpy as np
from tensorflow.keras.utils import Sequence
from tensorflow.keras.models import load_model

EPOCHS = 100

# Record the start time
start_time = time.time()

# === Load last completed epoch from metrics file ===
def load_last_epoch():
    if os.path.exists(pre_metrics_file):
        try:
            df = pd.read_excel(pre_metrics_file, engine='openpyxl')
            if not df.empty and 'epoch' in df.columns:
                return int(df['epoch'].iloc[-1]) + 1
        except Exception as e:
            print(f"⚠️ Failed to read metrics file: {e}")
    return 0

last_epoch = load_last_epoch()

# === Load pretrained weights if available ===
if os.path.exists(pre_checkpoint_filepath):
    print("✅ Checkpoint found. Loading pretrained weights...")
    model.load_weights(pre_checkpoint_filepath)
    print(f"🔁 Resuming training from epoch {last_epoch}")
else:
    print("🆕 No checkpoint found. Starting training from scratch.")
    last_epoch = 0

# === Prepare input and label tensors ===
lung_train = np.asarray(lung_train, dtype=np.float16)
infect_train = np.asarray(infect_train, dtype=np.uint8)

lung_temp = np.asarray(lung_temp, dtype=np.float16)
infect_temp = np.asarray(infect_temp, dtype=np.uint8)

lung_test = np.asarray(lung_test, dtype=np.float16)
infect_test = np.asarray(infect_test, dtype=np.uint8)

# === Data Generator ===
class LungDataGenerator(Sequence):
    def __init__(self, X, Y, batch_size=8, shuffle=True):
        self.X = X
        self.Y = Y
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indices = np.arange(len(X))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.X) / self.batch_size))

    def __getitem__(self, index):
        batch_ids = self.indices[index * self.batch_size:(index + 1) * self.batch_size]
        X_batch = self.X[batch_ids]
        Y_batch = self.Y[batch_ids]
        return np.asarray(X_batch, dtype=np.float16), np.asarray(Y_batch, dtype=np.uint8)

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indices)

# === Create generators ===
train_gen = LungDataGenerator(lung_train, infect_train, batch_size=8)
temp_gen = LungDataGenerator(lung_temp, infect_temp, batch_size=8, shuffle=False)
val_gen = LungDataGenerator(lung_test, infect_test, batch_size=8, shuffle=False)

# === Train the model ===
history = model.fit(
    train_gen,
    validation_data=temp_gen,
    epochs=EPOCHS,
    initial_epoch=last_epoch,
    callbacks=callbacks
)

# === Timing info ===
end_time = time.time()
total_time = end_time - start_time
print(f"✅ Total training time: {total_time:.2f} seconds ({total_time / 60:.2f} minutes)")
# Out:
# 🆕 No checkpoint found. Starting training from scratch.
# Epoch 1/100
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 192s 155ms/step - loss: 1.4375 - dice_coef_infection: 0.0529 - iou_coef_infection: 0.0304 - precision_infection: 0.0734 - recall_infection: 0.1478 - hausdorff95_infection: 202.4260 - specificity_infection: 0.9798 - accuracy_infection: 0.9717 - f1_infection: 0.8750 - val_loss: 0.7711 - val_dice_coef_infection: 0.2579 - val_iou_coef_infection: 0.2410 - val_precision_infection: 0.2534 - val_recall_infection: 0.8433 - val_hausdorff95_infection: 230.8185 - val_specificity_infection: 0.9972 - val_accuracy_infection: 0.9959 - val_f1_infection: 0.6797
# ✅ Model saved at epoch 1 with val_loss: 0.7711
# Epoch 2/100
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.8080 - dice_coef_infection: 0.2649 - iou_coef_infection: 0.1719 - precision_infection: 0.2945 - recall_infection: 0.3522 - hausdorff95_infection: 139.0261 - specificity_infection: 0.9917 - accuracy_infection: 0.9859 - f1_infection: 0.7748 - val_loss: 0.6935 - val_dice_coef_infection: 0.3290 - val_iou_coef_infection: 0.3028 - val_precision_infection: 0.3201 - val_recall_infection: 0.8934 - val_hausdorff95_infection: 227.3661 - val_specificity_infection: 0.9969 - val_accuracy_infection: 0.9960 - val_f1_infection: 0.6836
# ✅ Model saved at epoch 2 with val_loss: 0.6935
# Epoch 3/100
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.6027 - dice_coef_infection: 0.4493 - iou_coef_infection: 0.3173 - precision_infection: 0.4961 - recall_infection: 0.5188 - hausdorff95_infection: 104.0806 - specificity_infection: 0.9955 - accuracy_infection: 0.9915 - f1_infection: 0.7642 - val_loss: 0.4910 - val_dice_coef_infection: 0.5218 - val_iou_coef_infection: 0.4921 - val_precision_infection: 0.5152 - val_recall_infection: 0.9043 - val_hausdorff95_infection: 141.3748 - val_specificity_infection: 0.9987 - val_accuracy_infection: 0.9980 - val_f1_infection: 0.7782
# ✅ Model saved at epoch 3 with val_loss: 0.4910
# Epoch 4/100
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.5680 - dice_coef_infection: 0.4927 - iou_coef_infection: 0.3616 - precision_infection: 0.5534 - recall_infection: 0.5367 - hausdorff95_infection: 105.4606 - specificity_infection: 0.9964 - accuracy_infection: 0.9926 - f1_infection: 0.7827 - val_loss: 0.3519 - val_dice_coef_infection: 0.6594 - val_iou_coef_infection: 0.6362 - val_precision_infection: 0.7097 - val_recall_infection: 0.8464 - val_hausdorff95_infection: 67.8995 - val_specificity_infection: 0.9998 - val_accuracy_infection: 0.9986 - val_f1_infection: 0.8571
# ✅ Model saved at epoch 4 with val_loss: 0.3519
# Epoch 5/100
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.5014 - dice_coef_infection: 0.5433 - iou_coef_infection: 0.4076 - precision_infection: 0.5863 - recall_infection: 0.5817 - hausdorff95_infection: 86.3167 - specificity_infection: 0.9969 - accuracy_infection: 0.9936 - f1_infection: 0.7951 - val_loss: 0.4974 - val_dice_coef_infection: 0.5151 - val_iou_coef_infection: 0.4899 - val_precision_infection: 0.5079 - val_recall_infection: 0.9058 - val_hausdorff95_infection: 147.0735 - val_specificity_infection: 0.9984 - val_accuracy_infection: 0.9978 - val_f1_infection: 0.7810
# Epoch 6/100
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.4012 - dice_coef_infection: 0.6285 - iou_coef_infection: 0.4905 - precision_infection: 0.6535 - recall_infection: 0.6482 - hausdorff95_infection: 70.3958 - specificity_infection: 0.9976 - accuracy_infection: 0.9951 - f1_infection: 0.8194 - val_loss: 0.4459 - val_dice_coef_infection: 0.5659 - val_iou_coef_infection: 0.5369 - val_precision_infection: 0.5479 - val_recall_infection: 0.9362 - val_hausdorff95_infection: 136.8379 - val_specificity_infection: 0.9980 - val_accuracy_infection: 0.9977 - val_f1_infection: 0.7928
# Epoch 7/100
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.3889 - dice_coef_infection: 0.6388 - iou_coef_infection: 0.5032 - precision_infection: 0.6629 - recall_infection: 0.6783 - hausdorff95_infection: 64.8194 - specificity_infection: 0.9976 - accuracy_infection: 0.9953 - f1_infection: 0.8178 - val_loss: 0.3976 - val_dice_coef_infection: 0.6110 - val_iou_coef_infection: 0.5822 - val_precision_infection: 0.5991 - val_recall_infection: 0.9294 - val_hausdorff95_infection: 112.3432 - val_specificity_infection: 0.9988 - val_accuracy_infection: 0.9984 - val_f1_infection: 0.8171
# Epoch 8/100
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.3704 - dice_coef_infection: 0.6564 - iou_coef_infection: 0.5221 - precision_infection: 0.6818 - recall_infection: 0.6920 - hausdorff95_infection: 59.5972 - specificity_infection: 0.9978 - accuracy_infection: 0.9954 - f1_infection: 0.8233 - val_loss: 0.4149 - val_dice_coef_infection: 0.5930 - val_iou_coef_infection: 0.5642 - val_precision_infection: 0.5817 - val_recall_infection: 0.9243 - val_hausdorff95_infection: 117.4272 - val_specificity_infection: 0.9988 - val_accuracy_infection: 0.9984 - val_f1_infection: 0.8094
# Epoch 9/100
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.3705 - dice_coef_infection: 0.6582 - iou_coef_infection: 0.5210 - precision_infection: 0.6938 - recall_infection: 0.6780 - hausdorff95_infection: 57.2762 - specificity_infection: 0.9978 - accuracy_infection: 0.9954 - f1_infection: 0.8237 - val_loss: 0.3794 - val_dice_coef_infection: 0.6316 - val_iou_coef_infection: 0.6015 - val_precision_infection: 0.6126 - val_recall_infection: 0.9387 - val_hausdorff95_infection: 105.1226 - val_specificity_infection: 0.9982 - val_accuracy_infection: 0.9980 - val_f1_infection: 0.8258
# Epoch 10/100
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.3668 - dice_coef_infection: 0.6596 - iou_coef_infection: 0.5253 - precision_infection: 0.6842 - recall_infection: 0.6852 - hausdorff95_infection: 55.2286 - specificity_infection: 0.9979 - accuracy_infection: 0.9956 - f1_infection: 0.8293 - val_loss: 0.4186 - val_dice_coef_infection: 0.5918 - val_iou_coef_infection: 0.5620 - val_precision_infection: 0.5718 - val_recall_infection: 0.9399 - val_hausdorff95_infection: 120.7988 - val_specificity_infection: 0.9983 - val_accuracy_infection: 0.9980 - val_f1_infection: 0.8061
# Epoch 11/100
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.3665 - dice_coef_infection: 0.6600 - iou_coef_infection: 0.5274 - precision_infection: 0.6852 - recall_infection: 0.6970 - hausdorff95_infection: 52.7734 - specificity_infection: 0.9979 - accuracy_infection: 0.9957 - f1_infection: 0.8271 - val_loss: 0.4060 - val_dice_coef_infection: 0.6052 - val_iou_coef_infection: 0.5750 - val_precision_infection: 0.5849 - val_recall_infection: 0.9433 - val_hausdorff95_infection: 119.3897 - val_specificity_infection: 0.9980 - val_accuracy_infection: 0.9977 - val_f1_infection: 0.8112
# Epoch 12/100
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.3503 - dice_coef_infection: 0.6770 - iou_coef_infection: 0.5421 - precision_infection: 0.7014 - recall_infection: 0.7029 - hausdorff95_infection: 48.9393 - specificity_infection: 0.9978 - accuracy_infection: 0.9955 - f1_infection: 0.8328 - val_loss: 0.3602 - val_dice_coef_infection: 0.6473 - val_iou_coef_infection: 0.6184 - val_precision_infection: 0.6381 - val_recall_infection: 0.9265 - val_hausdorff95_infection: 90.5521 - val_specificity_infection: 0.9990 - val_accuracy_infection: 0.9986 - val_f1_infection: 0.8354
# Epoch 13/100
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.3473 - dice_coef_infection: 0.6809 - iou_coef_infection: 0.5469 - precision_infection: 0.7177 - recall_infection: 0.7069 - hausdorff95_infection: 47.3824 - specificity_infection: 0.9980 - accuracy_infection: 0.9957 - f1_infection: 0.8290 - val_loss: 0.4004 - val_dice_coef_infection: 0.6147 - val_iou_coef_infection: 0.5856 - val_precision_infection: 0.5911 - val_recall_infection: 0.9521 - val_hausdorff95_infection: 117.7377 - val_specificity_infection: 0.9970 - val_accuracy_infection: 0.9969 - val_f1_infection: 0.8149
# Epoch 14/100
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.3377 - dice_coef_infection: 0.6873 - iou_coef_infection: 0.5519 - precision_infection: 0.7182 - recall_infection: 0.7014 - hausdorff95_infection: 43.7817 - specificity_infection: 0.9980 - accuracy_infection: 0.9959 - f1_infection: 0.8346 - val_loss: 0.3637 - val_dice_coef_infection: 0.6491 - val_iou_coef_infection: 0.6189 - val_precision_infection: 0.6248 - val_recall_infection: 0.9533 - val_hausdorff95_infection: 106.7629 - val_specificity_infection: 0.9975 - val_accuracy_infection: 0.9973 - val_f1_infection: 0.8309
# Epoch 15/100
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.3322 - dice_coef_infection: 0.6933 - iou_coef_infection: 0.5580 - precision_infection: 0.7185 - recall_infection: 0.7072 - hausdorff95_infection: 46.3463 - specificity_infection: 0.9979 - accuracy_infection: 0.9958 - f1_infection: 0.8387 - val_loss: 0.4189 - val_dice_coef_infection: 0.5891 - val_iou_coef_infection: 0.5598 - val_precision_infection: 0.5749 - val_recall_infection: 0.9342 - val_hausdorff95_infection: 115.3354 - val_specificity_infection: 0.9987 - val_accuracy_infection: 0.9984 - val_f1_infection: 0.8046
# Epoch 16/100
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.3357 - dice_coef_infection: 0.6887 - iou_coef_infection: 0.5538 - precision_infection: 0.7151 - recall_infection: 0.7022 - hausdorff95_infection: 47.1633 - specificity_infection: 0.9980 - accuracy_infection: 0.9960 - f1_infection: 0.8385 - val_loss: 0.4068 - val_dice_coef_infection: 0.6067 - val_iou_coef_infection: 0.5771 - val_precision_infection: 0.5855 - val_recall_infection: 0.9436 - val_hausdorff95_infection: 114.3413 - val_specificity_infection: 0.9976 - val_accuracy_infection: 0.9974 - val_f1_infection: 0.8136
# Epoch 17/100
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.3366 - dice_coef_infection: 0.6914 - iou_coef_infection: 0.5567 - precision_infection: 0.7257 - recall_infection: 0.7065 - hausdorff95_infection: 44.3841 - specificity_infection: 0.9980 - accuracy_infection: 0.9958 - f1_infection: 0.8362 - val_loss: 0.3874 - val_dice_coef_infection: 0.6223 - val_iou_coef_infection: 0.5921 - val_precision_infection: 0.6035 - val_recall_infection: 0.9385 - val_hausdorff95_infection: 106.5390 - val_specificity_infection: 0.9983 - val_accuracy_infection: 0.9980 - val_f1_infection: 0.8216
# Epoch 18/100
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.3255 - dice_coef_infection: 0.7016 - iou_coef_infection: 0.5702 - precision_infection: 0.7288 - recall_infection: 0.7273 - hausdorff95_infection: 42.0631 - specificity_infection: 0.9979 - accuracy_infection: 0.9957 - f1_infection: 0.8393 - val_loss: 0.3639 - val_dice_coef_infection: 0.6477 - val_iou_coef_infection: 0.6173 - val_precision_infection: 0.6251 - val_recall_infection: 0.9479 - val_hausdorff95_infection: 106.8262 - val_specificity_infection: 0.9978 - val_accuracy_infection: 0.9976 - val_f1_infection: 0.8314
# Epoch 19/100
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.3215 - dice_coef_infection: 0.7039 - iou_coef_infection: 0.5711 - precision_infection: 0.7293 - recall_infection: 0.7223 - hausdorff95_infection: 37.7016 - specificity_infection: 0.9980 - accuracy_infection: 0.9959 - f1_infection: 0.8401 - val_loss: 0.3806 - val_dice_coef_infection: 0.6328 - val_iou_coef_infection: 0.6039 - val_precision_infection: 0.6100 - val_recall_infection: 0.9467 - val_hausdorff95_infection: 111.6490 - val_specificity_infection: 0.9975 - val_accuracy_infection: 0.9973 - val_f1_infection: 0.8255
# Epoch 20/100
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.3223 - dice_coef_infection: 0.7025 - iou_coef_infection: 0.5678 - precision_infection: 0.7223 - recall_infection: 0.7247 - hausdorff95_infection: 40.0889 - specificity_infection: 0.9978 - accuracy_infection: 0.9958 - f1_infection: 0.8392 - val_loss: 0.3487 - val_dice_coef_infection: 0.6603 - val_iou_coef_infection: 0.6302 - val_precision_infection: 0.6446 - val_recall_infection: 0.9372 - val_hausdorff95_infection: 107.8812 - val_specificity_infection: 0.9984 - val_accuracy_infection: 0.9980 - val_f1_infection: 0.8364
# ✅ Model saved at epoch 20 with val_loss: 0.3487
# Epoch 21/100
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.3197 - dice_coef_infection: 0.7052 - iou_coef_infection: 0.5715 - precision_infection: 0.7268 - recall_infection: 0.7284 - hausdorff95_infection: 38.6848 - specificity_infection: 0.9980 - accuracy_infection: 0.9960 - f1_infection: 0.8396 - val_loss: 0.3518 - val_dice_coef_infection: 0.6555 - val_iou_coef_infection: 0.6265 - val_precision_infection: 0.6430 - val_recall_infection: 0.9291 - val_hausdorff95_infection: 101.3993 - val_specificity_infection: 0.9988 - val_accuracy_infection: 0.9985 - val_f1_infection: 0.8382
# Epoch 22/100
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.3160 - dice_coef_infection: 0.7078 - iou_coef_infection: 0.5757 - precision_infection: 0.7245 - recall_infection: 0.7271 - hausdorff95_infection: 37.4657 - specificity_infection: 0.9979 - accuracy_infection: 0.9959 - f1_infection: 0.8451 - val_loss: 0.3681 - val_dice_coef_infection: 0.6402 - val_iou_coef_infection: 0.6106 - val_precision_infection: 0.6257 - val_recall_infection: 0.9315 - val_hausdorff95_infection: 106.7907 - val_specificity_infection: 0.9985 - val_accuracy_infection: 0.9982 - val_f1_infection: 0.8309
# Epoch 23/100
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.3112 - dice_coef_infection: 0.7130 - iou_coef_infection: 0.5809 - precision_infection: 0.7411 - recall_infection: 0.7333 - hausdorff95_infection: 36.0220 - specificity_infection: 0.9980 - accuracy_infection: 0.9960 - f1_infection: 0.8422 - val_loss: 0.3780 - val_dice_coef_infection: 0.6286 - val_iou_coef_infection: 0.6002 - val_precision_infection: 0.6177 - val_recall_infection: 0.9301 - val_hausdorff95_infection: 91.7893 - val_specificity_infection: 0.9990 - val_accuracy_infection: 0.9987 - val_f1_infection: 0.8260
# Epoch 24/100
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.3141 - dice_coef_infection: 0.7095 - iou_coef_infection: 0.5767 - precision_infection: 0.7323 - recall_infection: 0.7286 - hausdorff95_infection: 38.2891 - specificity_infection: 0.9980 - accuracy_infection: 0.9960 - f1_infection: 0.8437 - val_loss: 0.3652 - val_dice_coef_infection: 0.6414 - val_iou_coef_infection: 0.6129 - val_precision_infection: 0.6319 - val_recall_infection: 0.9269 - val_hausdorff95_infection: 95.5618 - val_specificity_infection: 0.9990 - val_accuracy_infection: 0.9987 - val_f1_infection: 0.8325
# Epoch 25/100
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.3071 - dice_coef_infection: 0.7156 - iou_coef_infection: 0.5828 - precision_infection: 0.7314 - recall_infection: 0.7441 - hausdorff95_infection: 34.8236 - specificity_infection: 0.9980 - accuracy_infection: 0.9961 - f1_infection: 0.8433 - val_loss: 0.3651 - val_dice_coef_infection: 0.6430 - val_iou_coef_infection: 0.6134 - val_precision_infection: 0.6300 - val_recall_infection: 0.9288 - val_hausdorff95_infection: 103.1562 - val_specificity_infection: 0.9987 - val_accuracy_infection: 0.9984 - val_f1_infection: 0.8327
# Epoch 26/100
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.3303 - dice_coef_infection: 0.6925 - iou_coef_infection: 0.5640 - precision_infection: 0.7175 - recall_infection: 0.7197 - hausdorff95_infection: 36.7882 - specificity_infection: 0.9981 - accuracy_infection: 0.9962 - f1_infection: 0.8409 - val_loss: 0.3695 - val_dice_coef_infection: 0.6378 - val_iou_coef_infection: 0.6103 - val_precision_infection: 0.6270 - val_recall_infection: 0.9254 - val_hausdorff95_infection: 100.7338 - val_specificity_infection: 0.9988 - val_accuracy_infection: 0.9985 - val_f1_infection: 0.8337
# Epoch 27/100
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.3180 - dice_coef_infection: 0.7055 - iou_coef_infection: 0.5777 - precision_infection: 0.7309 - recall_infection: 0.7366 - hausdorff95_infection: 36.8404 - specificity_infection: 0.9981 - accuracy_infection: 0.9961 - f1_infection: 0.8434 - val_loss: 0.3361 - val_dice_coef_infection: 0.6704 - val_iou_coef_infection: 0.6426 - val_precision_infection: 0.6680 - val_recall_infection: 0.9205 - val_hausdorff95_infection: 68.2610 - val_specificity_infection: 0.9992 - val_accuracy_infection: 0.9988 - val_f1_infection: 0.8484
# ✅ Model saved at epoch 27 with val_loss: 0.3361
# Epoch 28/100
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.3032 - dice_coef_infection: 0.7194 - iou_coef_infection: 0.5875 - precision_infection: 0.7396 - recall_infection: 0.7365 - hausdorff95_infection: 36.9366 - specificity_infection: 0.9980 - accuracy_infection: 0.9960 - f1_infection: 0.8475 - val_loss: 0.4035 - val_dice_coef_infection: 0.6174 - val_iou_coef_infection: 0.5892 - val_precision_infection: 0.5929 - val_recall_infection: 0.9529 - val_hausdorff95_infection: 108.2928 - val_specificity_infection: 0.9959 - val_accuracy_infection: 0.9959 - val_f1_infection: 0.8162
# Epoch 29/100
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.3048 - dice_coef_infection: 0.7198 - iou_coef_infection: 0.5884 - precision_infection: 0.7470 - recall_infection: 0.7412 - hausdorff95_infection: 35.0526 - specificity_infection: 0.9979 - accuracy_infection: 0.9960 - f1_infection: 0.8441 - val_loss: 0.2283 - val_dice_coef_infection: 0.7789 - val_iou_coef_infection: 0.7518 - val_precision_infection: 0.7953 - val_recall_infection: 0.9009 - val_hausdorff95_infection: 23.2375 - val_specificity_infection: 0.9995 - val_accuracy_infection: 0.9989 - val_f1_infection: 0.9064
# ✅ Model saved at epoch 29 with val_loss: 0.2283
# Epoch 30/100
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.3114 - dice_coef_infection: 0.7127 - iou_coef_infection: 0.5828 - precision_infection: 0.7497 - recall_infection: 0.7233 - hausdorff95_infection: 37.6243 - specificity_infection: 0.9980 - accuracy_infection: 0.9960 - f1_infection: 0.8443 - val_loss: 0.3656 - val_dice_coef_infection: 0.6409 - val_iou_coef_infection: 0.6129 - val_precision_infection: 0.6393 - val_recall_infection: 0.9179 - val_hausdorff95_infection: 76.6008 - val_specificity_infection: 0.9992 - val_accuracy_infection: 0.9987 - val_f1_infection: 0.8334
# Epoch 31/100
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.3015 - dice_coef_infection: 0.7224 - iou_coef_infection: 0.5920 - precision_infection: 0.7416 - recall_infection: 0.7493 - hausdorff95_infection: 31.1266 - specificity_infection: 0.9979 - accuracy_infection: 0.9960 - f1_infection: 0.8466 - val_loss: 0.3184 - val_dice_coef_infection: 0.6898 - val_iou_coef_infection: 0.6643 - val_precision_infection: 0.6783 - val_recall_infection: 0.9261 - val_hausdorff95_infection: 61.9471 - val_specificity_infection: 0.9988 - val_accuracy_infection: 0.9986 - val_f1_infection: 0.8660
# Epoch 32/100
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.3133 - dice_coef_infection: 0.7098 - iou_coef_infection: 0.5790 - precision_infection: 0.7358 - recall_infection: 0.7341 - hausdorff95_infection: 33.7167 - specificity_infection: 0.9980 - accuracy_infection: 0.9960 - f1_infection: 0.8425 - val_loss: 0.2890 - val_dice_coef_infection: 0.7174 - val_iou_coef_infection: 0.6929 - val_precision_infection: 0.7246 - val_recall_infection: 0.9148 - val_hausdorff95_infection: 46.0963 - val_specificity_infection: 0.9993 - val_accuracy_infection: 0.9989 - val_f1_infection: 0.8746
# Epoch 33/100
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.2958 - dice_coef_infection: 0.7278 - iou_coef_infection: 0.5978 - precision_infection: 0.7631 - recall_infection: 0.7330 - hausdorff95_infection: 29.6693 - specificity_infection: 0.9981 - accuracy_infection: 0.9962 - f1_infection: 0.8488 - val_loss: 0.3693 - val_dice_coef_infection: 0.6386 - val_iou_coef_infection: 0.6092 - val_precision_infection: 0.6247 - val_recall_infection: 0.9339 - val_hausdorff95_infection: 79.9490 - val_specificity_infection: 0.9986 - val_accuracy_infection: 0.9984 - val_f1_infection: 0.8313
# Epoch 34/100
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.2885 - dice_coef_infection: 0.7333 - iou_coef_infection: 0.6020 - precision_infection: 0.7511 - recall_infection: 0.7484 - hausdorff95_infection: 31.3483 - specificity_infection: 0.9981 - accuracy_infection: 0.9963 - f1_infection: 0.8528 - val_loss: 0.3614 - val_dice_coef_infection: 0.6449 - val_iou_coef_infection: 0.6176 - val_precision_infection: 0.6416 - val_recall_infection: 0.9265 - val_hausdorff95_infection: 75.9115 - val_specificity_infection: 0.9992 - val_accuracy_infection: 0.9988 - val_f1_infection: 0.8354
# Epoch 35/100
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.3001 - dice_coef_infection: 0.7232 - iou_coef_infection: 0.5922 - precision_infection: 0.7508 - recall_infection: 0.7388 - hausdorff95_infection: 29.2127 - specificity_infection: 0.9980 - accuracy_infection: 0.9961 - f1_infection: 0.8467 - val_loss: 0.3693 - val_dice_coef_infection: 0.6415 - val_iou_coef_infection: 0.6122 - val_precision_infection: 0.6237 - val_recall_infection: 0.9368 - val_hausdorff95_infection: 99.5447 - val_specificity_infection: 0.9981 - val_accuracy_infection: 0.9979 - val_f1_infection: 0.8319
# Epoch 36/100
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.2931 - dice_coef_infection: 0.7286 - iou_coef_infection: 0.5988 - precision_infection: 0.7462 - recall_infection: 0.7505 - hausdorff95_infection: 30.4733 - specificity_infection: 0.9980 - accuracy_infection: 0.9962 - f1_infection: 0.8510 - val_loss: 0.3443 - val_dice_coef_infection: 0.6624 - val_iou_coef_infection: 0.6342 - val_precision_infection: 0.6585 - val_recall_infection: 0.9227 - val_hausdorff95_infection: 64.5169 - val_specificity_infection: 0.9990 - val_accuracy_infection: 0.9986 - val_f1_infection: 0.8449
# Epoch 37/100
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.3005 - dice_coef_infection: 0.7215 - iou_coef_infection: 0.5878 - precision_infection: 0.7386 - recall_infection: 0.7367 - hausdorff95_infection: 35.4187 - specificity_infection: 0.9980 - accuracy_infection: 0.9961 - f1_infection: 0.8463 - val_loss: 0.3553 - val_dice_coef_infection: 0.6538 - val_iou_coef_infection: 0.6251 - val_precision_infection: 0.6403 - val_recall_infection: 0.9330 - val_hausdorff95_infection: 94.1506 - val_specificity_infection: 0.9985 - val_accuracy_infection: 0.9983 - val_f1_infection: 0.8391
# Epoch 38/100
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.2941 - dice_coef_infection: 0.7291 - iou_coef_infection: 0.5981 - precision_infection: 0.7512 - recall_infection: 0.7476 - hausdorff95_infection: 32.3568 - specificity_infection: 0.9979 - accuracy_infection: 0.9960 - f1_infection: 0.8502 - val_loss: 0.3083 - val_dice_coef_infection: 0.6991 - val_iou_coef_infection: 0.6705 - val_precision_infection: 0.6974 - val_recall_infection: 0.9153 - val_hausdorff95_infection: 43.3666 - val_specificity_infection: 0.9989 - val_accuracy_infection: 0.9985 - val_f1_infection: 0.8649
# Epoch 39/100
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.2901 - dice_coef_infection: 0.7322 - iou_coef_infection: 0.6029 - precision_infection: 0.7508 - recall_infection: 0.7480 - hausdorff95_infection: 29.2197 - specificity_infection: 0.9980 - accuracy_infection: 0.9961 - f1_infection: 0.8535 - val_loss: 0.3348 - val_dice_coef_infection: 0.6713 - val_iou_coef_infection: 0.6454 - val_precision_infection: 0.6784 - val_recall_infection: 0.9066 - val_hausdorff95_infection: 50.9136 - val_specificity_infection: 0.9993 - val_accuracy_infection: 0.9989 - val_f1_infection: 0.8535
# Epoch 40/100
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.2844 - dice_coef_infection: 0.7373 - iou_coef_infection: 0.6058 - precision_infection: 0.7573 - recall_infection: 0.7490 - hausdorff95_infection: 28.1718 - specificity_infection: 0.9980 - accuracy_infection: 0.9962 - f1_infection: 0.8532 - val_loss: 0.2924 - val_dice_coef_infection: 0.7151 - val_iou_coef_infection: 0.6898 - val_precision_infection: 0.7181 - val_recall_infection: 0.9134 - val_hausdorff95_infection: 46.1454 - val_specificity_infection: 0.9991 - val_accuracy_infection: 0.9988 - val_f1_infection: 0.8762
# Epoch 41/100
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.2897 - dice_coef_infection: 0.7318 - iou_coef_infection: 0.6012 - precision_infection: 0.7441 - recall_infection: 0.7531 - hausdorff95_infection: 28.2419 - specificity_infection: 0.9980 - accuracy_infection: 0.9963 - f1_infection: 0.8529 - val_loss: 0.3421 - val_dice_coef_infection: 0.6644 - val_iou_coef_infection: 0.6369 - val_precision_infection: 0.6624 - val_recall_infection: 0.9179 - val_hausdorff95_infection: 65.4773 - val_specificity_infection: 0.9991 - val_accuracy_infection: 0.9987 - val_f1_infection: 0.8472
# Epoch 42/100
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.2751 - dice_coef_infection: 0.7468 - iou_coef_infection: 0.6171 - precision_infection: 0.7641 - recall_infection: 0.7575 - hausdorff95_infection: 26.1861 - specificity_infection: 0.9980 - accuracy_infection: 0.9962 - f1_infection: 0.8574 - val_loss: 0.3415 - val_dice_coef_infection: 0.6662 - val_iou_coef_infection: 0.6380 - val_precision_infection: 0.6649 - val_recall_infection: 0.9165 - val_hausdorff95_infection: 58.0313 - val_specificity_infection: 0.9989 - val_accuracy_infection: 0.9986 - val_f1_infection: 0.8469
# Epoch 43/100
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.2860 - dice_coef_infection: 0.7356 - iou_coef_infection: 0.6111 - precision_infection: 0.7609 - recall_infection: 0.7474 - hausdorff95_infection: 28.8073 - specificity_infection: 0.9980 - accuracy_infection: 0.9962 - f1_infection: 0.8570 - val_loss: 0.3704 - val_dice_coef_infection: 0.6365 - val_iou_coef_infection: 0.6106 - val_precision_infection: 0.6345 - val_recall_infection: 0.9145 - val_hausdorff95_infection: 74.8450 - val_specificity_infection: 0.9991 - val_accuracy_infection: 0.9987 - val_f1_infection: 0.8373
# Epoch 44/100
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.2826 - dice_coef_infection: 0.7400 - iou_coef_infection: 0.6097 - precision_infection: 0.7567 - recall_infection: 0.7556 - hausdorff95_infection: 30.0536 - specificity_infection: 0.9980 - accuracy_infection: 0.9962 - f1_infection: 0.8549 - val_loss: 0.3197 - val_dice_coef_infection: 0.6886 - val_iou_coef_infection: 0.6613 - val_precision_infection: 0.6891 - val_recall_infection: 0.9157 - val_hausdorff95_infection: 52.4469 - val_specificity_infection: 0.9988 - val_accuracy_infection: 0.9985 - val_f1_infection: 0.8615
# Epoch 45/100
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.2746 - dice_coef_infection: 0.7462 - iou_coef_infection: 0.6191 - precision_infection: 0.7626 - recall_infection: 0.7583 - hausdorff95_infection: 27.4905 - specificity_infection: 0.9981 - accuracy_infection: 0.9964 - f1_infection: 0.8593 - val_loss: 0.2306 - val_dice_coef_infection: 0.7758 - val_iou_coef_infection: 0.7524 - val_precision_infection: 0.7953 - val_recall_infection: 0.8977 - val_hausdorff95_infection: 28.1814 - val_specificity_infection: 0.9996 - val_accuracy_infection: 0.9990 - val_f1_infection: 0.9075
# Epoch 46/100
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.2733 - dice_coef_infection: 0.7475 - iou_coef_infection: 0.6187 - precision_infection: 0.7593 - recall_infection: 0.7660 - hausdorff95_infection: 25.9419 - specificity_infection: 0.9980 - accuracy_infection: 0.9963 - f1_infection: 0.8577 - val_loss: 0.3227 - val_dice_coef_infection: 0.6857 - val_iou_coef_infection: 0.6563 - val_precision_infection: 0.6798 - val_recall_infection: 0.9205 - val_hausdorff95_infection: 64.7287 - val_specificity_infection: 0.9987 - val_accuracy_infection: 0.9983 - val_f1_infection: 0.8562
# Epoch 47/100
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.2895 - dice_coef_infection: 0.7333 - iou_coef_infection: 0.6031 - precision_infection: 0.7575 - recall_infection: 0.7462 - hausdorff95_infection: 26.7315 - specificity_infection: 0.9981 - accuracy_infection: 0.9962 - f1_infection: 0.8515 - val_loss: 0.2649 - val_dice_coef_infection: 0.7412 - val_iou_coef_infection: 0.7163 - val_precision_infection: 0.7502 - val_recall_infection: 0.9131 - val_hausdorff95_infection: 26.1964 - val_specificity_infection: 0.9993 - val_accuracy_infection: 0.9989 - val_f1_infection: 0.8911
# Epoch 48/100
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.2798 - dice_coef_infection: 0.7430 - iou_coef_infection: 0.6126 - precision_infection: 0.7652 - recall_infection: 0.7494 - hausdorff95_infection: 27.0007 - specificity_infection: 0.9981 - accuracy_infection: 0.9963 - f1_infection: 0.8562 - val_loss: 0.2942 - val_dice_coef_infection: 0.7130 - val_iou_coef_infection: 0.6854 - val_precision_infection: 0.7143 - val_recall_infection: 0.9169 - val_hausdorff95_infection: 37.9472 - val_specificity_infection: 0.9988 - val_accuracy_infection: 0.9985 - val_f1_infection: 0.8738
# Epoch 49/100
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0001.
# 1143/1143 [==============================] - 175s 153ms/step - loss: 0.2607 - dice_coef_infection: 0.7598 - iou_coef_infection: 0.6333 - precision_infection: 0.7784 - recall_infection: 0.7705 - hausdorff95_infection: 24.7408 - specificity_infection: 0.9981 - accuracy_infection: 0.9964 - f1_infection: 0.8625 - val_loss: 0.3425 - val_dice_coef_infection: 0.6639 - val_iou_coef_infection: 0.6348 - val_precision_infection: 0.6629 - val_recall_infection: 0.9123 - val_hausdorff95_infection: 59.7139 - val_specificity_infection: 0.9990 - val_accuracy_infection: 0.9986 - val_f1_infection: 0.8461
# 🛑 Early stopping at epoch 49
# ✅ Total training time: 8601.95 seconds (143.37 minutes)

# %% [markdown]
# ## Plotting the performance metrics

# %%
plt.plot(history.history['dice_coef_infection'])
plt.plot(history.history['val_dice_coef_infection'])
plt.title('dice_coef_infection vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Dice_coef')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# %%
plt.plot(history.history['iou_coef_infection'])
plt.plot(history.history['val_iou_coef_infection'])
plt.title('iou_coef_infection vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Iou_coef')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Val'], loc = 'upper right')
plt.show()

# %% [markdown]
# ## Using our trained model for prediction

# %%
import numpy as np
import time

# Start timer (high precision)
start_time = time.perf_counter()

# Evaluate the model on the validation generator
results = model.evaluate(val_gen, verbose=1)

# End timer
end_time = time.perf_counter()

# Calculate evaluation time
eval_time = end_time - start_time

# Print metric names with results
print("\n===== Validation Metrics =====")
for name, value in zip(model.metrics_names, results):
    print(f"{name}: {value:.6f}")

print(f"\nEvaluation Time: {eval_time:.8f} seconds\n")
# Out:
# 128/128 [==============================] - 8s 59ms/step - loss: 0.3393 - dice_coef_infection: 0.6941 - iou_coef_infection: 0.6473 - precision_infection: 0.7972 - recall_infection: 0.7657 - hausdorff95_infection: 46.4037 - specificity_infection: 0.9988 - accuracy_infection: 0.9963 - f1_infection: 0.8611
#
# ===== Validation Metrics =====
# loss: 0.339336
# dice_coef_infection: 0.694129
# iou_coef_infection: 0.647265
# precision_infection: 0.797171
# recall_infection: 0.765723
# hausdorff95_infection: 46.403671
# specificity_infection: 0.998791
# accuracy_infection: 0.996260
# f1_infection: 0.861096
#
# Evaluation Time: 7.58821582 seconds

# %%
import matplotlib.pyplot as plt
import numpy as np

# Run inference if not already done
predicted = model.predict(lung_test)

# Selected indices to visualize (744 as 1st, 280 as 2nd, 230 as 3rd)
selected_indices = [744, 280, 230]
n_samples = len(selected_indices)

# Mapping indices to custom names
name_mapping = {
    0: ("Image1_Covid", "GT1_Covid", "Predict1_Covid_DSEG_Unet"),  # Index 744
    1: ("Image2_Covid", "GT2_Covid", "Predict2_Covid_DSEG_Unet"),  # Index 280
    2: ("Image3_Covid", "GT3_Covid", "Predict3_Covid_DSEG_Unet")   # Index 230
}

# Plot
for j, i in enumerate(selected_indices):
    lung_img = lung_test[i][..., 0].astype(np.float32)
    gt_infect = (infect_test[i][..., 0] > 0.5).astype(np.float32)
    pred_infect = predicted[i][..., 0].astype(np.float32)

    # Normalize lung image
    if lung_img.max() > lung_img.min():
        lung_img = (lung_img - lung_img.min()) / (lung_img.max() - lung_img.min())
    lung_img = np.clip(lung_img, 0, 1)
    pred_infect = np.clip(pred_infect, 0, 1)

    # Get custom names for this index
    input_name, gt_name, pred_name = name_mapping[j]

    # Save Original Lung
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{input_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

    # Save Ground Truth Infection
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.imshow(gt_infect, cmap='Reds', alpha=0.6)
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{gt_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

    # Save Predicted Infection
    fig, ax = plt.subplots(figsize=(320/300, 320/300), dpi=300)
    ax.imshow(lung_img, cmap='bone')
    ax.imshow(pred_infect, cmap='Reds', alpha=0.6)
    ax.axis('off')
    fig.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(f'{pred_name}.jpeg', dpi=300, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

print("Separate JPEG files saved for input images (Image1_Covid, Image2_Covid, Image3_Covid), "
      "ground truths (GT1_Covid, GT2_Covid, GT3_Covid), and predictions "
      "(Predict1_Covid_DSEG_Unet, Predict2_Covid_DSEG_Unet, Predict3_Covid_DSEG_Unet).")
# Out:
# Separate JPEG files saved for input images (Image1_Covid, Image2_Covid, Image3_Covid), ground truths (GT1_Covid, GT2_Covid, GT3_Covid), and predictions (Predict1_Covid_DSEG_Unet, Predict2_Covid_DSEG_Unet, Predict3_Covid_DSEG_Unet).
